# %% [markdown]
# # Benchmark v5 — GPU — BACE — scaffold split, seed 0
#
# **Task:** Binary — binds BACE-1 (1) or not (0)
# **Size:** ~1,513 molecules
# **Metric:** ROC-AUC ↑
#
# **Scaffold split**, seed **0** — GIN, D-MPNN, SchNet, LSTM with Optuna HPO.
#
# Results go to `results/seed_0/scaffold/`.

# %%
# NOTE: autoreload is intentionally NOT enabled. With C-extension packages
# (numpy, torch, torch_geometric) `%autoreload 2` reloads them mid-run and
# corrupts their state (numpy RecursionError / torch_geometric circular
# import). If you edit the benchmark modules, restart the kernel instead.
import os
# Avoid XGBoost/OpenMP segfaults in Jupyter on macOS (OMP Error #179).
for _omp_var in (
    "OMP_NUM_THREADS",
    "OPENBLAS_NUM_THREADS",
    "MKL_NUM_THREADS",
    "VECLIB_MAXIMUM_THREADS",
    "NUMEXPR_NUM_THREADS",
):
    os.environ[_omp_var] = "1"

import sys
from pathlib import Path

ROOT = Path(".").resolve()
for _ in range(6):
    if (ROOT / "mol_repr_utils.py").exists():
        break
    ROOT = ROOT.parent
else:
    raise FileNotFoundError("Could not find benchmark_v5 root (mol_repr_utils.py)")
sys.path.insert(0, str(ROOT))

from mol_repr_utils import *
from split_utils import (
    get_or_create_splits, subset_array, subset_list, subset_graphs_by_valid_idx,
    check_split_proportions,
)
from conformer_generation import load_conformer_graphs
from hpo_utils import (
    hpo_tabular, hpo_gnn, hpo_schnet, hpo_lstm,
    save_hpo_params, hpo_params_path,
)
from hpo_config import SKLEARN_HPO_N_ITER

DATA_DIR = ROOT / "data"

DEVICE = get_device()
print(f"Benchmark v5 (GPU) code root: {ROOT}")
print(f"Device: {DEVICE}")
print("Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.")
# Out:
# INFO | Using device: cpu (request a GPU node on the cluster for large GNN/LSTM jobs)
# Benchmark v5 (GPU) code root: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5
# Device: cpu
# Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.

# %%
DATASET_SLUG = "bace"
TASK_TYPE = "classification"
OUT_CHANNELS = 1
BATCH_SIZE = 32
GNN_EPOCHS = 100
LSTM_EPOCHS = 100
TOX21_TABULAR = False

HPO_EPOCHS = 80  # Optuna trial length; GNN_EPOCHS for final refit
HPO_N_TRIALS = 20
print(f"GPU HPO tier: standard — {HPO_N_TRIALS} trials, {HPO_EPOCHS} epochs/trial, batch={BATCH_SIZE}")

SPLIT_MODE = "scaffold"   # "scaffold" or "random"
SPLIT_SEED = 0

RESULTS_ROOT = ROOT / "results" / f"seed_{SPLIT_SEED}" / SPLIT_MODE
RESULTS_DIR = RESULTS_ROOT / "gpu"
SPLITS_DIR = RESULTS_ROOT / "splits"
HPO_DIR = RESULTS_DIR / "hpo"
HISTORY_DIR = RESULTS_DIR / "histories"
for d in (RESULTS_DIR, SPLITS_DIR, HPO_DIR, HISTORY_DIR):
    d.mkdir(parents=True, exist_ok=True)
print(f"Results → {RESULTS_ROOT}")

PARTIAL_PATH = RESULTS_DIR / f"{DATASET_SLUG}_partial.json"
FRESH_RUN = False
HPO_N_ITER = SKLEARN_HPO_N_ITER

if FRESH_RUN:
    reset_dataset_run(
        DATASET_SLUG, RESULTS_DIR,
        results_root=RESULTS_ROOT, split_mode=SPLIT_MODE,
    )
    print("Fresh run — cleared partial results and splits.")

results = load_partial_results(PARTIAL_PATH)
if results:
    print(f"Resuming {len(results)} saved model(s): {', '.join(order_results(results).keys())}")
print(f"SPLIT_SEED={SPLIT_SEED}  mode={SPLIT_MODE}")
# Out:
# GPU HPO tier: standard — 20 trials, 80 epochs/trial, batch=32
# Results → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold
# Resuming 1 saved model(s): GIN (2D)
# SPLIT_SEED=0  mode=scaffold

# %% [markdown]
# ### Load data

# %%
import numpy as np
import pandas as pd

df = load_dataset("bace", cache_dir=DATA_DIR)
smiles, y = preprocess_dataset(df, "bace")
print(f"Molecules : {len(smiles)}")
print(f"Class balance: {np.bincount(y.astype(int))}")
smiles, y = filter_bonded_molecules(smiles, y)
print(f'After bond filter: {len(smiles)} molecules')
# Out:
# INFO | Loading 'bace' from cache: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace.csv
# INFO | [bace] 1513 / 1513 valid molecules
# Molecules : 1513
# Class balance: [822 691]
# After bond filter: 1513 molecules

# %% [markdown]
# ### Representations & scaffold split

# %%
graphs2d_all = smiles_to_graphs(smiles, y)
graphs_dmpnn_all = smiles_to_dmpnn_graphs(smiles, y)
X_tok_all, vocab = tokenize_smiles(smiles)

graphs3d_all, valid_idx_3d, _ = load_conformer_graphs(
    DATASET_SLUG, data_dir=DATA_DIR, n_confs=25
)
graphs3d_all = ensure_atomic_numbers_list(graphs3d_all)
print(f"3D graphs loaded: {len(graphs3d_all)} / {len(smiles)} (valid_idx mapping)")

split_data = get_or_create_splits(
    smiles, RESULTS_ROOT, DATASET_SLUG,
    mode=SPLIT_MODE, seed=SPLIT_SEED, force=FRESH_RUN,
)
train_idx = split_data["train_idx"]
val_idx = split_data["val_idx"]
test_idx = split_data["test_idx"]
check_split_proportions(train_idx, val_idx, test_idx, raise_on_fail=True)
print(split_data["summary"])

tr2d = subset_list(graphs2d_all, train_idx)
va2d = subset_list(graphs2d_all, val_idx)
te2d = subset_list(graphs2d_all, test_idx)

tr_dmpnn = subset_list(graphs_dmpnn_all, train_idx)
va_dmpnn = subset_list(graphs_dmpnn_all, val_idx)
te_dmpnn = subset_list(graphs_dmpnn_all, test_idx)

tr3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, train_idx)
va3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, val_idx)
te3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, test_idx)

tr_ds = SMILESDataset(subset_array(X_tok_all, train_idx), subset_array(y, train_idx))
va_ds = SMILESDataset(subset_array(X_tok_all, val_idx), subset_array(y, val_idx))
te_ds = SMILESDataset(subset_array(X_tok_all, test_idx), subset_array(y, test_idx))
# Out:
# INFO | Loaded 1513 / 1513 graphs from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace_conformers_n25.pkl  (n_confs=25)
# INFO | Loaded splits from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/splits/bace_scaffold_splits.pkl
# 3D graphs loaded: 1513 / 1513 (valid_idx mapping)
# {'n_total': 1513, 'n_train': 1210, 'n_val': 151, 'n_test': 152, 'n_scaffolds_total': 671, 'n_scaffolds_train': 368, 'n_scaffolds_val': 151, 'n_scaffolds_test': 152}

# %% [markdown]
# ### GIN (2D)

# %%
MODEL_KEY = "GIN (2D)"
tr = tr3d if "2D" == "3D" else tr2d
va = va3d if "2D" == "3D" else va2d
te = te3d if "2D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (2D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# Skipping GIN (2D)

# %% [markdown]
# ### D-MPNN (2D)
# Bond-centric directed MPNN (Yang et al. 2019).

# %%
MODEL_KEY = "D-MPNN (2D)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr_dmpnn, va_dmpnn, TASK_TYPE, "DMPNN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("DMPNN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr_dmpnn, va_dmpnn, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te_dmpnn, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_dmpnn.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | DMPNN 2D — starting trial 1/20 (layers=5, hidden=192)
# → D-MPNN (2D) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=1.1714 | val={'ROC-AUC': 0.5782178217821783, 'PRC-AUC': 0.40183681661021164}
# INFO | HPO epoch   5/80 | loss=0.6660 | val={'ROC-AUC': 0.7687128712871287, 'PRC-AUC': 0.6324712069943963}
# INFO | HPO epoch  10/80 | loss=0.5918 | val={'ROC-AUC': 0.7671287128712871, 'PRC-AUC': 0.6246618172796515}
# INFO | HPO epoch  15/80 | loss=0.5490 | val={'ROC-AUC': 0.7867326732673268, 'PRC-AUC': 0.653283075897833}
# INFO | HPO epoch  20/80 | loss=0.5204 | val={'ROC-AUC': 0.7895049504950494, 'PRC-AUC': 0.6623729580640477}
# INFO | HPO epoch  25/80 | loss=0.5136 | val={'ROC-AUC': 0.7659405940594061, 'PRC-AUC': 0.6423260862625464}
# INFO | HPO epoch  30/80 | loss=0.4976 | val={'ROC-AUC': 0.8083168316831684, 'PRC-AUC': 0.677794088385904}
# INFO | HPO epoch  35/80 | loss=0.4738 | val={'ROC-AUC': 0.8306930693069307, 'PRC-AUC': 0.7048927928522242}
# INFO | HPO epoch  40/80 | loss=0.4630 | val={'ROC-AUC': 0.8166336633663366, 'PRC-AUC': 0.6908865692617436}
# INFO | HPO epoch  45/80 | loss=0.4365 | val={'ROC-AUC': 0.8356435643564356, 'PRC-AUC': 0.6996689928720619}
# INFO | HPO epoch  50/80 | loss=0.4506 | val={'ROC-AUC': 0.8499009900990099, 'PRC-AUC': 0.714380801482256}
# INFO | HPO epoch  55/80 | loss=0.4308 | val={'ROC-AUC': 0.8469306930693069, 'PRC-AUC': 0.6980128473128004}
# INFO | HPO epoch  60/80 | loss=0.3962 | val={'ROC-AUC': 0.827920792079208, 'PRC-AUC': 0.6716691258917505}
# INFO | Early stop at epoch 64 (patience=15)
# INFO | DMPNN 2D HPO — trial 1/20 finished | val=-0.851089 | best=-0.851089
# INFO | DMPNN 2D — starting trial 2/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=1.1999 | val={'ROC-AUC': 0.43326732673267326, 'PRC-AUC': 0.3295975810117046}
# INFO | HPO epoch   5/80 | loss=0.6418 | val={'ROC-AUC': 0.6970297029702971, 'PRC-AUC': 0.5504599940289698}
# INFO | HPO epoch  10/80 | loss=0.5264 | val={'ROC-AUC': 0.7671287128712871, 'PRC-AUC': 0.6773205995633093}
# INFO | HPO epoch  15/80 | loss=0.4787 | val={'ROC-AUC': 0.7726732673267327, 'PRC-AUC': 0.6380638762926371}
# INFO | HPO epoch  20/80 | loss=0.4461 | val={'ROC-AUC': 0.7940594059405941, 'PRC-AUC': 0.6524721717790307}
# INFO | HPO epoch  25/80 | loss=0.4346 | val={'ROC-AUC': 0.8093069306930694, 'PRC-AUC': 0.6848097774627991}
# INFO | HPO epoch  30/80 | loss=0.3899 | val={'ROC-AUC': 0.8019801980198019, 'PRC-AUC': 0.6559231117364155}
# INFO | HPO epoch  35/80 | loss=0.3827 | val={'ROC-AUC': 0.8146534653465346, 'PRC-AUC': 0.7012772463963972}
# INFO | HPO epoch  40/80 | loss=0.3485 | val={'ROC-AUC': 0.8140594059405941, 'PRC-AUC': 0.689913484135869}
# INFO | HPO epoch  45/80 | loss=0.3475 | val={'ROC-AUC': 0.8095049504950496, 'PRC-AUC': 0.6809667103239438}
# INFO | HPO epoch  50/80 | loss=0.3238 | val={'ROC-AUC': 0.8154455445544555, 'PRC-AUC': 0.7049249402799619}
# INFO | HPO epoch  55/80 | loss=0.3370 | val={'ROC-AUC': 0.8003960396039604, 'PRC-AUC': 0.6768545230471223}
# INFO | Early stop at epoch 59 (patience=15)
# INFO | DMPNN 2D HPO — trial 2/20 finished | val=-0.833465 | best=-0.851089
# INFO | DMPNN 2D — starting trial 3/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.7317 | val={'ROC-AUC': 0.6097029702970298, 'PRC-AUC': 0.45996116585862584}
# INFO | HPO epoch   5/80 | loss=0.5924 | val={'ROC-AUC': 0.7966336633663367, 'PRC-AUC': 0.6542563201055436}
# INFO | HPO epoch  10/80 | loss=0.5236 | val={'ROC-AUC': 0.785940594059406, 'PRC-AUC': 0.6553358185376325}
# INFO | HPO epoch  15/80 | loss=0.4988 | val={'ROC-AUC': 0.801980198019802, 'PRC-AUC': 0.663236594458297}
# INFO | HPO epoch  20/80 | loss=0.4921 | val={'ROC-AUC': 0.7885148514851485, 'PRC-AUC': 0.6571787188691507}
# INFO | HPO epoch  25/80 | loss=0.4320 | val={'ROC-AUC': 0.8168316831683169, 'PRC-AUC': 0.6418345709014432}
# INFO | HPO epoch  30/80 | loss=0.4197 | val={'ROC-AUC': 0.8443564356435643, 'PRC-AUC': 0.7006287916813093}
# INFO | HPO epoch  35/80 | loss=0.4123 | val={'ROC-AUC': 0.8302970297029704, 'PRC-AUC': 0.678651684609225}
# INFO | HPO epoch  40/80 | loss=0.3985 | val={'ROC-AUC': 0.8328712871287128, 'PRC-AUC': 0.6963807455672338}
# INFO | HPO epoch  45/80 | loss=0.4015 | val={'ROC-AUC': 0.8045544554455446, 'PRC-AUC': 0.6354137631971165}
# INFO | HPO epoch  50/80 | loss=0.3732 | val={'ROC-AUC': 0.8221782178217822, 'PRC-AUC': 0.6967458005648856}
# INFO | Early stop at epoch 52 (patience=15)
# INFO | DMPNN 2D HPO — trial 3/20 finished | val=-0.845743 | best=-0.851089
# INFO | DMPNN 2D — starting trial 4/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8978 | val={'ROC-AUC': 0.7233663366336633, 'PRC-AUC': 0.5548934171326084}
# INFO | HPO epoch   5/80 | loss=0.6302 | val={'ROC-AUC': 0.7954455445544554, 'PRC-AUC': 0.6498049986922529}
# INFO | HPO epoch  10/80 | loss=0.5505 | val={'ROC-AUC': 0.7865346534653466, 'PRC-AUC': 0.6422354165624792}
# INFO | HPO epoch  15/80 | loss=0.5096 | val={'ROC-AUC': 0.809108910891089, 'PRC-AUC': 0.6574659961578959}
# INFO | HPO epoch  20/80 | loss=0.4764 | val={'ROC-AUC': 0.7960396039603961, 'PRC-AUC': 0.6684376175171519}
# INFO | HPO epoch  25/80 | loss=0.4633 | val={'ROC-AUC': 0.82, 'PRC-AUC': 0.6873995555631396}
# INFO | HPO epoch  30/80 | loss=0.4312 | val={'ROC-AUC': 0.8172277227722773, 'PRC-AUC': 0.6830947263947849}
# INFO | HPO epoch  35/80 | loss=0.4057 | val={'ROC-AUC': 0.832079207920792, 'PRC-AUC': 0.7060418082734331}
# INFO | HPO epoch  40/80 | loss=0.3995 | val={'ROC-AUC': 0.8308910891089109, 'PRC-AUC': 0.7017219943142416}
# INFO | HPO epoch  45/80 | loss=0.3770 | val={'ROC-AUC': 0.8324752475247524, 'PRC-AUC': 0.7082498256541496}
# INFO | HPO epoch  50/80 | loss=0.3608 | val={'ROC-AUC': 0.8326732673267326, 'PRC-AUC': 0.7140042619238932}
# INFO | HPO epoch  55/80 | loss=0.3542 | val={'ROC-AUC': 0.8285148514851486, 'PRC-AUC': 0.7042718455514551}
# INFO | Early stop at epoch 58 (patience=15)
# INFO | DMPNN 2D HPO — trial 4/20 finished | val=-0.847327 | best=-0.851089
# INFO | DMPNN 2D — starting trial 5/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8478 | val={'ROC-AUC': 0.7308910891089109, 'PRC-AUC': 0.5886441336655998}
# INFO | HPO epoch   5/80 | loss=0.6272 | val={'ROC-AUC': 0.7647524752475248, 'PRC-AUC': 0.6304130271751311}
# INFO | HPO epoch  10/80 | loss=0.5599 | val={'ROC-AUC': 0.8027722772277228, 'PRC-AUC': 0.6801751492179845}
# INFO | HPO epoch  15/80 | loss=0.5201 | val={'ROC-AUC': 0.7665346534653465, 'PRC-AUC': 0.6712846466751424}
# INFO | HPO epoch  20/80 | loss=0.4809 | val={'ROC-AUC': 0.8087128712871288, 'PRC-AUC': 0.689381497241228}
# INFO | HPO epoch  25/80 | loss=0.4720 | val={'ROC-AUC': 0.8392079207920792, 'PRC-AUC': 0.7216170723891487}
# INFO | HPO epoch  30/80 | loss=0.4476 | val={'ROC-AUC': 0.841980198019802, 'PRC-AUC': 0.7195802545706395}
# INFO | HPO epoch  35/80 | loss=0.4346 | val={'ROC-AUC': 0.8453465346534653, 'PRC-AUC': 0.7234276944614797}
# INFO | HPO epoch  40/80 | loss=0.4259 | val={'ROC-AUC': 0.858019801980198, 'PRC-AUC': 0.7342544665368986}
# INFO | HPO epoch  45/80 | loss=0.4064 | val={'ROC-AUC': 0.853069306930693, 'PRC-AUC': 0.7091214945657658}
# INFO | HPO epoch  50/80 | loss=0.3925 | val={'ROC-AUC': 0.8435643564356435, 'PRC-AUC': 0.7254132446116226}
# INFO | HPO epoch  55/80 | loss=0.4011 | val={'ROC-AUC': 0.8522772277227724, 'PRC-AUC': 0.7104090451662969}
# INFO | HPO epoch  60/80 | loss=0.3917 | val={'ROC-AUC': 0.8493069306930693, 'PRC-AUC': 0.711616647377226}
# INFO | Early stop at epoch 64 (patience=15)
# INFO | DMPNN 2D HPO — trial 5/20 finished | val=-0.862178 | best=-0.862178
# INFO | DMPNN 2D — starting trial 6/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.7556 | val={'ROC-AUC': 0.5720792079207921, 'PRC-AUC': 0.47163775074397707}
# INFO | HPO epoch   5/80 | loss=0.6557 | val={'ROC-AUC': 0.6720792079207921, 'PRC-AUC': 0.5246815402993608}
# INFO | HPO epoch  10/80 | loss=0.6161 | val={'ROC-AUC': 0.7364356435643564, 'PRC-AUC': 0.5804731331556666}
# INFO | HPO epoch  15/80 | loss=0.6138 | val={'ROC-AUC': 0.7461386138613861, 'PRC-AUC': 0.598718395960913}
# INFO | HPO epoch  20/80 | loss=0.5627 | val={'ROC-AUC': 0.7510891089108911, 'PRC-AUC': 0.6090139778386006}
# INFO | HPO epoch  25/80 | loss=0.5402 | val={'ROC-AUC': 0.7576237623762376, 'PRC-AUC': 0.6229823474096778}
# INFO | HPO epoch  30/80 | loss=0.5302 | val={'ROC-AUC': 0.7843564356435643, 'PRC-AUC': 0.6381087049714891}
# INFO | HPO epoch  35/80 | loss=0.5097 | val={'ROC-AUC': 0.7548514851485149, 'PRC-AUC': 0.6249885798899687}
# INFO | HPO epoch  40/80 | loss=0.5065 | val={'ROC-AUC': 0.783960396039604, 'PRC-AUC': 0.6513190891253298}
# INFO | HPO epoch  45/80 | loss=0.5061 | val={'ROC-AUC': 0.7928712871287128, 'PRC-AUC': 0.621557379171596}
# INFO | HPO epoch  50/80 | loss=0.4852 | val={'ROC-AUC': 0.7906930693069306, 'PRC-AUC': 0.6345956717900603}
# INFO | HPO epoch  55/80 | loss=0.4988 | val={'ROC-AUC': 0.7881188118811882, 'PRC-AUC': 0.6462147549912005}
# INFO | HPO epoch  60/80 | loss=0.4591 | val={'ROC-AUC': 0.7916831683168317, 'PRC-AUC': 0.6212794586780179}
# INFO | Early stop at epoch 62 (patience=15)
# INFO | DMPNN 2D HPO — trial 6/20 finished | val=-0.805941 | best=-0.862178
# INFO | DMPNN 2D — starting trial 7/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8046 | val={'ROC-AUC': 0.7102970297029704, 'PRC-AUC': 0.5865804002321706}
# INFO | HPO epoch   5/80 | loss=0.6245 | val={'ROC-AUC': 0.7475247524752475, 'PRC-AUC': 0.6155336226357877}
# INFO | HPO epoch  10/80 | loss=0.5297 | val={'ROC-AUC': 0.8005940594059405, 'PRC-AUC': 0.6675031736599549}
# INFO | HPO epoch  15/80 | loss=0.4860 | val={'ROC-AUC': 0.7857425742574258, 'PRC-AUC': 0.6839291324614871}
# INFO | HPO epoch  20/80 | loss=0.4747 | val={'ROC-AUC': 0.8251485148514851, 'PRC-AUC': 0.6994233189736027}
# INFO | HPO epoch  25/80 | loss=0.4376 | val={'ROC-AUC': 0.8013861386138614, 'PRC-AUC': 0.6771726138849219}
# INFO | HPO epoch  30/80 | loss=0.4153 | val={'ROC-AUC': 0.8354455445544555, 'PRC-AUC': 0.7089714182951179}
# INFO | HPO epoch  35/80 | loss=0.4049 | val={'ROC-AUC': 0.8225742574257425, 'PRC-AUC': 0.6877029227652928}
# INFO | HPO epoch  40/80 | loss=0.3732 | val={'ROC-AUC': 0.8178217821782179, 'PRC-AUC': 0.6846503065995344}
# INFO | HPO epoch  45/80 | loss=0.3615 | val={'ROC-AUC': 0.811089108910891, 'PRC-AUC': 0.6765695924275863}
# INFO | HPO epoch  50/80 | loss=0.3381 | val={'ROC-AUC': 0.8152475247524753, 'PRC-AUC': 0.6741796145235781}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | DMPNN 2D HPO — trial 7/20 finished | val=-0.845347 | best=-0.862178
# INFO | DMPNN 2D — starting trial 8/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8181 | val={'ROC-AUC': 0.6479207920792079, 'PRC-AUC': 0.5017644956872387}
# INFO | HPO epoch   5/80 | loss=0.6252 | val={'ROC-AUC': 0.7752475247524752, 'PRC-AUC': 0.6621365616135731}
# INFO | HPO epoch  10/80 | loss=0.5440 | val={'ROC-AUC': 0.7708910891089109, 'PRC-AUC': 0.6426665179741483}
# INFO | HPO epoch  15/80 | loss=0.4742 | val={'ROC-AUC': 0.806930693069307, 'PRC-AUC': 0.636195294796923}
# INFO | HPO epoch  20/80 | loss=0.4413 | val={'ROC-AUC': 0.8114851485148514, 'PRC-AUC': 0.6665672696715038}
# INFO | HPO epoch  25/80 | loss=0.4014 | val={'ROC-AUC': 0.8158415841584158, 'PRC-AUC': 0.6877803100863047}
# INFO | HPO epoch  30/80 | loss=0.3958 | val={'ROC-AUC': 0.7960396039603961, 'PRC-AUC': 0.6355765871139414}
# INFO | HPO epoch  35/80 | loss=0.3734 | val={'ROC-AUC': 0.8174257425742575, 'PRC-AUC': 0.6711099622378106}
# INFO | HPO epoch  40/80 | loss=0.3530 | val={'ROC-AUC': 0.8021782178217821, 'PRC-AUC': 0.647580589327031}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | DMPNN 2D HPO — trial 8/20 finished | val=-0.839802 | best=-0.862178
# INFO | DMPNN 2D — starting trial 9/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.2449 | val={'ROC-AUC': 0.5150495049504951, 'PRC-AUC': 0.41796544302827493}
# INFO | HPO epoch   5/80 | loss=0.6198 | val={'ROC-AUC': 0.6902970297029702, 'PRC-AUC': 0.6003065823385716}
# INFO | HPO epoch  10/80 | loss=0.5499 | val={'ROC-AUC': 0.7009900990099011, 'PRC-AUC': 0.6295850951117782}
# INFO | HPO epoch  15/80 | loss=0.5156 | val={'ROC-AUC': 0.7081188118811881, 'PRC-AUC': 0.6155349891257482}
# INFO | HPO epoch  20/80 | loss=0.4912 | val={'ROC-AUC': 0.7334653465346535, 'PRC-AUC': 0.6321129870558535}
# INFO | HPO epoch  25/80 | loss=0.4588 | val={'ROC-AUC': 0.7344554455445544, 'PRC-AUC': 0.6370522445243005}
# INFO | HPO epoch  30/80 | loss=0.4264 | val={'ROC-AUC': 0.7693069306930693, 'PRC-AUC': 0.6777574299283602}
# INFO | HPO epoch  35/80 | loss=0.4173 | val={'ROC-AUC': 0.7851485148514852, 'PRC-AUC': 0.6565805146760446}
# INFO | HPO epoch  40/80 | loss=0.4093 | val={'ROC-AUC': 0.7984158415841585, 'PRC-AUC': 0.6706440589214413}
# INFO | HPO epoch  45/80 | loss=0.3837 | val={'ROC-AUC': 0.7954455445544555, 'PRC-AUC': 0.6874089588883714}
# INFO | HPO epoch  50/80 | loss=0.3892 | val={'ROC-AUC': 0.7940594059405941, 'PRC-AUC': 0.6929473993204354}
# INFO | HPO epoch  55/80 | loss=0.3686 | val={'ROC-AUC': 0.8203960396039605, 'PRC-AUC': 0.7018062454339182}
# INFO | HPO epoch  60/80 | loss=0.3652 | val={'ROC-AUC': 0.810891089108911, 'PRC-AUC': 0.7029551457592806}
# INFO | HPO epoch  65/80 | loss=0.3308 | val={'ROC-AUC': 0.81009900990099, 'PRC-AUC': 0.7160125724624696}
# INFO | Early stop at epoch 66 (patience=15)
# INFO | DMPNN 2D HPO — trial 9/20 finished | val=-0.825545 | best=-0.862178
# INFO | DMPNN 2D — starting trial 10/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.8287 | val={'ROC-AUC': 0.5938613861386138, 'PRC-AUC': 0.4238974293611948}
# INFO | HPO epoch   5/80 | loss=0.6294 | val={'ROC-AUC': 0.7532673267326734, 'PRC-AUC': 0.6219366753348843}
# INFO | HPO epoch  10/80 | loss=0.5244 | val={'ROC-AUC': 0.8174257425742574, 'PRC-AUC': 0.7016507058817217}
# INFO | HPO epoch  15/80 | loss=0.4676 | val={'ROC-AUC': 0.8162376237623763, 'PRC-AUC': 0.6586048928881498}
# INFO | HPO epoch  20/80 | loss=0.4313 | val={'ROC-AUC': 0.8403960396039604, 'PRC-AUC': 0.703856605718217}
# INFO | HPO epoch  25/80 | loss=0.4141 | val={'ROC-AUC': 0.8443564356435644, 'PRC-AUC': 0.7209384155848535}
# INFO | HPO epoch  30/80 | loss=0.3748 | val={'ROC-AUC': 0.8099009900990098, 'PRC-AUC': 0.7012504932010261}
# INFO | HPO epoch  35/80 | loss=0.3731 | val={'ROC-AUC': 0.8356435643564356, 'PRC-AUC': 0.7233449794710115}
# INFO | HPO epoch  40/80 | loss=0.3422 | val={'ROC-AUC': 0.8314851485148514, 'PRC-AUC': 0.714180123617726}
# INFO | Early stop at epoch 42 (patience=15)
# INFO | DMPNN 2D HPO — trial 10/20 finished | val=-0.857030 | best=-0.862178
# INFO | DMPNN 2D — starting trial 11/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.7389 | val={'ROC-AUC': 0.6514851485148514, 'PRC-AUC': 0.5651885907521986}
# INFO | HPO epoch   5/80 | loss=0.6909 | val={'ROC-AUC': 0.6528712871287129, 'PRC-AUC': 0.5406740514512918}
# INFO | HPO epoch  10/80 | loss=0.6121 | val={'ROC-AUC': 0.6473267326732672, 'PRC-AUC': 0.5212531266638498}
# INFO | HPO epoch  15/80 | loss=0.5746 | val={'ROC-AUC': 0.7265346534653466, 'PRC-AUC': 0.5920854364361491}
# INFO | HPO epoch  20/80 | loss=0.5582 | val={'ROC-AUC': 0.7631683168316831, 'PRC-AUC': 0.6309874997698375}
# INFO | HPO epoch  25/80 | loss=0.5317 | val={'ROC-AUC': 0.7740594059405941, 'PRC-AUC': 0.6438878024856127}
# INFO | HPO epoch  30/80 | loss=0.5028 | val={'ROC-AUC': 0.8031683168316832, 'PRC-AUC': 0.6524425545046945}
# INFO | HPO epoch  35/80 | loss=0.5040 | val={'ROC-AUC': 0.7920792079207921, 'PRC-AUC': 0.6587894096043929}
# INFO | HPO epoch  40/80 | loss=0.4833 | val={'ROC-AUC': 0.8126732673267326, 'PRC-AUC': 0.6798611187888391}
# INFO | HPO epoch  45/80 | loss=0.4897 | val={'ROC-AUC': 0.8172277227722772, 'PRC-AUC': 0.6737968453823062}
# INFO | HPO epoch  50/80 | loss=0.4993 | val={'ROC-AUC': 0.7954455445544555, 'PRC-AUC': 0.66222530905496}
# INFO | HPO epoch  55/80 | loss=0.4423 | val={'ROC-AUC': 0.82, 'PRC-AUC': 0.6593554741302282}
# INFO | HPO epoch  60/80 | loss=0.4355 | val={'ROC-AUC': 0.8150495049504951, 'PRC-AUC': 0.65665189669197}
# INFO | HPO epoch  65/80 | loss=0.4438 | val={'ROC-AUC': 0.8322772277227724, 'PRC-AUC': 0.6811842705263164}
# INFO | HPO epoch  70/80 | loss=0.4277 | val={'ROC-AUC': 0.832871287128713, 'PRC-AUC': 0.6765755078363191}
# INFO | Early stop at epoch 72 (patience=15)
# INFO | DMPNN 2D HPO — trial 11/20 finished | val=-0.834257 | best=-0.862178
# INFO | DMPNN 2D — starting trial 12/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.0285 | val={'ROC-AUC': 0.6091089108910891, 'PRC-AUC': 0.46578461025180506}
# INFO | HPO epoch   5/80 | loss=0.6101 | val={'ROC-AUC': 0.6930693069306931, 'PRC-AUC': 0.587586388913602}
# INFO | HPO epoch  10/80 | loss=0.5361 | val={'ROC-AUC': 0.787920792079208, 'PRC-AUC': 0.6910027539859995}
# INFO | HPO epoch  15/80 | loss=0.4767 | val={'ROC-AUC': 0.8431683168316831, 'PRC-AUC': 0.6912410124699578}
# INFO | HPO epoch  20/80 | loss=0.4467 | val={'ROC-AUC': 0.842970297029703, 'PRC-AUC': 0.7145543489674543}
# INFO | HPO epoch  25/80 | loss=0.4455 | val={'ROC-AUC': 0.8499009900990099, 'PRC-AUC': 0.6904033748482461}
# INFO | HPO epoch  30/80 | loss=0.4130 | val={'ROC-AUC': 0.8277227722772277, 'PRC-AUC': 0.6530396063126744}
# INFO | HPO epoch  35/80 | loss=0.3655 | val={'ROC-AUC': 0.8245544554455445, 'PRC-AUC': 0.6480005124515801}
# INFO | Early stop at epoch 37 (patience=15)
# INFO | DMPNN 2D HPO — trial 12/20 finished | val=-0.874851 | best=-0.874851
# INFO | DMPNN 2D — starting trial 13/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.9235 | val={'ROC-AUC': 0.6960396039603961, 'PRC-AUC': 0.5674637695878209}
# INFO | HPO epoch   5/80 | loss=0.6049 | val={'ROC-AUC': 0.7326732673267327, 'PRC-AUC': 0.6368001328845483}
# INFO | HPO epoch  10/80 | loss=0.5255 | val={'ROC-AUC': 0.7863366336633664, 'PRC-AUC': 0.6761422927455126}
# INFO | HPO epoch  15/80 | loss=0.4594 | val={'ROC-AUC': 0.8182178217821782, 'PRC-AUC': 0.6811881115479206}
# INFO | HPO epoch  20/80 | loss=0.4374 | val={'ROC-AUC': 0.8425742574257425, 'PRC-AUC': 0.7195303268482773}
# INFO | HPO epoch  25/80 | loss=0.4061 | val={'ROC-AUC': 0.8346534653465346, 'PRC-AUC': 0.6948005032942881}
# INFO | HPO epoch  30/80 | loss=0.3874 | val={'ROC-AUC': 0.8413861386138615, 'PRC-AUC': 0.7233412694818229}
# INFO | HPO epoch  35/80 | loss=0.3764 | val={'ROC-AUC': 0.8275247524752476, 'PRC-AUC': 0.6712754497475619}
# INFO | HPO epoch  40/80 | loss=0.3638 | val={'ROC-AUC': 0.856039603960396, 'PRC-AUC': 0.7343307643058541}
# INFO | HPO epoch  45/80 | loss=0.3459 | val={'ROC-AUC': 0.8306930693069308, 'PRC-AUC': 0.7224219774046907}
# INFO | HPO epoch  50/80 | loss=0.3210 | val={'ROC-AUC': 0.8291089108910891, 'PRC-AUC': 0.6846789858114025}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | DMPNN 2D HPO — trial 13/20 finished | val=-0.862574 | best=-0.874851
# INFO | DMPNN 2D — starting trial 14/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.9252 | val={'ROC-AUC': 0.5360396039603961, 'PRC-AUC': 0.3917553802227598}
# INFO | HPO epoch   5/80 | loss=0.6427 | val={'ROC-AUC': 0.7100990099009902, 'PRC-AUC': 0.5548469061131487}
# INFO | HPO epoch  10/80 | loss=0.5690 | val={'ROC-AUC': 0.7900990099009901, 'PRC-AUC': 0.665056592046157}
# INFO | HPO epoch  15/80 | loss=0.5075 | val={'ROC-AUC': 0.7671287128712871, 'PRC-AUC': 0.6664140714103568}
# INFO | HPO epoch  20/80 | loss=0.4438 | val={'ROC-AUC': 0.8081188118811882, 'PRC-AUC': 0.6628647582111353}
# INFO | HPO epoch  25/80 | loss=0.4208 | val={'ROC-AUC': 0.832079207920792, 'PRC-AUC': 0.7155240320433743}
# INFO | HPO epoch  30/80 | loss=0.3924 | val={'ROC-AUC': 0.8328712871287128, 'PRC-AUC': 0.7230919011745334}
# INFO | HPO epoch  35/80 | loss=0.3859 | val={'ROC-AUC': 0.8172277227722772, 'PRC-AUC': 0.7124844995113747}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | DMPNN 2D HPO — trial 14/20 finished | val=-0.847921 | best=-0.874851
# INFO | DMPNN 2D — starting trial 15/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.1576 | val={'ROC-AUC': 0.5899009900990099, 'PRC-AUC': 0.4318940693066494}
# INFO | HPO epoch   5/80 | loss=0.6247 | val={'ROC-AUC': 0.7106930693069307, 'PRC-AUC': 0.5889817960587371}
# INFO | HPO epoch  10/80 | loss=0.5430 | val={'ROC-AUC': 0.7928712871287129, 'PRC-AUC': 0.6628320314247845}
# INFO | HPO epoch  15/80 | loss=0.4864 | val={'ROC-AUC': 0.796039603960396, 'PRC-AUC': 0.6676776095633503}
# INFO | HPO epoch  20/80 | loss=0.4451 | val={'ROC-AUC': 0.8196039603960397, 'PRC-AUC': 0.6686006540337756}
# INFO | HPO epoch  25/80 | loss=0.4072 | val={'ROC-AUC': 0.8178217821782178, 'PRC-AUC': 0.7177594767400584}
# INFO | HPO epoch  30/80 | loss=0.4027 | val={'ROC-AUC': 0.8188118811881189, 'PRC-AUC': 0.7210304828462711}
# INFO | HPO epoch  35/80 | loss=0.3798 | val={'ROC-AUC': 0.8415841584158416, 'PRC-AUC': 0.7527024990798541}
# INFO | HPO epoch  40/80 | loss=0.3649 | val={'ROC-AUC': 0.8588118811881188, 'PRC-AUC': 0.7634536560862594}
# INFO | HPO epoch  45/80 | loss=0.3482 | val={'ROC-AUC': 0.8481188118811881, 'PRC-AUC': 0.734616483330453}
# INFO | HPO epoch  50/80 | loss=0.3475 | val={'ROC-AUC': 0.8241584158415841, 'PRC-AUC': 0.7197771987418582}
# INFO | HPO epoch  55/80 | loss=0.3322 | val={'ROC-AUC': 0.8196039603960397, 'PRC-AUC': 0.706751212610358}
# INFO | HPO epoch  60/80 | loss=0.3003 | val={'ROC-AUC': 0.8344554455445544, 'PRC-AUC': 0.7381966700284186}
# INFO | Early stop at epoch 62 (patience=15)
# INFO | DMPNN 2D HPO — trial 15/20 finished | val=-0.860000 | best=-0.874851
# INFO | DMPNN 2D — starting trial 16/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.0207 | val={'ROC-AUC': 0.3897029702970297, 'PRC-AUC': 0.2870437511434146}
# INFO | HPO epoch   5/80 | loss=0.6523 | val={'ROC-AUC': 0.6853465346534654, 'PRC-AUC': 0.5562632688011232}
# INFO | HPO epoch  10/80 | loss=0.5488 | val={'ROC-AUC': 0.8025742574257426, 'PRC-AUC': 0.6864900636827085}
# INFO | HPO epoch  15/80 | loss=0.4844 | val={'ROC-AUC': 0.7768316831683169, 'PRC-AUC': 0.6711993044103113}
# INFO | HPO epoch  20/80 | loss=0.4498 | val={'ROC-AUC': 0.8104950495049505, 'PRC-AUC': 0.6889477935808856}
# INFO | HPO epoch  25/80 | loss=0.4198 | val={'ROC-AUC': 0.8275247524752475, 'PRC-AUC': 0.6751482499851527}
# INFO | HPO epoch  30/80 | loss=0.4170 | val={'ROC-AUC': 0.8241584158415841, 'PRC-AUC': 0.6893802036920357}
# INFO | HPO epoch  35/80 | loss=0.3905 | val={'ROC-AUC': 0.8578217821782178, 'PRC-AUC': 0.7455988524965923}
# INFO | HPO epoch  40/80 | loss=0.3442 | val={'ROC-AUC': 0.8326732673267326, 'PRC-AUC': 0.7071440081265401}
# INFO | Early stop at epoch 42 (patience=15)
# INFO | DMPNN 2D HPO — trial 16/20 finished | val=-0.872673 | best=-0.874851
# INFO | DMPNN 2D — starting trial 17/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.4362 | val={'ROC-AUC': 0.6845544554455445, 'PRC-AUC': 0.5454859991934287}
# INFO | HPO epoch   5/80 | loss=0.6358 | val={'ROC-AUC': 0.7285148514851485, 'PRC-AUC': 0.6107073161784077}
# INFO | HPO epoch  10/80 | loss=0.5499 | val={'ROC-AUC': 0.7736633663366336, 'PRC-AUC': 0.6935796859324619}
# INFO | HPO epoch  15/80 | loss=0.5022 | val={'ROC-AUC': 0.789108910891089, 'PRC-AUC': 0.7118924499753864}
# INFO | HPO epoch  20/80 | loss=0.4483 | val={'ROC-AUC': 0.8104950495049504, 'PRC-AUC': 0.7243353215598768}
# INFO | HPO epoch  25/80 | loss=0.4375 | val={'ROC-AUC': 0.8203960396039603, 'PRC-AUC': 0.7318419639040372}
# INFO | HPO epoch  30/80 | loss=0.4158 | val={'ROC-AUC': 0.8174257425742574, 'PRC-AUC': 0.7214373834599498}
# INFO | HPO epoch  35/80 | loss=0.3913 | val={'ROC-AUC': 0.8126732673267327, 'PRC-AUC': 0.6784262752552807}
# INFO | HPO epoch  40/80 | loss=0.3648 | val={'ROC-AUC': 0.8164356435643565, 'PRC-AUC': 0.7181576237390653}
# INFO | HPO epoch  45/80 | loss=0.3557 | val={'ROC-AUC': 0.8055445544554456, 'PRC-AUC': 0.7427190701599915}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | DMPNN 2D HPO — trial 17/20 finished | val=-0.837426 | best=-0.874851
# INFO | DMPNN 2D — starting trial 18/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.0489 | val={'ROC-AUC': 0.5675247524752476, 'PRC-AUC': 0.43999652144904083}
# INFO | HPO epoch   5/80 | loss=0.6117 | val={'ROC-AUC': 0.7475247524752475, 'PRC-AUC': 0.6324534568295108}
# INFO | HPO epoch  10/80 | loss=0.5319 | val={'ROC-AUC': 0.774059405940594, 'PRC-AUC': 0.6424872696880644}
# INFO | HPO epoch  15/80 | loss=0.4359 | val={'ROC-AUC': 0.8061386138613861, 'PRC-AUC': 0.6773321156374266}
# INFO | HPO epoch  20/80 | loss=0.4106 | val={'ROC-AUC': 0.8467326732673267, 'PRC-AUC': 0.7428783995189783}
# INFO | HPO epoch  25/80 | loss=0.3844 | val={'ROC-AUC': 0.8332673267326732, 'PRC-AUC': 0.6916546469888252}
# INFO | HPO epoch  30/80 | loss=0.4007 | val={'ROC-AUC': 0.8467326732673267, 'PRC-AUC': 0.7297736133387724}
# INFO | HPO epoch  35/80 | loss=0.3543 | val={'ROC-AUC': 0.8067326732673268, 'PRC-AUC': 0.6725277029440409}
# INFO | Early stop at epoch 35 (patience=15)
# INFO | DMPNN 2D HPO — trial 18/20 finished | val=-0.846733 | best=-0.874851
# INFO | DMPNN 2D — starting trial 19/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.9633 | val={'ROC-AUC': 0.6508910891089109, 'PRC-AUC': 0.4852756248138171}
# INFO | HPO epoch   5/80 | loss=0.5996 | val={'ROC-AUC': 0.712871287128713, 'PRC-AUC': 0.5893629057181559}
# INFO | HPO epoch  10/80 | loss=0.5397 | val={'ROC-AUC': 0.7627722772277228, 'PRC-AUC': 0.6700501960186921}
# INFO | HPO epoch  15/80 | loss=0.4721 | val={'ROC-AUC': 0.7974257425742575, 'PRC-AUC': 0.6850180764760672}
# INFO | HPO epoch  20/80 | loss=0.4318 | val={'ROC-AUC': 0.8415841584158416, 'PRC-AUC': 0.7072277176059565}
# INFO | HPO epoch  25/80 | loss=0.4075 | val={'ROC-AUC': 0.819009900990099, 'PRC-AUC': 0.6831527622354397}
# INFO | HPO epoch  30/80 | loss=0.3691 | val={'ROC-AUC': 0.8291089108910891, 'PRC-AUC': 0.6845490640898727}
# INFO | HPO epoch  35/80 | loss=0.3658 | val={'ROC-AUC': 0.8477227722772277, 'PRC-AUC': 0.7065795977835626}
# INFO | HPO epoch  40/80 | loss=0.3245 | val={'ROC-AUC': 0.8497029702970297, 'PRC-AUC': 0.723417544490987}
# INFO | Early stop at epoch 41 (patience=15)
# INFO | DMPNN 2D HPO — trial 19/20 finished | val=-0.858416 | best=-0.874851
# INFO | DMPNN 2D — starting trial 20/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.0866 | val={'ROC-AUC': 0.5, 'PRC-AUC': 0.3905044001982516}
# INFO | HPO epoch   5/80 | loss=0.6349 | val={'ROC-AUC': 0.6788118811881189, 'PRC-AUC': 0.5784767222622578}
# INFO | HPO epoch  10/80 | loss=0.5714 | val={'ROC-AUC': 0.715049504950495, 'PRC-AUC': 0.6059693560440724}
# INFO | HPO epoch  15/80 | loss=0.4975 | val={'ROC-AUC': 0.7730693069306931, 'PRC-AUC': 0.6390307653503945}
# INFO | HPO epoch  20/80 | loss=0.4510 | val={'ROC-AUC': 0.8176237623762377, 'PRC-AUC': 0.6800428724485877}
# INFO | HPO epoch  25/80 | loss=0.4331 | val={'ROC-AUC': 0.8348514851485149, 'PRC-AUC': 0.7168100574511493}
# INFO | HPO epoch  30/80 | loss=0.4178 | val={'ROC-AUC': 0.8518811881188119, 'PRC-AUC': 0.7293355076845612}
# INFO | HPO epoch  35/80 | loss=0.3949 | val={'ROC-AUC': 0.8338613861386139, 'PRC-AUC': 0.7078512953228043}
# INFO | HPO epoch  40/80 | loss=0.3650 | val={'ROC-AUC': 0.8166336633663367, 'PRC-AUC': 0.7279951308389104}
# INFO | HPO epoch  45/80 | loss=0.3303 | val={'ROC-AUC': 0.8293069306930693, 'PRC-AUC': 0.7231268939967632}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | DMPNN 2D HPO — trial 20/20 finished | val=-0.851881 | best=-0.874851
# INFO | Epoch  10 | loss=0.5400 | val={'ROC-AUC': 0.7483168316831683, 'PRC-AUC': 0.660093045140327}
# INFO | Epoch  20 | loss=0.4432 | val={'ROC-AUC': 0.8457425742574257, 'PRC-AUC': 0.696851984256615}
# INFO | Epoch  30 | loss=0.3788 | val={'ROC-AUC': 0.8196039603960396, 'PRC-AUC': 0.6466011098992243}
# INFO | Epoch  40 | loss=0.3492 | val={'ROC-AUC': 0.8289108910891089, 'PRC-AUC': 0.6784463767660434}
# INFO | Epoch  50 | loss=0.3076 | val={'ROC-AUC': 0.8386138613861387, 'PRC-AUC': 0.685611190081307}
# INFO | Epoch  60 | loss=0.3017 | val={'ROC-AUC': 0.8287128712871288, 'PRC-AUC': 0.6861744285136429}
# INFO | Epoch  70 | loss=0.3037 | val={'ROC-AUC': 0.8265346534653466, 'PRC-AUC': 0.6756762889554724}
# INFO | Epoch  80 | loss=0.2775 | val={'ROC-AUC': 0.8269306930693069, 'PRC-AUC': 0.6809714563311037}
# INFO | Saved D-MPNN (2D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.7879464285714285, 'PRC-AUC': 0.6566201448799195}

# %% [markdown]
# ### GIN (3D)

# %%
MODEL_KEY = "GIN (3D)"
tr = tr3d if "3D" == "3D" else tr2d
va = va3d if "3D" == "3D" else va2d
te = te3d if "3D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "3D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "3D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (3D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | GIN 3D — starting trial 1/20 (layers=5, hidden=192)
# → GIN (3D) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.8302 | val={'ROC-AUC': 0.7433663366336634, 'PRC-AUC': 0.5895948863700323}
# INFO | HPO epoch   5/80 | loss=0.5659 | val={'ROC-AUC': 0.794059405940594, 'PRC-AUC': 0.667080849946111}
# INFO | HPO epoch  10/80 | loss=0.5355 | val={'ROC-AUC': 0.8607920792079208, 'PRC-AUC': 0.7204652689849499}
# INFO | HPO epoch  15/80 | loss=0.4955 | val={'ROC-AUC': 0.8471287128712871, 'PRC-AUC': 0.7218222461457708}
# INFO | HPO epoch  20/80 | loss=0.4438 | val={'ROC-AUC': 0.7863366336633664, 'PRC-AUC': 0.6298777079132608}
# INFO | HPO epoch  25/80 | loss=0.4008 | val={'ROC-AUC': 0.8439603960396039, 'PRC-AUC': 0.6803613137878688}
# INFO | Early stop at epoch 25 (patience=15)
# INFO | GIN 3D HPO — trial 1/20 finished | val=-0.860792 | best=-0.860792
# INFO | GIN 3D — starting trial 2/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=1.0856 | val={'ROC-AUC': 0.7168316831683168, 'PRC-AUC': 0.5779246917217666}
# INFO | HPO epoch   5/80 | loss=0.5564 | val={'ROC-AUC': 0.7302970297029703, 'PRC-AUC': 0.6069519571471902}
# INFO | HPO epoch  10/80 | loss=0.5193 | val={'ROC-AUC': 0.7544554455445545, 'PRC-AUC': 0.5898340411704792}
# INFO | HPO epoch  15/80 | loss=0.4475 | val={'ROC-AUC': 0.7485148514851485, 'PRC-AUC': 0.600801025008307}
# INFO | HPO epoch  20/80 | loss=0.3924 | val={'ROC-AUC': 0.8233663366336633, 'PRC-AUC': 0.7329095239677912}
# INFO | HPO epoch  25/80 | loss=0.3723 | val={'ROC-AUC': 0.8293069306930694, 'PRC-AUC': 0.6793373916071388}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | GIN 3D HPO — trial 2/20 finished | val=-0.841188 | best=-0.860792
# INFO | GIN 3D — starting trial 3/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.9167 | val={'ROC-AUC': 0.7837623762376238, 'PRC-AUC': 0.6370281187104012}
# INFO | HPO epoch   5/80 | loss=0.5108 | val={'ROC-AUC': 0.833069306930693, 'PRC-AUC': 0.6557708193606605}
# INFO | HPO epoch  10/80 | loss=0.4152 | val={'ROC-AUC': 0.8356435643564357, 'PRC-AUC': 0.7187500549116228}
# INFO | HPO epoch  15/80 | loss=0.4298 | val={'ROC-AUC': 0.7441584158415842, 'PRC-AUC': 0.5582534276840917}
# INFO | HPO epoch  20/80 | loss=0.3773 | val={'ROC-AUC': 0.8512871287128713, 'PRC-AUC': 0.728883755891886}
# INFO | HPO epoch  25/80 | loss=0.3297 | val={'ROC-AUC': 0.8558415841584159, 'PRC-AUC': 0.7213114009955507}
# INFO | HPO epoch  30/80 | loss=0.3125 | val={'ROC-AUC': 0.8233663366336634, 'PRC-AUC': 0.7156014204128415}
# INFO | HPO epoch  35/80 | loss=0.3046 | val={'ROC-AUC': 0.8326732673267326, 'PRC-AUC': 0.7047836700231125}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | GIN 3D HPO — trial 3/20 finished | val=-0.858020 | best=-0.860792
# INFO | GIN 3D — starting trial 4/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8266 | val={'ROC-AUC': 0.6475247524752475, 'PRC-AUC': 0.45754427622030336}
# INFO | HPO epoch   5/80 | loss=0.5951 | val={'ROC-AUC': 0.7922772277227723, 'PRC-AUC': 0.63837842356649}
# INFO | HPO epoch  10/80 | loss=0.5263 | val={'ROC-AUC': 0.8172277227722772, 'PRC-AUC': 0.665367455189426}
# INFO | HPO epoch  15/80 | loss=0.4340 | val={'ROC-AUC': 0.8225742574257426, 'PRC-AUC': 0.6925935582665641}
# INFO | HPO epoch  20/80 | loss=0.4556 | val={'ROC-AUC': 0.7463366336633663, 'PRC-AUC': 0.5689049370689397}
# INFO | HPO epoch  25/80 | loss=0.4093 | val={'ROC-AUC': 0.737029702970297, 'PRC-AUC': 0.545132948339375}
# INFO | HPO epoch  30/80 | loss=0.3756 | val={'ROC-AUC': 0.7544554455445545, 'PRC-AUC': 0.5588490352339501}
# INFO | HPO epoch  35/80 | loss=0.3281 | val={'ROC-AUC': 0.8283168316831683, 'PRC-AUC': 0.6768757558965911}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | GIN 3D HPO — trial 4/20 finished | val=-0.875050 | best=-0.875050
# INFO | GIN 3D — starting trial 5/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.9514 | val={'ROC-AUC': 0.6516831683168317, 'PRC-AUC': 0.5128162754394712}
# INFO | HPO epoch   5/80 | loss=0.6409 | val={'ROC-AUC': 0.7405940594059406, 'PRC-AUC': 0.5576931721245634}
# INFO | HPO epoch  10/80 | loss=0.5084 | val={'ROC-AUC': 0.7611881188118812, 'PRC-AUC': 0.5764678073349516}
# INFO | HPO epoch  15/80 | loss=0.4526 | val={'ROC-AUC': 0.8895049504950495, 'PRC-AUC': 0.7977414578995666}
# INFO | HPO epoch  20/80 | loss=0.4578 | val={'ROC-AUC': 0.841980198019802, 'PRC-AUC': 0.7153258436506491}
# INFO | HPO epoch  25/80 | loss=0.4498 | val={'ROC-AUC': 0.8586138613861386, 'PRC-AUC': 0.7543920688689119}
# INFO | HPO epoch  30/80 | loss=0.3563 | val={'ROC-AUC': 0.8734653465346535, 'PRC-AUC': 0.7380039798386094}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | GIN 3D HPO — trial 5/20 finished | val=-0.889505 | best=-0.889505
# INFO | GIN 3D — starting trial 6/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.9412 | val={'ROC-AUC': 0.7912871287128713, 'PRC-AUC': 0.6407279902299332}
# INFO | HPO epoch   5/80 | loss=0.5448 | val={'ROC-AUC': 0.8112871287128713, 'PRC-AUC': 0.7189527595749248}
# INFO | HPO epoch  10/80 | loss=0.4991 | val={'ROC-AUC': 0.7902970297029702, 'PRC-AUC': 0.6826622800588059}
# INFO | HPO epoch  15/80 | loss=0.4861 | val={'ROC-AUC': 0.8475247524752475, 'PRC-AUC': 0.7179038699637207}
# INFO | HPO epoch  20/80 | loss=0.4454 | val={'ROC-AUC': 0.8461386138613861, 'PRC-AUC': 0.7305794845732941}
# INFO | HPO epoch  25/80 | loss=0.4373 | val={'ROC-AUC': 0.8190099009900991, 'PRC-AUC': 0.7001700155429399}
# INFO | HPO epoch  30/80 | loss=0.4696 | val={'ROC-AUC': 0.8746534653465347, 'PRC-AUC': 0.7709903007132128}
# INFO | HPO epoch  35/80 | loss=0.4197 | val={'ROC-AUC': 0.8473267326732673, 'PRC-AUC': 0.7122804867884508}
# INFO | HPO epoch  40/80 | loss=0.3941 | val={'ROC-AUC': 0.8479207920792079, 'PRC-AUC': 0.7140095749540855}
# INFO | HPO epoch  45/80 | loss=0.3925 | val={'ROC-AUC': 0.8665346534653465, 'PRC-AUC': 0.7379660200088147}
# INFO | HPO epoch  50/80 | loss=0.3481 | val={'ROC-AUC': 0.8558415841584158, 'PRC-AUC': 0.7245776581168473}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | GIN 3D HPO — trial 6/20 finished | val=-0.877228 | best=-0.889505
# INFO | GIN 3D — starting trial 7/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8901 | val={'ROC-AUC': 0.8075247524752475, 'PRC-AUC': 0.6271065923100207}
# INFO | HPO epoch   5/80 | loss=0.5282 | val={'ROC-AUC': 0.8203960396039603, 'PRC-AUC': 0.6672522417192474}
# INFO | HPO epoch  10/80 | loss=0.4439 | val={'ROC-AUC': 0.8194059405940594, 'PRC-AUC': 0.6950140569788085}
# INFO | HPO epoch  15/80 | loss=0.4077 | val={'ROC-AUC': 0.8102970297029704, 'PRC-AUC': 0.6504592420358707}
# INFO | HPO epoch  20/80 | loss=0.3834 | val={'ROC-AUC': 0.8893069306930693, 'PRC-AUC': 0.7549953154840848}
# INFO | HPO epoch  25/80 | loss=0.3794 | val={'ROC-AUC': 0.8372277227722773, 'PRC-AUC': 0.7214189369670556}
# INFO | HPO epoch  30/80 | loss=0.3678 | val={'ROC-AUC': 0.8403960396039604, 'PRC-AUC': 0.7167750446873222}
# INFO | HPO epoch  35/80 | loss=0.2986 | val={'ROC-AUC': 0.8536633663366336, 'PRC-AUC': 0.7374537517365195}
# INFO | Early stop at epoch 35 (patience=15)
# INFO | GIN 3D HPO — trial 7/20 finished | val=-0.889307 | best=-0.889505
# INFO | GIN 3D — starting trial 8/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8299 | val={'ROC-AUC': 0.8346534653465346, 'PRC-AUC': 0.6718148028594326}
# INFO | HPO epoch   5/80 | loss=0.5014 | val={'ROC-AUC': 0.8306930693069308, 'PRC-AUC': 0.7123595679762563}
# INFO | HPO epoch  10/80 | loss=0.4462 | val={'ROC-AUC': 0.8433663366336634, 'PRC-AUC': 0.7422321954285936}
# INFO | HPO epoch  15/80 | loss=0.3882 | val={'ROC-AUC': 0.841980198019802, 'PRC-AUC': 0.7128654147322838}
# INFO | HPO epoch  20/80 | loss=0.3877 | val={'ROC-AUC': 0.8263366336633663, 'PRC-AUC': 0.7158973526873971}
# INFO | HPO epoch  25/80 | loss=0.3082 | val={'ROC-AUC': 0.8518811881188119, 'PRC-AUC': 0.7421449122296135}
# INFO | Early stop at epoch 26 (patience=15)
# INFO | GIN 3D HPO — trial 8/20 finished | val=-0.870297 | best=-0.889505
# INFO | GIN 3D — starting trial 9/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.1919 | val={'ROC-AUC': 0.710891089108911, 'PRC-AUC': 0.5214059974102132}
# INFO | HPO epoch   5/80 | loss=0.5993 | val={'ROC-AUC': 0.7530693069306931, 'PRC-AUC': 0.6309036915392969}
# INFO | HPO epoch  10/80 | loss=0.5033 | val={'ROC-AUC': 0.8194059405940595, 'PRC-AUC': 0.6700563888199336}
# INFO | HPO epoch  15/80 | loss=0.4663 | val={'ROC-AUC': 0.5815841584158417, 'PRC-AUC': 0.373573971479835}
# INFO | HPO epoch  20/80 | loss=0.4525 | val={'ROC-AUC': 0.8007920792079208, 'PRC-AUC': 0.7042752511882818}
# INFO | HPO epoch  25/80 | loss=0.4244 | val={'ROC-AUC': 0.8255445544554455, 'PRC-AUC': 0.6483069632459987}
# INFO | HPO epoch  30/80 | loss=0.3892 | val={'ROC-AUC': 0.8338613861386138, 'PRC-AUC': 0.7099843326403251}
# INFO | Early stop at epoch 31 (patience=15)
# INFO | GIN 3D HPO — trial 9/20 finished | val=-0.852277 | best=-0.889505
# INFO | GIN 3D — starting trial 10/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.9449 | val={'ROC-AUC': 0.5744554455445545, 'PRC-AUC': 0.4702222831919275}
# INFO | HPO epoch   5/80 | loss=0.5880 | val={'ROC-AUC': 0.6912871287128712, 'PRC-AUC': 0.5211949468658471}
# INFO | HPO epoch  10/80 | loss=0.4931 | val={'ROC-AUC': 0.8043564356435644, 'PRC-AUC': 0.6793648922867376}
# INFO | HPO epoch  15/80 | loss=0.4525 | val={'ROC-AUC': 0.8388118811881188, 'PRC-AUC': 0.6955053300358935}
# INFO | HPO epoch  20/80 | loss=0.4124 | val={'ROC-AUC': 0.84, 'PRC-AUC': 0.6972092128457136}
# INFO | HPO epoch  25/80 | loss=0.3855 | val={'ROC-AUC': 0.8766336633663366, 'PRC-AUC': 0.7541680116168763}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | GIN 3D HPO — trial 10/20 finished | val=-0.879604 | best=-0.889505
# INFO | GIN 3D — starting trial 11/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8153 | val={'ROC-AUC': 0.6198019801980198, 'PRC-AUC': 0.4373499725921901}
# INFO | HPO epoch   5/80 | loss=0.5659 | val={'ROC-AUC': 0.7853465346534654, 'PRC-AUC': 0.6176723950918137}
# INFO | HPO epoch  10/80 | loss=0.5277 | val={'ROC-AUC': 0.8287128712871288, 'PRC-AUC': 0.7047839008093768}
# INFO | HPO epoch  15/80 | loss=0.5097 | val={'ROC-AUC': 0.8453465346534653, 'PRC-AUC': 0.7104500440868287}
# INFO | HPO epoch  20/80 | loss=0.4460 | val={'ROC-AUC': 0.857029702970297, 'PRC-AUC': 0.7352759051541774}
# INFO | HPO epoch  25/80 | loss=0.4191 | val={'ROC-AUC': 0.8677227722772277, 'PRC-AUC': 0.6979158551709006}
# INFO | HPO epoch  30/80 | loss=0.4226 | val={'ROC-AUC': 0.8615841584158415, 'PRC-AUC': 0.7194870267797376}
# INFO | HPO epoch  35/80 | loss=0.4184 | val={'ROC-AUC': 0.8677227722772277, 'PRC-AUC': 0.7319489617541404}
# INFO | HPO epoch  40/80 | loss=0.3788 | val={'ROC-AUC': 0.8512871287128713, 'PRC-AUC': 0.6785897282802461}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | GIN 3D HPO — trial 11/20 finished | val=-0.867723 | best=-0.889505
# INFO | GIN 3D — starting trial 12/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.9158 | val={'ROC-AUC': 0.7742574257425743, 'PRC-AUC': 0.6395853797636144}
# INFO | HPO epoch   5/80 | loss=0.5803 | val={'ROC-AUC': 0.7708910891089109, 'PRC-AUC': 0.5846780032768292}
# INFO | HPO epoch  10/80 | loss=0.4581 | val={'ROC-AUC': 0.8314851485148514, 'PRC-AUC': 0.6716348338528809}
# INFO | HPO epoch  15/80 | loss=0.4341 | val={'ROC-AUC': 0.8194059405940594, 'PRC-AUC': 0.6614677411015469}
# INFO | HPO epoch  20/80 | loss=0.4061 | val={'ROC-AUC': 0.8271287128712871, 'PRC-AUC': 0.7065902309740972}
# INFO | HPO epoch  25/80 | loss=0.3392 | val={'ROC-AUC': 0.8263366336633663, 'PRC-AUC': 0.6814389742285238}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | GIN 3D HPO — trial 12/20 finished | val=-0.856832 | best=-0.889505
# INFO | GIN 3D — starting trial 13/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=1.6798 | val={'ROC-AUC': 0.6679207920792078, 'PRC-AUC': 0.4797976050159388}
# INFO | HPO epoch   5/80 | loss=0.6312 | val={'ROC-AUC': 0.5750495049504951, 'PRC-AUC': 0.37374852418040816}
# INFO | HPO epoch  10/80 | loss=0.5459 | val={'ROC-AUC': 0.7851485148514852, 'PRC-AUC': 0.6067669129007746}
# INFO | HPO epoch  15/80 | loss=0.4973 | val={'ROC-AUC': 0.8398019801980198, 'PRC-AUC': 0.6817298982235108}
# INFO | HPO epoch  20/80 | loss=0.4667 | val={'ROC-AUC': 0.7348514851485148, 'PRC-AUC': 0.5774449655275251}
# INFO | HPO epoch  25/80 | loss=0.4598 | val={'ROC-AUC': 0.7546534653465347, 'PRC-AUC': 0.5559587804243158}
# INFO | HPO epoch  30/80 | loss=0.4073 | val={'ROC-AUC': 0.8417821782178219, 'PRC-AUC': 0.7096624103801835}
# INFO | HPO epoch  35/80 | loss=0.4014 | val={'ROC-AUC': 0.7952475247524752, 'PRC-AUC': 0.6215983683991678}
# INFO | HPO epoch  40/80 | loss=0.3833 | val={'ROC-AUC': 0.7724752475247525, 'PRC-AUC': 0.5791521996516391}
# INFO | HPO epoch  45/80 | loss=0.3825 | val={'ROC-AUC': 0.7813861386138614, 'PRC-AUC': 0.6323643048771761}
# INFO | HPO epoch  50/80 | loss=0.3580 | val={'ROC-AUC': 0.8394059405940594, 'PRC-AUC': 0.6398441807764678}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | GIN 3D HPO — trial 13/20 finished | val=-0.861782 | best=-0.889505
# INFO | GIN 3D — starting trial 14/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8184 | val={'ROC-AUC': 0.7007920792079207, 'PRC-AUC': 0.500706270334092}
# INFO | HPO epoch   5/80 | loss=0.6123 | val={'ROC-AUC': 0.7704950495049505, 'PRC-AUC': 0.6544513989759487}
# INFO | HPO epoch  10/80 | loss=0.4727 | val={'ROC-AUC': 0.8213861386138614, 'PRC-AUC': 0.6113693818445891}
# INFO | HPO epoch  15/80 | loss=0.4188 | val={'ROC-AUC': 0.8205940594059407, 'PRC-AUC': 0.6349785663474532}
# INFO | HPO epoch  20/80 | loss=0.3909 | val={'ROC-AUC': 0.8392079207920792, 'PRC-AUC': 0.6581210759786333}
# INFO | HPO epoch  25/80 | loss=0.3474 | val={'ROC-AUC': 0.8255445544554455, 'PRC-AUC': 0.6731888823544597}
# INFO | HPO epoch  30/80 | loss=0.3095 | val={'ROC-AUC': 0.8338613861386138, 'PRC-AUC': 0.6664081381331088}
# INFO | HPO epoch  35/80 | loss=0.3401 | val={'ROC-AUC': 0.8548514851485148, 'PRC-AUC': 0.7092382802474838}
# INFO | HPO epoch  40/80 | loss=0.3109 | val={'ROC-AUC': 0.8457425742574257, 'PRC-AUC': 0.703551331116842}
# INFO | Early stop at epoch 43 (patience=15)
# INFO | GIN 3D HPO — trial 14/20 finished | val=-0.873663 | best=-0.889505
# INFO | GIN 3D — starting trial 15/20 (layers=5, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8656 | val={'ROC-AUC': 0.7742574257425743, 'PRC-AUC': 0.5752366687751002}
# INFO | HPO epoch   5/80 | loss=0.5015 | val={'ROC-AUC': 0.7514851485148515, 'PRC-AUC': 0.5835248815877394}
# INFO | HPO epoch  10/80 | loss=0.4552 | val={'ROC-AUC': 0.7782178217821782, 'PRC-AUC': 0.6656227189396462}
# INFO | HPO epoch  15/80 | loss=0.4105 | val={'ROC-AUC': 0.8053465346534654, 'PRC-AUC': 0.6888968624810812}
# INFO | HPO epoch  20/80 | loss=0.3805 | val={'ROC-AUC': 0.80990099009901, 'PRC-AUC': 0.6775663428111288}
# INFO | HPO epoch  25/80 | loss=0.3097 | val={'ROC-AUC': 0.7936633663366337, 'PRC-AUC': 0.6555081160102227}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | GIN 3D HPO — trial 15/20 finished | val=-0.864554 | best=-0.889505
# INFO | GIN 3D — starting trial 16/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8725 | val={'ROC-AUC': 0.5687128712871288, 'PRC-AUC': 0.3782823132712302}
# INFO | HPO epoch   5/80 | loss=0.5620 | val={'ROC-AUC': 0.8081188118811882, 'PRC-AUC': 0.6422415893151107}
# INFO | HPO epoch  10/80 | loss=0.5089 | val={'ROC-AUC': 0.8188118811881188, 'PRC-AUC': 0.642533944692228}
# INFO | HPO epoch  15/80 | loss=0.4422 | val={'ROC-AUC': 0.8401980198019802, 'PRC-AUC': 0.6876105654379472}
# INFO | HPO epoch  20/80 | loss=0.4105 | val={'ROC-AUC': 0.8207920792079207, 'PRC-AUC': 0.7063873345378979}
# INFO | HPO epoch  25/80 | loss=0.3986 | val={'ROC-AUC': 0.8465346534653465, 'PRC-AUC': 0.6903796888025877}
# INFO | HPO epoch  30/80 | loss=0.4063 | val={'ROC-AUC': 0.8675247524752475, 'PRC-AUC': 0.7560567403860543}
# INFO | HPO epoch  35/80 | loss=0.3730 | val={'ROC-AUC': 0.841980198019802, 'PRC-AUC': 0.7358654194074026}
# INFO | HPO epoch  40/80 | loss=0.3599 | val={'ROC-AUC': 0.7372277227722772, 'PRC-AUC': 0.605793147716857}
# INFO | HPO epoch  45/80 | loss=0.2919 | val={'ROC-AUC': 0.8241584158415841, 'PRC-AUC': 0.6909344743642091}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | GIN 3D HPO — trial 16/20 finished | val=-0.867525 | best=-0.889505
# INFO | GIN 3D — starting trial 17/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.9406 | val={'ROC-AUC': 0.6465346534653464, 'PRC-AUC': 0.49039523191201784}
# INFO | HPO epoch   5/80 | loss=0.5915 | val={'ROC-AUC': 0.7205940594059406, 'PRC-AUC': 0.577250396531421}
# INFO | HPO epoch  10/80 | loss=0.5419 | val={'ROC-AUC': 0.7459405940594059, 'PRC-AUC': 0.5569755715681401}
# INFO | HPO epoch  15/80 | loss=0.4487 | val={'ROC-AUC': 0.8221782178217821, 'PRC-AUC': 0.6470583187795745}
# INFO | HPO epoch  20/80 | loss=0.3985 | val={'ROC-AUC': 0.8122772277227723, 'PRC-AUC': 0.6593446318678633}
# INFO | HPO epoch  25/80 | loss=0.3724 | val={'ROC-AUC': 0.800990099009901, 'PRC-AUC': 0.6495307300626796}
# INFO | HPO epoch  30/80 | loss=0.3500 | val={'ROC-AUC': 0.8198019801980198, 'PRC-AUC': 0.6949407687948946}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | GIN 3D HPO — trial 17/20 finished | val=-0.867525 | best=-0.889505
# INFO | GIN 3D — starting trial 18/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=1.3921 | val={'ROC-AUC': 0.7405940594059406, 'PRC-AUC': 0.5755556013708871}
# INFO | HPO epoch   5/80 | loss=0.5201 | val={'ROC-AUC': 0.8194059405940594, 'PRC-AUC': 0.685000632534856}
# INFO | HPO epoch  10/80 | loss=0.4837 | val={'ROC-AUC': 0.8659405940594059, 'PRC-AUC': 0.7374128621386278}
# INFO | HPO epoch  15/80 | loss=0.4121 | val={'ROC-AUC': 0.859009900990099, 'PRC-AUC': 0.7215427422798956}
# INFO | HPO epoch  20/80 | loss=0.4109 | val={'ROC-AUC': 0.8548514851485148, 'PRC-AUC': 0.7365340547576309}
# INFO | HPO epoch  25/80 | loss=0.3771 | val={'ROC-AUC': 0.8689108910891089, 'PRC-AUC': 0.7523680639755573}
# INFO | HPO epoch  30/80 | loss=0.3687 | val={'ROC-AUC': 0.8746534653465347, 'PRC-AUC': 0.7601026987726742}
# INFO | HPO epoch  35/80 | loss=0.3436 | val={'ROC-AUC': 0.8841584158415841, 'PRC-AUC': 0.7835992832623896}
# INFO | HPO epoch  40/80 | loss=0.3483 | val={'ROC-AUC': 0.872871287128713, 'PRC-AUC': 0.752674256427548}
# INFO | HPO epoch  45/80 | loss=0.3449 | val={'ROC-AUC': 0.8704950495049505, 'PRC-AUC': 0.7475489519795352}
# INFO | HPO epoch  50/80 | loss=0.3230 | val={'ROC-AUC': 0.8762376237623762, 'PRC-AUC': 0.7607064345220402}
# INFO | Early stop at epoch 52 (patience=15)
# INFO | GIN 3D HPO — trial 18/20 finished | val=-0.884752 | best=-0.889505
# INFO | GIN 3D — starting trial 19/20 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=2.1818 | val={'ROC-AUC': 0.6005940594059406, 'PRC-AUC': 0.4075036049038357}
# INFO | HPO epoch   5/80 | loss=0.5773 | val={'ROC-AUC': 0.7168316831683168, 'PRC-AUC': 0.588750553025827}
# INFO | HPO epoch  10/80 | loss=0.5263 | val={'ROC-AUC': 0.763960396039604, 'PRC-AUC': 0.6485946860984069}
# INFO | HPO epoch  15/80 | loss=0.5105 | val={'ROC-AUC': 0.6673267326732674, 'PRC-AUC': 0.4742182168093474}
# INFO | HPO epoch  20/80 | loss=0.4610 | val={'ROC-AUC': 0.5807920792079208, 'PRC-AUC': 0.4349274227477373}
# INFO | HPO epoch  25/80 | loss=0.4577 | val={'ROC-AUC': 0.6813861386138613, 'PRC-AUC': 0.4590296685420807}
# INFO | HPO epoch  30/80 | loss=0.4194 | val={'ROC-AUC': 0.8473267326732673, 'PRC-AUC': 0.6748655267915675}
# INFO | HPO epoch  35/80 | loss=0.3925 | val={'ROC-AUC': 0.8203960396039603, 'PRC-AUC': 0.67543759086899}
# INFO | HPO epoch  40/80 | loss=0.3726 | val={'ROC-AUC': 0.8144554455445544, 'PRC-AUC': 0.6712725832159224}
# INFO | HPO epoch  45/80 | loss=0.3584 | val={'ROC-AUC': 0.7772277227722773, 'PRC-AUC': 0.6160739373613191}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | GIN 3D HPO — trial 19/20 finished | val=-0.847327 | best=-0.889505
# INFO | GIN 3D — starting trial 20/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.6611 | val={'ROC-AUC': 0.7598019801980198, 'PRC-AUC': 0.580115698976075}
# INFO | HPO epoch   5/80 | loss=0.5200 | val={'ROC-AUC': 0.827920792079208, 'PRC-AUC': 0.6905710164257555}
# INFO | HPO epoch  10/80 | loss=0.4436 | val={'ROC-AUC': 0.8342574257425742, 'PRC-AUC': 0.6684584089322215}
# INFO | HPO epoch  15/80 | loss=0.4154 | val={'ROC-AUC': 0.836039603960396, 'PRC-AUC': 0.7106822166780703}
# INFO | HPO epoch  20/80 | loss=0.3722 | val={'ROC-AUC': 0.8261386138613861, 'PRC-AUC': 0.7159206054288563}
# INFO | HPO epoch  25/80 | loss=0.3590 | val={'ROC-AUC': 0.8285148514851486, 'PRC-AUC': 0.6809496921528344}
# INFO | HPO epoch  30/80 | loss=0.3539 | val={'ROC-AUC': 0.8112871287128713, 'PRC-AUC': 0.680745947717855}
# INFO | HPO epoch  35/80 | loss=0.3108 | val={'ROC-AUC': 0.8716831683168317, 'PRC-AUC': 0.7172457496486346}
# INFO | HPO epoch  40/80 | loss=0.2850 | val={'ROC-AUC': 0.8138613861386139, 'PRC-AUC': 0.6845224393740372}
# INFO | HPO epoch  45/80 | loss=0.2720 | val={'ROC-AUC': 0.8170297029702971, 'PRC-AUC': 0.6557162466633852}
# INFO | HPO epoch  50/80 | loss=0.2495 | val={'ROC-AUC': 0.838019801980198, 'PRC-AUC': 0.6899031371665204}
# INFO | Early stop at epoch 51 (patience=15)
# INFO | GIN 3D HPO — trial 20/20 finished | val=-0.879802 | best=-0.889505
# INFO | Epoch  10 | loss=0.4797 | val={'ROC-AUC': 0.8261386138613861, 'PRC-AUC': 0.733044795836635}
# INFO | Epoch  20 | loss=0.4332 | val={'ROC-AUC': 0.8225742574257426, 'PRC-AUC': 0.6899778419123389}
# INFO | Epoch  30 | loss=0.3471 | val={'ROC-AUC': 0.8455445544554455, 'PRC-AUC': 0.7020065421823084}
# INFO | Epoch  40 | loss=0.3103 | val={'ROC-AUC': 0.8255445544554456, 'PRC-AUC': 0.6628241103470142}
# INFO | Epoch  50 | loss=0.2885 | val={'ROC-AUC': 0.8324752475247524, 'PRC-AUC': 0.6770346083293286}
# INFO | Epoch  60 | loss=0.2803 | val={'ROC-AUC': 0.8461386138613861, 'PRC-AUC': 0.6871595947311705}
# INFO | Epoch  70 | loss=0.2662 | val={'ROC-AUC': 0.845940594059406, 'PRC-AUC': 0.6774205375505181}
# INFO | Epoch  80 | loss=0.2698 | val={'ROC-AUC': 0.8457425742574257, 'PRC-AUC': 0.6749683446593389}
# INFO | Saved GIN (3D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.7933407738095238, 'PRC-AUC': 0.6115280252009194}

# %% [markdown]
# ### SchNet (3D coords)
# Uses atomic numbers + xyz from min-energy n=25 conformer.

# %%
MODEL_KEY = "SchNet (3D coords)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_schnet(
        tr3d, va3d, TASK_TYPE, OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_schnet, PyGLoader, build_schnet, train_schnet
    model = build_schnet(
        OUT_CHANNELS,
        hidden_channels=best["hidden_channels"],
        num_filters=best["num_filters"],
        num_interactions=best["num_interactions"],
        num_gaussians=best["num_gaussians"],
        cutoff=best["cutoff"],
    )
    train_schnet(model, tr3d, va3d, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
                 batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    te3d_schnet = ensure_atomic_numbers_list(te3d)
    test_metrics = eval_schnet(model, PyGLoader(te3d_schnet, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_schnet.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | SchNet — starting trial 1/20
# → SchNet (3D coords) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=2.1465 | val={'ROC-AUC': 0.5625742574257426, 'PRC-AUC': 0.3768018801121363}
# INFO | HPO epoch   5/80 | loss=0.6279 | val={'ROC-AUC': 0.7178217821782179, 'PRC-AUC': 0.578515561294322}
# INFO | HPO epoch  10/80 | loss=0.6088 | val={'ROC-AUC': 0.7146534653465346, 'PRC-AUC': 0.6090314979611944}
# INFO | HPO epoch  15/80 | loss=0.5633 | val={'ROC-AUC': 0.7774257425742575, 'PRC-AUC': 0.6692504973129181}
# INFO | HPO epoch  20/80 | loss=0.5120 | val={'ROC-AUC': 0.8110891089108911, 'PRC-AUC': 0.6916943596949428}
# INFO | HPO epoch  25/80 | loss=0.4935 | val={'ROC-AUC': 0.8126732673267326, 'PRC-AUC': 0.6869958462474258}
# INFO | HPO epoch  30/80 | loss=0.5104 | val={'ROC-AUC': 0.840990099009901, 'PRC-AUC': 0.7346924528989671}
# INFO | HPO epoch  35/80 | loss=0.4505 | val={'ROC-AUC': 0.8265346534653466, 'PRC-AUC': 0.7127564263758683}
# INFO | HPO epoch  40/80 | loss=0.4214 | val={'ROC-AUC': 0.8362376237623762, 'PRC-AUC': 0.7226116364058202}
# INFO | Early stop at epoch 42 (patience=15)
# INFO | SchNet HPO — trial 1/20 finished | val=-0.850693 | best=-0.850693
# INFO | SchNet — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=1.0853 | val={'ROC-AUC': 0.5942574257425743, 'PRC-AUC': 0.5161447011833135}
# INFO | HPO epoch   5/80 | loss=0.5933 | val={'ROC-AUC': 0.7514851485148515, 'PRC-AUC': 0.6363041714357934}
# INFO | HPO epoch  10/80 | loss=0.5928 | val={'ROC-AUC': 0.7588118811881188, 'PRC-AUC': 0.64603171519071}
# INFO | HPO epoch  15/80 | loss=0.5053 | val={'ROC-AUC': 0.8130693069306931, 'PRC-AUC': 0.6928879211238919}
# INFO | HPO epoch  20/80 | loss=0.4679 | val={'ROC-AUC': 0.8310891089108912, 'PRC-AUC': 0.7024720248460428}
# INFO | HPO epoch  25/80 | loss=0.4140 | val={'ROC-AUC': 0.8437623762376237, 'PRC-AUC': 0.7155383658422177}
# INFO | HPO epoch  30/80 | loss=0.3989 | val={'ROC-AUC': 0.8166336633663367, 'PRC-AUC': 0.6857414938060835}
# INFO | HPO epoch  35/80 | loss=0.3648 | val={'ROC-AUC': 0.8253465346534653, 'PRC-AUC': 0.7205047977616896}
# INFO | HPO epoch  40/80 | loss=0.3033 | val={'ROC-AUC': 0.838019801980198, 'PRC-AUC': 0.7229233238866397}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | SchNet HPO — trial 2/20 finished | val=-0.843762 | best=-0.850693
# INFO | SchNet — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=2.0385 | val={'ROC-AUC': 0.5817821782178219, 'PRC-AUC': 0.5212246334675058}
# INFO | HPO epoch   5/80 | loss=0.6381 | val={'ROC-AUC': 0.7342574257425742, 'PRC-AUC': 0.6228595503376614}
# INFO | HPO epoch  10/80 | loss=0.5992 | val={'ROC-AUC': 0.7663366336633664, 'PRC-AUC': 0.6963636008291353}
# INFO | HPO epoch  15/80 | loss=0.5270 | val={'ROC-AUC': 0.7837623762376238, 'PRC-AUC': 0.7146460208834234}
# INFO | HPO epoch  20/80 | loss=0.4806 | val={'ROC-AUC': 0.7574257425742574, 'PRC-AUC': 0.6710726015472381}
# INFO | HPO epoch  25/80 | loss=0.6000 | val={'ROC-AUC': 0.7255445544554455, 'PRC-AUC': 0.624743389827231}
# INFO | HPO epoch  30/80 | loss=0.4626 | val={'ROC-AUC': 0.7960396039603961, 'PRC-AUC': 0.7254108626508794}
# INFO | HPO epoch  35/80 | loss=0.4304 | val={'ROC-AUC': 0.7588118811881188, 'PRC-AUC': 0.6811619600308536}
# INFO | HPO epoch  40/80 | loss=0.3790 | val={'ROC-AUC': 0.7823762376237624, 'PRC-AUC': 0.6841366495530641}
# INFO | HPO epoch  45/80 | loss=0.3636 | val={'ROC-AUC': 0.7904950495049505, 'PRC-AUC': 0.6727472598086388}
# INFO | HPO epoch  50/80 | loss=0.3249 | val={'ROC-AUC': 0.811089108910891, 'PRC-AUC': 0.6886494257961799}
# INFO | HPO epoch  55/80 | loss=0.3204 | val={'ROC-AUC': 0.817029702970297, 'PRC-AUC': 0.694191575899238}
# INFO | HPO epoch  60/80 | loss=0.2993 | val={'ROC-AUC': 0.8049504950495049, 'PRC-AUC': 0.7069480911801221}
# INFO | HPO epoch  65/80 | loss=0.2494 | val={'ROC-AUC': 0.8154455445544554, 'PRC-AUC': 0.7185690415728693}
# INFO | HPO epoch  70/80 | loss=0.1679 | val={'ROC-AUC': 0.8237623762376238, 'PRC-AUC': 0.7160085968261053}
# INFO | Early stop at epoch 72 (patience=15)
# INFO | SchNet HPO — trial 3/20 finished | val=-0.826139 | best=-0.850693
# INFO | SchNet — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=0.8738 | val={'ROC-AUC': 0.5944554455445544, 'PRC-AUC': 0.5172084526976519}
# INFO | HPO epoch   5/80 | loss=0.6576 | val={'ROC-AUC': 0.6863366336633664, 'PRC-AUC': 0.5695887581280652}
# INFO | HPO epoch  10/80 | loss=0.6475 | val={'ROC-AUC': 0.7122772277227722, 'PRC-AUC': 0.5905655085735676}
# INFO | HPO epoch  15/80 | loss=0.6029 | val={'ROC-AUC': 0.7401980198019802, 'PRC-AUC': 0.6205093415982246}
# INFO | HPO epoch  20/80 | loss=0.5884 | val={'ROC-AUC': 0.7061386138613861, 'PRC-AUC': 0.5843858669553045}
# INFO | HPO epoch  25/80 | loss=0.5709 | val={'ROC-AUC': 0.7469306930693069, 'PRC-AUC': 0.6266565857264006}
# INFO | HPO epoch  30/80 | loss=0.5597 | val={'ROC-AUC': 0.760990099009901, 'PRC-AUC': 0.6487804867418}
# INFO | HPO epoch  35/80 | loss=0.5492 | val={'ROC-AUC': 0.760990099009901, 'PRC-AUC': 0.665169898024564}
# INFO | HPO epoch  40/80 | loss=0.5415 | val={'ROC-AUC': 0.7716831683168317, 'PRC-AUC': 0.6711084804008189}
# INFO | HPO epoch  45/80 | loss=0.5137 | val={'ROC-AUC': 0.7760396039603961, 'PRC-AUC': 0.676653566264902}
# INFO | HPO epoch  50/80 | loss=0.5000 | val={'ROC-AUC': 0.782970297029703, 'PRC-AUC': 0.6801966221880363}
# INFO | HPO epoch  55/80 | loss=0.4941 | val={'ROC-AUC': 0.7897029702970297, 'PRC-AUC': 0.6889265013954085}
# INFO | HPO epoch  60/80 | loss=0.4840 | val={'ROC-AUC': 0.7893069306930693, 'PRC-AUC': 0.6938439749816107}
# INFO | HPO epoch  65/80 | loss=0.4732 | val={'ROC-AUC': 0.7887128712871286, 'PRC-AUC': 0.6723865011119551}
# INFO | HPO epoch  70/80 | loss=0.5207 | val={'ROC-AUC': 0.7782178217821782, 'PRC-AUC': 0.6613637122489262}
# INFO | HPO epoch  75/80 | loss=0.4473 | val={'ROC-AUC': 0.7924752475247525, 'PRC-AUC': 0.7000734222392152}
# INFO | HPO epoch  80/80 | loss=0.4375 | val={'ROC-AUC': 0.7958415841584159, 'PRC-AUC': 0.6889622819108631}
# INFO | SchNet HPO — trial 4/20 finished | val=-0.801980 | best=-0.850693
# INFO | SchNet — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=2.0293 | val={'ROC-AUC': 0.646138613861386, 'PRC-AUC': 0.5330216767626033}
# INFO | HPO epoch   5/80 | loss=0.5419 | val={'ROC-AUC': 0.783960396039604, 'PRC-AUC': 0.6645320865000891}
# INFO | HPO epoch  10/80 | loss=0.4671 | val={'ROC-AUC': 0.8150495049504951, 'PRC-AUC': 0.7206179160803363}
# INFO | HPO epoch  15/80 | loss=0.3717 | val={'ROC-AUC': 0.7934653465346534, 'PRC-AUC': 0.7271608176100562}
# INFO | HPO epoch  20/80 | loss=0.2899 | val={'ROC-AUC': 0.7904950495049505, 'PRC-AUC': 0.7138302786541991}
# INFO | HPO epoch  25/80 | loss=0.1835 | val={'ROC-AUC': 0.8095049504950494, 'PRC-AUC': 0.7373722609919079}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | SchNet HPO — trial 5/20 finished | val=-0.826535 | best=-0.850693
# INFO | SchNet — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=2.0352 | val={'ROC-AUC': 0.6413861386138614, 'PRC-AUC': 0.5331006020437765}
# INFO | HPO epoch   5/80 | loss=0.7409 | val={'ROC-AUC': 0.719009900990099, 'PRC-AUC': 0.6056642175782773}
# INFO | HPO epoch  10/80 | loss=0.5596 | val={'ROC-AUC': 0.7586138613861386, 'PRC-AUC': 0.6452172466009413}
# INFO | HPO epoch  15/80 | loss=0.4875 | val={'ROC-AUC': 0.7057425742574257, 'PRC-AUC': 0.5759431129865484}
# INFO | HPO epoch  20/80 | loss=0.4831 | val={'ROC-AUC': 0.7910891089108911, 'PRC-AUC': 0.699377322281933}
# INFO | HPO epoch  25/80 | loss=0.4063 | val={'ROC-AUC': 0.8093069306930694, 'PRC-AUC': 0.7138950529773533}
# INFO | HPO epoch  30/80 | loss=0.4203 | val={'ROC-AUC': 0.7899009900990099, 'PRC-AUC': 0.6708745763914116}
# INFO | HPO epoch  35/80 | loss=0.4127 | val={'ROC-AUC': 0.8114851485148515, 'PRC-AUC': 0.6870731721201327}
# INFO | HPO epoch  40/80 | loss=0.3622 | val={'ROC-AUC': 0.7999999999999999, 'PRC-AUC': 0.7108586974754774}
# INFO | HPO epoch  45/80 | loss=0.2897 | val={'ROC-AUC': 0.805940594059406, 'PRC-AUC': 0.6842413568766422}
# INFO | HPO epoch  50/80 | loss=0.2443 | val={'ROC-AUC': 0.8132673267326732, 'PRC-AUC': 0.6584600914028841}
# INFO | HPO epoch  55/80 | loss=0.1823 | val={'ROC-AUC': 0.7784158415841583, 'PRC-AUC': 0.6866992102609607}
# INFO | Early stop at epoch 57 (patience=15)
# INFO | SchNet HPO — trial 6/20 finished | val=-0.835248 | best=-0.850693
# INFO | SchNet — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=1.1348 | val={'ROC-AUC': 0.5910891089108911, 'PRC-AUC': 0.4859841663634713}
# INFO | HPO epoch   5/80 | loss=0.6140 | val={'ROC-AUC': 0.7627722772277228, 'PRC-AUC': 0.6580642542586228}
# INFO | HPO epoch  10/80 | loss=0.5521 | val={'ROC-AUC': 0.8104950495049504, 'PRC-AUC': 0.7216295276365717}
# INFO | HPO epoch  15/80 | loss=0.5957 | val={'ROC-AUC': 0.833069306930693, 'PRC-AUC': 0.7409774054728205}
# INFO | HPO epoch  20/80 | loss=0.4491 | val={'ROC-AUC': 0.814059405940594, 'PRC-AUC': 0.7116023835059999}
# INFO | HPO epoch  25/80 | loss=0.5102 | val={'ROC-AUC': 0.8027722772277228, 'PRC-AUC': 0.714780772731613}
# INFO | HPO epoch  30/80 | loss=0.4061 | val={'ROC-AUC': 0.8019801980198019, 'PRC-AUC': 0.6993770641920328}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | SchNet HPO — trial 7/20 finished | val=-0.846931 | best=-0.850693
# INFO | SchNet — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=1.6829 | val={'ROC-AUC': 0.5560396039603961, 'PRC-AUC': 0.3589618791778114}
# INFO | HPO epoch   5/80 | loss=0.6059 | val={'ROC-AUC': 0.7326732673267328, 'PRC-AUC': 0.5911981627930085}
# INFO | HPO epoch  10/80 | loss=0.5161 | val={'ROC-AUC': 0.7859405940594059, 'PRC-AUC': 0.6513113511811618}
# INFO | HPO epoch  15/80 | loss=0.4941 | val={'ROC-AUC': 0.8001980198019802, 'PRC-AUC': 0.6476272480210647}
# INFO | HPO epoch  20/80 | loss=0.4895 | val={'ROC-AUC': 0.8227722772277227, 'PRC-AUC': 0.67077121399294}
# INFO | HPO epoch  25/80 | loss=0.4016 | val={'ROC-AUC': 0.821980198019802, 'PRC-AUC': 0.6755238231756124}
# INFO | HPO epoch  30/80 | loss=0.3439 | val={'ROC-AUC': 0.8201980198019801, 'PRC-AUC': 0.6770599029162438}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | SchNet HPO — trial 8/20 finished | val=-0.828317 | best=-0.850693
# INFO | SchNet — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=0.8699 | val={'ROC-AUC': 0.5875247524752475, 'PRC-AUC': 0.4596215271680517}
# INFO | HPO epoch   5/80 | loss=0.6381 | val={'ROC-AUC': 0.6794059405940593, 'PRC-AUC': 0.5545809415704667}
# INFO | HPO epoch  10/80 | loss=0.6168 | val={'ROC-AUC': 0.6720792079207921, 'PRC-AUC': 0.5711513015237257}
# INFO | HPO epoch  15/80 | loss=0.6140 | val={'ROC-AUC': 0.7023762376237623, 'PRC-AUC': 0.580555447432718}
# INFO | HPO epoch  20/80 | loss=0.5725 | val={'ROC-AUC': 0.7279207920792079, 'PRC-AUC': 0.6086085207378704}
# INFO | HPO epoch  25/80 | loss=0.5678 | val={'ROC-AUC': 0.7382178217821782, 'PRC-AUC': 0.6192677252501256}
# INFO | HPO epoch  30/80 | loss=0.5698 | val={'ROC-AUC': 0.756039603960396, 'PRC-AUC': 0.6421107990132441}
# INFO | HPO epoch  35/80 | loss=0.5444 | val={'ROC-AUC': 0.7568316831683168, 'PRC-AUC': 0.6567216640221709}
# INFO | HPO epoch  40/80 | loss=0.5390 | val={'ROC-AUC': 0.7607920792079208, 'PRC-AUC': 0.6574582633376764}
# INFO | HPO epoch  45/80 | loss=0.5297 | val={'ROC-AUC': 0.7704950495049505, 'PRC-AUC': 0.6609147130051781}
# INFO | HPO epoch  50/80 | loss=0.5261 | val={'ROC-AUC': 0.7807920792079208, 'PRC-AUC': 0.6800616547155762}
# INFO | HPO epoch  55/80 | loss=0.5247 | val={'ROC-AUC': 0.7855445544554456, 'PRC-AUC': 0.6883784843895641}
# INFO | HPO epoch  60/80 | loss=0.4981 | val={'ROC-AUC': 0.7857425742574258, 'PRC-AUC': 0.6726922075478887}
# INFO | HPO epoch  65/80 | loss=0.4877 | val={'ROC-AUC': 0.7889108910891088, 'PRC-AUC': 0.6811923667485837}
# INFO | HPO epoch  70/80 | loss=0.4894 | val={'ROC-AUC': 0.7900990099009901, 'PRC-AUC': 0.6894846801384339}
# INFO | HPO epoch  75/80 | loss=0.4662 | val={'ROC-AUC': 0.79009900990099, 'PRC-AUC': 0.6997569158672897}
# INFO | HPO epoch  80/80 | loss=0.4466 | val={'ROC-AUC': 0.7899009900990099, 'PRC-AUC': 0.6955027009953608}
# INFO | SchNet HPO — trial 9/20 finished | val=-0.796040 | best=-0.850693
# INFO | SchNet — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=1.6434 | val={'ROC-AUC': 0.5621782178217822, 'PRC-AUC': 0.40867414257072227}
# INFO | HPO epoch   5/80 | loss=0.6397 | val={'ROC-AUC': 0.6855445544554455, 'PRC-AUC': 0.5257712339309959}
# INFO | HPO epoch  10/80 | loss=0.6030 | val={'ROC-AUC': 0.7479207920792078, 'PRC-AUC': 0.6179025700001245}
# INFO | HPO epoch  15/80 | loss=0.6192 | val={'ROC-AUC': 0.7603960396039604, 'PRC-AUC': 0.6367957203091398}
# INFO | HPO epoch  20/80 | loss=0.5619 | val={'ROC-AUC': 0.7912871287128713, 'PRC-AUC': 0.670786229590882}
# INFO | HPO epoch  25/80 | loss=0.5381 | val={'ROC-AUC': 0.7980198019801981, 'PRC-AUC': 0.6787279781020414}
# INFO | HPO epoch  30/80 | loss=0.5414 | val={'ROC-AUC': 0.7998019801980198, 'PRC-AUC': 0.6881245192828148}
# INFO | HPO epoch  35/80 | loss=0.5316 | val={'ROC-AUC': 0.8148514851485149, 'PRC-AUC': 0.7057324209316413}
# INFO | HPO epoch  40/80 | loss=0.5409 | val={'ROC-AUC': 0.8225742574257426, 'PRC-AUC': 0.7036678994004024}
# INFO | HPO epoch  45/80 | loss=0.5255 | val={'ROC-AUC': 0.8168316831683168, 'PRC-AUC': 0.6761150964128667}
# INFO | HPO epoch  50/80 | loss=0.4695 | val={'ROC-AUC': 0.8326732673267326, 'PRC-AUC': 0.6835908244071399}
# INFO | HPO epoch  55/80 | loss=0.4877 | val={'ROC-AUC': 0.8293069306930693, 'PRC-AUC': 0.6969443241906176}
# INFO | HPO epoch  60/80 | loss=0.4669 | val={'ROC-AUC': 0.84, 'PRC-AUC': 0.705851634249218}
# INFO | HPO epoch  65/80 | loss=0.4607 | val={'ROC-AUC': 0.8336633663366336, 'PRC-AUC': 0.706479965844055}
# INFO | HPO epoch  70/80 | loss=0.4422 | val={'ROC-AUC': 0.8398019801980198, 'PRC-AUC': 0.7090228006920724}
# INFO | HPO epoch  75/80 | loss=0.4313 | val={'ROC-AUC': 0.832079207920792, 'PRC-AUC': 0.7128102082792032}
# INFO | HPO epoch  80/80 | loss=0.4077 | val={'ROC-AUC': 0.8283168316831683, 'PRC-AUC': 0.7043925413909552}
# INFO | SchNet HPO — trial 10/20 finished | val=-0.843564 | best=-0.850693
# INFO | SchNet — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=1.0174 | val={'ROC-AUC': 0.6295049504950495, 'PRC-AUC': 0.4825136259048314}
# INFO | HPO epoch   5/80 | loss=0.6691 | val={'ROC-AUC': 0.7100990099009901, 'PRC-AUC': 0.5858549703731541}
# INFO | HPO epoch  10/80 | loss=0.6097 | val={'ROC-AUC': 0.758019801980198, 'PRC-AUC': 0.6396748545636959}
# INFO | HPO epoch  15/80 | loss=0.6333 | val={'ROC-AUC': 0.8, 'PRC-AUC': 0.7069187994486317}
# INFO | HPO epoch  20/80 | loss=0.5619 | val={'ROC-AUC': 0.814059405940594, 'PRC-AUC': 0.7152424276883744}
# INFO | HPO epoch  25/80 | loss=0.5774 | val={'ROC-AUC': 0.7893069306930693, 'PRC-AUC': 0.6964942687578175}
# INFO | HPO epoch  30/80 | loss=0.4804 | val={'ROC-AUC': 0.8251485148514852, 'PRC-AUC': 0.715663140781637}
# INFO | HPO epoch  35/80 | loss=0.4842 | val={'ROC-AUC': 0.8293069306930693, 'PRC-AUC': 0.6959329512217401}
# INFO | HPO epoch  40/80 | loss=0.4279 | val={'ROC-AUC': 0.8223762376237623, 'PRC-AUC': 0.6777582123309374}
# INFO | Early stop at epoch 41 (patience=15)
# INFO | SchNet HPO — trial 11/20 finished | val=-0.831881 | best=-0.850693
# INFO | SchNet — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=1.9867 | val={'ROC-AUC': 0.4869306930693069, 'PRC-AUC': 0.4230203032688967}
# INFO | HPO epoch   5/80 | loss=0.6166 | val={'ROC-AUC': 0.7275247524752475, 'PRC-AUC': 0.5817532397710616}
# INFO | HPO epoch  10/80 | loss=0.5749 | val={'ROC-AUC': 0.7998019801980198, 'PRC-AUC': 0.6809426850732484}
# INFO | HPO epoch  15/80 | loss=0.5191 | val={'ROC-AUC': 0.7885148514851485, 'PRC-AUC': 0.6517851908951824}
# INFO | HPO epoch  20/80 | loss=0.4997 | val={'ROC-AUC': 0.8344554455445544, 'PRC-AUC': 0.7201814645083341}
# INFO | HPO epoch  25/80 | loss=0.4726 | val={'ROC-AUC': 0.8201980198019803, 'PRC-AUC': 0.7042969471700863}
# INFO | HPO epoch  30/80 | loss=0.3856 | val={'ROC-AUC': 0.8265346534653466, 'PRC-AUC': 0.7181296619415064}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | SchNet HPO — trial 12/20 finished | val=-0.840792 | best=-0.850693
# INFO | SchNet — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=1.7138 | val={'ROC-AUC': 0.6651485148514851, 'PRC-AUC': 0.5269973506598548}
# INFO | HPO epoch   5/80 | loss=0.5998 | val={'ROC-AUC': 0.7241584158415841, 'PRC-AUC': 0.594992124506394}
# INFO | HPO epoch  10/80 | loss=0.6176 | val={'ROC-AUC': 0.7677227722772277, 'PRC-AUC': 0.6483221302876895}
# INFO | HPO epoch  15/80 | loss=0.5279 | val={'ROC-AUC': 0.8007920792079208, 'PRC-AUC': 0.6757437001475678}
# INFO | HPO epoch  20/80 | loss=0.5927 | val={'ROC-AUC': 0.8118811881188119, 'PRC-AUC': 0.6797013022893006}
# INFO | HPO epoch  25/80 | loss=0.5004 | val={'ROC-AUC': 0.821980198019802, 'PRC-AUC': 0.6896509317764}
# INFO | HPO epoch  30/80 | loss=0.4845 | val={'ROC-AUC': 0.8297029702970298, 'PRC-AUC': 0.6919234731243522}
# INFO | HPO epoch  35/80 | loss=0.4311 | val={'ROC-AUC': 0.8144554455445545, 'PRC-AUC': 0.6891325630115446}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | SchNet HPO — trial 13/20 finished | val=-0.836040 | best=-0.850693
# INFO | SchNet — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=1.1629 | val={'ROC-AUC': 0.6388118811881188, 'PRC-AUC': 0.5348139217448383}
# INFO | HPO epoch   5/80 | loss=0.6395 | val={'ROC-AUC': 0.7138613861386138, 'PRC-AUC': 0.5774976751853056}
# INFO | HPO epoch  10/80 | loss=0.6083 | val={'ROC-AUC': 0.7768316831683169, 'PRC-AUC': 0.6320652131967863}
# INFO | HPO epoch  15/80 | loss=0.5669 | val={'ROC-AUC': 0.8217821782178218, 'PRC-AUC': 0.6886543430266578}
# INFO | HPO epoch  20/80 | loss=0.5710 | val={'ROC-AUC': 0.8312871287128712, 'PRC-AUC': 0.7211641270638705}
# INFO | HPO epoch  25/80 | loss=0.5452 | val={'ROC-AUC': 0.8364356435643564, 'PRC-AUC': 0.7133229469993043}
# INFO | HPO epoch  30/80 | loss=0.4772 | val={'ROC-AUC': 0.8576237623762376, 'PRC-AUC': 0.7293170417942413}
# INFO | HPO epoch  35/80 | loss=0.5145 | val={'ROC-AUC': 0.8455445544554455, 'PRC-AUC': 0.7197039240266174}
# INFO | HPO epoch  40/80 | loss=0.4982 | val={'ROC-AUC': 0.8396039603960397, 'PRC-AUC': 0.6943864380173735}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | SchNet HPO — trial 14/20 finished | val=-0.864158 | best=-0.864158
# INFO | SchNet — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=1.3426 | val={'ROC-AUC': 0.6354455445544553, 'PRC-AUC': 0.46047747974912456}
# INFO | HPO epoch   5/80 | loss=0.6252 | val={'ROC-AUC': 0.6972277227722773, 'PRC-AUC': 0.5656456158343481}
# INFO | HPO epoch  10/80 | loss=0.5906 | val={'ROC-AUC': 0.7712871287128712, 'PRC-AUC': 0.6474163532929001}
# INFO | HPO epoch  15/80 | loss=0.5490 | val={'ROC-AUC': 0.8025742574257426, 'PRC-AUC': 0.6894107092943975}
# INFO | HPO epoch  20/80 | loss=0.5344 | val={'ROC-AUC': 0.8225742574257425, 'PRC-AUC': 0.6985469163105178}
# INFO | HPO epoch  25/80 | loss=0.5388 | val={'ROC-AUC': 0.845940594059406, 'PRC-AUC': 0.7108045862897758}
# INFO | HPO epoch  30/80 | loss=0.4930 | val={'ROC-AUC': 0.8510891089108911, 'PRC-AUC': 0.7005696764862188}
# INFO | HPO epoch  35/80 | loss=0.4762 | val={'ROC-AUC': 0.8439603960396039, 'PRC-AUC': 0.6981903600613022}
# INFO | HPO epoch  40/80 | loss=0.4370 | val={'ROC-AUC': 0.8356435643564357, 'PRC-AUC': 0.6706371471803745}
# INFO | HPO epoch  45/80 | loss=0.4073 | val={'ROC-AUC': 0.8388118811881189, 'PRC-AUC': 0.6968162994556765}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | SchNet HPO — trial 15/20 finished | val=-0.851089 | best=-0.864158
# INFO | SchNet — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=1.1353 | val={'ROC-AUC': 0.6295049504950495, 'PRC-AUC': 0.4860115641630911}
# INFO | HPO epoch   5/80 | loss=0.6283 | val={'ROC-AUC': 0.7233663366336633, 'PRC-AUC': 0.5825975659689595}
# INFO | HPO epoch  10/80 | loss=0.6359 | val={'ROC-AUC': 0.7976237623762376, 'PRC-AUC': 0.676700728732631}
# INFO | HPO epoch  15/80 | loss=0.5635 | val={'ROC-AUC': 0.6924752475247525, 'PRC-AUC': 0.5943323191447325}
# INFO | HPO epoch  20/80 | loss=0.5882 | val={'ROC-AUC': 0.8213861386138613, 'PRC-AUC': 0.6959530862451567}
# INFO | HPO epoch  25/80 | loss=0.5254 | val={'ROC-AUC': 0.8308910891089109, 'PRC-AUC': 0.7053053436728736}
# INFO | HPO epoch  30/80 | loss=0.4821 | val={'ROC-AUC': 0.8338613861386138, 'PRC-AUC': 0.6958156125991545}
# INFO | HPO epoch  35/80 | loss=0.4679 | val={'ROC-AUC': 0.8344554455445544, 'PRC-AUC': 0.6965433564325322}
# INFO | HPO epoch  40/80 | loss=0.4686 | val={'ROC-AUC': 0.8241584158415842, 'PRC-AUC': 0.6774773106701678}
# INFO | HPO epoch  45/80 | loss=0.4171 | val={'ROC-AUC': 0.8184158415841585, 'PRC-AUC': 0.6814534840297499}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | SchNet HPO — trial 16/20 finished | val=-0.846931 | best=-0.864158
# INFO | SchNet — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=1.3005 | val={'ROC-AUC': 0.4803960396039604, 'PRC-AUC': 0.4065792262128149}
# INFO | HPO epoch   5/80 | loss=0.6475 | val={'ROC-AUC': 0.6463366336633664, 'PRC-AUC': 0.5460554541472484}
# INFO | HPO epoch  10/80 | loss=0.6073 | val={'ROC-AUC': 0.7750495049504951, 'PRC-AUC': 0.6683025154301873}
# INFO | HPO epoch  15/80 | loss=0.6454 | val={'ROC-AUC': 0.785940594059406, 'PRC-AUC': 0.6817886075747743}
# INFO | HPO epoch  20/80 | loss=0.5192 | val={'ROC-AUC': 0.8184158415841585, 'PRC-AUC': 0.7041449147171963}
# INFO | HPO epoch  25/80 | loss=0.5284 | val={'ROC-AUC': 0.8506930693069308, 'PRC-AUC': 0.7552743479120121}
# INFO | HPO epoch  30/80 | loss=0.5113 | val={'ROC-AUC': 0.8522772277227723, 'PRC-AUC': 0.7291551036675425}
# INFO | HPO epoch  35/80 | loss=0.5086 | val={'ROC-AUC': 0.8427722772277229, 'PRC-AUC': 0.6987366468534917}
# INFO | HPO epoch  40/80 | loss=0.4372 | val={'ROC-AUC': 0.8265346534653465, 'PRC-AUC': 0.6982238184762344}
# INFO | Early stop at epoch 43 (patience=15)
# INFO | SchNet HPO — trial 17/20 finished | val=-0.859604 | best=-0.864158
# INFO | SchNet — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=1.0698 | val={'ROC-AUC': 0.5936633663366336, 'PRC-AUC': 0.4709509887143881}
# INFO | HPO epoch   5/80 | loss=0.6300 | val={'ROC-AUC': 0.7104950495049505, 'PRC-AUC': 0.5815177973117754}
# INFO | HPO epoch  10/80 | loss=0.6100 | val={'ROC-AUC': 0.7500990099009901, 'PRC-AUC': 0.6207203565437507}
# INFO | HPO epoch  15/80 | loss=0.5974 | val={'ROC-AUC': 0.7827722772277228, 'PRC-AUC': 0.6903681182714583}
# INFO | HPO epoch  20/80 | loss=0.5336 | val={'ROC-AUC': 0.7958415841584159, 'PRC-AUC': 0.6728608560822178}
# INFO | HPO epoch  25/80 | loss=0.5093 | val={'ROC-AUC': 0.8281188118811881, 'PRC-AUC': 0.6908476333125007}
# INFO | HPO epoch  30/80 | loss=0.5187 | val={'ROC-AUC': 0.8302970297029703, 'PRC-AUC': 0.6815010548457537}
# INFO | HPO epoch  35/80 | loss=0.4676 | val={'ROC-AUC': 0.8118811881188118, 'PRC-AUC': 0.6965816477745039}
# INFO | HPO epoch  40/80 | loss=0.4847 | val={'ROC-AUC': 0.8128712871287128, 'PRC-AUC': 0.6915492498105723}
# INFO | HPO epoch  45/80 | loss=0.4118 | val={'ROC-AUC': 0.8223762376237624, 'PRC-AUC': 0.6944399940238205}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | SchNet HPO — trial 18/20 finished | val=-0.830297 | best=-0.864158
# INFO | SchNet — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=1.8274 | val={'ROC-AUC': 0.5231683168316832, 'PRC-AUC': 0.3920249571433597}
# INFO | HPO epoch   5/80 | loss=0.7052 | val={'ROC-AUC': 0.6033663366336633, 'PRC-AUC': 0.5254706622924621}
# INFO | HPO epoch  10/80 | loss=0.6501 | val={'ROC-AUC': 0.69009900990099, 'PRC-AUC': 0.5911443873251221}
# INFO | HPO epoch  15/80 | loss=0.6254 | val={'ROC-AUC': 0.69009900990099, 'PRC-AUC': 0.5656536179380717}
# INFO | HPO epoch  20/80 | loss=0.6018 | val={'ROC-AUC': 0.7253465346534653, 'PRC-AUC': 0.6128268407116146}
# INFO | HPO epoch  25/80 | loss=0.5775 | val={'ROC-AUC': 0.7318811881188119, 'PRC-AUC': 0.614714051447679}
# INFO | HPO epoch  30/80 | loss=0.5727 | val={'ROC-AUC': 0.7291089108910891, 'PRC-AUC': 0.6065541843917255}
# INFO | HPO epoch  35/80 | loss=0.5777 | val={'ROC-AUC': 0.718019801980198, 'PRC-AUC': 0.600706724932247}
# INFO | HPO epoch  40/80 | loss=0.5510 | val={'ROC-AUC': 0.7314851485148515, 'PRC-AUC': 0.6152167939164473}
# INFO | HPO epoch  45/80 | loss=0.5659 | val={'ROC-AUC': 0.7556435643564356, 'PRC-AUC': 0.6501344343334481}
# INFO | HPO epoch  50/80 | loss=0.5380 | val={'ROC-AUC': 0.7497029702970297, 'PRC-AUC': 0.6336937191258483}
# INFO | HPO epoch  55/80 | loss=0.5609 | val={'ROC-AUC': 0.7562376237623762, 'PRC-AUC': 0.6512129159687298}
# INFO | HPO epoch  60/80 | loss=0.5314 | val={'ROC-AUC': 0.7605940594059405, 'PRC-AUC': 0.6520013319146346}
# INFO | HPO epoch  65/80 | loss=0.5368 | val={'ROC-AUC': 0.7730693069306931, 'PRC-AUC': 0.6635061573354278}
# INFO | HPO epoch  70/80 | loss=0.5164 | val={'ROC-AUC': 0.7697029702970297, 'PRC-AUC': 0.6530296881307206}
# INFO | HPO epoch  75/80 | loss=0.5382 | val={'ROC-AUC': 0.7738613861386139, 'PRC-AUC': 0.6633493145169141}
# INFO | HPO epoch  80/80 | loss=0.5080 | val={'ROC-AUC': 0.7782178217821782, 'PRC-AUC': 0.6700942208743926}
# INFO | SchNet HPO — trial 19/20 finished | val=-0.778218 | best=-0.864158
# INFO | SchNet — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=2.7422 | val={'ROC-AUC': 0.6061386138613861, 'PRC-AUC': 0.5230172099980772}
# INFO | HPO epoch   5/80 | loss=0.6363 | val={'ROC-AUC': 0.6998019801980199, 'PRC-AUC': 0.5761405388590194}
# INFO | HPO epoch  10/80 | loss=0.6650 | val={'ROC-AUC': 0.7912871287128713, 'PRC-AUC': 0.6924534322508378}
# INFO | HPO epoch  15/80 | loss=0.5309 | val={'ROC-AUC': 0.7964356435643565, 'PRC-AUC': 0.662782640367705}
# INFO | HPO epoch  20/80 | loss=0.5103 | val={'ROC-AUC': 0.8166336633663367, 'PRC-AUC': 0.672591142095698}
# INFO | HPO epoch  25/80 | loss=0.5265 | val={'ROC-AUC': 0.8011881188118811, 'PRC-AUC': 0.687431593906384}
# INFO | HPO epoch  30/80 | loss=0.4372 | val={'ROC-AUC': 0.8152475247524752, 'PRC-AUC': 0.69834602490939}
# INFO | HPO epoch  35/80 | loss=0.4157 | val={'ROC-AUC': 0.8239603960396039, 'PRC-AUC': 0.718556084855766}
# INFO | HPO epoch  40/80 | loss=0.3884 | val={'ROC-AUC': 0.8239603960396039, 'PRC-AUC': 0.7201268994069683}
# INFO | Early stop at epoch 43 (patience=15)
# INFO | SchNet HPO — trial 20/20 finished | val=-0.833663 | best=-0.864158
# INFO | Epoch  10 | loss=0.6361 | val={'ROC-AUC': 0.7459405940594059, 'PRC-AUC': 0.6433702254302444}
# INFO | Epoch  20 | loss=0.5501 | val={'ROC-AUC': 0.8178217821782179, 'PRC-AUC': 0.6992358735069018}
# INFO | Epoch  30 | loss=0.5323 | val={'ROC-AUC': 0.823960396039604, 'PRC-AUC': 0.7104504108479532}
# INFO | Epoch  40 | loss=0.4392 | val={'ROC-AUC': 0.8047524752475248, 'PRC-AUC': 0.6818508811418373}
# INFO | Epoch  50 | loss=0.4119 | val={'ROC-AUC': 0.8063366336633664, 'PRC-AUC': 0.6826145759973099}
# INFO | Epoch  60 | loss=0.3901 | val={'ROC-AUC': 0.8015841584158416, 'PRC-AUC': 0.6721012548922781}
# INFO | Epoch  70 | loss=0.3795 | val={'ROC-AUC': 0.7992079207920791, 'PRC-AUC': 0.665208262699139}
# INFO | Epoch  80 | loss=0.3757 | val={'ROC-AUC': 0.7954455445544554, 'PRC-AUC': 0.6676803178043514}
# INFO | Saved SchNet (3D coords) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.7619047619047619, 'PRC-AUC': 0.6483057971774466}

# %% [markdown]
# ### SMILES LSTM
# Canonical isomeric SMILES tokens.

# %%
MODEL_KEY = "SMILES LSTM"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_lstm(
        tr_ds, va_ds, TASK_TYPE, len(vocab), OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import SmilesLSTM, eval_lstm, TorchLoader, train_lstm
    model = SmilesLSTM(len(vocab), embed_dim=best["embed_dim"], hidden_dim=best["hidden_dim"],
                       n_layers=best["n_layers"], out_channels=OUT_CHANNELS, dropout=best["dropout"])
    train_lstm(model, tr_ds, va_ds, TASK_TYPE, epochs=LSTM_EPOCHS, lr=best["lr"],
               batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_lstm(model, TorchLoader(te_ds, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_lstm.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | LSTM — starting trial 1/20
# → SMILES LSTM (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.6924 | val={'ROC-AUC': 0.5704950495049506, 'PRC-AUC': 0.3865136751937022}
# INFO | HPO epoch   5/80 | loss=0.6778 | val={'ROC-AUC': 0.6174257425742574, 'PRC-AUC': 0.4693272021259095}
# INFO | HPO epoch  10/80 | loss=0.5984 | val={'ROC-AUC': 0.6594059405940594, 'PRC-AUC': 0.5686903436038844}
# INFO | HPO epoch  15/80 | loss=0.5331 | val={'ROC-AUC': 0.6986138613861387, 'PRC-AUC': 0.6204243720951784}
# INFO | HPO epoch  20/80 | loss=0.5043 | val={'ROC-AUC': 0.7291089108910891, 'PRC-AUC': 0.6333536749910386}
# INFO | HPO epoch  25/80 | loss=0.4765 | val={'ROC-AUC': 0.7510891089108911, 'PRC-AUC': 0.6692691948548228}
# INFO | HPO epoch  30/80 | loss=0.4573 | val={'ROC-AUC': 0.7530693069306931, 'PRC-AUC': 0.6596283412994788}
# INFO | HPO epoch  35/80 | loss=0.4624 | val={'ROC-AUC': 0.7716831683168317, 'PRC-AUC': 0.6805254738905514}
# INFO | HPO epoch  40/80 | loss=0.4452 | val={'ROC-AUC': 0.7798019801980198, 'PRC-AUC': 0.6934945996517874}
# INFO | HPO epoch  45/80 | loss=0.4179 | val={'ROC-AUC': 0.8043564356435644, 'PRC-AUC': 0.7073932377321988}
# INFO | HPO epoch  50/80 | loss=0.4121 | val={'ROC-AUC': 0.816039603960396, 'PRC-AUC': 0.7100376263203513}
# INFO | HPO epoch  55/80 | loss=0.3914 | val={'ROC-AUC': 0.8267326732673267, 'PRC-AUC': 0.6930270477960502}
# INFO | HPO epoch  60/80 | loss=0.3886 | val={'ROC-AUC': 0.8469306930693069, 'PRC-AUC': 0.7313619923411647}
# INFO | HPO epoch  65/80 | loss=0.3682 | val={'ROC-AUC': 0.855049504950495, 'PRC-AUC': 0.7239971995192235}
# INFO | HPO epoch  70/80 | loss=0.3494 | val={'ROC-AUC': 0.8447524752475247, 'PRC-AUC': 0.7180047792618167}
# INFO | HPO epoch  75/80 | loss=0.3436 | val={'ROC-AUC': 0.8467326732673267, 'PRC-AUC': 0.7389691668936834}
# INFO | HPO epoch  80/80 | loss=0.3169 | val={'ROC-AUC': 0.8520792079207921, 'PRC-AUC': 0.7372689037419896}
# INFO | LSTM HPO — trial 1/20 finished | val=-0.859604 | best=-0.859604
# INFO | LSTM — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=0.6927 | val={'ROC-AUC': 0.6019801980198021, 'PRC-AUC': 0.4445484735185073}
# INFO | HPO epoch   5/80 | loss=0.6345 | val={'ROC-AUC': 0.6500990099009901, 'PRC-AUC': 0.5806802663143646}
# INFO | HPO epoch  10/80 | loss=0.5516 | val={'ROC-AUC': 0.6770297029702971, 'PRC-AUC': 0.613237348143552}
# INFO | HPO epoch  15/80 | loss=0.5220 | val={'ROC-AUC': 0.7221782178217822, 'PRC-AUC': 0.6373268941003032}
# INFO | HPO epoch  20/80 | loss=0.4861 | val={'ROC-AUC': 0.7542574257425743, 'PRC-AUC': 0.6686117417236728}
# INFO | HPO epoch  25/80 | loss=0.4634 | val={'ROC-AUC': 0.819009900990099, 'PRC-AUC': 0.7301157844658556}
# INFO | HPO epoch  30/80 | loss=0.4341 | val={'ROC-AUC': 0.8251485148514851, 'PRC-AUC': 0.7049939620058525}
# INFO | HPO epoch  35/80 | loss=0.4522 | val={'ROC-AUC': 0.8176237623762376, 'PRC-AUC': 0.7034199061418022}
# INFO | HPO epoch  40/80 | loss=0.4126 | val={'ROC-AUC': 0.8316831683168316, 'PRC-AUC': 0.7196612967849708}
# INFO | HPO epoch  45/80 | loss=0.4334 | val={'ROC-AUC': 0.7936633663366336, 'PRC-AUC': 0.668430079355125}
# INFO | HPO epoch  50/80 | loss=0.3990 | val={'ROC-AUC': 0.8196039603960397, 'PRC-AUC': 0.7258276883285705}
# INFO | HPO epoch  55/80 | loss=0.4160 | val={'ROC-AUC': 0.8502970297029703, 'PRC-AUC': 0.7554617025743373}
# INFO | HPO epoch  60/80 | loss=0.3809 | val={'ROC-AUC': 0.8213861386138613, 'PRC-AUC': 0.7231413431642556}
# INFO | Early stop at epoch 62 (patience=15)
# INFO | LSTM HPO — trial 2/20 finished | val=-0.854851 | best=-0.859604
# INFO | LSTM — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=0.6910 | val={'ROC-AUC': 0.6061386138613861, 'PRC-AUC': 0.45889047158017904}
# INFO | HPO epoch   5/80 | loss=0.6265 | val={'ROC-AUC': 0.6243564356435644, 'PRC-AUC': 0.5252792534418016}
# INFO | HPO epoch  10/80 | loss=0.5458 | val={'ROC-AUC': 0.6776237623762377, 'PRC-AUC': 0.5675567440590947}
# INFO | HPO epoch  15/80 | loss=0.4760 | val={'ROC-AUC': 0.8097029702970298, 'PRC-AUC': 0.6778615748463331}
# INFO | HPO epoch  20/80 | loss=0.4466 | val={'ROC-AUC': 0.7914851485148514, 'PRC-AUC': 0.6849972661417809}
# INFO | HPO epoch  25/80 | loss=0.4225 | val={'ROC-AUC': 0.8215841584158416, 'PRC-AUC': 0.7330281770967179}
# INFO | HPO epoch  30/80 | loss=0.4073 | val={'ROC-AUC': 0.8300990099009901, 'PRC-AUC': 0.7665441804136028}
# INFO | HPO epoch  35/80 | loss=0.4135 | val={'ROC-AUC': 0.8156435643564356, 'PRC-AUC': 0.6754373426183595}
# INFO | HPO epoch  40/80 | loss=0.3805 | val={'ROC-AUC': 0.8126732673267326, 'PRC-AUC': 0.6805400482844691}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | LSTM HPO — trial 3/20 finished | val=-0.841188 | best=-0.859604
# INFO | LSTM — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=0.6906 | val={'ROC-AUC': 0.5996039603960396, 'PRC-AUC': 0.4177995358475056}
# INFO | HPO epoch   5/80 | loss=0.6292 | val={'ROC-AUC': 0.6194059405940593, 'PRC-AUC': 0.49449670145971875}
# INFO | HPO epoch  10/80 | loss=0.5491 | val={'ROC-AUC': 0.6974257425742575, 'PRC-AUC': 0.5728070818542951}
# INFO | HPO epoch  15/80 | loss=0.5149 | val={'ROC-AUC': 0.7164356435643564, 'PRC-AUC': 0.556906481070229}
# INFO | HPO epoch  20/80 | loss=0.4663 | val={'ROC-AUC': 0.7499009900990099, 'PRC-AUC': 0.5941748456256479}
# INFO | HPO epoch  25/80 | loss=0.4304 | val={'ROC-AUC': 0.7942574257425743, 'PRC-AUC': 0.6456088618925949}
# INFO | HPO epoch  30/80 | loss=0.4045 | val={'ROC-AUC': 0.7811881188118812, 'PRC-AUC': 0.650925830951799}
# INFO | HPO epoch  35/80 | loss=0.3702 | val={'ROC-AUC': 0.7772277227722773, 'PRC-AUC': 0.64581312733876}
# INFO | HPO epoch  40/80 | loss=0.3582 | val={'ROC-AUC': 0.8328712871287128, 'PRC-AUC': 0.7067853474231057}
# INFO | HPO epoch  45/80 | loss=0.3754 | val={'ROC-AUC': 0.8423762376237623, 'PRC-AUC': 0.7294433688646359}
# INFO | HPO epoch  50/80 | loss=0.3446 | val={'ROC-AUC': 0.8164356435643564, 'PRC-AUC': 0.708401454479789}
# INFO | HPO epoch  55/80 | loss=0.3172 | val={'ROC-AUC': 0.8322772277227722, 'PRC-AUC': 0.710690193225173}
# INFO | HPO epoch  60/80 | loss=0.3042 | val={'ROC-AUC': 0.8310891089108912, 'PRC-AUC': 0.6686228902239041}
# INFO | HPO epoch  65/80 | loss=0.2663 | val={'ROC-AUC': 0.8388118811881188, 'PRC-AUC': 0.7233880876511098}
# INFO | Early stop at epoch 68 (patience=15)
# INFO | LSTM HPO — trial 4/20 finished | val=-0.851089 | best=-0.859604
# INFO | LSTM — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=0.6919 | val={'ROC-AUC': 0.5964356435643564, 'PRC-AUC': 0.4113770436517667}
# INFO | HPO epoch   5/80 | loss=0.6407 | val={'ROC-AUC': 0.6253465346534653, 'PRC-AUC': 0.5399128669839258}
# INFO | HPO epoch  10/80 | loss=0.5508 | val={'ROC-AUC': 0.7065346534653465, 'PRC-AUC': 0.6005455641992129}
# INFO | HPO epoch  15/80 | loss=0.4957 | val={'ROC-AUC': 0.7752475247524752, 'PRC-AUC': 0.628685420333359}
# INFO | HPO epoch  20/80 | loss=0.4734 | val={'ROC-AUC': 0.8219801980198019, 'PRC-AUC': 0.7261617920386809}
# INFO | HPO epoch  25/80 | loss=0.4294 | val={'ROC-AUC': 0.8063366336633664, 'PRC-AUC': 0.7096717601181435}
# INFO | HPO epoch  30/80 | loss=0.4218 | val={'ROC-AUC': 0.817029702970297, 'PRC-AUC': 0.7314327011030307}
# INFO | HPO epoch  35/80 | loss=0.4083 | val={'ROC-AUC': 0.8734653465346535, 'PRC-AUC': 0.7816805896782497}
# INFO | HPO epoch  40/80 | loss=0.3894 | val={'ROC-AUC': 0.8544554455445544, 'PRC-AUC': 0.773126778705896}
# INFO | HPO epoch  45/80 | loss=0.3678 | val={'ROC-AUC': 0.8332673267326732, 'PRC-AUC': 0.7687626874273932}
# INFO | HPO epoch  50/80 | loss=0.3359 | val={'ROC-AUC': 0.8596039603960396, 'PRC-AUC': 0.761843070430242}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | LSTM HPO — trial 5/20 finished | val=-0.873465 | best=-0.873465
# INFO | LSTM — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=0.6916 | val={'ROC-AUC': 0.6007920792079209, 'PRC-AUC': 0.4293956585888731}
# INFO | HPO epoch   5/80 | loss=0.6028 | val={'ROC-AUC': 0.6835643564356435, 'PRC-AUC': 0.5760971982347449}
# INFO | HPO epoch  10/80 | loss=0.4999 | val={'ROC-AUC': 0.8251485148514851, 'PRC-AUC': 0.7265369342879312}
# INFO | HPO epoch  15/80 | loss=0.4053 | val={'ROC-AUC': 0.8574257425742574, 'PRC-AUC': 0.7655971806133077}
# INFO | HPO epoch  20/80 | loss=0.3407 | val={'ROC-AUC': 0.8407920792079208, 'PRC-AUC': 0.7182465217639231}
# INFO | HPO epoch  25/80 | loss=0.3144 | val={'ROC-AUC': 0.8398019801980199, 'PRC-AUC': 0.7342236664728705}
# INFO | HPO epoch  30/80 | loss=0.2357 | val={'ROC-AUC': 0.8578217821782178, 'PRC-AUC': 0.7382261339002862}
# INFO | HPO epoch  35/80 | loss=0.2223 | val={'ROC-AUC': 0.8651485148514851, 'PRC-AUC': 0.7659960532384757}
# INFO | HPO epoch  40/80 | loss=0.1880 | val={'ROC-AUC': 0.853069306930693, 'PRC-AUC': 0.737510780944732}
# INFO | HPO epoch  45/80 | loss=0.1554 | val={'ROC-AUC': 0.8431683168316831, 'PRC-AUC': 0.6994282872349796}
# INFO | HPO epoch  50/80 | loss=0.1355 | val={'ROC-AUC': 0.8312871287128712, 'PRC-AUC': 0.7216006354521938}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | LSTM HPO — trial 6/20 finished | val=-0.865149 | best=-0.873465
# INFO | LSTM — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=0.6915 | val={'ROC-AUC': 0.6043564356435643, 'PRC-AUC': 0.44042718620466653}
# INFO | HPO epoch   5/80 | loss=0.6650 | val={'ROC-AUC': 0.6162376237623762, 'PRC-AUC': 0.465127497623953}
# INFO | HPO epoch  10/80 | loss=0.5776 | val={'ROC-AUC': 0.6764356435643564, 'PRC-AUC': 0.5480629432373016}
# INFO | HPO epoch  15/80 | loss=0.5343 | val={'ROC-AUC': 0.7271287128712871, 'PRC-AUC': 0.5843744500170316}
# INFO | HPO epoch  20/80 | loss=0.4976 | val={'ROC-AUC': 0.7392079207920792, 'PRC-AUC': 0.6408397080456348}
# INFO | HPO epoch  25/80 | loss=0.4650 | val={'ROC-AUC': 0.780990099009901, 'PRC-AUC': 0.6738264509791662}
# INFO | HPO epoch  30/80 | loss=0.4428 | val={'ROC-AUC': 0.7792079207920791, 'PRC-AUC': 0.662741144150262}
# INFO | HPO epoch  35/80 | loss=0.4255 | val={'ROC-AUC': 0.7760396039603961, 'PRC-AUC': 0.6670754306379418}
# INFO | HPO epoch  40/80 | loss=0.4016 | val={'ROC-AUC': 0.7897029702970296, 'PRC-AUC': 0.696296370053637}
# INFO | HPO epoch  45/80 | loss=0.4022 | val={'ROC-AUC': 0.8053465346534653, 'PRC-AUC': 0.7124858029314765}
# INFO | HPO epoch  50/80 | loss=0.3786 | val={'ROC-AUC': 0.8047524752475248, 'PRC-AUC': 0.7049654976833981}
# INFO | HPO epoch  55/80 | loss=0.3737 | val={'ROC-AUC': 0.7908910891089109, 'PRC-AUC': 0.6911391638999054}
# INFO | HPO epoch  60/80 | loss=0.3802 | val={'ROC-AUC': 0.8059405940594059, 'PRC-AUC': 0.7218947636181287}
# INFO | HPO epoch  65/80 | loss=0.3529 | val={'ROC-AUC': 0.8095049504950496, 'PRC-AUC': 0.7149963072358385}
# INFO | Early stop at epoch 66 (patience=15)
# INFO | LSTM HPO — trial 7/20 finished | val=-0.814455 | best=-0.873465
# INFO | LSTM — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=0.6929 | val={'ROC-AUC': 0.6112871287128714, 'PRC-AUC': 0.41102408608218277}
# INFO | HPO epoch   5/80 | loss=0.6447 | val={'ROC-AUC': 0.6354455445544555, 'PRC-AUC': 0.5490751224570555}
# INFO | HPO epoch  10/80 | loss=0.5556 | val={'ROC-AUC': 0.6823762376237623, 'PRC-AUC': 0.6045513385465062}
# INFO | HPO epoch  15/80 | loss=0.5113 | val={'ROC-AUC': 0.7291089108910891, 'PRC-AUC': 0.6363367500711031}
# INFO | HPO epoch  20/80 | loss=0.5130 | val={'ROC-AUC': 0.7847524752475248, 'PRC-AUC': 0.6580787497686937}
# INFO | HPO epoch  25/80 | loss=0.4688 | val={'ROC-AUC': 0.7895049504950495, 'PRC-AUC': 0.6401657219848994}
# INFO | HPO epoch  30/80 | loss=0.4445 | val={'ROC-AUC': 0.8047524752475248, 'PRC-AUC': 0.7132843832847594}
# INFO | HPO epoch  35/80 | loss=0.4354 | val={'ROC-AUC': 0.8073267326732673, 'PRC-AUC': 0.6966844682434652}
# INFO | HPO epoch  40/80 | loss=0.4079 | val={'ROC-AUC': 0.8346534653465346, 'PRC-AUC': 0.7389156870706919}
# INFO | HPO epoch  45/80 | loss=0.4171 | val={'ROC-AUC': 0.8289108910891089, 'PRC-AUC': 0.7242871257724712}
# INFO | HPO epoch  50/80 | loss=0.3763 | val={'ROC-AUC': 0.8198019801980198, 'PRC-AUC': 0.7388097253790542}
# INFO | HPO epoch  55/80 | loss=0.3704 | val={'ROC-AUC': 0.8162376237623762, 'PRC-AUC': 0.7363903002073726}
# INFO | HPO epoch  60/80 | loss=0.3612 | val={'ROC-AUC': 0.8132673267326733, 'PRC-AUC': 0.7365862479944159}
# INFO | HPO epoch  65/80 | loss=0.3400 | val={'ROC-AUC': 0.8447524752475248, 'PRC-AUC': 0.759655434885418}
# INFO | HPO epoch  70/80 | loss=0.3306 | val={'ROC-AUC': 0.8556435643564356, 'PRC-AUC': 0.7618879811769904}
# INFO | HPO epoch  75/80 | loss=0.3131 | val={'ROC-AUC': 0.8645544554455445, 'PRC-AUC': 0.7525239828239774}
# INFO | HPO epoch  80/80 | loss=0.3112 | val={'ROC-AUC': 0.8528712871287129, 'PRC-AUC': 0.7431644423857792}
# INFO | LSTM HPO — trial 8/20 finished | val=-0.883960 | best=-0.883960
# INFO | LSTM — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=0.6940 | val={'ROC-AUC': 0.6053465346534654, 'PRC-AUC': 0.4305037275540141}
# INFO | HPO epoch   5/80 | loss=0.5927 | val={'ROC-AUC': 0.6596039603960396, 'PRC-AUC': 0.5616605911856203}
# INFO | HPO epoch  10/80 | loss=0.6048 | val={'ROC-AUC': 0.6976237623762377, 'PRC-AUC': 0.5775174737046682}
# INFO | HPO epoch  15/80 | loss=0.5327 | val={'ROC-AUC': 0.768118811881188, 'PRC-AUC': 0.6501155843193731}
# INFO | HPO epoch  20/80 | loss=0.5129 | val={'ROC-AUC': 0.7994059405940593, 'PRC-AUC': 0.684291305913056}
# INFO | HPO epoch  25/80 | loss=0.5117 | val={'ROC-AUC': 0.8031683168316831, 'PRC-AUC': 0.6991803262929157}
# INFO | HPO epoch  30/80 | loss=0.4913 | val={'ROC-AUC': 0.8188118811881189, 'PRC-AUC': 0.7187354288318593}
# INFO | HPO epoch  35/80 | loss=0.4771 | val={'ROC-AUC': 0.8144554455445544, 'PRC-AUC': 0.690154348897372}
# INFO | HPO epoch  40/80 | loss=0.5002 | val={'ROC-AUC': 0.8027722772277228, 'PRC-AUC': 0.6341171681814779}
# INFO | HPO epoch  45/80 | loss=0.4532 | val={'ROC-AUC': 0.8283168316831684, 'PRC-AUC': 0.7055975103592241}
# INFO | HPO epoch  50/80 | loss=0.4584 | val={'ROC-AUC': 0.8350495049504951, 'PRC-AUC': 0.7200101669980212}
# INFO | HPO epoch  55/80 | loss=0.4454 | val={'ROC-AUC': 0.8247524752475247, 'PRC-AUC': 0.7122419627343095}
# INFO | Early stop at epoch 59 (patience=15)
# INFO | LSTM HPO — trial 9/20 finished | val=-0.854455 | best=-0.883960
# INFO | LSTM — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=0.6918 | val={'ROC-AUC': 0.6215841584158417, 'PRC-AUC': 0.4561573722099366}
# INFO | HPO epoch   5/80 | loss=0.6272 | val={'ROC-AUC': 0.6867326732673268, 'PRC-AUC': 0.6045015780029339}
# INFO | HPO epoch  10/80 | loss=0.5204 | val={'ROC-AUC': 0.7839603960396039, 'PRC-AUC': 0.7332607054797732}
# INFO | HPO epoch  15/80 | loss=0.4757 | val={'ROC-AUC': 0.8213861386138613, 'PRC-AUC': 0.7569533133817399}
# INFO | HPO epoch  20/80 | loss=0.4274 | val={'ROC-AUC': 0.837029702970297, 'PRC-AUC': 0.7490731756009326}
# INFO | HPO epoch  25/80 | loss=0.3851 | val={'ROC-AUC': 0.8433663366336633, 'PRC-AUC': 0.7752577223522628}
# INFO | HPO epoch  30/80 | loss=0.3593 | val={'ROC-AUC': 0.8821782178217822, 'PRC-AUC': 0.7881820659189602}
# INFO | HPO epoch  35/80 | loss=0.3321 | val={'ROC-AUC': 0.866930693069307, 'PRC-AUC': 0.6977625681787287}
# INFO | HPO epoch  40/80 | loss=0.3143 | val={'ROC-AUC': 0.8700990099009901, 'PRC-AUC': 0.6868885155555644}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | LSTM HPO — trial 10/20 finished | val=-0.884158 | best=-0.884158
# INFO | LSTM — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=0.6905 | val={'ROC-AUC': 0.5948514851485148, 'PRC-AUC': 0.40335223712820056}
# INFO | HPO epoch   5/80 | loss=0.6083 | val={'ROC-AUC': 0.6722772277227723, 'PRC-AUC': 0.6034495980060816}
# INFO | HPO epoch  10/80 | loss=0.5589 | val={'ROC-AUC': 0.6710891089108911, 'PRC-AUC': 0.5770306391427543}
# INFO | HPO epoch  15/80 | loss=0.5265 | val={'ROC-AUC': 0.7061386138613861, 'PRC-AUC': 0.6332842611774084}
# INFO | HPO epoch  20/80 | loss=0.4973 | val={'ROC-AUC': 0.7934653465346535, 'PRC-AUC': 0.7208276493028077}
# INFO | HPO epoch  25/80 | loss=0.4596 | val={'ROC-AUC': 0.7996039603960396, 'PRC-AUC': 0.6886493053778786}
# INFO | HPO epoch  30/80 | loss=0.4346 | val={'ROC-AUC': 0.7920792079207921, 'PRC-AUC': 0.6927743659337248}
# INFO | HPO epoch  35/80 | loss=0.4229 | val={'ROC-AUC': 0.8283168316831684, 'PRC-AUC': 0.7565781941384236}
# INFO | HPO epoch  40/80 | loss=0.4007 | val={'ROC-AUC': 0.8168316831683168, 'PRC-AUC': 0.7483898029500589}
# INFO | HPO epoch  45/80 | loss=0.3707 | val={'ROC-AUC': 0.8360396039603961, 'PRC-AUC': 0.7370340606214557}
# INFO | HPO epoch  50/80 | loss=0.3457 | val={'ROC-AUC': 0.8605940594059406, 'PRC-AUC': 0.7668955887080708}
# INFO | HPO epoch  55/80 | loss=0.3437 | val={'ROC-AUC': 0.8582178217821782, 'PRC-AUC': 0.7618469333878071}
# INFO | HPO epoch  60/80 | loss=0.3286 | val={'ROC-AUC': 0.8732673267326733, 'PRC-AUC': 0.7877228698417593}
# INFO | HPO epoch  65/80 | loss=0.3078 | val={'ROC-AUC': 0.8396039603960397, 'PRC-AUC': 0.7486738899149906}
# INFO | HPO epoch  70/80 | loss=0.2992 | val={'ROC-AUC': 0.8671287128712871, 'PRC-AUC': 0.7839483187042378}
# INFO | HPO epoch  75/80 | loss=0.2716 | val={'ROC-AUC': 0.878019801980198, 'PRC-AUC': 0.7824897517527429}
# INFO | Early stop at epoch 79 (patience=15)
# INFO | LSTM HPO — trial 11/20 finished | val=-0.900198 | best=-0.900198
# INFO | LSTM — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=0.6895 | val={'ROC-AUC': 0.6039603960396039, 'PRC-AUC': 0.4615635063439273}
# INFO | HPO epoch   5/80 | loss=0.6099 | val={'ROC-AUC': 0.6316831683168317, 'PRC-AUC': 0.563136634447339}
# INFO | HPO epoch  10/80 | loss=0.5459 | val={'ROC-AUC': 0.7473267326732673, 'PRC-AUC': 0.6606963487736658}
# INFO | HPO epoch  15/80 | loss=0.4972 | val={'ROC-AUC': 0.7932673267326732, 'PRC-AUC': 0.7055684231836098}
# INFO | HPO epoch  20/80 | loss=0.4734 | val={'ROC-AUC': 0.8225742574257425, 'PRC-AUC': 0.697080891979757}
# INFO | HPO epoch  25/80 | loss=0.4344 | val={'ROC-AUC': 0.8174257425742574, 'PRC-AUC': 0.6954412020459098}
# INFO | HPO epoch  30/80 | loss=0.4038 | val={'ROC-AUC': 0.7936633663366336, 'PRC-AUC': 0.6707491625708931}
# INFO | HPO epoch  35/80 | loss=0.3896 | val={'ROC-AUC': 0.8304950495049505, 'PRC-AUC': 0.7206234164900742}
# INFO | HPO epoch  40/80 | loss=0.3678 | val={'ROC-AUC': 0.8031683168316832, 'PRC-AUC': 0.6879138028714309}
# INFO | HPO epoch  45/80 | loss=0.3365 | val={'ROC-AUC': 0.8348514851485149, 'PRC-AUC': 0.7252638356791079}
# INFO | HPO epoch  50/80 | loss=0.3500 | val={'ROC-AUC': 0.832871287128713, 'PRC-AUC': 0.7095920732318712}
# INFO | HPO epoch  55/80 | loss=0.3096 | val={'ROC-AUC': 0.8188118811881189, 'PRC-AUC': 0.6825461157718669}
# INFO | HPO epoch  60/80 | loss=0.2644 | val={'ROC-AUC': 0.8413861386138614, 'PRC-AUC': 0.7031652707383591}
# INFO | Early stop at epoch 63 (patience=15)
# INFO | LSTM HPO — trial 12/20 finished | val=-0.846535 | best=-0.900198
# INFO | LSTM — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=0.6910 | val={'ROC-AUC': 0.6176237623762376, 'PRC-AUC': 0.46386229380817356}
# INFO | HPO epoch   5/80 | loss=0.6134 | val={'ROC-AUC': 0.6433663366336634, 'PRC-AUC': 0.577998996794393}
# INFO | HPO epoch  10/80 | loss=0.5486 | val={'ROC-AUC': 0.6827722772277227, 'PRC-AUC': 0.6138105628469359}
# INFO | HPO epoch  15/80 | loss=0.5091 | val={'ROC-AUC': 0.7734653465346535, 'PRC-AUC': 0.6536932924613106}
# INFO | HPO epoch  20/80 | loss=0.4544 | val={'ROC-AUC': 0.8073267326732674, 'PRC-AUC': 0.7036439977358286}
# INFO | HPO epoch  25/80 | loss=0.4267 | val={'ROC-AUC': 0.7948514851485149, 'PRC-AUC': 0.6857196538626672}
# INFO | HPO epoch  30/80 | loss=0.4120 | val={'ROC-AUC': 0.8196039603960396, 'PRC-AUC': 0.745636582192406}
# INFO | HPO epoch  35/80 | loss=0.3888 | val={'ROC-AUC': 0.8421782178217823, 'PRC-AUC': 0.7682404327212982}
# INFO | HPO epoch  40/80 | loss=0.3576 | val={'ROC-AUC': 0.8338613861386138, 'PRC-AUC': 0.7416932961394035}
# INFO | HPO epoch  45/80 | loss=0.3687 | val={'ROC-AUC': 0.8346534653465346, 'PRC-AUC': 0.7345138066872189}
# INFO | HPO epoch  50/80 | loss=0.3470 | val={'ROC-AUC': 0.8413861386138614, 'PRC-AUC': 0.7322103350510183}
# INFO | HPO epoch  55/80 | loss=0.3216 | val={'ROC-AUC': 0.8293069306930693, 'PRC-AUC': 0.7187450761139261}
# INFO | HPO epoch  60/80 | loss=0.3468 | val={'ROC-AUC': 0.8344554455445544, 'PRC-AUC': 0.7084600862100288}
# INFO | HPO epoch  65/80 | loss=0.2715 | val={'ROC-AUC': 0.8186138613861387, 'PRC-AUC': 0.707518300020163}
# INFO | Early stop at epoch 68 (patience=15)
# INFO | LSTM HPO — trial 13/20 finished | val=-0.868713 | best=-0.900198
# INFO | LSTM — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=0.6890 | val={'ROC-AUC': 0.6063366336633664, 'PRC-AUC': 0.4489439569551835}
# INFO | HPO epoch   5/80 | loss=0.6325 | val={'ROC-AUC': 0.6691089108910891, 'PRC-AUC': 0.603023488123765}
# INFO | HPO epoch  10/80 | loss=0.5540 | val={'ROC-AUC': 0.733069306930693, 'PRC-AUC': 0.6024399497709592}
# INFO | HPO epoch  15/80 | loss=0.5197 | val={'ROC-AUC': 0.7243564356435643, 'PRC-AUC': 0.5920863876595385}
# INFO | HPO epoch  20/80 | loss=0.4828 | val={'ROC-AUC': 0.7904950495049505, 'PRC-AUC': 0.6620989874727617}
# INFO | HPO epoch  25/80 | loss=0.4557 | val={'ROC-AUC': 0.7877227722772278, 'PRC-AUC': 0.678784519192628}
# INFO | HPO epoch  30/80 | loss=0.4068 | val={'ROC-AUC': 0.7984158415841585, 'PRC-AUC': 0.7139962658574285}
# INFO | HPO epoch  35/80 | loss=0.4354 | val={'ROC-AUC': 0.8245544554455445, 'PRC-AUC': 0.7201671304096047}
# INFO | HPO epoch  40/80 | loss=0.3740 | val={'ROC-AUC': 0.8411881188118812, 'PRC-AUC': 0.7130876594047408}
# INFO | HPO epoch  45/80 | loss=0.3650 | val={'ROC-AUC': 0.8077227722772277, 'PRC-AUC': 0.7161310638859588}
# INFO | HPO epoch  50/80 | loss=0.3376 | val={'ROC-AUC': 0.8332673267326732, 'PRC-AUC': 0.7089921645450883}
# INFO | HPO epoch  55/80 | loss=0.2785 | val={'ROC-AUC': 0.8382178217821782, 'PRC-AUC': 0.6958982077282343}
# INFO | Early stop at epoch 55 (patience=15)
# INFO | LSTM HPO — trial 14/20 finished | val=-0.841188 | best=-0.900198
# INFO | LSTM — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=0.6924 | val={'ROC-AUC': 0.5893069306930693, 'PRC-AUC': 0.412089286049998}
# INFO | HPO epoch   5/80 | loss=0.6601 | val={'ROC-AUC': 0.6106930693069307, 'PRC-AUC': 0.4896213279173822}
# INFO | HPO epoch  10/80 | loss=0.6355 | val={'ROC-AUC': 0.6728712871287129, 'PRC-AUC': 0.5576119777042747}
# INFO | HPO epoch  15/80 | loss=0.5638 | val={'ROC-AUC': 0.7885148514851485, 'PRC-AUC': 0.6959845539084979}
# INFO | HPO epoch  20/80 | loss=0.5394 | val={'ROC-AUC': 0.7944554455445544, 'PRC-AUC': 0.7105912053227599}
# INFO | HPO epoch  25/80 | loss=0.5379 | val={'ROC-AUC': 0.7928712871287129, 'PRC-AUC': 0.671948942623954}
# INFO | HPO epoch  30/80 | loss=0.5113 | val={'ROC-AUC': 0.7843564356435644, 'PRC-AUC': 0.6700120263166325}
# INFO | HPO epoch  35/80 | loss=0.5193 | val={'ROC-AUC': 0.7611881188118812, 'PRC-AUC': 0.5897259068956111}
# INFO | HPO epoch  40/80 | loss=0.5028 | val={'ROC-AUC': 0.8104950495049504, 'PRC-AUC': 0.7001526297514848}
# INFO | HPO epoch  45/80 | loss=0.5047 | val={'ROC-AUC': 0.8158415841584158, 'PRC-AUC': 0.703330692265041}
# INFO | HPO epoch  50/80 | loss=0.5086 | val={'ROC-AUC': 0.7572277227722772, 'PRC-AUC': 0.6070479953059771}
# INFO | HPO epoch  55/80 | loss=0.5015 | val={'ROC-AUC': 0.8150495049504951, 'PRC-AUC': 0.6848015040675833}
# INFO | HPO epoch  60/80 | loss=0.4810 | val={'ROC-AUC': 0.8011881188118812, 'PRC-AUC': 0.6631652235608075}
# INFO | Early stop at epoch 60 (patience=15)
# INFO | LSTM HPO — trial 15/20 finished | val=-0.815842 | best=-0.900198
# INFO | LSTM — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=0.6912 | val={'ROC-AUC': 0.6071287128712871, 'PRC-AUC': 0.45698974763070127}
# INFO | HPO epoch   5/80 | loss=0.6136 | val={'ROC-AUC': 0.6552475247524753, 'PRC-AUC': 0.5607414945871141}
# INFO | HPO epoch  10/80 | loss=0.5346 | val={'ROC-AUC': 0.7538613861386139, 'PRC-AUC': 0.6575552438667578}
# INFO | HPO epoch  15/80 | loss=0.5093 | val={'ROC-AUC': 0.7558415841584158, 'PRC-AUC': 0.6342523806584609}
# INFO | HPO epoch  20/80 | loss=0.4687 | val={'ROC-AUC': 0.7752475247524752, 'PRC-AUC': 0.6459982997762868}
# INFO | HPO epoch  25/80 | loss=0.4179 | val={'ROC-AUC': 0.8200000000000001, 'PRC-AUC': 0.6844915685914694}
# INFO | HPO epoch  30/80 | loss=0.4089 | val={'ROC-AUC': 0.8714851485148515, 'PRC-AUC': 0.7688084874060365}
# INFO | HPO epoch  35/80 | loss=0.3664 | val={'ROC-AUC': 0.856039603960396, 'PRC-AUC': 0.7447433322776149}
# INFO | HPO epoch  40/80 | loss=0.3557 | val={'ROC-AUC': 0.8461386138613861, 'PRC-AUC': 0.7815498355512053}
# INFO | HPO epoch  45/80 | loss=0.3178 | val={'ROC-AUC': 0.8594059405940594, 'PRC-AUC': 0.7724750834203802}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | LSTM HPO — trial 16/20 finished | val=-0.871485 | best=-0.900198
# INFO | LSTM — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=0.6903 | val={'ROC-AUC': 0.6093069306930693, 'PRC-AUC': 0.4468819972409943}
# INFO | HPO epoch   5/80 | loss=0.6153 | val={'ROC-AUC': 0.6457425742574258, 'PRC-AUC': 0.551292478998526}
# INFO | HPO epoch  10/80 | loss=0.5533 | val={'ROC-AUC': 0.6823762376237624, 'PRC-AUC': 0.5480387072599796}
# INFO | HPO epoch  15/80 | loss=0.4918 | val={'ROC-AUC': 0.7596039603960396, 'PRC-AUC': 0.6460327770317302}
# INFO | HPO epoch  20/80 | loss=0.4751 | val={'ROC-AUC': 0.8043564356435644, 'PRC-AUC': 0.686689156514259}
# INFO | HPO epoch  25/80 | loss=0.4473 | val={'ROC-AUC': 0.8003960396039604, 'PRC-AUC': 0.7063893870074764}
# INFO | HPO epoch  30/80 | loss=0.4125 | val={'ROC-AUC': 0.8003960396039603, 'PRC-AUC': 0.6823890045340902}
# INFO | Early stop at epoch 31 (patience=15)
# INFO | LSTM HPO — trial 17/20 finished | val=-0.824950 | best=-0.900198
# INFO | LSTM — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=0.6911 | val={'ROC-AUC': 0.6396039603960396, 'PRC-AUC': 0.51061569684287}
# INFO | HPO epoch   5/80 | loss=0.5667 | val={'ROC-AUC': 0.7146534653465346, 'PRC-AUC': 0.5837775000760321}
# INFO | HPO epoch  10/80 | loss=0.4566 | val={'ROC-AUC': 0.7817821782178218, 'PRC-AUC': 0.6639407166434429}
# INFO | HPO epoch  15/80 | loss=0.4004 | val={'ROC-AUC': 0.8661386138613861, 'PRC-AUC': 0.7018113687014276}
# INFO | HPO epoch  20/80 | loss=0.3392 | val={'ROC-AUC': 0.8805940594059406, 'PRC-AUC': 0.746800345791179}
# INFO | HPO epoch  25/80 | loss=0.3018 | val={'ROC-AUC': 0.8647524752475247, 'PRC-AUC': 0.7274359450433568}
# INFO | HPO epoch  30/80 | loss=0.2455 | val={'ROC-AUC': 0.8295049504950496, 'PRC-AUC': 0.6826070053922377}
# INFO | HPO epoch  35/80 | loss=0.1895 | val={'ROC-AUC': 0.8401980198019802, 'PRC-AUC': 0.716466834215869}
# INFO | Early stop at epoch 35 (patience=15)
# INFO | LSTM HPO — trial 18/20 finished | val=-0.880594 | best=-0.900198
# INFO | LSTM — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=0.6915 | val={'ROC-AUC': 0.6437623762376238, 'PRC-AUC': 0.5033810437232855}
# INFO | HPO epoch   5/80 | loss=0.6373 | val={'ROC-AUC': 0.6653465346534654, 'PRC-AUC': 0.5826566916367217}
# INFO | HPO epoch  10/80 | loss=0.5539 | val={'ROC-AUC': 0.7053465346534653, 'PRC-AUC': 0.5859354624072655}
# INFO | HPO epoch  15/80 | loss=0.5321 | val={'ROC-AUC': 0.7344554455445544, 'PRC-AUC': 0.6233404065957362}
# INFO | HPO epoch  20/80 | loss=0.4828 | val={'ROC-AUC': 0.7405940594059406, 'PRC-AUC': 0.6220206757039455}
# INFO | HPO epoch  25/80 | loss=0.4605 | val={'ROC-AUC': 0.8055445544554455, 'PRC-AUC': 0.720713912670057}
# INFO | HPO epoch  30/80 | loss=0.4311 | val={'ROC-AUC': 0.8110891089108913, 'PRC-AUC': 0.7138087837836984}
# INFO | HPO epoch  35/80 | loss=0.3983 | val={'ROC-AUC': 0.804950495049505, 'PRC-AUC': 0.7292052486045737}
# INFO | HPO epoch  40/80 | loss=0.3784 | val={'ROC-AUC': 0.8255445544554455, 'PRC-AUC': 0.686357415070685}
# INFO | HPO epoch  45/80 | loss=0.3627 | val={'ROC-AUC': 0.8512871287128713, 'PRC-AUC': 0.7333974045948641}
# INFO | HPO epoch  50/80 | loss=0.3379 | val={'ROC-AUC': 0.8487128712871287, 'PRC-AUC': 0.7126150029307026}
# INFO | HPO epoch  55/80 | loss=0.3264 | val={'ROC-AUC': 0.833069306930693, 'PRC-AUC': 0.7282046915672274}
# INFO | HPO epoch  60/80 | loss=0.2896 | val={'ROC-AUC': 0.8138613861386139, 'PRC-AUC': 0.7187245050754104}
# INFO | HPO epoch  65/80 | loss=0.2860 | val={'ROC-AUC': 0.8421782178217821, 'PRC-AUC': 0.7098781781696206}
# INFO | HPO epoch  70/80 | loss=0.2606 | val={'ROC-AUC': 0.8548514851485148, 'PRC-AUC': 0.7154840410448753}
# INFO | Early stop at epoch 71 (patience=15)
# INFO | LSTM HPO — trial 19/20 finished | val=-0.862970 | best=-0.900198
# INFO | LSTM — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=0.6917 | val={'ROC-AUC': 0.5994059405940594, 'PRC-AUC': 0.4196355607696237}
# INFO | HPO epoch   5/80 | loss=0.6674 | val={'ROC-AUC': 0.599009900990099, 'PRC-AUC': 0.4600954194280198}
# INFO | HPO epoch  10/80 | loss=0.5914 | val={'ROC-AUC': 0.6607920792079208, 'PRC-AUC': 0.5356236183576365}
# INFO | HPO epoch  15/80 | loss=0.5321 | val={'ROC-AUC': 0.7348514851485148, 'PRC-AUC': 0.616126590562378}
# INFO | HPO epoch  20/80 | loss=0.5041 | val={'ROC-AUC': 0.7304950495049505, 'PRC-AUC': 0.6203936025965655}
# INFO | HPO epoch  25/80 | loss=0.4984 | val={'ROC-AUC': 0.7166336633663366, 'PRC-AUC': 0.5874341797334379}
# INFO | HPO epoch  30/80 | loss=0.4957 | val={'ROC-AUC': 0.7562376237623762, 'PRC-AUC': 0.6345508210597182}
# INFO | HPO epoch  35/80 | loss=0.4873 | val={'ROC-AUC': 0.8025742574257425, 'PRC-AUC': 0.6836330568253531}
# INFO | HPO epoch  40/80 | loss=0.4740 | val={'ROC-AUC': 0.7706930693069307, 'PRC-AUC': 0.6741964057112002}
# INFO | HPO epoch  45/80 | loss=0.4603 | val={'ROC-AUC': 0.7897029702970297, 'PRC-AUC': 0.6768891036481861}
# INFO | HPO epoch  50/80 | loss=0.4513 | val={'ROC-AUC': 0.7776237623762376, 'PRC-AUC': 0.6547056279878662}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | LSTM HPO — trial 20/20 finished | val=-0.802574 | best=-0.900198
# INFO | Epoch  10 | loss=0.5410 | val={'ROC-AUC': 0.7510891089108911, 'PRC-AUC': 0.6395190771750141}
# INFO | Epoch  20 | loss=0.4723 | val={'ROC-AUC': 0.8128712871287128, 'PRC-AUC': 0.7559422810527454}
# INFO | Epoch  30 | loss=0.4285 | val={'ROC-AUC': 0.8011881188118812, 'PRC-AUC': 0.7319536529472435}
# INFO | Epoch  40 | loss=0.3736 | val={'ROC-AUC': 0.8542574257425742, 'PRC-AUC': 0.7961415169019089}
# INFO | Epoch  50 | loss=0.3765 | val={'ROC-AUC': 0.8510891089108911, 'PRC-AUC': 0.7716495957348817}
# INFO | Epoch  60 | loss=0.3151 | val={'ROC-AUC': 0.8528712871287129, 'PRC-AUC': 0.8001261030499712}
# INFO | Epoch  70 | loss=0.2748 | val={'ROC-AUC': 0.8651485148514851, 'PRC-AUC': 0.7755260577536521}
# INFO | Epoch  80 | loss=0.2233 | val={'ROC-AUC': 0.8548514851485148, 'PRC-AUC': 0.7688701057029761}
# INFO | Saved SMILES LSTM → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.8234747023809523, 'PRC-AUC': 0.6250410140485736}

# %% [markdown]
# ### Finalize GPU + merge

# %%
finalize_dataset_results(DATASET_SLUG, PARTIAL_PATH, RESULTS_DIR, TASK_TYPE,
    plot_title=f"BACE – ROC-AUC by Model (higher is better) (GPU, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
cpu_partial = RESULTS_ROOT / "cpu" / f"{DATASET_SLUG}_partial.json"
if cpu_partial.exists():
    merge_combined_results(DATASET_SLUG, cpu_partial, PARTIAL_PATH, RESULTS_ROOT / "combined",
        TASK_TYPE, plot_title=f"BACE – ROC-AUC by Model (higher is better) (all models, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
else:
    print("Run CPU notebook first for combined results.")
# Out:
# === BACE Results (5/12 models) ===
#                             ROC-AUC          PRC-AUC
# Model
# GIN (2D)            0.8272 ± 0.0000  0.7038 ± 0.0000
# D-MPNN (2D)         0.7879 ± 0.0000  0.6566 ± 0.0000
# GIN (3D)            0.7933 ± 0.0000  0.6115 ± 0.0000
# SchNet (3D coords)  0.7619 ± 0.0000  0.6483 ± 0.0000
# SMILES LSTM         0.8235 ± 0.0000  0.6250 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/bace_partial.json
# === BACE Results (12/12 models) ===
#                                ROC-AUC          PRC-AUC
# Model
# Morgan + RF            0.8203 ± 0.0000  0.7017 ± 0.0000
# Morgan + SVM           0.7721 ± 0.0000  0.6321 ± 0.0000
# Morgan + XGBoost       0.8324 ± 0.0000  0.7119 ± 0.0000
# Descriptors + RF       0.8279 ± 0.0000  0.6931 ± 0.0000
# Descriptors + SVM      0.7915 ± 0.0000  0.6804 ± 0.0000
# Descriptors + XGBoost  0.7747 ± 0.0000  0.6446 ± 0.0000
# Combined + XGBoost     0.8116 ± 0.0000  0.6918 ± 0.0000
# GIN (2D)               0.8272 ± 0.0000  0.7038 ± 0.0000
# D-MPNN (2D)            0.7879 ± 0.0000  0.6566 ± 0.0000
# GIN (3D)               0.7933 ± 0.0000  0.6115 ± 0.0000
# SchNet (3D coords)     0.7619 ± 0.0000  0.6483 ± 0.0000
# SMILES LSTM            0.8235 ± 0.0000  0.6250 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/combined/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/combined/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/combined/bace_partial.json
