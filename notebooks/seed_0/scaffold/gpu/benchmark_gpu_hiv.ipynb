# %% [markdown]
# # Benchmark v5 — GPU — HIV — scaffold split, seed 0
#
# **Task:** Binary — inhibits HIV replication (1) or not (0)
# **Size:** ~41,000 molecules
# **Metric:** ROC-AUC ↑
# **Cluster GPU strongly recommended** for GNN/LSTM cells.
# **Requires:** `./data/hiv_conformers_n25.pkl` for 3D models.
#
# **Scaffold split**, seed **0** — GIN, D-MPNN, SchNet, LSTM with Optuna HPO.
#
# Results go to `results/seed_0/scaffold/`.

# %%
# NOTE: autoreload is intentionally NOT enabled. With C-extension packages
# (numpy, torch, torch_geometric) `%autoreload 2` reloads them mid-run and
# corrupts their state (numpy RecursionError / torch_geometric circular
# import). If you edit the benchmark modules, restart the kernel instead.
import os
# Avoid XGBoost/OpenMP segfaults in Jupyter on macOS (OMP Error #179).
for _omp_var in (
    "OMP_NUM_THREADS",
    "OPENBLAS_NUM_THREADS",
    "MKL_NUM_THREADS",
    "VECLIB_MAXIMUM_THREADS",
    "NUMEXPR_NUM_THREADS",
):
    os.environ[_omp_var] = "1"

import sys
from pathlib import Path

ROOT = Path(".").resolve()
for _ in range(6):
    if (ROOT / "mol_repr_utils.py").exists():
        break
    ROOT = ROOT.parent
else:
    raise FileNotFoundError("Could not find benchmark_v5 root (mol_repr_utils.py)")
sys.path.insert(0, str(ROOT))

from mol_repr_utils import *
from split_utils import (
    get_or_create_splits, subset_array, subset_list, subset_graphs_by_valid_idx,
    check_split_proportions,
)
from conformer_generation import load_conformer_graphs
from hpo_utils import (
    hpo_tabular, hpo_gnn, hpo_schnet, hpo_lstm,
    save_hpo_params, hpo_params_path,
)
from hpo_config import SKLEARN_HPO_N_ITER

DATA_DIR = ROOT / "data"

DEVICE = get_device()
print(f"Benchmark v5 (GPU) code root: {ROOT}")
print(f"Device: {DEVICE}")
print("Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.")
# Out:
# INFO | Using device: cpu (request a GPU node on the cluster for large GNN/LSTM jobs)
# Benchmark v5 (GPU) code root: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5
# Device: cpu
# Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.

# %%
DATASET_SLUG = "hiv"
TASK_TYPE = "classification"
OUT_CHANNELS = 1
BATCH_SIZE = 128
GNN_EPOCHS = 80
LSTM_EPOCHS = 60
TOX21_TABULAR = False

HPO_EPOCHS = 50  # Optuna trial length; GNN_EPOCHS for final refit
HPO_N_TRIALS = 10
print(f"GPU HPO tier: xlarge — {HPO_N_TRIALS} trials, {HPO_EPOCHS} epochs/trial, batch={BATCH_SIZE}")

SPLIT_MODE = "scaffold"   # "scaffold" or "random"
SPLIT_SEED = 0

RESULTS_ROOT = ROOT / "results" / f"seed_{SPLIT_SEED}" / SPLIT_MODE
RESULTS_DIR = RESULTS_ROOT / "gpu"
SPLITS_DIR = RESULTS_ROOT / "splits"
HPO_DIR = RESULTS_DIR / "hpo"
HISTORY_DIR = RESULTS_DIR / "histories"
for d in (RESULTS_DIR, SPLITS_DIR, HPO_DIR, HISTORY_DIR):
    d.mkdir(parents=True, exist_ok=True)
print(f"Results → {RESULTS_ROOT}")

PARTIAL_PATH = RESULTS_DIR / f"{DATASET_SLUG}_partial.json"
FRESH_RUN = False
HPO_N_ITER = SKLEARN_HPO_N_ITER

if FRESH_RUN:
    reset_dataset_run(
        DATASET_SLUG, RESULTS_DIR,
        results_root=RESULTS_ROOT, split_mode=SPLIT_MODE,
    )
    print("Fresh run — cleared partial results and splits.")

results = load_partial_results(PARTIAL_PATH)
if results:
    print(f"Resuming {len(results)} saved model(s): {', '.join(order_results(results).keys())}")
print(f"SPLIT_SEED={SPLIT_SEED}  mode={SPLIT_MODE}")
# Out:
# GPU HPO tier: xlarge — 10 trials, 50 epochs/trial, batch=128
# Results → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold
# SPLIT_SEED=0  mode=scaffold

# %% [markdown]
# ### Load data

# %%
import numpy as np
import pandas as pd

df = load_dataset("hiv", cache_dir=DATA_DIR)
smiles, y = preprocess_dataset(df, "hiv")
print(f"Molecules : {len(smiles)}")
print(f"Class balance: {np.bincount(y.astype(int))}  (pos rate: {y.mean():.1%})")
smiles, y = filter_bonded_molecules(smiles, y)
print(f'After bond filter: {len(smiles)} molecules')
# Out:
# INFO | Loading 'hiv' from cache: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/hiv.csv
# [14:48:48] Explicit valence for atom # 3 Al, 6, is greater than permitted
# [14:48:49] Explicit valence for atom # 5 B, 5, is greater than permitted
# [14:48:51] Explicit valence for atom # 16 Al, 9, is greater than permitted
# [14:48:52] Explicit valence for atom # 4 Al, 9, is greater than permitted
# [14:48:57] Explicit valence for atom # 12 Al, 7, is greater than permitted
# [14:48:57] Explicit valence for atom # 13 Al, 7, is greater than permitted
# [14:48:58] WARNING: not removing hydrogen atom without neighbors
# [14:48:58] WARNING: not removing hydrogen atom without neighbors
# [14:48:58] Explicit valence for atom # 6 Ge, 5, is greater than permitted
# INFO | [hiv] 41120 / 41127 valid molecules
# [14:49:32] WARNING: not removing hydrogen atom without neighbors
# [14:49:32] WARNING: not removing hydrogen atom without neighbors
# Molecules : 41120
# Class balance: [39677  1443]  (pos rate: 3.5%)
# [14:49:47] WARNING: not removing hydrogen atom without neighbors
# [14:49:47] WARNING: not removing hydrogen atom without neighbors
# After bond filter: 41120 molecules

# %% [markdown]
# ### Representations & scaffold split

# %%
graphs2d_all = smiles_to_graphs(smiles, y)
graphs_dmpnn_all = smiles_to_dmpnn_graphs(smiles, y)
X_tok_all, vocab = tokenize_smiles(smiles)

graphs3d_all, valid_idx_3d, _ = load_conformer_graphs(
    DATASET_SLUG, data_dir=DATA_DIR, n_confs=25
)
graphs3d_all = ensure_atomic_numbers_list(graphs3d_all)
print(f"3D graphs loaded: {len(graphs3d_all)} / {len(smiles)} (valid_idx mapping)")

split_data = get_or_create_splits(
    smiles, RESULTS_ROOT, DATASET_SLUG,
    mode=SPLIT_MODE, seed=SPLIT_SEED, force=FRESH_RUN,
)
train_idx = split_data["train_idx"]
val_idx = split_data["val_idx"]
test_idx = split_data["test_idx"]
check_split_proportions(train_idx, val_idx, test_idx, raise_on_fail=True)
print(split_data["summary"])

tr2d = subset_list(graphs2d_all, train_idx)
va2d = subset_list(graphs2d_all, val_idx)
te2d = subset_list(graphs2d_all, test_idx)

tr_dmpnn = subset_list(graphs_dmpnn_all, train_idx)
va_dmpnn = subset_list(graphs_dmpnn_all, val_idx)
te_dmpnn = subset_list(graphs_dmpnn_all, test_idx)

tr3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, train_idx)
va3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, val_idx)
te3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, test_idx)

tr_ds = SMILESDataset(subset_array(X_tok_all, train_idx), subset_array(y, train_idx))
va_ds = SMILESDataset(subset_array(X_tok_all, val_idx), subset_array(y, val_idx))
te_ds = SMILESDataset(subset_array(X_tok_all, test_idx), subset_array(y, test_idx))
# Out:
# [14:50:54] WARNING: not removing hydrogen atom without neighbors
# [14:50:54] WARNING: not removing hydrogen atom without neighbors
# [14:56:04] WARNING: not removing hydrogen atom without neighbors
# [14:56:04] WARNING: not removing hydrogen atom without neighbors
# INFO | Loaded 25905 / 26040 graphs from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/hiv_conformers_n25.pkl  (n_confs=25)
# INFO | Loaded splits from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/splits/hiv_scaffold_splits.pkl
# WARNING | 12344 molecules in split have no 3D conformer (e.g. idx [26054, 26077, 26125, 26144, 26146]); excluded from 3D train/val/test subsets
# WARNING | 1421 molecules in split have no 3D conformer (e.g. idx [36513, 28578, 39493, 31621, 36486]); excluded from 3D train/val/test subsets
# WARNING | 1450 molecules in split have no 3D conformer (e.g. idx [31617, 30669, 27734, 28819, 35629]); excluded from 3D train/val/test subsets
# 3D graphs loaded: 25905 / 41120 (valid_idx mapping)
# {'n_total': 41120, 'n_train': 32896, 'n_val': 4112, 'n_test': 4112, 'n_scaffolds_total': 19082, 'n_scaffolds_train': 10858, 'n_scaffolds_val': 4112, 'n_scaffolds_test': 4112}

# %% [markdown]
# ### GIN (2D)

# %%
MODEL_KEY = "GIN (2D)"
tr = tr3d if "2D" == "3D" else tr2d
va = va3d if "2D" == "3D" else va2d
te = te3d if "2D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (2D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | GIN 2D — starting trial 1/10 (layers=5, hidden=192)
# → GIN (2D) (Optuna 10 trials, scaffold split) …
# INFO | HPO epoch   1/50 | loss=0.1966 | val={'ROC-AUC': 0.6619823803501863, 'PRC-AUC': 0.2068920281724606}
# INFO | HPO epoch   5/50 | loss=0.1427 | val={'ROC-AUC': 0.7395500029705575, 'PRC-AUC': 0.3379620030767928}
# INFO | HPO epoch  10/50 | loss=0.1290 | val={'ROC-AUC': 0.7262779762864636, 'PRC-AUC': 0.32311241650759}
# INFO | HPO epoch  15/50 | loss=0.1200 | val={'ROC-AUC': 0.731296096687404, 'PRC-AUC': 0.31226837823133824}
# INFO | HPO epoch  20/50 | loss=0.1143 | val={'ROC-AUC': 0.7160995730884464, 'PRC-AUC': 0.30794409927098004}
# INFO | HPO epoch  25/50 | loss=0.1041 | val={'ROC-AUC': 0.7586697843375233, 'PRC-AUC': 0.3475166626300728}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | GIN 2D HPO — trial 1/10 finished | val=-0.777898 | best=-0.777898
# INFO | GIN 2D — starting trial 2/10 (layers=4, hidden=192)
# INFO | HPO epoch   1/50 | loss=0.2188 | val={'ROC-AUC': 0.6971686343073932, 'PRC-AUC': 0.21921563111879527}
# INFO | HPO epoch   5/50 | loss=0.1479 | val={'ROC-AUC': 0.5343481323680436, 'PRC-AUC': 0.039894254992018964}
# INFO | HPO epoch  10/50 | loss=0.1397 | val={'ROC-AUC': 0.6450438369418534, 'PRC-AUC': 0.21007638548700783}
# INFO | HPO epoch  15/50 | loss=0.1327 | val={'ROC-AUC': 0.7408676574183308, 'PRC-AUC': 0.2720923858076011}
# INFO | HPO epoch  20/50 | loss=0.1261 | val={'ROC-AUC': 0.7488563353504833, 'PRC-AUC': 0.2942686713345218}
# INFO | HPO epoch  25/50 | loss=0.1231 | val={'ROC-AUC': 0.764511173539971, 'PRC-AUC': 0.3190780285166962}
# INFO | HPO epoch  30/50 | loss=0.1216 | val={'ROC-AUC': 0.7595227587143427, 'PRC-AUC': 0.3433822557550994}
# INFO | HPO epoch  35/50 | loss=0.1157 | val={'ROC-AUC': 0.7534034102000458, 'PRC-AUC': 0.36456915302813225}
# INFO | Early stop at epoch 38 (patience=15)
# INFO | GIN 2D HPO — trial 2/10 finished | val=-0.769031 | best=-0.777898
# INFO | GIN 2D — starting trial 3/10 (layers=3, hidden=192)
# INFO | HPO epoch   1/50 | loss=0.1748 | val={'ROC-AUC': 0.6801303650390841, 'PRC-AUC': 0.19543596910413355}
# INFO | HPO epoch   5/50 | loss=0.1346 | val={'ROC-AUC': 0.7588480177893959, 'PRC-AUC': 0.31314084226375005}
# INFO | HPO epoch  10/50 | loss=0.1190 | val={'ROC-AUC': 0.737466369045093, 'PRC-AUC': 0.31482146942479805}
# INFO | HPO epoch  15/50 | loss=0.1124 | val={'ROC-AUC': 0.7749123685528293, 'PRC-AUC': 0.35021802913814487}
# INFO | HPO epoch  20/50 | loss=0.1051 | val={'ROC-AUC': 0.7543539886100338, 'PRC-AUC': 0.36273852488963265}
# INFO | HPO epoch  25/50 | loss=0.1011 | val={'ROC-AUC': 0.7638321889614084, 'PRC-AUC': 0.3719661887129413}
# INFO | HPO epoch  30/50 | loss=0.0946 | val={'ROC-AUC': 0.7437066616874465, 'PRC-AUC': 0.3716013827426077}
# INFO | HPO epoch  35/50 | loss=0.0903 | val={'ROC-AUC': 0.7304898025003607, 'PRC-AUC': 0.3384471802198884}
# INFO | HPO epoch  40/50 | loss=0.0773 | val={'ROC-AUC': 0.764273528937474, 'PRC-AUC': 0.4001621181776086}
# INFO | Early stop at epoch 43 (patience=15)
# INFO | GIN 2D HPO — trial 3/10 finished | val=-0.786086 | best=-0.786086
# INFO | GIN 2D — starting trial 4/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.2016 | val={'ROC-AUC': 0.6661454045474992, 'PRC-AUC': 0.20832351645206434}
# INFO | HPO epoch   5/50 | loss=0.1428 | val={'ROC-AUC': 0.680607776070886, 'PRC-AUC': 0.18935201305285973}
# INFO | HPO epoch  10/50 | loss=0.1301 | val={'ROC-AUC': 0.6768288025258227, 'PRC-AUC': 0.23513939696816247}
# INFO | HPO epoch  15/50 | loss=0.1215 | val={'ROC-AUC': 0.7407658097315465, 'PRC-AUC': 0.2509921939450627}
# INFO | HPO epoch  20/50 | loss=0.1095 | val={'ROC-AUC': 0.7227515001315534, 'PRC-AUC': 0.2964996151500473}
# INFO | HPO epoch  25/50 | loss=0.1055 | val={'ROC-AUC': 0.7380626023781436, 'PRC-AUC': 0.3606804689737373}
# INFO | HPO epoch  30/50 | loss=0.1015 | val={'ROC-AUC': 0.7443538188638891, 'PRC-AUC': 0.3256105888483102}
# INFO | HPO epoch  35/50 | loss=0.0983 | val={'ROC-AUC': 0.7526989636997868, 'PRC-AUC': 0.3623685595342415}
# INFO | HPO epoch  40/50 | loss=0.0963 | val={'ROC-AUC': 0.7577680079441196, 'PRC-AUC': 0.3920805528487459}
# INFO | HPO epoch  45/50 | loss=0.0922 | val={'ROC-AUC': 0.7656612036699119, 'PRC-AUC': 0.3785193966919865}
# INFO | HPO epoch  50/50 | loss=0.0900 | val={'ROC-AUC': 0.7660643507634333, 'PRC-AUC': 0.3770505989414015}
# INFO | GIN 2D HPO — trial 4/10 finished | val=-0.779875 | best=-0.786086
# INFO | GIN 2D — starting trial 5/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.2017 | val={'ROC-AUC': 0.6187968393267869, 'PRC-AUC': 0.1610564386171389}
# INFO | HPO epoch   5/50 | loss=0.1426 | val={'ROC-AUC': 0.6954075180567462, 'PRC-AUC': 0.2605182435829292}
# INFO | HPO epoch  10/50 | loss=0.1273 | val={'ROC-AUC': 0.7590007893195726, 'PRC-AUC': 0.3390264221485815}
# INFO | HPO epoch  15/50 | loss=0.1232 | val={'ROC-AUC': 0.7397664293049744, 'PRC-AUC': 0.3762510082074591}
# INFO | HPO epoch  20/50 | loss=0.1163 | val={'ROC-AUC': 0.7333924615737166, 'PRC-AUC': 0.3016270776380813}
# INFO | HPO epoch  25/50 | loss=0.1038 | val={'ROC-AUC': 0.7596224845743191, 'PRC-AUC': 0.3568172255664367}
# INFO | Early stop at epoch 26 (patience=15)
# INFO | GIN 2D HPO — trial 5/10 finished | val=-0.773202 | best=-0.786086
# INFO | GIN 2D — starting trial 6/10 (layers=3, hidden=192)
# INFO | HPO epoch   1/50 | loss=0.1815 | val={'ROC-AUC': 0.6076954414672857, 'PRC-AUC': 0.11747774833756622}
# INFO | HPO epoch   5/50 | loss=0.1442 | val={'ROC-AUC': 0.755409597447018, 'PRC-AUC': 0.24814342899678782}
# INFO | HPO epoch  10/50 | loss=0.1302 | val={'ROC-AUC': 0.7403011296605926, 'PRC-AUC': 0.28297367299512893}
# INFO | HPO epoch  15/50 | loss=0.1251 | val={'ROC-AUC': 0.7902743946428117, 'PRC-AUC': 0.3344311012236238}
# INFO | HPO epoch  20/50 | loss=0.1204 | val={'ROC-AUC': 0.7573691045042139, 'PRC-AUC': 0.3624928586452001}
# INFO | HPO epoch  25/50 | loss=0.1135 | val={'ROC-AUC': 0.7722070393726181, 'PRC-AUC': 0.3650678481401385}
# INFO | HPO epoch  30/50 | loss=0.1052 | val={'ROC-AUC': 0.7744880031912275, 'PRC-AUC': 0.37250596583079126}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | GIN 2D HPO — trial 6/10 finished | val=-0.790274 | best=-0.790274
# INFO | GIN 2D — starting trial 7/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.1882 | val={'ROC-AUC': 0.6408468635156125, 'PRC-AUC': 0.10973805466308406}
# INFO | HPO epoch   5/50 | loss=0.1388 | val={'ROC-AUC': 0.7365327652495692, 'PRC-AUC': 0.30779405076570227}
# INFO | HPO epoch  10/50 | loss=0.1237 | val={'ROC-AUC': 0.7149389338244654, 'PRC-AUC': 0.2729972041439001}
# INFO | HPO epoch  15/50 | loss=0.1169 | val={'ROC-AUC': 0.7567028508864991, 'PRC-AUC': 0.34283529771535215}
# INFO | HPO epoch  20/50 | loss=0.1080 | val={'ROC-AUC': 0.7659412848085688, 'PRC-AUC': 0.355514743356774}
# INFO | HPO epoch  25/50 | loss=0.0960 | val={'ROC-AUC': 0.7713901360515351, 'PRC-AUC': 0.39828663431201555}
# INFO | HPO epoch  30/50 | loss=0.0909 | val={'ROC-AUC': 0.7515595427038864, 'PRC-AUC': 0.35505071424058454}
# INFO | HPO epoch  35/50 | loss=0.0863 | val={'ROC-AUC': 0.7339526238510309, 'PRC-AUC': 0.36212358418961205}
# INFO | HPO epoch  40/50 | loss=0.0755 | val={'ROC-AUC': 0.7708172428133726, 'PRC-AUC': 0.399237153595758}
# INFO | Early stop at epoch 42 (patience=15)
# INFO | GIN 2D HPO — trial 7/10 finished | val=-0.776103 | best=-0.790274
# INFO | GIN 2D — starting trial 8/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.1954 | val={'ROC-AUC': 0.629925820934792, 'PRC-AUC': 0.13799570936856878}
# INFO | HPO epoch   5/50 | loss=0.1377 | val={'ROC-AUC': 0.7442604584843368, 'PRC-AUC': 0.3387319975339391}
# INFO | HPO epoch  10/50 | loss=0.1225 | val={'ROC-AUC': 0.7215123532756763, 'PRC-AUC': 0.2968798676936575}
# INFO | HPO epoch  15/50 | loss=0.1147 | val={'ROC-AUC': 0.7636072753197595, 'PRC-AUC': 0.3331262520893577}
# INFO | HPO epoch  20/50 | loss=0.1064 | val={'ROC-AUC': 0.7606961289391715, 'PRC-AUC': 0.3878910443562133}
# INFO | Early stop at epoch 24 (patience=15)
# INFO | GIN 2D HPO — trial 8/10 finished | val=-0.776780 | best=-0.790274
# INFO | GIN 2D — starting trial 9/10 (layers=3, hidden=128)
# INFO | HPO epoch   1/50 | loss=0.1913 | val={'ROC-AUC': 0.44266823964760704, 'PRC-AUC': 0.024477989350957078}
# INFO | HPO epoch   5/50 | loss=0.1478 | val={'ROC-AUC': 0.6862391044193409, 'PRC-AUC': 0.17387554294514598}
# INFO | HPO epoch  10/50 | loss=0.1352 | val={'ROC-AUC': 0.7515850046255823, 'PRC-AUC': 0.23843006145238918}
# INFO | HPO epoch  15/50 | loss=0.1308 | val={'ROC-AUC': 0.7038375359649645, 'PRC-AUC': 0.20451056215674276}
# INFO | HPO epoch  20/50 | loss=0.1299 | val={'ROC-AUC': 0.7109350466377533, 'PRC-AUC': 0.24657352409816902}
# INFO | HPO epoch  25/50 | loss=0.1274 | val={'ROC-AUC': 0.697346867759266, 'PRC-AUC': 0.2181992113532505}
# INFO | HPO epoch  30/50 | loss=0.1240 | val={'ROC-AUC': 0.7284082904017044, 'PRC-AUC': 0.2624689693249275}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | GIN 2D HPO — trial 9/10 finished | val=-0.772810 | best=-0.790274
# INFO | GIN 2D — starting trial 10/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/50 | loss=0.1957 | val={'ROC-AUC': 0.5739923444488768, 'PRC-AUC': 0.07692054678801401}
# INFO | HPO epoch   5/50 | loss=0.1394 | val={'ROC-AUC': 0.6999736893475806, 'PRC-AUC': 0.23954272498071041}
# INFO | HPO epoch  10/50 | loss=0.1292 | val={'ROC-AUC': 0.7285695492391128, 'PRC-AUC': 0.30284489168779555}
# INFO | HPO epoch  15/50 | loss=0.1194 | val={'ROC-AUC': 0.7742079220525703, 'PRC-AUC': 0.3510821566852079}
# INFO | HPO epoch  20/50 | loss=0.1151 | val={'ROC-AUC': 0.7718442069884489, 'PRC-AUC': 0.2731179042428455}
# INFO | HPO epoch  25/50 | loss=0.1093 | val={'ROC-AUC': 0.767231355507838, 'PRC-AUC': 0.38095643649642114}
# INFO | HPO epoch  30/50 | loss=0.0996 | val={'ROC-AUC': 0.7443920117464331, 'PRC-AUC': 0.41114905057822404}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | GIN 2D HPO — trial 10/10 finished | val=-0.774208 | best=-0.790274
# INFO | Epoch  10 | loss=0.1317 | val={'ROC-AUC': 0.7685978119721956, 'PRC-AUC': 0.33512336627918454}
# INFO | Epoch  20 | loss=0.1192 | val={'ROC-AUC': 0.7461382752094243, 'PRC-AUC': 0.2882596981749205}
# INFO | Epoch  30 | loss=0.1083 | val={'ROC-AUC': 0.76031420011373, 'PRC-AUC': 0.3273927546007839}
# INFO | Epoch  40 | loss=0.1028 | val={'ROC-AUC': 0.7629579963165087, 'PRC-AUC': 0.3269222247259271}
# INFO | Epoch  50 | loss=0.0919 | val={'ROC-AUC': 0.7821753817166427, 'PRC-AUC': 0.42289780244621517}
# INFO | Saved GIN (2D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/hiv_partial.json
#    scaffold test: {'ROC-AUC': 0.7311248260911767, 'PRC-AUC': 0.32241006517886595}

# %% [markdown]
# ### D-MPNN (2D)
# Bond-centric directed MPNN (Yang et al. 2019).

# %%
MODEL_KEY = "D-MPNN (2D)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr_dmpnn, va_dmpnn, TASK_TYPE, "DMPNN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("DMPNN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr_dmpnn, va_dmpnn, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te_dmpnn, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_dmpnn.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | DMPNN 2D — starting trial 1/10 (layers=5, hidden=192)
# → D-MPNN (2D) (Optuna 10 trials, scaffold split) …
# INFO | HPO epoch   1/50 | loss=0.3218 | val={'ROC-AUC': 0.4453417414256979, 'PRC-AUC': 0.03753777679857621}
# INFO | HPO epoch   5/50 | loss=0.1553 | val={'ROC-AUC': 0.7207697138928733, 'PRC-AUC': 0.20732926770120175}
# INFO | HPO epoch  10/50 | loss=0.1415 | val={'ROC-AUC': 0.7416866825662223, 'PRC-AUC': 0.28317796271858847}
# INFO | HPO epoch  15/50 | loss=0.1346 | val={'ROC-AUC': 0.769410471639663, 'PRC-AUC': 0.3098050110265408}
# INFO | HPO epoch  20/50 | loss=0.1290 | val={'ROC-AUC': 0.7375427548101814, 'PRC-AUC': 0.32711229696729127}
# INFO | HPO epoch  25/50 | loss=0.1202 | val={'ROC-AUC': 0.7446699710582824, 'PRC-AUC': 0.3401129490270916}
# INFO | HPO epoch  30/50 | loss=0.1137 | val={'ROC-AUC': 0.7513325072354294, 'PRC-AUC': 0.3371033314190706}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | DMPNN 2D HPO — trial 1/10 finished | val=-0.769410 | best=-0.769410
# INFO | DMPNN 2D — starting trial 2/10 (layers=4, hidden=192)
# INFO | HPO epoch   1/50 | loss=0.2040 | val={'ROC-AUC': 0.5771559882196176, 'PRC-AUC': 0.1000663283861483}
# INFO | HPO epoch   5/50 | loss=0.1476 | val={'ROC-AUC': 0.7014759427276509, 'PRC-AUC': 0.25191497057465106}
# INFO | HPO epoch  10/50 | loss=0.1375 | val={'ROC-AUC': 0.7265113772353444, 'PRC-AUC': 0.2905555125372493}
# INFO | HPO epoch  15/50 | loss=0.1302 | val={'ROC-AUC': 0.6996278315778753, 'PRC-AUC': 0.2323656755130701}
# INFO | HPO epoch  20/50 | loss=0.1279 | val={'ROC-AUC': 0.7454041231338534, 'PRC-AUC': 0.3126783597125334}
# INFO | HPO epoch  25/50 | loss=0.1246 | val={'ROC-AUC': 0.7400634850580955, 'PRC-AUC': 0.3131960341467881}
# INFO | Early stop at epoch 29 (patience=15)
# INFO | DMPNN 2D HPO — trial 2/10 finished | val=-0.754980 | best=-0.769410
# INFO | DMPNN 2D — starting trial 3/10 (layers=3, hidden=192)
# INFO | HPO epoch   1/50 | loss=0.2017 | val={'ROC-AUC': 0.6333334747884539, 'PRC-AUC': 0.1580432598213678}
# INFO | HPO epoch   5/50 | loss=0.1455 | val={'ROC-AUC': 0.6150221094353394, 'PRC-AUC': 0.07468647970920393}
# INFO | HPO epoch  10/50 | loss=0.1320 | val={'ROC-AUC': 0.7252170628824595, 'PRC-AUC': 0.25941430045871505}
# INFO | HPO epoch  15/50 | loss=0.1221 | val={'ROC-AUC': 0.7343833546930565, 'PRC-AUC': 0.31073539036681846}
# INFO | HPO epoch  20/50 | loss=0.1171 | val={'ROC-AUC': 0.7470527825636759, 'PRC-AUC': 0.3456634543659787}
# INFO | HPO epoch  25/50 | loss=0.1100 | val={'ROC-AUC': 0.7762682158831469, 'PRC-AUC': 0.36808482181298524}
# INFO | HPO epoch  30/50 | loss=0.1034 | val={'ROC-AUC': 0.7558201709343677, 'PRC-AUC': 0.31943955487425546}
# INFO | HPO epoch  35/50 | loss=0.1026 | val={'ROC-AUC': 0.7863193094726835, 'PRC-AUC': 0.38661459931651804}
# INFO | HPO epoch  40/50 | loss=0.0954 | val={'ROC-AUC': 0.7415063272875415, 'PRC-AUC': 0.349402535850813}
# INFO | HPO epoch  45/50 | loss=0.0912 | val={'ROC-AUC': 0.7782160528928987, 'PRC-AUC': 0.39405200711239624}
# INFO | HPO epoch  50/50 | loss=0.0871 | val={'ROC-AUC': 0.769215263573326, 'PRC-AUC': 0.35875122916245783}
# INFO | DMPNN 2D HPO — trial 3/10 finished | val=-0.792358 | best=-0.792358
# INFO | DMPNN 2D — starting trial 4/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.2324 | val={'ROC-AUC': 0.523363434982983, 'PRC-AUC': 0.08131803586285333}
# INFO | HPO epoch   5/50 | loss=0.1584 | val={'ROC-AUC': 0.7588649924038602, 'PRC-AUC': 0.2754766879520467}
# INFO | HPO epoch  10/50 | loss=0.1368 | val={'ROC-AUC': 0.7141793198271984, 'PRC-AUC': 0.2416165761035803}
# INFO | HPO epoch  15/50 | loss=0.1300 | val={'ROC-AUC': 0.7380435059368714, 'PRC-AUC': 0.29884950911344305}
# INFO | HPO epoch  20/50 | loss=0.1185 | val={'ROC-AUC': 0.7723534454223708, 'PRC-AUC': 0.36669846916793475}
# INFO | HPO epoch  25/50 | loss=0.1154 | val={'ROC-AUC': 0.7567325564618115, 'PRC-AUC': 0.3362615823658837}
# INFO | HPO epoch  30/50 | loss=0.1121 | val={'ROC-AUC': 0.7710442782818296, 'PRC-AUC': 0.3850990773713427}
# INFO | HPO epoch  35/50 | loss=0.1063 | val={'ROC-AUC': 0.7602717635775696, 'PRC-AUC': 0.38985596028848973}
# INFO | Early stop at epoch 35 (patience=15)
# INFO | DMPNN 2D HPO — trial 4/10 finished | val=-0.772353 | best=-0.792358
# INFO | DMPNN 2D — starting trial 5/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.2102 | val={'ROC-AUC': 0.5054552167233901, 'PRC-AUC': 0.07088492703753548}
# INFO | HPO epoch   5/50 | loss=0.1461 | val={'ROC-AUC': 0.7112724171002266, 'PRC-AUC': 0.26871097774146113}
# INFO | HPO epoch  10/50 | loss=0.1316 | val={'ROC-AUC': 0.7331505733176036, 'PRC-AUC': 0.3086621543851771}
# INFO | HPO epoch  15/50 | loss=0.1246 | val={'ROC-AUC': 0.755907165833496, 'PRC-AUC': 0.32524504979842933}
# INFO | HPO epoch  20/50 | loss=0.1168 | val={'ROC-AUC': 0.7508932890861716, 'PRC-AUC': 0.3445775307770546}
# INFO | HPO epoch  25/50 | loss=0.1077 | val={'ROC-AUC': 0.7594675912173345, 'PRC-AUC': 0.38328329414711193}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | DMPNN 2D HPO — trial 5/10 finished | val=-0.777331 | best=-0.792358
# INFO | DMPNN 2D — starting trial 6/10 (layers=3, hidden=192)
# INFO | HPO epoch   1/50 | loss=0.2219 | val={'ROC-AUC': 0.4568080934961765, 'PRC-AUC': 0.05470473531260555}
# INFO | HPO epoch   5/50 | loss=0.1630 | val={'ROC-AUC': 0.7085352605178956, 'PRC-AUC': 0.23649945730040461}
# INFO | HPO epoch  10/50 | loss=0.1457 | val={'ROC-AUC': 0.7113233409436188, 'PRC-AUC': 0.2312996388752122}
# INFO | HPO epoch  15/50 | loss=0.1376 | val={'ROC-AUC': 0.7355758213591573, 'PRC-AUC': 0.26046130513707905}
# INFO | HPO epoch  20/50 | loss=0.1364 | val={'ROC-AUC': 0.7469827622790116, 'PRC-AUC': 0.2860264079954133}
# INFO | HPO epoch  25/50 | loss=0.1323 | val={'ROC-AUC': 0.7481752289451126, 'PRC-AUC': 0.3167595570371863}
# INFO | HPO epoch  30/50 | loss=0.1291 | val={'ROC-AUC': 0.7540463237228724, 'PRC-AUC': 0.3041950448874741}
# INFO | HPO epoch  35/50 | loss=0.1283 | val={'ROC-AUC': 0.7526544053368188, 'PRC-AUC': 0.32638108118897763}
# INFO | HPO epoch  40/50 | loss=0.1259 | val={'ROC-AUC': 0.7483386096093292, 'PRC-AUC': 0.331809415845218}
# INFO | HPO epoch  45/50 | loss=0.1237 | val={'ROC-AUC': 0.754693480899315, 'PRC-AUC': 0.3302804819080314}
# INFO | HPO epoch  50/50 | loss=0.1188 | val={'ROC-AUC': 0.7582623935903856, 'PRC-AUC': 0.3378398395045345}
# INFO | DMPNN 2D HPO — trial 6/10 finished | val=-0.777208 | best=-0.792358
# INFO | DMPNN 2D — starting trial 7/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.2391 | val={'ROC-AUC': 0.4608119806828887, 'PRC-AUC': 0.06284423852553901}
# INFO | HPO epoch   5/50 | loss=0.1486 | val={'ROC-AUC': 0.7127767923071047, 'PRC-AUC': 0.25947871905445524}
# INFO | HPO epoch  10/50 | loss=0.1345 | val={'ROC-AUC': 0.7070605908863297, 'PRC-AUC': 0.26445900959597546}
# INFO | HPO epoch  15/50 | loss=0.1231 | val={'ROC-AUC': 0.7404687539784253, 'PRC-AUC': 0.31128577131185314}
# INFO | HPO epoch  20/50 | loss=0.1155 | val={'ROC-AUC': 0.7442074128141366, 'PRC-AUC': 0.33045985638076913}
# INFO | HPO epoch  25/50 | loss=0.1098 | val={'ROC-AUC': 0.7309375079568505, 'PRC-AUC': 0.3149352751330175}
# INFO | HPO epoch  30/50 | loss=0.0982 | val={'ROC-AUC': 0.7666393658284036, 'PRC-AUC': 0.33721943238824326}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | DMPNN 2D HPO — trial 7/10 finished | val=-0.767320 | best=-0.792358
# INFO | DMPNN 2D — starting trial 8/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.2373 | val={'ROC-AUC': 0.5402086180117633, 'PRC-AUC': 0.10386397428391526}
# INFO | HPO epoch   5/50 | loss=0.1471 | val={'ROC-AUC': 0.7341160045152475, 'PRC-AUC': 0.25700045863113885}
# INFO | HPO epoch  10/50 | loss=0.1287 | val={'ROC-AUC': 0.7477041833937347, 'PRC-AUC': 0.33688476335668005}
# INFO | HPO epoch  15/50 | loss=0.1204 | val={'ROC-AUC': 0.718997988508186, 'PRC-AUC': 0.3086039928194126}
# INFO | HPO epoch  20/50 | loss=0.1074 | val={'ROC-AUC': 0.7508678271644754, 'PRC-AUC': 0.366485139374789}
# INFO | HPO epoch  25/50 | loss=0.1038 | val={'ROC-AUC': 0.7461870772260086, 'PRC-AUC': 0.3325206402528092}
# INFO | HPO epoch  30/50 | loss=0.0997 | val={'ROC-AUC': 0.769185557998014, 'PRC-AUC': 0.40248493215381387}
# INFO | HPO epoch  35/50 | loss=0.0946 | val={'ROC-AUC': 0.7387585615711703, 'PRC-AUC': 0.36039451277217155}
# INFO | HPO epoch  40/50 | loss=0.0905 | val={'ROC-AUC': 0.7508890454325556, 'PRC-AUC': 0.3387979422984475}
# INFO | HPO epoch  45/50 | loss=0.0836 | val={'ROC-AUC': 0.7694189589468947, 'PRC-AUC': 0.37261849578723355}
# INFO | HPO epoch  50/50 | loss=0.0817 | val={'ROC-AUC': 0.7540781511249925, 'PRC-AUC': 0.37600058127848357}
# INFO | DMPNN 2D HPO — trial 8/10 finished | val=-0.769419 | best=-0.792358
# INFO | DMPNN 2D — starting trial 9/10 (layers=3, hidden=128)
# INFO | HPO epoch   1/50 | loss=0.2169 | val={'ROC-AUC': 0.38454079424221077, 'PRC-AUC': 0.021940047750366037}
# INFO | HPO epoch   5/50 | loss=0.1476 | val={'ROC-AUC': 0.601389372193884, 'PRC-AUC': 0.10097547295454962}
# INFO | HPO epoch  10/50 | loss=0.1348 | val={'ROC-AUC': 0.7076334841244918, 'PRC-AUC': 0.28043128709775794}
# INFO | HPO epoch  15/50 | loss=0.1310 | val={'ROC-AUC': 0.7325543399845532, 'PRC-AUC': 0.29123118095535305}
# INFO | HPO epoch  20/50 | loss=0.1289 | val={'ROC-AUC': 0.7552154502940851, 'PRC-AUC': 0.30568949491454406}
# INFO | HPO epoch  25/50 | loss=0.1291 | val={'ROC-AUC': 0.7532739787647573, 'PRC-AUC': 0.29282376380563796}
# INFO | HPO epoch  30/50 | loss=0.1270 | val={'ROC-AUC': 0.734506420647921, 'PRC-AUC': 0.2883917602803129}
# INFO | HPO epoch  35/50 | loss=0.1253 | val={'ROC-AUC': 0.7594293983347904, 'PRC-AUC': 0.3115028664826583}
# INFO | HPO epoch  40/50 | loss=0.1248 | val={'ROC-AUC': 0.7557119577671593, 'PRC-AUC': 0.31128146522900524}
# INFO | HPO epoch  45/50 | loss=0.1246 | val={'ROC-AUC': 0.7612478039092537, 'PRC-AUC': 0.26737807892062876}
# INFO | HPO epoch  50/50 | loss=0.1240 | val={'ROC-AUC': 0.749753868090271, 'PRC-AUC': 0.34106092498134966}
# INFO | DMPNN 2D HPO — trial 9/10 finished | val=-0.761248 | best=-0.792358
# INFO | DMPNN 2D — starting trial 10/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/50 | loss=0.2399 | val={'ROC-AUC': 0.5303569761421794, 'PRC-AUC': 0.08671302065359371}
# INFO | HPO epoch   5/50 | loss=0.1458 | val={'ROC-AUC': 0.6940283306315405, 'PRC-AUC': 0.23677470019881833}
# INFO | HPO epoch  10/50 | loss=0.1266 | val={'ROC-AUC': 0.7523212785279614, 'PRC-AUC': 0.3134930540844822}
# INFO | HPO epoch  15/50 | loss=0.1152 | val={'ROC-AUC': 0.7440991996469281, 'PRC-AUC': 0.33978850133777666}
# INFO | HPO epoch  20/50 | loss=0.1090 | val={'ROC-AUC': 0.7669385434083329, 'PRC-AUC': 0.3836316546755247}
# INFO | HPO epoch  25/50 | loss=0.1038 | val={'ROC-AUC': 0.767736350288144, 'PRC-AUC': 0.38802086459771234}
# INFO | HPO epoch  30/50 | loss=0.1001 | val={'ROC-AUC': 0.7678806345110886, 'PRC-AUC': 0.3622874415433871}
# INFO | HPO epoch  35/50 | loss=0.0948 | val={'ROC-AUC': 0.7779571900223217, 'PRC-AUC': 0.41029760070409577}
# INFO | HPO epoch  40/50 | loss=0.0923 | val={'ROC-AUC': 0.748542304982898, 'PRC-AUC': 0.3733040920023697}
# INFO | HPO epoch  45/50 | loss=0.0887 | val={'ROC-AUC': 0.7739299627407212, 'PRC-AUC': 0.39982153338903154}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | DMPNN 2D HPO — trial 10/10 finished | val=-0.789073 | best=-0.792358
# INFO | Epoch  10 | loss=0.1328 | val={'ROC-AUC': 0.7198233791365014, 'PRC-AUC': 0.2487273674268179}
# INFO | Epoch  20 | loss=0.1173 | val={'ROC-AUC': 0.7557989526662876, 'PRC-AUC': 0.3526079638632227}
# INFO | Epoch  30 | loss=0.1042 | val={'ROC-AUC': 0.7691367559814296, 'PRC-AUC': 0.36782334469962047}
# INFO | Epoch  40 | loss=0.0957 | val={'ROC-AUC': 0.7522852074722254, 'PRC-AUC': 0.3861712986464029}
# INFO | Epoch  50 | loss=0.0844 | val={'ROC-AUC': 0.7633823616781104, 'PRC-AUC': 0.39956661370909924}
# INFO | Saved D-MPNN (2D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/hiv_partial.json
#    scaffold test: {'ROC-AUC': 0.7542607661694761, 'PRC-AUC': 0.3082226827367126}

# %% [markdown]
# ### GIN (3D)

# %%
MODEL_KEY = "GIN (3D)"
tr = tr3d if "3D" == "3D" else tr2d
va = va3d if "3D" == "3D" else va2d
te = te3d if "3D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "3D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "3D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (3D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | GIN 3D — starting trial 1/10 (layers=5, hidden=192)
# → GIN (3D) (Optuna 10 trials, scaffold split) …
# INFO | HPO epoch   1/50 | loss=0.1716 | val={'ROC-AUC': 0.5887750251495153, 'PRC-AUC': 0.03850381895718522}
# INFO | HPO epoch   5/50 | loss=0.1318 | val={'ROC-AUC': 0.7803866945245912, 'PRC-AUC': 0.32941475452974067}
# INFO | HPO epoch  10/50 | loss=0.1162 | val={'ROC-AUC': 0.7794415149404703, 'PRC-AUC': 0.2802963223473935}
# INFO | HPO epoch  15/50 | loss=0.1036 | val={'ROC-AUC': 0.7808012469737671, 'PRC-AUC': 0.3121761279864986}
# INFO | Early stop at epoch 17 (patience=15)
# INFO | GIN 3D HPO — trial 1/10 finished | val=-0.799920 | best=-0.799920
# INFO | GIN 3D — starting trial 2/10 (layers=4, hidden=192)
# INFO | HPO epoch   1/50 | loss=0.2327 | val={'ROC-AUC': 0.5267635061187941, 'PRC-AUC': 0.0786769921968225}
# INFO | HPO epoch   5/50 | loss=0.1378 | val={'ROC-AUC': 0.6572425076554019, 'PRC-AUC': 0.1392096964750202}
# INFO | HPO epoch  10/50 | loss=0.1280 | val={'ROC-AUC': 0.6246421030522116, 'PRC-AUC': 0.07461906227015723}
# INFO | HPO epoch  15/50 | loss=0.1251 | val={'ROC-AUC': 0.5784443781160525, 'PRC-AUC': 0.03420985948339199}
# INFO | HPO epoch  20/50 | loss=0.1182 | val={'ROC-AUC': 0.4695663228645022, 'PRC-AUC': 0.027387648486823665}
# INFO | HPO epoch  25/50 | loss=0.1086 | val={'ROC-AUC': 0.728805315115135, 'PRC-AUC': 0.3003976865636468}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | GIN 3D HPO — trial 2/10 finished | val=-0.770752 | best=-0.799920
# INFO | GIN 3D — starting trial 3/10 (layers=3, hidden=192)
# INFO | HPO epoch   1/50 | loss=0.1786 | val={'ROC-AUC': 0.7533302380083795, 'PRC-AUC': 0.2924680081854591}
# INFO | HPO epoch   5/50 | loss=0.1238 | val={'ROC-AUC': 0.8143855227230016, 'PRC-AUC': 0.3225773211668228}
# INFO | HPO epoch  10/50 | loss=0.1136 | val={'ROC-AUC': 0.7878431112437678, 'PRC-AUC': 0.32679170731731405}
# INFO | HPO epoch  15/50 | loss=0.1017 | val={'ROC-AUC': 0.7500746194408516, 'PRC-AUC': 0.2618422808095393}
# INFO | HPO epoch  20/50 | loss=0.0898 | val={'ROC-AUC': 0.7602007539327209, 'PRC-AUC': 0.2939294218868334}
# INFO | Early stop at epoch 20 (patience=15)
# INFO | GIN 3D HPO — trial 3/10 finished | val=-0.814386 | best=-0.814386
# INFO | GIN 3D — starting trial 4/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.1965 | val={'ROC-AUC': 0.6180313733293537, 'PRC-AUC': 0.14395289802455125}
# INFO | HPO epoch   5/50 | loss=0.1267 | val={'ROC-AUC': 0.7670546877590952, 'PRC-AUC': 0.23422514593892435}
# INFO | HPO epoch  10/50 | loss=0.1179 | val={'ROC-AUC': 0.7180822250964525, 'PRC-AUC': 0.15827764588322712}
# INFO | HPO epoch  15/50 | loss=0.1120 | val={'ROC-AUC': 0.7013895798096376, 'PRC-AUC': 0.10832773593776991}
# INFO | HPO epoch  20/50 | loss=0.1059 | val={'ROC-AUC': 0.7676129517239855, 'PRC-AUC': 0.30641416946013217}
# INFO | HPO epoch  25/50 | loss=0.1019 | val={'ROC-AUC': 0.751130346344753, 'PRC-AUC': 0.12959095805023332}
# INFO | HPO epoch  30/50 | loss=0.1011 | val={'ROC-AUC': 0.755049248830962, 'PRC-AUC': 0.18618238530900788}
# INFO | HPO epoch  35/50 | loss=0.0942 | val={'ROC-AUC': 0.7670546877590952, 'PRC-AUC': 0.3535485215795404}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | GIN 3D HPO — trial 4/10 finished | val=-0.791762 | best=-0.814386
# INFO | GIN 3D — starting trial 5/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.1755 | val={'ROC-AUC': 0.7658497219734908, 'PRC-AUC': 0.2988452140047478}
# INFO | HPO epoch   5/50 | loss=0.1278 | val={'ROC-AUC': 0.7366873390154657, 'PRC-AUC': 0.27143860737924064}
# INFO | HPO epoch  10/50 | loss=0.1182 | val={'ROC-AUC': 0.6721940326556783, 'PRC-AUC': 0.07492185277678222}
# INFO | HPO epoch  15/50 | loss=0.1127 | val={'ROC-AUC': 0.6559214671840281, 'PRC-AUC': 0.10382285231194041}
# INFO | HPO epoch  20/50 | loss=0.1001 | val={'ROC-AUC': 0.7682485988127218, 'PRC-AUC': 0.3244316385157788}
# INFO | Early stop at epoch 23 (patience=15)
# INFO | GIN 3D HPO — trial 5/10 finished | val=-0.797803 | best=-0.814386
# INFO | GIN 3D — starting trial 6/10 (layers=3, hidden=192)
# INFO | HPO epoch   1/50 | loss=0.1669 | val={'ROC-AUC': 0.6505212306127637, 'PRC-AUC': 0.21741341504772405}
# INFO | HPO epoch   5/50 | loss=0.1295 | val={'ROC-AUC': 0.7386163897456306, 'PRC-AUC': 0.2986903200341298}
# INFO | HPO epoch  10/50 | loss=0.1222 | val={'ROC-AUC': 0.7631634221028311, 'PRC-AUC': 0.34965154232696977}
# INFO | HPO epoch  15/50 | loss=0.1125 | val={'ROC-AUC': 0.765075890735029, 'PRC-AUC': 0.3265692643900683}
# INFO | HPO epoch  20/50 | loss=0.1066 | val={'ROC-AUC': 0.7985551465304722, 'PRC-AUC': 0.3747567711068128}
# INFO | HPO epoch  25/50 | loss=0.1023 | val={'ROC-AUC': 0.7453321394222797, 'PRC-AUC': 0.2301247231114989}
# INFO | HPO epoch  30/50 | loss=0.0995 | val={'ROC-AUC': 0.75405432295294, 'PRC-AUC': 0.34656551810469877}
# INFO | HPO epoch  35/50 | loss=0.0957 | val={'ROC-AUC': 0.7689616290253042, 'PRC-AUC': 0.3761559913986215}
# INFO | HPO epoch  40/50 | loss=0.0899 | val={'ROC-AUC': 0.7853447418167347, 'PRC-AUC': 0.37553660741777367}
# INFO | Early stop at epoch 41 (patience=15)
# INFO | GIN 3D HPO — trial 6/10 finished | val=-0.799318 | best=-0.814386
# INFO | GIN 3D — starting trial 7/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.2076 | val={'ROC-AUC': 0.7641859848107982, 'PRC-AUC': 0.28587285308414906}
# INFO | HPO epoch   5/50 | loss=0.1276 | val={'ROC-AUC': 0.6929990382383179, 'PRC-AUC': 0.1694295364077492}
# INFO | HPO epoch  10/50 | loss=0.1145 | val={'ROC-AUC': 0.7692545794227219, 'PRC-AUC': 0.24745571202099298}
# INFO | HPO epoch  15/50 | loss=0.1061 | val={'ROC-AUC': 0.7297449673332671, 'PRC-AUC': 0.1219594574939853}
# INFO | HPO epoch  20/50 | loss=0.1034 | val={'ROC-AUC': 0.7372677124443118, 'PRC-AUC': 0.2630198540515458}
# INFO | HPO epoch  25/50 | loss=0.0899 | val={'ROC-AUC': 0.7879149670016251, 'PRC-AUC': 0.3423815227954025}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | GIN 3D HPO — trial 7/10 finished | val=-0.797754 | best=-0.814386
# INFO | GIN 3D — starting trial 8/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/50 | loss=0.1757 | val={'ROC-AUC': 0.7409876297549166, 'PRC-AUC': 0.26392963326735086}
# INFO | HPO epoch   5/50 | loss=0.1225 | val={'ROC-AUC': 0.7570833195149184, 'PRC-AUC': 0.2697959587950953}
# INFO | HPO epoch  10/50 | loss=0.1116 | val={'ROC-AUC': 0.6413292209730375, 'PRC-AUC': 0.05330932074985291}
# INFO | HPO epoch  15/50 | loss=0.1074 | val={'ROC-AUC': 0.7493781713262362, 'PRC-AUC': 0.2787363973132439}
# INFO | HPO epoch  20/50 | loss=0.0959 | val={'ROC-AUC': 0.7586641461877758, 'PRC-AUC': 0.31222609415343516}
# INFO | HPO epoch  25/50 | loss=0.0920 | val={'ROC-AUC': 0.7482561160304668, 'PRC-AUC': 0.2805760396897861}
# INFO | HPO epoch  30/50 | loss=0.0876 | val={'ROC-AUC': 0.7821222874451409, 'PRC-AUC': 0.325126394181515}
# INFO | HPO epoch  35/50 | loss=0.0716 | val={'ROC-AUC': 0.76205242153904, 'PRC-AUC': 0.37201588996697305}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | GIN 3D HPO — trial 8/10 finished | val=-0.794570 | best=-0.814386
# INFO | GIN 3D — starting trial 9/10 (layers=3, hidden=128)
# INFO | HPO epoch   1/50 | loss=0.2676 | val={'ROC-AUC': 0.38049281995158024, 'PRC-AUC': 0.019148190581122947}
# INFO | HPO epoch   5/50 | loss=0.1373 | val={'ROC-AUC': 0.38862910268740536, 'PRC-AUC': 0.02017414173960571}
# INFO | HPO epoch  10/50 | loss=0.1280 | val={'ROC-AUC': 0.7765230656982722, 'PRC-AUC': 0.2946639329862724}
# INFO | HPO epoch  15/50 | loss=0.1234 | val={'ROC-AUC': 0.584314440796383, 'PRC-AUC': 0.08061646594893583}
# INFO | HPO epoch  20/50 | loss=0.1188 | val={'ROC-AUC': 0.705866746260737, 'PRC-AUC': 0.23192816395714838}
# INFO | HPO epoch  25/50 | loss=0.1166 | val={'ROC-AUC': 0.697255110049857, 'PRC-AUC': 0.23595466331668138}
# INFO | Early stop at epoch 29 (patience=15)
# INFO | GIN 3D HPO — trial 9/10 finished | val=-0.789584 | best=-0.814386
# INFO | GIN 3D — starting trial 10/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/50 | loss=0.2091 | val={'ROC-AUC': 0.7254612586917829, 'PRC-AUC': 0.2989134060946617}
# INFO | HPO epoch   5/50 | loss=0.1314 | val={'ROC-AUC': 0.7462939011043677, 'PRC-AUC': 0.285967815822218}
# INFO | HPO epoch  10/50 | loss=0.1191 | val={'ROC-AUC': 0.6240396201594092, 'PRC-AUC': 0.10227396123918728}
# INFO | HPO epoch  15/50 | loss=0.1115 | val={'ROC-AUC': 0.7338628549950806, 'PRC-AUC': 0.23122943408272503}
# INFO | HPO epoch  20/50 | loss=0.1067 | val={'ROC-AUC': 0.6756044174708984, 'PRC-AUC': 0.14883184485843018}
# INFO | HPO epoch  25/50 | loss=0.1028 | val={'ROC-AUC': 0.681573972739031, 'PRC-AUC': 0.08261632133506844}
# INFO | HPO epoch  30/50 | loss=0.0991 | val={'ROC-AUC': 0.7443151040803015, 'PRC-AUC': 0.31448140670688096}
# INFO | HPO epoch  35/50 | loss=0.0959 | val={'ROC-AUC': 0.7257929006511237, 'PRC-AUC': 0.1827575398693624}
# INFO | HPO epoch  40/50 | loss=0.0929 | val={'ROC-AUC': 0.779314385522723, 'PRC-AUC': 0.3356729627549079}
# INFO | HPO epoch  45/50 | loss=0.0831 | val={'ROC-AUC': 0.7751467515670082, 'PRC-AUC': 0.36370372798805056}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | GIN 3D HPO — trial 10/10 finished | val=-0.798937 | best=-0.814386
# INFO | Epoch  10 | loss=0.1155 | val={'ROC-AUC': 0.7411479233685979, 'PRC-AUC': 0.21622354552362433}
# INFO | Epoch  20 | loss=0.1016 | val={'ROC-AUC': 0.7080390010944183, 'PRC-AUC': 0.1146453024758206}
# INFO | Epoch  30 | loss=0.0881 | val={'ROC-AUC': 0.7405454404757956, 'PRC-AUC': 0.3512501216879332}
# INFO | Epoch  40 | loss=0.0693 | val={'ROC-AUC': 0.7418388441172244, 'PRC-AUC': 0.2910583122648273}
# INFO | Epoch  50 | loss=0.0565 | val={'ROC-AUC': 0.7440387357808511, 'PRC-AUC': 0.3302455605746165}
# INFO | Saved GIN (3D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/hiv_partial.json
#    scaffold test: {'ROC-AUC': 0.6749843629715165, 'PRC-AUC': 0.2891048392190308}

# %% [markdown]
# ### SchNet (3D coords)
# Uses atomic numbers + xyz from min-energy n=25 conformer.

# %%
MODEL_KEY = "SchNet (3D coords)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_schnet(
        tr3d, va3d, TASK_TYPE, OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_schnet, PyGLoader, build_schnet, train_schnet
    model = build_schnet(
        OUT_CHANNELS,
        hidden_channels=best["hidden_channels"],
        num_filters=best["num_filters"],
        num_interactions=best["num_interactions"],
        num_gaussians=best["num_gaussians"],
        cutoff=best["cutoff"],
    )
    train_schnet(model, tr3d, va3d, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
                 batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    te3d_schnet = ensure_atomic_numbers_list(te3d)
    test_metrics = eval_schnet(model, PyGLoader(te3d_schnet, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_schnet.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# → SchNet (3D coords) (Optuna 10 trials, scaffold split) …
# INFO | SchNet — starting trial 1/10
# INFO | HPO epoch   1/50 | loss=0.1761 | val={'ROC-AUC': 0.4902718358593396, 'PRC-AUC': 0.08946176953203692}
# INFO | HPO epoch   5/50 | loss=0.1406 | val={'ROC-AUC': 0.4909074829480759, 'PRC-AUC': 0.0774605020854695}
# INFO | HPO epoch  10/50 | loss=0.1388 | val={'ROC-AUC': 0.5901458119147901, 'PRC-AUC': 0.14254591541482217}
# INFO | HPO epoch  15/50 | loss=0.1363 | val={'ROC-AUC': 0.6008246830055605, 'PRC-AUC': 0.14577378907273336}
# INFO | HPO epoch  20/50 | loss=0.1332 | val={'ROC-AUC': 0.6537713218143028, 'PRC-AUC': 0.15496624288390248}
# INFO | HPO epoch  25/50 | loss=0.1314 | val={'ROC-AUC': 0.6823478039774925, 'PRC-AUC': 0.1866746529521584}
# INFO | HPO epoch  30/50 | loss=0.1311 | val={'ROC-AUC': 0.6916669430349661, 'PRC-AUC': 0.21937763402164553}
# INFO | HPO epoch  35/50 | loss=0.1323 | val={'ROC-AUC': 0.6478404581080932, 'PRC-AUC': 0.19443295969226107}
# INFO | HPO epoch  40/50 | loss=0.1303 | val={'ROC-AUC': 0.6634055207331498, 'PRC-AUC': 0.202945620447089}
# INFO | HPO epoch  45/50 | loss=0.1314 | val={'ROC-AUC': 0.642550768856609, 'PRC-AUC': 0.19157849939038757}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | SchNet HPO — trial 1/10 finished | val=-0.731558 | best=-0.731558
# INFO | SchNet — starting trial 2/10
# INFO | HPO epoch   1/50 | loss=0.3979 | val={'ROC-AUC': 0.5067710233365392, 'PRC-AUC': 0.09469191333589844}
# INFO | HPO epoch   5/50 | loss=0.1343 | val={'ROC-AUC': 0.5829823455930311, 'PRC-AUC': 0.15718129444497397}
# INFO | HPO epoch  10/50 | loss=0.1240 | val={'ROC-AUC': 0.6607910766203473, 'PRC-AUC': 0.1874479158680463}
# INFO | HPO epoch  15/50 | loss=0.1188 | val={'ROC-AUC': 0.7222056401242551, 'PRC-AUC': 0.21392318891253806}
# INFO | HPO epoch  20/50 | loss=0.1093 | val={'ROC-AUC': 0.7261963983683216, 'PRC-AUC': 0.23733454162262643}
# INFO | HPO epoch  25/50 | loss=0.1033 | val={'ROC-AUC': 0.730701201649366, 'PRC-AUC': 0.25228832075168384}
# INFO | HPO epoch  30/50 | loss=0.1007 | val={'ROC-AUC': 0.7530096507810168, 'PRC-AUC': 0.2571157884267635}
# INFO | HPO epoch  35/50 | loss=0.0935 | val={'ROC-AUC': 0.7339181286549707, 'PRC-AUC': 0.25838263335970446}
# INFO | HPO epoch  40/50 | loss=0.0788 | val={'ROC-AUC': 0.7629976011231607, 'PRC-AUC': 0.3180396858896731}
# INFO | HPO epoch  45/50 | loss=0.0710 | val={'ROC-AUC': 0.7506107739417858, 'PRC-AUC': 0.27026118739101695}
# INFO | HPO epoch  50/50 | loss=0.0667 | val={'ROC-AUC': 0.7362285676383776, 'PRC-AUC': 0.29097587528337526}
# INFO | SchNet HPO — trial 2/10 finished | val=-0.772018 | best=-0.772018
# INFO | SchNet — starting trial 3/10
# INFO | HPO epoch   1/50 | loss=0.4857 | val={'ROC-AUC': 0.4916702594545595, 'PRC-AUC': 0.07204031209037681}
# INFO | HPO epoch   5/50 | loss=0.1481 | val={'ROC-AUC': 0.6064017952884732, 'PRC-AUC': 0.13458795020745973}
# INFO | HPO epoch  10/50 | loss=0.1347 | val={'ROC-AUC': 0.6883505234415591, 'PRC-AUC': 0.1992317891789995}
# INFO | HPO epoch  15/50 | loss=0.1309 | val={'ROC-AUC': 0.6286162791983108, 'PRC-AUC': 0.11166714399917414}
# INFO | HPO epoch  20/50 | loss=0.1279 | val={'ROC-AUC': 0.6607358029604572, 'PRC-AUC': 0.18782199599980035}
# INFO | HPO epoch  25/50 | loss=0.1202 | val={'ROC-AUC': 0.753136780198764, 'PRC-AUC': 0.2741536930968843}
# INFO | HPO epoch  30/50 | loss=0.1179 | val={'ROC-AUC': 0.7320719884146408, 'PRC-AUC': 0.22093011176724314}
# INFO | HPO epoch  35/50 | loss=0.1123 | val={'ROC-AUC': 0.7036226356691981, 'PRC-AUC': 0.1332663740265807}
# INFO | HPO epoch  40/50 | loss=0.0998 | val={'ROC-AUC': 0.6793851358073824, 'PRC-AUC': 0.13826640772551194}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | SchNet HPO — trial 3/10 finished | val=-0.753137 | best=-0.772018
# INFO | SchNet — starting trial 4/10
# INFO | HPO epoch   1/50 | loss=0.3143 | val={'ROC-AUC': 0.4508230247957638, 'PRC-AUC': 0.0358765081410153}
# INFO | HPO epoch   5/50 | loss=0.1561 | val={'ROC-AUC': 0.5692302590123702, 'PRC-AUC': 0.12981233779714285}
# INFO | HPO epoch  10/50 | loss=0.1474 | val={'ROC-AUC': 0.5449761770525874, 'PRC-AUC': 0.09232494143828923}
# INFO | HPO epoch  15/50 | loss=0.1409 | val={'ROC-AUC': 0.5331033949081905, 'PRC-AUC': 0.05730085641356442}
# INFO | HPO epoch  20/50 | loss=0.1365 | val={'ROC-AUC': 0.6343039388010037, 'PRC-AUC': 0.2083312727608823}
# INFO | HPO epoch  25/50 | loss=0.1331 | val={'ROC-AUC': 0.6455244917586973, 'PRC-AUC': 0.22394934544648387}
# INFO | HPO epoch  30/50 | loss=0.1280 | val={'ROC-AUC': 0.6519804552338628, 'PRC-AUC': 0.16913745916610617}
# INFO | HPO epoch  35/50 | loss=0.1220 | val={'ROC-AUC': 0.6457566411302359, 'PRC-AUC': 0.13805314626146853}
# INFO | HPO epoch  40/50 | loss=0.1209 | val={'ROC-AUC': 0.7011242662421651, 'PRC-AUC': 0.21156139870323454}
# INFO | HPO epoch  45/50 | loss=0.1174 | val={'ROC-AUC': 0.6912579179517792, 'PRC-AUC': 0.20578117052371103}
# INFO | HPO epoch  50/50 | loss=0.1202 | val={'ROC-AUC': 0.7282525785162338, 'PRC-AUC': 0.23789430190978475}
# INFO | SchNet HPO — trial 4/10 finished | val=-0.728253 | best=-0.772018
# INFO | SchNet — starting trial 5/10
# INFO | HPO epoch   1/50 | loss=0.2390 | val={'ROC-AUC': 0.4871046551476359, 'PRC-AUC': 0.0458328486101515}
# INFO | HPO epoch   5/50 | loss=0.1255 | val={'ROC-AUC': 0.7062481345139787, 'PRC-AUC': 0.23729716851161992}
# INFO | HPO epoch  10/50 | loss=0.1126 | val={'ROC-AUC': 0.6677997766944141, 'PRC-AUC': 0.1152654655345789}
# INFO | HPO epoch  15/50 | loss=0.1047 | val={'ROC-AUC': 0.7272687073701897, 'PRC-AUC': 0.26146241451357843}
# INFO | HPO epoch  20/50 | loss=0.0978 | val={'ROC-AUC': 0.753059397074918, 'PRC-AUC': 0.35662092357428765}
# INFO | HPO epoch  25/50 | loss=0.0695 | val={'ROC-AUC': 0.7582606484705778, 'PRC-AUC': 0.27614469326870755}
# INFO | Early stop at epoch 26 (patience=15)
# INFO | SchNet HPO — trial 5/10 finished | val=-0.785439 | best=-0.785439
# INFO | SchNet — starting trial 6/10
# INFO | HPO epoch   1/50 | loss=0.2434 | val={'ROC-AUC': 0.5132601510076388, 'PRC-AUC': 0.05904887460182685}
# INFO | HPO epoch   5/50 | loss=0.1502 | val={'ROC-AUC': 0.6426834256403453, 'PRC-AUC': 0.18418210110592323}
# INFO | HPO epoch  10/50 | loss=0.1321 | val={'ROC-AUC': 0.6378801445958944, 'PRC-AUC': 0.12512692912657059}
# INFO | HPO epoch  15/50 | loss=0.1214 | val={'ROC-AUC': 0.6644391381730951, 'PRC-AUC': 0.12292435738607871}
# INFO | HPO epoch  20/50 | loss=0.1200 | val={'ROC-AUC': 0.6494157574149615, 'PRC-AUC': 0.14092861680352903}
# INFO | HPO epoch  25/50 | loss=0.1140 | val={'ROC-AUC': 0.6883394687095811, 'PRC-AUC': 0.22343966344144778}
# INFO | HPO epoch  30/50 | loss=0.1084 | val={'ROC-AUC': 0.6970561248742525, 'PRC-AUC': 0.23071395398733574}
# INFO | HPO epoch  35/50 | loss=0.1034 | val={'ROC-AUC': 0.7143899446157927, 'PRC-AUC': 0.20137006707237382}
# INFO | HPO epoch  40/50 | loss=0.0917 | val={'ROC-AUC': 0.7222609137841454, 'PRC-AUC': 0.3046420474703429}
# INFO | HPO epoch  45/50 | loss=0.0858 | val={'ROC-AUC': 0.7332272079063443, 'PRC-AUC': 0.27367234149098857}
# INFO | HPO epoch  50/50 | loss=0.0853 | val={'ROC-AUC': 0.721149913220354, 'PRC-AUC': 0.3077234742735569}
# INFO | SchNet HPO — trial 6/10 finished | val=-0.751998 | best=-0.785439
# INFO | SchNet — starting trial 7/10
# INFO | HPO epoch   1/50 | loss=0.4225 | val={'ROC-AUC': 0.5166981726528039, 'PRC-AUC': 0.0783896253884103}
# INFO | HPO epoch   5/50 | loss=0.1375 | val={'ROC-AUC': 0.6059209144474292, 'PRC-AUC': 0.1351124422587807}
# INFO | HPO epoch  10/50 | loss=0.1214 | val={'ROC-AUC': 0.6649863474060071, 'PRC-AUC': 0.2140123961270425}
# INFO | HPO epoch  15/50 | loss=0.1140 | val={'ROC-AUC': 0.7534297305961818, 'PRC-AUC': 0.2807951855047957}
# INFO | HPO epoch  20/50 | loss=0.1063 | val={'ROC-AUC': 0.7166561646712876, 'PRC-AUC': 0.28663051849214405}
# INFO | HPO epoch  25/50 | loss=0.0958 | val={'ROC-AUC': 0.7802319282768989, 'PRC-AUC': 0.3101866948078678}
# INFO | HPO epoch  30/50 | loss=0.0906 | val={'ROC-AUC': 0.7646447561878862, 'PRC-AUC': 0.33285572898762616}
# INFO | HPO epoch  35/50 | loss=0.0783 | val={'ROC-AUC': 0.7495495196718955, 'PRC-AUC': 0.4018004726995112}
# INFO | HPO epoch  40/50 | loss=0.0525 | val={'ROC-AUC': 0.7113001470279353, 'PRC-AUC': 0.33554592431072694}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | SchNet HPO — trial 7/10 finished | val=-0.780232 | best=-0.785439
# INFO | SchNet — starting trial 8/10
# INFO | HPO epoch   1/50 | loss=0.1699 | val={'ROC-AUC': 0.5435501166274224, 'PRC-AUC': 0.14989374052405105}
# INFO | HPO epoch   5/50 | loss=0.1233 | val={'ROC-AUC': 0.7038934766026598, 'PRC-AUC': 0.2468469440107365}
# INFO | HPO epoch  10/50 | loss=0.1097 | val={'ROC-AUC': 0.6809051614543605, 'PRC-AUC': 0.1902555581624741}
# INFO | HPO epoch  15/50 | loss=0.0976 | val={'ROC-AUC': 0.7562984335444788, 'PRC-AUC': 0.21570882559229962}
# INFO | HPO epoch  20/50 | loss=0.0818 | val={'ROC-AUC': 0.7227915409190904, 'PRC-AUC': 0.2758590001921417}
# INFO | HPO epoch  25/50 | loss=0.0627 | val={'ROC-AUC': 0.7676295338219524, 'PRC-AUC': 0.3063715733004006}
# INFO | HPO epoch  30/50 | loss=0.0538 | val={'ROC-AUC': 0.7356316121115644, 'PRC-AUC': 0.2532772114923536}
# INFO | HPO epoch  35/50 | loss=0.0264 | val={'ROC-AUC': 0.704015078654418, 'PRC-AUC': 0.24194147129327218}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | SchNet HPO — trial 8/10 finished | val=-0.783040 | best=-0.785439
# INFO | SchNet — starting trial 9/10
# INFO | HPO epoch   1/50 | loss=0.1853 | val={'ROC-AUC': 0.4549740766535115, 'PRC-AUC': 0.029904205291851282}
# INFO | HPO epoch   5/50 | loss=0.1529 | val={'ROC-AUC': 0.5708995235410518, 'PRC-AUC': 0.15449362667869765}
# INFO | HPO epoch  10/50 | loss=0.1411 | val={'ROC-AUC': 0.5601432693264352, 'PRC-AUC': 0.09558568350932152}
# INFO | HPO epoch  15/50 | loss=0.1362 | val={'ROC-AUC': 0.6595197824428746, 'PRC-AUC': 0.22595490102177618}
# INFO | HPO epoch  20/50 | loss=0.1327 | val={'ROC-AUC': 0.6541195458716104, 'PRC-AUC': 0.18182853871240365}
# INFO | HPO epoch  25/50 | loss=0.1219 | val={'ROC-AUC': 0.6986093147171646, 'PRC-AUC': 0.23506432192250068}
# INFO | HPO epoch  30/50 | loss=0.1178 | val={'ROC-AUC': 0.6893896682474933, 'PRC-AUC': 0.20740651688098066}
# INFO | HPO epoch  35/50 | loss=0.1141 | val={'ROC-AUC': 0.6813473507334815, 'PRC-AUC': 0.20361856271836806}
# INFO | HPO epoch  40/50 | loss=0.1107 | val={'ROC-AUC': 0.684470312517273, 'PRC-AUC': 0.2033468346895583}
# INFO | HPO epoch  45/50 | loss=0.1060 | val={'ROC-AUC': 0.6736366751788103, 'PRC-AUC': 0.1578065146828817}
# INFO | HPO epoch  50/50 | loss=0.1026 | val={'ROC-AUC': 0.6759250046982611, 'PRC-AUC': 0.17256077725856542}
# INFO | SchNet HPO — trial 9/10 finished | val=-0.760405 | best=-0.785439
# INFO | SchNet — starting trial 10/10
# INFO | HPO epoch   1/50 | loss=0.1817 | val={'ROC-AUC': 0.5018571949723079, 'PRC-AUC': 0.08242867399198445}
# INFO | HPO epoch   5/50 | loss=0.1402 | val={'ROC-AUC': 0.576305287478305, 'PRC-AUC': 0.1512712768872948}
# INFO | HPO epoch  10/50 | loss=0.1372 | val={'ROC-AUC': 0.5674615018958865, 'PRC-AUC': 0.09629714639032062}
# INFO | HPO epoch  15/50 | loss=0.1372 | val={'ROC-AUC': 0.5572414021822041, 'PRC-AUC': 0.13016224198476659}
# INFO | HPO epoch  20/50 | loss=0.1354 | val={'ROC-AUC': 0.6116251561480892, 'PRC-AUC': 0.15974565204868998}
# INFO | HPO epoch  25/50 | loss=0.1376 | val={'ROC-AUC': 0.6877093489868339, 'PRC-AUC': 0.2073623504519708}
# INFO | HPO epoch  30/50 | loss=0.1320 | val={'ROC-AUC': 0.6355475961485314, 'PRC-AUC': 0.167737556509408}
# INFO | HPO epoch  35/50 | loss=0.1326 | val={'ROC-AUC': 0.6642622624614466, 'PRC-AUC': 0.18469542910002984}
# INFO | HPO epoch  40/50 | loss=0.1293 | val={'ROC-AUC': 0.6417161365922684, 'PRC-AUC': 0.17046828763545063}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | SchNet HPO — trial 10/10 finished | val=-0.687709 | best=-0.785439
# INFO | Epoch  10 | loss=0.1196 | val={'ROC-AUC': 0.6969428138714777, 'PRC-AUC': 0.2844128149347648}
# INFO | Epoch  20 | loss=0.0986 | val={'ROC-AUC': 0.739815828165246, 'PRC-AUC': 0.27329242067213955}
# INFO | Epoch  30 | loss=0.0907 | val={'ROC-AUC': 0.7644844625742049, 'PRC-AUC': 0.25279078638815516}
# INFO | Epoch  40 | loss=0.0518 | val={'ROC-AUC': 0.687759095280735, 'PRC-AUC': 0.20582434442422298}
# INFO | Epoch  50 | loss=0.0221 | val={'ROC-AUC': 0.7175681800594744, 'PRC-AUC': 0.19504255980114968}
# INFO | Saved SchNet (3D coords) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/hiv_partial.json
#    scaffold test: {'ROC-AUC': 0.673709343725943, 'PRC-AUC': 0.2142234160608148}

# %% [markdown]
# ### SMILES LSTM
# Canonical isomeric SMILES tokens.

# %%
MODEL_KEY = "SMILES LSTM"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_lstm(
        tr_ds, va_ds, TASK_TYPE, len(vocab), OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import SmilesLSTM, eval_lstm, TorchLoader, train_lstm
    model = SmilesLSTM(len(vocab), embed_dim=best["embed_dim"], hidden_dim=best["hidden_dim"],
                       n_layers=best["n_layers"], out_channels=OUT_CHANNELS, dropout=best["dropout"])
    train_lstm(model, tr_ds, va_ds, TASK_TYPE, epochs=LSTM_EPOCHS, lr=best["lr"],
               batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_lstm(model, TorchLoader(te_ds, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_lstm.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | LSTM — starting trial 1/10
# → SMILES LSTM (Optuna 10 trials, scaffold split) …
# INFO | HPO epoch   1/50 | loss=0.2317 | val={'ROC-AUC': 0.608760598524906, 'PRC-AUC': 0.03884173094438032}
# INFO | HPO epoch   5/50 | loss=0.1475 | val={'ROC-AUC': 0.7246144640689848, 'PRC-AUC': 0.1720549743810493}
# INFO | HPO epoch  10/50 | loss=0.1317 | val={'ROC-AUC': 0.7733040238323587, 'PRC-AUC': 0.2631703521434673}
# INFO | HPO epoch  15/50 | loss=0.1244 | val={'ROC-AUC': 0.7994406864534088, 'PRC-AUC': 0.30885543616240524}
# INFO | HPO epoch  20/50 | loss=0.1189 | val={'ROC-AUC': 0.78248729025742, 'PRC-AUC': 0.3177652912796066}
# INFO | HPO epoch  25/50 | loss=0.1147 | val={'ROC-AUC': 0.7911782928630234, 'PRC-AUC': 0.36866873822688523}
# INFO | HPO epoch  30/50 | loss=0.1099 | val={'ROC-AUC': 0.7601762813712093, 'PRC-AUC': 0.34829789498048397}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | LSTM HPO — trial 1/10 finished | val=-0.799441 | best=-0.799441
# INFO | LSTM — starting trial 2/10
# INFO | HPO epoch   1/50 | loss=0.1726 | val={'ROC-AUC': 0.6637350092936015, 'PRC-AUC': 0.05726914647953857}
# INFO | HPO epoch   5/50 | loss=0.1502 | val={'ROC-AUC': 0.7157473498383168, 'PRC-AUC': 0.13630101205292025}
# INFO | HPO epoch  10/50 | loss=0.1452 | val={'ROC-AUC': 0.6770070359776954, 'PRC-AUC': 0.13332408328665923}
# INFO | HPO epoch  15/50 | loss=0.1434 | val={'ROC-AUC': 0.7037844902947642, 'PRC-AUC': 0.14926927661910946}
# INFO | HPO epoch  20/50 | loss=0.1424 | val={'ROC-AUC': 0.7326477003641054, 'PRC-AUC': 0.18251707694871838}
# INFO | HPO epoch  25/50 | loss=0.1433 | val={'ROC-AUC': 0.730568310092257, 'PRC-AUC': 0.1887995116425507}
# INFO | HPO epoch  30/50 | loss=0.1437 | val={'ROC-AUC': 0.7437554637040307, 'PRC-AUC': 0.1821857167524905}
# INFO | HPO epoch  35/50 | loss=0.1416 | val={'ROC-AUC': 0.7334264108026447, 'PRC-AUC': 0.19147967487650486}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | LSTM HPO — trial 2/10 finished | val=-0.745744 | best=-0.799441
# INFO | LSTM — starting trial 3/10
# INFO | HPO epoch   1/50 | loss=0.1928 | val={'ROC-AUC': 0.6666928358639654, 'PRC-AUC': 0.059425659049553214}
# INFO | HPO epoch   5/50 | loss=0.1356 | val={'ROC-AUC': 0.7307529090245537, 'PRC-AUC': 0.256819993197913}
# INFO | HPO epoch  10/50 | loss=0.1262 | val={'ROC-AUC': 0.785173522996359, 'PRC-AUC': 0.33194656209737994}
# INFO | HPO epoch  15/50 | loss=0.1182 | val={'ROC-AUC': 0.7896017755446729, 'PRC-AUC': 0.33153550324028075}
# INFO | HPO epoch  20/50 | loss=0.1120 | val={'ROC-AUC': 0.7761239316602022, 'PRC-AUC': 0.3881210907581133}
# INFO | HPO epoch  25/50 | loss=0.1050 | val={'ROC-AUC': 0.7549799275183963, 'PRC-AUC': 0.36571347578431834}
# INFO | HPO epoch  30/50 | loss=0.0984 | val={'ROC-AUC': 0.7907114909652614, 'PRC-AUC': 0.3722639486775894}
# INFO | HPO epoch  35/50 | loss=0.0877 | val={'ROC-AUC': 0.7856954923911291, 'PRC-AUC': 0.37072089982956863}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | LSTM HPO — trial 3/10 finished | val=-0.794465 | best=-0.799441
# INFO | LSTM — starting trial 4/10
# INFO | HPO epoch   1/50 | loss=0.1897 | val={'ROC-AUC': 0.6736460623138096, 'PRC-AUC': 0.06630494260057053}
# INFO | HPO epoch   5/50 | loss=0.1406 | val={'ROC-AUC': 0.7437363672627585, 'PRC-AUC': 0.18953471072556693}
# INFO | HPO epoch  10/50 | loss=0.1324 | val={'ROC-AUC': 0.7726611103095321, 'PRC-AUC': 0.2922257233013627}
# INFO | HPO epoch  15/50 | loss=0.1268 | val={'ROC-AUC': 0.78785763390849, 'PRC-AUC': 0.3380052121130546}
# INFO | HPO epoch  20/50 | loss=0.1228 | val={'ROC-AUC': 0.7919548814747546, 'PRC-AUC': 0.34896898133915455}
# INFO | HPO epoch  25/50 | loss=0.1199 | val={'ROC-AUC': 0.7835439600078082, 'PRC-AUC': 0.34601321220969694}
# INFO | HPO epoch  30/50 | loss=0.1173 | val={'ROC-AUC': 0.7781375453010023, 'PRC-AUC': 0.35763727032117937}
# INFO | HPO epoch  35/50 | loss=0.1152 | val={'ROC-AUC': 0.788905816351646, 'PRC-AUC': 0.32759440730475603}
# INFO | HPO epoch  40/50 | loss=0.1130 | val={'ROC-AUC': 0.7986789506293338, 'PRC-AUC': 0.3305463293028273}
# INFO | HPO epoch  45/50 | loss=0.1089 | val={'ROC-AUC': 0.7985877120765894, 'PRC-AUC': 0.3157979903013732}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | LSTM HPO — trial 4/10 finished | val=-0.803929 | best=-0.803929
# INFO | LSTM — starting trial 5/10
# INFO | HPO epoch   1/50 | loss=0.1874 | val={'ROC-AUC': 0.660187314870611, 'PRC-AUC': 0.06459749358071802}
# INFO | HPO epoch   5/50 | loss=0.1419 | val={'ROC-AUC': 0.7219155003691979, 'PRC-AUC': 0.1825215429662823}
# INFO | HPO epoch  10/50 | loss=0.1338 | val={'ROC-AUC': 0.7755998404386241, 'PRC-AUC': 0.23185708381433937}
# INFO | HPO epoch  15/50 | loss=0.1280 | val={'ROC-AUC': 0.7708830194444207, 'PRC-AUC': 0.256735805051531}
# INFO | HPO epoch  20/50 | loss=0.1233 | val={'ROC-AUC': 0.7853305381801517, 'PRC-AUC': 0.30920452175595703}
# INFO | HPO epoch  25/50 | loss=0.1200 | val={'ROC-AUC': 0.7655508686758953, 'PRC-AUC': 0.3073500849753365}
# INFO | HPO epoch  30/50 | loss=0.1176 | val={'ROC-AUC': 0.7630046765062848, 'PRC-AUC': 0.31601618863030895}
# INFO | HPO epoch  35/50 | loss=0.1120 | val={'ROC-AUC': 0.7510163550410361, 'PRC-AUC': 0.3348239635126835}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | LSTM HPO — trial 5/10 finished | val=-0.788681 | best=-0.803929
# INFO | LSTM — starting trial 6/10
# INFO | HPO epoch   1/50 | loss=0.1722 | val={'ROC-AUC': 0.7206126987090806, 'PRC-AUC': 0.16504938085351722}
# INFO | HPO epoch   5/50 | loss=0.1285 | val={'ROC-AUC': 0.7513897965592455, 'PRC-AUC': 0.2995044730880073}
# INFO | HPO epoch  10/50 | loss=0.1147 | val={'ROC-AUC': 0.7542988211130254, 'PRC-AUC': 0.3482376179585195}
# INFO | HPO epoch  15/50 | loss=0.1022 | val={'ROC-AUC': 0.7841953608378669, 'PRC-AUC': 0.37448473914465646}
# INFO | HPO epoch  20/50 | loss=0.0904 | val={'ROC-AUC': 0.7830177469594222, 'PRC-AUC': 0.33014459672342317}
# INFO | HPO epoch  25/50 | loss=0.0789 | val={'ROC-AUC': 0.7755446729416158, 'PRC-AUC': 0.3786973425958931}
# INFO | HPO epoch  30/50 | loss=0.0627 | val={'ROC-AUC': 0.778774093343405, 'PRC-AUC': 0.365424380859635}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | LSTM HPO — trial 6/10 finished | val=-0.784195 | best=-0.803929
# INFO | LSTM — starting trial 7/10
# INFO | HPO epoch   1/50 | loss=0.2249 | val={'ROC-AUC': 0.5973324393369714, 'PRC-AUC': 0.038715005816925344}
# INFO | HPO epoch   5/50 | loss=0.1420 | val={'ROC-AUC': 0.7505601622773143, 'PRC-AUC': 0.208498623257036}
# INFO | HPO epoch  10/50 | loss=0.1305 | val={'ROC-AUC': 0.7725698717567877, 'PRC-AUC': 0.3246121151144212}
# INFO | HPO epoch  15/50 | loss=0.1256 | val={'ROC-AUC': 0.788903694524838, 'PRC-AUC': 0.32676698856703085}
# INFO | HPO epoch  20/50 | loss=0.1204 | val={'ROC-AUC': 0.7866099997453807, 'PRC-AUC': 0.34535687839358936}
# INFO | HPO epoch  25/50 | loss=0.1151 | val={'ROC-AUC': 0.790342293100668, 'PRC-AUC': 0.3553529592265262}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | LSTM HPO — trial 7/10 finished | val=-0.796763 | best=-0.803929
# INFO | LSTM — starting trial 8/10
# INFO | HPO epoch   1/50 | loss=0.1979 | val={'ROC-AUC': 0.6373203873607021, 'PRC-AUC': 0.04627989811411329}
# INFO | HPO epoch   5/50 | loss=0.1396 | val={'ROC-AUC': 0.7260573062984307, 'PRC-AUC': 0.24824571619572688}
# INFO | HPO epoch  10/50 | loss=0.1319 | val={'ROC-AUC': 0.7916917749505614, 'PRC-AUC': 0.3143738983786246}
# INFO | HPO epoch  15/50 | loss=0.1238 | val={'ROC-AUC': 0.7570529523098207, 'PRC-AUC': 0.2927633458409594}
# INFO | HPO epoch  20/50 | loss=0.1188 | val={'ROC-AUC': 0.7881992480245793, 'PRC-AUC': 0.31496021253826106}
# INFO | HPO epoch  25/50 | loss=0.1112 | val={'ROC-AUC': 0.7927060081647894, 'PRC-AUC': 0.3375001820131702}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | LSTM HPO — trial 8/10 finished | val=-0.804688 | best=-0.804688
# INFO | LSTM — starting trial 9/10
# INFO | HPO epoch   1/50 | loss=0.1683 | val={'ROC-AUC': 0.6746327117795337, 'PRC-AUC': 0.07142601336932954}
# INFO | HPO epoch   5/50 | loss=0.1533 | val={'ROC-AUC': 0.7307359344100897, 'PRC-AUC': 0.1558764224789166}
# INFO | HPO epoch  10/50 | loss=0.1500 | val={'ROC-AUC': 0.7010749174609371, 'PRC-AUC': 0.1781919608465349}
# INFO | HPO epoch  15/50 | loss=0.1471 | val={'ROC-AUC': 0.7098773159739609, 'PRC-AUC': 0.17664351805430792}
# INFO | HPO epoch  20/50 | loss=0.1451 | val={'ROC-AUC': 0.7212216630029791, 'PRC-AUC': 0.16571213803643814}
# INFO | Early stop at epoch 20 (patience=15)
# INFO | LSTM HPO — trial 9/10 finished | val=-0.730736 | best=-0.804688
# INFO | LSTM — starting trial 10/10
# INFO | HPO epoch   1/50 | loss=0.1836 | val={'ROC-AUC': 0.6681017288644832, 'PRC-AUC': 0.06983574351349697}
# INFO | HPO epoch   5/50 | loss=0.1418 | val={'ROC-AUC': 0.6948325029917758, 'PRC-AUC': 0.1739801099410801}
# INFO | HPO epoch  10/50 | loss=0.1284 | val={'ROC-AUC': 0.7258302708299738, 'PRC-AUC': 0.28400113815523925}
# INFO | HPO epoch  15/50 | loss=0.1215 | val={'ROC-AUC': 0.7330614565916671, 'PRC-AUC': 0.3191971009522814}
# INFO | HPO epoch  20/50 | loss=0.1162 | val={'ROC-AUC': 0.7611204943007733, 'PRC-AUC': 0.34038916328612623}
# INFO | HPO epoch  25/50 | loss=0.1093 | val={'ROC-AUC': 0.7611544435297014, 'PRC-AUC': 0.38644050560193005}
# INFO | HPO epoch  30/50 | loss=0.1011 | val={'ROC-AUC': 0.7562699982176655, 'PRC-AUC': 0.3990943602028548}
# INFO | HPO epoch  35/50 | loss=0.0912 | val={'ROC-AUC': 0.7703101262062586, 'PRC-AUC': 0.40097582313465324}
# INFO | HPO epoch  40/50 | loss=0.0862 | val={'ROC-AUC': 0.7631468389024214, 'PRC-AUC': 0.38099863943964735}
# INFO | HPO epoch  45/50 | loss=0.0802 | val={'ROC-AUC': 0.7624020776928104, 'PRC-AUC': 0.3945174186845967}
# INFO | HPO epoch  50/50 | loss=0.0767 | val={'ROC-AUC': 0.7720394150547856, 'PRC-AUC': 0.39805193757946533}
# INFO | LSTM HPO — trial 10/10 finished | val=-0.774045 | best=-0.804688
# INFO | Epoch  10 | loss=0.1288 | val={'ROC-AUC': 0.7743246225270108, 'PRC-AUC': 0.2903075142041364}
# INFO | Epoch  20 | loss=0.1172 | val={'ROC-AUC': 0.8018277416124185, 'PRC-AUC': 0.3484859104598029}
# INFO | Epoch  30 | loss=0.1048 | val={'ROC-AUC': 0.80512930412568, 'PRC-AUC': 0.3916422731694242}
# INFO | Epoch  40 | loss=0.0967 | val={'ROC-AUC': 0.803675852762194, 'PRC-AUC': 0.346231284493465}
# INFO | Epoch  50 | loss=0.0888 | val={'ROC-AUC': 0.7886554407883011, 'PRC-AUC': 0.33257381804551955}
# INFO | Saved SMILES LSTM → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/hiv_partial.json
#    scaffold test: {'ROC-AUC': 0.7314776992267124, 'PRC-AUC': 0.2674360958478847}

# %% [markdown]
# ### Finalize GPU + merge

# %%
finalize_dataset_results(DATASET_SLUG, PARTIAL_PATH, RESULTS_DIR, TASK_TYPE,
    plot_title=f"HIV – ROC-AUC by Model (higher is better) (GPU, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
cpu_partial = RESULTS_ROOT / "cpu" / f"{DATASET_SLUG}_partial.json"
if cpu_partial.exists():
    merge_combined_results(DATASET_SLUG, cpu_partial, PARTIAL_PATH, RESULTS_ROOT / "combined",
        TASK_TYPE, plot_title=f"HIV – ROC-AUC by Model (higher is better) (all models, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
else:
    print("Run CPU notebook first for combined results.")
# Out:
# === HIV Results (5/12 models) ===
#                             ROC-AUC          PRC-AUC
# Model
# GIN (2D)            0.7311 ± 0.0000  0.3224 ± 0.0000
# D-MPNN (2D)         0.7543 ± 0.0000  0.3082 ± 0.0000
# GIN (3D)            0.6750 ± 0.0000  0.2891 ± 0.0000
# SchNet (3D coords)  0.6737 ± 0.0000  0.2142 ± 0.0000
# SMILES LSTM         0.7315 ± 0.0000  0.2674 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/hiv_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/hiv_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/gpu/hiv_partial.json
# === HIV Results (12/12 models) ===
#                                ROC-AUC          PRC-AUC
# Model
# Morgan + RF            0.8106 ± 0.0000  0.3689 ± 0.0000
# Morgan + SVM           0.7880 ± 0.0000  0.3134 ± 0.0000
# Morgan + XGBoost       0.7855 ± 0.0000  0.3562 ± 0.0000
# Descriptors + RF       0.7853 ± 0.0000  0.3555 ± 0.0000
# Descriptors + SVM      0.7586 ± 0.0000  0.2864 ± 0.0000
# Descriptors + XGBoost  0.7836 ± 0.0000  0.3515 ± 0.0000
# Combined + XGBoost     0.7864 ± 0.0000  0.3779 ± 0.0000
# GIN (2D)               0.7311 ± 0.0000  0.3224 ± 0.0000
# D-MPNN (2D)            0.7543 ± 0.0000  0.3082 ± 0.0000
# GIN (3D)               0.6750 ± 0.0000  0.2891 ± 0.0000
# SchNet (3D coords)     0.6737 ± 0.0000  0.2142 ± 0.0000
# SMILES LSTM            0.7315 ± 0.0000  0.2674 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/combined/hiv_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/combined/hiv_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_0/scaffold/combined/hiv_partial.json
