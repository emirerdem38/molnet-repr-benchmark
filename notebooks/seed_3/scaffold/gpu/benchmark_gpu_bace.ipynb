# %% [markdown]
# # Benchmark v5 — GPU — BACE — scaffold split, seed 3
#
# **Task:** Binary — binds BACE-1 (1) or not (0)
# **Size:** ~1,513 molecules
# **Metric:** ROC-AUC ↑
#
# **Scaffold split**, seed **3** — GIN, D-MPNN, SchNet, LSTM with Optuna HPO.
#
# Results go to `results/seed_3/scaffold/`.

# %%
# %load_ext autoreload
# %autoreload 2

import os
# Avoid XGBoost/OpenMP segfaults in Jupyter on macOS (OMP Error #179).
for _omp_var in (
    "OMP_NUM_THREADS",
    "OPENBLAS_NUM_THREADS",
    "MKL_NUM_THREADS",
    "VECLIB_MAXIMUM_THREADS",
    "NUMEXPR_NUM_THREADS",
):
    os.environ[_omp_var] = "1"

import sys
from pathlib import Path

ROOT = Path(".").resolve()
for _ in range(6):
    if (ROOT / "mol_repr_utils.py").exists():
        break
    ROOT = ROOT.parent
else:
    raise FileNotFoundError("Could not find benchmark_v5 root (mol_repr_utils.py)")
sys.path.insert(0, str(ROOT))

from mol_repr_utils import *
from split_utils import (
    get_or_create_splits, subset_array, subset_list, subset_graphs_by_valid_idx,
    check_split_proportions,
)
from conformer_generation import load_conformer_graphs
from hpo_utils import (
    hpo_tabular, hpo_gnn, hpo_schnet, hpo_lstm,
    save_hpo_params, hpo_params_path,
)
from hpo_config import SKLEARN_HPO_N_ITER

DATA_DIR = ROOT / "data"

DEVICE = get_device()
print(f"Benchmark v5 (GPU) code root: {ROOT}")
print(f"Device: {DEVICE}")
print("Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.")
# Out:
# INFO | Using device: cpu (request a GPU node on the cluster for large GNN/LSTM jobs)
# Benchmark v5 (GPU) code root: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5
# Device: cpu
# Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.

# %%
DATASET_SLUG = "bace"
TASK_TYPE = "classification"
OUT_CHANNELS = 1
BATCH_SIZE = 32
GNN_EPOCHS = 100
LSTM_EPOCHS = 100
TOX21_TABULAR = False

HPO_EPOCHS = 80  # Optuna trial length; GNN_EPOCHS for final refit
HPO_N_TRIALS = 20
print(f"GPU HPO tier: standard — {HPO_N_TRIALS} trials, {HPO_EPOCHS} epochs/trial, batch={BATCH_SIZE}")

SPLIT_MODE = "scaffold"   # "scaffold" or "random"
SPLIT_SEED = 3

RESULTS_ROOT = ROOT / "results" / f"seed_{SPLIT_SEED}" / SPLIT_MODE
RESULTS_DIR = RESULTS_ROOT / "gpu"
SPLITS_DIR = RESULTS_ROOT / "splits"
HPO_DIR = RESULTS_DIR / "hpo"
HISTORY_DIR = RESULTS_DIR / "histories"
for d in (RESULTS_DIR, SPLITS_DIR, HPO_DIR, HISTORY_DIR):
    d.mkdir(parents=True, exist_ok=True)
print(f"Results → {RESULTS_ROOT}")

PARTIAL_PATH = RESULTS_DIR / f"{DATASET_SLUG}_partial.json"
FRESH_RUN = False
HPO_N_ITER = SKLEARN_HPO_N_ITER

if FRESH_RUN:
    reset_dataset_run(
        DATASET_SLUG, RESULTS_DIR,
        results_root=RESULTS_ROOT, split_mode=SPLIT_MODE,
    )
    print("Fresh run — cleared partial results and splits.")

results = load_partial_results(PARTIAL_PATH)
if results:
    print(f"Resuming {len(results)} saved model(s): {', '.join(order_results(results).keys())}")
print(f"SPLIT_SEED={SPLIT_SEED}  mode={SPLIT_MODE}")
# Out:
# GPU HPO tier: standard — 20 trials, 80 epochs/trial, batch=32
# Results → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold
# Resuming 2 saved model(s): GIN (2D), D-MPNN (2D)
# SPLIT_SEED=3  mode=scaffold

# %% [markdown]
# ### Load data

# %%
import numpy as np
import pandas as pd

df = load_dataset("bace", cache_dir=DATA_DIR)
smiles, y = preprocess_dataset(df, "bace")
print(f"Molecules : {len(smiles)}")
print(f"Class balance: {np.bincount(y.astype(int))}")
smiles, y = filter_bonded_molecules(smiles, y)
print(f'After bond filter: {len(smiles)} molecules')
# Out:
# INFO | Loading 'bace' from cache: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace.csv
# INFO | [bace] 1513 / 1513 valid molecules
# Molecules : 1513
# Class balance: [822 691]
# After bond filter: 1513 molecules

# %% [markdown]
# ### Representations & scaffold split

# %%
graphs2d_all = smiles_to_graphs(smiles, y)
graphs_dmpnn_all = smiles_to_dmpnn_graphs(smiles, y)
X_tok_all, vocab = tokenize_smiles(smiles)

graphs3d_all, valid_idx_3d, _ = load_conformer_graphs(
    DATASET_SLUG, data_dir=DATA_DIR, n_confs=25
)
graphs3d_all = ensure_atomic_numbers_list(graphs3d_all)
print(f"3D graphs loaded: {len(graphs3d_all)} / {len(smiles)} (valid_idx mapping)")

split_data = get_or_create_splits(
    smiles, RESULTS_ROOT, DATASET_SLUG,
    mode=SPLIT_MODE, seed=SPLIT_SEED, force=FRESH_RUN,
)
train_idx = split_data["train_idx"]
val_idx = split_data["val_idx"]
test_idx = split_data["test_idx"]
check_split_proportions(train_idx, val_idx, test_idx, raise_on_fail=True)
print(split_data["summary"])

tr2d = subset_list(graphs2d_all, train_idx)
va2d = subset_list(graphs2d_all, val_idx)
te2d = subset_list(graphs2d_all, test_idx)

tr_dmpnn = subset_list(graphs_dmpnn_all, train_idx)
va_dmpnn = subset_list(graphs_dmpnn_all, val_idx)
te_dmpnn = subset_list(graphs_dmpnn_all, test_idx)

tr3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, train_idx)
va3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, val_idx)
te3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, test_idx)

tr_ds = SMILESDataset(subset_array(X_tok_all, train_idx), subset_array(y, train_idx))
va_ds = SMILESDataset(subset_array(X_tok_all, val_idx), subset_array(y, val_idx))
te_ds = SMILESDataset(subset_array(X_tok_all, test_idx), subset_array(y, test_idx))
# Out:
# INFO | Loaded 1513 / 1513 graphs from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace_conformers_n25.pkl  (n_confs=25)
# INFO | Loaded splits from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/splits/bace_scaffold_splits.pkl
# 3D graphs loaded: 1513 / 1513 (valid_idx mapping)
# {'n_total': 1513, 'n_train': 1210, 'n_val': 151, 'n_test': 152, 'n_scaffolds_total': 671, 'n_scaffolds_train': 368, 'n_scaffolds_val': 151, 'n_scaffolds_test': 152}

# %% [markdown]
# ### GIN (2D)

# %%
MODEL_KEY = "GIN (2D)"
tr = tr3d if "2D" == "3D" else tr2d
va = va3d if "2D" == "3D" else va2d
te = te3d if "2D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (2D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# Skipping GIN (2D)

# %% [markdown]
# ### D-MPNN (2D)
# Bond-centric directed MPNN (Yang et al. 2019).

# %%
MODEL_KEY = "D-MPNN (2D)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr_dmpnn, va_dmpnn, TASK_TYPE, "DMPNN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("DMPNN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr_dmpnn, va_dmpnn, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te_dmpnn, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_dmpnn.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# Skipping D-MPNN (2D)

# %% [markdown]
# ### GIN (3D)

# %%
MODEL_KEY = "GIN (3D)"
tr = tr3d if "3D" == "3D" else tr2d
va = va3d if "3D" == "3D" else va2d
te = te3d if "3D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "3D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "3D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (3D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | GIN 3D — starting trial 1/20 (layers=5, hidden=192)
# → GIN (3D) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=1.2763 | val={'ROC-AUC': 0.5307369224894998, 'PRC-AUC': 0.39888337160379306}
# INFO | HPO epoch   5/80 | loss=0.5873 | val={'ROC-AUC': 0.6869033982436045, 'PRC-AUC': 0.5661522536299733}
# INFO | HPO epoch  10/80 | loss=0.5359 | val={'ROC-AUC': 0.6744940817105765, 'PRC-AUC': 0.557900215863211}
# INFO | HPO epoch  15/80 | loss=0.4832 | val={'ROC-AUC': 0.6567392134402443, 'PRC-AUC': 0.4890364644176867}
# INFO | HPO epoch  20/80 | loss=0.4851 | val={'ROC-AUC': 0.7468499427262315, 'PRC-AUC': 0.6003711178448072}
# INFO | HPO epoch  25/80 | loss=0.4509 | val={'ROC-AUC': 0.7399770904925543, 'PRC-AUC': 0.5480910867817821}
# INFO | HPO epoch  30/80 | loss=0.4353 | val={'ROC-AUC': 0.738831615120275, 'PRC-AUC': 0.5939513621807275}
# INFO | HPO epoch  35/80 | loss=0.4256 | val={'ROC-AUC': 0.6951126384116075, 'PRC-AUC': 0.5897882546992675}
# INFO | HPO epoch  40/80 | loss=0.3904 | val={'ROC-AUC': 0.7418862161130203, 'PRC-AUC': 0.5545635367237911}
# INFO | HPO epoch  45/80 | loss=0.3731 | val={'ROC-AUC': 0.7878961435662468, 'PRC-AUC': 0.6385583369039165}
# INFO | HPO epoch  50/80 | loss=0.3839 | val={'ROC-AUC': 0.8079419625811378, 'PRC-AUC': 0.644720379366692}
# INFO | HPO epoch  55/80 | loss=0.3352 | val={'ROC-AUC': 0.8094692630775105, 'PRC-AUC': 0.6338603324398076}
# INFO | HPO epoch  60/80 | loss=0.3133 | val={'ROC-AUC': 0.8096601756395571, 'PRC-AUC': 0.6623992487316696}
# INFO | HPO epoch  65/80 | loss=0.3291 | val={'ROC-AUC': 0.8243604429171439, 'PRC-AUC': 0.6939493941420881}
# INFO | HPO epoch  70/80 | loss=0.2964 | val={'ROC-AUC': 0.8211149293623521, 'PRC-AUC': 0.6548739775928326}
# INFO | HPO epoch  75/80 | loss=0.3141 | val={'ROC-AUC': 0.829324169530355, 'PRC-AUC': 0.6905386101138432}
# INFO | HPO epoch  80/80 | loss=0.2969 | val={'ROC-AUC': 0.8348606338297059, 'PRC-AUC': 0.6936656889040744}
# INFO | GIN 3D HPO — trial 1/20 finished | val=-0.844215 | best=-0.844215
# INFO | GIN 3D — starting trial 2/20 (layers=5, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.7675 | val={'ROC-AUC': 0.5883925162275678, 'PRC-AUC': 0.413163139077615}
# INFO | HPO epoch   5/80 | loss=0.5990 | val={'ROC-AUC': 0.7352042764413899, 'PRC-AUC': 0.601261997366215}
# INFO | HPO epoch  10/80 | loss=0.5186 | val={'ROC-AUC': 0.7535318823978617, 'PRC-AUC': 0.6525593347077928}
# INFO | HPO epoch  15/80 | loss=0.5058 | val={'ROC-AUC': 0.7640320733104239, 'PRC-AUC': 0.6268347799474302}
# INFO | HPO epoch  20/80 | loss=0.4655 | val={'ROC-AUC': 0.7779686903398244, 'PRC-AUC': 0.6289120496894889}
# INFO | HPO epoch  25/80 | loss=0.4627 | val={'ROC-AUC': 0.7777777777777778, 'PRC-AUC': 0.6131297377653127}
# INFO | HPO epoch  30/80 | loss=0.4427 | val={'ROC-AUC': 0.7905689194348989, 'PRC-AUC': 0.6342481636926318}
# INFO | HPO epoch  35/80 | loss=0.4426 | val={'ROC-AUC': 0.8025964108438335, 'PRC-AUC': 0.6453727194345731}
# INFO | HPO epoch  40/80 | loss=0.4011 | val={'ROC-AUC': 0.8203512791141657, 'PRC-AUC': 0.6696311386709817}
# INFO | HPO epoch  45/80 | loss=0.3989 | val={'ROC-AUC': 0.8167239404352806, 'PRC-AUC': 0.6597645933956953}
# INFO | HPO epoch  50/80 | loss=0.3979 | val={'ROC-AUC': 0.8176785032455136, 'PRC-AUC': 0.6233629370508977}
# INFO | HPO epoch  55/80 | loss=0.3759 | val={'ROC-AUC': 0.8132875143184422, 'PRC-AUC': 0.6475711655166924}
# INFO | HPO epoch  60/80 | loss=0.3671 | val={'ROC-AUC': 0.833906071019473, 'PRC-AUC': 0.6790173048053172}
# INFO | HPO epoch  65/80 | loss=0.3723 | val={'ROC-AUC': 0.8266513936617029, 'PRC-AUC': 0.6931909774886189}
# INFO | HPO epoch  70/80 | loss=0.3599 | val={'ROC-AUC': 0.8134784268804888, 'PRC-AUC': 0.6578221357028798}
# INFO | Early stop at epoch 73 (patience=15)
# INFO | GIN 3D HPO — trial 2/20 finished | val=-0.838870 | best=-0.844215
# INFO | GIN 3D — starting trial 3/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7198 | val={'ROC-AUC': 0.6699121802214586, 'PRC-AUC': 0.6030224579617816}
# INFO | HPO epoch   5/80 | loss=0.5976 | val={'ROC-AUC': 0.7201221840397098, 'PRC-AUC': 0.6275138490122432}
# INFO | HPO epoch  10/80 | loss=0.5197 | val={'ROC-AUC': 0.7646048109965635, 'PRC-AUC': 0.6563384779038246}
# INFO | HPO epoch  15/80 | loss=0.4802 | val={'ROC-AUC': 0.7758686521573119, 'PRC-AUC': 0.6667963584935221}
# INFO | HPO epoch  20/80 | loss=0.4711 | val={'ROC-AUC': 0.7737686139747997, 'PRC-AUC': 0.6477190351100005}
# INFO | HPO epoch  25/80 | loss=0.4386 | val={'ROC-AUC': 0.7812142038946162, 'PRC-AUC': 0.651309398231278}
# INFO | HPO epoch  30/80 | loss=0.4325 | val={'ROC-AUC': 0.7899961817487591, 'PRC-AUC': 0.6554205473858279}
# INFO | HPO epoch  35/80 | loss=0.4092 | val={'ROC-AUC': 0.7865597556319206, 'PRC-AUC': 0.6430942499335066}
# INFO | HPO epoch  40/80 | loss=0.4119 | val={'ROC-AUC': 0.8048873615883926, 'PRC-AUC': 0.6896304780712228}
# INFO | HPO epoch  45/80 | loss=0.4031 | val={'ROC-AUC': 0.8146239022527683, 'PRC-AUC': 0.7174345053930966}
# INFO | HPO epoch  50/80 | loss=0.4085 | val={'ROC-AUC': 0.8117602138220694, 'PRC-AUC': 0.6633233755093615}
# INFO | Early stop at epoch 54 (patience=15)
# INFO | GIN 3D HPO — trial 3/20 finished | val=-0.821306 | best=-0.844215
# INFO | GIN 3D — starting trial 4/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.9277 | val={'ROC-AUC': 0.4837724322260405, 'PRC-AUC': 0.35129908722654296}
# INFO | HPO epoch   5/80 | loss=0.5723 | val={'ROC-AUC': 0.715922107674685, 'PRC-AUC': 0.5782949573247688}
# INFO | HPO epoch  10/80 | loss=0.5299 | val={'ROC-AUC': 0.7373043146239022, 'PRC-AUC': 0.6107795697204998}
# INFO | HPO epoch  15/80 | loss=0.4965 | val={'ROC-AUC': 0.7796869033982435, 'PRC-AUC': 0.642266572705263}
# INFO | HPO epoch  20/80 | loss=0.4456 | val={'ROC-AUC': 0.7941962581137838, 'PRC-AUC': 0.6947806052448479}
# INFO | HPO epoch  25/80 | loss=0.4453 | val={'ROC-AUC': 0.8054600992745322, 'PRC-AUC': 0.6650331669034464}
# INFO | HPO epoch  30/80 | loss=0.4212 | val={'ROC-AUC': 0.8098510882016037, 'PRC-AUC': 0.7239325536578681}
# INFO | HPO epoch  35/80 | loss=0.4137 | val={'ROC-AUC': 0.8016418480336006, 'PRC-AUC': 0.6628245668847479}
# INFO | HPO epoch  40/80 | loss=0.4067 | val={'ROC-AUC': 0.8123329515082093, 'PRC-AUC': 0.6957435641528413}
# INFO | HPO epoch  45/80 | loss=0.3945 | val={'ROC-AUC': 0.8121420389461627, 'PRC-AUC': 0.6553631661162458}
# INFO | HPO epoch  50/80 | loss=0.3575 | val={'ROC-AUC': 0.8203512791141657, 'PRC-AUC': 0.6753204108017867}
# INFO | HPO epoch  55/80 | loss=0.3550 | val={'ROC-AUC': 0.8235967926689576, 'PRC-AUC': 0.682986665259319}
# INFO | HPO epoch  60/80 | loss=0.3472 | val={'ROC-AUC': 0.8291332569683085, 'PRC-AUC': 0.7202690680261178}
# INFO | HPO epoch  65/80 | loss=0.3323 | val={'ROC-AUC': 0.8255059182894235, 'PRC-AUC': 0.6799595485142812}
# INFO | HPO epoch  70/80 | loss=0.3401 | val={'ROC-AUC': 0.8298969072164949, 'PRC-AUC': 0.6817495410970349}
# INFO | HPO epoch  75/80 | loss=0.3283 | val={'ROC-AUC': 0.830278732340588, 'PRC-AUC': 0.6839259537550058}
# INFO | HPO epoch  80/80 | loss=0.3352 | val={'ROC-AUC': 0.8277968690339824, 'PRC-AUC': 0.7281232489464717}
# INFO | GIN 3D HPO — trial 4/20 finished | val=-0.834670 | best=-0.844215
# INFO | GIN 3D — starting trial 5/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.8174 | val={'ROC-AUC': 0.5893470790378007, 'PRC-AUC': 0.4345555852222258}
# INFO | HPO epoch   5/80 | loss=0.5849 | val={'ROC-AUC': 0.772241313478427, 'PRC-AUC': 0.6520707972114009}
# INFO | HPO epoch  10/80 | loss=0.5407 | val={'ROC-AUC': 0.7535318823978618, 'PRC-AUC': 0.5682861505742912}
# INFO | HPO epoch  15/80 | loss=0.4382 | val={'ROC-AUC': 0.7502863688430699, 'PRC-AUC': 0.6093843038518283}
# INFO | HPO epoch  20/80 | loss=0.4344 | val={'ROC-AUC': 0.766704849179076, 'PRC-AUC': 0.6428848166200759}
# INFO | HPO epoch  25/80 | loss=0.4297 | val={'ROC-AUC': 0.8123329515082093, 'PRC-AUC': 0.6693292481208908}
# INFO | HPO epoch  30/80 | loss=0.3862 | val={'ROC-AUC': 0.7590683466972128, 'PRC-AUC': 0.5816304932058038}
# INFO | HPO epoch  35/80 | loss=0.3866 | val={'ROC-AUC': 0.7877052310042, 'PRC-AUC': 0.6183617538618126}
# INFO | HPO epoch  40/80 | loss=0.3581 | val={'ROC-AUC': 0.811951126384116, 'PRC-AUC': 0.6326666357047752}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | GIN 3D HPO — trial 5/20 finished | val=-0.812333 | best=-0.844215
# INFO | GIN 3D — starting trial 6/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=1.7390 | val={'ROC-AUC': 0.5717831233295151, 'PRC-AUC': 0.4351604833921689}
# INFO | HPO epoch   5/80 | loss=0.5606 | val={'ROC-AUC': 0.5906834669721268, 'PRC-AUC': 0.4238394688316054}
# INFO | HPO epoch  10/80 | loss=0.5227 | val={'ROC-AUC': 0.6447117220313097, 'PRC-AUC': 0.4998628558385485}
# INFO | HPO epoch  15/80 | loss=0.4889 | val={'ROC-AUC': 0.5372279495990836, 'PRC-AUC': 0.38816773980203767}
# INFO | HPO epoch  20/80 | loss=0.4650 | val={'ROC-AUC': 0.7201221840397097, 'PRC-AUC': 0.5346337064022775}
# INFO | HPO epoch  25/80 | loss=0.4652 | val={'ROC-AUC': 0.6941580756013745, 'PRC-AUC': 0.5242252739431457}
# INFO | HPO epoch  30/80 | loss=0.4039 | val={'ROC-AUC': 0.7323405880106911, 'PRC-AUC': 0.5355583422938179}
# INFO | HPO epoch  35/80 | loss=0.4011 | val={'ROC-AUC': 0.7615502100038183, 'PRC-AUC': 0.5622262882528128}
# INFO | HPO epoch  40/80 | loss=0.4144 | val={'ROC-AUC': 0.7707140129820542, 'PRC-AUC': 0.5783249733312259}
# INFO | HPO epoch  45/80 | loss=0.4157 | val={'ROC-AUC': 0.7630775105001909, 'PRC-AUC': 0.5731079002049535}
# INFO | HPO epoch  50/80 | loss=0.3860 | val={'ROC-AUC': 0.7693776250477282, 'PRC-AUC': 0.6243576651611222}
# INFO | HPO epoch  55/80 | loss=0.3763 | val={'ROC-AUC': 0.7875143184421535, 'PRC-AUC': 0.6283376456576996}
# INFO | HPO epoch  60/80 | loss=0.3507 | val={'ROC-AUC': 0.7915234822451317, 'PRC-AUC': 0.5994988740094566}
# INFO | HPO epoch  65/80 | loss=0.3498 | val={'ROC-AUC': 0.780832378770523, 'PRC-AUC': 0.6096826123472486}
# INFO | HPO epoch  70/80 | loss=0.3456 | val={'ROC-AUC': 0.8144329896907216, 'PRC-AUC': 0.6783809150033949}
# INFO | HPO epoch  75/80 | loss=0.3372 | val={'ROC-AUC': 0.7915234822451317, 'PRC-AUC': 0.6155449315712782}
# INFO | HPO epoch  80/80 | loss=0.3183 | val={'ROC-AUC': 0.7716685757922872, 'PRC-AUC': 0.582016836925295}
# INFO | GIN 3D HPO — trial 6/20 finished | val=-0.814433 | best=-0.844215
# INFO | GIN 3D — starting trial 7/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.3229 | val={'ROC-AUC': 0.45341733486063385, 'PRC-AUC': 0.3283329528745593}
# INFO | HPO epoch   5/80 | loss=0.6057 | val={'ROC-AUC': 0.6389843451699122, 'PRC-AUC': 0.47613331854463936}
# INFO | HPO epoch  10/80 | loss=0.5189 | val={'ROC-AUC': 0.6510118365788469, 'PRC-AUC': 0.557379852756334}
# INFO | HPO epoch  15/80 | loss=0.4879 | val={'ROC-AUC': 0.6890034364261168, 'PRC-AUC': 0.5870074758328548}
# INFO | HPO epoch  20/80 | loss=0.4689 | val={'ROC-AUC': 0.7189767086674304, 'PRC-AUC': 0.5358456240747936}
# INFO | HPO epoch  25/80 | loss=0.4401 | val={'ROC-AUC': 0.7415043909889272, 'PRC-AUC': 0.5859010659280561}
# INFO | HPO epoch  30/80 | loss=0.4125 | val={'ROC-AUC': 0.7626956853760978, 'PRC-AUC': 0.5825842061328637}
# INFO | HPO epoch  35/80 | loss=0.4199 | val={'ROC-AUC': 0.7668957617411225, 'PRC-AUC': 0.6036295039281466}
# INFO | HPO epoch  40/80 | loss=0.3997 | val={'ROC-AUC': 0.7716685757922872, 'PRC-AUC': 0.5672255501923118}
# INFO | HPO epoch  45/80 | loss=0.4002 | val={'ROC-AUC': 0.7945780832378769, 'PRC-AUC': 0.5899180836787258}
# INFO | HPO epoch  50/80 | loss=0.3803 | val={'ROC-AUC': 0.7126765941198931, 'PRC-AUC': 0.5236618069078973}
# INFO | HPO epoch  55/80 | loss=0.3820 | val={'ROC-AUC': 0.7833142420771287, 'PRC-AUC': 0.6560314133328446}
# INFO | HPO epoch  60/80 | loss=0.3659 | val={'ROC-AUC': 0.777205040091638, 'PRC-AUC': 0.5844958394560255}
# INFO | HPO epoch  65/80 | loss=0.3463 | val={'ROC-AUC': 0.7613592974417718, 'PRC-AUC': 0.6061096133391661}
# INFO | HPO epoch  70/80 | loss=0.3264 | val={'ROC-AUC': 0.8199694539900725, 'PRC-AUC': 0.6669171451102734}
# INFO | HPO epoch  75/80 | loss=0.3129 | val={'ROC-AUC': 0.8214967544864453, 'PRC-AUC': 0.6706519703986265}
# INFO | HPO epoch  80/80 | loss=0.2994 | val={'ROC-AUC': 0.8048873615883925, 'PRC-AUC': 0.6589865063863611}
# INFO | GIN 3D HPO — trial 7/20 finished | val=-0.825315 | best=-0.844215
# INFO | GIN 3D — starting trial 8/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.6819 | val={'ROC-AUC': 0.6699121802214586, 'PRC-AUC': 0.4852512195645526}
# INFO | HPO epoch   5/80 | loss=0.5012 | val={'ROC-AUC': 0.7415043909889272, 'PRC-AUC': 0.552125156156591}
# INFO | HPO epoch  10/80 | loss=0.4565 | val={'ROC-AUC': 0.7835051546391752, 'PRC-AUC': 0.6277903881420237}
# INFO | HPO epoch  15/80 | loss=0.4387 | val={'ROC-AUC': 0.7749140893470791, 'PRC-AUC': 0.6141819655686318}
# INFO | HPO epoch  20/80 | loss=0.4018 | val={'ROC-AUC': 0.7985872470408553, 'PRC-AUC': 0.6643966613325109}
# INFO | HPO epoch  25/80 | loss=0.3937 | val={'ROC-AUC': 0.790950744558992, 'PRC-AUC': 0.6221879856734266}
# INFO | HPO epoch  30/80 | loss=0.3875 | val={'ROC-AUC': 0.8029782359679267, 'PRC-AUC': 0.6311084190770423}
# INFO | HPO epoch  35/80 | loss=0.3658 | val={'ROC-AUC': 0.8125238640702558, 'PRC-AUC': 0.6603543556293067}
# INFO | HPO epoch  40/80 | loss=0.3535 | val={'ROC-AUC': 0.8125238640702559, 'PRC-AUC': 0.659066609427472}
# INFO | HPO epoch  45/80 | loss=0.3286 | val={'ROC-AUC': 0.821114929362352, 'PRC-AUC': 0.6666439156442597}
# INFO | HPO epoch  50/80 | loss=0.3284 | val={'ROC-AUC': 0.8264604810996563, 'PRC-AUC': 0.6664150980857058}
# INFO | HPO epoch  55/80 | loss=0.3095 | val={'ROC-AUC': 0.8281786941580757, 'PRC-AUC': 0.6915318286928376}
# INFO | HPO epoch  60/80 | loss=0.3105 | val={'ROC-AUC': 0.8329515082092401, 'PRC-AUC': 0.6929224385168524}
# INFO | HPO epoch  65/80 | loss=0.3068 | val={'ROC-AUC': 0.8445971744940817, 'PRC-AUC': 0.7046312001238406}
# INFO | HPO epoch  70/80 | loss=0.3040 | val={'ROC-AUC': 0.8449789996181748, 'PRC-AUC': 0.7052148609800132}
# INFO | HPO epoch  75/80 | loss=0.2972 | val={'ROC-AUC': 0.8461244749904544, 'PRC-AUC': 0.7251619047705928}
# INFO | HPO epoch  80/80 | loss=0.2921 | val={'ROC-AUC': 0.845360824742268, 'PRC-AUC': 0.7189289930713488}
# INFO | GIN 3D HPO — trial 8/20 finished | val=-0.847270 | best=-0.847270
# INFO | GIN 3D — starting trial 9/20 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8259 | val={'ROC-AUC': 0.5834287896143566, 'PRC-AUC': 0.4294760063633667}
# INFO | HPO epoch   5/80 | loss=0.5296 | val={'ROC-AUC': 0.7218403970981291, 'PRC-AUC': 0.5604282841978026}
# INFO | HPO epoch  10/80 | loss=0.5201 | val={'ROC-AUC': 0.7174494081710576, 'PRC-AUC': 0.5593998339349361}
# INFO | HPO epoch  15/80 | loss=0.4523 | val={'ROC-AUC': 0.7586865215731194, 'PRC-AUC': 0.5739792355406635}
# INFO | HPO epoch  20/80 | loss=0.4476 | val={'ROC-AUC': 0.7804505536464299, 'PRC-AUC': 0.6273875778377276}
# INFO | HPO epoch  25/80 | loss=0.4382 | val={'ROC-AUC': 0.7745322642229858, 'PRC-AUC': 0.5749468242192116}
# INFO | HPO epoch  30/80 | loss=0.4105 | val={'ROC-AUC': 0.7905689194348988, 'PRC-AUC': 0.6219125929201037}
# INFO | HPO epoch  35/80 | loss=0.4086 | val={'ROC-AUC': 0.8050782741504391, 'PRC-AUC': 0.6399369527868105}
# INFO | HPO epoch  40/80 | loss=0.3843 | val={'ROC-AUC': 0.8067964872088583, 'PRC-AUC': 0.6371724240797484}
# INFO | HPO epoch  45/80 | loss=0.3999 | val={'ROC-AUC': 0.8022145857197405, 'PRC-AUC': 0.6546146309374268}
# INFO | HPO epoch  50/80 | loss=0.3709 | val={'ROC-AUC': 0.8140511645666285, 'PRC-AUC': 0.6665487678574359}
# INFO | HPO epoch  55/80 | loss=0.3575 | val={'ROC-AUC': 0.8178694158075602, 'PRC-AUC': 0.6704748766397466}
# INFO | HPO epoch  60/80 | loss=0.3539 | val={'ROC-AUC': 0.8249331806032836, 'PRC-AUC': 0.6570381418857634}
# INFO | HPO epoch  65/80 | loss=0.3503 | val={'ROC-AUC': 0.8199694539900725, 'PRC-AUC': 0.6534966980693553}
# INFO | HPO epoch  70/80 | loss=0.3229 | val={'ROC-AUC': 0.834860633829706, 'PRC-AUC': 0.7183976624876651}
# INFO | HPO epoch  75/80 | loss=0.3097 | val={'ROC-AUC': 0.8285605192821687, 'PRC-AUC': 0.6887515560883365}
# INFO | Early stop at epoch 78 (patience=15)
# INFO | GIN 3D HPO — trial 9/20 finished | val=-0.839061 | best=-0.847270
# INFO | GIN 3D — starting trial 10/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=1.4893 | val={'ROC-AUC': 0.6441389843451699, 'PRC-AUC': 0.5197841523867059}
# INFO | HPO epoch   5/80 | loss=0.5723 | val={'ROC-AUC': 0.47728140511645667, 'PRC-AUC': 0.3488599255889244}
# INFO | HPO epoch  10/80 | loss=0.5086 | val={'ROC-AUC': 0.6504390988927071, 'PRC-AUC': 0.4924178022245794}
# INFO | HPO epoch  15/80 | loss=0.4745 | val={'ROC-AUC': 0.719167621229477, 'PRC-AUC': 0.5879296266866834}
# INFO | HPO epoch  20/80 | loss=0.4467 | val={'ROC-AUC': 0.7235586101565484, 'PRC-AUC': 0.5840586748157304}
# INFO | HPO epoch  25/80 | loss=0.4439 | val={'ROC-AUC': 0.7378770523100421, 'PRC-AUC': 0.5761377715902298}
# INFO | HPO epoch  30/80 | loss=0.4137 | val={'ROC-AUC': 0.698549064528446, 'PRC-AUC': 0.4953397596577282}
# INFO | HPO epoch  35/80 | loss=0.4000 | val={'ROC-AUC': 0.7514318442153494, 'PRC-AUC': 0.5750932118855869}
# INFO | HPO epoch  40/80 | loss=0.3504 | val={'ROC-AUC': 0.7436044291714395, 'PRC-AUC': 0.6123515280774742}
# INFO | HPO epoch  45/80 | loss=0.3738 | val={'ROC-AUC': 0.7789232531500573, 'PRC-AUC': 0.6082343348079999}
# INFO | HPO epoch  50/80 | loss=0.3427 | val={'ROC-AUC': 0.800114547537228, 'PRC-AUC': 0.6513465019607099}
# INFO | HPO epoch  55/80 | loss=0.3320 | val={'ROC-AUC': 0.7861779305078275, 'PRC-AUC': 0.6225292019493218}
# INFO | HPO epoch  60/80 | loss=0.3272 | val={'ROC-AUC': 0.8039327987781596, 'PRC-AUC': 0.6219399337333669}
# INFO | HPO epoch  65/80 | loss=0.3319 | val={'ROC-AUC': 0.7899961817487591, 'PRC-AUC': 0.6431459845513363}
# INFO | HPO epoch  70/80 | loss=0.3083 | val={'ROC-AUC': 0.800114547537228, 'PRC-AUC': 0.6345084177787914}
# INFO | Early stop at epoch 72 (patience=15)
# INFO | GIN 3D HPO — trial 10/20 finished | val=-0.814051 | best=-0.847270
# INFO | GIN 3D — starting trial 11/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7639 | val={'ROC-AUC': 0.6460481099656358, 'PRC-AUC': 0.5010459988572133}
# INFO | HPO epoch   5/80 | loss=0.5436 | val={'ROC-AUC': 0.7329133256968309, 'PRC-AUC': 0.5803963313977564}
# INFO | HPO epoch  10/80 | loss=0.4321 | val={'ROC-AUC': 0.7226040473463153, 'PRC-AUC': 0.6089672174296218}
# INFO | HPO epoch  15/80 | loss=0.4399 | val={'ROC-AUC': 0.7464681176021383, 'PRC-AUC': 0.6075865533715272}
# INFO | HPO epoch  20/80 | loss=0.4185 | val={'ROC-AUC': 0.7434135166093929, 'PRC-AUC': 0.5758146327540128}
# INFO | HPO epoch  25/80 | loss=0.4048 | val={'ROC-AUC': 0.7193585337915235, 'PRC-AUC': 0.5395226769491966}
# INFO | HPO epoch  30/80 | loss=0.3440 | val={'ROC-AUC': 0.8100420007636503, 'PRC-AUC': 0.6423655228297459}
# INFO | HPO epoch  35/80 | loss=0.3328 | val={'ROC-AUC': 0.8073692248949982, 'PRC-AUC': 0.640145461761324}
# INFO | HPO epoch  40/80 | loss=0.3072 | val={'ROC-AUC': 0.7852233676975946, 'PRC-AUC': 0.5942031294342575}
# INFO | HPO epoch  45/80 | loss=0.2779 | val={'ROC-AUC': 0.8228331424207713, 'PRC-AUC': 0.6640880608656717}
# INFO | HPO epoch  50/80 | loss=0.2628 | val={'ROC-AUC': 0.829324169530355, 'PRC-AUC': 0.684017979964616}
# INFO | HPO epoch  55/80 | loss=0.2637 | val={'ROC-AUC': 0.8381061473844978, 'PRC-AUC': 0.6930967621489218}
# INFO | HPO epoch  60/80 | loss=0.2396 | val={'ROC-AUC': 0.8193967163039328, 'PRC-AUC': 0.6707572394325958}
# INFO | HPO epoch  65/80 | loss=0.2475 | val={'ROC-AUC': 0.8083237877052311, 'PRC-AUC': 0.6544483805619284}
# INFO | HPO epoch  70/80 | loss=0.2302 | val={'ROC-AUC': 0.8180603283696067, 'PRC-AUC': 0.6878802047562167}
# INFO | HPO epoch  75/80 | loss=0.2250 | val={'ROC-AUC': 0.8287514318442153, 'PRC-AUC': 0.6820455706530727}
# INFO | Early stop at epoch 79 (patience=15)
# INFO | GIN 3D HPO — trial 11/20 finished | val=-0.847843 | best=-0.847843
# INFO | GIN 3D — starting trial 12/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.8337 | val={'ROC-AUC': 0.6861397479954181, 'PRC-AUC': 0.5804083851572976}
# INFO | HPO epoch   5/80 | loss=0.5058 | val={'ROC-AUC': 0.7130584192439863, 'PRC-AUC': 0.5255321452178365}
# INFO | HPO epoch  10/80 | loss=0.4596 | val={'ROC-AUC': 0.7210767468499427, 'PRC-AUC': 0.5499326092878949}
# INFO | HPO epoch  15/80 | loss=0.4388 | val={'ROC-AUC': 0.7189767086674304, 'PRC-AUC': 0.527375535840261}
# INFO | HPO epoch  20/80 | loss=0.3873 | val={'ROC-AUC': 0.7502863688430699, 'PRC-AUC': 0.5734685993839456}
# INFO | HPO epoch  25/80 | loss=0.3775 | val={'ROC-AUC': 0.7449408171057657, 'PRC-AUC': 0.6414453807309051}
# INFO | HPO epoch  30/80 | loss=0.3411 | val={'ROC-AUC': 0.8220694921725848, 'PRC-AUC': 0.6744710685017908}
# INFO | HPO epoch  35/80 | loss=0.3346 | val={'ROC-AUC': 0.803741886216113, 'PRC-AUC': 0.6675517547843468}
# INFO | HPO epoch  40/80 | loss=0.3055 | val={'ROC-AUC': 0.8237877052310043, 'PRC-AUC': 0.7154456334751148}
# INFO | HPO epoch  45/80 | loss=0.2988 | val={'ROC-AUC': 0.8004963726613211, 'PRC-AUC': 0.6462111732183615}
# INFO | HPO epoch  50/80 | loss=0.2916 | val={'ROC-AUC': 0.7955326460481099, 'PRC-AUC': 0.6554539035832156}
# INFO | HPO epoch  55/80 | loss=0.2896 | val={'ROC-AUC': 0.8132875143184423, 'PRC-AUC': 0.6783930549266859}
# INFO | HPO epoch  60/80 | loss=0.2633 | val={'ROC-AUC': 0.8426880488736159, 'PRC-AUC': 0.6936143404726056}
# INFO | Early stop at epoch 63 (patience=15)
# INFO | GIN 3D HPO — trial 12/20 finished | val=-0.843643 | best=-0.847843
# INFO | GIN 3D — starting trial 13/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.8646 | val={'ROC-AUC': 0.7029400534555174, 'PRC-AUC': 0.5452426593880749}
# INFO | HPO epoch   5/80 | loss=0.5438 | val={'ROC-AUC': 0.7058037418862161, 'PRC-AUC': 0.5306130270497948}
# INFO | HPO epoch  10/80 | loss=0.4525 | val={'ROC-AUC': 0.7371134020618557, 'PRC-AUC': 0.572846129675731}
# INFO | HPO epoch  15/80 | loss=0.4182 | val={'ROC-AUC': 0.7609774723176785, 'PRC-AUC': 0.5877895962119086}
# INFO | HPO epoch  20/80 | loss=0.4233 | val={'ROC-AUC': 0.7701412752959145, 'PRC-AUC': 0.6220595995670268}
# INFO | HPO epoch  25/80 | loss=0.3863 | val={'ROC-AUC': 0.7869415807560137, 'PRC-AUC': 0.6358353500449951}
# INFO | HPO epoch  30/80 | loss=0.3706 | val={'ROC-AUC': 0.7794959908361971, 'PRC-AUC': 0.6218343326052763}
# INFO | HPO epoch  35/80 | loss=0.3593 | val={'ROC-AUC': 0.8027873234058801, 'PRC-AUC': 0.6340477184679091}
# INFO | HPO epoch  40/80 | loss=0.3434 | val={'ROC-AUC': 0.7472317678503245, 'PRC-AUC': 0.5677754563236234}
# INFO | HPO epoch  45/80 | loss=0.2965 | val={'ROC-AUC': 0.7959144711722032, 'PRC-AUC': 0.6696861635348077}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | GIN 3D HPO — trial 13/20 finished | val=-0.818824 | best=-0.847843
# INFO | GIN 3D — starting trial 14/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.9402 | val={'ROC-AUC': 0.6691485299732722, 'PRC-AUC': 0.4840785329411803}
# INFO | HPO epoch   5/80 | loss=0.5121 | val={'ROC-AUC': 0.6937762504772813, 'PRC-AUC': 0.5490693877965882}
# INFO | HPO epoch  10/80 | loss=0.4547 | val={'ROC-AUC': 0.7464681176021382, 'PRC-AUC': 0.5841519559439553}
# INFO | HPO epoch  15/80 | loss=0.4582 | val={'ROC-AUC': 0.6746849942726232, 'PRC-AUC': 0.5049616025918733}
# INFO | HPO epoch  20/80 | loss=0.4097 | val={'ROC-AUC': 0.7710958381061473, 'PRC-AUC': 0.5937954581193374}
# INFO | HPO epoch  25/80 | loss=0.4100 | val={'ROC-AUC': 0.7657502863688431, 'PRC-AUC': 0.6034296073831606}
# INFO | HPO epoch  30/80 | loss=0.3467 | val={'ROC-AUC': 0.8321878579610539, 'PRC-AUC': 0.6628325415140924}
# INFO | HPO epoch  35/80 | loss=0.3423 | val={'ROC-AUC': 0.8356242840778924, 'PRC-AUC': 0.6597531679696349}
# INFO | HPO epoch  40/80 | loss=0.3123 | val={'ROC-AUC': 0.8346697212676595, 'PRC-AUC': 0.6721034957148748}
# INFO | HPO epoch  45/80 | loss=0.3140 | val={'ROC-AUC': 0.8232149675448645, 'PRC-AUC': 0.6644106352738389}
# INFO | HPO epoch  50/80 | loss=0.2795 | val={'ROC-AUC': 0.8285605192821688, 'PRC-AUC': 0.6372602123483566}
# INFO | HPO epoch  55/80 | loss=0.2813 | val={'ROC-AUC': 0.8424971363115692, 'PRC-AUC': 0.6942222579411336}
# INFO | HPO epoch  60/80 | loss=0.2687 | val={'ROC-AUC': 0.8396334478808705, 'PRC-AUC': 0.7100918272300469}
# INFO | HPO epoch  65/80 | loss=0.2354 | val={'ROC-AUC': 0.8312332951508209, 'PRC-AUC': 0.6748230951288319}
# INFO | HPO epoch  70/80 | loss=0.2349 | val={'ROC-AUC': 0.8249331806032837, 'PRC-AUC': 0.6724580631448455}
# INFO | HPO epoch  75/80 | loss=0.2384 | val={'ROC-AUC': 0.8256968308514699, 'PRC-AUC': 0.6567392324948196}
# INFO | Early stop at epoch 79 (patience=15)
# INFO | GIN 3D HPO — trial 14/20 finished | val=-0.846697 | best=-0.847843
# INFO | GIN 3D — starting trial 15/20 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.9846 | val={'ROC-AUC': 0.6960672012218404, 'PRC-AUC': 0.5556902978598088}
# INFO | HPO epoch   5/80 | loss=0.5138 | val={'ROC-AUC': 0.7974417716685759, 'PRC-AUC': 0.6340114839683427}
# INFO | HPO epoch  10/80 | loss=0.4315 | val={'ROC-AUC': 0.771286750668194, 'PRC-AUC': 0.6215198590905016}
# INFO | HPO epoch  15/80 | loss=0.3808 | val={'ROC-AUC': 0.817487590683467, 'PRC-AUC': 0.6854298812602933}
# INFO | HPO epoch  20/80 | loss=0.3509 | val={'ROC-AUC': 0.8027873234058801, 'PRC-AUC': 0.6154120633988763}
# INFO | HPO epoch  25/80 | loss=0.3679 | val={'ROC-AUC': 0.796487208858343, 'PRC-AUC': 0.6535121716414627}
# INFO | HPO epoch  30/80 | loss=0.3333 | val={'ROC-AUC': 0.8340969835815197, 'PRC-AUC': 0.7157545805655402}
# INFO | HPO epoch  35/80 | loss=0.3376 | val={'ROC-AUC': 0.8163421153111875, 'PRC-AUC': 0.6481759197395043}
# INFO | HPO epoch  40/80 | loss=0.3117 | val={'ROC-AUC': 0.8367697594501718, 'PRC-AUC': 0.6973082864334104}
# INFO | HPO epoch  45/80 | loss=0.2560 | val={'ROC-AUC': 0.8247422680412371, 'PRC-AUC': 0.7066198827940517}
# INFO | Early stop at epoch 46 (patience=15)
# INFO | GIN 3D HPO — trial 15/20 finished | val=-0.840779 | best=-0.847843
# INFO | GIN 3D — starting trial 16/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7681 | val={'ROC-AUC': 0.7019854906452845, 'PRC-AUC': 0.5152152717880464}
# INFO | HPO epoch   5/80 | loss=0.6262 | val={'ROC-AUC': 0.6733486063382971, 'PRC-AUC': 0.5364189890303381}
# INFO | HPO epoch  10/80 | loss=0.4472 | val={'ROC-AUC': 0.750668193967163, 'PRC-AUC': 0.6002517139617844}
# INFO | HPO epoch  15/80 | loss=0.4414 | val={'ROC-AUC': 0.7117220313096603, 'PRC-AUC': 0.5578029456525604}
# INFO | HPO epoch  20/80 | loss=0.4167 | val={'ROC-AUC': 0.7657502863688431, 'PRC-AUC': 0.5729616983412545}
# INFO | HPO epoch  25/80 | loss=0.3807 | val={'ROC-AUC': 0.7791141657121039, 'PRC-AUC': 0.6440618039295325}
# INFO | HPO epoch  30/80 | loss=0.3791 | val={'ROC-AUC': 0.7128675066819397, 'PRC-AUC': 0.5365021037299685}
# INFO | HPO epoch  35/80 | loss=0.3631 | val={'ROC-AUC': 0.7840778923253149, 'PRC-AUC': 0.6575130121435089}
# INFO | HPO epoch  40/80 | loss=0.3544 | val={'ROC-AUC': 0.775868652157312, 'PRC-AUC': 0.650127008402974}
# INFO | HPO epoch  45/80 | loss=0.3273 | val={'ROC-AUC': 0.8373424971363116, 'PRC-AUC': 0.7469142605854963}
# INFO | HPO epoch  50/80 | loss=0.3304 | val={'ROC-AUC': 0.8169148529973272, 'PRC-AUC': 0.6739301395878444}
# INFO | HPO epoch  55/80 | loss=0.3109 | val={'ROC-AUC': 0.8222604047346316, 'PRC-AUC': 0.7249460110486866}
# INFO | HPO epoch  60/80 | loss=0.2562 | val={'ROC-AUC': 0.8470790378006874, 'PRC-AUC': 0.7381794054152119}
# INFO | HPO epoch  65/80 | loss=0.2624 | val={'ROC-AUC': 0.8226422298587247, 'PRC-AUC': 0.664124222134637}
# INFO | HPO epoch  70/80 | loss=0.2518 | val={'ROC-AUC': 0.8451699121802214, 'PRC-AUC': 0.7435242562242051}
# INFO | HPO epoch  75/80 | loss=0.2372 | val={'ROC-AUC': 0.7999236349751814, 'PRC-AUC': 0.6202097754334315}
# INFO | HPO epoch  80/80 | loss=0.2054 | val={'ROC-AUC': 0.8478426880488736, 'PRC-AUC': 0.7353452512990647}
# INFO | GIN 3D HPO — trial 16/20 finished | val=-0.871134 | best=-0.871134
# INFO | GIN 3D — starting trial 17/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.8191 | val={'ROC-AUC': 0.6284841542573502, 'PRC-AUC': 0.4551704270216331}
# INFO | HPO epoch   5/80 | loss=0.5022 | val={'ROC-AUC': 0.7189767086674304, 'PRC-AUC': 0.5467706727411511}
# INFO | HPO epoch  10/80 | loss=0.4500 | val={'ROC-AUC': 0.7143948071783124, 'PRC-AUC': 0.5170225887955413}
# INFO | HPO epoch  15/80 | loss=0.4236 | val={'ROC-AUC': 0.7586865215731196, 'PRC-AUC': 0.5616152099525099}
# INFO | HPO epoch  20/80 | loss=0.4232 | val={'ROC-AUC': 0.7361588392516228, 'PRC-AUC': 0.5631378890002746}
# INFO | HPO epoch  25/80 | loss=0.3673 | val={'ROC-AUC': 0.7804505536464299, 'PRC-AUC': 0.5768169969086657}
# INFO | HPO epoch  30/80 | loss=0.3689 | val={'ROC-AUC': 0.7812142038946163, 'PRC-AUC': 0.6439192697932774}
# INFO | HPO epoch  35/80 | loss=0.3862 | val={'ROC-AUC': 0.7588774341351662, 'PRC-AUC': 0.5536316738624909}
# INFO | HPO epoch  40/80 | loss=0.3530 | val={'ROC-AUC': 0.7315769377625049, 'PRC-AUC': 0.5551763384507001}
# INFO | HPO epoch  45/80 | loss=0.3431 | val={'ROC-AUC': 0.7747231767850326, 'PRC-AUC': 0.5799134688702469}
# INFO | HPO epoch  50/80 | loss=0.3309 | val={'ROC-AUC': 0.7789232531500573, 'PRC-AUC': 0.6078416692877682}
# INFO | HPO epoch  55/80 | loss=0.3280 | val={'ROC-AUC': 0.7854142802596411, 'PRC-AUC': 0.6144403184254422}
# INFO | HPO epoch  60/80 | loss=0.3354 | val={'ROC-AUC': 0.7745322642229859, 'PRC-AUC': 0.5890160876489755}
# INFO | HPO epoch  65/80 | loss=0.2785 | val={'ROC-AUC': 0.7932416953035509, 'PRC-AUC': 0.6665415412971948}
# INFO | HPO epoch  70/80 | loss=0.2802 | val={'ROC-AUC': 0.799159984726995, 'PRC-AUC': 0.6316332937897476}
# INFO | HPO epoch  75/80 | loss=0.2723 | val={'ROC-AUC': 0.8209240168003056, 'PRC-AUC': 0.7027747622445498}
# INFO | HPO epoch  80/80 | loss=0.2929 | val={'ROC-AUC': 0.7777777777777779, 'PRC-AUC': 0.6524911961381599}
# INFO | GIN 3D HPO — trial 17/20 finished | val=-0.820924 | best=-0.871134
# INFO | GIN 3D — starting trial 18/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7371 | val={'ROC-AUC': 0.693012600229095, 'PRC-AUC': 0.5353737691642139}
# INFO | HPO epoch   5/80 | loss=0.4936 | val={'ROC-AUC': 0.7243222604047346, 'PRC-AUC': 0.5747845305207614}
# INFO | HPO epoch  10/80 | loss=0.4540 | val={'ROC-AUC': 0.7691867124856816, 'PRC-AUC': 0.6257996048163655}
# INFO | HPO epoch  15/80 | loss=0.4341 | val={'ROC-AUC': 0.7478045055364644, 'PRC-AUC': 0.5757354808391723}
# INFO | HPO epoch  20/80 | loss=0.3868 | val={'ROC-AUC': 0.7556319205803743, 'PRC-AUC': 0.636620957918249}
# INFO | HPO epoch  25/80 | loss=0.3791 | val={'ROC-AUC': 0.784077892325315, 'PRC-AUC': 0.5955643677934261}
# INFO | HPO epoch  30/80 | loss=0.3703 | val={'ROC-AUC': 0.7590683466972126, 'PRC-AUC': 0.5623691255491988}
# INFO | HPO epoch  35/80 | loss=0.3389 | val={'ROC-AUC': 0.7940053455517373, 'PRC-AUC': 0.6517528337369135}
# INFO | HPO epoch  40/80 | loss=0.3478 | val={'ROC-AUC': 0.7867506681939672, 'PRC-AUC': 0.6191060243686376}
# INFO | HPO epoch  45/80 | loss=0.3457 | val={'ROC-AUC': 0.7504772814051165, 'PRC-AUC': 0.5742845538753221}
# INFO | HPO epoch  50/80 | loss=0.2792 | val={'ROC-AUC': 0.8077510500190912, 'PRC-AUC': 0.6664094975021739}
# INFO | Early stop at epoch 51 (patience=15)
# INFO | GIN 3D HPO — trial 18/20 finished | val=-0.811187 | best=-0.871134
# INFO | GIN 3D — starting trial 19/20 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=1.2045 | val={'ROC-AUC': 0.6689576174112257, 'PRC-AUC': 0.5131254929199991}
# INFO | HPO epoch   5/80 | loss=0.5187 | val={'ROC-AUC': 0.7094310805651012, 'PRC-AUC': 0.5639073994873176}
# INFO | HPO epoch  10/80 | loss=0.4579 | val={'ROC-AUC': 0.7269950362733868, 'PRC-AUC': 0.6311193511376028}
# INFO | HPO epoch  15/80 | loss=0.4369 | val={'ROC-AUC': 0.7682321496754487, 'PRC-AUC': 0.5899249858220437}
# INFO | HPO epoch  20/80 | loss=0.4149 | val={'ROC-AUC': 0.7798778159602903, 'PRC-AUC': 0.649467791979836}
# INFO | HPO epoch  25/80 | loss=0.3907 | val={'ROC-AUC': 0.7439862542955327, 'PRC-AUC': 0.6012842309442812}
# INFO | HPO epoch  30/80 | loss=0.3455 | val={'ROC-AUC': 0.7548682703321878, 'PRC-AUC': 0.5987541545211319}
# INFO | HPO epoch  35/80 | loss=0.3567 | val={'ROC-AUC': 0.8073692248949981, 'PRC-AUC': 0.67344070143616}
# INFO | HPO epoch  40/80 | loss=0.3058 | val={'ROC-AUC': 0.8174875906834671, 'PRC-AUC': 0.6816319097360551}
# INFO | HPO epoch  45/80 | loss=0.3046 | val={'ROC-AUC': 0.8100420007636503, 'PRC-AUC': 0.6833833764791943}
# INFO | HPO epoch  50/80 | loss=0.2667 | val={'ROC-AUC': 0.8375334096983582, 'PRC-AUC': 0.7244430923802839}
# INFO | HPO epoch  55/80 | loss=0.2547 | val={'ROC-AUC': 0.84077892325315, 'PRC-AUC': 0.7231892948758231}
# INFO | HPO epoch  60/80 | loss=0.2432 | val={'ROC-AUC': 0.7888507063764796, 'PRC-AUC': 0.668754779695902}
# INFO | HPO epoch  65/80 | loss=0.2145 | val={'ROC-AUC': 0.7947689957999235, 'PRC-AUC': 0.6672684742894722}
# INFO | HPO epoch  70/80 | loss=0.2009 | val={'ROC-AUC': 0.8293241695303551, 'PRC-AUC': 0.726510702453088}
# INFO | Early stop at epoch 70 (patience=15)
# INFO | GIN 3D HPO — trial 19/20 finished | val=-0.840779 | best=-0.871134
# INFO | GIN 3D — starting trial 20/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.8581 | val={'ROC-AUC': 0.6311569301260023, 'PRC-AUC': 0.48936354819833905}
# INFO | HPO epoch   5/80 | loss=0.5919 | val={'ROC-AUC': 0.7392134402443681, 'PRC-AUC': 0.6376142959966422}
# INFO | HPO epoch  10/80 | loss=0.4728 | val={'ROC-AUC': 0.7422680412371134, 'PRC-AUC': 0.5923946095425769}
# INFO | HPO epoch  15/80 | loss=0.4528 | val={'ROC-AUC': 0.7733867888507063, 'PRC-AUC': 0.6367277327920815}
# INFO | HPO epoch  20/80 | loss=0.4169 | val={'ROC-AUC': 0.6947308132875144, 'PRC-AUC': 0.5233580435635046}
# INFO | HPO epoch  25/80 | loss=0.4074 | val={'ROC-AUC': 0.7663230240549829, 'PRC-AUC': 0.6059860984322353}
# INFO | HPO epoch  30/80 | loss=0.3624 | val={'ROC-AUC': 0.7560137457044673, 'PRC-AUC': 0.6502935129960794}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | GIN 3D HPO — trial 20/20 finished | val=-0.806987 | best=-0.871134
# INFO | Epoch  10 | loss=0.5343 | val={'ROC-AUC': 0.6830851470026728, 'PRC-AUC': 0.583342236580408}
# INFO | Epoch  20 | loss=0.4032 | val={'ROC-AUC': 0.7838869797632684, 'PRC-AUC': 0.6046921848290457}
# INFO | Epoch  30 | loss=0.3817 | val={'ROC-AUC': 0.7766323024054983, 'PRC-AUC': 0.6227422736375642}
# INFO | Epoch  40 | loss=0.3554 | val={'ROC-AUC': 0.7915234822451318, 'PRC-AUC': 0.633025061137907}
# INFO | Epoch  50 | loss=0.3496 | val={'ROC-AUC': 0.788659793814433, 'PRC-AUC': 0.6370098161139223}
# INFO | Epoch  60 | loss=0.3248 | val={'ROC-AUC': 0.8192058037418861, 'PRC-AUC': 0.7191842109910013}
# INFO | Epoch  70 | loss=0.2583 | val={'ROC-AUC': 0.8172966781214204, 'PRC-AUC': 0.6621500565303525}
# INFO | Epoch  80 | loss=0.2122 | val={'ROC-AUC': 0.8146239022527683, 'PRC-AUC': 0.661505141855523}
# INFO | Saved GIN (3D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.9032258064516129, 'PRC-AUC': 0.8094548735594095}

# %% [markdown]
# ### SchNet (3D coords)
# Uses atomic numbers + xyz from min-energy n=25 conformer.

# %%
MODEL_KEY = "SchNet (3D coords)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_schnet(
        tr3d, va3d, TASK_TYPE, OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_schnet, PyGLoader, build_schnet, train_schnet
    model = build_schnet(
        OUT_CHANNELS,
        hidden_channels=best["hidden_channels"],
        num_filters=best["num_filters"],
        num_interactions=best["num_interactions"],
        num_gaussians=best["num_gaussians"],
        cutoff=best["cutoff"],
    )
    train_schnet(model, tr3d, va3d, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
                 batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    te3d_schnet = ensure_atomic_numbers_list(te3d)
    test_metrics = eval_schnet(model, PyGLoader(te3d_schnet, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_schnet.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | SchNet — starting trial 1/20
# → SchNet (3D coords) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=1.1781 | val={'ROC-AUC': 0.5248186330660558, 'PRC-AUC': 0.3659038676043641}
# INFO | HPO epoch   5/80 | loss=0.6735 | val={'ROC-AUC': 0.617602138220695, 'PRC-AUC': 0.5413689209365232}
# INFO | HPO epoch  10/80 | loss=0.5938 | val={'ROC-AUC': 0.6718213058419243, 'PRC-AUC': 0.5719512967399041}
# INFO | HPO epoch  15/80 | loss=0.5778 | val={'ROC-AUC': 0.6834669721267659, 'PRC-AUC': 0.5918866847551323}
# INFO | HPO epoch  20/80 | loss=0.6213 | val={'ROC-AUC': 0.6754486445208095, 'PRC-AUC': 0.5786025808450447}
# INFO | HPO epoch  25/80 | loss=0.5371 | val={'ROC-AUC': 0.6928216876670485, 'PRC-AUC': 0.6242754745965899}
# INFO | HPO epoch  30/80 | loss=0.5357 | val={'ROC-AUC': 0.6943489881634212, 'PRC-AUC': 0.6130675418604427}
# INFO | HPO epoch  35/80 | loss=0.5474 | val={'ROC-AUC': 0.7059946544482627, 'PRC-AUC': 0.6448723692316256}
# INFO | HPO epoch  40/80 | loss=0.4924 | val={'ROC-AUC': 0.7180221458571975, 'PRC-AUC': 0.6624180362871849}
# INFO | HPO epoch  45/80 | loss=0.4847 | val={'ROC-AUC': 0.6974035891561664, 'PRC-AUC': 0.6338124234128946}
# INFO | HPO epoch  50/80 | loss=0.4701 | val={'ROC-AUC': 0.7164948453608249, 'PRC-AUC': 0.6618208599296834}
# INFO | HPO epoch  55/80 | loss=0.4569 | val={'ROC-AUC': 0.7168766704849179, 'PRC-AUC': 0.6485601227563288}
# INFO | Early stop at epoch 55 (patience=15)
# INFO | SchNet HPO — trial 1/20 finished | val=-0.718022 | best=-0.718022
# INFO | SchNet — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=1.3495 | val={'ROC-AUC': 0.5320733104238259, 'PRC-AUC': 0.465148954132986}
# INFO | HPO epoch   5/80 | loss=0.6667 | val={'ROC-AUC': 0.6510118365788469, 'PRC-AUC': 0.5295706300080892}
# INFO | HPO epoch  10/80 | loss=0.5864 | val={'ROC-AUC': 0.6932035127911417, 'PRC-AUC': 0.6004284276512604}
# INFO | HPO epoch  15/80 | loss=0.5762 | val={'ROC-AUC': 0.7180221458571974, 'PRC-AUC': 0.6373385809597629}
# INFO | HPO epoch  20/80 | loss=0.4889 | val={'ROC-AUC': 0.777205040091638, 'PRC-AUC': 0.6883607449696773}
# INFO | HPO epoch  25/80 | loss=0.4427 | val={'ROC-AUC': 0.7516227567773959, 'PRC-AUC': 0.6476379677413959}
# INFO | HPO epoch  30/80 | loss=0.4323 | val={'ROC-AUC': 0.774914089347079, 'PRC-AUC': 0.6472039365468474}
# INFO | HPO epoch  35/80 | loss=0.4184 | val={'ROC-AUC': 0.768041237113402, 'PRC-AUC': 0.6487076899605467}
# INFO | HPO epoch  40/80 | loss=0.3550 | val={'ROC-AUC': 0.7901870943108057, 'PRC-AUC': 0.6716625773592262}
# INFO | HPO epoch  45/80 | loss=0.3248 | val={'ROC-AUC': 0.7798778159602903, 'PRC-AUC': 0.6455260243949353}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | SchNet HPO — trial 2/20 finished | val=-0.797442 | best=-0.797442
# INFO | SchNet — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=1.8079 | val={'ROC-AUC': 0.5053455517373043, 'PRC-AUC': 0.44208526094631206}
# INFO | HPO epoch   5/80 | loss=0.6131 | val={'ROC-AUC': 0.6718213058419245, 'PRC-AUC': 0.532597807132724}
# INFO | HPO epoch  10/80 | loss=0.6271 | val={'ROC-AUC': 0.6657121038564338, 'PRC-AUC': 0.5478073881432892}
# INFO | HPO epoch  15/80 | loss=0.6398 | val={'ROC-AUC': 0.7134402443680794, 'PRC-AUC': 0.6186276499096834}
# INFO | HPO epoch  20/80 | loss=0.5236 | val={'ROC-AUC': 0.7035127911416571, 'PRC-AUC': 0.6251724858029162}
# INFO | HPO epoch  25/80 | loss=0.5369 | val={'ROC-AUC': 0.7583046964490263, 'PRC-AUC': 0.6613689254362869}
# INFO | HPO epoch  30/80 | loss=0.4598 | val={'ROC-AUC': 0.7583046964490264, 'PRC-AUC': 0.6777550382933532}
# INFO | HPO epoch  35/80 | loss=0.4359 | val={'ROC-AUC': 0.7342497136311569, 'PRC-AUC': 0.6297263100041129}
# INFO | HPO epoch  40/80 | loss=0.4411 | val={'ROC-AUC': 0.7987781596029019, 'PRC-AUC': 0.6869032027703041}
# INFO | HPO epoch  45/80 | loss=0.3942 | val={'ROC-AUC': 0.7800687285223368, 'PRC-AUC': 0.6587862468512444}
# INFO | HPO epoch  50/80 | loss=0.3797 | val={'ROC-AUC': 0.7319587628865979, 'PRC-AUC': 0.5921086890240629}
# INFO | HPO epoch  55/80 | loss=0.2878 | val={'ROC-AUC': 0.7678503245513554, 'PRC-AUC': 0.621798796770155}
# INFO | Early stop at epoch 55 (patience=15)
# INFO | SchNet HPO — trial 3/20 finished | val=-0.798778 | best=-0.798778
# INFO | SchNet — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=1.1080 | val={'ROC-AUC': 0.42229858724704084, 'PRC-AUC': 0.3274255199761006}
# INFO | HPO epoch   5/80 | loss=0.6456 | val={'ROC-AUC': 0.6000381825124093, 'PRC-AUC': 0.4843778676529419}
# INFO | HPO epoch  10/80 | loss=0.6076 | val={'ROC-AUC': 0.6317296678121421, 'PRC-AUC': 0.49975561070128055}
# INFO | HPO epoch  15/80 | loss=0.6108 | val={'ROC-AUC': 0.6210385643375335, 'PRC-AUC': 0.4781752193555002}
# INFO | HPO epoch  20/80 | loss=0.5683 | val={'ROC-AUC': 0.6588392516227567, 'PRC-AUC': 0.5201904334094477}
# INFO | HPO epoch  25/80 | loss=0.5613 | val={'ROC-AUC': 0.6731576937762503, 'PRC-AUC': 0.5503238838309328}
# INFO | HPO epoch  30/80 | loss=0.5653 | val={'ROC-AUC': 0.6815578465063001, 'PRC-AUC': 0.5562746737871582}
# INFO | HPO epoch  35/80 | loss=0.5526 | val={'ROC-AUC': 0.6689576174112257, 'PRC-AUC': 0.5384377441085013}
# INFO | HPO epoch  40/80 | loss=0.5460 | val={'ROC-AUC': 0.6796487208858343, 'PRC-AUC': 0.5607105212665414}
# INFO | HPO epoch  45/80 | loss=0.5526 | val={'ROC-AUC': 0.6649484536082474, 'PRC-AUC': 0.532126800122383}
# INFO | HPO epoch  50/80 | loss=0.5693 | val={'ROC-AUC': 0.6735395189003437, 'PRC-AUC': 0.5484491066909825}
# INFO | HPO epoch  55/80 | loss=0.5395 | val={'ROC-AUC': 0.6796487208858343, 'PRC-AUC': 0.5582125285917081}
# INFO | HPO epoch  60/80 | loss=0.5379 | val={'ROC-AUC': 0.6762122947689958, 'PRC-AUC': 0.555959882184607}
# INFO | HPO epoch  65/80 | loss=0.5397 | val={'ROC-AUC': 0.6785032455135548, 'PRC-AUC': 0.5576146875839989}
# INFO | HPO epoch  70/80 | loss=0.5254 | val={'ROC-AUC': 0.6821305841924399, 'PRC-AUC': 0.5664877199836962}
# INFO | HPO epoch  75/80 | loss=0.5209 | val={'ROC-AUC': 0.6848033600610921, 'PRC-AUC': 0.5702651390938472}
# INFO | HPO epoch  80/80 | loss=0.5160 | val={'ROC-AUC': 0.6863306605574646, 'PRC-AUC': 0.573655039723899}
# INFO | SchNet HPO — trial 4/20 finished | val=-0.690531 | best=-0.798778
# INFO | SchNet — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=1.1439 | val={'ROC-AUC': 0.614356624665903, 'PRC-AUC': 0.49518916921226797}
# INFO | HPO epoch   5/80 | loss=0.6742 | val={'ROC-AUC': 0.6615120274914089, 'PRC-AUC': 0.5420283162595455}
# INFO | HPO epoch  10/80 | loss=0.5985 | val={'ROC-AUC': 0.6838487972508591, 'PRC-AUC': 0.5514411576841238}
# INFO | HPO epoch  15/80 | loss=0.6060 | val={'ROC-AUC': 0.6666666666666667, 'PRC-AUC': 0.5367035955178191}
# INFO | HPO epoch  20/80 | loss=0.5455 | val={'ROC-AUC': 0.6741122565864834, 'PRC-AUC': 0.5472806686304665}
# INFO | HPO epoch  25/80 | loss=0.5424 | val={'ROC-AUC': 0.6882397861779305, 'PRC-AUC': 0.5776408433054451}
# INFO | HPO epoch  30/80 | loss=0.5515 | val={'ROC-AUC': 0.6945399007254678, 'PRC-AUC': 0.584280520959794}
# INFO | HPO epoch  35/80 | loss=0.4965 | val={'ROC-AUC': 0.7266132111492937, 'PRC-AUC': 0.6217118305727088}
# INFO | HPO epoch  40/80 | loss=0.4948 | val={'ROC-AUC': 0.7588774341351661, 'PRC-AUC': 0.6649385342293936}
# INFO | HPO epoch  45/80 | loss=0.4896 | val={'ROC-AUC': 0.7334860633829706, 'PRC-AUC': 0.6557419172967055}
# INFO | HPO epoch  50/80 | loss=0.4653 | val={'ROC-AUC': 0.7728140511645667, 'PRC-AUC': 0.66231854935268}
# INFO | HPO epoch  55/80 | loss=0.4396 | val={'ROC-AUC': 0.7699503627338679, 'PRC-AUC': 0.7024632224818222}
# INFO | HPO epoch  60/80 | loss=0.4780 | val={'ROC-AUC': 0.7523864070255823, 'PRC-AUC': 0.6579616365559612}
# INFO | HPO epoch  65/80 | loss=0.4823 | val={'ROC-AUC': 0.7754868270332187, 'PRC-AUC': 0.6907228385365676}
# INFO | HPO epoch  70/80 | loss=0.4400 | val={'ROC-AUC': 0.7693776250477281, 'PRC-AUC': 0.6560601335362668}
# INFO | HPO epoch  75/80 | loss=0.4184 | val={'ROC-AUC': 0.7842688048873615, 'PRC-AUC': 0.7155854912136397}
# INFO | HPO epoch  80/80 | loss=0.3813 | val={'ROC-AUC': 0.7940053455517373, 'PRC-AUC': 0.7240273342605361}
# INFO | SchNet HPO — trial 5/20 finished | val=-0.798015 | best=-0.798778
# INFO | SchNet — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=1.7836 | val={'ROC-AUC': 0.6620847651775488, 'PRC-AUC': 0.5351747501607294}
# INFO | HPO epoch   5/80 | loss=0.6419 | val={'ROC-AUC': 0.6426116838487972, 'PRC-AUC': 0.517497300453457}
# INFO | HPO epoch  10/80 | loss=0.5932 | val={'ROC-AUC': 0.6485299732722413, 'PRC-AUC': 0.5089884112994366}
# INFO | HPO epoch  15/80 | loss=0.5697 | val={'ROC-AUC': 0.7046582665139367, 'PRC-AUC': 0.5690030272231216}
# INFO | HPO epoch  20/80 | loss=0.5316 | val={'ROC-AUC': 0.6848033600610921, 'PRC-AUC': 0.5672544974311009}
# INFO | HPO epoch  25/80 | loss=0.5587 | val={'ROC-AUC': 0.6981672394043529, 'PRC-AUC': 0.6093748645109887}
# INFO | HPO epoch  30/80 | loss=0.4961 | val={'ROC-AUC': 0.7306223749522719, 'PRC-AUC': 0.641985632478574}
# INFO | HPO epoch  35/80 | loss=0.5120 | val={'ROC-AUC': 0.7371134020618557, 'PRC-AUC': 0.6672929108247571}
# INFO | HPO epoch  40/80 | loss=0.5210 | val={'ROC-AUC': 0.7392134402443681, 'PRC-AUC': 0.6527617866734374}
# INFO | HPO epoch  45/80 | loss=0.4958 | val={'ROC-AUC': 0.7489499809087439, 'PRC-AUC': 0.6731994638880003}
# INFO | HPO epoch  50/80 | loss=0.4678 | val={'ROC-AUC': 0.7878961435662466, 'PRC-AUC': 0.684649623199906}
# INFO | HPO epoch  55/80 | loss=0.4222 | val={'ROC-AUC': 0.7514318442153495, 'PRC-AUC': 0.6831210507355876}
# INFO | HPO epoch  60/80 | loss=0.4292 | val={'ROC-AUC': 0.782168766704849, 'PRC-AUC': 0.6941962825857149}
# INFO | HPO epoch  65/80 | loss=0.4310 | val={'ROC-AUC': 0.8043146239022527, 'PRC-AUC': 0.7020666854473048}
# INFO | HPO epoch  70/80 | loss=0.3919 | val={'ROC-AUC': 0.7714776632302406, 'PRC-AUC': 0.6427628040022226}
# INFO | HPO epoch  75/80 | loss=0.4173 | val={'ROC-AUC': 0.7930507827415044, 'PRC-AUC': 0.6997877283743652}
# INFO | HPO epoch  80/80 | loss=0.3693 | val={'ROC-AUC': 0.8025964108438336, 'PRC-AUC': 0.7032068329389233}
# INFO | Early stop at epoch 80 (patience=15)
# INFO | SchNet HPO — trial 6/20 finished | val=-0.804315 | best=-0.804315
# INFO | SchNet — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=1.5423 | val={'ROC-AUC': 0.5433371515845743, 'PRC-AUC': 0.47379771570486645}
# INFO | HPO epoch   5/80 | loss=0.6598 | val={'ROC-AUC': 0.6882397861779305, 'PRC-AUC': 0.5820195150895977}
# INFO | HPO epoch  10/80 | loss=0.4755 | val={'ROC-AUC': 0.7184039709812906, 'PRC-AUC': 0.6369217584154839}
# INFO | HPO epoch  15/80 | loss=0.4297 | val={'ROC-AUC': 0.750668193967163, 'PRC-AUC': 0.629015313397187}
# INFO | HPO epoch  20/80 | loss=0.3484 | val={'ROC-AUC': 0.766704849179076, 'PRC-AUC': 0.641788206313402}
# INFO | HPO epoch  25/80 | loss=0.2949 | val={'ROC-AUC': 0.7550591828942343, 'PRC-AUC': 0.624912601999358}
# INFO | HPO epoch  30/80 | loss=0.1931 | val={'ROC-AUC': 0.7867506681939671, 'PRC-AUC': 0.6491862005275074}
# INFO | Early stop at epoch 34 (patience=15)
# INFO | SchNet HPO — trial 7/20 finished | val=-0.795342 | best=-0.804315
# INFO | SchNet — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=1.1436 | val={'ROC-AUC': 0.5404734631538756, 'PRC-AUC': 0.45441246628746895}
# INFO | HPO epoch   5/80 | loss=0.6363 | val={'ROC-AUC': 0.6521573119511264, 'PRC-AUC': 0.5556359479887738}
# INFO | HPO epoch  10/80 | loss=0.6184 | val={'ROC-AUC': 0.7268041237113403, 'PRC-AUC': 0.6558963845470434}
# INFO | HPO epoch  15/80 | loss=0.5332 | val={'ROC-AUC': 0.7210767468499427, 'PRC-AUC': 0.6625424531548831}
# INFO | HPO epoch  20/80 | loss=0.4770 | val={'ROC-AUC': 0.6945399007254678, 'PRC-AUC': 0.5899930914842417}
# INFO | HPO epoch  25/80 | loss=0.4577 | val={'ROC-AUC': 0.7338678885070639, 'PRC-AUC': 0.6617412013903201}
# INFO | HPO epoch  30/80 | loss=0.4191 | val={'ROC-AUC': 0.7332951508209241, 'PRC-AUC': 0.6524556195476168}
# INFO | HPO epoch  35/80 | loss=0.3937 | val={'ROC-AUC': 0.7491408934707904, 'PRC-AUC': 0.6791634398570993}
# INFO | HPO epoch  40/80 | loss=0.3476 | val={'ROC-AUC': 0.7903780068728522, 'PRC-AUC': 0.6917527734877195}
# INFO | HPO epoch  45/80 | loss=0.3220 | val={'ROC-AUC': 0.7571592210767469, 'PRC-AUC': 0.6133781370550607}
# INFO | HPO epoch  50/80 | loss=0.3465 | val={'ROC-AUC': 0.7697594501718215, 'PRC-AUC': 0.6452282010086958}
# INFO | HPO epoch  55/80 | loss=0.1865 | val={'ROC-AUC': 0.8029782359679266, 'PRC-AUC': 0.6923705185751385}
# INFO | HPO epoch  60/80 | loss=0.1620 | val={'ROC-AUC': 0.8039327987781596, 'PRC-AUC': 0.7108622134939536}
# INFO | HPO epoch  65/80 | loss=0.1546 | val={'ROC-AUC': 0.816151202749141, 'PRC-AUC': 0.705896390795002}
# INFO | HPO epoch  70/80 | loss=0.1197 | val={'ROC-AUC': 0.782741504390989, 'PRC-AUC': 0.6637261617913999}
# INFO | HPO epoch  75/80 | loss=0.0880 | val={'ROC-AUC': 0.7833142420771287, 'PRC-AUC': 0.6612679022763571}
# INFO | HPO epoch  80/80 | loss=0.0539 | val={'ROC-AUC': 0.7737686139747996, 'PRC-AUC': 0.6606425053576257}
# INFO | Early stop at epoch 80 (patience=15)
# INFO | SchNet HPO — trial 8/20 finished | val=-0.816151 | best=-0.816151
# INFO | SchNet — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=1.9739 | val={'ROC-AUC': 0.5958381061473845, 'PRC-AUC': 0.4640385364244631}
# INFO | HPO epoch   5/80 | loss=0.6243 | val={'ROC-AUC': 0.6471935853379153, 'PRC-AUC': 0.5247007567798428}
# INFO | HPO epoch  10/80 | loss=0.6518 | val={'ROC-AUC': 0.7206949217258496, 'PRC-AUC': 0.580289662955002}
# INFO | HPO epoch  15/80 | loss=0.4704 | val={'ROC-AUC': 0.7241313478426881, 'PRC-AUC': 0.567093425225881}
# INFO | HPO epoch  20/80 | loss=0.4762 | val={'ROC-AUC': 0.740168003054601, 'PRC-AUC': 0.5928650168188296}
# INFO | HPO epoch  25/80 | loss=0.4241 | val={'ROC-AUC': 0.7250859106529209, 'PRC-AUC': 0.5529041924492721}
# INFO | HPO epoch  30/80 | loss=0.3557 | val={'ROC-AUC': 0.7562046582665138, 'PRC-AUC': 0.6028203195105588}
# INFO | HPO epoch  35/80 | loss=0.2884 | val={'ROC-AUC': 0.7449408171057657, 'PRC-AUC': 0.6013186045255112}
# INFO | HPO epoch  40/80 | loss=0.3273 | val={'ROC-AUC': 0.7430316914852998, 'PRC-AUC': 0.6322178130333475}
# INFO | HPO epoch  45/80 | loss=0.1914 | val={'ROC-AUC': 0.7751050019091257, 'PRC-AUC': 0.6560984116530968}
# INFO | HPO epoch  50/80 | loss=0.2091 | val={'ROC-AUC': 0.7630775105001909, 'PRC-AUC': 0.6520751572493478}
# INFO | HPO epoch  55/80 | loss=0.1429 | val={'ROC-AUC': 0.7504772814051164, 'PRC-AUC': 0.6311495057553903}
# INFO | HPO epoch  60/80 | loss=0.1141 | val={'ROC-AUC': 0.767659411989309, 'PRC-AUC': 0.6816847590454457}
# INFO | HPO epoch  65/80 | loss=0.0627 | val={'ROC-AUC': 0.7779686903398243, 'PRC-AUC': 0.6891179980251149}
# INFO | Early stop at epoch 68 (patience=15)
# INFO | SchNet HPO — trial 9/20 finished | val=-0.786751 | best=-0.816151
# INFO | SchNet — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=0.8911 | val={'ROC-AUC': 0.5551737304314623, 'PRC-AUC': 0.42739392018374384}
# INFO | HPO epoch   5/80 | loss=0.6616 | val={'ROC-AUC': 0.6754486445208094, 'PRC-AUC': 0.573745856497419}
# INFO | HPO epoch  10/80 | loss=0.6178 | val={'ROC-AUC': 0.6769759450171821, 'PRC-AUC': 0.569178528845828}
# INFO | HPO epoch  15/80 | loss=0.6006 | val={'ROC-AUC': 0.6687667048491791, 'PRC-AUC': 0.5470462780947463}
# INFO | HPO epoch  20/80 | loss=0.5863 | val={'ROC-AUC': 0.671057655593738, 'PRC-AUC': 0.537845344040003}
# INFO | HPO epoch  25/80 | loss=0.5869 | val={'ROC-AUC': 0.6872852233676976, 'PRC-AUC': 0.5512937136192262}
# INFO | HPO epoch  30/80 | loss=0.5518 | val={'ROC-AUC': 0.6882397861779306, 'PRC-AUC': 0.5509850661625226}
# INFO | Early stop at epoch 31 (patience=15)
# INFO | SchNet HPO — trial 10/20 finished | val=-0.697976 | best=-0.816151
# INFO | SchNet — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=1.3052 | val={'ROC-AUC': 0.5580374188621611, 'PRC-AUC': 0.4705958723807461}
# INFO | HPO epoch   5/80 | loss=0.5845 | val={'ROC-AUC': 0.6911034746086292, 'PRC-AUC': 0.5848266327345268}
# INFO | HPO epoch  10/80 | loss=0.5544 | val={'ROC-AUC': 0.6970217640320733, 'PRC-AUC': 0.5900874446691902}
# INFO | HPO epoch  15/80 | loss=0.4842 | val={'ROC-AUC': 0.7302405498281788, 'PRC-AUC': 0.6150846035812055}
# INFO | HPO epoch  20/80 | loss=0.4983 | val={'ROC-AUC': 0.7470408552882781, 'PRC-AUC': 0.623175717137154}
# INFO | HPO epoch  25/80 | loss=0.4315 | val={'ROC-AUC': 0.7420771286750668, 'PRC-AUC': 0.5839515283686706}
# INFO | HPO epoch  30/80 | loss=0.3518 | val={'ROC-AUC': 0.7166857579228714, 'PRC-AUC': 0.5958805865028982}
# INFO | HPO epoch  35/80 | loss=0.3442 | val={'ROC-AUC': 0.7359679266895762, 'PRC-AUC': 0.5802268540589676}
# INFO | HPO epoch  40/80 | loss=0.2554 | val={'ROC-AUC': 0.7098129056891944, 'PRC-AUC': 0.5812795591518956}
# INFO | Early stop at epoch 41 (patience=15)
# INFO | SchNet HPO — trial 11/20 finished | val=-0.752959 | best=-0.816151
# INFO | SchNet — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=1.0355 | val={'ROC-AUC': 0.7096219931271478, 'PRC-AUC': 0.5895258702467812}
# INFO | HPO epoch   5/80 | loss=0.6076 | val={'ROC-AUC': 0.6681939671630394, 'PRC-AUC': 0.5737076725638799}
# INFO | HPO epoch  10/80 | loss=0.6818 | val={'ROC-AUC': 0.7079037800687284, 'PRC-AUC': 0.6130808803291286}
# INFO | HPO epoch  15/80 | loss=0.5481 | val={'ROC-AUC': 0.6838487972508592, 'PRC-AUC': 0.5906050573395175}
# INFO | Early stop at epoch 16 (patience=15)
# INFO | SchNet HPO — trial 12/20 finished | val=-0.709622 | best=-0.816151
# INFO | SchNet — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=0.8971 | val={'ROC-AUC': 0.4809087437953417, 'PRC-AUC': 0.39940545031103464}
# INFO | HPO epoch   5/80 | loss=0.6543 | val={'ROC-AUC': 0.5906834669721267, 'PRC-AUC': 0.4800242133418967}
# INFO | HPO epoch  10/80 | loss=0.5679 | val={'ROC-AUC': 0.6643757159221078, 'PRC-AUC': 0.5456031125671061}
# INFO | HPO epoch  15/80 | loss=0.5940 | val={'ROC-AUC': 0.6727758686521574, 'PRC-AUC': 0.5744689770178806}
# INFO | HPO epoch  20/80 | loss=0.5248 | val={'ROC-AUC': 0.6945399007254677, 'PRC-AUC': 0.6279007647747363}
# INFO | HPO epoch  25/80 | loss=0.5838 | val={'ROC-AUC': 0.7014127529591447, 'PRC-AUC': 0.6466793904391979}
# INFO | HPO epoch  30/80 | loss=0.4842 | val={'ROC-AUC': 0.7184039709812906, 'PRC-AUC': 0.6533039971608371}
# INFO | HPO epoch  35/80 | loss=0.4937 | val={'ROC-AUC': 0.7229858724704085, 'PRC-AUC': 0.6703167437569381}
# INFO | HPO epoch  40/80 | loss=0.4629 | val={'ROC-AUC': 0.7560137457044673, 'PRC-AUC': 0.680014385327993}
# INFO | HPO epoch  45/80 | loss=0.4522 | val={'ROC-AUC': 0.7325315005727376, 'PRC-AUC': 0.6546187921282538}
# INFO | HPO epoch  50/80 | loss=0.4140 | val={'ROC-AUC': 0.7451317296678122, 'PRC-AUC': 0.6711064892832062}
# INFO | HPO epoch  55/80 | loss=0.4141 | val={'ROC-AUC': 0.761168384879725, 'PRC-AUC': 0.6622907113854213}
# INFO | HPO epoch  60/80 | loss=0.4282 | val={'ROC-AUC': 0.764413898434517, 'PRC-AUC': 0.6608580235044061}
# INFO | HPO epoch  65/80 | loss=0.3967 | val={'ROC-AUC': 0.7703321878579611, 'PRC-AUC': 0.6619660469605811}
# INFO | HPO epoch  70/80 | loss=0.3624 | val={'ROC-AUC': 0.7508591065292097, 'PRC-AUC': 0.6636806886593203}
# INFO | HPO epoch  75/80 | loss=0.3531 | val={'ROC-AUC': 0.7628865979381444, 'PRC-AUC': 0.6400476354780255}
# INFO | HPO epoch  80/80 | loss=0.3448 | val={'ROC-AUC': 0.7779686903398244, 'PRC-AUC': 0.6751736336164114}
# INFO | SchNet HPO — trial 13/20 finished | val=-0.777969 | best=-0.816151
# INFO | SchNet — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=1.1065 | val={'ROC-AUC': 0.6365024818633067, 'PRC-AUC': 0.5112891982637348}
# INFO | HPO epoch   5/80 | loss=0.6099 | val={'ROC-AUC': 0.6483390607101948, 'PRC-AUC': 0.5473753605211222}
# INFO | HPO epoch  10/80 | loss=0.5940 | val={'ROC-AUC': 0.6905307369224895, 'PRC-AUC': 0.6182147626777471}
# INFO | HPO epoch  15/80 | loss=0.5326 | val={'ROC-AUC': 0.684803360061092, 'PRC-AUC': 0.606337339990253}
# INFO | HPO epoch  20/80 | loss=0.5294 | val={'ROC-AUC': 0.7254677357770141, 'PRC-AUC': 0.6651369215472839}
# INFO | HPO epoch  25/80 | loss=0.5541 | val={'ROC-AUC': 0.7199312714776632, 'PRC-AUC': 0.6758786599937501}
# INFO | HPO epoch  30/80 | loss=0.4657 | val={'ROC-AUC': 0.7386407025582282, 'PRC-AUC': 0.6611139787048863}
# INFO | HPO epoch  35/80 | loss=0.4732 | val={'ROC-AUC': 0.7600229095074457, 'PRC-AUC': 0.7125236475717216}
# INFO | HPO epoch  40/80 | loss=0.4441 | val={'ROC-AUC': 0.7562046582665138, 'PRC-AUC': 0.695669092985376}
# INFO | HPO epoch  45/80 | loss=0.4164 | val={'ROC-AUC': 0.7756777395952653, 'PRC-AUC': 0.6935053943055542}
# INFO | HPO epoch  50/80 | loss=0.4078 | val={'ROC-AUC': 0.7768232149675449, 'PRC-AUC': 0.7103975988672201}
# INFO | HPO epoch  55/80 | loss=0.3953 | val={'ROC-AUC': 0.7661321114929363, 'PRC-AUC': 0.6712483180797055}
# INFO | HPO epoch  60/80 | loss=0.3670 | val={'ROC-AUC': 0.7959144711722032, 'PRC-AUC': 0.6997975932935647}
# INFO | HPO epoch  65/80 | loss=0.3859 | val={'ROC-AUC': 0.7777777777777778, 'PRC-AUC': 0.6982448522808677}
# INFO | HPO epoch  70/80 | loss=0.3525 | val={'ROC-AUC': 0.773577701412753, 'PRC-AUC': 0.6757664720939446}
# INFO | HPO epoch  75/80 | loss=0.3181 | val={'ROC-AUC': 0.7842688048873616, 'PRC-AUC': 0.6761810576740002}
# INFO | Early stop at epoch 75 (patience=15)
# INFO | SchNet HPO — trial 14/20 finished | val=-0.795914 | best=-0.816151
# INFO | SchNet — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=1.1069 | val={'ROC-AUC': 0.488545246277205, 'PRC-AUC': 0.38190885346997505}
# INFO | HPO epoch   5/80 | loss=0.6642 | val={'ROC-AUC': 0.6767850324551354, 'PRC-AUC': 0.5443239696640108}
# INFO | HPO epoch  10/80 | loss=0.5752 | val={'ROC-AUC': 0.7012218403970981, 'PRC-AUC': 0.5655834464575336}
# INFO | HPO epoch  15/80 | loss=0.5643 | val={'ROC-AUC': 0.6947308132875143, 'PRC-AUC': 0.5664052578205805}
# INFO | HPO epoch  20/80 | loss=0.5847 | val={'ROC-AUC': 0.709049255441008, 'PRC-AUC': 0.5866909816388526}
# INFO | HPO epoch  25/80 | loss=0.5024 | val={'ROC-AUC': 0.7279495990836197, 'PRC-AUC': 0.6176624725222959}
# INFO | HPO epoch  30/80 | loss=0.4852 | val={'ROC-AUC': 0.7218403970981291, 'PRC-AUC': 0.5966088734846512}
# INFO | HPO epoch  35/80 | loss=0.4427 | val={'ROC-AUC': 0.7258495609011073, 'PRC-AUC': 0.6062562745434729}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | SchNet HPO — trial 15/20 finished | val=-0.736159 | best=-0.816151
# INFO | SchNet — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=2.3879 | val={'ROC-AUC': 0.5836197021764031, 'PRC-AUC': 0.5231171691640925}
# INFO | HPO epoch   5/80 | loss=0.6466 | val={'ROC-AUC': 0.6710576555937381, 'PRC-AUC': 0.5526120898742063}
# INFO | HPO epoch  10/80 | loss=0.5620 | val={'ROC-AUC': 0.7155402825505918, 'PRC-AUC': 0.5923104693089531}
# INFO | HPO epoch  15/80 | loss=0.5071 | val={'ROC-AUC': 0.7189767086674304, 'PRC-AUC': 0.6457451961369184}
# INFO | HPO epoch  20/80 | loss=0.4926 | val={'ROC-AUC': 0.7369224894998091, 'PRC-AUC': 0.6323354679472395}
# INFO | HPO epoch  25/80 | loss=0.4430 | val={'ROC-AUC': 0.7707140129820541, 'PRC-AUC': 0.683553279839358}
# INFO | HPO epoch  30/80 | loss=0.4286 | val={'ROC-AUC': 0.7758686521573119, 'PRC-AUC': 0.6900260668586162}
# INFO | HPO epoch  35/80 | loss=0.3543 | val={'ROC-AUC': 0.7850324551355479, 'PRC-AUC': 0.6579087052853867}
# INFO | HPO epoch  40/80 | loss=0.3644 | val={'ROC-AUC': 0.7884688812523863, 'PRC-AUC': 0.6764468620079938}
# INFO | HPO epoch  45/80 | loss=0.2233 | val={'ROC-AUC': 0.8012600229095075, 'PRC-AUC': 0.6517917524561806}
# INFO | HPO epoch  50/80 | loss=0.2026 | val={'ROC-AUC': 0.7833142420771286, 'PRC-AUC': 0.660445051736436}
# INFO | HPO epoch  55/80 | loss=0.1595 | val={'ROC-AUC': 0.7619320351279114, 'PRC-AUC': 0.629351309813504}
# INFO | HPO epoch  60/80 | loss=0.0728 | val={'ROC-AUC': 0.7930507827415044, 'PRC-AUC': 0.6644213454483192}
# INFO | Early stop at epoch 61 (patience=15)
# INFO | SchNet HPO — trial 16/20 finished | val=-0.816151 | best=-0.816151
# INFO | SchNet — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=1.4810 | val={'ROC-AUC': 0.6563573883161513, 'PRC-AUC': 0.5286252208635853}
# INFO | HPO epoch   5/80 | loss=0.6032 | val={'ROC-AUC': 0.7059946544482627, 'PRC-AUC': 0.5997501785631797}
# INFO | HPO epoch  10/80 | loss=0.5485 | val={'ROC-AUC': 0.6987399770904926, 'PRC-AUC': 0.6194667028863975}
# INFO | HPO epoch  15/80 | loss=0.5538 | val={'ROC-AUC': 0.7420771286750669, 'PRC-AUC': 0.6643276005125779}
# INFO | HPO epoch  20/80 | loss=0.4896 | val={'ROC-AUC': 0.7485681557846507, 'PRC-AUC': 0.6654894031595633}
# INFO | HPO epoch  25/80 | loss=0.4344 | val={'ROC-AUC': 0.7812142038946163, 'PRC-AUC': 0.6784607635268446}
# INFO | HPO epoch  30/80 | loss=0.4282 | val={'ROC-AUC': 0.7466590301641849, 'PRC-AUC': 0.6367882382656191}
# INFO | HPO epoch  35/80 | loss=0.4916 | val={'ROC-AUC': 0.7867506681939672, 'PRC-AUC': 0.6922576227954791}
# INFO | HPO epoch  40/80 | loss=0.3354 | val={'ROC-AUC': 0.7982054219167621, 'PRC-AUC': 0.7283155947339349}
# INFO | HPO epoch  45/80 | loss=0.3092 | val={'ROC-AUC': 0.7815960290187094, 'PRC-AUC': 0.729372549459036}
# INFO | HPO epoch  50/80 | loss=0.1929 | val={'ROC-AUC': 0.7978235967926689, 'PRC-AUC': 0.6924993163976553}
# INFO | Early stop at epoch 52 (patience=15)
# INFO | SchNet HPO — trial 17/20 finished | val=-0.809087 | best=-0.816151
# INFO | SchNet — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=1.7301 | val={'ROC-AUC': 0.5286368843069873, 'PRC-AUC': 0.4490056619397657}
# INFO | HPO epoch   5/80 | loss=0.5839 | val={'ROC-AUC': 0.6449026345933563, 'PRC-AUC': 0.5173824590791802}
# INFO | HPO epoch  10/80 | loss=0.5098 | val={'ROC-AUC': 0.7073310423825887, 'PRC-AUC': 0.6431498587856425}
# INFO | HPO epoch  15/80 | loss=0.5019 | val={'ROC-AUC': 0.7544864452080947, 'PRC-AUC': 0.6943228720316783}
# INFO | HPO epoch  20/80 | loss=0.4841 | val={'ROC-AUC': 0.7495227185948835, 'PRC-AUC': 0.6487776808309076}
# INFO | HPO epoch  25/80 | loss=0.4249 | val={'ROC-AUC': 0.7508591065292096, 'PRC-AUC': 0.6490207870564627}
# INFO | HPO epoch  30/80 | loss=0.4031 | val={'ROC-AUC': 0.7691867124856816, 'PRC-AUC': 0.6821874254985044}
# INFO | HPO epoch  35/80 | loss=0.3262 | val={'ROC-AUC': 0.7523864070255822, 'PRC-AUC': 0.6323141127105074}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | SchNet HPO — trial 18/20 finished | val=-0.777778 | best=-0.816151
# INFO | SchNet — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=2.7244 | val={'ROC-AUC': 0.5173730431462391, 'PRC-AUC': 0.4567218639336086}
# INFO | HPO epoch   5/80 | loss=0.6165 | val={'ROC-AUC': 0.6867124856815578, 'PRC-AUC': 0.5788904592527466}
# INFO | HPO epoch  10/80 | loss=0.4754 | val={'ROC-AUC': 0.7035127911416572, 'PRC-AUC': 0.576300951091645}
# INFO | HPO epoch  15/80 | loss=0.4142 | val={'ROC-AUC': 0.7525773195876289, 'PRC-AUC': 0.5938111494348525}
# INFO | HPO epoch  20/80 | loss=0.2814 | val={'ROC-AUC': 0.7353951890034364, 'PRC-AUC': 0.5822090980795156}
# INFO | HPO epoch  25/80 | loss=0.1958 | val={'ROC-AUC': 0.7773959526536847, 'PRC-AUC': 0.6333214409230596}
# INFO | HPO epoch  30/80 | loss=0.1594 | val={'ROC-AUC': 0.7716685757922871, 'PRC-AUC': 0.6256242965743047}
# INFO | HPO epoch  35/80 | loss=0.0891 | val={'ROC-AUC': 0.7588774341351661, 'PRC-AUC': 0.6288347891210022}
# INFO | HPO epoch  40/80 | loss=0.0792 | val={'ROC-AUC': 0.7915234822451317, 'PRC-AUC': 0.6803001766803916}
# INFO | HPO epoch  45/80 | loss=0.0486 | val={'ROC-AUC': 0.7808323787705231, 'PRC-AUC': 0.624988158235251}
# INFO | HPO epoch  50/80 | loss=0.0847 | val={'ROC-AUC': 0.7583046964490263, 'PRC-AUC': 0.6385683899161896}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | SchNet HPO — trial 19/20 finished | val=-0.797633 | best=-0.816151
# INFO | SchNet — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=2.4440 | val={'ROC-AUC': 0.4938907980145094, 'PRC-AUC': 0.4372182738331362}
# INFO | HPO epoch   5/80 | loss=0.6336 | val={'ROC-AUC': 0.680221458571974, 'PRC-AUC': 0.5877362434420861}
# INFO | HPO epoch  10/80 | loss=0.6030 | val={'ROC-AUC': 0.713631156930126, 'PRC-AUC': 0.6215038300900125}
# INFO | HPO epoch  15/80 | loss=0.5342 | val={'ROC-AUC': 0.7315769377625049, 'PRC-AUC': 0.6431627509538219}
# INFO | HPO epoch  20/80 | loss=0.4819 | val={'ROC-AUC': 0.7495227185948835, 'PRC-AUC': 0.6653374640547839}
# INFO | HPO epoch  25/80 | loss=0.4869 | val={'ROC-AUC': 0.7884688812523865, 'PRC-AUC': 0.7112950078604299}
# INFO | HPO epoch  30/80 | loss=0.4463 | val={'ROC-AUC': 0.8022145857197405, 'PRC-AUC': 0.7129249965519732}
# INFO | HPO epoch  35/80 | loss=0.3735 | val={'ROC-AUC': 0.7884688812523863, 'PRC-AUC': 0.7017287522206161}
# INFO | HPO epoch  40/80 | loss=0.3418 | val={'ROC-AUC': 0.7546773577701413, 'PRC-AUC': 0.6504782744650675}
# INFO | HPO epoch  45/80 | loss=0.2536 | val={'ROC-AUC': 0.772241313478427, 'PRC-AUC': 0.6567355152777953}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | SchNet HPO — trial 20/20 finished | val=-0.802215 | best=-0.816151
# INFO | Epoch  10 | loss=0.5454 | val={'ROC-AUC': 0.705421916762123, 'PRC-AUC': 0.643706213040258}
# INFO | Epoch  20 | loss=0.4578 | val={'ROC-AUC': 0.7703321878579611, 'PRC-AUC': 0.706237775002327}
# INFO | Epoch  30 | loss=0.4325 | val={'ROC-AUC': 0.7705231004200077, 'PRC-AUC': 0.6580503264185843}
# INFO | Epoch  40 | loss=0.2875 | val={'ROC-AUC': 0.7884688812523863, 'PRC-AUC': 0.6899183768600605}
# INFO | Epoch  50 | loss=0.1879 | val={'ROC-AUC': 0.7922871324933181, 'PRC-AUC': 0.6766254723416213}
# INFO | Epoch  60 | loss=0.1270 | val={'ROC-AUC': 0.7920962199312716, 'PRC-AUC': 0.6815159155987183}
# INFO | Epoch  70 | loss=0.0938 | val={'ROC-AUC': 0.7878961435662467, 'PRC-AUC': 0.6798624315098077}
# INFO | Epoch  80 | loss=0.0820 | val={'ROC-AUC': 0.7856051928216877, 'PRC-AUC': 0.6851458119746999}
# INFO | Saved SchNet (3D coords) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.8193912885000912, 'PRC-AUC': 0.7348912299078638}

# %% [markdown]
# ### SMILES LSTM
# Canonical isomeric SMILES tokens.

# %%
MODEL_KEY = "SMILES LSTM"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_lstm(
        tr_ds, va_ds, TASK_TYPE, len(vocab), OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import SmilesLSTM, eval_lstm, TorchLoader, train_lstm
    model = SmilesLSTM(len(vocab), embed_dim=best["embed_dim"], hidden_dim=best["hidden_dim"],
                       n_layers=best["n_layers"], out_channels=OUT_CHANNELS, dropout=best["dropout"])
    train_lstm(model, tr_ds, va_ds, TASK_TYPE, epochs=LSTM_EPOCHS, lr=best["lr"],
               batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_lstm(model, TorchLoader(te_ds, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_lstm.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | LSTM — starting trial 1/20
# → SMILES LSTM (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.6855 | val={'ROC-AUC': 0.5744558991981672, 'PRC-AUC': 0.4193904425297467}
# INFO | HPO epoch   5/80 | loss=0.5721 | val={'ROC-AUC': 0.6983581519663994, 'PRC-AUC': 0.5785822021208207}
# INFO | HPO epoch  10/80 | loss=0.4983 | val={'ROC-AUC': 0.7016036655211914, 'PRC-AUC': 0.6065852194556673}
# INFO | HPO epoch  15/80 | loss=0.4041 | val={'ROC-AUC': 0.7462772050400917, 'PRC-AUC': 0.6246689201012414}
# INFO | HPO epoch  20/80 | loss=0.3479 | val={'ROC-AUC': 0.7586865215731194, 'PRC-AUC': 0.6427973790497901}
# INFO | HPO epoch  25/80 | loss=0.3062 | val={'ROC-AUC': 0.7655593738067965, 'PRC-AUC': 0.6250243311874034}
# INFO | HPO epoch  30/80 | loss=0.2457 | val={'ROC-AUC': 0.7808323787705231, 'PRC-AUC': 0.6711936560726992}
# INFO | HPO epoch  35/80 | loss=0.1977 | val={'ROC-AUC': 0.7821687667048492, 'PRC-AUC': 0.6505905733944068}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | LSTM HPO — trial 1/20 finished | val=-0.783314 | best=-0.783314
# INFO | LSTM — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=0.6883 | val={'ROC-AUC': 0.5775105001909125, 'PRC-AUC': 0.41334683100106584}
# INFO | HPO epoch   5/80 | loss=0.5858 | val={'ROC-AUC': 0.629438717067583, 'PRC-AUC': 0.5139542966582509}
# INFO | HPO epoch  10/80 | loss=0.4597 | val={'ROC-AUC': 0.7296678121420389, 'PRC-AUC': 0.6191430096511619}
# INFO | HPO epoch  15/80 | loss=0.3793 | val={'ROC-AUC': 0.753913707521955, 'PRC-AUC': 0.6085026984681005}
# INFO | HPO epoch  20/80 | loss=0.3304 | val={'ROC-AUC': 0.7707140129820542, 'PRC-AUC': 0.64226363992704}
# INFO | HPO epoch  25/80 | loss=0.2773 | val={'ROC-AUC': 0.7617411225658648, 'PRC-AUC': 0.620623689504941}
# INFO | HPO epoch  30/80 | loss=0.2216 | val={'ROC-AUC': 0.768041237113402, 'PRC-AUC': 0.6016539504420881}
# INFO | HPO epoch  35/80 | loss=0.2045 | val={'ROC-AUC': 0.7731958762886598, 'PRC-AUC': 0.6483741405975244}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | LSTM HPO — trial 2/20 finished | val=-0.786560 | best=-0.786560
# INFO | LSTM — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=0.6809 | val={'ROC-AUC': 0.5603283696067202, 'PRC-AUC': 0.41138110633539227}
# INFO | HPO epoch   5/80 | loss=0.5721 | val={'ROC-AUC': 0.6034746086292478, 'PRC-AUC': 0.5177552535435831}
# INFO | HPO epoch  10/80 | loss=0.5111 | val={'ROC-AUC': 0.6807941962581138, 'PRC-AUC': 0.5545333396541667}
# INFO | HPO epoch  15/80 | loss=0.4649 | val={'ROC-AUC': 0.7155402825505918, 'PRC-AUC': 0.5708263069872935}
# INFO | HPO epoch  20/80 | loss=0.3839 | val={'ROC-AUC': 0.6834669721267659, 'PRC-AUC': 0.5429083008875347}
# INFO | HPO epoch  25/80 | loss=0.3650 | val={'ROC-AUC': 0.7138220694921725, 'PRC-AUC': 0.5842118802225978}
# INFO | HPO epoch  30/80 | loss=0.2878 | val={'ROC-AUC': 0.7033218785796105, 'PRC-AUC': 0.6124914046086333}
# INFO | HPO epoch  35/80 | loss=0.3041 | val={'ROC-AUC': 0.7344406261932035, 'PRC-AUC': 0.6108965148372562}
# INFO | HPO epoch  40/80 | loss=0.2234 | val={'ROC-AUC': 0.7124856815578464, 'PRC-AUC': 0.5746356588076007}
# INFO | HPO epoch  45/80 | loss=0.1738 | val={'ROC-AUC': 0.7334860633829706, 'PRC-AUC': 0.6263991543909094}
# INFO | Early stop at epoch 46 (patience=15)
# INFO | LSTM HPO — trial 3/20 finished | val=-0.741886 | best=-0.786560
# INFO | LSTM — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=0.6912 | val={'ROC-AUC': 0.5738831615120275, 'PRC-AUC': 0.4161847967641883}
# INFO | HPO epoch   5/80 | loss=0.6317 | val={'ROC-AUC': 0.603856433753341, 'PRC-AUC': 0.5096449350847414}
# INFO | HPO epoch  10/80 | loss=0.5391 | val={'ROC-AUC': 0.6725849560901108, 'PRC-AUC': 0.5650675509581136}
# INFO | HPO epoch  15/80 | loss=0.4970 | val={'ROC-AUC': 0.6840397098129056, 'PRC-AUC': 0.5438277257026993}
# INFO | HPO epoch  20/80 | loss=0.4517 | val={'ROC-AUC': 0.7166857579228715, 'PRC-AUC': 0.5624432946386242}
# INFO | HPO epoch  25/80 | loss=0.4043 | val={'ROC-AUC': 0.728713249331806, 'PRC-AUC': 0.573989698455303}
# INFO | HPO epoch  30/80 | loss=0.3820 | val={'ROC-AUC': 0.7092401680030546, 'PRC-AUC': 0.5542444834225059}
# INFO | HPO epoch  35/80 | loss=0.3379 | val={'ROC-AUC': 0.7695685376097747, 'PRC-AUC': 0.6168227678234866}
# INFO | HPO epoch  40/80 | loss=0.3214 | val={'ROC-AUC': 0.7617411225658648, 'PRC-AUC': 0.5995748774214419}
# INFO | HPO epoch  45/80 | loss=0.2880 | val={'ROC-AUC': 0.7521954944635357, 'PRC-AUC': 0.6620188797101851}
# INFO | HPO epoch  50/80 | loss=0.2845 | val={'ROC-AUC': 0.766704849179076, 'PRC-AUC': 0.6271256636768958}
# INFO | HPO epoch  55/80 | loss=0.2729 | val={'ROC-AUC': 0.7705231004200077, 'PRC-AUC': 0.6986020036452258}
# INFO | HPO epoch  60/80 | loss=0.2329 | val={'ROC-AUC': 0.7728140511645666, 'PRC-AUC': 0.6928291853649875}
# INFO | HPO epoch  65/80 | loss=0.2148 | val={'ROC-AUC': 0.7665139366170294, 'PRC-AUC': 0.6772058041935658}
# INFO | HPO epoch  70/80 | loss=0.2113 | val={'ROC-AUC': 0.779495990836197, 'PRC-AUC': 0.6674000522956913}
# INFO | Early stop at epoch 74 (patience=15)
# INFO | LSTM HPO — trial 4/20 finished | val=-0.785223 | best=-0.786560
# INFO | LSTM — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=0.6899 | val={'ROC-AUC': 0.5588010691103474, 'PRC-AUC': 0.4153253892973604}
# INFO | HPO epoch   5/80 | loss=0.6430 | val={'ROC-AUC': 0.5987017945780833, 'PRC-AUC': 0.5061082486724962}
# INFO | HPO epoch  10/80 | loss=0.5295 | val={'ROC-AUC': 0.7061855670103092, 'PRC-AUC': 0.5847584181810069}
# INFO | HPO epoch  15/80 | loss=0.4874 | val={'ROC-AUC': 0.7325315005727376, 'PRC-AUC': 0.6319005390892364}
# INFO | HPO epoch  20/80 | loss=0.4530 | val={'ROC-AUC': 0.7544864452080947, 'PRC-AUC': 0.6727979741810193}
# INFO | HPO epoch  25/80 | loss=0.4197 | val={'ROC-AUC': 0.794578083237877, 'PRC-AUC': 0.7028440612174975}
# INFO | HPO epoch  30/80 | loss=0.3782 | val={'ROC-AUC': 0.7810232913325696, 'PRC-AUC': 0.6656194900032252}
# INFO | HPO epoch  35/80 | loss=0.3520 | val={'ROC-AUC': 0.8129056891943489, 'PRC-AUC': 0.7403469370971892}
# INFO | HPO epoch  40/80 | loss=0.3361 | val={'ROC-AUC': 0.7924780450553646, 'PRC-AUC': 0.697019314114362}
# INFO | HPO epoch  45/80 | loss=0.3144 | val={'ROC-AUC': 0.8239786177930508, 'PRC-AUC': 0.7496568506989999}
# INFO | HPO epoch  50/80 | loss=0.3189 | val={'ROC-AUC': 0.8291332569683085, 'PRC-AUC': 0.7481308076568389}
# INFO | HPO epoch  55/80 | loss=0.2836 | val={'ROC-AUC': 0.817487590683467, 'PRC-AUC': 0.7461096481097735}
# INFO | HPO epoch  60/80 | loss=0.2701 | val={'ROC-AUC': 0.8092783505154639, 'PRC-AUC': 0.7316772275110546}
# INFO | Early stop at epoch 64 (patience=15)
# INFO | LSTM HPO — trial 5/20 finished | val=-0.835052 | best=-0.835052
# INFO | LSTM — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=0.6861 | val={'ROC-AUC': 0.5788468881252387, 'PRC-AUC': 0.4386257099434345}
# INFO | HPO epoch   5/80 | loss=0.5979 | val={'ROC-AUC': 0.6502481863306606, 'PRC-AUC': 0.5277513228134552}
# INFO | HPO epoch  10/80 | loss=0.5218 | val={'ROC-AUC': 0.687094310805651, 'PRC-AUC': 0.5452290387732998}
# INFO | HPO epoch  15/80 | loss=0.4693 | val={'ROC-AUC': 0.6975945017182131, 'PRC-AUC': 0.5779523418626132}
# INFO | HPO epoch  20/80 | loss=0.4370 | val={'ROC-AUC': 0.7151584574264986, 'PRC-AUC': 0.583576376222763}
# INFO | HPO epoch  25/80 | loss=0.4165 | val={'ROC-AUC': 0.7359679266895762, 'PRC-AUC': 0.5750401015081575}
# INFO | HPO epoch  30/80 | loss=0.4047 | val={'ROC-AUC': 0.7485681557846506, 'PRC-AUC': 0.5638661747249938}
# INFO | HPO epoch  35/80 | loss=0.3863 | val={'ROC-AUC': 0.727758686521573, 'PRC-AUC': 0.598508781633312}
# INFO | HPO epoch  40/80 | loss=0.4001 | val={'ROC-AUC': 0.7254677357770142, 'PRC-AUC': 0.5737702604785256}
# INFO | HPO epoch  45/80 | loss=0.3608 | val={'ROC-AUC': 0.7046582665139366, 'PRC-AUC': 0.564068461803213}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | LSTM HPO — trial 6/20 finished | val=-0.767087 | best=-0.835052
# INFO | LSTM — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=0.6886 | val={'ROC-AUC': 0.5427644138984346, 'PRC-AUC': 0.38189599153022463}
# INFO | HPO epoch   5/80 | loss=0.5728 | val={'ROC-AUC': 0.5956471935853379, 'PRC-AUC': 0.47713458268473724}
# INFO | HPO epoch  10/80 | loss=0.4842 | val={'ROC-AUC': 0.7248949980908743, 'PRC-AUC': 0.5879490096716944}
# INFO | HPO epoch  15/80 | loss=0.3997 | val={'ROC-AUC': 0.7485681557846507, 'PRC-AUC': 0.5799563714791613}
# INFO | HPO epoch  20/80 | loss=0.3208 | val={'ROC-AUC': 0.7579228713249332, 'PRC-AUC': 0.6156619406083775}
# INFO | HPO epoch  25/80 | loss=0.2925 | val={'ROC-AUC': 0.7464681176021383, 'PRC-AUC': 0.562946611762327}
# INFO | HPO epoch  30/80 | loss=0.2436 | val={'ROC-AUC': 0.7413134784268804, 'PRC-AUC': 0.6020103105464898}
# INFO | HPO epoch  35/80 | loss=0.1857 | val={'ROC-AUC': 0.7546773577701412, 'PRC-AUC': 0.6094504671841056}
# INFO | Early stop at epoch 38 (patience=15)
# INFO | LSTM HPO — trial 7/20 finished | val=-0.785414 | best=-0.835052
# INFO | LSTM — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=0.6917 | val={'ROC-AUC': 0.5332187857961054, 'PRC-AUC': 0.3828688837424463}
# INFO | HPO epoch   5/80 | loss=0.6573 | val={'ROC-AUC': 0.5643375334096984, 'PRC-AUC': 0.4339033058225036}
# INFO | HPO epoch  10/80 | loss=0.5962 | val={'ROC-AUC': 0.6219931271477663, 'PRC-AUC': 0.5457067767247153}
# INFO | HPO epoch  15/80 | loss=0.5312 | val={'ROC-AUC': 0.6838487972508592, 'PRC-AUC': 0.56863713534625}
# INFO | HPO epoch  20/80 | loss=0.5357 | val={'ROC-AUC': 0.7430316914852997, 'PRC-AUC': 0.6368975665358106}
# INFO | HPO epoch  25/80 | loss=0.4855 | val={'ROC-AUC': 0.6882397861779306, 'PRC-AUC': 0.5455034108433908}
# INFO | HPO epoch  30/80 | loss=0.4519 | val={'ROC-AUC': 0.7096219931271478, 'PRC-AUC': 0.5580696469404486}
# INFO | HPO epoch  35/80 | loss=0.4116 | val={'ROC-AUC': 0.7107674684994272, 'PRC-AUC': 0.5637375871492367}
# INFO | Early stop at epoch 35 (patience=15)
# INFO | LSTM HPO — trial 8/20 finished | val=-0.743032 | best=-0.835052
# INFO | LSTM — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=0.6920 | val={'ROC-AUC': 0.5429553264604812, 'PRC-AUC': 0.3849014065187979}
# INFO | HPO epoch   5/80 | loss=0.6136 | val={'ROC-AUC': 0.6447117220313097, 'PRC-AUC': 0.5610928335145784}
# INFO | HPO epoch  10/80 | loss=0.5840 | val={'ROC-AUC': 0.6561664757541046, 'PRC-AUC': 0.5284314610129024}
# INFO | HPO epoch  15/80 | loss=0.4863 | val={'ROC-AUC': 0.7338678885070637, 'PRC-AUC': 0.6086564611722222}
# INFO | HPO epoch  20/80 | loss=0.4938 | val={'ROC-AUC': 0.7481863306605574, 'PRC-AUC': 0.6082722123772355}
# INFO | HPO epoch  25/80 | loss=0.4511 | val={'ROC-AUC': 0.7094310805651012, 'PRC-AUC': 0.5620839493011169}
# INFO | HPO epoch  30/80 | loss=0.4112 | val={'ROC-AUC': 0.718213058419244, 'PRC-AUC': 0.5570356192423003}
# INFO | HPO epoch  35/80 | loss=0.3557 | val={'ROC-AUC': 0.7825505918289424, 'PRC-AUC': 0.5877378422555503}
# INFO | HPO epoch  40/80 | loss=0.3117 | val={'ROC-AUC': 0.7857961053837342, 'PRC-AUC': 0.7100718917347281}
# INFO | HPO epoch  45/80 | loss=0.2609 | val={'ROC-AUC': 0.786368843069874, 'PRC-AUC': 0.664579405803452}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | LSTM HPO — trial 9/20 finished | val=-0.805842 | best=-0.835052
# INFO | LSTM — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=0.6905 | val={'ROC-AUC': 0.5647193585337915, 'PRC-AUC': 0.400329291003073}
# INFO | HPO epoch   5/80 | loss=0.5179 | val={'ROC-AUC': 0.680221458571974, 'PRC-AUC': 0.5413103016032214}
# INFO | HPO epoch  10/80 | loss=0.3939 | val={'ROC-AUC': 0.7678503245513555, 'PRC-AUC': 0.6282510024445356}
# INFO | HPO epoch  15/80 | loss=0.3112 | val={'ROC-AUC': 0.785032455135548, 'PRC-AUC': 0.6057462400879982}
# INFO | HPO epoch  20/80 | loss=0.2378 | val={'ROC-AUC': 0.7737686139747996, 'PRC-AUC': 0.666913270181696}
# INFO | HPO epoch  25/80 | loss=0.1683 | val={'ROC-AUC': 0.7878961435662466, 'PRC-AUC': 0.6671465072305606}
# INFO | HPO epoch  30/80 | loss=0.1211 | val={'ROC-AUC': 0.8004963726613211, 'PRC-AUC': 0.6963280784355218}
# INFO | HPO epoch  35/80 | loss=0.1073 | val={'ROC-AUC': 0.8024054982817869, 'PRC-AUC': 0.7151763128519314}
# INFO | HPO epoch  40/80 | loss=0.0885 | val={'ROC-AUC': 0.7934326078655976, 'PRC-AUC': 0.6993827382302121}
# INFO | HPO epoch  45/80 | loss=0.0627 | val={'ROC-AUC': 0.7888507063764796, 'PRC-AUC': 0.6658382194432654}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | LSTM HPO — trial 10/20 finished | val=-0.813097 | best=-0.835052
# INFO | LSTM — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=0.6894 | val={'ROC-AUC': 0.5364642993508973, 'PRC-AUC': 0.37680820157443673}
# INFO | HPO epoch   5/80 | loss=0.6445 | val={'ROC-AUC': 0.5994654448262696, 'PRC-AUC': 0.4813983410163838}
# INFO | HPO epoch  10/80 | loss=0.5597 | val={'ROC-AUC': 0.6588392516227568, 'PRC-AUC': 0.5339558872339129}
# INFO | HPO epoch  15/80 | loss=0.5149 | val={'ROC-AUC': 0.6676212294768995, 'PRC-AUC': 0.5721099528331837}
# INFO | HPO epoch  20/80 | loss=0.4879 | val={'ROC-AUC': 0.6846124474990455, 'PRC-AUC': 0.5642956898872312}
# INFO | HPO epoch  25/80 | loss=0.4722 | val={'ROC-AUC': 0.6937762504772814, 'PRC-AUC': 0.5464651074659205}
# INFO | HPO epoch  30/80 | loss=0.4673 | val={'ROC-AUC': 0.6958762886597938, 'PRC-AUC': 0.5266707282003544}
# INFO | HPO epoch  35/80 | loss=0.4401 | val={'ROC-AUC': 0.6441389843451699, 'PRC-AUC': 0.4696919589326113}
# INFO | HPO epoch  40/80 | loss=0.4397 | val={'ROC-AUC': 0.667430316914853, 'PRC-AUC': 0.4903828627599145}
# INFO | HPO epoch  45/80 | loss=0.4237 | val={'ROC-AUC': 0.7040855288277968, 'PRC-AUC': 0.5241216893969429}
# INFO | HPO epoch  50/80 | loss=0.3999 | val={'ROC-AUC': 0.7180221458571975, 'PRC-AUC': 0.5347770705451218}
# INFO | HPO epoch  55/80 | loss=0.3872 | val={'ROC-AUC': 0.7226040473463154, 'PRC-AUC': 0.5318173091416494}
# INFO | HPO epoch  60/80 | loss=0.3805 | val={'ROC-AUC': 0.7163039327987782, 'PRC-AUC': 0.5238783560619612}
# INFO | HPO epoch  65/80 | loss=0.3658 | val={'ROC-AUC': 0.7283314242077128, 'PRC-AUC': 0.5367771940505367}
# INFO | HPO epoch  70/80 | loss=0.3616 | val={'ROC-AUC': 0.7166857579228714, 'PRC-AUC': 0.5281869674984154}
# INFO | Early stop at epoch 72 (patience=15)
# INFO | LSTM HPO — trial 11/20 finished | val=-0.731959 | best=-0.835052
# INFO | LSTM — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=0.6917 | val={'ROC-AUC': 0.5225276823214968, 'PRC-AUC': 0.3702118963069967}
# INFO | HPO epoch   5/80 | loss=0.6539 | val={'ROC-AUC': 0.565864833906071, 'PRC-AUC': 0.4136571956651909}
# INFO | HPO epoch  10/80 | loss=0.5643 | val={'ROC-AUC': 0.653302787323406, 'PRC-AUC': 0.5456511267190711}
# INFO | HPO epoch  15/80 | loss=0.4788 | val={'ROC-AUC': 0.6655211912943871, 'PRC-AUC': 0.5420878555009048}
# INFO | HPO epoch  20/80 | loss=0.4420 | val={'ROC-AUC': 0.685757922871325, 'PRC-AUC': 0.49600285314700376}
# INFO | HPO epoch  25/80 | loss=0.4191 | val={'ROC-AUC': 0.7227949599083618, 'PRC-AUC': 0.6022658979471933}
# INFO | HPO epoch  30/80 | loss=0.3903 | val={'ROC-AUC': 0.710385643375334, 'PRC-AUC': 0.5674104163601046}
# INFO | HPO epoch  35/80 | loss=0.4014 | val={'ROC-AUC': 0.716876670484918, 'PRC-AUC': 0.5296354360786266}
# INFO | HPO epoch  40/80 | loss=0.3598 | val={'ROC-AUC': 0.7258495609011073, 'PRC-AUC': 0.5284413099032725}
# INFO | HPO epoch  45/80 | loss=0.3458 | val={'ROC-AUC': 0.7397861779305078, 'PRC-AUC': 0.5393385540801193}
# INFO | HPO epoch  50/80 | loss=0.3448 | val={'ROC-AUC': 0.7340588010691104, 'PRC-AUC': 0.5175484366901862}
# INFO | HPO epoch  55/80 | loss=0.3138 | val={'ROC-AUC': 0.7426498663612067, 'PRC-AUC': 0.5386391885821825}
# INFO | HPO epoch  60/80 | loss=0.3254 | val={'ROC-AUC': 0.7422680412371134, 'PRC-AUC': 0.5388188349025501}
# INFO | HPO epoch  65/80 | loss=0.2905 | val={'ROC-AUC': 0.7415043909889272, 'PRC-AUC': 0.5235975830866839}
# INFO | HPO epoch  70/80 | loss=0.3021 | val={'ROC-AUC': 0.7453226422298588, 'PRC-AUC': 0.5271306729224081}
# INFO | HPO epoch  75/80 | loss=0.2524 | val={'ROC-AUC': 0.7458953799159985, 'PRC-AUC': 0.532742015995066}
# INFO | HPO epoch  80/80 | loss=0.2460 | val={'ROC-AUC': 0.7439862542955327, 'PRC-AUC': 0.5336794004042368}
# INFO | LSTM HPO — trial 12/20 finished | val=-0.754677 | best=-0.835052
# INFO | LSTM — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=0.6876 | val={'ROC-AUC': 0.5431462390225277, 'PRC-AUC': 0.3904409524169375}
# INFO | HPO epoch   5/80 | loss=0.6007 | val={'ROC-AUC': 0.6687667048491791, 'PRC-AUC': 0.5575912405957606}
# INFO | HPO epoch  10/80 | loss=0.4629 | val={'ROC-AUC': 0.7254677357770142, 'PRC-AUC': 0.6505562641523632}
# INFO | HPO epoch  15/80 | loss=0.4055 | val={'ROC-AUC': 0.7439862542955327, 'PRC-AUC': 0.5695119259384476}
# INFO | HPO epoch  20/80 | loss=0.3563 | val={'ROC-AUC': 0.7569683085147002, 'PRC-AUC': 0.5840809390301119}
# INFO | HPO epoch  25/80 | loss=0.3262 | val={'ROC-AUC': 0.7655593738067965, 'PRC-AUC': 0.66473324970159}
# INFO | HPO epoch  30/80 | loss=0.2916 | val={'ROC-AUC': 0.7871324933180603, 'PRC-AUC': 0.708567534880302}
# INFO | HPO epoch  35/80 | loss=0.2768 | val={'ROC-AUC': 0.744749904543719, 'PRC-AUC': 0.6105507078153501}
# INFO | HPO epoch  40/80 | loss=0.2261 | val={'ROC-AUC': 0.7636502481863305, 'PRC-AUC': 0.654478938860496}
# INFO | HPO epoch  45/80 | loss=0.1768 | val={'ROC-AUC': 0.763459335624284, 'PRC-AUC': 0.6483512615888315}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | LSTM HPO — trial 13/20 finished | val=-0.787132 | best=-0.835052
# INFO | LSTM — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=0.6912 | val={'ROC-AUC': 0.5448644520809469, 'PRC-AUC': 0.39842092896481696}
# INFO | HPO epoch   5/80 | loss=0.6542 | val={'ROC-AUC': 0.5725467735777013, 'PRC-AUC': 0.4161873182612127}
# INFO | HPO epoch  10/80 | loss=0.5636 | val={'ROC-AUC': 0.6676212294768997, 'PRC-AUC': 0.5935773773890436}
# INFO | HPO epoch  15/80 | loss=0.4985 | val={'ROC-AUC': 0.7149675448644521, 'PRC-AUC': 0.6002624938059127}
# INFO | HPO epoch  20/80 | loss=0.4733 | val={'ROC-AUC': 0.7109583810614737, 'PRC-AUC': 0.55810444613214}
# INFO | HPO epoch  25/80 | loss=0.4533 | val={'ROC-AUC': 0.7445589919816724, 'PRC-AUC': 0.595126091698899}
# INFO | HPO epoch  30/80 | loss=0.4302 | val={'ROC-AUC': 0.7311951126384115, 'PRC-AUC': 0.5620209252601625}
# INFO | HPO epoch  35/80 | loss=0.3959 | val={'ROC-AUC': 0.7395952653684612, 'PRC-AUC': 0.5804495643552782}
# INFO | HPO epoch  40/80 | loss=0.3933 | val={'ROC-AUC': 0.7531500572737686, 'PRC-AUC': 0.6120231290168877}
# INFO | HPO epoch  45/80 | loss=0.3651 | val={'ROC-AUC': 0.7407407407407406, 'PRC-AUC': 0.573849402879062}
# INFO | HPO epoch  50/80 | loss=0.3416 | val={'ROC-AUC': 0.7457044673539519, 'PRC-AUC': 0.5829059855877515}
# INFO | Early stop at epoch 52 (patience=15)
# INFO | LSTM HPO — trial 14/20 finished | val=-0.756014 | best=-0.835052
# INFO | LSTM — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=0.6907 | val={'ROC-AUC': 0.5366552119129439, 'PRC-AUC': 0.38957213908168953}
# INFO | HPO epoch   5/80 | loss=0.6224 | val={'ROC-AUC': 0.6019473081328751, 'PRC-AUC': 0.5160411210223229}
# INFO | HPO epoch  10/80 | loss=0.5617 | val={'ROC-AUC': 0.6485299732722414, 'PRC-AUC': 0.5481771188284614}
# INFO | HPO epoch  15/80 | loss=0.4727 | val={'ROC-AUC': 0.6981672394043528, 'PRC-AUC': 0.5244263295546534}
# INFO | HPO epoch  20/80 | loss=0.4441 | val={'ROC-AUC': 0.7294768995799924, 'PRC-AUC': 0.55489421874997}
# INFO | HPO epoch  25/80 | loss=0.3936 | val={'ROC-AUC': 0.7386407025582284, 'PRC-AUC': 0.5605524980097003}
# INFO | HPO epoch  30/80 | loss=0.3790 | val={'ROC-AUC': 0.7325315005727377, 'PRC-AUC': 0.5711648679891362}
# INFO | HPO epoch  35/80 | loss=0.3513 | val={'ROC-AUC': 0.7476135929744177, 'PRC-AUC': 0.5874534209564536}
# INFO | HPO epoch  40/80 | loss=0.3412 | val={'ROC-AUC': 0.7592592592592593, 'PRC-AUC': 0.6061318915357587}
# INFO | HPO epoch  45/80 | loss=0.2766 | val={'ROC-AUC': 0.7579228713249332, 'PRC-AUC': 0.609634623352817}
# INFO | Early stop at epoch 46 (patience=15)
# INFO | LSTM HPO — trial 15/20 finished | val=-0.774532 | best=-0.835052
# INFO | LSTM — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=0.6898 | val={'ROC-AUC': 0.5580374188621612, 'PRC-AUC': 0.39927417937413023}
# INFO | HPO epoch   5/80 | loss=0.5684 | val={'ROC-AUC': 0.6685757922871325, 'PRC-AUC': 0.5598047368848267}
# INFO | HPO epoch  10/80 | loss=0.4832 | val={'ROC-AUC': 0.7323405880106911, 'PRC-AUC': 0.6145162413140636}
# INFO | HPO epoch  15/80 | loss=0.4269 | val={'ROC-AUC': 0.7609774723176785, 'PRC-AUC': 0.6644090128768422}
# INFO | HPO epoch  20/80 | loss=0.3968 | val={'ROC-AUC': 0.7489499809087438, 'PRC-AUC': 0.6517169594419617}
# INFO | HPO epoch  25/80 | loss=0.3686 | val={'ROC-AUC': 0.755250095456281, 'PRC-AUC': 0.5955674366634665}
# INFO | HPO epoch  30/80 | loss=0.2961 | val={'ROC-AUC': 0.7453226422298588, 'PRC-AUC': 0.5809749874144903}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | LSTM HPO — trial 16/20 finished | val=-0.760977 | best=-0.835052
# INFO | LSTM — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=0.6914 | val={'ROC-AUC': 0.5295914471172203, 'PRC-AUC': 0.38985976923951693}
# INFO | HPO epoch   5/80 | loss=0.6719 | val={'ROC-AUC': 0.5788468881252385, 'PRC-AUC': 0.4249362758823727}
# INFO | HPO epoch  10/80 | loss=0.6030 | val={'ROC-AUC': 0.6452844597174494, 'PRC-AUC': 0.5833273951082731}
# INFO | HPO epoch  15/80 | loss=0.5360 | val={'ROC-AUC': 0.6838487972508591, 'PRC-AUC': 0.601793151201194}
# INFO | HPO epoch  20/80 | loss=0.5164 | val={'ROC-AUC': 0.6725849560901106, 'PRC-AUC': 0.601871015776003}
# INFO | HPO epoch  25/80 | loss=0.4901 | val={'ROC-AUC': 0.6830851470026728, 'PRC-AUC': 0.5656865900412579}
# INFO | HPO epoch  30/80 | loss=0.4784 | val={'ROC-AUC': 0.7090492554410079, 'PRC-AUC': 0.6075404654842779}
# INFO | HPO epoch  35/80 | loss=0.4843 | val={'ROC-AUC': 0.6886216113020237, 'PRC-AUC': 0.5634848635937978}
# INFO | HPO epoch  40/80 | loss=0.4605 | val={'ROC-AUC': 0.7338678885070637, 'PRC-AUC': 0.608273308898925}
# INFO | HPO epoch  45/80 | loss=0.4421 | val={'ROC-AUC': 0.7132493318060329, 'PRC-AUC': 0.5704140595931093}
# INFO | HPO epoch  50/80 | loss=0.4456 | val={'ROC-AUC': 0.747040855288278, 'PRC-AUC': 0.645234281524353}
# INFO | HPO epoch  55/80 | loss=0.4266 | val={'ROC-AUC': 0.7418862161130202, 'PRC-AUC': 0.6251963207134136}
# INFO | Early stop at epoch 57 (patience=15)
# INFO | LSTM HPO — trial 17/20 finished | val=-0.754296 | best=-0.835052
# INFO | LSTM — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=0.6899 | val={'ROC-AUC': 0.5624284077892325, 'PRC-AUC': 0.40472403145986613}
# INFO | HPO epoch   5/80 | loss=0.5511 | val={'ROC-AUC': 0.7260404734631539, 'PRC-AUC': 0.5752600420035519}
# INFO | HPO epoch  10/80 | loss=0.4341 | val={'ROC-AUC': 0.7239404352806414, 'PRC-AUC': 0.5758719481619334}
# INFO | HPO epoch  15/80 | loss=0.3494 | val={'ROC-AUC': 0.7672775868652157, 'PRC-AUC': 0.5943099691034278}
# INFO | HPO epoch  20/80 | loss=0.2981 | val={'ROC-AUC': 0.7680412371134021, 'PRC-AUC': 0.6703827263625265}
# INFO | HPO epoch  25/80 | loss=0.2323 | val={'ROC-AUC': 0.7817869415807559, 'PRC-AUC': 0.6252477034960341}
# INFO | HPO epoch  30/80 | loss=0.2040 | val={'ROC-AUC': 0.7426498663612066, 'PRC-AUC': 0.6117282399198595}
# INFO | HPO epoch  35/80 | loss=0.1478 | val={'ROC-AUC': 0.7588774341351662, 'PRC-AUC': 0.6301948971024427}
# INFO | HPO epoch  40/80 | loss=0.0920 | val={'ROC-AUC': 0.7493318060328369, 'PRC-AUC': 0.6058855386589879}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | LSTM HPO — trial 18/20 finished | val=-0.781787 | best=-0.835052
# INFO | LSTM — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=0.6935 | val={'ROC-AUC': 0.546200840015273, 'PRC-AUC': 0.4086494268042163}
# INFO | HPO epoch   5/80 | loss=0.6815 | val={'ROC-AUC': 0.5496372661321115, 'PRC-AUC': 0.39120470990466893}
# INFO | HPO epoch  10/80 | loss=0.6116 | val={'ROC-AUC': 0.6168384879725087, 'PRC-AUC': 0.5467580362407524}
# INFO | HPO epoch  15/80 | loss=0.5611 | val={'ROC-AUC': 0.6649484536082474, 'PRC-AUC': 0.5664006037708604}
# INFO | HPO epoch  20/80 | loss=0.5303 | val={'ROC-AUC': 0.649102710958381, 'PRC-AUC': 0.580366325410834}
# INFO | HPO epoch  25/80 | loss=0.5213 | val={'ROC-AUC': 0.6945399007254678, 'PRC-AUC': 0.6212260900547105}
# INFO | HPO epoch  30/80 | loss=0.5054 | val={'ROC-AUC': 0.6710576555937381, 'PRC-AUC': 0.5770240782109667}
# INFO | HPO epoch  35/80 | loss=0.4855 | val={'ROC-AUC': 0.7101947308132875, 'PRC-AUC': 0.6282272163983563}
# INFO | HPO epoch  40/80 | loss=0.4661 | val={'ROC-AUC': 0.7346315387552502, 'PRC-AUC': 0.6646848446372101}
# INFO | HPO epoch  45/80 | loss=0.4575 | val={'ROC-AUC': 0.7646048109965636, 'PRC-AUC': 0.7034556242972807}
# INFO | HPO epoch  50/80 | loss=0.4387 | val={'ROC-AUC': 0.7525773195876289, 'PRC-AUC': 0.672569494588944}
# INFO | HPO epoch  55/80 | loss=0.4252 | val={'ROC-AUC': 0.7737686139747997, 'PRC-AUC': 0.6874668178890225}
# INFO | HPO epoch  60/80 | loss=0.4130 | val={'ROC-AUC': 0.7760595647193586, 'PRC-AUC': 0.7060162737668596}
# INFO | HPO epoch  65/80 | loss=0.4120 | val={'ROC-AUC': 0.8077510500190913, 'PRC-AUC': 0.7151086081651354}
# INFO | HPO epoch  70/80 | loss=0.3941 | val={'ROC-AUC': 0.793241695303551, 'PRC-AUC': 0.705668498040176}
# INFO | HPO epoch  75/80 | loss=0.3997 | val={'ROC-AUC': 0.7823596792668959, 'PRC-AUC': 0.70216436100551}
# INFO | HPO epoch  80/80 | loss=0.3775 | val={'ROC-AUC': 0.8003054600992745, 'PRC-AUC': 0.7206831233630641}
# INFO | LSTM HPO — trial 19/20 finished | val=-0.813860 | best=-0.835052
# INFO | LSTM — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=0.6925 | val={'ROC-AUC': 0.5313096601756396, 'PRC-AUC': 0.37893423364895645}
# INFO | HPO epoch   5/80 | loss=0.6817 | val={'ROC-AUC': 0.550782741504391, 'PRC-AUC': 0.39070228992766753}
# INFO | HPO epoch  10/80 | loss=0.6322 | val={'ROC-AUC': 0.6284841542573503, 'PRC-AUC': 0.4951760930455218}
# INFO | HPO epoch  15/80 | loss=0.5946 | val={'ROC-AUC': 0.6489117983963344, 'PRC-AUC': 0.5741390469601807}
# INFO | HPO epoch  20/80 | loss=0.5660 | val={'ROC-AUC': 0.6454753722794961, 'PRC-AUC': 0.5518727626148916}
# INFO | HPO epoch  25/80 | loss=0.5285 | val={'ROC-AUC': 0.7027491408934708, 'PRC-AUC': 0.5863678513170534}
# INFO | HPO epoch  30/80 | loss=0.4934 | val={'ROC-AUC': 0.7229858724704085, 'PRC-AUC': 0.6292401512205091}
# INFO | HPO epoch  35/80 | loss=0.4890 | val={'ROC-AUC': 0.7430316914852998, 'PRC-AUC': 0.6714892983193673}
# INFO | HPO epoch  40/80 | loss=0.4670 | val={'ROC-AUC': 0.7325315005727377, 'PRC-AUC': 0.6354983783226349}
# INFO | HPO epoch  45/80 | loss=0.4685 | val={'ROC-AUC': 0.7447499045437189, 'PRC-AUC': 0.6703973396961695}
# INFO | HPO epoch  50/80 | loss=0.4716 | val={'ROC-AUC': 0.7376861397479955, 'PRC-AUC': 0.6608168798110122}
# INFO | HPO epoch  55/80 | loss=0.4585 | val={'ROC-AUC': 0.7521954944635357, 'PRC-AUC': 0.6596948665162431}
# INFO | HPO epoch  60/80 | loss=0.4474 | val={'ROC-AUC': 0.7415043909889271, 'PRC-AUC': 0.6446351203190092}
# INFO | Early stop at epoch 61 (patience=15)
# INFO | LSTM HPO — trial 20/20 finished | val=-0.754677 | best=-0.835052
# INFO | Epoch  10 | loss=0.5719 | val={'ROC-AUC': 0.672012218403971, 'PRC-AUC': 0.5460693930208647}
# INFO | Epoch  20 | loss=0.4407 | val={'ROC-AUC': 0.7541046200840015, 'PRC-AUC': 0.6448009562430017}
# INFO | Epoch  30 | loss=0.3614 | val={'ROC-AUC': 0.7346315387552501, 'PRC-AUC': 0.597747537977982}
# INFO | Epoch  40 | loss=0.3170 | val={'ROC-AUC': 0.7487590683466973, 'PRC-AUC': 0.5996340136549302}
# INFO | Epoch  50 | loss=0.2772 | val={'ROC-AUC': 0.7615502100038183, 'PRC-AUC': 0.6050611760596757}
# INFO | Epoch  60 | loss=0.2584 | val={'ROC-AUC': 0.7304314623902253, 'PRC-AUC': 0.5411990118718797}
# INFO | Epoch  70 | loss=0.2388 | val={'ROC-AUC': 0.7395952653684612, 'PRC-AUC': 0.5956908100907509}
# INFO | Epoch  80 | loss=0.2273 | val={'ROC-AUC': 0.7447499045437189, 'PRC-AUC': 0.5602721103325444}
# INFO | Saved SMILES LSTM → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.778385274284673, 'PRC-AUC': 0.6872245660849652}

# %% [markdown]
# ### Finalize GPU + merge

# %%
finalize_dataset_results(DATASET_SLUG, PARTIAL_PATH, RESULTS_DIR, TASK_TYPE,
    plot_title=f"BACE – ROC-AUC by Model (higher is better) (GPU, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
cpu_partial = RESULTS_ROOT / "cpu" / f"{DATASET_SLUG}_partial.json"
if cpu_partial.exists():
    merge_combined_results(DATASET_SLUG, cpu_partial, PARTIAL_PATH, RESULTS_ROOT / "combined",
        TASK_TYPE, plot_title=f"BACE – ROC-AUC by Model (higher is better) (all models, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
else:
    print("Run CPU notebook first for combined results.")
# Out:
# === BACE Results (5/12 models) ===
#                             ROC-AUC          PRC-AUC
# Model
# GIN (2D)            0.9189 ± 0.0000  0.8244 ± 0.0000
# D-MPNN (2D)         0.8872 ± 0.0000  0.8124 ± 0.0000
# GIN (3D)            0.9032 ± 0.0000  0.8095 ± 0.0000
# SchNet (3D coords)  0.8194 ± 0.0000  0.7349 ± 0.0000
# SMILES LSTM         0.7784 ± 0.0000  0.6872 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/gpu/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/gpu/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/gpu/bace_partial.json
# === BACE Results (12/12 models) ===
#                                ROC-AUC          PRC-AUC
# Model
# Morgan + RF            0.8948 ± 0.0000  0.8371 ± 0.0000
# Morgan + SVM           0.8724 ± 0.0000  0.7885 ± 0.0000
# Morgan + XGBoost       0.9127 ± 0.0000  0.8583 ± 0.0000
# Descriptors + RF       0.8555 ± 0.0000  0.7525 ± 0.0000
# Descriptors + SVM      0.8298 ± 0.0000  0.7510 ± 0.0000
# Descriptors + XGBoost  0.8342 ± 0.0000  0.7274 ± 0.0000
# Combined + XGBoost     0.8506 ± 0.0000  0.7542 ± 0.0000
# GIN (2D)               0.9189 ± 0.0000  0.8244 ± 0.0000
# D-MPNN (2D)            0.8872 ± 0.0000  0.8124 ± 0.0000
# GIN (3D)               0.9032 ± 0.0000  0.8095 ± 0.0000
# SchNet (3D coords)     0.8194 ± 0.0000  0.7349 ± 0.0000
# SMILES LSTM            0.7784 ± 0.0000  0.6872 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/combined/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/combined/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_3/scaffold/combined/bace_partial.json
