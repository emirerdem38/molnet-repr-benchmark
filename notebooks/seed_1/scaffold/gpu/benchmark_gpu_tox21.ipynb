# %% [markdown]
# # Benchmark v5 — GPU — Tox21 — scaffold split, seed 1
#
# **Task:** 12 binary toxicity assays (multi-label)
# **Size:** ~7,831 molecules
# **Metric:** Mean ROC-AUC ↑
#
# **Scaffold split**, seed **1** — GIN, D-MPNN, SchNet, LSTM with Optuna HPO.
#
# Results go to `results/seed_1/scaffold/`.

# %%
# NOTE: autoreload is intentionally NOT enabled. With C-extension packages
# (numpy, torch, torch_geometric) `%autoreload 2` reloads them mid-run and
# corrupts their state (numpy RecursionError / torch_geometric circular
# import). If you edit the benchmark modules, restart the kernel instead.
import os
# Avoid XGBoost/OpenMP segfaults in Jupyter on macOS (OMP Error #179).
for _omp_var in (
    "OMP_NUM_THREADS",
    "OPENBLAS_NUM_THREADS",
    "MKL_NUM_THREADS",
    "VECLIB_MAXIMUM_THREADS",
    "NUMEXPR_NUM_THREADS",
):
    os.environ[_omp_var] = "1"

import sys
from pathlib import Path

ROOT = Path(".").resolve()
for _ in range(6):
    if (ROOT / "mol_repr_utils.py").exists():
        break
    ROOT = ROOT.parent
else:
    raise FileNotFoundError("Could not find benchmark_v5 root (mol_repr_utils.py)")
sys.path.insert(0, str(ROOT))

from mol_repr_utils import *
from split_utils import (
    get_or_create_splits, subset_array, subset_list, subset_graphs_by_valid_idx,
    check_split_proportions,
)
from conformer_generation import load_conformer_graphs
from hpo_utils import (
    hpo_tabular, hpo_gnn, hpo_schnet, hpo_lstm,
    save_hpo_params, hpo_params_path,
)
from hpo_config import SKLEARN_HPO_N_ITER

DATA_DIR = ROOT / "data"

DEVICE = get_device()
print(f"Benchmark v5 (GPU) code root: {ROOT}")
print(f"Device: {DEVICE}")
print("Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.")
# Out:
# INFO | Using device: cpu (request a GPU node on the cluster for large GNN/LSTM jobs)
# Benchmark v5 (GPU) code root: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5
# Device: cpu
# Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.

# %%
DATASET_SLUG = "tox21"
TASK_TYPE = "classification"
OUT_CHANNELS = 12
BATCH_SIZE = 128
GNN_EPOCHS = 80
LSTM_EPOCHS = 80
TOX21_TABULAR = True

HPO_EPOCHS = 80  # Optuna trial length; GNN_EPOCHS for final refit
HPO_N_TRIALS = 10
print(f"GPU HPO tier: large — {HPO_N_TRIALS} trials, {HPO_EPOCHS} epochs/trial, batch={BATCH_SIZE}")

SPLIT_MODE = "scaffold"   # "scaffold" or "random"
SPLIT_SEED = 1

RESULTS_ROOT = ROOT / "results" / f"seed_{SPLIT_SEED}" / SPLIT_MODE
RESULTS_DIR = RESULTS_ROOT / "gpu"
SPLITS_DIR = RESULTS_ROOT / "splits"
HPO_DIR = RESULTS_DIR / "hpo"
HISTORY_DIR = RESULTS_DIR / "histories"
for d in (RESULTS_DIR, SPLITS_DIR, HPO_DIR, HISTORY_DIR):
    d.mkdir(parents=True, exist_ok=True)
print(f"Results → {RESULTS_ROOT}")

PARTIAL_PATH = RESULTS_DIR / f"{DATASET_SLUG}_partial.json"
FRESH_RUN = False
HPO_N_ITER = SKLEARN_HPO_N_ITER

if FRESH_RUN:
    reset_dataset_run(
        DATASET_SLUG, RESULTS_DIR,
        results_root=RESULTS_ROOT, split_mode=SPLIT_MODE,
    )
    print("Fresh run — cleared partial results and splits.")

results = load_partial_results(PARTIAL_PATH)
if results:
    print(f"Resuming {len(results)} saved model(s): {', '.join(order_results(results).keys())}")
print(f"SPLIT_SEED={SPLIT_SEED}  mode={SPLIT_MODE}")
# Out:
# GPU HPO tier: large — 10 trials, 80 epochs/trial, batch=128
# Results → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold
# SPLIT_SEED=1  mode=scaffold

# %% [markdown]
# ### Load data

# %%
import numpy as np
import pandas as pd

df = pd.read_csv(DATA_DIR / "tox21.csv", na_values=["", " "])
smiles, y = preprocess_dataset(df, "tox21")
print(f"Molecules : {len(smiles)}")
print(f"Target shape: {y.shape}")
print(f"Missing fraction: {np.isnan(y).mean():.2%}")
smiles, y = filter_bonded_molecules(smiles, y)
print(f'After bond filter: {len(smiles)} molecules')
# Out:
# [14:51:44] WARNING: not removing hydrogen atom without neighbors
# [14:51:44] Explicit valence for atom # 8 Al, 6, is greater than permitted
# [14:51:44] Explicit valence for atom # 3 Al, 6, is greater than permitted
# [14:51:44] Explicit valence for atom # 4 Al, 6, is greater than permitted
# [14:51:45] Explicit valence for atom # 4 Al, 6, is greater than permitted
# [14:51:45] Explicit valence for atom # 9 Al, 6, is greater than permitted
# [14:51:45] Explicit valence for atom # 5 Al, 6, is greater than permitted
# [14:51:45] Explicit valence for atom # 16 Al, 6, is greater than permitted
# [14:51:46] Explicit valence for atom # 20 Al, 6, is greater than permitted
# INFO | [tox21] 7823 / 7831 valid molecules
# [14:51:46] WARNING: not removing hydrogen atom without neighbors
# Molecules : 7823
# Target shape: (7823, 12)
# Missing fraction: 17.06%
# [14:51:59] WARNING: not removing hydrogen atom without neighbors
# After bond filter: 7804 molecules

# %% [markdown]
# ### Representations & scaffold split

# %%
graphs2d_all = smiles_to_graphs(smiles, y)
graphs_dmpnn_all = smiles_to_dmpnn_graphs(smiles, y)
X_tok_all, vocab = tokenize_smiles(smiles)

graphs3d_all, valid_idx_3d, _ = load_conformer_graphs(
    DATASET_SLUG, data_dir=DATA_DIR, n_confs=25
)
graphs3d_all = ensure_atomic_numbers_list(graphs3d_all)
print(f"3D graphs loaded: {len(graphs3d_all)} / {len(smiles)} (valid_idx mapping)")

split_data = get_or_create_splits(
    smiles, RESULTS_ROOT, DATASET_SLUG,
    mode=SPLIT_MODE, seed=SPLIT_SEED, force=FRESH_RUN,
)
train_idx = split_data["train_idx"]
val_idx = split_data["val_idx"]
test_idx = split_data["test_idx"]
check_split_proportions(train_idx, val_idx, test_idx, raise_on_fail=True)
print(split_data["summary"])

tr2d = subset_list(graphs2d_all, train_idx)
va2d = subset_list(graphs2d_all, val_idx)
te2d = subset_list(graphs2d_all, test_idx)

tr_dmpnn = subset_list(graphs_dmpnn_all, train_idx)
va_dmpnn = subset_list(graphs_dmpnn_all, val_idx)
te_dmpnn = subset_list(graphs_dmpnn_all, test_idx)

tr3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, train_idx)
va3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, val_idx)
te3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, test_idx)

tr_ds = SMILESDataset(subset_array(X_tok_all, train_idx), subset_array(y, train_idx))
va_ds = SMILESDataset(subset_array(X_tok_all, val_idx), subset_array(y, val_idx))
te_ds = SMILESDataset(subset_array(X_tok_all, test_idx), subset_array(y, test_idx))
# Out:
# [14:52:02] WARNING: not removing hydrogen atom without neighbors
# [14:52:18] WARNING: not removing hydrogen atom without neighbors
# INFO | Loaded 7810 / 7823 graphs from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/tox21_conformers_n25.pkl  (n_confs=25)
# INFO | Loaded splits from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/splits/tox21_scaffold_splits.pkl
# WARNING | 11 molecules in split have no 3D conformer (e.g. idx [217, 3445, 4930, 7312, 304]); excluded from 3D train/val/test subsets
# WARNING | 1 molecules in split have no 3D conformer (e.g. idx [4863]); excluded from 3D train/val/test subsets
# WARNING | 1 molecules in split have no 3D conformer (e.g. idx [3241]); excluded from 3D train/val/test subsets
# 3D graphs loaded: 7810 / 7804 (valid_idx mapping)
# {'n_total': 7804, 'n_train': 6243, 'n_val': 780, 'n_test': 781, 'n_scaffolds_total': 2325, 'n_scaffolds_train': 764, 'n_scaffolds_val': 780, 'n_scaffolds_test': 781}

# %% [markdown]
# ### GIN (2D)

# %%
MODEL_KEY = "GIN (2D)"
tr = tr3d if "2D" == "3D" else tr2d
va = va3d if "2D" == "3D" else va2d
te = te3d if "2D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (2D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | GIN 2D — starting trial 1/10 (layers=3, hidden=192)
# → GIN (2D) (Optuna 10 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.3021 | val={'ROC-AUC': 0.6438790966716759, 'PRC-AUC': 0.24334817260896943}
# INFO | HPO epoch   5/80 | loss=0.2047 | val={'ROC-AUC': 0.7126896986443344, 'PRC-AUC': 0.26728815118104254}
# INFO | HPO epoch  10/80 | loss=0.1827 | val={'ROC-AUC': 0.7001383360999275, 'PRC-AUC': 0.29412956284028285}
# INFO | HPO epoch  15/80 | loss=0.1749 | val={'ROC-AUC': 0.7057044661310531, 'PRC-AUC': 0.3041000797758057}
# INFO | HPO epoch  20/80 | loss=0.1613 | val={'ROC-AUC': 0.7018813531156448, 'PRC-AUC': 0.2999783162818193}
# INFO | Early stop at epoch 20 (patience=15)
# INFO | GIN 2D HPO — trial 1/10 finished | val=-0.712690 | best=-0.712690
# INFO | GIN 2D — starting trial 2/10 (layers=5, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.3665 | val={'ROC-AUC': 0.5877187889896104, 'PRC-AUC': 0.1805289387225952}
# INFO | HPO epoch   5/80 | loss=0.2288 | val={'ROC-AUC': 0.6648119876560341, 'PRC-AUC': 0.2648123799909871}
# INFO | HPO epoch  10/80 | loss=0.2053 | val={'ROC-AUC': 0.6782391000065634, 'PRC-AUC': 0.2786460901591002}
# INFO | HPO epoch  15/80 | loss=0.1934 | val={'ROC-AUC': 0.6908207047180567, 'PRC-AUC': 0.287206904995945}
# INFO | HPO epoch  20/80 | loss=0.1850 | val={'ROC-AUC': 0.7081327950846493, 'PRC-AUC': 0.31179428998261266}
# INFO | HPO epoch  25/80 | loss=0.1789 | val={'ROC-AUC': 0.7100727007960567, 'PRC-AUC': 0.2967203288421926}
# INFO | HPO epoch  30/80 | loss=0.1745 | val={'ROC-AUC': 0.7115786962221787, 'PRC-AUC': 0.31995108170784764}
# INFO | HPO epoch  35/80 | loss=0.1681 | val={'ROC-AUC': 0.7136079347926763, 'PRC-AUC': 0.3151406504035265}
# INFO | HPO epoch  40/80 | loss=0.1635 | val={'ROC-AUC': 0.7108936428335988, 'PRC-AUC': 0.3140969301751469}
# INFO | HPO epoch  45/80 | loss=0.1566 | val={'ROC-AUC': 0.7159492079774017, 'PRC-AUC': 0.3162367253256572}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | GIN 2D HPO — trial 2/10 finished | val=-0.716834 | best=-0.716834
# INFO | GIN 2D — starting trial 3/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.2990 | val={'ROC-AUC': 0.6409493287300804, 'PRC-AUC': 0.23676007445684555}
# INFO | HPO epoch   5/80 | loss=0.2096 | val={'ROC-AUC': 0.670358785580062, 'PRC-AUC': 0.2781141076967933}
# INFO | HPO epoch  10/80 | loss=0.1931 | val={'ROC-AUC': 0.6636247699475221, 'PRC-AUC': 0.2764392106516943}
# INFO | HPO epoch  15/80 | loss=0.1850 | val={'ROC-AUC': 0.7023976201284339, 'PRC-AUC': 0.29351195234003835}
# INFO | HPO epoch  20/80 | loss=0.1772 | val={'ROC-AUC': 0.7020162766147364, 'PRC-AUC': 0.30410507966289657}
# INFO | HPO epoch  25/80 | loss=0.1735 | val={'ROC-AUC': 0.7084159064369632, 'PRC-AUC': 0.3138872326064679}
# INFO | HPO epoch  30/80 | loss=0.1671 | val={'ROC-AUC': 0.6938341942497058, 'PRC-AUC': 0.29688950874708153}
# INFO | HPO epoch  35/80 | loss=0.1670 | val={'ROC-AUC': 0.7182050528089708, 'PRC-AUC': 0.3013197770504677}
# INFO | HPO epoch  40/80 | loss=0.1603 | val={'ROC-AUC': 0.7143556565711502, 'PRC-AUC': 0.3145703617111561}
# INFO | HPO epoch  45/80 | loss=0.1566 | val={'ROC-AUC': 0.707939128653106, 'PRC-AUC': 0.3310325921607147}
# INFO | HPO epoch  50/80 | loss=0.1444 | val={'ROC-AUC': 0.717170534471656, 'PRC-AUC': 0.31221570460951564}
# INFO | HPO epoch  55/80 | loss=0.1434 | val={'ROC-AUC': 0.7233061060167431, 'PRC-AUC': 0.3279957521371905}
# INFO | HPO epoch  60/80 | loss=0.1439 | val={'ROC-AUC': 0.7242472763570315, 'PRC-AUC': 0.33221153358746275}
# INFO | HPO epoch  65/80 | loss=0.1400 | val={'ROC-AUC': 0.7180517935491507, 'PRC-AUC': 0.31186004289988817}
# INFO | HPO epoch  70/80 | loss=0.1382 | val={'ROC-AUC': 0.7178791168122846, 'PRC-AUC': 0.32086363916832045}
# INFO | HPO epoch  75/80 | loss=0.1366 | val={'ROC-AUC': 0.7246977776134141, 'PRC-AUC': 0.32269555837642644}
# INFO | HPO epoch  80/80 | loss=0.1279 | val={'ROC-AUC': 0.7250276397442872, 'PRC-AUC': 0.33939868492635056}
# INFO | GIN 2D HPO — trial 3/10 finished | val=-0.727249 | best=-0.727249
# INFO | GIN 2D — starting trial 4/10 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3059 | val={'ROC-AUC': 0.6284351666441156, 'PRC-AUC': 0.21726670400931794}
# INFO | HPO epoch   5/80 | loss=0.2072 | val={'ROC-AUC': 0.6983558218106403, 'PRC-AUC': 0.27281916343634516}
# INFO | HPO epoch  10/80 | loss=0.1888 | val={'ROC-AUC': 0.7073861727088313, 'PRC-AUC': 0.3021843315452575}
# INFO | HPO epoch  15/80 | loss=0.1766 | val={'ROC-AUC': 0.6915023449577323, 'PRC-AUC': 0.28581807291878714}
# INFO | HPO epoch  20/80 | loss=0.1712 | val={'ROC-AUC': 0.7031739454717706, 'PRC-AUC': 0.2849434538555531}
# INFO | HPO epoch  25/80 | loss=0.1671 | val={'ROC-AUC': 0.6836558884794837, 'PRC-AUC': 0.2881673732444659}
# INFO | HPO epoch  30/80 | loss=0.1530 | val={'ROC-AUC': 0.7085325361716114, 'PRC-AUC': 0.3100505007403784}
# INFO | HPO epoch  35/80 | loss=0.1503 | val={'ROC-AUC': 0.6963530798729157, 'PRC-AUC': 0.3060234257007772}
# INFO | HPO epoch  40/80 | loss=0.1411 | val={'ROC-AUC': 0.7128579846046167, 'PRC-AUC': 0.3057075021064239}
# INFO | HPO epoch  45/80 | loss=0.1409 | val={'ROC-AUC': 0.7169005541599517, 'PRC-AUC': 0.31868680673024447}
# INFO | HPO epoch  50/80 | loss=0.1386 | val={'ROC-AUC': 0.7128972050028302, 'PRC-AUC': 0.3113916626486131}
# INFO | HPO epoch  55/80 | loss=0.1353 | val={'ROC-AUC': 0.7108522314616286, 'PRC-AUC': 0.31480004668992717}
# INFO | HPO epoch  60/80 | loss=0.1342 | val={'ROC-AUC': 0.7212990530144346, 'PRC-AUC': 0.3175037044923402}
# INFO | HPO epoch  65/80 | loss=0.1320 | val={'ROC-AUC': 0.715106315348479, 'PRC-AUC': 0.3210056035714738}
# INFO | HPO epoch  70/80 | loss=0.1297 | val={'ROC-AUC': 0.7140412534168742, 'PRC-AUC': 0.31881706052763975}
# INFO | HPO epoch  75/80 | loss=0.1253 | val={'ROC-AUC': 0.7155562201881889, 'PRC-AUC': 0.32136895732948895}
# INFO | Early stop at epoch 75 (patience=15)
# INFO | GIN 2D HPO — trial 4/10 finished | val=-0.721299 | best=-0.727249
# INFO | GIN 2D — starting trial 5/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.3415 | val={'ROC-AUC': 0.6023373331236365, 'PRC-AUC': 0.17416142351854147}
# INFO | HPO epoch   5/80 | loss=0.2198 | val={'ROC-AUC': 0.6505440195707235, 'PRC-AUC': 0.24634538933827174}
# INFO | HPO epoch  10/80 | loss=0.2046 | val={'ROC-AUC': 0.6830372654603419, 'PRC-AUC': 0.26263521140531215}
# INFO | HPO epoch  15/80 | loss=0.1981 | val={'ROC-AUC': 0.6881381995648561, 'PRC-AUC': 0.28200907660342983}
# INFO | HPO epoch  20/80 | loss=0.1828 | val={'ROC-AUC': 0.7095897686505971, 'PRC-AUC': 0.29007547160956104}
# INFO | HPO epoch  25/80 | loss=0.1763 | val={'ROC-AUC': 0.7054949603899959, 'PRC-AUC': 0.2908182277789781}
# INFO | HPO epoch  30/80 | loss=0.1712 | val={'ROC-AUC': 0.6938131307295862, 'PRC-AUC': 0.2915604452471629}
# INFO | HPO epoch  35/80 | loss=0.1620 | val={'ROC-AUC': 0.7180068883894496, 'PRC-AUC': 0.3138030773211673}
# INFO | HPO epoch  40/80 | loss=0.1619 | val={'ROC-AUC': 0.701381682609623, 'PRC-AUC': 0.29980322172812296}
# INFO | HPO epoch  45/80 | loss=0.1580 | val={'ROC-AUC': 0.7107081725667649, 'PRC-AUC': 0.28891612358804075}
# INFO | HPO epoch  50/80 | loss=0.1495 | val={'ROC-AUC': 0.7144576503879718, 'PRC-AUC': 0.308535805073153}
# INFO | HPO epoch  55/80 | loss=0.1467 | val={'ROC-AUC': 0.7133198328909245, 'PRC-AUC': 0.30556106504866243}
# INFO | HPO epoch  60/80 | loss=0.1439 | val={'ROC-AUC': 0.7148250809185589, 'PRC-AUC': 0.31111614455773556}
# INFO | HPO epoch  65/80 | loss=0.1373 | val={'ROC-AUC': 0.721526605303032, 'PRC-AUC': 0.31520309348056746}
# INFO | HPO epoch  70/80 | loss=0.1370 | val={'ROC-AUC': 0.7184475960943834, 'PRC-AUC': 0.303342984471703}
# INFO | HPO epoch  75/80 | loss=0.1339 | val={'ROC-AUC': 0.716952110336599, 'PRC-AUC': 0.3135824374793977}
# INFO | HPO epoch  80/80 | loss=0.1288 | val={'ROC-AUC': 0.7221331106231562, 'PRC-AUC': 0.31023161615495143}
# INFO | GIN 2D HPO — trial 5/10 finished | val=-0.722133 | best=-0.727249
# INFO | GIN 2D — starting trial 6/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3117 | val={'ROC-AUC': 0.6497047360680458, 'PRC-AUC': 0.23517370243888522}
# INFO | HPO epoch   5/80 | loss=0.2055 | val={'ROC-AUC': 0.6685439212153762, 'PRC-AUC': 0.2903942948322671}
# INFO | HPO epoch  10/80 | loss=0.1885 | val={'ROC-AUC': 0.6812840048755168, 'PRC-AUC': 0.2683880647234999}
# INFO | HPO epoch  15/80 | loss=0.1790 | val={'ROC-AUC': 0.6949895413711311, 'PRC-AUC': 0.29515923524723153}
# INFO | HPO epoch  20/80 | loss=0.1685 | val={'ROC-AUC': 0.6885524318688784, 'PRC-AUC': 0.2990482853739701}
# INFO | HPO epoch  25/80 | loss=0.1628 | val={'ROC-AUC': 0.7055291091531264, 'PRC-AUC': 0.30448300137850953}
# INFO | HPO epoch  30/80 | loss=0.1495 | val={'ROC-AUC': 0.7084696493777859, 'PRC-AUC': 0.3090454258383167}
# INFO | HPO epoch  35/80 | loss=0.1429 | val={'ROC-AUC': 0.713141827564934, 'PRC-AUC': 0.3184983366308806}
# INFO | HPO epoch  40/80 | loss=0.1390 | val={'ROC-AUC': 0.7140901916952749, 'PRC-AUC': 0.32496326325785324}
# INFO | HPO epoch  45/80 | loss=0.1370 | val={'ROC-AUC': 0.7103610026793127, 'PRC-AUC': 0.31868864320309265}
# INFO | HPO epoch  50/80 | loss=0.1276 | val={'ROC-AUC': 0.7158212762971421, 'PRC-AUC': 0.31794176354488024}
# INFO | HPO epoch  55/80 | loss=0.1246 | val={'ROC-AUC': 0.7115548019462867, 'PRC-AUC': 0.3181061496764168}
# INFO | HPO epoch  60/80 | loss=0.1187 | val={'ROC-AUC': 0.7182356496861141, 'PRC-AUC': 0.32248767596810896}
# INFO | Early stop at epoch 61 (patience=15)
# INFO | GIN 2D HPO — trial 6/10 finished | val=-0.725425 | best=-0.727249
# INFO | GIN 2D — starting trial 7/10 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3386 | val={'ROC-AUC': 0.6404629557303263, 'PRC-AUC': 0.21475588204901533}
# INFO | HPO epoch   5/80 | loss=0.2089 | val={'ROC-AUC': 0.687183435472431, 'PRC-AUC': 0.26799729263991434}
# INFO | HPO epoch  10/80 | loss=0.1886 | val={'ROC-AUC': 0.6891988402109787, 'PRC-AUC': 0.28684058003602525}
# INFO | HPO epoch  15/80 | loss=0.1784 | val={'ROC-AUC': 0.6676926104462445, 'PRC-AUC': 0.28450713368975983}
# INFO | HPO epoch  20/80 | loss=0.1698 | val={'ROC-AUC': 0.6897480726105938, 'PRC-AUC': 0.26451962771455667}
# INFO | HPO epoch  25/80 | loss=0.1663 | val={'ROC-AUC': 0.6907786045374267, 'PRC-AUC': 0.28640492552025354}
# INFO | HPO epoch  30/80 | loss=0.1544 | val={'ROC-AUC': 0.6937966295256536, 'PRC-AUC': 0.3082940913828787}
# INFO | Early stop at epoch 31 (patience=15)
# INFO | GIN 2D HPO — trial 7/10 finished | val=-0.711969 | best=-0.727249
# INFO | GIN 2D — starting trial 8/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3441 | val={'ROC-AUC': 0.6147002332113162, 'PRC-AUC': 0.17783970410178904}
# INFO | HPO epoch   5/80 | loss=0.2206 | val={'ROC-AUC': 0.5778283012952334, 'PRC-AUC': 0.1807320023332133}
# INFO | HPO epoch  10/80 | loss=0.2137 | val={'ROC-AUC': 0.6521614439824386, 'PRC-AUC': 0.266615321380213}
# INFO | HPO epoch  15/80 | loss=0.2075 | val={'ROC-AUC': 0.6544458233760022, 'PRC-AUC': 0.2545083852018237}
# INFO | HPO epoch  20/80 | loss=0.1988 | val={'ROC-AUC': 0.6714767580440308, 'PRC-AUC': 0.2644004191330846}
# INFO | HPO epoch  25/80 | loss=0.1960 | val={'ROC-AUC': 0.6470563952377774, 'PRC-AUC': 0.25684990451802164}
# INFO | HPO epoch  30/80 | loss=0.1943 | val={'ROC-AUC': 0.6724770033666028, 'PRC-AUC': 0.283310130845092}
# INFO | HPO epoch  35/80 | loss=0.1921 | val={'ROC-AUC': 0.675038367500472, 'PRC-AUC': 0.28647342992676533}
# INFO | HPO epoch  40/80 | loss=0.1825 | val={'ROC-AUC': 0.6884864919448117, 'PRC-AUC': 0.28933814297674315}
# INFO | HPO epoch  45/80 | loss=0.1779 | val={'ROC-AUC': 0.6867104821464936, 'PRC-AUC': 0.28083993412167746}
# INFO | HPO epoch  50/80 | loss=0.1733 | val={'ROC-AUC': 0.6773457584553856, 'PRC-AUC': 0.26055287332230165}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | GIN 2D HPO — trial 8/10 finished | val=-0.703394 | best=-0.727249
# INFO | GIN 2D — starting trial 9/10 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.3447 | val={'ROC-AUC': 0.6405940187578331, 'PRC-AUC': 0.2084688693294975}
# INFO | HPO epoch   5/80 | loss=0.2022 | val={'ROC-AUC': 0.7029640576139125, 'PRC-AUC': 0.27974283056924976}
# INFO | HPO epoch  10/80 | loss=0.1823 | val={'ROC-AUC': 0.6630641987897584, 'PRC-AUC': 0.28348988636210914}
# INFO | HPO epoch  15/80 | loss=0.1736 | val={'ROC-AUC': 0.7000288092266834, 'PRC-AUC': 0.29685533694589644}
# INFO | HPO epoch  20/80 | loss=0.1631 | val={'ROC-AUC': 0.7049045875102186, 'PRC-AUC': 0.30061542055639573}
# INFO | HPO epoch  25/80 | loss=0.1581 | val={'ROC-AUC': 0.7090498437724956, 'PRC-AUC': 0.3109322755402712}
# INFO | HPO epoch  30/80 | loss=0.1424 | val={'ROC-AUC': 0.7046755507176998, 'PRC-AUC': 0.3048804517326827}
# INFO | Early stop at epoch 31 (patience=15)
# INFO | GIN 2D HPO — trial 9/10 finished | val=-0.716582 | best=-0.727249
# INFO | GIN 2D — starting trial 10/10 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.3192 | val={'ROC-AUC': 0.6518309121078959, 'PRC-AUC': 0.22304007309864304}
# INFO | HPO epoch   5/80 | loss=0.2002 | val={'ROC-AUC': 0.6731886405682563, 'PRC-AUC': 0.2581981452066742}
# INFO | HPO epoch  10/80 | loss=0.1836 | val={'ROC-AUC': 0.6920061580651139, 'PRC-AUC': 0.304998198429377}
# INFO | HPO epoch  15/80 | loss=0.1796 | val={'ROC-AUC': 0.6953160076030734, 'PRC-AUC': 0.30207310807413196}
# INFO | HPO epoch  20/80 | loss=0.1692 | val={'ROC-AUC': 0.6998493027769533, 'PRC-AUC': 0.3184861747289183}
# INFO | HPO epoch  25/80 | loss=0.1585 | val={'ROC-AUC': 0.7132645747106574, 'PRC-AUC': 0.3222205097516659}
# INFO | HPO epoch  30/80 | loss=0.1408 | val={'ROC-AUC': 0.7031853964069056, 'PRC-AUC': 0.31990032164018517}
# INFO | HPO epoch  35/80 | loss=0.1362 | val={'ROC-AUC': 0.7090923860881199, 'PRC-AUC': 0.31892900222521114}
# INFO | HPO epoch  40/80 | loss=0.1320 | val={'ROC-AUC': 0.7106065037535402, 'PRC-AUC': 0.3153802430235234}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | GIN 2D HPO — trial 10/10 finished | val=-0.728622 | best=-0.728622
# INFO | Epoch  10 | loss=0.1829 | val={'ROC-AUC': 0.673134968022775, 'PRC-AUC': 0.2767371552699723}
# INFO | Epoch  20 | loss=0.1637 | val={'ROC-AUC': 0.6946397508890542, 'PRC-AUC': 0.29558825134234346}
# INFO | Epoch  30 | loss=0.1405 | val={'ROC-AUC': 0.7167307539153925, 'PRC-AUC': 0.3297944851914039}
# INFO | Epoch  40 | loss=0.1250 | val={'ROC-AUC': 0.7119841634105272, 'PRC-AUC': 0.3124539761597387}
# INFO | Epoch  50 | loss=0.1150 | val={'ROC-AUC': 0.7131852902148182, 'PRC-AUC': 0.3266052394716025}
# INFO | Epoch  60 | loss=0.1026 | val={'ROC-AUC': 0.7142593762188314, 'PRC-AUC': 0.32695663109833023}
# INFO | Epoch  70 | loss=0.0944 | val={'ROC-AUC': 0.7162291736546464, 'PRC-AUC': 0.33915439125906804}
# INFO | Epoch  80 | loss=0.0917 | val={'ROC-AUC': 0.714113913710828, 'PRC-AUC': 0.33519605041311146}
# INFO | Saved GIN (2D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/tox21_partial.json
#    scaffold test: {'ROC-AUC': 0.7111850871453459, 'PRC-AUC': 0.2968075207548368}

# %% [markdown]
# ### D-MPNN (2D)
# Bond-centric directed MPNN (Yang et al. 2019).

# %%
MODEL_KEY = "D-MPNN (2D)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr_dmpnn, va_dmpnn, TASK_TYPE, "DMPNN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("DMPNN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr_dmpnn, va_dmpnn, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te_dmpnn, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_dmpnn.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | DMPNN 2D — starting trial 1/10 (layers=3, hidden=192)
# → D-MPNN (2D) (Optuna 10 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.3258 | val={'ROC-AUC': 0.5733516722589446, 'PRC-AUC': 0.15428792823658916}
# INFO | HPO epoch   5/80 | loss=0.2175 | val={'ROC-AUC': 0.6826333670268055, 'PRC-AUC': 0.24761374630829494}
# INFO | HPO epoch  10/80 | loss=0.1967 | val={'ROC-AUC': 0.699748658796511, 'PRC-AUC': 0.26313481510028774}
# INFO | HPO epoch  15/80 | loss=0.1870 | val={'ROC-AUC': 0.7065737301649815, 'PRC-AUC': 0.287575753686194}
# INFO | HPO epoch  20/80 | loss=0.1793 | val={'ROC-AUC': 0.7084115624853348, 'PRC-AUC': 0.30026979388193037}
# INFO | HPO epoch  25/80 | loss=0.1693 | val={'ROC-AUC': 0.7094273406181003, 'PRC-AUC': 0.30116456748123327}
# INFO | HPO epoch  30/80 | loss=0.1586 | val={'ROC-AUC': 0.7099492051770463, 'PRC-AUC': 0.3114191426655299}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | DMPNN 2D HPO — trial 1/10 finished | val=-0.716760 | best=-0.716760
# INFO | DMPNN 2D — starting trial 2/10 (layers=5, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.3883 | val={'ROC-AUC': 0.5360588287399309, 'PRC-AUC': 0.13795331581352574}
# INFO | HPO epoch   5/80 | loss=0.2672 | val={'ROC-AUC': 0.646189915469061, 'PRC-AUC': 0.20736008617676682}
# INFO | HPO epoch  10/80 | loss=0.2357 | val={'ROC-AUC': 0.6923404190494442, 'PRC-AUC': 0.23535281513134967}
# INFO | HPO epoch  15/80 | loss=0.2178 | val={'ROC-AUC': 0.7054081009094889, 'PRC-AUC': 0.24726342420049308}
# INFO | HPO epoch  20/80 | loss=0.2109 | val={'ROC-AUC': 0.7091281298958179, 'PRC-AUC': 0.2690112963214401}
# INFO | HPO epoch  25/80 | loss=0.2049 | val={'ROC-AUC': 0.7090771007319994, 'PRC-AUC': 0.26543157664949263}
# INFO | HPO epoch  30/80 | loss=0.2020 | val={'ROC-AUC': 0.7103734277198804, 'PRC-AUC': 0.2764119927453186}
# INFO | HPO epoch  35/80 | loss=0.1961 | val={'ROC-AUC': 0.7074016398266826, 'PRC-AUC': 0.26737338291510393}
# INFO | HPO epoch  40/80 | loss=0.1961 | val={'ROC-AUC': 0.7108558503466571, 'PRC-AUC': 0.2844493578934441}
# INFO | HPO epoch  45/80 | loss=0.1923 | val={'ROC-AUC': 0.7121469323638383, 'PRC-AUC': 0.2779335116489667}
# INFO | HPO epoch  50/80 | loss=0.1888 | val={'ROC-AUC': 0.7076056039918601, 'PRC-AUC': 0.28547625597737153}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | DMPNN 2D HPO — trial 2/10 finished | val=-0.717665 | best=-0.717665
# INFO | DMPNN 2D — starting trial 3/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3343 | val={'ROC-AUC': 0.58306582123973, 'PRC-AUC': 0.15856528614587778}
# INFO | HPO epoch   5/80 | loss=0.2240 | val={'ROC-AUC': 0.6845823636387417, 'PRC-AUC': 0.23672389828476945}
# INFO | HPO epoch  10/80 | loss=0.2017 | val={'ROC-AUC': 0.6994400063811931, 'PRC-AUC': 0.2751931423830069}
# INFO | HPO epoch  15/80 | loss=0.1915 | val={'ROC-AUC': 0.7111379704816474, 'PRC-AUC': 0.2976393132491758}
# INFO | HPO epoch  20/80 | loss=0.1832 | val={'ROC-AUC': 0.7100702970567774, 'PRC-AUC': 0.303788494574289}
# INFO | HPO epoch  25/80 | loss=0.1782 | val={'ROC-AUC': 0.717734807819446, 'PRC-AUC': 0.31083931103165074}
# INFO | HPO epoch  30/80 | loss=0.1704 | val={'ROC-AUC': 0.7053334883160272, 'PRC-AUC': 0.3067573193532694}
# INFO | HPO epoch  35/80 | loss=0.1659 | val={'ROC-AUC': 0.7175824482371217, 'PRC-AUC': 0.3193475215805179}
# INFO | HPO epoch  40/80 | loss=0.1643 | val={'ROC-AUC': 0.717424328119757, 'PRC-AUC': 0.32022466848126785}
# INFO | HPO epoch  45/80 | loss=0.1542 | val={'ROC-AUC': 0.715248148864997, 'PRC-AUC': 0.3140692897539081}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | DMPNN 2D HPO — trial 3/10 finished | val=-0.723896 | best=-0.723896
# INFO | DMPNN 2D — starting trial 4/10 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3289 | val={'ROC-AUC': 0.5729195874160445, 'PRC-AUC': 0.16016803002830166}
# INFO | HPO epoch   5/80 | loss=0.2219 | val={'ROC-AUC': 0.7010200445171667, 'PRC-AUC': 0.24870126351504687}
# INFO | HPO epoch  10/80 | loss=0.2010 | val={'ROC-AUC': 0.7137053148870364, 'PRC-AUC': 0.26644762727092347}
# INFO | HPO epoch  15/80 | loss=0.1954 | val={'ROC-AUC': 0.7183415842355684, 'PRC-AUC': 0.27460196440650914}
# INFO | HPO epoch  20/80 | loss=0.1827 | val={'ROC-AUC': 0.7125096863689487, 'PRC-AUC': 0.29490645536747323}
# INFO | HPO epoch  25/80 | loss=0.1763 | val={'ROC-AUC': 0.715392327900943, 'PRC-AUC': 0.2898687531487843}
# INFO | HPO epoch  30/80 | loss=0.1731 | val={'ROC-AUC': 0.7115764650831665, 'PRC-AUC': 0.2991701269260882}
# INFO | HPO epoch  35/80 | loss=0.1708 | val={'ROC-AUC': 0.7146636183854803, 'PRC-AUC': 0.29903292954135086}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | DMPNN 2D HPO — trial 4/10 finished | val=-0.721630 | best=-0.723896
# INFO | DMPNN 2D — starting trial 5/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.3393 | val={'ROC-AUC': 0.548741820447659, 'PRC-AUC': 0.1374217200518013}
# INFO | HPO epoch   5/80 | loss=0.2097 | val={'ROC-AUC': 0.6932557823720011, 'PRC-AUC': 0.24000385308322322}
# INFO | HPO epoch  10/80 | loss=0.1855 | val={'ROC-AUC': 0.7171709599467753, 'PRC-AUC': 0.3024547331542268}
# INFO | HPO epoch  15/80 | loss=0.1744 | val={'ROC-AUC': 0.7120448652552471, 'PRC-AUC': 0.3050355414663467}
# INFO | HPO epoch  20/80 | loss=0.1620 | val={'ROC-AUC': 0.7034214726942464, 'PRC-AUC': 0.29594802696100536}
# INFO | HPO epoch  25/80 | loss=0.1556 | val={'ROC-AUC': 0.7094341734706703, 'PRC-AUC': 0.3172849512661244}
# INFO | HPO epoch  30/80 | loss=0.1444 | val={'ROC-AUC': 0.7234067413634065, 'PRC-AUC': 0.33311261348568993}
# INFO | Early stop at epoch 33 (patience=15)
# INFO | DMPNN 2D HPO — trial 5/10 finished | val=-0.727022 | best=-0.727022
# INFO | DMPNN 2D — starting trial 6/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3386 | val={'ROC-AUC': 0.5650282414463268, 'PRC-AUC': 0.14745486188791768}
# INFO | HPO epoch   5/80 | loss=0.2129 | val={'ROC-AUC': 0.6993241519275304, 'PRC-AUC': 0.2532201167693073}
# INFO | HPO epoch  10/80 | loss=0.1973 | val={'ROC-AUC': 0.7046610305630491, 'PRC-AUC': 0.2738512700650365}
# INFO | HPO epoch  15/80 | loss=0.1827 | val={'ROC-AUC': 0.7137778265796683, 'PRC-AUC': 0.2973041093694785}
# INFO | HPO epoch  20/80 | loss=0.1731 | val={'ROC-AUC': 0.7132245521267753, 'PRC-AUC': 0.29937106669811764}
# INFO | HPO epoch  25/80 | loss=0.1705 | val={'ROC-AUC': 0.7232293943167583, 'PRC-AUC': 0.304762836855115}
# INFO | HPO epoch  30/80 | loss=0.1592 | val={'ROC-AUC': 0.7250867167005461, 'PRC-AUC': 0.31649279559905874}
# INFO | HPO epoch  35/80 | loss=0.1561 | val={'ROC-AUC': 0.7276777279301325, 'PRC-AUC': 0.3190530820385528}
# INFO | HPO epoch  40/80 | loss=0.1512 | val={'ROC-AUC': 0.723595060721753, 'PRC-AUC': 0.30990427516639346}
# INFO | HPO epoch  45/80 | loss=0.1512 | val={'ROC-AUC': 0.728805465796619, 'PRC-AUC': 0.31915025772396083}
# INFO | HPO epoch  50/80 | loss=0.1474 | val={'ROC-AUC': 0.7266739541949607, 'PRC-AUC': 0.3151160715351006}
# INFO | HPO epoch  55/80 | loss=0.1445 | val={'ROC-AUC': 0.7258631998420442, 'PRC-AUC': 0.31392106487942756}
# INFO | Early stop at epoch 58 (patience=15)
# INFO | DMPNN 2D HPO — trial 6/10 finished | val=-0.729742 | best=-0.729742
# INFO | DMPNN 2D — starting trial 7/10 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3390 | val={'ROC-AUC': 0.5538845953956367, 'PRC-AUC': 0.14005373655996445}
# INFO | HPO epoch   5/80 | loss=0.2185 | val={'ROC-AUC': 0.6885594438216817, 'PRC-AUC': 0.23844678413852693}
# INFO | HPO epoch  10/80 | loss=0.2012 | val={'ROC-AUC': 0.7013922627032173, 'PRC-AUC': 0.2605404705166073}
# INFO | HPO epoch  15/80 | loss=0.1902 | val={'ROC-AUC': 0.7119967627049233, 'PRC-AUC': 0.2790724823382323}
# INFO | HPO epoch  20/80 | loss=0.1850 | val={'ROC-AUC': 0.7159357300040434, 'PRC-AUC': 0.2995978576703606}
# INFO | HPO epoch  25/80 | loss=0.1752 | val={'ROC-AUC': 0.7234534692143638, 'PRC-AUC': 0.294633763376038}
# INFO | HPO epoch  30/80 | loss=0.1711 | val={'ROC-AUC': 0.7146690700502408, 'PRC-AUC': 0.31051811586650907}
# INFO | HPO epoch  35/80 | loss=0.1641 | val={'ROC-AUC': 0.7157892207975696, 'PRC-AUC': 0.312530712363472}
# INFO | HPO epoch  40/80 | loss=0.1667 | val={'ROC-AUC': 0.724051828589035, 'PRC-AUC': 0.3220196802928961}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | DMPNN 2D HPO — trial 7/10 finished | val=-0.731241 | best=-0.731241
# INFO | DMPNN 2D — starting trial 8/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3183 | val={'ROC-AUC': 0.579967699568057, 'PRC-AUC': 0.1692976383259228}
# INFO | HPO epoch   5/80 | loss=0.2197 | val={'ROC-AUC': 0.6829965781373106, 'PRC-AUC': 0.24052743323555306}
# INFO | HPO epoch  10/80 | loss=0.2071 | val={'ROC-AUC': 0.6937081474926406, 'PRC-AUC': 0.26147794577828837}
# INFO | HPO epoch  15/80 | loss=0.1968 | val={'ROC-AUC': 0.7004689970034498, 'PRC-AUC': 0.27154218556666126}
# INFO | HPO epoch  20/80 | loss=0.1958 | val={'ROC-AUC': 0.7048925775866418, 'PRC-AUC': 0.2735631350841025}
# INFO | HPO epoch  25/80 | loss=0.1868 | val={'ROC-AUC': 0.7094239460197694, 'PRC-AUC': 0.2986430884159469}
# INFO | HPO epoch  30/80 | loss=0.1841 | val={'ROC-AUC': 0.7146179192793128, 'PRC-AUC': 0.2920516342901042}
# INFO | HPO epoch  35/80 | loss=0.1825 | val={'ROC-AUC': 0.7151573686524649, 'PRC-AUC': 0.29392782452706984}
# INFO | HPO epoch  40/80 | loss=0.1794 | val={'ROC-AUC': 0.7187874857536029, 'PRC-AUC': 0.30731062466133946}
# INFO | HPO epoch  45/80 | loss=0.1782 | val={'ROC-AUC': 0.7080871033764606, 'PRC-AUC': 0.2946852843395371}
# INFO | HPO epoch  50/80 | loss=0.1719 | val={'ROC-AUC': 0.7112114344564485, 'PRC-AUC': 0.3066524721014095}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | DMPNN 2D HPO — trial 8/10 finished | val=-0.725819 | best=-0.731241
# INFO | DMPNN 2D — starting trial 9/10 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.3661 | val={'ROC-AUC': 0.557317937897405, 'PRC-AUC': 0.13743456051291456}
# INFO | HPO epoch   5/80 | loss=0.2360 | val={'ROC-AUC': 0.6719144888572425, 'PRC-AUC': 0.22517461084529514}
# INFO | HPO epoch  10/80 | loss=0.2060 | val={'ROC-AUC': 0.6933085813587571, 'PRC-AUC': 0.2454522555038928}
# INFO | HPO epoch  15/80 | loss=0.2033 | val={'ROC-AUC': 0.6850536796254151, 'PRC-AUC': 0.2638425485873234}
# INFO | HPO epoch  20/80 | loss=0.1905 | val={'ROC-AUC': 0.6978672755380737, 'PRC-AUC': 0.2683969197917678}
# INFO | HPO epoch  25/80 | loss=0.1848 | val={'ROC-AUC': 0.7133921562582054, 'PRC-AUC': 0.2819682561283188}
# INFO | HPO epoch  30/80 | loss=0.1808 | val={'ROC-AUC': 0.7120329103788222, 'PRC-AUC': 0.2911204095581105}
# INFO | HPO epoch  35/80 | loss=0.1773 | val={'ROC-AUC': 0.7137274943802794, 'PRC-AUC': 0.299508127158436}
# INFO | HPO epoch  40/80 | loss=0.1707 | val={'ROC-AUC': 0.7110560559150589, 'PRC-AUC': 0.2975438110774558}
# INFO | Early stop at epoch 41 (patience=15)
# INFO | DMPNN 2D HPO — trial 9/10 finished | val=-0.716267 | best=-0.731241
# INFO | DMPNN 2D — starting trial 10/10 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.3171 | val={'ROC-AUC': 0.5804789715643798, 'PRC-AUC': 0.164413755024228}
# INFO | HPO epoch   5/80 | loss=0.2154 | val={'ROC-AUC': 0.714158705111676, 'PRC-AUC': 0.25637408222970653}
# INFO | HPO epoch  10/80 | loss=0.1939 | val={'ROC-AUC': 0.7100241281114369, 'PRC-AUC': 0.28927234128290674}
# INFO | HPO epoch  15/80 | loss=0.1850 | val={'ROC-AUC': 0.7184798949903506, 'PRC-AUC': 0.30210091717462456}
# INFO | HPO epoch  20/80 | loss=0.1729 | val={'ROC-AUC': 0.717131148072721, 'PRC-AUC': 0.3041556115428868}
# INFO | HPO epoch  25/80 | loss=0.1666 | val={'ROC-AUC': 0.7162474551028025, 'PRC-AUC': 0.3116758368358345}
# INFO | HPO epoch  30/80 | loss=0.1584 | val={'ROC-AUC': 0.7147183703731145, 'PRC-AUC': 0.32151445265434314}
# INFO | Early stop at epoch 31 (patience=15)
# INFO | DMPNN 2D HPO — trial 10/10 finished | val=-0.723801 | best=-0.731241
# INFO | Epoch  10 | loss=0.1991 | val={'ROC-AUC': 0.7141247782442015, 'PRC-AUC': 0.27088778118487195}
# INFO | Epoch  20 | loss=0.1839 | val={'ROC-AUC': 0.7052283480470267, 'PRC-AUC': 0.28927532415142126}
# INFO | Epoch  30 | loss=0.1719 | val={'ROC-AUC': 0.7080547648088679, 'PRC-AUC': 0.3008309284949963}
# INFO | Epoch  40 | loss=0.1626 | val={'ROC-AUC': 0.7101570064173969, 'PRC-AUC': 0.30546183953517}
# INFO | Epoch  50 | loss=0.1595 | val={'ROC-AUC': 0.7094292258361925, 'PRC-AUC': 0.30528205436285477}
# INFO | Epoch  60 | loss=0.1568 | val={'ROC-AUC': 0.7077280596841179, 'PRC-AUC': 0.29890498371675345}
# INFO | Epoch  70 | loss=0.1557 | val={'ROC-AUC': 0.7083634524168158, 'PRC-AUC': 0.2993474063639973}
# INFO | Epoch  80 | loss=0.1571 | val={'ROC-AUC': 0.7072172567376378, 'PRC-AUC': 0.29945065526473263}
# INFO | Saved D-MPNN (2D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/tox21_partial.json
#    scaffold test: {'ROC-AUC': 0.7222150255792359, 'PRC-AUC': 0.3209916551103838}

# %% [markdown]
# ### GIN (3D)

# %%
MODEL_KEY = "GIN (3D)"
tr = tr3d if "3D" == "3D" else tr2d
va = va3d if "3D" == "3D" else va2d
te = te3d if "3D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "3D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "3D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (3D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | GIN 3D — starting trial 1/10 (layers=3, hidden=192)
# → GIN (3D) (Optuna 10 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.3733 | val={'ROC-AUC': 0.6078145960314494, 'PRC-AUC': 0.1895479590032493}
# INFO | HPO epoch   5/80 | loss=0.2212 | val={'ROC-AUC': 0.7653302061665674, 'PRC-AUC': 0.3219565829490321}
# INFO | HPO epoch  10/80 | loss=0.2095 | val={'ROC-AUC': 0.685397055037294, 'PRC-AUC': 0.29917135685014146}
# INFO | HPO epoch  15/80 | loss=0.1996 | val={'ROC-AUC': 0.7562301746790729, 'PRC-AUC': 0.36093538916387363}
# INFO | HPO epoch  20/80 | loss=0.1873 | val={'ROC-AUC': 0.7957658859314845, 'PRC-AUC': 0.4097718926691995}
# INFO | HPO epoch  25/80 | loss=0.1839 | val={'ROC-AUC': 0.7406922191800277, 'PRC-AUC': 0.35345953498940236}
# INFO | HPO epoch  30/80 | loss=0.1754 | val={'ROC-AUC': 0.7682829217747545, 'PRC-AUC': 0.382699111335671}
# INFO | HPO epoch  35/80 | loss=0.1598 | val={'ROC-AUC': 0.7438629426150083, 'PRC-AUC': 0.37267026023549416}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | GIN 3D HPO — trial 1/10 finished | val=-0.804219 | best=-0.804219
# INFO | GIN 3D — starting trial 2/10 (layers=5, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.3918 | val={'ROC-AUC': 0.5381306394503563, 'PRC-AUC': 0.14820653698071584}
# INFO | HPO epoch   5/80 | loss=0.2392 | val={'ROC-AUC': 0.7129717162391915, 'PRC-AUC': 0.28633498666313745}
# INFO | HPO epoch  10/80 | loss=0.2184 | val={'ROC-AUC': 0.7705862387177261, 'PRC-AUC': 0.34837387462438946}
# INFO | HPO epoch  15/80 | loss=0.2064 | val={'ROC-AUC': 0.7815831454534492, 'PRC-AUC': 0.38089407038521267}
# INFO | HPO epoch  20/80 | loss=0.1995 | val={'ROC-AUC': 0.7865623764855307, 'PRC-AUC': 0.39746452710887575}
# INFO | HPO epoch  25/80 | loss=0.1912 | val={'ROC-AUC': 0.7706982972912417, 'PRC-AUC': 0.3899014304158543}
# INFO | HPO epoch  30/80 | loss=0.1861 | val={'ROC-AUC': 0.7723658831773941, 'PRC-AUC': 0.38881765518190187}
# INFO | HPO epoch  35/80 | loss=0.1809 | val={'ROC-AUC': 0.7947849928300831, 'PRC-AUC': 0.4223690036584265}
# INFO | HPO epoch  40/80 | loss=0.1780 | val={'ROC-AUC': 0.7976531185670571, 'PRC-AUC': 0.409242663332128}
# INFO | HPO epoch  45/80 | loss=0.1741 | val={'ROC-AUC': 0.8035037463078738, 'PRC-AUC': 0.43325182649437294}
# INFO | HPO epoch  50/80 | loss=0.1742 | val={'ROC-AUC': 0.7940650238839364, 'PRC-AUC': 0.41133904189658294}
# INFO | HPO epoch  55/80 | loss=0.1699 | val={'ROC-AUC': 0.7895894063320862, 'PRC-AUC': 0.4096773525916797}
# INFO | HPO epoch  60/80 | loss=0.1706 | val={'ROC-AUC': 0.8043590771600023, 'PRC-AUC': 0.4269535633825632}
# INFO | HPO epoch  65/80 | loss=0.1672 | val={'ROC-AUC': 0.8039170785690173, 'PRC-AUC': 0.41147132307076345}
# INFO | HPO epoch  70/80 | loss=0.1656 | val={'ROC-AUC': 0.8050459509104698, 'PRC-AUC': 0.4270434744205358}
# INFO | HPO epoch  75/80 | loss=0.1625 | val={'ROC-AUC': 0.8067298819038294, 'PRC-AUC': 0.42729380283577617}
# INFO | Early stop at epoch 76 (patience=15)
# INFO | GIN 3D HPO — trial 2/10 finished | val=-0.821136 | best=-0.821136
# INFO | GIN 3D — starting trial 3/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3193 | val={'ROC-AUC': 0.6196067824762646, 'PRC-AUC': 0.1830768234187442}
# INFO | HPO epoch   5/80 | loss=0.2270 | val={'ROC-AUC': 0.7418249555329727, 'PRC-AUC': 0.30783375057130197}
# INFO | HPO epoch  10/80 | loss=0.2143 | val={'ROC-AUC': 0.7481537874462664, 'PRC-AUC': 0.31579382873704004}
# INFO | HPO epoch  15/80 | loss=0.2016 | val={'ROC-AUC': 0.7578876283682202, 'PRC-AUC': 0.30529817838051715}
# INFO | HPO epoch  20/80 | loss=0.1974 | val={'ROC-AUC': 0.6908776736754176, 'PRC-AUC': 0.2743535314621545}
# INFO | HPO epoch  25/80 | loss=0.1949 | val={'ROC-AUC': 0.768393652157254, 'PRC-AUC': 0.3491875508204891}
# INFO | HPO epoch  30/80 | loss=0.1912 | val={'ROC-AUC': 0.7568161276539316, 'PRC-AUC': 0.37097697642717503}
# INFO | HPO epoch  35/80 | loss=0.1860 | val={'ROC-AUC': 0.7350932371274737, 'PRC-AUC': 0.32114648976661203}
# INFO | HPO epoch  40/80 | loss=0.1715 | val={'ROC-AUC': 0.7868434212277079, 'PRC-AUC': 0.4075272897312536}
# INFO | HPO epoch  45/80 | loss=0.1690 | val={'ROC-AUC': 0.7890367401395867, 'PRC-AUC': 0.4107380095823961}
# INFO | HPO epoch  50/80 | loss=0.1672 | val={'ROC-AUC': 0.7807492405741977, 'PRC-AUC': 0.40156366013417144}
# INFO | HPO epoch  55/80 | loss=0.1658 | val={'ROC-AUC': 0.7992264889704072, 'PRC-AUC': 0.4268555972515466}
# INFO | HPO epoch  60/80 | loss=0.1570 | val={'ROC-AUC': 0.8001557497498538, 'PRC-AUC': 0.42968515183144523}
# INFO | Early stop at epoch 63 (patience=15)
# INFO | GIN 3D HPO — trial 3/10 finished | val=-0.816013 | best=-0.821136
# INFO | GIN 3D — starting trial 4/10 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3402 | val={'ROC-AUC': 0.6150275857825324, 'PRC-AUC': 0.18923131735182494}
# INFO | HPO epoch   5/80 | loss=0.2269 | val={'ROC-AUC': 0.7424158838266358, 'PRC-AUC': 0.30395277142734173}
# INFO | HPO epoch  10/80 | loss=0.2134 | val={'ROC-AUC': 0.735273641368293, 'PRC-AUC': 0.336951518380602}
# INFO | HPO epoch  15/80 | loss=0.2013 | val={'ROC-AUC': 0.7739274165412947, 'PRC-AUC': 0.3385911667997931}
# INFO | HPO epoch  20/80 | loss=0.1934 | val={'ROC-AUC': 0.7935419461115357, 'PRC-AUC': 0.38488986412580894}
# INFO | HPO epoch  25/80 | loss=0.1878 | val={'ROC-AUC': 0.7747714320882103, 'PRC-AUC': 0.35211146684032735}
# INFO | HPO epoch  30/80 | loss=0.1843 | val={'ROC-AUC': 0.7764328249066224, 'PRC-AUC': 0.3923016079112458}
# INFO | HPO epoch  35/80 | loss=0.1772 | val={'ROC-AUC': 0.7945558073364833, 'PRC-AUC': 0.4115670234187556}
# INFO | HPO epoch  40/80 | loss=0.1741 | val={'ROC-AUC': 0.7771568036207185, 'PRC-AUC': 0.40240466220485094}
# INFO | HPO epoch  45/80 | loss=0.1687 | val={'ROC-AUC': 0.7789847961655957, 'PRC-AUC': 0.36979568467388174}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | GIN 3D HPO — trial 4/10 finished | val=-0.812393 | best=-0.821136
# INFO | GIN 3D — starting trial 5/10 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.3388 | val={'ROC-AUC': 0.6558160151336582, 'PRC-AUC': 0.20749874707600016}
# INFO | HPO epoch   5/80 | loss=0.2311 | val={'ROC-AUC': 0.6589998581322957, 'PRC-AUC': 0.2214135609870506}
# INFO | HPO epoch  10/80 | loss=0.2212 | val={'ROC-AUC': 0.6822759808232292, 'PRC-AUC': 0.2439684175754738}
# INFO | HPO epoch  15/80 | loss=0.2134 | val={'ROC-AUC': 0.7749024105275474, 'PRC-AUC': 0.2800300630729288}
# INFO | HPO epoch  20/80 | loss=0.2079 | val={'ROC-AUC': 0.7433804298958092, 'PRC-AUC': 0.2869597098679081}
# INFO | HPO epoch  25/80 | loss=0.2056 | val={'ROC-AUC': 0.7734067146797242, 'PRC-AUC': 0.2762262935500414}
# INFO | HPO epoch  30/80 | loss=0.1986 | val={'ROC-AUC': 0.7568143695630197, 'PRC-AUC': 0.24348686664384067}
# INFO | HPO epoch  35/80 | loss=0.1960 | val={'ROC-AUC': 0.7255807426715114, 'PRC-AUC': 0.28077962597781697}
# INFO | HPO epoch  40/80 | loss=0.1905 | val={'ROC-AUC': 0.7689870525952848, 'PRC-AUC': 0.3432230118431834}
# INFO | HPO epoch  45/80 | loss=0.1897 | val={'ROC-AUC': 0.7729129084931974, 'PRC-AUC': 0.3357271686444545}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | GIN 3D HPO — trial 5/10 finished | val=-0.810977 | best=-0.821136
# INFO | GIN 3D — starting trial 6/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3341 | val={'ROC-AUC': 0.6914136769406127, 'PRC-AUC': 0.21389047534555053}
# INFO | HPO epoch   5/80 | loss=0.2231 | val={'ROC-AUC': 0.7692440862397144, 'PRC-AUC': 0.27505866161050146}
# INFO | HPO epoch  10/80 | loss=0.2057 | val={'ROC-AUC': 0.7275693604277501, 'PRC-AUC': 0.2750972216521393}
# INFO | HPO epoch  15/80 | loss=0.1984 | val={'ROC-AUC': 0.7427237219085732, 'PRC-AUC': 0.35323749225450335}
# INFO | HPO epoch  20/80 | loss=0.1903 | val={'ROC-AUC': 0.7724683760938847, 'PRC-AUC': 0.3703433717542914}
# INFO | HPO epoch  25/80 | loss=0.1855 | val={'ROC-AUC': 0.7858447794141327, 'PRC-AUC': 0.3781147375818259}
# INFO | HPO epoch  30/80 | loss=0.1804 | val={'ROC-AUC': 0.793790733444001, 'PRC-AUC': 0.3499939928479498}
# INFO | HPO epoch  35/80 | loss=0.1747 | val={'ROC-AUC': 0.7907212551329775, 'PRC-AUC': 0.40191992618386535}
# INFO | HPO epoch  40/80 | loss=0.1597 | val={'ROC-AUC': 0.8042547400246375, 'PRC-AUC': 0.45123355104818774}
# INFO | HPO epoch  45/80 | loss=0.1552 | val={'ROC-AUC': 0.8021977628463253, 'PRC-AUC': 0.4247864031761505}
# INFO | HPO epoch  50/80 | loss=0.1512 | val={'ROC-AUC': 0.7859211194463094, 'PRC-AUC': 0.41071767465676867}
# INFO | HPO epoch  55/80 | loss=0.1490 | val={'ROC-AUC': 0.802952417115599, 'PRC-AUC': 0.4409531089215802}
# INFO | HPO epoch  60/80 | loss=0.1458 | val={'ROC-AUC': 0.8081325827410272, 'PRC-AUC': 0.4454124705322177}
# INFO | HPO epoch  65/80 | loss=0.1350 | val={'ROC-AUC': 0.8129546550438081, 'PRC-AUC': 0.4493131817202323}
# INFO | HPO epoch  70/80 | loss=0.1299 | val={'ROC-AUC': 0.807582910102988, 'PRC-AUC': 0.45589585987805387}
# INFO | HPO epoch  75/80 | loss=0.1293 | val={'ROC-AUC': 0.7998822235297595, 'PRC-AUC': 0.44765177213111124}
# INFO | HPO epoch  80/80 | loss=0.1229 | val={'ROC-AUC': 0.807463937939918, 'PRC-AUC': 0.46062620943255256}
# INFO | GIN 3D HPO — trial 6/10 finished | val=-0.816315 | best=-0.821136
# INFO | GIN 3D — starting trial 7/10 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3274 | val={'ROC-AUC': 0.6801912543817655, 'PRC-AUC': 0.21133071299374404}
# INFO | HPO epoch   5/80 | loss=0.2270 | val={'ROC-AUC': 0.6211173938865865, 'PRC-AUC': 0.20679935176812272}
# INFO | HPO epoch  10/80 | loss=0.2101 | val={'ROC-AUC': 0.625775914740592, 'PRC-AUC': 0.17866480075707405}
# INFO | HPO epoch  15/80 | loss=0.2058 | val={'ROC-AUC': 0.7435168182140774, 'PRC-AUC': 0.33795034035632315}
# INFO | HPO epoch  20/80 | loss=0.1936 | val={'ROC-AUC': 0.7533034067132975, 'PRC-AUC': 0.35937041982657575}
# INFO | HPO epoch  25/80 | loss=0.1807 | val={'ROC-AUC': 0.7663674354283504, 'PRC-AUC': 0.37597047917378196}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | GIN 3D HPO — trial 7/10 finished | val=-0.795788 | best=-0.821136
# INFO | GIN 3D — starting trial 8/10 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.3164 | val={'ROC-AUC': 0.6599407884846368, 'PRC-AUC': 0.17820290182139517}
# INFO | HPO epoch   5/80 | loss=0.2402 | val={'ROC-AUC': 0.5267141646175347, 'PRC-AUC': 0.12808432599498804}
# INFO | HPO epoch  10/80 | loss=0.2321 | val={'ROC-AUC': 0.7504745210093541, 'PRC-AUC': 0.2658917367487201}
# INFO | HPO epoch  15/80 | loss=0.2250 | val={'ROC-AUC': 0.4347588145986492, 'PRC-AUC': 0.07615065822844085}
# INFO | HPO epoch  20/80 | loss=0.2249 | val={'ROC-AUC': 0.7592297711776954, 'PRC-AUC': 0.279136632868833}
# INFO | HPO epoch  25/80 | loss=0.2228 | val={'ROC-AUC': 0.41242988785310336, 'PRC-AUC': 0.07227349775023924}
# INFO | Early stop at epoch 29 (patience=15)
# INFO | GIN 3D HPO — trial 8/10 finished | val=-0.759607 | best=-0.821136
# INFO | GIN 3D — starting trial 9/10 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.3279 | val={'ROC-AUC': 0.6861700639059866, 'PRC-AUC': 0.2295570847656003}
# INFO | HPO epoch   5/80 | loss=0.2208 | val={'ROC-AUC': 0.7398978149104583, 'PRC-AUC': 0.315522878944365}
# INFO | HPO epoch  10/80 | loss=0.2022 | val={'ROC-AUC': 0.8004987021506443, 'PRC-AUC': 0.3874916180302152}
# INFO | HPO epoch  15/80 | loss=0.1891 | val={'ROC-AUC': 0.7452389982113262, 'PRC-AUC': 0.3629002518070608}
# INFO | HPO epoch  20/80 | loss=0.1809 | val={'ROC-AUC': 0.7872876379390602, 'PRC-AUC': 0.416201910454513}
# INFO | HPO epoch  25/80 | loss=0.1679 | val={'ROC-AUC': 0.7781621831879498, 'PRC-AUC': 0.40791402648415054}
# INFO | Early stop at epoch 25 (patience=15)
# INFO | GIN 3D HPO — trial 9/10 finished | val=-0.800499 | best=-0.821136
# INFO | GIN 3D — starting trial 10/10 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.3265 | val={'ROC-AUC': 0.6643100842611736, 'PRC-AUC': 0.20357676897920216}
# INFO | HPO epoch   5/80 | loss=0.2234 | val={'ROC-AUC': 0.7260565216935442, 'PRC-AUC': 0.29479199776269555}
# INFO | HPO epoch  10/80 | loss=0.2024 | val={'ROC-AUC': 0.780948561203906, 'PRC-AUC': 0.3643753664954857}
# INFO | HPO epoch  15/80 | loss=0.1964 | val={'ROC-AUC': 0.7395312413788887, 'PRC-AUC': 0.3260507735381884}
# INFO | HPO epoch  20/80 | loss=0.1866 | val={'ROC-AUC': 0.7704839205078526, 'PRC-AUC': 0.3808363064297677}
# INFO | HPO epoch  25/80 | loss=0.1705 | val={'ROC-AUC': 0.787768331236718, 'PRC-AUC': 0.40839156900627094}
# INFO | HPO epoch  30/80 | loss=0.1652 | val={'ROC-AUC': 0.8068618067381149, 'PRC-AUC': 0.4415640505562617}
# INFO | HPO epoch  35/80 | loss=0.1604 | val={'ROC-AUC': 0.7674197555624495, 'PRC-AUC': 0.39939102354536277}
# INFO | HPO epoch  40/80 | loss=0.1570 | val={'ROC-AUC': 0.7979293386776606, 'PRC-AUC': 0.4280334752340238}
# INFO | HPO epoch  45/80 | loss=0.1421 | val={'ROC-AUC': 0.793612612623909, 'PRC-AUC': 0.43180058994181825}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | GIN 3D HPO — trial 10/10 finished | val=-0.806862 | best=-0.821136
# INFO | Epoch  10 | loss=0.2178 | val={'ROC-AUC': 0.7580297035366669, 'PRC-AUC': 0.34241418004491136}
# INFO | Epoch  20 | loss=0.2007 | val={'ROC-AUC': 0.7806600342296558, 'PRC-AUC': 0.372385910858898}
# INFO | Epoch  30 | loss=0.1867 | val={'ROC-AUC': 0.7699832234812801, 'PRC-AUC': 0.3386114955871396}
# INFO | Epoch  40 | loss=0.1752 | val={'ROC-AUC': 0.7922290893750675, 'PRC-AUC': 0.40242437271867654}
# INFO | Epoch  50 | loss=0.1696 | val={'ROC-AUC': 0.7789905172702928, 'PRC-AUC': 0.40269568752648993}
# INFO | Epoch  60 | loss=0.1630 | val={'ROC-AUC': 0.7955735405008224, 'PRC-AUC': 0.408661104666777}
# INFO | Epoch  70 | loss=0.1626 | val={'ROC-AUC': 0.8088896939035791, 'PRC-AUC': 0.4240122123226584}
# INFO | Epoch  80 | loss=0.1595 | val={'ROC-AUC': 0.803681686628822, 'PRC-AUC': 0.4224386988973646}
# INFO | Saved GIN (3D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/tox21_partial.json
#    scaffold test: {'ROC-AUC': 0.8222091898815993, 'PRC-AUC': 0.42052884880391495}

# %% [markdown]
# ### SchNet (3D coords)
# Uses atomic numbers + xyz from min-energy n=25 conformer.

# %%
MODEL_KEY = "SchNet (3D coords)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_schnet(
        tr3d, va3d, TASK_TYPE, OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_schnet, PyGLoader, build_schnet, train_schnet
    model = build_schnet(
        OUT_CHANNELS,
        hidden_channels=best["hidden_channels"],
        num_filters=best["num_filters"],
        num_interactions=best["num_interactions"],
        num_gaussians=best["num_gaussians"],
        cutoff=best["cutoff"],
    )
    train_schnet(model, tr3d, va3d, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
                 batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    te3d_schnet = ensure_atomic_numbers_list(te3d)
    test_metrics = eval_schnet(model, PyGLoader(te3d_schnet, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_schnet.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# → SchNet (3D coords) (Optuna 10 trials, scaffold split) …
# INFO | SchNet — starting trial 1/10
# INFO | HPO epoch   1/80 | loss=0.5731 | val={'ROC-AUC': 0.4840901974534227, 'PRC-AUC': 0.08954840491868023}
# INFO | HPO epoch   5/80 | loss=0.2456 | val={'ROC-AUC': 0.6849525464601459, 'PRC-AUC': 0.21528012754414572}
# INFO | HPO epoch  10/80 | loss=0.2250 | val={'ROC-AUC': 0.7557322869198574, 'PRC-AUC': 0.2914736725384482}
# INFO | HPO epoch  15/80 | loss=0.2108 | val={'ROC-AUC': 0.7735087687903789, 'PRC-AUC': 0.303730535140539}
# INFO | HPO epoch  20/80 | loss=0.2021 | val={'ROC-AUC': 0.7799976134847849, 'PRC-AUC': 0.32998946513304217}
# INFO | HPO epoch  25/80 | loss=0.1931 | val={'ROC-AUC': 0.7864858519411578, 'PRC-AUC': 0.3363158748274578}
# INFO | HPO epoch  30/80 | loss=0.1854 | val={'ROC-AUC': 0.801955751515802, 'PRC-AUC': 0.37102059601090565}
# INFO | HPO epoch  35/80 | loss=0.1774 | val={'ROC-AUC': 0.7982955024998518, 'PRC-AUC': 0.3827686810950716}
# INFO | HPO epoch  40/80 | loss=0.1673 | val={'ROC-AUC': 0.7999427553432145, 'PRC-AUC': 0.37223418387869484}
# INFO | HPO epoch  45/80 | loss=0.1587 | val={'ROC-AUC': 0.8079110211199887, 'PRC-AUC': 0.37176377192648785}
# INFO | HPO epoch  50/80 | loss=0.1491 | val={'ROC-AUC': 0.7941744983550513, 'PRC-AUC': 0.38792363615602143}
# INFO | HPO epoch  55/80 | loss=0.1356 | val={'ROC-AUC': 0.7855493866928073, 'PRC-AUC': 0.37881716687082084}
# INFO | HPO epoch  60/80 | loss=0.1212 | val={'ROC-AUC': 0.7837705792623487, 'PRC-AUC': 0.38651538108291894}
# INFO | Early stop at epoch 60 (patience=15)
# INFO | SchNet HPO — trial 1/10 finished | val=-0.807911 | best=-0.807911
# INFO | SchNet — starting trial 2/10
# INFO | HPO epoch   1/80 | loss=0.9253 | val={'ROC-AUC': 0.3696011062354992, 'PRC-AUC': 0.0643302082111858}
# INFO | HPO epoch   5/80 | loss=0.3056 | val={'ROC-AUC': 0.5103250957788851, 'PRC-AUC': 0.1355720416472839}
# INFO | HPO epoch  10/80 | loss=0.2732 | val={'ROC-AUC': 0.5596740584717806, 'PRC-AUC': 0.1625473901505434}
# INFO | HPO epoch  15/80 | loss=0.2584 | val={'ROC-AUC': 0.5851311858576963, 'PRC-AUC': 0.1737635065165263}
# INFO | HPO epoch  20/80 | loss=0.2483 | val={'ROC-AUC': 0.6301658294425835, 'PRC-AUC': 0.1948479979272019}
# INFO | HPO epoch  25/80 | loss=0.2432 | val={'ROC-AUC': 0.6539406562516974, 'PRC-AUC': 0.21034750656359877}
# INFO | HPO epoch  30/80 | loss=0.2363 | val={'ROC-AUC': 0.668563773981336, 'PRC-AUC': 0.22970135219205298}
# INFO | HPO epoch  35/80 | loss=0.2345 | val={'ROC-AUC': 0.6637395010383986, 'PRC-AUC': 0.2332937238926961}
# INFO | HPO epoch  40/80 | loss=0.2282 | val={'ROC-AUC': 0.6992328924033516, 'PRC-AUC': 0.2589879582792615}
# INFO | HPO epoch  45/80 | loss=0.2240 | val={'ROC-AUC': 0.6858035706045248, 'PRC-AUC': 0.2545648554191507}
# INFO | HPO epoch  50/80 | loss=0.2205 | val={'ROC-AUC': 0.7217130005940365, 'PRC-AUC': 0.2808072315570749}
# INFO | HPO epoch  55/80 | loss=0.2195 | val={'ROC-AUC': 0.7196727286638159, 'PRC-AUC': 0.28162063525664227}
# INFO | HPO epoch  60/80 | loss=0.2132 | val={'ROC-AUC': 0.7207615642405503, 'PRC-AUC': 0.2893134234863275}
# INFO | HPO epoch  65/80 | loss=0.2122 | val={'ROC-AUC': 0.7423117593156138, 'PRC-AUC': 0.30329095715115384}
# INFO | HPO epoch  70/80 | loss=0.2069 | val={'ROC-AUC': 0.7394286019299283, 'PRC-AUC': 0.30827654525939674}
# INFO | HPO epoch  75/80 | loss=0.2034 | val={'ROC-AUC': 0.7513166469215323, 'PRC-AUC': 0.3197628764753226}
# INFO | HPO epoch  80/80 | loss=0.1999 | val={'ROC-AUC': 0.7558345130731629, 'PRC-AUC': 0.3258179571283676}
# INFO | SchNet HPO — trial 2/10 finished | val=-0.755835 | best=-0.807911
# INFO | SchNet — starting trial 3/10
# INFO | HPO epoch   1/80 | loss=0.4985 | val={'ROC-AUC': 0.5178162931944753, 'PRC-AUC': 0.1057624647583794}
# INFO | HPO epoch   5/80 | loss=0.2434 | val={'ROC-AUC': 0.6907393189806409, 'PRC-AUC': 0.2354822430875225}
# INFO | HPO epoch  10/80 | loss=0.2335 | val={'ROC-AUC': 0.728826568290768, 'PRC-AUC': 0.23904439113232653}
# INFO | HPO epoch  15/80 | loss=0.2307 | val={'ROC-AUC': 0.7347061361025392, 'PRC-AUC': 0.2279298309966192}
# INFO | HPO epoch  20/80 | loss=0.2290 | val={'ROC-AUC': 0.7379137939951916, 'PRC-AUC': 0.23246560046019935}
# INFO | HPO epoch  25/80 | loss=0.2253 | val={'ROC-AUC': 0.7473655725562557, 'PRC-AUC': 0.2413080911266652}
# INFO | HPO epoch  30/80 | loss=0.2212 | val={'ROC-AUC': 0.7475728402144245, 'PRC-AUC': 0.22948611248197484}
# INFO | HPO epoch  35/80 | loss=0.2185 | val={'ROC-AUC': 0.7646815683250296, 'PRC-AUC': 0.2584388587358092}
# INFO | HPO epoch  40/80 | loss=0.2177 | val={'ROC-AUC': 0.7615977766593693, 'PRC-AUC': 0.25069947437347406}
# INFO | HPO epoch  45/80 | loss=0.2175 | val={'ROC-AUC': 0.7672831707375208, 'PRC-AUC': 0.2555514490042182}
# INFO | HPO epoch  50/80 | loss=0.2174 | val={'ROC-AUC': 0.7657653047780872, 'PRC-AUC': 0.2758864236443494}
# INFO | HPO epoch  55/80 | loss=0.2175 | val={'ROC-AUC': 0.7635758897237955, 'PRC-AUC': 0.2531259054274109}
# INFO | HPO epoch  60/80 | loss=0.2141 | val={'ROC-AUC': 0.7727090140137723, 'PRC-AUC': 0.2685158892674529}
# INFO | HPO epoch  65/80 | loss=0.2143 | val={'ROC-AUC': 0.7618404329464646, 'PRC-AUC': 0.26454366796555423}
# INFO | HPO epoch  70/80 | loss=0.2140 | val={'ROC-AUC': 0.7703533984388403, 'PRC-AUC': 0.2636940472791041}
# INFO | HPO epoch  75/80 | loss=0.2126 | val={'ROC-AUC': 0.7691483555317896, 'PRC-AUC': 0.2657449718231743}
# INFO | Early stop at epoch 75 (patience=15)
# INFO | SchNet HPO — trial 3/10 finished | val=-0.772709 | best=-0.807911
# INFO | SchNet — starting trial 4/10
# INFO | HPO epoch   1/80 | loss=0.4367 | val={'ROC-AUC': 0.5944509820275796, 'PRC-AUC': 0.1528484013756256}
# INFO | HPO epoch   5/80 | loss=0.2312 | val={'ROC-AUC': 0.7535560546332339, 'PRC-AUC': 0.2474968262074675}
# INFO | HPO epoch  10/80 | loss=0.2163 | val={'ROC-AUC': 0.758006275308468, 'PRC-AUC': 0.28639051166605134}
# INFO | HPO epoch  15/80 | loss=0.2105 | val={'ROC-AUC': 0.7940777247400149, 'PRC-AUC': 0.32680450586674636}
# INFO | HPO epoch  20/80 | loss=0.2040 | val={'ROC-AUC': 0.7911818447582254, 'PRC-AUC': 0.3403386224503502}
# INFO | HPO epoch  25/80 | loss=0.1919 | val={'ROC-AUC': 0.794551587696419, 'PRC-AUC': 0.3675556585488198}
# INFO | HPO epoch  30/80 | loss=0.1777 | val={'ROC-AUC': 0.8101766533311262, 'PRC-AUC': 0.3939859868992044}
# INFO | HPO epoch  35/80 | loss=0.1701 | val={'ROC-AUC': 0.7957576136187487, 'PRC-AUC': 0.39048676657133163}
# INFO | HPO epoch  40/80 | loss=0.1655 | val={'ROC-AUC': 0.7985067342256987, 'PRC-AUC': 0.3565963201224734}
# INFO | HPO epoch  45/80 | loss=0.1551 | val={'ROC-AUC': 0.7858739057157877, 'PRC-AUC': 0.38132298093387235}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | SchNet HPO — trial 4/10 finished | val=-0.816465 | best=-0.816465
# INFO | SchNet — starting trial 5/10
# INFO | HPO epoch   1/80 | loss=0.4171 | val={'ROC-AUC': 0.5314211061036226, 'PRC-AUC': 0.11487308490231174}
# INFO | HPO epoch   5/80 | loss=0.2410 | val={'ROC-AUC': 0.6433937840090929, 'PRC-AUC': 0.18979207958268887}
# INFO | HPO epoch  10/80 | loss=0.2363 | val={'ROC-AUC': 0.7170875511632872, 'PRC-AUC': 0.21714075636929253}
# INFO | HPO epoch  15/80 | loss=0.2282 | val={'ROC-AUC': 0.732299572311799, 'PRC-AUC': 0.22699470743672148}
# INFO | HPO epoch  20/80 | loss=0.2266 | val={'ROC-AUC': 0.7317338274455917, 'PRC-AUC': 0.23525514273981474}
# INFO | HPO epoch  25/80 | loss=0.2260 | val={'ROC-AUC': 0.7418680212596106, 'PRC-AUC': 0.24302161528537478}
# INFO | HPO epoch  30/80 | loss=0.2233 | val={'ROC-AUC': 0.753844002119803, 'PRC-AUC': 0.2421885744603175}
# INFO | HPO epoch  35/80 | loss=0.2232 | val={'ROC-AUC': 0.76445276687692, 'PRC-AUC': 0.2569713048767331}
# INFO | HPO epoch  40/80 | loss=0.2226 | val={'ROC-AUC': 0.7528828398252804, 'PRC-AUC': 0.24185850735922276}
# INFO | HPO epoch  45/80 | loss=0.2209 | val={'ROC-AUC': 0.7669088737841953, 'PRC-AUC': 0.2469899816575123}
# INFO | HPO epoch  50/80 | loss=0.2198 | val={'ROC-AUC': 0.7627469615546908, 'PRC-AUC': 0.2581985585118695}
# INFO | HPO epoch  55/80 | loss=0.2190 | val={'ROC-AUC': 0.7661018232764679, 'PRC-AUC': 0.23880572438364478}
# INFO | HPO epoch  60/80 | loss=0.2175 | val={'ROC-AUC': 0.7736096810914689, 'PRC-AUC': 0.2616155155058398}
# INFO | HPO epoch  65/80 | loss=0.2166 | val={'ROC-AUC': 0.7701538708378478, 'PRC-AUC': 0.2500414899665701}
# INFO | HPO epoch  70/80 | loss=0.2167 | val={'ROC-AUC': 0.7701768149324014, 'PRC-AUC': 0.26047655495491956}
# INFO | HPO epoch  75/80 | loss=0.2173 | val={'ROC-AUC': 0.7712181135856326, 'PRC-AUC': 0.2544374760715421}
# INFO | HPO epoch  80/80 | loss=0.2155 | val={'ROC-AUC': 0.7747568254579796, 'PRC-AUC': 0.25081097699456095}
# INFO | SchNet HPO — trial 5/10 finished | val=-0.775427 | best=-0.816465
# INFO | SchNet — starting trial 6/10
# INFO | HPO epoch   1/80 | loss=0.4688 | val={'ROC-AUC': 0.4662164857802465, 'PRC-AUC': 0.11143203225515967}
# INFO | HPO epoch   5/80 | loss=0.2661 | val={'ROC-AUC': 0.6013220193942296, 'PRC-AUC': 0.1798465122812719}
# INFO | HPO epoch  10/80 | loss=0.2464 | val={'ROC-AUC': 0.6502269002339449, 'PRC-AUC': 0.2073561924859212}
# INFO | HPO epoch  15/80 | loss=0.2383 | val={'ROC-AUC': 0.7174203756467277, 'PRC-AUC': 0.2514127485252747}
# INFO | HPO epoch  20/80 | loss=0.2269 | val={'ROC-AUC': 0.7087805199839963, 'PRC-AUC': 0.2660246403030918}
# INFO | HPO epoch  25/80 | loss=0.2187 | val={'ROC-AUC': 0.7041880780955699, 'PRC-AUC': 0.2741049225940608}
# INFO | HPO epoch  30/80 | loss=0.2106 | val={'ROC-AUC': 0.7507734150460883, 'PRC-AUC': 0.2987878321925699}
# INFO | HPO epoch  35/80 | loss=0.2065 | val={'ROC-AUC': 0.7389201870935856, 'PRC-AUC': 0.29388271032496044}
# INFO | HPO epoch  40/80 | loss=0.1964 | val={'ROC-AUC': 0.7681429680860918, 'PRC-AUC': 0.33357804915965206}
# INFO | HPO epoch  45/80 | loss=0.1895 | val={'ROC-AUC': 0.7754379827321173, 'PRC-AUC': 0.3410969026097053}
# INFO | HPO epoch  50/80 | loss=0.1852 | val={'ROC-AUC': 0.7741363673200264, 'PRC-AUC': 0.3406039508782536}
# INFO | HPO epoch  55/80 | loss=0.1687 | val={'ROC-AUC': 0.7758572792342019, 'PRC-AUC': 0.3584840269679708}
# INFO | HPO epoch  60/80 | loss=0.1668 | val={'ROC-AUC': 0.7856244417591499, 'PRC-AUC': 0.3694580783005419}
# INFO | HPO epoch  65/80 | loss=0.1600 | val={'ROC-AUC': 0.7885577773880525, 'PRC-AUC': 0.37888482038240906}
# INFO | HPO epoch  70/80 | loss=0.1553 | val={'ROC-AUC': 0.7887761050130209, 'PRC-AUC': 0.3787137654061313}
# INFO | HPO epoch  75/80 | loss=0.1496 | val={'ROC-AUC': 0.788267210539205, 'PRC-AUC': 0.38905480528567876}
# INFO | HPO epoch  80/80 | loss=0.1425 | val={'ROC-AUC': 0.786711888338746, 'PRC-AUC': 0.3784169700374094}
# INFO | SchNet HPO — trial 6/10 finished | val=-0.791018 | best=-0.816465
# INFO | SchNet — starting trial 7/10
# INFO | HPO epoch   1/80 | loss=0.4459 | val={'ROC-AUC': 0.4924835051078842, 'PRC-AUC': 0.09429277730076563}
# INFO | HPO epoch   5/80 | loss=0.2668 | val={'ROC-AUC': 0.624477222281328, 'PRC-AUC': 0.18967585873155143}
# INFO | HPO epoch  10/80 | loss=0.2375 | val={'ROC-AUC': 0.6625198268261183, 'PRC-AUC': 0.23347462651971537}
# INFO | HPO epoch  15/80 | loss=0.2293 | val={'ROC-AUC': 0.7283582168374481, 'PRC-AUC': 0.29255759914360546}
# INFO | HPO epoch  20/80 | loss=0.2292 | val={'ROC-AUC': 0.7373468296778461, 'PRC-AUC': 0.3006575212033179}
# INFO | HPO epoch  25/80 | loss=0.2106 | val={'ROC-AUC': 0.7458519202502255, 'PRC-AUC': 0.31363926744266685}
# INFO | HPO epoch  30/80 | loss=0.2045 | val={'ROC-AUC': 0.7635625940294198, 'PRC-AUC': 0.3434436411404483}
# INFO | HPO epoch  35/80 | loss=0.1999 | val={'ROC-AUC': 0.7772553263435086, 'PRC-AUC': 0.343404016594785}
# INFO | HPO epoch  40/80 | loss=0.1945 | val={'ROC-AUC': 0.7640032045074229, 'PRC-AUC': 0.332814962983802}
# INFO | HPO epoch  45/80 | loss=0.1822 | val={'ROC-AUC': 0.7840464910637547, 'PRC-AUC': 0.36034800128607625}
# INFO | HPO epoch  50/80 | loss=0.1761 | val={'ROC-AUC': 0.7822697443058514, 'PRC-AUC': 0.32823311216699985}
# INFO | HPO epoch  55/80 | loss=0.1581 | val={'ROC-AUC': 0.7831389556767293, 'PRC-AUC': 0.37067375357555044}
# INFO | HPO epoch  60/80 | loss=0.1556 | val={'ROC-AUC': 0.782272803522366, 'PRC-AUC': 0.3678630712746585}
# INFO | HPO epoch  65/80 | loss=0.1502 | val={'ROC-AUC': 0.7835464920037607, 'PRC-AUC': 0.35359106015669367}
# INFO | Early stop at epoch 69 (patience=15)
# INFO | SchNet HPO — trial 7/10 finished | val=-0.788673 | best=-0.816465
# INFO | SchNet — starting trial 8/10
# INFO | HPO epoch   1/80 | loss=0.5800 | val={'ROC-AUC': 0.4060607470437299, 'PRC-AUC': 0.0753859598254092}
# INFO | HPO epoch   5/80 | loss=0.2781 | val={'ROC-AUC': 0.5625208687972532, 'PRC-AUC': 0.15638749022001966}
# INFO | HPO epoch  10/80 | loss=0.2535 | val={'ROC-AUC': 0.6183842307593693, 'PRC-AUC': 0.19148603950984577}
# INFO | HPO epoch  15/80 | loss=0.2433 | val={'ROC-AUC': 0.6602182438302383, 'PRC-AUC': 0.21239209776844548}
# INFO | HPO epoch  20/80 | loss=0.2382 | val={'ROC-AUC': 0.6213520638872336, 'PRC-AUC': 0.19566687228295512}
# INFO | HPO epoch  25/80 | loss=0.2318 | val={'ROC-AUC': 0.6947165161988483, 'PRC-AUC': 0.2460696244336195}
# INFO | HPO epoch  30/80 | loss=0.2276 | val={'ROC-AUC': 0.7224495060266317, 'PRC-AUC': 0.2674950264517096}
# INFO | HPO epoch  35/80 | loss=0.2242 | val={'ROC-AUC': 0.7129493527784286, 'PRC-AUC': 0.2764237720880271}
# INFO | HPO epoch  40/80 | loss=0.2165 | val={'ROC-AUC': 0.7271727022806878, 'PRC-AUC': 0.29168397604053425}
# INFO | HPO epoch  45/80 | loss=0.2100 | val={'ROC-AUC': 0.731139415804658, 'PRC-AUC': 0.30211235579366047}
# INFO | HPO epoch  50/80 | loss=0.2060 | val={'ROC-AUC': 0.7302322860008402, 'PRC-AUC': 0.3072645853551804}
# INFO | HPO epoch  55/80 | loss=0.2023 | val={'ROC-AUC': 0.7317299974593844, 'PRC-AUC': 0.31608452143841165}
# INFO | HPO epoch  60/80 | loss=0.2021 | val={'ROC-AUC': 0.7596192525798108, 'PRC-AUC': 0.33362885722135105}
# INFO | HPO epoch  65/80 | loss=0.1990 | val={'ROC-AUC': 0.7493778822923254, 'PRC-AUC': 0.34059318197841937}
# INFO | HPO epoch  70/80 | loss=0.1940 | val={'ROC-AUC': 0.769496810048324, 'PRC-AUC': 0.339148770396361}
# INFO | HPO epoch  75/80 | loss=0.1892 | val={'ROC-AUC': 0.7480557442362571, 'PRC-AUC': 0.3331359270116675}
# INFO | HPO epoch  80/80 | loss=0.1886 | val={'ROC-AUC': 0.7582170732301422, 'PRC-AUC': 0.34908084052047905}
# INFO | SchNet HPO — trial 8/10 finished | val=-0.771504 | best=-0.816465
# INFO | SchNet — starting trial 9/10
# INFO | HPO epoch   1/80 | loss=0.4333 | val={'ROC-AUC': 0.4414138659467175, 'PRC-AUC': 0.07548206930569405}
# INFO | HPO epoch   5/80 | loss=0.2691 | val={'ROC-AUC': 0.5813510326358889, 'PRC-AUC': 0.15530378984955578}
# INFO | HPO epoch  10/80 | loss=0.2617 | val={'ROC-AUC': 0.6284460651620006, 'PRC-AUC': 0.17320655914447602}
# INFO | HPO epoch  15/80 | loss=0.2559 | val={'ROC-AUC': 0.6034635922865531, 'PRC-AUC': 0.17186045928399218}
# INFO | HPO epoch  20/80 | loss=0.2530 | val={'ROC-AUC': 0.603651616184797, 'PRC-AUC': 0.16675216265529236}
# INFO | HPO epoch  25/80 | loss=0.2517 | val={'ROC-AUC': 0.6016327008190776, 'PRC-AUC': 0.16219933526820607}
# INFO | HPO epoch  30/80 | loss=0.2477 | val={'ROC-AUC': 0.6462516474655393, 'PRC-AUC': 0.18565151411491573}
# INFO | HPO epoch  35/80 | loss=0.2463 | val={'ROC-AUC': 0.6453959863931468, 'PRC-AUC': 0.18397186661303352}
# INFO | HPO epoch  40/80 | loss=0.2464 | val={'ROC-AUC': 0.641495780579309, 'PRC-AUC': 0.18316089510052783}
# INFO | HPO epoch  45/80 | loss=0.2464 | val={'ROC-AUC': 0.6322949037389171, 'PRC-AUC': 0.1789862486789593}
# INFO | HPO epoch  50/80 | loss=0.2452 | val={'ROC-AUC': 0.6555940834837736, 'PRC-AUC': 0.19276427604794988}
# INFO | HPO epoch  55/80 | loss=0.2430 | val={'ROC-AUC': 0.6227765462981599, 'PRC-AUC': 0.17623922172781273}
# INFO | HPO epoch  60/80 | loss=0.2432 | val={'ROC-AUC': 0.6440426629223672, 'PRC-AUC': 0.19066279519725327}
# INFO | Early stop at epoch 64 (patience=15)
# INFO | SchNet HPO — trial 9/10 finished | val=-0.676452 | best=-0.816465
# INFO | SchNet — starting trial 10/10
# INFO | HPO epoch   1/80 | loss=0.4624 | val={'ROC-AUC': 0.5152618473097873, 'PRC-AUC': 0.11682494198026434}
# INFO | HPO epoch   5/80 | loss=0.2449 | val={'ROC-AUC': 0.659743991410149, 'PRC-AUC': 0.19929219320077318}
# INFO | HPO epoch  10/80 | loss=0.2331 | val={'ROC-AUC': 0.7097695874251765, 'PRC-AUC': 0.2309569317072855}
# INFO | HPO epoch  15/80 | loss=0.2307 | val={'ROC-AUC': 0.7379775536797735, 'PRC-AUC': 0.2426714521136127}
# INFO | HPO epoch  20/80 | loss=0.2276 | val={'ROC-AUC': 0.7468868520846033, 'PRC-AUC': 0.2653428171527475}
# INFO | HPO epoch  25/80 | loss=0.2259 | val={'ROC-AUC': 0.7531452980781327, 'PRC-AUC': 0.2758685315470962}
# INFO | HPO epoch  30/80 | loss=0.2232 | val={'ROC-AUC': 0.7423761429363577, 'PRC-AUC': 0.2629678043565177}
# INFO | HPO epoch  35/80 | loss=0.2236 | val={'ROC-AUC': 0.7608135901661927, 'PRC-AUC': 0.27146017766418795}
# INFO | HPO epoch  40/80 | loss=0.2200 | val={'ROC-AUC': 0.7623337110307292, 'PRC-AUC': 0.28056119638022387}
# INFO | HPO epoch  45/80 | loss=0.2190 | val={'ROC-AUC': 0.7633203788555708, 'PRC-AUC': 0.2816144715876205}
# INFO | HPO epoch  50/80 | loss=0.2178 | val={'ROC-AUC': 0.757171873732199, 'PRC-AUC': 0.27811943664768185}
# INFO | HPO epoch  55/80 | loss=0.2180 | val={'ROC-AUC': 0.7699607992311922, 'PRC-AUC': 0.26937098925761926}
# INFO | HPO epoch  60/80 | loss=0.2190 | val={'ROC-AUC': 0.7637687406513232, 'PRC-AUC': 0.2720535337510843}
# INFO | HPO epoch  65/80 | loss=0.2158 | val={'ROC-AUC': 0.772323932880668, 'PRC-AUC': 0.30703115381670804}
# INFO | HPO epoch  70/80 | loss=0.2201 | val={'ROC-AUC': 0.771639071339281, 'PRC-AUC': 0.29702971296261077}
# INFO | HPO epoch  75/80 | loss=0.2144 | val={'ROC-AUC': 0.7797007037645612, 'PRC-AUC': 0.3004474796135017}
# INFO | Early stop at epoch 77 (patience=15)
# INFO | SchNet HPO — trial 10/10 finished | val=-0.780146 | best=-0.816465
# INFO | Epoch  10 | loss=0.2140 | val={'ROC-AUC': 0.7774028554597933, 'PRC-AUC': 0.2974718044699738}
# INFO | Epoch  20 | loss=0.1990 | val={'ROC-AUC': 0.8007201190694636, 'PRC-AUC': 0.3573707355313543}
# INFO | Epoch  30 | loss=0.1836 | val={'ROC-AUC': 0.8154882621063216, 'PRC-AUC': 0.39213324815035105}
# INFO | Epoch  40 | loss=0.1677 | val={'ROC-AUC': 0.7952104860844843, 'PRC-AUC': 0.3586808990898425}
# INFO | Epoch  50 | loss=0.1336 | val={'ROC-AUC': 0.7873481555136513, 'PRC-AUC': 0.39133849814155414}
# INFO | Epoch  60 | loss=0.1035 | val={'ROC-AUC': 0.7410488189668532, 'PRC-AUC': 0.3718830816581968}
# INFO | Epoch  70 | loss=0.0803 | val={'ROC-AUC': 0.7318339336071645, 'PRC-AUC': 0.34874240315484556}
# INFO | Epoch  80 | loss=0.0650 | val={'ROC-AUC': 0.7195516323668253, 'PRC-AUC': 0.34391167147347756}
# INFO | Saved SchNet (3D coords) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/tox21_partial.json
#    scaffold test: {'ROC-AUC': 0.7825944996998624, 'PRC-AUC': 0.3129443095898638}

# %% [markdown]
# ### SMILES LSTM
# Canonical isomeric SMILES tokens.

# %%
MODEL_KEY = "SMILES LSTM"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_lstm(
        tr_ds, va_ds, TASK_TYPE, len(vocab), OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import SmilesLSTM, eval_lstm, TorchLoader, train_lstm
    model = SmilesLSTM(len(vocab), embed_dim=best["embed_dim"], hidden_dim=best["hidden_dim"],
                       n_layers=best["n_layers"], out_channels=OUT_CHANNELS, dropout=best["dropout"])
    train_lstm(model, tr_ds, va_ds, TASK_TYPE, epochs=LSTM_EPOCHS, lr=best["lr"],
               batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_lstm(model, TorchLoader(te_ds, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_lstm.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | LSTM — starting trial 1/10
# → SMILES LSTM (Optuna 10 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.3586 | val={'ROC-AUC': 0.5510189779965052, 'PRC-AUC': 0.1320176532925332}
# INFO | HPO epoch   5/80 | loss=0.2107 | val={'ROC-AUC': 0.6656888024694029, 'PRC-AUC': 0.23236328428669914}
# INFO | HPO epoch  10/80 | loss=0.1891 | val={'ROC-AUC': 0.6954728929210022, 'PRC-AUC': 0.2696767085895799}
# INFO | HPO epoch  15/80 | loss=0.1760 | val={'ROC-AUC': 0.6998213454122745, 'PRC-AUC': 0.2906082577214118}
# INFO | HPO epoch  20/80 | loss=0.1661 | val={'ROC-AUC': 0.7192145456443603, 'PRC-AUC': 0.3116648699360172}
# INFO | HPO epoch  25/80 | loss=0.1551 | val={'ROC-AUC': 0.7282965203212748, 'PRC-AUC': 0.3247687263795224}
# INFO | HPO epoch  30/80 | loss=0.1459 | val={'ROC-AUC': 0.7233201786502034, 'PRC-AUC': 0.33094854429925297}
# INFO | HPO epoch  35/80 | loss=0.1357 | val={'ROC-AUC': 0.7289029455861974, 'PRC-AUC': 0.3231327904980541}
# INFO | HPO epoch  40/80 | loss=0.1271 | val={'ROC-AUC': 0.7284136264683357, 'PRC-AUC': 0.3150305984819713}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | LSTM HPO — trial 1/10 finished | val=-0.732505 | best=-0.732505
# INFO | LSTM — starting trial 2/10
# INFO | HPO epoch   1/80 | loss=0.2854 | val={'ROC-AUC': 0.6185964714417646, 'PRC-AUC': 0.17447112602740592}
# INFO | HPO epoch   5/80 | loss=0.1996 | val={'ROC-AUC': 0.7053605646850972, 'PRC-AUC': 0.2776432912548203}
# INFO | HPO epoch  10/80 | loss=0.1782 | val={'ROC-AUC': 0.7247802708439761, 'PRC-AUC': 0.3114760113333207}
# INFO | HPO epoch  15/80 | loss=0.1651 | val={'ROC-AUC': 0.7302162426147273, 'PRC-AUC': 0.2921289930885224}
# INFO | HPO epoch  20/80 | loss=0.1534 | val={'ROC-AUC': 0.7411665350422431, 'PRC-AUC': 0.31523483916405043}
# INFO | HPO epoch  25/80 | loss=0.1407 | val={'ROC-AUC': 0.7399860972730807, 'PRC-AUC': 0.3170675230831853}
# INFO | HPO epoch  30/80 | loss=0.1245 | val={'ROC-AUC': 0.7444918179742676, 'PRC-AUC': 0.32266343326319347}
# INFO | Early stop at epoch 33 (patience=15)
# INFO | LSTM HPO — trial 2/10 finished | val=-0.746716 | best=-0.746716
# INFO | LSTM — starting trial 3/10
# INFO | HPO epoch   1/80 | loss=0.4626 | val={'ROC-AUC': 0.5356546534715265, 'PRC-AUC': 0.126165232835448}
# INFO | HPO epoch   5/80 | loss=0.2259 | val={'ROC-AUC': 0.6402551484616947, 'PRC-AUC': 0.18944905033731807}
# INFO | HPO epoch  10/80 | loss=0.2077 | val={'ROC-AUC': 0.6679641896865135, 'PRC-AUC': 0.2418036549167142}
# INFO | HPO epoch  15/80 | loss=0.2002 | val={'ROC-AUC': 0.7068786776136348, 'PRC-AUC': 0.28000533455748783}
# INFO | HPO epoch  20/80 | loss=0.1926 | val={'ROC-AUC': 0.7214022896718197, 'PRC-AUC': 0.3033142806303084}
# INFO | HPO epoch  25/80 | loss=0.1870 | val={'ROC-AUC': 0.7159497276781502, 'PRC-AUC': 0.3040396038221124}
# INFO | HPO epoch  30/80 | loss=0.1839 | val={'ROC-AUC': 0.7037467985538656, 'PRC-AUC': 0.29006419952767665}
# INFO | HPO epoch  35/80 | loss=0.1801 | val={'ROC-AUC': 0.7107742063993016, 'PRC-AUC': 0.2926007611494738}
# INFO | HPO epoch  40/80 | loss=0.1770 | val={'ROC-AUC': 0.7147906943983049, 'PRC-AUC': 0.29153057279487876}
# INFO | HPO epoch  45/80 | loss=0.1746 | val={'ROC-AUC': 0.7243034922162633, 'PRC-AUC': 0.2984254563921478}
# INFO | HPO epoch  50/80 | loss=0.1731 | val={'ROC-AUC': 0.7238268454549107, 'PRC-AUC': 0.29730471249548146}
# INFO | HPO epoch  55/80 | loss=0.1722 | val={'ROC-AUC': 0.723577577145268, 'PRC-AUC': 0.3009976816053144}
# INFO | HPO epoch  60/80 | loss=0.1703 | val={'ROC-AUC': 0.7220084668242608, 'PRC-AUC': 0.2953577592018413}
# INFO | Early stop at epoch 60 (patience=15)
# INFO | LSTM HPO — trial 3/10 finished | val=-0.724303 | best=-0.746716
# INFO | LSTM — starting trial 4/10
# INFO | HPO epoch   1/80 | loss=0.3761 | val={'ROC-AUC': 0.5439161026561361, 'PRC-AUC': 0.127954386964327}
# INFO | HPO epoch   5/80 | loss=0.2161 | val={'ROC-AUC': 0.6526700255174839, 'PRC-AUC': 0.21169116359380089}
# INFO | HPO epoch  10/80 | loss=0.1981 | val={'ROC-AUC': 0.7009003890937816, 'PRC-AUC': 0.2630619869811008}
# INFO | HPO epoch  15/80 | loss=0.1919 | val={'ROC-AUC': 0.6937022596272415, 'PRC-AUC': 0.26802688882442366}
# INFO | HPO epoch  20/80 | loss=0.1833 | val={'ROC-AUC': 0.7142875405680574, 'PRC-AUC': 0.2805656365032347}
# INFO | HPO epoch  25/80 | loss=0.1768 | val={'ROC-AUC': 0.7127692122815458, 'PRC-AUC': 0.28288936893988986}
# INFO | HPO epoch  30/80 | loss=0.1720 | val={'ROC-AUC': 0.7212242877025394, 'PRC-AUC': 0.29099561016771347}
# INFO | HPO epoch  35/80 | loss=0.1675 | val={'ROC-AUC': 0.7223392802030458, 'PRC-AUC': 0.29673209773459736}
# INFO | HPO epoch  40/80 | loss=0.1643 | val={'ROC-AUC': 0.6996726816985509, 'PRC-AUC': 0.27989385285368634}
# INFO | HPO epoch  45/80 | loss=0.1605 | val={'ROC-AUC': 0.7189919865271032, 'PRC-AUC': 0.2874448317800159}
# INFO | HPO epoch  50/80 | loss=0.1518 | val={'ROC-AUC': 0.7096731802413044, 'PRC-AUC': 0.29463480863732366}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | LSTM HPO — trial 4/10 finished | val=-0.722339 | best=-0.746716
# INFO | LSTM — starting trial 5/10
# INFO | HPO epoch   1/80 | loss=0.2780 | val={'ROC-AUC': 0.5883716520823553, 'PRC-AUC': 0.15590400739963614}
# INFO | HPO epoch   5/80 | loss=0.2025 | val={'ROC-AUC': 0.7078286721285623, 'PRC-AUC': 0.27890433239393236}
# INFO | HPO epoch  10/80 | loss=0.1862 | val={'ROC-AUC': 0.7207117523545817, 'PRC-AUC': 0.28587927837885907}
# INFO | HPO epoch  15/80 | loss=0.1721 | val={'ROC-AUC': 0.7277897477117033, 'PRC-AUC': 0.31447572772048105}
# INFO | HPO epoch  20/80 | loss=0.1677 | val={'ROC-AUC': 0.729027565294807, 'PRC-AUC': 0.31810097039602764}
# INFO | HPO epoch  25/80 | loss=0.1649 | val={'ROC-AUC': 0.7287778938463556, 'PRC-AUC': 0.30693512346911256}
# INFO | HPO epoch  30/80 | loss=0.1578 | val={'ROC-AUC': 0.7187274581357289, 'PRC-AUC': 0.3087584373464049}
# INFO | HPO epoch  35/80 | loss=0.1543 | val={'ROC-AUC': 0.7417482676300717, 'PRC-AUC': 0.31492222522029195}
# INFO | HPO epoch  40/80 | loss=0.1492 | val={'ROC-AUC': 0.7325093675184062, 'PRC-AUC': 0.30624689660024995}
# INFO | HPO epoch  45/80 | loss=0.1460 | val={'ROC-AUC': 0.7319432165674457, 'PRC-AUC': 0.31167205015744587}
# INFO | HPO epoch  50/80 | loss=0.1336 | val={'ROC-AUC': 0.7242780088537103, 'PRC-AUC': 0.30611149086318545}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | LSTM HPO — trial 5/10 finished | val=-0.741748 | best=-0.746716
# INFO | LSTM — starting trial 6/10
# INFO | HPO epoch   1/80 | loss=0.4705 | val={'ROC-AUC': 0.5212785298097194, 'PRC-AUC': 0.11984113468281758}
# INFO | HPO epoch   5/80 | loss=0.2240 | val={'ROC-AUC': 0.6308981656467815, 'PRC-AUC': 0.1829721832300991}
# INFO | HPO epoch  10/80 | loss=0.2060 | val={'ROC-AUC': 0.6964841883150723, 'PRC-AUC': 0.2558311365184132}
# INFO | HPO epoch  15/80 | loss=0.1957 | val={'ROC-AUC': 0.7083618272184129, 'PRC-AUC': 0.2873550068854856}
# INFO | HPO epoch  20/80 | loss=0.1889 | val={'ROC-AUC': 0.7242484683449438, 'PRC-AUC': 0.2959147218256634}
# INFO | HPO epoch  25/80 | loss=0.1821 | val={'ROC-AUC': 0.7219374896176917, 'PRC-AUC': 0.2879244228208429}
# INFO | HPO epoch  30/80 | loss=0.1760 | val={'ROC-AUC': 0.7268747793903555, 'PRC-AUC': 0.28970181032965886}
# INFO | HPO epoch  35/80 | loss=0.1714 | val={'ROC-AUC': 0.7207898771057234, 'PRC-AUC': 0.2809802946607898}
# INFO | HPO epoch  40/80 | loss=0.1692 | val={'ROC-AUC': 0.7361028339735561, 'PRC-AUC': 0.3002558919131964}
# INFO | HPO epoch  45/80 | loss=0.1640 | val={'ROC-AUC': 0.7280411290860997, 'PRC-AUC': 0.29910815316545886}
# INFO | HPO epoch  50/80 | loss=0.1612 | val={'ROC-AUC': 0.7287416611296188, 'PRC-AUC': 0.30726906051470204}
# INFO | HPO epoch  55/80 | loss=0.1546 | val={'ROC-AUC': 0.736393574421876, 'PRC-AUC': 0.3085588199632879}
# INFO | HPO epoch  60/80 | loss=0.1522 | val={'ROC-AUC': 0.7351385399523411, 'PRC-AUC': 0.30547093369771217}
# INFO | HPO epoch  65/80 | loss=0.1491 | val={'ROC-AUC': 0.7308714179433723, 'PRC-AUC': 0.30274327474637364}
# INFO | HPO epoch  70/80 | loss=0.1460 | val={'ROC-AUC': 0.7340978921143037, 'PRC-AUC': 0.30723045857284664}
# INFO | Early stop at epoch 72 (patience=15)
# INFO | LSTM HPO — trial 6/10 finished | val=-0.738284 | best=-0.746716
# INFO | LSTM — starting trial 7/10
# INFO | HPO epoch   1/80 | loss=0.3701 | val={'ROC-AUC': 0.5639285340916453, 'PRC-AUC': 0.12745123272114606}
# INFO | HPO epoch   5/80 | loss=0.2140 | val={'ROC-AUC': 0.6572323426633857, 'PRC-AUC': 0.20926022774910766}
# INFO | HPO epoch  10/80 | loss=0.1958 | val={'ROC-AUC': 0.6834975069963547, 'PRC-AUC': 0.2694066566358723}
# INFO | HPO epoch  15/80 | loss=0.1821 | val={'ROC-AUC': 0.6853369854155996, 'PRC-AUC': 0.27727236295765734}
# INFO | HPO epoch  20/80 | loss=0.1724 | val={'ROC-AUC': 0.7110897697729283, 'PRC-AUC': 0.2924940030765743}
# INFO | HPO epoch  25/80 | loss=0.1624 | val={'ROC-AUC': 0.7193021031831263, 'PRC-AUC': 0.30527790482425093}
# INFO | HPO epoch  30/80 | loss=0.1535 | val={'ROC-AUC': 0.7299220327315866, 'PRC-AUC': 0.31266600197749245}
# INFO | HPO epoch  35/80 | loss=0.1426 | val={'ROC-AUC': 0.7219513039154611, 'PRC-AUC': 0.31682416167851263}
# INFO | HPO epoch  40/80 | loss=0.1375 | val={'ROC-AUC': 0.7383465659684189, 'PRC-AUC': 0.32423359814284}
# INFO | HPO epoch  45/80 | loss=0.1265 | val={'ROC-AUC': 0.7394723479876371, 'PRC-AUC': 0.3183238669741865}
# INFO | HPO epoch  50/80 | loss=0.1213 | val={'ROC-AUC': 0.7191950182781085, 'PRC-AUC': 0.30604763473700153}
# INFO | HPO epoch  55/80 | loss=0.1076 | val={'ROC-AUC': 0.7243440903758791, 'PRC-AUC': 0.31530261434885765}
# INFO | HPO epoch  60/80 | loss=0.0937 | val={'ROC-AUC': 0.7281751954828621, 'PRC-AUC': 0.32683782884488194}
# INFO | Early stop at epoch 60 (patience=15)
# INFO | LSTM HPO — trial 7/10 finished | val=-0.739472 | best=-0.746716
# INFO | LSTM — starting trial 8/10
# INFO | HPO epoch   1/80 | loss=0.3232 | val={'ROC-AUC': 0.5859091224621517, 'PRC-AUC': 0.14210926067818527}
# INFO | HPO epoch   5/80 | loss=0.2193 | val={'ROC-AUC': 0.6405903253767272, 'PRC-AUC': 0.20372747716176032}
# INFO | HPO epoch  10/80 | loss=0.2122 | val={'ROC-AUC': 0.6689692113846458, 'PRC-AUC': 0.239844601986171}
# INFO | HPO epoch  15/80 | loss=0.2108 | val={'ROC-AUC': 0.6600759929335688, 'PRC-AUC': 0.22836619246700407}
# INFO | HPO epoch  20/80 | loss=0.2111 | val={'ROC-AUC': 0.666179741936735, 'PRC-AUC': 0.2249650990279788}
# INFO | HPO epoch  25/80 | loss=0.2084 | val={'ROC-AUC': 0.6777694305311336, 'PRC-AUC': 0.23812249743562577}
# INFO | HPO epoch  30/80 | loss=0.2096 | val={'ROC-AUC': 0.6781857784175679, 'PRC-AUC': 0.24756246885288305}
# INFO | HPO epoch  35/80 | loss=0.2085 | val={'ROC-AUC': 0.676582049187081, 'PRC-AUC': 0.2452248368351312}
# INFO | HPO epoch  40/80 | loss=0.2098 | val={'ROC-AUC': 0.6785472508144811, 'PRC-AUC': 0.24414970558028726}
# INFO | HPO epoch  45/80 | loss=0.2075 | val={'ROC-AUC': 0.6811260648622895, 'PRC-AUC': 0.2482364870144483}
# INFO | Early stop at epoch 46 (patience=15)
# INFO | LSTM HPO — trial 8/10 finished | val=-0.684682 | best=-0.746716
# INFO | LSTM — starting trial 9/10
# INFO | HPO epoch   1/80 | loss=0.5153 | val={'ROC-AUC': 0.5113229932426988, 'PRC-AUC': 0.1112355853580353}
# INFO | HPO epoch   5/80 | loss=0.2317 | val={'ROC-AUC': 0.6180830085330412, 'PRC-AUC': 0.16502787910854985}
# INFO | HPO epoch  10/80 | loss=0.2066 | val={'ROC-AUC': 0.672771614399474, 'PRC-AUC': 0.24822123407688124}
# INFO | HPO epoch  15/80 | loss=0.1923 | val={'ROC-AUC': 0.6956221534779948, 'PRC-AUC': 0.2791584850211834}
# INFO | HPO epoch  20/80 | loss=0.1829 | val={'ROC-AUC': 0.7090180172368776, 'PRC-AUC': 0.28918402871900933}
# INFO | HPO epoch  25/80 | loss=0.1753 | val={'ROC-AUC': 0.7215697511220562, 'PRC-AUC': 0.3055110981033762}
# INFO | HPO epoch  30/80 | loss=0.1680 | val={'ROC-AUC': 0.7175808808996672, 'PRC-AUC': 0.302233019095338}
# INFO | HPO epoch  35/80 | loss=0.1626 | val={'ROC-AUC': 0.7198975047418767, 'PRC-AUC': 0.30555685356360063}
# INFO | HPO epoch  40/80 | loss=0.1550 | val={'ROC-AUC': 0.7223153138591689, 'PRC-AUC': 0.2984437669354395}
# INFO | HPO epoch  45/80 | loss=0.1516 | val={'ROC-AUC': 0.7241642560117586, 'PRC-AUC': 0.30238341380411143}
# INFO | HPO epoch  50/80 | loss=0.1480 | val={'ROC-AUC': 0.7223264598966624, 'PRC-AUC': 0.29604792587904033}
# INFO | HPO epoch  55/80 | loss=0.1450 | val={'ROC-AUC': 0.7204567173349424, 'PRC-AUC': 0.3050072344765865}
# INFO | HPO epoch  60/80 | loss=0.1411 | val={'ROC-AUC': 0.7185305847682915, 'PRC-AUC': 0.3076353084280035}
# INFO | Early stop at epoch 62 (patience=15)
# INFO | LSTM HPO — trial 9/10 finished | val=-0.726452 | best=-0.746716
# INFO | LSTM — starting trial 10/10
# INFO | HPO epoch   1/80 | loss=0.3588 | val={'ROC-AUC': 0.5737217845944711, 'PRC-AUC': 0.14057735249925737}
# INFO | HPO epoch   5/80 | loss=0.2100 | val={'ROC-AUC': 0.6733663701893247, 'PRC-AUC': 0.24614680928964983}
# INFO | HPO epoch  10/80 | loss=0.1927 | val={'ROC-AUC': 0.7106701150459086, 'PRC-AUC': 0.27211799839889844}
# INFO | HPO epoch  15/80 | loss=0.1816 | val={'ROC-AUC': 0.7273285283465718, 'PRC-AUC': 0.3107705463593989}
# INFO | HPO epoch  20/80 | loss=0.1723 | val={'ROC-AUC': 0.7226790829405871, 'PRC-AUC': 0.3076788157783574}
# INFO | HPO epoch  25/80 | loss=0.1656 | val={'ROC-AUC': 0.7345700668410126, 'PRC-AUC': 0.308160428576395}
# INFO | HPO epoch  30/80 | loss=0.1585 | val={'ROC-AUC': 0.7373477388843273, 'PRC-AUC': 0.3055274231344815}
# INFO | HPO epoch  35/80 | loss=0.1530 | val={'ROC-AUC': 0.738242421297024, 'PRC-AUC': 0.3172809977094555}
# INFO | HPO epoch  40/80 | loss=0.1475 | val={'ROC-AUC': 0.7404875871707012, 'PRC-AUC': 0.3202637260731473}
# INFO | HPO epoch  45/80 | loss=0.1324 | val={'ROC-AUC': 0.7320341249266683, 'PRC-AUC': 0.3046834000135237}
# INFO | Early stop at epoch 46 (patience=15)
# INFO | LSTM HPO — trial 10/10 finished | val=-0.746275 | best=-0.746716
# INFO | Epoch  10 | loss=0.1777 | val={'ROC-AUC': 0.7367020918537106, 'PRC-AUC': 0.32140774737733324}
# INFO | Epoch  20 | loss=0.1505 | val={'ROC-AUC': 0.7356314798293043, 'PRC-AUC': 0.33479707788041124}
# INFO | Epoch  30 | loss=0.1281 | val={'ROC-AUC': 0.7188225816498933, 'PRC-AUC': 0.3189382283354059}
# INFO | Epoch  40 | loss=0.1090 | val={'ROC-AUC': 0.7172043734874548, 'PRC-AUC': 0.3318851278670992}
# INFO | Epoch  50 | loss=0.0959 | val={'ROC-AUC': 0.7079605110013484, 'PRC-AUC': 0.3060730268531236}
# INFO | Epoch  60 | loss=0.0890 | val={'ROC-AUC': 0.7030403787604335, 'PRC-AUC': 0.31050494313192395}
# INFO | Epoch  70 | loss=0.0855 | val={'ROC-AUC': 0.6988770094916287, 'PRC-AUC': 0.29990119864476955}
# INFO | Epoch  80 | loss=0.0830 | val={'ROC-AUC': 0.6964896297736387, 'PRC-AUC': 0.29786314299567346}
# INFO | Saved SMILES LSTM → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/tox21_partial.json
#    scaffold test: {'ROC-AUC': 0.7541693239889872, 'PRC-AUC': 0.32850018205554116}

# %% [markdown]
# ### Finalize GPU + merge

# %%
finalize_dataset_results(DATASET_SLUG, PARTIAL_PATH, RESULTS_DIR, TASK_TYPE,
    plot_title=f"Tox21 – Mean ROC-AUC by Model (higher is better) (GPU, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="Mean ROC-AUC", minimize=False)
cpu_partial = RESULTS_ROOT / "cpu" / f"{DATASET_SLUG}_partial.json"
if cpu_partial.exists():
    merge_combined_results(DATASET_SLUG, cpu_partial, PARTIAL_PATH, RESULTS_ROOT / "combined",
        TASK_TYPE, plot_title=f"Tox21 – Mean ROC-AUC by Model (higher is better) (all models, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="Mean ROC-AUC", minimize=False)
else:
    print("Run CPU notebook first for combined results.")
# Out:
# === TOX21 Results (5/12 models) ===
#                             ROC-AUC          PRC-AUC
# Model
# GIN (2D)            0.7112 ± 0.0000  0.2968 ± 0.0000
# D-MPNN (2D)         0.7222 ± 0.0000  0.3210 ± 0.0000
# GIN (3D)            0.8222 ± 0.0000  0.4205 ± 0.0000
# SchNet (3D coords)  0.7826 ± 0.0000  0.3129 ± 0.0000
# SMILES LSTM         0.7542 ± 0.0000  0.3285 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/tox21_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/tox21_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/tox21_partial.json
# === TOX21 Results (12/12 models) ===
#                                ROC-AUC          PRC-AUC
# Model
# Morgan + RF            0.7311 ± 0.0000  0.3745 ± 0.0000
# Morgan + SVM           0.6692 ± 0.0000  0.2853 ± 0.0000
# Morgan + XGBoost       0.7310 ± 0.0000  0.3499 ± 0.0000
# Descriptors + RF       0.7840 ± 0.0000  0.4169 ± 0.0000
# Descriptors + SVM      0.7576 ± 0.0000  0.3918 ± 0.0000
# Descriptors + XGBoost  0.7868 ± 0.0000  0.4135 ± 0.0000
# Combined + XGBoost     0.7858 ± 0.0000  0.4249 ± 0.0000
# GIN (2D)               0.7112 ± 0.0000  0.2968 ± 0.0000
# D-MPNN (2D)            0.7222 ± 0.0000  0.3210 ± 0.0000
# GIN (3D)               0.8222 ± 0.0000  0.4205 ± 0.0000
# SchNet (3D coords)     0.7826 ± 0.0000  0.3129 ± 0.0000
# SMILES LSTM            0.7542 ± 0.0000  0.3285 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/combined/tox21_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/combined/tox21_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/combined/tox21_partial.json
