# %% [markdown]
# # Benchmark v5 — GPU — BACE — scaffold split, seed 1
#
# **Task:** Binary — binds BACE-1 (1) or not (0)
# **Size:** ~1,513 molecules
# **Metric:** ROC-AUC ↑
#
# **Scaffold split**, seed **1** — GIN, D-MPNN, SchNet, LSTM with Optuna HPO.
#
# Results go to `results/seed_1/scaffold/`.

# %%
# NOTE: autoreload is intentionally NOT enabled. With C-extension packages
# (numpy, torch, torch_geometric) `%autoreload 2` reloads them mid-run and
# corrupts their state (numpy RecursionError / torch_geometric circular
# import). If you edit the benchmark modules, restart the kernel instead.
import os
# Avoid XGBoost/OpenMP segfaults in Jupyter on macOS (OMP Error #179).
for _omp_var in (
    "OMP_NUM_THREADS",
    "OPENBLAS_NUM_THREADS",
    "MKL_NUM_THREADS",
    "VECLIB_MAXIMUM_THREADS",
    "NUMEXPR_NUM_THREADS",
):
    os.environ[_omp_var] = "1"

import sys
from pathlib import Path

ROOT = Path(".").resolve()
for _ in range(6):
    if (ROOT / "mol_repr_utils.py").exists():
        break
    ROOT = ROOT.parent
else:
    raise FileNotFoundError("Could not find benchmark_v5 root (mol_repr_utils.py)")
sys.path.insert(0, str(ROOT))

from mol_repr_utils import *
from split_utils import (
    get_or_create_splits, subset_array, subset_list, subset_graphs_by_valid_idx,
    check_split_proportions,
)
from conformer_generation import load_conformer_graphs
from hpo_utils import (
    hpo_tabular, hpo_gnn, hpo_schnet, hpo_lstm,
    save_hpo_params, hpo_params_path,
)
from hpo_config import SKLEARN_HPO_N_ITER

DATA_DIR = ROOT / "data"

DEVICE = get_device()
print(f"Benchmark v5 (GPU) code root: {ROOT}")
print(f"Device: {DEVICE}")
print("Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.")
# Out:
# INFO | Using device: cpu (request a GPU node on the cluster for large GNN/LSTM jobs)
# Benchmark v5 (GPU) code root: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5
# Device: cpu
# Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.

# %%
DATASET_SLUG = "bace"
TASK_TYPE = "classification"
OUT_CHANNELS = 1
BATCH_SIZE = 32
GNN_EPOCHS = 100
LSTM_EPOCHS = 100
TOX21_TABULAR = False

HPO_EPOCHS = 80  # Optuna trial length; GNN_EPOCHS for final refit
HPO_N_TRIALS = 20
print(f"GPU HPO tier: standard — {HPO_N_TRIALS} trials, {HPO_EPOCHS} epochs/trial, batch={BATCH_SIZE}")

SPLIT_MODE = "scaffold"   # "scaffold" or "random"
SPLIT_SEED = 1

RESULTS_ROOT = ROOT / "results" / f"seed_{SPLIT_SEED}" / SPLIT_MODE
RESULTS_DIR = RESULTS_ROOT / "gpu"
SPLITS_DIR = RESULTS_ROOT / "splits"
HPO_DIR = RESULTS_DIR / "hpo"
HISTORY_DIR = RESULTS_DIR / "histories"
for d in (RESULTS_DIR, SPLITS_DIR, HPO_DIR, HISTORY_DIR):
    d.mkdir(parents=True, exist_ok=True)
print(f"Results → {RESULTS_ROOT}")

PARTIAL_PATH = RESULTS_DIR / f"{DATASET_SLUG}_partial.json"
FRESH_RUN = False
HPO_N_ITER = SKLEARN_HPO_N_ITER

if FRESH_RUN:
    reset_dataset_run(
        DATASET_SLUG, RESULTS_DIR,
        results_root=RESULTS_ROOT, split_mode=SPLIT_MODE,
    )
    print("Fresh run — cleared partial results and splits.")

results = load_partial_results(PARTIAL_PATH)
if results:
    print(f"Resuming {len(results)} saved model(s): {', '.join(order_results(results).keys())}")
print(f"SPLIT_SEED={SPLIT_SEED}  mode={SPLIT_MODE}")
# Out:
# GPU HPO tier: standard — 20 trials, 80 epochs/trial, batch=32
# Results → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold
# Resuming 2 saved model(s): GIN (2D), D-MPNN (2D)
# SPLIT_SEED=1  mode=scaffold

# %% [markdown]
# ### Load data

# %%
import numpy as np
import pandas as pd

df = load_dataset("bace", cache_dir=DATA_DIR)
smiles, y = preprocess_dataset(df, "bace")
print(f"Molecules : {len(smiles)}")
print(f"Class balance: {np.bincount(y.astype(int))}")
smiles, y = filter_bonded_molecules(smiles, y)
print(f'After bond filter: {len(smiles)} molecules')
# Out:
# INFO | Loading 'bace' from cache: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace.csv
# INFO | [bace] 1513 / 1513 valid molecules
# Molecules : 1513
# Class balance: [822 691]
# After bond filter: 1513 molecules

# %% [markdown]
# ### Representations & scaffold split

# %%
graphs2d_all = smiles_to_graphs(smiles, y)
graphs_dmpnn_all = smiles_to_dmpnn_graphs(smiles, y)
X_tok_all, vocab = tokenize_smiles(smiles)

graphs3d_all, valid_idx_3d, _ = load_conformer_graphs(
    DATASET_SLUG, data_dir=DATA_DIR, n_confs=25
)
graphs3d_all = ensure_atomic_numbers_list(graphs3d_all)
print(f"3D graphs loaded: {len(graphs3d_all)} / {len(smiles)} (valid_idx mapping)")

split_data = get_or_create_splits(
    smiles, RESULTS_ROOT, DATASET_SLUG,
    mode=SPLIT_MODE, seed=SPLIT_SEED, force=FRESH_RUN,
)
train_idx = split_data["train_idx"]
val_idx = split_data["val_idx"]
test_idx = split_data["test_idx"]
check_split_proportions(train_idx, val_idx, test_idx, raise_on_fail=True)
print(split_data["summary"])

tr2d = subset_list(graphs2d_all, train_idx)
va2d = subset_list(graphs2d_all, val_idx)
te2d = subset_list(graphs2d_all, test_idx)

tr_dmpnn = subset_list(graphs_dmpnn_all, train_idx)
va_dmpnn = subset_list(graphs_dmpnn_all, val_idx)
te_dmpnn = subset_list(graphs_dmpnn_all, test_idx)

tr3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, train_idx)
va3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, val_idx)
te3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, test_idx)

tr_ds = SMILESDataset(subset_array(X_tok_all, train_idx), subset_array(y, train_idx))
va_ds = SMILESDataset(subset_array(X_tok_all, val_idx), subset_array(y, val_idx))
te_ds = SMILESDataset(subset_array(X_tok_all, test_idx), subset_array(y, test_idx))
# Out:
# INFO | Loaded 1513 / 1513 graphs from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace_conformers_n25.pkl  (n_confs=25)
# INFO | Loaded splits from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/splits/bace_scaffold_splits.pkl
# 3D graphs loaded: 1513 / 1513 (valid_idx mapping)
# {'n_total': 1513, 'n_train': 1210, 'n_val': 151, 'n_test': 152, 'n_scaffolds_total': 671, 'n_scaffolds_train': 368, 'n_scaffolds_val': 151, 'n_scaffolds_test': 152}

# %% [markdown]
# ### GIN (2D)

# %%
MODEL_KEY = "GIN (2D)"
tr = tr3d if "2D" == "3D" else tr2d
va = va3d if "2D" == "3D" else va2d
te = te3d if "2D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (2D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# Skipping GIN (2D)

# %% [markdown]
# ### D-MPNN (2D)
# Bond-centric directed MPNN (Yang et al. 2019).

# %%
MODEL_KEY = "D-MPNN (2D)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr_dmpnn, va_dmpnn, TASK_TYPE, "DMPNN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("DMPNN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr_dmpnn, va_dmpnn, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te_dmpnn, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_dmpnn.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# Skipping D-MPNN (2D)

# %% [markdown]
# ### GIN (3D)

# %%
MODEL_KEY = "GIN (3D)"
tr = tr3d if "3D" == "3D" else tr2d
va = va3d if "3D" == "3D" else va2d
te = te3d if "3D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "3D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "3D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (3D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | GIN 3D — starting trial 1/20 (layers=3, hidden=192)
# → GIN (3D) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=1.1668 | val={'ROC-AUC': 0.702156862745098, 'PRC-AUC': 0.5792127996353478}
# INFO | HPO epoch   5/80 | loss=0.5472 | val={'ROC-AUC': 0.7952941176470588, 'PRC-AUC': 0.5899826125772907}
# INFO | HPO epoch  10/80 | loss=0.5116 | val={'ROC-AUC': 0.7756862745098039, 'PRC-AUC': 0.6314833632433072}
# INFO | HPO epoch  15/80 | loss=0.4674 | val={'ROC-AUC': 0.8570588235294119, 'PRC-AUC': 0.7293205016700057}
# INFO | HPO epoch  20/80 | loss=0.4233 | val={'ROC-AUC': 0.840392156862745, 'PRC-AUC': 0.7571860198926856}
# INFO | HPO epoch  25/80 | loss=0.4081 | val={'ROC-AUC': 0.8192156862745098, 'PRC-AUC': 0.7157031590446993}
# INFO | HPO epoch  30/80 | loss=0.3726 | val={'ROC-AUC': 0.8401960784313726, 'PRC-AUC': 0.7697803138702347}
# INFO | Early stop at epoch 33 (patience=15)
# INFO | GIN 3D HPO — trial 1/20 finished | val=-0.877647 | best=-0.877647
# INFO | GIN 3D — starting trial 2/20 (layers=5, hidden=192)
# INFO | HPO epoch   1/80 | loss=1.2662 | val={'ROC-AUC': 0.755686274509804, 'PRC-AUC': 0.5612678147959751}
# INFO | HPO epoch   5/80 | loss=0.6297 | val={'ROC-AUC': 0.8150980392156862, 'PRC-AUC': 0.6843346184947618}
# INFO | HPO epoch  10/80 | loss=0.5604 | val={'ROC-AUC': 0.8427450980392157, 'PRC-AUC': 0.7871026061380862}
# INFO | HPO epoch  15/80 | loss=0.4868 | val={'ROC-AUC': 0.8394117647058822, 'PRC-AUC': 0.7771257749304088}
# INFO | HPO epoch  20/80 | loss=0.4843 | val={'ROC-AUC': 0.838235294117647, 'PRC-AUC': 0.7707884253320241}
# INFO | HPO epoch  25/80 | loss=0.4567 | val={'ROC-AUC': 0.8556862745098038, 'PRC-AUC': 0.7780539189316668}
# INFO | HPO epoch  30/80 | loss=0.4202 | val={'ROC-AUC': 0.8484313725490196, 'PRC-AUC': 0.7035134154933926}
# INFO | HPO epoch  35/80 | loss=0.4175 | val={'ROC-AUC': 0.8539215686274509, 'PRC-AUC': 0.7227324610327159}
# INFO | HPO epoch  40/80 | loss=0.4004 | val={'ROC-AUC': 0.8584313725490196, 'PRC-AUC': 0.7301066431298048}
# INFO | HPO epoch  45/80 | loss=0.3861 | val={'ROC-AUC': 0.8594117647058824, 'PRC-AUC': 0.7118744712484406}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | GIN 3D HPO — trial 2/20 finished | val=-0.871176 | best=-0.877647
# INFO | GIN 3D — starting trial 3/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.0039 | val={'ROC-AUC': 0.6423529411764706, 'PRC-AUC': 0.4821047451153959}
# INFO | HPO epoch   5/80 | loss=0.5512 | val={'ROC-AUC': 0.7217647058823529, 'PRC-AUC': 0.5588603949242793}
# INFO | HPO epoch  10/80 | loss=0.5362 | val={'ROC-AUC': 0.7864705882352941, 'PRC-AUC': 0.6685879327018549}
# INFO | HPO epoch  15/80 | loss=0.4679 | val={'ROC-AUC': 0.8037254901960784, 'PRC-AUC': 0.7025656063136767}
# INFO | HPO epoch  20/80 | loss=0.4379 | val={'ROC-AUC': 0.7909803921568627, 'PRC-AUC': 0.6791989655107441}
# INFO | HPO epoch  25/80 | loss=0.4189 | val={'ROC-AUC': 0.8182352941176471, 'PRC-AUC': 0.7050678750020952}
# INFO | HPO epoch  30/80 | loss=0.4055 | val={'ROC-AUC': 0.8629411764705883, 'PRC-AUC': 0.7561060465196724}
# INFO | HPO epoch  35/80 | loss=0.3986 | val={'ROC-AUC': 0.8539215686274508, 'PRC-AUC': 0.7532790151465303}
# INFO | HPO epoch  40/80 | loss=0.3434 | val={'ROC-AUC': 0.861764705882353, 'PRC-AUC': 0.7829145365393182}
# INFO | Early stop at epoch 42 (patience=15)
# INFO | GIN 3D HPO — trial 3/20 finished | val=-0.886863 | best=-0.886863
# INFO | GIN 3D — starting trial 4/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.8863 | val={'ROC-AUC': 0.6523529411764706, 'PRC-AUC': 0.4905857691817619}
# INFO | HPO epoch   5/80 | loss=0.6219 | val={'ROC-AUC': 0.7809803921568628, 'PRC-AUC': 0.6059360729164291}
# INFO | HPO epoch  10/80 | loss=0.4930 | val={'ROC-AUC': 0.8454901960784313, 'PRC-AUC': 0.7408867467322985}
# INFO | HPO epoch  15/80 | loss=0.4622 | val={'ROC-AUC': 0.7927450980392157, 'PRC-AUC': 0.6792095121886143}
# INFO | HPO epoch  20/80 | loss=0.4413 | val={'ROC-AUC': 0.7629411764705882, 'PRC-AUC': 0.5953592604869711}
# INFO | HPO epoch  25/80 | loss=0.4376 | val={'ROC-AUC': 0.7668627450980392, 'PRC-AUC': 0.5913542342838756}
# INFO | HPO epoch  30/80 | loss=0.3889 | val={'ROC-AUC': 0.874313725490196, 'PRC-AUC': 0.7789009961579273}
# INFO | HPO epoch  35/80 | loss=0.3738 | val={'ROC-AUC': 0.8529411764705882, 'PRC-AUC': 0.7737446213935762}
# INFO | HPO epoch  40/80 | loss=0.3503 | val={'ROC-AUC': 0.8596078431372549, 'PRC-AUC': 0.77798787661892}
# INFO | HPO epoch  45/80 | loss=0.3335 | val={'ROC-AUC': 0.8633333333333333, 'PRC-AUC': 0.7882970151152138}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | GIN 3D HPO — trial 4/20 finished | val=-0.877647 | best=-0.886863
# INFO | GIN 3D — starting trial 5/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=2.0927 | val={'ROC-AUC': 0.5345098039215687, 'PRC-AUC': 0.39523752614705976}
# INFO | HPO epoch   5/80 | loss=0.6151 | val={'ROC-AUC': 0.6901960784313724, 'PRC-AUC': 0.5102319354509333}
# INFO | HPO epoch  10/80 | loss=0.5078 | val={'ROC-AUC': 0.8037254901960784, 'PRC-AUC': 0.6827819170838083}
# INFO | HPO epoch  15/80 | loss=0.4861 | val={'ROC-AUC': 0.806078431372549, 'PRC-AUC': 0.6249029660110166}
# INFO | HPO epoch  20/80 | loss=0.4777 | val={'ROC-AUC': 0.8574509803921568, 'PRC-AUC': 0.7455902506627369}
# INFO | HPO epoch  25/80 | loss=0.4415 | val={'ROC-AUC': 0.8056862745098039, 'PRC-AUC': 0.6334076106934989}
# INFO | HPO epoch  30/80 | loss=0.4371 | val={'ROC-AUC': 0.8462745098039216, 'PRC-AUC': 0.7499361526838643}
# INFO | HPO epoch  35/80 | loss=0.3943 | val={'ROC-AUC': 0.7854901960784314, 'PRC-AUC': 0.6594768389848434}
# INFO | HPO epoch  40/80 | loss=0.4138 | val={'ROC-AUC': 0.8439215686274509, 'PRC-AUC': 0.756213294687663}
# INFO | HPO epoch  45/80 | loss=0.3515 | val={'ROC-AUC': 0.8592156862745098, 'PRC-AUC': 0.7537549835897972}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | GIN 3D HPO — trial 5/20 finished | val=-0.882353 | best=-0.886863
# INFO | GIN 3D — starting trial 6/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.9303 | val={'ROC-AUC': 0.6888235294117647, 'PRC-AUC': 0.593520567688205}
# INFO | HPO epoch   5/80 | loss=0.5867 | val={'ROC-AUC': 0.6692156862745099, 'PRC-AUC': 0.5398883041886455}
# INFO | HPO epoch  10/80 | loss=0.5316 | val={'ROC-AUC': 0.6815686274509803, 'PRC-AUC': 0.48518216649526147}
# INFO | HPO epoch  15/80 | loss=0.4762 | val={'ROC-AUC': 0.8280392156862745, 'PRC-AUC': 0.6709271635488276}
# INFO | HPO epoch  20/80 | loss=0.4396 | val={'ROC-AUC': 0.8539215686274509, 'PRC-AUC': 0.722014872747856}
# INFO | HPO epoch  25/80 | loss=0.3876 | val={'ROC-AUC': 0.8145098039215687, 'PRC-AUC': 0.7310439139597187}
# INFO | HPO epoch  30/80 | loss=0.3766 | val={'ROC-AUC': 0.7096078431372548, 'PRC-AUC': 0.5521794668534328}
# INFO | HPO epoch  35/80 | loss=0.3813 | val={'ROC-AUC': 0.82, 'PRC-AUC': 0.6531290240319686}
# INFO | HPO epoch  40/80 | loss=0.3687 | val={'ROC-AUC': 0.8423529411764706, 'PRC-AUC': 0.7345440528770649}
# INFO | HPO epoch  45/80 | loss=0.3488 | val={'ROC-AUC': 0.8037254901960785, 'PRC-AUC': 0.6684354860694345}
# INFO | HPO epoch  50/80 | loss=0.3096 | val={'ROC-AUC': 0.864313725490196, 'PRC-AUC': 0.78008586613655}
# INFO | Early stop at epoch 51 (patience=15)
# INFO | GIN 3D HPO — trial 6/20 finished | val=-0.879412 | best=-0.886863
# INFO | GIN 3D — starting trial 7/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.0654 | val={'ROC-AUC': 0.7227450980392157, 'PRC-AUC': 0.506421811955116}
# INFO | HPO epoch   5/80 | loss=0.5774 | val={'ROC-AUC': 0.8174509803921568, 'PRC-AUC': 0.6886092905095363}
# INFO | HPO epoch  10/80 | loss=0.5392 | val={'ROC-AUC': 0.8558823529411765, 'PRC-AUC': 0.7797808940765406}
# INFO | HPO epoch  15/80 | loss=0.4909 | val={'ROC-AUC': 0.8829411764705883, 'PRC-AUC': 0.7593418129604437}
# INFO | HPO epoch  20/80 | loss=0.4590 | val={'ROC-AUC': 0.7817647058823528, 'PRC-AUC': 0.7038547714442595}
# INFO | HPO epoch  25/80 | loss=0.4265 | val={'ROC-AUC': 0.8349019607843138, 'PRC-AUC': 0.7747256168097264}
# INFO | HPO epoch  30/80 | loss=0.3890 | val={'ROC-AUC': 0.834313725490196, 'PRC-AUC': 0.732341040678321}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | GIN 3D HPO — trial 7/20 finished | val=-0.882941 | best=-0.886863
# INFO | GIN 3D — starting trial 8/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.3272 | val={'ROC-AUC': 0.51, 'PRC-AUC': 0.421670427073182}
# INFO | HPO epoch   5/80 | loss=0.5812 | val={'ROC-AUC': 0.6184313725490196, 'PRC-AUC': 0.4337072106387099}
# INFO | HPO epoch  10/80 | loss=0.5163 | val={'ROC-AUC': 0.6852941176470588, 'PRC-AUC': 0.4628366734310435}
# INFO | HPO epoch  15/80 | loss=0.4942 | val={'ROC-AUC': 0.8068627450980392, 'PRC-AUC': 0.7262744381441397}
# INFO | HPO epoch  20/80 | loss=0.5070 | val={'ROC-AUC': 0.7823529411764706, 'PRC-AUC': 0.6210935510383884}
# INFO | HPO epoch  25/80 | loss=0.4836 | val={'ROC-AUC': 0.7043137254901961, 'PRC-AUC': 0.5036604608658237}
# INFO | HPO epoch  30/80 | loss=0.4135 | val={'ROC-AUC': 0.8423529411764705, 'PRC-AUC': 0.7222327847718275}
# INFO | HPO epoch  35/80 | loss=0.4068 | val={'ROC-AUC': 0.7988235294117647, 'PRC-AUC': 0.7273484206556518}
# INFO | HPO epoch  40/80 | loss=0.4117 | val={'ROC-AUC': 0.8092156862745098, 'PRC-AUC': 0.709748869562391}
# INFO | HPO epoch  45/80 | loss=0.3969 | val={'ROC-AUC': 0.7958823529411765, 'PRC-AUC': 0.6560027386364473}
# INFO | HPO epoch  50/80 | loss=0.3843 | val={'ROC-AUC': 0.8211764705882353, 'PRC-AUC': 0.6869232374836198}
# INFO | HPO epoch  55/80 | loss=0.3817 | val={'ROC-AUC': 0.7966666666666666, 'PRC-AUC': 0.6523145242422789}
# INFO | HPO epoch  60/80 | loss=0.3812 | val={'ROC-AUC': 0.7876470588235294, 'PRC-AUC': 0.6433396454977977}
# INFO | Early stop at epoch 64 (patience=15)
# INFO | GIN 3D HPO — trial 8/20 finished | val=-0.870392 | best=-0.886863
# INFO | GIN 3D — starting trial 9/20 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.8334 | val={'ROC-AUC': 0.6833333333333333, 'PRC-AUC': 0.4856304430970064}
# INFO | HPO epoch   5/80 | loss=0.5437 | val={'ROC-AUC': 0.8066666666666668, 'PRC-AUC': 0.7523776506168939}
# INFO | HPO epoch  10/80 | loss=0.4749 | val={'ROC-AUC': 0.7807843137254903, 'PRC-AUC': 0.6720367351336479}
# INFO | HPO epoch  15/80 | loss=0.4381 | val={'ROC-AUC': 0.8658823529411765, 'PRC-AUC': 0.7694677697786025}
# INFO | HPO epoch  20/80 | loss=0.4131 | val={'ROC-AUC': 0.8449019607843138, 'PRC-AUC': 0.7480753037299193}
# INFO | Early stop at epoch 24 (patience=15)
# INFO | GIN 3D HPO — trial 9/20 finished | val=-0.867255 | best=-0.886863
# INFO | GIN 3D — starting trial 10/20 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=1.0350 | val={'ROC-AUC': 0.712549019607843, 'PRC-AUC': 0.5356446244756768}
# INFO | HPO epoch   5/80 | loss=0.5623 | val={'ROC-AUC': 0.7701960784313725, 'PRC-AUC': 0.7080832768610396}
# INFO | HPO epoch  10/80 | loss=0.5074 | val={'ROC-AUC': 0.8209803921568628, 'PRC-AUC': 0.7519222561234877}
# INFO | HPO epoch  15/80 | loss=0.4707 | val={'ROC-AUC': 0.8601960784313726, 'PRC-AUC': 0.7650513791695659}
# INFO | HPO epoch  20/80 | loss=0.4209 | val={'ROC-AUC': 0.7290196078431372, 'PRC-AUC': 0.5861533720045323}
# INFO | HPO epoch  25/80 | loss=0.3560 | val={'ROC-AUC': 0.8588235294117648, 'PRC-AUC': 0.7718807901407967}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | GIN 3D HPO — trial 10/20 finished | val=-0.864118 | best=-0.886863
# INFO | GIN 3D — starting trial 11/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7119 | val={'ROC-AUC': 0.6321568627450981, 'PRC-AUC': 0.48812171323243175}
# INFO | HPO epoch   5/80 | loss=0.5296 | val={'ROC-AUC': 0.7898039215686276, 'PRC-AUC': 0.7266496182333583}
# INFO | HPO epoch  10/80 | loss=0.4486 | val={'ROC-AUC': 0.786078431372549, 'PRC-AUC': 0.6812171268053697}
# INFO | HPO epoch  15/80 | loss=0.4026 | val={'ROC-AUC': 0.8629411764705882, 'PRC-AUC': 0.8026635840367846}
# INFO | HPO epoch  20/80 | loss=0.4069 | val={'ROC-AUC': 0.7723529411764706, 'PRC-AUC': 0.683348688251519}
# INFO | HPO epoch  25/80 | loss=0.3459 | val={'ROC-AUC': 0.8150980392156862, 'PRC-AUC': 0.7113644787024366}
# INFO | HPO epoch  30/80 | loss=0.3502 | val={'ROC-AUC': 0.8031372549019608, 'PRC-AUC': 0.6676224694873907}
# INFO | HPO epoch  35/80 | loss=0.3170 | val={'ROC-AUC': 0.854313725490196, 'PRC-AUC': 0.788401275119079}
# INFO | HPO epoch  40/80 | loss=0.2961 | val={'ROC-AUC': 0.8680392156862745, 'PRC-AUC': 0.8052279403864339}
# INFO | HPO epoch  45/80 | loss=0.3020 | val={'ROC-AUC': 0.8758823529411764, 'PRC-AUC': 0.8283256052968531}
# INFO | HPO epoch  50/80 | loss=0.2687 | val={'ROC-AUC': 0.8633333333333334, 'PRC-AUC': 0.7912893466443519}
# INFO | HPO epoch  55/80 | loss=0.2507 | val={'ROC-AUC': 0.874313725490196, 'PRC-AUC': 0.8036369202655984}
# INFO | HPO epoch  60/80 | loss=0.2493 | val={'ROC-AUC': 0.8796078431372549, 'PRC-AUC': 0.8175273298013327}
# INFO | HPO epoch  65/80 | loss=0.2406 | val={'ROC-AUC': 0.8574509803921568, 'PRC-AUC': 0.7902207971873327}
# INFO | HPO epoch  70/80 | loss=0.2355 | val={'ROC-AUC': 0.877843137254902, 'PRC-AUC': 0.8215207864331845}
# INFO | HPO epoch  75/80 | loss=0.2244 | val={'ROC-AUC': 0.8890196078431373, 'PRC-AUC': 0.8348701454515822}
# INFO | Early stop at epoch 79 (patience=15)
# INFO | GIN 3D HPO — trial 11/20 finished | val=-0.889020 | best=-0.889020
# INFO | GIN 3D — starting trial 12/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7351 | val={'ROC-AUC': 0.7749019607843137, 'PRC-AUC': 0.6196083244353908}
# INFO | HPO epoch   5/80 | loss=0.5065 | val={'ROC-AUC': 0.8637254901960785, 'PRC-AUC': 0.7156192483179349}
# INFO | HPO epoch  10/80 | loss=0.4123 | val={'ROC-AUC': 0.88, 'PRC-AUC': 0.8027878573755449}
# INFO | HPO epoch  15/80 | loss=0.3892 | val={'ROC-AUC': 0.8523529411764705, 'PRC-AUC': 0.7486261539341278}
# INFO | HPO epoch  20/80 | loss=0.3964 | val={'ROC-AUC': 0.8282352941176471, 'PRC-AUC': 0.696678591433769}
# INFO | HPO epoch  25/80 | loss=0.3414 | val={'ROC-AUC': 0.8866666666666666, 'PRC-AUC': 0.7584355772683612}
# INFO | HPO epoch  30/80 | loss=0.3237 | val={'ROC-AUC': 0.8535294117647059, 'PRC-AUC': 0.7694891009644442}
# INFO | HPO epoch  35/80 | loss=0.3145 | val={'ROC-AUC': 0.8429411764705882, 'PRC-AUC': 0.7052435320237123}
# INFO | HPO epoch  40/80 | loss=0.2815 | val={'ROC-AUC': 0.8741176470588236, 'PRC-AUC': 0.7775691699742088}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | GIN 3D HPO — trial 12/20 finished | val=-0.886667 | best=-0.889020
# INFO | GIN 3D — starting trial 13/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.9805 | val={'ROC-AUC': 0.7256862745098039, 'PRC-AUC': 0.5778209114391585}
# INFO | HPO epoch   5/80 | loss=0.4840 | val={'ROC-AUC': 0.8298039215686275, 'PRC-AUC': 0.6952746187222019}
# INFO | HPO epoch  10/80 | loss=0.4627 | val={'ROC-AUC': 0.8280392156862745, 'PRC-AUC': 0.7483484974317309}
# INFO | HPO epoch  15/80 | loss=0.3909 | val={'ROC-AUC': 0.8307843137254901, 'PRC-AUC': 0.7745279594416248}
# INFO | HPO epoch  20/80 | loss=0.3742 | val={'ROC-AUC': 0.8294117647058823, 'PRC-AUC': 0.6516889465536913}
# INFO | HPO epoch  25/80 | loss=0.3674 | val={'ROC-AUC': 0.8196078431372549, 'PRC-AUC': 0.6780005997145246}
# INFO | HPO epoch  30/80 | loss=0.3557 | val={'ROC-AUC': 0.7935294117647059, 'PRC-AUC': 0.7060767678016563}
# INFO | Early stop at epoch 34 (patience=15)
# INFO | GIN 3D HPO — trial 13/20 finished | val=-0.875490 | best=-0.889020
# INFO | GIN 3D — starting trial 14/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7483 | val={'ROC-AUC': 0.6815686274509805, 'PRC-AUC': 0.5463749013940962}
# INFO | HPO epoch   5/80 | loss=0.5429 | val={'ROC-AUC': 0.8405882352941176, 'PRC-AUC': 0.7457825388047944}
# INFO | HPO epoch  10/80 | loss=0.4851 | val={'ROC-AUC': 0.8566666666666666, 'PRC-AUC': 0.7801187974639308}
# INFO | HPO epoch  15/80 | loss=0.4543 | val={'ROC-AUC': 0.8464705882352941, 'PRC-AUC': 0.7157313131720505}
# INFO | HPO epoch  20/80 | loss=0.4124 | val={'ROC-AUC': 0.8470588235294118, 'PRC-AUC': 0.7303094685435849}
# INFO | HPO epoch  25/80 | loss=0.3865 | val={'ROC-AUC': 0.8688235294117647, 'PRC-AUC': 0.7593683945397594}
# INFO | HPO epoch  30/80 | loss=0.3627 | val={'ROC-AUC': 0.8786274509803922, 'PRC-AUC': 0.7493442918924992}
# INFO | HPO epoch  35/80 | loss=0.3600 | val={'ROC-AUC': 0.8752941176470589, 'PRC-AUC': 0.789014805064121}
# INFO | HPO epoch  40/80 | loss=0.3523 | val={'ROC-AUC': 0.871764705882353, 'PRC-AUC': 0.746671362097588}
# INFO | HPO epoch  45/80 | loss=0.3445 | val={'ROC-AUC': 0.8684313725490196, 'PRC-AUC': 0.7684371258109982}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | GIN 3D HPO — trial 14/20 finished | val=-0.878627 | best=-0.889020
# INFO | GIN 3D — starting trial 15/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7483 | val={'ROC-AUC': 0.6501960784313725, 'PRC-AUC': 0.5845936089172756}
# INFO | HPO epoch   5/80 | loss=0.5692 | val={'ROC-AUC': 0.8188235294117646, 'PRC-AUC': 0.683294894635608}
# INFO | HPO epoch  10/80 | loss=0.4969 | val={'ROC-AUC': 0.8298039215686275, 'PRC-AUC': 0.7500061497693552}
# INFO | HPO epoch  15/80 | loss=0.4566 | val={'ROC-AUC': 0.854313725490196, 'PRC-AUC': 0.7319397617762999}
# INFO | HPO epoch  20/80 | loss=0.4151 | val={'ROC-AUC': 0.8286274509803921, 'PRC-AUC': 0.7455959005096604}
# INFO | HPO epoch  25/80 | loss=0.4133 | val={'ROC-AUC': 0.8496078431372549, 'PRC-AUC': 0.6939699297808143}
# INFO | HPO epoch  30/80 | loss=0.3938 | val={'ROC-AUC': 0.8533333333333334, 'PRC-AUC': 0.759672157172536}
# INFO | HPO epoch  35/80 | loss=0.3856 | val={'ROC-AUC': 0.8535294117647059, 'PRC-AUC': 0.7374639437635033}
# INFO | HPO epoch  40/80 | loss=0.3566 | val={'ROC-AUC': 0.8692156862745097, 'PRC-AUC': 0.7710340593032895}
# INFO | HPO epoch  45/80 | loss=0.3498 | val={'ROC-AUC': 0.8723529411764706, 'PRC-AUC': 0.7950168986339909}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | GIN 3D HPO — trial 15/20 finished | val=-0.884118 | best=-0.889020
# INFO | GIN 3D — starting trial 16/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.9919 | val={'ROC-AUC': 0.7441176470588234, 'PRC-AUC': 0.5783945113665642}
# INFO | HPO epoch   5/80 | loss=0.5830 | val={'ROC-AUC': 0.8550980392156862, 'PRC-AUC': 0.7386366703414948}
# INFO | HPO epoch  10/80 | loss=0.5029 | val={'ROC-AUC': 0.8443137254901961, 'PRC-AUC': 0.7541290687403632}
# INFO | HPO epoch  15/80 | loss=0.4304 | val={'ROC-AUC': 0.8298039215686275, 'PRC-AUC': 0.7284778239856746}
# INFO | HPO epoch  20/80 | loss=0.4597 | val={'ROC-AUC': 0.8288235294117646, 'PRC-AUC': 0.6401449660736082}
# INFO | HPO epoch  25/80 | loss=0.4144 | val={'ROC-AUC': 0.8911764705882353, 'PRC-AUC': 0.8143271564235927}
# INFO | HPO epoch  30/80 | loss=0.4136 | val={'ROC-AUC': 0.8749019607843137, 'PRC-AUC': 0.752903704645168}
# INFO | HPO epoch  35/80 | loss=0.3964 | val={'ROC-AUC': 0.8515686274509804, 'PRC-AUC': 0.7540928119909657}
# INFO | HPO epoch  40/80 | loss=0.3705 | val={'ROC-AUC': 0.8590196078431372, 'PRC-AUC': 0.7569432704519341}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | GIN 3D HPO — trial 16/20 finished | val=-0.895098 | best=-0.895098
# INFO | GIN 3D — starting trial 17/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.7400 | val={'ROC-AUC': 0.7558823529411764, 'PRC-AUC': 0.5591496631361388}
# INFO | HPO epoch   5/80 | loss=0.5365 | val={'ROC-AUC': 0.8096078431372549, 'PRC-AUC': 0.6619632542065647}
# INFO | HPO epoch  10/80 | loss=0.4110 | val={'ROC-AUC': 0.8227450980392157, 'PRC-AUC': 0.6779481345097086}
# INFO | HPO epoch  15/80 | loss=0.4160 | val={'ROC-AUC': 0.8470588235294119, 'PRC-AUC': 0.6973584317196734}
# INFO | HPO epoch  20/80 | loss=0.3397 | val={'ROC-AUC': 0.8500000000000001, 'PRC-AUC': 0.7321886735130779}
# INFO | HPO epoch  25/80 | loss=0.3216 | val={'ROC-AUC': 0.8717647058823529, 'PRC-AUC': 0.7983452513790629}
# INFO | HPO epoch  30/80 | loss=0.3187 | val={'ROC-AUC': 0.8307843137254902, 'PRC-AUC': 0.7126935342020326}
# INFO | HPO epoch  35/80 | loss=0.2940 | val={'ROC-AUC': 0.871764705882353, 'PRC-AUC': 0.7725505419964631}
# INFO | HPO epoch  40/80 | loss=0.2892 | val={'ROC-AUC': 0.8470588235294118, 'PRC-AUC': 0.7660567355445002}
# INFO | HPO epoch  45/80 | loss=0.2655 | val={'ROC-AUC': 0.8449019607843137, 'PRC-AUC': 0.7542595517109558}
# INFO | HPO epoch  50/80 | loss=0.2995 | val={'ROC-AUC': 0.8601960784313726, 'PRC-AUC': 0.7446920360567488}
# INFO | HPO epoch  55/80 | loss=0.2643 | val={'ROC-AUC': 0.8919607843137255, 'PRC-AUC': 0.8254968004847797}
# INFO | HPO epoch  60/80 | loss=0.2165 | val={'ROC-AUC': 0.8707843137254903, 'PRC-AUC': 0.7841759323439746}
# INFO | HPO epoch  65/80 | loss=0.2042 | val={'ROC-AUC': 0.8813725490196078, 'PRC-AUC': 0.8158472597126447}
# INFO | HPO epoch  70/80 | loss=0.1891 | val={'ROC-AUC': 0.8831372549019608, 'PRC-AUC': 0.8132998284809411}
# INFO | Early stop at epoch 73 (patience=15)
# INFO | GIN 3D HPO — trial 17/20 finished | val=-0.894118 | best=-0.895098
# INFO | GIN 3D — starting trial 18/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.9458 | val={'ROC-AUC': 0.7845098039215687, 'PRC-AUC': 0.6441459935213283}
# INFO | HPO epoch   5/80 | loss=0.5880 | val={'ROC-AUC': 0.7974509803921569, 'PRC-AUC': 0.748098198247424}
# INFO | HPO epoch  10/80 | loss=0.5148 | val={'ROC-AUC': 0.8750980392156862, 'PRC-AUC': 0.7803441800193593}
# INFO | HPO epoch  15/80 | loss=0.4473 | val={'ROC-AUC': 0.8396078431372549, 'PRC-AUC': 0.6903526106956246}
# INFO | HPO epoch  20/80 | loss=0.4442 | val={'ROC-AUC': 0.8449019607843137, 'PRC-AUC': 0.7225347286570472}
# INFO | HPO epoch  25/80 | loss=0.3893 | val={'ROC-AUC': 0.8633333333333334, 'PRC-AUC': 0.7482800666548985}
# INFO | HPO epoch  30/80 | loss=0.3841 | val={'ROC-AUC': 0.8484313725490196, 'PRC-AUC': 0.740528789771362}
# INFO | HPO epoch  35/80 | loss=0.3579 | val={'ROC-AUC': 0.8568627450980393, 'PRC-AUC': 0.7576301953211794}
# INFO | Early stop at epoch 37 (patience=15)
# INFO | GIN 3D HPO — trial 18/20 finished | val=-0.881176 | best=-0.895098
# INFO | GIN 3D — starting trial 19/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.8255 | val={'ROC-AUC': 0.7774509803921569, 'PRC-AUC': 0.583997263862403}
# INFO | HPO epoch   5/80 | loss=0.5175 | val={'ROC-AUC': 0.800392156862745, 'PRC-AUC': 0.7181563706946}
# INFO | HPO epoch  10/80 | loss=0.4606 | val={'ROC-AUC': 0.8776470588235294, 'PRC-AUC': 0.7791158954725608}
# INFO | HPO epoch  15/80 | loss=0.4201 | val={'ROC-AUC': 0.8798039215686275, 'PRC-AUC': 0.7450162140923107}
# INFO | HPO epoch  20/80 | loss=0.3386 | val={'ROC-AUC': 0.8533333333333333, 'PRC-AUC': 0.7405313522424826}
# INFO | HPO epoch  25/80 | loss=0.3254 | val={'ROC-AUC': 0.876078431372549, 'PRC-AUC': 0.8115755635006845}
# INFO | HPO epoch  30/80 | loss=0.3055 | val={'ROC-AUC': 0.8541176470588234, 'PRC-AUC': 0.7451320533899637}
# INFO | HPO epoch  35/80 | loss=0.2884 | val={'ROC-AUC': 0.8613725490196078, 'PRC-AUC': 0.7928695446510701}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | GIN 3D HPO — trial 19/20 finished | val=-0.896078 | best=-0.896078
# INFO | GIN 3D — starting trial 20/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.7732 | val={'ROC-AUC': 0.6464705882352941, 'PRC-AUC': 0.4862213368379722}
# INFO | HPO epoch   5/80 | loss=0.5379 | val={'ROC-AUC': 0.7715686274509804, 'PRC-AUC': 0.6441191175571339}
# INFO | HPO epoch  10/80 | loss=0.4830 | val={'ROC-AUC': 0.8431372549019608, 'PRC-AUC': 0.6918607189670571}
# INFO | HPO epoch  15/80 | loss=0.4234 | val={'ROC-AUC': 0.7980392156862746, 'PRC-AUC': 0.6530130199320837}
# INFO | HPO epoch  20/80 | loss=0.4083 | val={'ROC-AUC': 0.7915686274509804, 'PRC-AUC': 0.6917910199957451}
# INFO | HPO epoch  25/80 | loss=0.4250 | val={'ROC-AUC': 0.7705882352941176, 'PRC-AUC': 0.6241009423287172}
# INFO | HPO epoch  30/80 | loss=0.3676 | val={'ROC-AUC': 0.8376470588235294, 'PRC-AUC': 0.7186168189397306}
# INFO | HPO epoch  35/80 | loss=0.3305 | val={'ROC-AUC': 0.8468627450980393, 'PRC-AUC': 0.756192722210986}
# INFO | HPO epoch  40/80 | loss=0.3321 | val={'ROC-AUC': 0.863921568627451, 'PRC-AUC': 0.7446235148763455}
# INFO | HPO epoch  45/80 | loss=0.2942 | val={'ROC-AUC': 0.8576470588235294, 'PRC-AUC': 0.7557163606512618}
# INFO | HPO epoch  50/80 | loss=0.3085 | val={'ROC-AUC': 0.8449019607843137, 'PRC-AUC': 0.7734070371814984}
# INFO | HPO epoch  55/80 | loss=0.2786 | val={'ROC-AUC': 0.842156862745098, 'PRC-AUC': 0.7287611608615887}
# INFO | HPO epoch  60/80 | loss=0.2915 | val={'ROC-AUC': 0.8733333333333334, 'PRC-AUC': 0.7644875710950362}
# INFO | HPO epoch  65/80 | loss=0.2741 | val={'ROC-AUC': 0.8847058823529412, 'PRC-AUC': 0.8155671598956858}
# INFO | HPO epoch  70/80 | loss=0.2470 | val={'ROC-AUC': 0.84, 'PRC-AUC': 0.7201646914003244}
# INFO | HPO epoch  75/80 | loss=0.2686 | val={'ROC-AUC': 0.8207843137254902, 'PRC-AUC': 0.7133109251579828}
# INFO | HPO epoch  80/80 | loss=0.2440 | val={'ROC-AUC': 0.8598039215686275, 'PRC-AUC': 0.7651138154983368}
# INFO | Early stop at epoch 80 (patience=15)
# INFO | GIN 3D HPO — trial 20/20 finished | val=-0.884706 | best=-0.896078
# INFO | Epoch  10 | loss=0.4390 | val={'ROC-AUC': 0.8405882352941176, 'PRC-AUC': 0.7093550153514634}
# INFO | Epoch  20 | loss=0.3418 | val={'ROC-AUC': 0.8494117647058823, 'PRC-AUC': 0.7596002848267829}
# INFO | Epoch  30 | loss=0.3191 | val={'ROC-AUC': 0.8762745098039216, 'PRC-AUC': 0.8033582697482925}
# INFO | Epoch  40 | loss=0.2714 | val={'ROC-AUC': 0.8607843137254902, 'PRC-AUC': 0.7668019879749498}
# INFO | Epoch  50 | loss=0.2504 | val={'ROC-AUC': 0.8745098039215686, 'PRC-AUC': 0.805098584453586}
# INFO | Epoch  60 | loss=0.2306 | val={'ROC-AUC': 0.8784313725490196, 'PRC-AUC': 0.8097341636317872}
# INFO | Epoch  70 | loss=0.2238 | val={'ROC-AUC': 0.8815686274509804, 'PRC-AUC': 0.8101975963189184}
# INFO | Epoch  80 | loss=0.2023 | val={'ROC-AUC': 0.882156862745098, 'PRC-AUC': 0.816662040769135}
# INFO | Saved GIN (3D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.8631310369965373, 'PRC-AUC': 0.812068734218899}

# %% [markdown]
# ### SchNet (3D coords)
# Uses atomic numbers + xyz from min-energy n=25 conformer.

# %%
MODEL_KEY = "SchNet (3D coords)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_schnet(
        tr3d, va3d, TASK_TYPE, OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_schnet, PyGLoader, build_schnet, train_schnet
    model = build_schnet(
        OUT_CHANNELS,
        hidden_channels=best["hidden_channels"],
        num_filters=best["num_filters"],
        num_interactions=best["num_interactions"],
        num_gaussians=best["num_gaussians"],
        cutoff=best["cutoff"],
    )
    train_schnet(model, tr3d, va3d, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
                 batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    te3d_schnet = ensure_atomic_numbers_list(te3d)
    test_metrics = eval_schnet(model, PyGLoader(te3d_schnet, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_schnet.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | SchNet — starting trial 1/20
# → SchNet (3D coords) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=1.1815 | val={'ROC-AUC': 0.6937254901960783, 'PRC-AUC': 0.5562689840796725}
# INFO | HPO epoch   5/80 | loss=0.5814 | val={'ROC-AUC': 0.8090196078431372, 'PRC-AUC': 0.6898837809427165}
# INFO | HPO epoch  10/80 | loss=0.5925 | val={'ROC-AUC': 0.8539215686274509, 'PRC-AUC': 0.7022624660170225}
# INFO | HPO epoch  15/80 | loss=0.5112 | val={'ROC-AUC': 0.844313725490196, 'PRC-AUC': 0.7231702481449535}
# INFO | HPO epoch  20/80 | loss=0.4952 | val={'ROC-AUC': 0.847843137254902, 'PRC-AUC': 0.7393934037430903}
# INFO | HPO epoch  25/80 | loss=0.3962 | val={'ROC-AUC': 0.8152941176470587, 'PRC-AUC': 0.7110869337170618}
# INFO | HPO epoch  30/80 | loss=0.3401 | val={'ROC-AUC': 0.8437254901960785, 'PRC-AUC': 0.741535950822977}
# INFO | Early stop at epoch 33 (patience=15)
# INFO | SchNet HPO — trial 1/20 finished | val=-0.864706 | best=-0.864706
# INFO | SchNet — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=0.7577 | val={'ROC-AUC': 0.6588235294117647, 'PRC-AUC': 0.4861451702974693}
# INFO | HPO epoch   5/80 | loss=0.6383 | val={'ROC-AUC': 0.6229411764705883, 'PRC-AUC': 0.4916511978631928}
# INFO | HPO epoch  10/80 | loss=0.6080 | val={'ROC-AUC': 0.7372549019607842, 'PRC-AUC': 0.62468406062644}
# INFO | HPO epoch  15/80 | loss=0.5625 | val={'ROC-AUC': 0.7388235294117647, 'PRC-AUC': 0.657741450333361}
# INFO | HPO epoch  20/80 | loss=0.5614 | val={'ROC-AUC': 0.768235294117647, 'PRC-AUC': 0.705268780086107}
# INFO | HPO epoch  25/80 | loss=0.5377 | val={'ROC-AUC': 0.7972549019607843, 'PRC-AUC': 0.7186804303383498}
# INFO | HPO epoch  30/80 | loss=0.5167 | val={'ROC-AUC': 0.7870588235294117, 'PRC-AUC': 0.7181090048090616}
# INFO | HPO epoch  35/80 | loss=0.5031 | val={'ROC-AUC': 0.8107843137254903, 'PRC-AUC': 0.7299467672615395}
# INFO | HPO epoch  40/80 | loss=0.4859 | val={'ROC-AUC': 0.809607843137255, 'PRC-AUC': 0.7416348612443895}
# INFO | HPO epoch  45/80 | loss=0.4869 | val={'ROC-AUC': 0.8119607843137254, 'PRC-AUC': 0.7316684363076543}
# INFO | HPO epoch  50/80 | loss=0.4712 | val={'ROC-AUC': 0.8133333333333334, 'PRC-AUC': 0.7401855658784375}
# INFO | HPO epoch  55/80 | loss=0.4476 | val={'ROC-AUC': 0.8347058823529411, 'PRC-AUC': 0.7698356547926364}
# INFO | HPO epoch  60/80 | loss=0.4655 | val={'ROC-AUC': 0.8333333333333334, 'PRC-AUC': 0.7715864593637678}
# INFO | HPO epoch  65/80 | loss=0.4482 | val={'ROC-AUC': 0.8468627450980393, 'PRC-AUC': 0.7829310517756188}
# INFO | HPO epoch  70/80 | loss=0.4352 | val={'ROC-AUC': 0.8339215686274509, 'PRC-AUC': 0.7609086681447768}
# INFO | HPO epoch  75/80 | loss=0.4552 | val={'ROC-AUC': 0.8394117647058824, 'PRC-AUC': 0.7714023628708622}
# INFO | HPO epoch  80/80 | loss=0.4170 | val={'ROC-AUC': 0.8498039215686274, 'PRC-AUC': 0.7822490163173754}
# INFO | SchNet HPO — trial 2/20 finished | val=-0.849804 | best=-0.864706
# INFO | SchNet — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=1.1580 | val={'ROC-AUC': 0.396078431372549, 'PRC-AUC': 0.37019269955793344}
# INFO | HPO epoch   5/80 | loss=0.5879 | val={'ROC-AUC': 0.776078431372549, 'PRC-AUC': 0.6518826568550297}
# INFO | HPO epoch  10/80 | loss=0.5302 | val={'ROC-AUC': 0.8041176470588236, 'PRC-AUC': 0.6992848953683898}
# INFO | HPO epoch  15/80 | loss=0.4926 | val={'ROC-AUC': 0.8137254901960784, 'PRC-AUC': 0.7447594421140811}
# INFO | HPO epoch  20/80 | loss=0.4413 | val={'ROC-AUC': 0.8001960784313725, 'PRC-AUC': 0.7336055399041879}
# INFO | HPO epoch  25/80 | loss=0.4236 | val={'ROC-AUC': 0.8035294117647058, 'PRC-AUC': 0.7439722929065504}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | SchNet HPO — trial 3/20 finished | val=-0.832549 | best=-0.864706
# INFO | SchNet — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=2.3083 | val={'ROC-AUC': 0.6649019607843136, 'PRC-AUC': 0.5311464916565254}
# INFO | HPO epoch   5/80 | loss=0.6107 | val={'ROC-AUC': 0.7835294117647059, 'PRC-AUC': 0.6590355050823045}
# INFO | HPO epoch  10/80 | loss=0.6218 | val={'ROC-AUC': 0.831764705882353, 'PRC-AUC': 0.7024381463301991}
# INFO | HPO epoch  15/80 | loss=0.4764 | val={'ROC-AUC': 0.7911764705882353, 'PRC-AUC': 0.6992835548528059}
# INFO | HPO epoch  20/80 | loss=0.4614 | val={'ROC-AUC': 0.7698039215686274, 'PRC-AUC': 0.6569792233379099}
# INFO | HPO epoch  25/80 | loss=0.3402 | val={'ROC-AUC': 0.8103921568627451, 'PRC-AUC': 0.7250953458885208}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | SchNet HPO — trial 4/20 finished | val=-0.834902 | best=-0.864706
# INFO | SchNet — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=1.5873 | val={'ROC-AUC': 0.62, 'PRC-AUC': 0.4957354419450847}
# INFO | HPO epoch   5/80 | loss=0.6277 | val={'ROC-AUC': 0.8119607843137255, 'PRC-AUC': 0.64054974746875}
# INFO | HPO epoch  10/80 | loss=0.5812 | val={'ROC-AUC': 0.769607843137255, 'PRC-AUC': 0.6853719601185662}
# INFO | HPO epoch  15/80 | loss=0.4714 | val={'ROC-AUC': 0.7768627450980391, 'PRC-AUC': 0.7090817420183385}
# INFO | HPO epoch  20/80 | loss=0.4196 | val={'ROC-AUC': 0.7727450980392156, 'PRC-AUC': 0.7023705824490851}
# INFO | HPO epoch  25/80 | loss=0.3529 | val={'ROC-AUC': 0.7672549019607843, 'PRC-AUC': 0.6915622149969957}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | SchNet HPO — trial 5/20 finished | val=-0.820980 | best=-0.864706
# INFO | SchNet — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=1.2695 | val={'ROC-AUC': 0.5800000000000001, 'PRC-AUC': 0.46664599801278767}
# INFO | HPO epoch   5/80 | loss=0.6873 | val={'ROC-AUC': 0.7154901960784315, 'PRC-AUC': 0.5655693294379452}
# INFO | HPO epoch  10/80 | loss=0.5833 | val={'ROC-AUC': 0.7862745098039216, 'PRC-AUC': 0.6708186859671013}
# INFO | HPO epoch  15/80 | loss=0.5913 | val={'ROC-AUC': 0.7917647058823528, 'PRC-AUC': 0.6547846588691064}
# INFO | HPO epoch  20/80 | loss=0.6305 | val={'ROC-AUC': 0.8123529411764706, 'PRC-AUC': 0.6932094752940283}
# INFO | HPO epoch  25/80 | loss=0.5301 | val={'ROC-AUC': 0.8278431372549019, 'PRC-AUC': 0.7449521930442436}
# INFO | HPO epoch  30/80 | loss=0.4953 | val={'ROC-AUC': 0.8205882352941177, 'PRC-AUC': 0.723134734607456}
# INFO | HPO epoch  35/80 | loss=0.4751 | val={'ROC-AUC': 0.8282352941176472, 'PRC-AUC': 0.7552038813789987}
# INFO | HPO epoch  40/80 | loss=0.4677 | val={'ROC-AUC': 0.8439215686274509, 'PRC-AUC': 0.7708683433017406}
# INFO | HPO epoch  45/80 | loss=0.4498 | val={'ROC-AUC': 0.8241176470588235, 'PRC-AUC': 0.7258353426252623}
# INFO | HPO epoch  50/80 | loss=0.4250 | val={'ROC-AUC': 0.8290196078431372, 'PRC-AUC': 0.7256540912748504}
# INFO | Early stop at epoch 52 (patience=15)
# INFO | SchNet HPO — trial 6/20 finished | val=-0.845686 | best=-0.864706
# INFO | SchNet — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=2.3630 | val={'ROC-AUC': 0.6617647058823529, 'PRC-AUC': 0.4897393793682053}
# INFO | HPO epoch   5/80 | loss=0.6600 | val={'ROC-AUC': 0.7362745098039216, 'PRC-AUC': 0.565424914995543}
# INFO | HPO epoch  10/80 | loss=0.5636 | val={'ROC-AUC': 0.7935294117647059, 'PRC-AUC': 0.7136441712480225}
# INFO | HPO epoch  15/80 | loss=0.5854 | val={'ROC-AUC': 0.7517647058823529, 'PRC-AUC': 0.6909546151907429}
# INFO | HPO epoch  20/80 | loss=0.5181 | val={'ROC-AUC': 0.8280392156862746, 'PRC-AUC': 0.7376651572436683}
# INFO | HPO epoch  25/80 | loss=0.4474 | val={'ROC-AUC': 0.7939215686274509, 'PRC-AUC': 0.6776395315077883}
# INFO | HPO epoch  30/80 | loss=0.4267 | val={'ROC-AUC': 0.7854901960784313, 'PRC-AUC': 0.6287140884515239}
# INFO | HPO epoch  35/80 | loss=0.3978 | val={'ROC-AUC': 0.806470588235294, 'PRC-AUC': 0.6979978624694071}
# INFO | HPO epoch  40/80 | loss=0.3120 | val={'ROC-AUC': 0.8125490196078431, 'PRC-AUC': 0.6543580228495303}
# INFO | Early stop at epoch 43 (patience=15)
# INFO | SchNet HPO — trial 7/20 finished | val=-0.841961 | best=-0.864706
# INFO | SchNet — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=0.9446 | val={'ROC-AUC': 0.6737254901960784, 'PRC-AUC': 0.47697873223696247}
# INFO | HPO epoch   5/80 | loss=0.6569 | val={'ROC-AUC': 0.6627450980392157, 'PRC-AUC': 0.5549525103083837}
# INFO | HPO epoch  10/80 | loss=0.5984 | val={'ROC-AUC': 0.7278431372549019, 'PRC-AUC': 0.6038916613767107}
# INFO | HPO epoch  15/80 | loss=0.5780 | val={'ROC-AUC': 0.7605882352941177, 'PRC-AUC': 0.6282989259956676}
# INFO | HPO epoch  20/80 | loss=0.5486 | val={'ROC-AUC': 0.8113725490196079, 'PRC-AUC': 0.7320348344826569}
# INFO | HPO epoch  25/80 | loss=0.5427 | val={'ROC-AUC': 0.8227450980392156, 'PRC-AUC': 0.7332532444916176}
# INFO | HPO epoch  30/80 | loss=0.5095 | val={'ROC-AUC': 0.8139215686274509, 'PRC-AUC': 0.7426887017917282}
# INFO | HPO epoch  35/80 | loss=0.4906 | val={'ROC-AUC': 0.8149019607843138, 'PRC-AUC': 0.736782831320671}
# INFO | HPO epoch  40/80 | loss=0.4706 | val={'ROC-AUC': 0.8115686274509805, 'PRC-AUC': 0.7224898297072215}
# INFO | HPO epoch  45/80 | loss=0.4569 | val={'ROC-AUC': 0.8345098039215687, 'PRC-AUC': 0.7515877630081992}
# INFO | Early stop at epoch 46 (patience=15)
# INFO | SchNet HPO — trial 8/20 finished | val=-0.840392 | best=-0.864706
# INFO | SchNet — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=0.9663 | val={'ROC-AUC': 0.6115686274509803, 'PRC-AUC': 0.47126494486155535}
# INFO | HPO epoch   5/80 | loss=0.7400 | val={'ROC-AUC': 0.7549019607843137, 'PRC-AUC': 0.6178989755614662}
# INFO | HPO epoch  10/80 | loss=0.6042 | val={'ROC-AUC': 0.7345098039215687, 'PRC-AUC': 0.6102968290065796}
# INFO | HPO epoch  15/80 | loss=0.5692 | val={'ROC-AUC': 0.7870588235294117, 'PRC-AUC': 0.6859437973528446}
# INFO | HPO epoch  20/80 | loss=0.5652 | val={'ROC-AUC': 0.8072549019607843, 'PRC-AUC': 0.7270382551275865}
# INFO | HPO epoch  25/80 | loss=0.5700 | val={'ROC-AUC': 0.8003921568627451, 'PRC-AUC': 0.7179810252416382}
# INFO | HPO epoch  30/80 | loss=0.5663 | val={'ROC-AUC': 0.7958823529411765, 'PRC-AUC': 0.691108637837057}
# INFO | HPO epoch  35/80 | loss=0.5139 | val={'ROC-AUC': 0.8211764705882352, 'PRC-AUC': 0.7470476642088508}
# INFO | HPO epoch  40/80 | loss=0.5407 | val={'ROC-AUC': 0.819607843137255, 'PRC-AUC': 0.7303823201854065}
# INFO | HPO epoch  45/80 | loss=0.4671 | val={'ROC-AUC': 0.8315686274509805, 'PRC-AUC': 0.7634076753427931}
# INFO | HPO epoch  50/80 | loss=0.4593 | val={'ROC-AUC': 0.8313725490196078, 'PRC-AUC': 0.7388429207009843}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | SchNet HPO — trial 9/20 finished | val=-0.834706 | best=-0.864706
# INFO | SchNet — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=2.0873 | val={'ROC-AUC': 0.721764705882353, 'PRC-AUC': 0.5509809321929348}
# INFO | HPO epoch   5/80 | loss=0.7121 | val={'ROC-AUC': 0.8092156862745098, 'PRC-AUC': 0.6465115581434558}
# INFO | HPO epoch  10/80 | loss=0.5770 | val={'ROC-AUC': 0.7835294117647058, 'PRC-AUC': 0.6731588687307566}
# INFO | HPO epoch  15/80 | loss=0.5738 | val={'ROC-AUC': 0.8327450980392157, 'PRC-AUC': 0.7257143613524718}
# INFO | HPO epoch  20/80 | loss=0.4823 | val={'ROC-AUC': 0.8350980392156863, 'PRC-AUC': 0.7189153140823101}
# INFO | HPO epoch  25/80 | loss=0.4686 | val={'ROC-AUC': 0.8492156862745097, 'PRC-AUC': 0.7411015935760676}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | SchNet HPO — trial 10/20 finished | val=-0.859020 | best=-0.864706
# INFO | SchNet — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=1.0893 | val={'ROC-AUC': 0.5949019607843138, 'PRC-AUC': 0.46025850150285447}
# INFO | HPO epoch   5/80 | loss=0.6285 | val={'ROC-AUC': 0.7462745098039215, 'PRC-AUC': 0.562441707817561}
# INFO | HPO epoch  10/80 | loss=0.6265 | val={'ROC-AUC': 0.7656862745098039, 'PRC-AUC': 0.6241004724992814}
# INFO | HPO epoch  15/80 | loss=0.6003 | val={'ROC-AUC': 0.7835294117647059, 'PRC-AUC': 0.6503599260098258}
# INFO | HPO epoch  20/80 | loss=0.5558 | val={'ROC-AUC': 0.8298039215686275, 'PRC-AUC': 0.709077380484337}
# INFO | HPO epoch  25/80 | loss=0.5509 | val={'ROC-AUC': 0.831764705882353, 'PRC-AUC': 0.725719471114441}
# INFO | HPO epoch  30/80 | loss=0.5803 | val={'ROC-AUC': 0.8382352941176471, 'PRC-AUC': 0.7276845580270398}
# INFO | HPO epoch  35/80 | loss=0.5782 | val={'ROC-AUC': 0.8484313725490197, 'PRC-AUC': 0.7362452039169408}
# INFO | HPO epoch  40/80 | loss=0.5209 | val={'ROC-AUC': 0.8264705882352941, 'PRC-AUC': 0.7163529030570912}
# INFO | HPO epoch  45/80 | loss=0.5054 | val={'ROC-AUC': 0.8345098039215687, 'PRC-AUC': 0.7155963907263923}
# INFO | HPO epoch  50/80 | loss=0.5036 | val={'ROC-AUC': 0.8341176470588235, 'PRC-AUC': 0.7152477759091647}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | SchNet HPO — trial 11/20 finished | val=-0.848431 | best=-0.864706
# INFO | SchNet — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=1.5122 | val={'ROC-AUC': 0.5988235294117648, 'PRC-AUC': 0.49010783729649793}
# INFO | HPO epoch   5/80 | loss=0.6115 | val={'ROC-AUC': 0.8190196078431372, 'PRC-AUC': 0.665005167904722}
# INFO | HPO epoch  10/80 | loss=0.6402 | val={'ROC-AUC': 0.7788235294117647, 'PRC-AUC': 0.6647582877526048}
# INFO | HPO epoch  15/80 | loss=0.5227 | val={'ROC-AUC': 0.8456862745098039, 'PRC-AUC': 0.7518039694361841}
# INFO | HPO epoch  20/80 | loss=0.5201 | val={'ROC-AUC': 0.8484313725490197, 'PRC-AUC': 0.7317641748839859}
# INFO | HPO epoch  25/80 | loss=0.4177 | val={'ROC-AUC': 0.8074509803921569, 'PRC-AUC': 0.7083279399919373}
# INFO | HPO epoch  30/80 | loss=0.4101 | val={'ROC-AUC': 0.8311764705882353, 'PRC-AUC': 0.7052872424624357}
# INFO | HPO epoch  35/80 | loss=0.3769 | val={'ROC-AUC': 0.787843137254902, 'PRC-AUC': 0.6768455705011882}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | SchNet HPO — trial 12/20 finished | val=-0.851176 | best=-0.864706
# INFO | SchNet — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=1.2135 | val={'ROC-AUC': 0.5107843137254902, 'PRC-AUC': 0.43747587316443626}
# INFO | HPO epoch   5/80 | loss=0.6802 | val={'ROC-AUC': 0.794313725490196, 'PRC-AUC': 0.6720421616392748}
# INFO | HPO epoch  10/80 | loss=0.5633 | val={'ROC-AUC': 0.8407843137254902, 'PRC-AUC': 0.727960378976668}
# INFO | HPO epoch  15/80 | loss=0.5361 | val={'ROC-AUC': 0.8254901960784313, 'PRC-AUC': 0.7227388395242968}
# INFO | HPO epoch  20/80 | loss=0.5834 | val={'ROC-AUC': 0.8090196078431372, 'PRC-AUC': 0.71716423362738}
# INFO | HPO epoch  25/80 | loss=0.4940 | val={'ROC-AUC': 0.83, 'PRC-AUC': 0.7183088510194034}
# INFO | HPO epoch  30/80 | loss=0.4548 | val={'ROC-AUC': 0.7670588235294117, 'PRC-AUC': 0.6986711279612314}
# INFO | HPO epoch  35/80 | loss=0.4224 | val={'ROC-AUC': 0.8223529411764706, 'PRC-AUC': 0.7130321846894596}
# INFO | Early stop at epoch 38 (patience=15)
# INFO | SchNet HPO — trial 13/20 finished | val=-0.849412 | best=-0.864706
# INFO | SchNet — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=2.5586 | val={'ROC-AUC': 0.5709803921568628, 'PRC-AUC': 0.42981223203271957}
# INFO | HPO epoch   5/80 | loss=0.6320 | val={'ROC-AUC': 0.7747058823529411, 'PRC-AUC': 0.6014920011431062}
# INFO | HPO epoch  10/80 | loss=0.6317 | val={'ROC-AUC': 0.816078431372549, 'PRC-AUC': 0.6913301989337954}
# INFO | HPO epoch  15/80 | loss=0.5517 | val={'ROC-AUC': 0.8286274509803921, 'PRC-AUC': 0.6964109129248436}
# INFO | HPO epoch  20/80 | loss=0.5127 | val={'ROC-AUC': 0.8415686274509805, 'PRC-AUC': 0.7132077276711076}
# INFO | HPO epoch  25/80 | loss=0.5060 | val={'ROC-AUC': 0.8454901960784313, 'PRC-AUC': 0.6981512802163978}
# INFO | HPO epoch  30/80 | loss=0.5006 | val={'ROC-AUC': 0.8398039215686275, 'PRC-AUC': 0.7218069337704057}
# INFO | HPO epoch  35/80 | loss=0.4597 | val={'ROC-AUC': 0.8439215686274509, 'PRC-AUC': 0.7027281681946997}
# INFO | HPO epoch  40/80 | loss=0.4337 | val={'ROC-AUC': 0.8547058823529412, 'PRC-AUC': 0.7057585671355924}
# INFO | HPO epoch  45/80 | loss=0.4373 | val={'ROC-AUC': 0.8341176470588235, 'PRC-AUC': 0.6921502873569378}
# INFO | HPO epoch  50/80 | loss=0.4119 | val={'ROC-AUC': 0.8037254901960784, 'PRC-AUC': 0.6672246482386943}
# INFO | HPO epoch  55/80 | loss=0.4006 | val={'ROC-AUC': 0.8201960784313725, 'PRC-AUC': 0.6674352750473465}
# INFO | Early stop at epoch 55 (patience=15)
# INFO | SchNet HPO — trial 14/20 finished | val=-0.854706 | best=-0.864706
# INFO | SchNet — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=1.9058 | val={'ROC-AUC': 0.6388235294117647, 'PRC-AUC': 0.48358962442581077}
# INFO | HPO epoch   5/80 | loss=0.6601 | val={'ROC-AUC': 0.7699999999999999, 'PRC-AUC': 0.6266281864981671}
# INFO | HPO epoch  10/80 | loss=0.5117 | val={'ROC-AUC': 0.7676470588235293, 'PRC-AUC': 0.6792189625590306}
# INFO | HPO epoch  15/80 | loss=0.4866 | val={'ROC-AUC': 0.8584313725490196, 'PRC-AUC': 0.7635748440211522}
# INFO | HPO epoch  20/80 | loss=0.4349 | val={'ROC-AUC': 0.7998039215686273, 'PRC-AUC': 0.755767032837548}
# INFO | HPO epoch  25/80 | loss=0.4297 | val={'ROC-AUC': 0.8384313725490196, 'PRC-AUC': 0.7767974322193166}
# INFO | HPO epoch  30/80 | loss=0.3403 | val={'ROC-AUC': 0.8280392156862745, 'PRC-AUC': 0.7723835529622938}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | SchNet HPO — trial 15/20 finished | val=-0.858431 | best=-0.864706
# INFO | SchNet — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=1.8798 | val={'ROC-AUC': 0.7615686274509804, 'PRC-AUC': 0.5892548863840434}
# INFO | HPO epoch   5/80 | loss=0.6138 | val={'ROC-AUC': 0.7788235294117647, 'PRC-AUC': 0.6405187002266568}
# INFO | HPO epoch  10/80 | loss=0.5832 | val={'ROC-AUC': 0.8101960784313725, 'PRC-AUC': 0.6727076350023103}
# INFO | HPO epoch  15/80 | loss=0.5734 | val={'ROC-AUC': 0.7603921568627451, 'PRC-AUC': 0.6648665503372427}
# INFO | HPO epoch  20/80 | loss=0.5614 | val={'ROC-AUC': 0.8005882352941176, 'PRC-AUC': 0.6791188957034531}
# INFO | HPO epoch  25/80 | loss=0.4715 | val={'ROC-AUC': 0.8331372549019608, 'PRC-AUC': 0.6957780272231064}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | SchNet HPO — trial 16/20 finished | val=-0.840000 | best=-0.864706
# INFO | SchNet — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=0.9598 | val={'ROC-AUC': 0.7088235294117647, 'PRC-AUC': 0.600947524087492}
# INFO | HPO epoch   5/80 | loss=0.7021 | val={'ROC-AUC': 0.7801960784313725, 'PRC-AUC': 0.6702781898343306}
# INFO | HPO epoch  10/80 | loss=0.6017 | val={'ROC-AUC': 0.8258823529411764, 'PRC-AUC': 0.6971648789563395}
# INFO | HPO epoch  15/80 | loss=0.5537 | val={'ROC-AUC': 0.8319607843137256, 'PRC-AUC': 0.6940059977465357}
# INFO | HPO epoch  20/80 | loss=0.5184 | val={'ROC-AUC': 0.8305882352941176, 'PRC-AUC': 0.7136852853072417}
# INFO | HPO epoch  25/80 | loss=0.5079 | val={'ROC-AUC': 0.8311764705882353, 'PRC-AUC': 0.7150927185230294}
# INFO | HPO epoch  30/80 | loss=0.4906 | val={'ROC-AUC': 0.8007843137254902, 'PRC-AUC': 0.6977026131197389}
# INFO | HPO epoch  35/80 | loss=0.4808 | val={'ROC-AUC': 0.831764705882353, 'PRC-AUC': 0.7232434631673111}
# INFO | HPO epoch  40/80 | loss=0.4718 | val={'ROC-AUC': 0.8325490196078431, 'PRC-AUC': 0.7237935001671584}
# INFO | HPO epoch  45/80 | loss=0.4532 | val={'ROC-AUC': 0.8384313725490197, 'PRC-AUC': 0.7302763183172803}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | SchNet HPO — trial 17/20 finished | val=-0.847255 | best=-0.864706
# INFO | SchNet — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=2.0851 | val={'ROC-AUC': 0.41843137254901963, 'PRC-AUC': 0.3219851030644295}
# INFO | HPO epoch   5/80 | loss=0.6759 | val={'ROC-AUC': 0.7798039215686274, 'PRC-AUC': 0.6042954160173626}
# INFO | HPO epoch  10/80 | loss=0.6058 | val={'ROC-AUC': 0.8180392156862746, 'PRC-AUC': 0.6833569990521722}
# INFO | HPO epoch  15/80 | loss=0.6109 | val={'ROC-AUC': 0.7945098039215687, 'PRC-AUC': 0.6787327941738858}
# INFO | HPO epoch  20/80 | loss=0.6236 | val={'ROC-AUC': 0.7794117647058824, 'PRC-AUC': 0.6563072866788362}
# INFO | HPO epoch  25/80 | loss=0.5211 | val={'ROC-AUC': 0.8286274509803923, 'PRC-AUC': 0.6803211224201432}
# INFO | HPO epoch  30/80 | loss=0.4677 | val={'ROC-AUC': 0.8343137254901961, 'PRC-AUC': 0.683284927418041}
# INFO | HPO epoch  35/80 | loss=0.4598 | val={'ROC-AUC': 0.8231372549019608, 'PRC-AUC': 0.6900000406278589}
# INFO | HPO epoch  40/80 | loss=0.4664 | val={'ROC-AUC': 0.8221568627450981, 'PRC-AUC': 0.6562749714531185}
# INFO | HPO epoch  45/80 | loss=0.4245 | val={'ROC-AUC': 0.8252941176470588, 'PRC-AUC': 0.6587054512409247}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | SchNet HPO — trial 18/20 finished | val=-0.838039 | best=-0.864706
# INFO | SchNet — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=1.4219 | val={'ROC-AUC': 0.6574509803921569, 'PRC-AUC': 0.4984873889238444}
# INFO | HPO epoch   5/80 | loss=0.6062 | val={'ROC-AUC': 0.7621568627450981, 'PRC-AUC': 0.6184160963186027}
# INFO | HPO epoch  10/80 | loss=0.6181 | val={'ROC-AUC': 0.8156862745098039, 'PRC-AUC': 0.6788395288172259}
# INFO | HPO epoch  15/80 | loss=0.5326 | val={'ROC-AUC': 0.8225490196078431, 'PRC-AUC': 0.7192989882557907}
# INFO | HPO epoch  20/80 | loss=0.4793 | val={'ROC-AUC': 0.8158823529411765, 'PRC-AUC': 0.7213570343748128}
# INFO | HPO epoch  25/80 | loss=0.3958 | val={'ROC-AUC': 0.8247058823529412, 'PRC-AUC': 0.7289954839141168}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | SchNet HPO — trial 19/20 finished | val=-0.832353 | best=-0.864706
# INFO | SchNet — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=0.9333 | val={'ROC-AUC': 0.7296078431372549, 'PRC-AUC': 0.5822707116755405}
# INFO | HPO epoch   5/80 | loss=0.6494 | val={'ROC-AUC': 0.7598039215686274, 'PRC-AUC': 0.6374292547001059}
# INFO | HPO epoch  10/80 | loss=0.5801 | val={'ROC-AUC': 0.8094117647058824, 'PRC-AUC': 0.6853327864675604}
# INFO | HPO epoch  15/80 | loss=0.5858 | val={'ROC-AUC': 0.8231372549019608, 'PRC-AUC': 0.7098684370988558}
# INFO | HPO epoch  20/80 | loss=0.6034 | val={'ROC-AUC': 0.841764705882353, 'PRC-AUC': 0.7249499982365573}
# INFO | HPO epoch  25/80 | loss=0.5495 | val={'ROC-AUC': 0.8390196078431373, 'PRC-AUC': 0.7255960824294831}
# INFO | HPO epoch  30/80 | loss=0.5326 | val={'ROC-AUC': 0.8486274509803922, 'PRC-AUC': 0.7242459506516612}
# INFO | HPO epoch  35/80 | loss=0.5384 | val={'ROC-AUC': 0.8482352941176471, 'PRC-AUC': 0.7208287290262055}
# INFO | HPO epoch  40/80 | loss=0.5248 | val={'ROC-AUC': 0.8456862745098039, 'PRC-AUC': 0.7212526087266488}
# INFO | HPO epoch  45/80 | loss=0.5094 | val={'ROC-AUC': 0.8280392156862745, 'PRC-AUC': 0.7124923216972415}
# INFO | HPO epoch  50/80 | loss=0.4724 | val={'ROC-AUC': 0.8452941176470589, 'PRC-AUC': 0.7225500619065721}
# INFO | HPO epoch  55/80 | loss=0.4569 | val={'ROC-AUC': 0.8527450980392157, 'PRC-AUC': 0.7305353755960761}
# INFO | HPO epoch  60/80 | loss=0.4261 | val={'ROC-AUC': 0.8517647058823531, 'PRC-AUC': 0.7344449357043545}
# INFO | Early stop at epoch 62 (patience=15)
# INFO | SchNet HPO — trial 20/20 finished | val=-0.856471 | best=-0.864706
# INFO | Epoch  10 | loss=0.6122 | val={'ROC-AUC': 0.8368627450980393, 'PRC-AUC': 0.7246107552516277}
# INFO | Epoch  20 | loss=0.4768 | val={'ROC-AUC': 0.8252941176470588, 'PRC-AUC': 0.712183215390672}
# INFO | Epoch  30 | loss=0.3860 | val={'ROC-AUC': 0.8325490196078431, 'PRC-AUC': 0.7372512602164271}
# INFO | Epoch  40 | loss=0.3675 | val={'ROC-AUC': 0.8368627450980393, 'PRC-AUC': 0.7665593785874454}
# INFO | Epoch  50 | loss=0.2717 | val={'ROC-AUC': 0.8192156862745098, 'PRC-AUC': 0.7615271873687912}
# INFO | Epoch  60 | loss=0.2428 | val={'ROC-AUC': 0.836078431372549, 'PRC-AUC': 0.7699137760064987}
# INFO | Epoch  70 | loss=0.2167 | val={'ROC-AUC': 0.8366666666666668, 'PRC-AUC': 0.7684852249768312}
# INFO | Epoch  80 | loss=0.2087 | val={'ROC-AUC': 0.8376470588235295, 'PRC-AUC': 0.7740511380119023}
# INFO | Saved SchNet (3D coords) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.7546929105157646, 'PRC-AUC': 0.6818540868397296}

# %% [markdown]
# ### SMILES LSTM
# Canonical isomeric SMILES tokens.

# %%
MODEL_KEY = "SMILES LSTM"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_lstm(
        tr_ds, va_ds, TASK_TYPE, len(vocab), OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import SmilesLSTM, eval_lstm, TorchLoader, train_lstm
    model = SmilesLSTM(len(vocab), embed_dim=best["embed_dim"], hidden_dim=best["hidden_dim"],
                       n_layers=best["n_layers"], out_channels=OUT_CHANNELS, dropout=best["dropout"])
    train_lstm(model, tr_ds, va_ds, TASK_TYPE, epochs=LSTM_EPOCHS, lr=best["lr"],
               batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_lstm(model, TorchLoader(te_ds, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_lstm.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | LSTM — starting trial 1/20
# → SMILES LSTM (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.6887 | val={'ROC-AUC': 0.6415686274509804, 'PRC-AUC': 0.46356013813066055}
# INFO | HPO epoch   5/80 | loss=0.5870 | val={'ROC-AUC': 0.7805882352941177, 'PRC-AUC': 0.6126581002387654}
# INFO | HPO epoch  10/80 | loss=0.4647 | val={'ROC-AUC': 0.8172549019607843, 'PRC-AUC': 0.6962826277657528}
# INFO | HPO epoch  15/80 | loss=0.3894 | val={'ROC-AUC': 0.8437254901960785, 'PRC-AUC': 0.7586194489707898}
# INFO | HPO epoch  20/80 | loss=0.3462 | val={'ROC-AUC': 0.8439215686274509, 'PRC-AUC': 0.7398758634698028}
# INFO | HPO epoch  25/80 | loss=0.3026 | val={'ROC-AUC': 0.7958823529411765, 'PRC-AUC': 0.656229489773744}
# INFO | HPO epoch  30/80 | loss=0.2813 | val={'ROC-AUC': 0.8288235294117647, 'PRC-AUC': 0.7088561278682204}
# INFO | Early stop at epoch 34 (patience=15)
# INFO | LSTM HPO — trial 1/20 finished | val=-0.871176 | best=-0.871176
# INFO | LSTM — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=0.6865 | val={'ROC-AUC': 0.6554901960784314, 'PRC-AUC': 0.493399905558468}
# INFO | HPO epoch   5/80 | loss=0.5747 | val={'ROC-AUC': 0.8205882352941176, 'PRC-AUC': 0.6943708428887208}
# INFO | HPO epoch  10/80 | loss=0.4418 | val={'ROC-AUC': 0.8074509803921568, 'PRC-AUC': 0.6902368331497172}
# INFO | HPO epoch  15/80 | loss=0.3767 | val={'ROC-AUC': 0.8447058823529412, 'PRC-AUC': 0.7598708431438685}
# INFO | HPO epoch  20/80 | loss=0.3194 | val={'ROC-AUC': 0.8519607843137255, 'PRC-AUC': 0.7731918592993221}
# INFO | HPO epoch  25/80 | loss=0.2638 | val={'ROC-AUC': 0.8484313725490196, 'PRC-AUC': 0.7526681739942773}
# INFO | HPO epoch  30/80 | loss=0.2078 | val={'ROC-AUC': 0.852156862745098, 'PRC-AUC': 0.7499288621932875}
# INFO | HPO epoch  35/80 | loss=0.1687 | val={'ROC-AUC': 0.8435294117647057, 'PRC-AUC': 0.7003099454192057}
# INFO | Early stop at epoch 38 (patience=15)
# INFO | LSTM HPO — trial 2/20 finished | val=-0.872353 | best=-0.872353
# INFO | LSTM — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=0.6912 | val={'ROC-AUC': 0.6013725490196078, 'PRC-AUC': 0.4652553131855304}
# INFO | HPO epoch   5/80 | loss=0.6494 | val={'ROC-AUC': 0.6405882352941176, 'PRC-AUC': 0.5345204485619535}
# INFO | HPO epoch  10/80 | loss=0.5627 | val={'ROC-AUC': 0.7443137254901961, 'PRC-AUC': 0.6357385207018468}
# INFO | HPO epoch  15/80 | loss=0.5107 | val={'ROC-AUC': 0.7568627450980392, 'PRC-AUC': 0.6711672838094543}
# INFO | HPO epoch  20/80 | loss=0.4776 | val={'ROC-AUC': 0.8141176470588235, 'PRC-AUC': 0.7044272093986258}
# INFO | HPO epoch  25/80 | loss=0.4382 | val={'ROC-AUC': 0.832156862745098, 'PRC-AUC': 0.7429369550043137}
# INFO | HPO epoch  30/80 | loss=0.4299 | val={'ROC-AUC': 0.8296078431372549, 'PRC-AUC': 0.695914477738734}
# INFO | HPO epoch  35/80 | loss=0.3955 | val={'ROC-AUC': 0.836078431372549, 'PRC-AUC': 0.6857444716861396}
# INFO | HPO epoch  40/80 | loss=0.3803 | val={'ROC-AUC': 0.8437254901960785, 'PRC-AUC': 0.6832398537067843}
# INFO | HPO epoch  45/80 | loss=0.3701 | val={'ROC-AUC': 0.843921568627451, 'PRC-AUC': 0.6937061386138095}
# INFO | HPO epoch  50/80 | loss=0.3488 | val={'ROC-AUC': 0.8735294117647059, 'PRC-AUC': 0.7465279299060088}
# INFO | HPO epoch  55/80 | loss=0.3036 | val={'ROC-AUC': 0.8588235294117648, 'PRC-AUC': 0.7262892894950901}
# INFO | Early stop at epoch 57 (patience=15)
# INFO | LSTM HPO — trial 3/20 finished | val=-0.884118 | best=-0.884118
# INFO | LSTM — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=0.6907 | val={'ROC-AUC': 0.6307843137254902, 'PRC-AUC': 0.4446493158013109}
# INFO | HPO epoch   5/80 | loss=0.6148 | val={'ROC-AUC': 0.7637254901960785, 'PRC-AUC': 0.6698027633752538}
# INFO | HPO epoch  10/80 | loss=0.5451 | val={'ROC-AUC': 0.804313725490196, 'PRC-AUC': 0.7285865489373546}
# INFO | HPO epoch  15/80 | loss=0.4769 | val={'ROC-AUC': 0.8294117647058823, 'PRC-AUC': 0.7540968162413705}
# INFO | HPO epoch  20/80 | loss=0.4572 | val={'ROC-AUC': 0.8462745098039216, 'PRC-AUC': 0.782987620926555}
# INFO | HPO epoch  25/80 | loss=0.4192 | val={'ROC-AUC': 0.8641176470588235, 'PRC-AUC': 0.8279010226069218}
# INFO | HPO epoch  30/80 | loss=0.3763 | val={'ROC-AUC': 0.8368627450980392, 'PRC-AUC': 0.7787767403702031}
# INFO | HPO epoch  35/80 | loss=0.3308 | val={'ROC-AUC': 0.8382352941176471, 'PRC-AUC': 0.8302655430148037}
# INFO | Early stop at epoch 38 (patience=15)
# INFO | LSTM HPO — trial 4/20 finished | val=-0.876275 | best=-0.884118
# INFO | LSTM — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=0.6890 | val={'ROC-AUC': 0.6349019607843136, 'PRC-AUC': 0.4923891940910936}
# INFO | HPO epoch   5/80 | loss=0.5491 | val={'ROC-AUC': 0.7968627450980392, 'PRC-AUC': 0.6739862569200669}
# INFO | HPO epoch  10/80 | loss=0.4567 | val={'ROC-AUC': 0.8272549019607843, 'PRC-AUC': 0.7208657377530694}
# INFO | HPO epoch  15/80 | loss=0.3736 | val={'ROC-AUC': 0.8519607843137255, 'PRC-AUC': 0.7510463502719564}
# INFO | HPO epoch  20/80 | loss=0.3014 | val={'ROC-AUC': 0.8396078431372549, 'PRC-AUC': 0.7195436776905151}
# INFO | HPO epoch  25/80 | loss=0.2662 | val={'ROC-AUC': 0.8364705882352941, 'PRC-AUC': 0.7219918702153683}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | LSTM HPO — trial 5/20 finished | val=-0.868627 | best=-0.884118
# INFO | LSTM — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=0.6930 | val={'ROC-AUC': 0.6309803921568627, 'PRC-AUC': 0.4439160582128261}
# INFO | HPO epoch   5/80 | loss=0.6419 | val={'ROC-AUC': 0.6552941176470588, 'PRC-AUC': 0.5249559992059656}
# INFO | HPO epoch  10/80 | loss=0.5300 | val={'ROC-AUC': 0.748235294117647, 'PRC-AUC': 0.6366756294839401}
# INFO | HPO epoch  15/80 | loss=0.4794 | val={'ROC-AUC': 0.8158823529411765, 'PRC-AUC': 0.695699671069296}
# INFO | HPO epoch  20/80 | loss=0.4480 | val={'ROC-AUC': 0.8237254901960784, 'PRC-AUC': 0.6399609988551178}
# INFO | HPO epoch  25/80 | loss=0.4201 | val={'ROC-AUC': 0.8288235294117646, 'PRC-AUC': 0.7157918157892903}
# INFO | HPO epoch  30/80 | loss=0.3801 | val={'ROC-AUC': 0.8296078431372549, 'PRC-AUC': 0.6917892626346595}
# INFO | HPO epoch  35/80 | loss=0.3620 | val={'ROC-AUC': 0.8411764705882353, 'PRC-AUC': 0.6809713910944466}
# INFO | HPO epoch  40/80 | loss=0.3263 | val={'ROC-AUC': 0.8358823529411764, 'PRC-AUC': 0.6799064687765041}
# INFO | HPO epoch  45/80 | loss=0.2878 | val={'ROC-AUC': 0.8292156862745098, 'PRC-AUC': 0.6837369001550178}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | LSTM HPO — trial 6/20 finished | val=-0.849216 | best=-0.884118
# INFO | LSTM — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=0.6901 | val={'ROC-AUC': 0.6262745098039215, 'PRC-AUC': 0.4454767702731667}
# INFO | HPO epoch   5/80 | loss=0.6050 | val={'ROC-AUC': 0.6976470588235294, 'PRC-AUC': 0.5584320605942867}
# INFO | HPO epoch  10/80 | loss=0.4978 | val={'ROC-AUC': 0.7950980392156863, 'PRC-AUC': 0.7178852734765491}
# INFO | HPO epoch  15/80 | loss=0.4475 | val={'ROC-AUC': 0.8198039215686274, 'PRC-AUC': 0.7328207993104461}
# INFO | HPO epoch  20/80 | loss=0.4006 | val={'ROC-AUC': 0.8403921568627452, 'PRC-AUC': 0.7166906738449846}
# INFO | HPO epoch  25/80 | loss=0.3395 | val={'ROC-AUC': 0.8262745098039215, 'PRC-AUC': 0.6815065988082141}
# INFO | HPO epoch  30/80 | loss=0.2944 | val={'ROC-AUC': 0.8233333333333334, 'PRC-AUC': 0.6733537237861086}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | LSTM HPO — trial 7/20 finished | val=-0.840980 | best=-0.884118
# INFO | LSTM — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=0.6861 | val={'ROC-AUC': 0.6401960784313725, 'PRC-AUC': 0.4919269726567156}
# INFO | HPO epoch   5/80 | loss=0.6357 | val={'ROC-AUC': 0.6560784313725491, 'PRC-AUC': 0.5317188917199368}
# INFO | HPO epoch  10/80 | loss=0.6029 | val={'ROC-AUC': 0.6968627450980392, 'PRC-AUC': 0.5730178708962095}
# INFO | HPO epoch  15/80 | loss=0.5570 | val={'ROC-AUC': 0.7321568627450981, 'PRC-AUC': 0.599437955805755}
# INFO | HPO epoch  20/80 | loss=0.5453 | val={'ROC-AUC': 0.777843137254902, 'PRC-AUC': 0.6419898844132225}
# INFO | HPO epoch  25/80 | loss=0.5381 | val={'ROC-AUC': 0.7723529411764706, 'PRC-AUC': 0.6341998664514973}
# INFO | HPO epoch  30/80 | loss=0.5184 | val={'ROC-AUC': 0.796078431372549, 'PRC-AUC': 0.6682749940926235}
# INFO | Early stop at epoch 34 (patience=15)
# INFO | LSTM HPO — trial 8/20 finished | val=-0.803922 | best=-0.884118
# INFO | LSTM — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=0.6914 | val={'ROC-AUC': 0.6198039215686274, 'PRC-AUC': 0.42101889957824623}
# INFO | HPO epoch   5/80 | loss=0.6453 | val={'ROC-AUC': 0.6727450980392158, 'PRC-AUC': 0.548268774630948}
# INFO | HPO epoch  10/80 | loss=0.5497 | val={'ROC-AUC': 0.7798039215686273, 'PRC-AUC': 0.6237352746651372}
# INFO | HPO epoch  15/80 | loss=0.4756 | val={'ROC-AUC': 0.7784313725490195, 'PRC-AUC': 0.6774442755549663}
# INFO | HPO epoch  20/80 | loss=0.4612 | val={'ROC-AUC': 0.7925490196078432, 'PRC-AUC': 0.6873289210909035}
# INFO | HPO epoch  25/80 | loss=0.4249 | val={'ROC-AUC': 0.8250980392156864, 'PRC-AUC': 0.7541902408887753}
# INFO | HPO epoch  30/80 | loss=0.4009 | val={'ROC-AUC': 0.8239215686274509, 'PRC-AUC': 0.7517197452362125}
# INFO | HPO epoch  35/80 | loss=0.3785 | val={'ROC-AUC': 0.8192156862745098, 'PRC-AUC': 0.7670112117561564}
# INFO | HPO epoch  40/80 | loss=0.3457 | val={'ROC-AUC': 0.7970588235294118, 'PRC-AUC': 0.7182638860921474}
# INFO | HPO epoch  45/80 | loss=0.3435 | val={'ROC-AUC': 0.8349019607843138, 'PRC-AUC': 0.7796326243291286}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | LSTM HPO — trial 9/20 finished | val=-0.850980 | best=-0.884118
# INFO | LSTM — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=0.6905 | val={'ROC-AUC': 0.6513725490196078, 'PRC-AUC': 0.46269411762668156}
# INFO | HPO epoch   5/80 | loss=0.6100 | val={'ROC-AUC': 0.7619607843137255, 'PRC-AUC': 0.6386482036661423}
# INFO | HPO epoch  10/80 | loss=0.4807 | val={'ROC-AUC': 0.823529411764706, 'PRC-AUC': 0.7174771035892671}
# INFO | HPO epoch  15/80 | loss=0.4309 | val={'ROC-AUC': 0.8227450980392157, 'PRC-AUC': 0.7275345867396483}
# INFO | HPO epoch  20/80 | loss=0.3709 | val={'ROC-AUC': 0.8376470588235294, 'PRC-AUC': 0.7742979341543862}
# INFO | HPO epoch  25/80 | loss=0.3127 | val={'ROC-AUC': 0.8290196078431372, 'PRC-AUC': 0.7752138586126834}
# INFO | HPO epoch  30/80 | loss=0.2970 | val={'ROC-AUC': 0.8450980392156863, 'PRC-AUC': 0.7979889114483422}
# INFO | HPO epoch  35/80 | loss=0.2410 | val={'ROC-AUC': 0.8454901960784313, 'PRC-AUC': 0.7785285147295121}
# INFO | HPO epoch  40/80 | loss=0.2022 | val={'ROC-AUC': 0.8482352941176471, 'PRC-AUC': 0.7669334595662787}
# INFO | HPO epoch  45/80 | loss=0.1926 | val={'ROC-AUC': 0.8396078431372549, 'PRC-AUC': 0.7706081653295498}
# INFO | HPO epoch  50/80 | loss=0.1838 | val={'ROC-AUC': 0.8356862745098038, 'PRC-AUC': 0.751395620693626}
# INFO | HPO epoch  55/80 | loss=0.1585 | val={'ROC-AUC': 0.8476470588235293, 'PRC-AUC': 0.7629954805501781}
# INFO | Early stop at epoch 59 (patience=15)
# INFO | LSTM HPO — trial 10/20 finished | val=-0.859608 | best=-0.884118
# INFO | LSTM — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=0.6923 | val={'ROC-AUC': 0.6109803921568627, 'PRC-AUC': 0.39901609576952296}
# INFO | HPO epoch   5/80 | loss=0.6853 | val={'ROC-AUC': 0.6574509803921569, 'PRC-AUC': 0.4650252185691295}
# INFO | HPO epoch  10/80 | loss=0.6740 | val={'ROC-AUC': 0.6466666666666666, 'PRC-AUC': 0.47773052922003656}
# INFO | HPO epoch  15/80 | loss=0.6146 | val={'ROC-AUC': 0.6366666666666667, 'PRC-AUC': 0.5341416993896329}
# INFO | HPO epoch  20/80 | loss=0.6048 | val={'ROC-AUC': 0.6415686274509804, 'PRC-AUC': 0.5387907789407593}
# INFO | Early stop at epoch 20 (patience=15)
# INFO | LSTM HPO — trial 11/20 finished | val=-0.657451 | best=-0.884118
# INFO | LSTM — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=0.6912 | val={'ROC-AUC': 0.6372549019607843, 'PRC-AUC': 0.4390581852686712}
# INFO | HPO epoch   5/80 | loss=0.6281 | val={'ROC-AUC': 0.6711764705882353, 'PRC-AUC': 0.5125092331315066}
# INFO | HPO epoch  10/80 | loss=0.5519 | val={'ROC-AUC': 0.7650980392156863, 'PRC-AUC': 0.6253433839475271}
# INFO | HPO epoch  15/80 | loss=0.5222 | val={'ROC-AUC': 0.7811764705882352, 'PRC-AUC': 0.6441556474747401}
# INFO | HPO epoch  20/80 | loss=0.5113 | val={'ROC-AUC': 0.7668627450980392, 'PRC-AUC': 0.6467499552126735}
# INFO | HPO epoch  25/80 | loss=0.4715 | val={'ROC-AUC': 0.8068627450980392, 'PRC-AUC': 0.676260577777841}
# INFO | HPO epoch  30/80 | loss=0.4490 | val={'ROC-AUC': 0.8166666666666667, 'PRC-AUC': 0.7200952886757783}
# INFO | HPO epoch  35/80 | loss=0.4248 | val={'ROC-AUC': 0.8101960784313724, 'PRC-AUC': 0.7230857742166464}
# INFO | HPO epoch  40/80 | loss=0.3952 | val={'ROC-AUC': 0.8315686274509804, 'PRC-AUC': 0.7454247700796756}
# INFO | HPO epoch  45/80 | loss=0.3709 | val={'ROC-AUC': 0.8388235294117646, 'PRC-AUC': 0.7617492737152077}
# INFO | HPO epoch  50/80 | loss=0.3543 | val={'ROC-AUC': 0.8386274509803922, 'PRC-AUC': 0.7652666963306054}
# INFO | HPO epoch  55/80 | loss=0.3110 | val={'ROC-AUC': 0.8309803921568627, 'PRC-AUC': 0.7547855705057633}
# INFO | Early stop at epoch 58 (patience=15)
# INFO | LSTM HPO — trial 12/20 finished | val=-0.839608 | best=-0.884118
# INFO | LSTM — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=0.6915 | val={'ROC-AUC': 0.6549019607843137, 'PRC-AUC': 0.48410203438847393}
# INFO | HPO epoch   5/80 | loss=0.6193 | val={'ROC-AUC': 0.7109803921568628, 'PRC-AUC': 0.5674847325653306}
# INFO | HPO epoch  10/80 | loss=0.5255 | val={'ROC-AUC': 0.7768627450980392, 'PRC-AUC': 0.6104427586513328}
# INFO | HPO epoch  15/80 | loss=0.4764 | val={'ROC-AUC': 0.8, 'PRC-AUC': 0.7019484510352372}
# INFO | HPO epoch  20/80 | loss=0.4460 | val={'ROC-AUC': 0.8286274509803921, 'PRC-AUC': 0.7529644164197523}
# INFO | HPO epoch  25/80 | loss=0.3960 | val={'ROC-AUC': 0.8327450980392157, 'PRC-AUC': 0.7303903025291986}
# INFO | HPO epoch  30/80 | loss=0.4041 | val={'ROC-AUC': 0.8058823529411765, 'PRC-AUC': 0.7025179087002138}
# INFO | HPO epoch  35/80 | loss=0.3432 | val={'ROC-AUC': 0.8037254901960784, 'PRC-AUC': 0.7170455804987456}
# INFO | Early stop at epoch 37 (patience=15)
# INFO | LSTM HPO — trial 13/20 finished | val=-0.843529 | best=-0.884118
# INFO | LSTM — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=0.6917 | val={'ROC-AUC': 0.6127450980392157, 'PRC-AUC': 0.4294029460343402}
# INFO | HPO epoch   5/80 | loss=0.6265 | val={'ROC-AUC': 0.6911764705882353, 'PRC-AUC': 0.549031656960943}
# INFO | HPO epoch  10/80 | loss=0.5517 | val={'ROC-AUC': 0.7431372549019608, 'PRC-AUC': 0.5853440028678399}
# INFO | HPO epoch  15/80 | loss=0.4997 | val={'ROC-AUC': 0.7809803921568628, 'PRC-AUC': 0.6510451702109558}
# INFO | HPO epoch  20/80 | loss=0.4710 | val={'ROC-AUC': 0.7972549019607844, 'PRC-AUC': 0.6160857552665093}
# INFO | HPO epoch  25/80 | loss=0.4252 | val={'ROC-AUC': 0.7847058823529411, 'PRC-AUC': 0.6133471602749315}
# INFO | HPO epoch  30/80 | loss=0.3952 | val={'ROC-AUC': 0.8182352941176471, 'PRC-AUC': 0.6602454632813387}
# INFO | HPO epoch  35/80 | loss=0.3764 | val={'ROC-AUC': 0.8133333333333332, 'PRC-AUC': 0.681933782813244}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | LSTM HPO — trial 14/20 finished | val=-0.833922 | best=-0.884118
# INFO | LSTM — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=0.6919 | val={'ROC-AUC': 0.6321568627450981, 'PRC-AUC': 0.44393157559993646}
# INFO | HPO epoch   5/80 | loss=0.6259 | val={'ROC-AUC': 0.7337254901960785, 'PRC-AUC': 0.5979668280294699}
# INFO | HPO epoch  10/80 | loss=0.5441 | val={'ROC-AUC': 0.8201960784313725, 'PRC-AUC': 0.7143712713981503}
# INFO | HPO epoch  15/80 | loss=0.4857 | val={'ROC-AUC': 0.8284313725490196, 'PRC-AUC': 0.6954507039412353}
# INFO | HPO epoch  20/80 | loss=0.4991 | val={'ROC-AUC': 0.8335294117647059, 'PRC-AUC': 0.7581581422509369}
# INFO | HPO epoch  25/80 | loss=0.3850 | val={'ROC-AUC': 0.848235294117647, 'PRC-AUC': 0.7390949080619705}
# INFO | HPO epoch  30/80 | loss=0.3477 | val={'ROC-AUC': 0.8431372549019608, 'PRC-AUC': 0.7702193162390495}
# INFO | HPO epoch  35/80 | loss=0.3378 | val={'ROC-AUC': 0.8368627450980393, 'PRC-AUC': 0.7559549891535751}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | LSTM HPO — trial 15/20 finished | val=-0.856275 | best=-0.884118
# INFO | LSTM — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=0.6931 | val={'ROC-AUC': 0.6574509803921569, 'PRC-AUC': 0.515891408044961}
# INFO | HPO epoch   5/80 | loss=0.6773 | val={'ROC-AUC': 0.6386274509803922, 'PRC-AUC': 0.475618700791815}
# INFO | HPO epoch  10/80 | loss=0.6089 | val={'ROC-AUC': 0.6535294117647059, 'PRC-AUC': 0.5257986321825296}
# INFO | HPO epoch  15/80 | loss=0.5757 | val={'ROC-AUC': 0.6825490196078433, 'PRC-AUC': 0.5681826486542724}
# INFO | HPO epoch  20/80 | loss=0.5622 | val={'ROC-AUC': 0.7107843137254901, 'PRC-AUC': 0.561248644022132}
# INFO | HPO epoch  25/80 | loss=0.5385 | val={'ROC-AUC': 0.7041176470588235, 'PRC-AUC': 0.5189350552295331}
# INFO | HPO epoch  30/80 | loss=0.5218 | val={'ROC-AUC': 0.7292156862745098, 'PRC-AUC': 0.5348393504990254}
# INFO | HPO epoch  35/80 | loss=0.4926 | val={'ROC-AUC': 0.7605882352941177, 'PRC-AUC': 0.5983672717738756}
# INFO | HPO epoch  40/80 | loss=0.4783 | val={'ROC-AUC': 0.7929411764705883, 'PRC-AUC': 0.6720504237595637}
# INFO | HPO epoch  45/80 | loss=0.4635 | val={'ROC-AUC': 0.8009803921568628, 'PRC-AUC': 0.6696619537446387}
# INFO | HPO epoch  50/80 | loss=0.4391 | val={'ROC-AUC': 0.789607843137255, 'PRC-AUC': 0.6773675493723438}
# INFO | HPO epoch  55/80 | loss=0.4383 | val={'ROC-AUC': 0.8168627450980392, 'PRC-AUC': 0.7115169396853149}
# INFO | HPO epoch  60/80 | loss=0.4057 | val={'ROC-AUC': 0.8141176470588236, 'PRC-AUC': 0.7303485629141491}
# INFO | HPO epoch  65/80 | loss=0.4105 | val={'ROC-AUC': 0.8054901960784314, 'PRC-AUC': 0.7381965638959673}
# INFO | HPO epoch  70/80 | loss=0.3881 | val={'ROC-AUC': 0.806078431372549, 'PRC-AUC': 0.7473235216874816}
# INFO | HPO epoch  75/80 | loss=0.3749 | val={'ROC-AUC': 0.8103921568627451, 'PRC-AUC': 0.763151934169646}
# INFO | HPO epoch  80/80 | loss=0.3712 | val={'ROC-AUC': 0.7984313725490196, 'PRC-AUC': 0.7547773757456404}
# INFO | LSTM HPO — trial 16/20 finished | val=-0.829608 | best=-0.884118
# INFO | LSTM — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=0.6919 | val={'ROC-AUC': 0.5935294117647059, 'PRC-AUC': 0.4131384006264841}
# INFO | HPO epoch   5/80 | loss=0.6491 | val={'ROC-AUC': 0.6639215686274509, 'PRC-AUC': 0.5605055357753728}
# INFO | HPO epoch  10/80 | loss=0.5274 | val={'ROC-AUC': 0.8231372549019608, 'PRC-AUC': 0.7593525871764919}
# INFO | HPO epoch  15/80 | loss=0.4465 | val={'ROC-AUC': 0.813921568627451, 'PRC-AUC': 0.7355669488486241}
# INFO | HPO epoch  20/80 | loss=0.4352 | val={'ROC-AUC': 0.8464705882352941, 'PRC-AUC': 0.7813297359682809}
# INFO | HPO epoch  25/80 | loss=0.3627 | val={'ROC-AUC': 0.8174509803921569, 'PRC-AUC': 0.728027687197601}
# INFO | HPO epoch  30/80 | loss=0.3477 | val={'ROC-AUC': 0.8184313725490195, 'PRC-AUC': 0.7249422060551073}
# INFO | HPO epoch  35/80 | loss=0.3422 | val={'ROC-AUC': 0.8345098039215687, 'PRC-AUC': 0.7265890531001202}
# INFO | HPO epoch  40/80 | loss=0.3264 | val={'ROC-AUC': 0.8252941176470588, 'PRC-AUC': 0.7429554474089786}
# INFO | HPO epoch  45/80 | loss=0.2828 | val={'ROC-AUC': 0.8349019607843137, 'PRC-AUC': 0.7585107289764428}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | LSTM HPO — trial 17/20 finished | val=-0.852157 | best=-0.884118
# INFO | LSTM — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=0.6922 | val={'ROC-AUC': 0.6349019607843137, 'PRC-AUC': 0.4149696691535065}
# INFO | HPO epoch   5/80 | loss=0.6771 | val={'ROC-AUC': 0.6274509803921569, 'PRC-AUC': 0.45518922618499436}
# INFO | HPO epoch  10/80 | loss=0.6188 | val={'ROC-AUC': 0.633921568627451, 'PRC-AUC': 0.5336678022668471}
# INFO | HPO epoch  15/80 | loss=0.6053 | val={'ROC-AUC': 0.6498039215686274, 'PRC-AUC': 0.533103715662958}
# INFO | HPO epoch  20/80 | loss=0.5501 | val={'ROC-AUC': 0.722156862745098, 'PRC-AUC': 0.6163810036299072}
# INFO | HPO epoch  25/80 | loss=0.5300 | val={'ROC-AUC': 0.761764705882353, 'PRC-AUC': 0.6213527127833439}
# INFO | HPO epoch  30/80 | loss=0.5313 | val={'ROC-AUC': 0.7464705882352941, 'PRC-AUC': 0.5891385850540793}
# INFO | HPO epoch  35/80 | loss=0.5073 | val={'ROC-AUC': 0.7986274509803921, 'PRC-AUC': 0.6904940500540008}
# INFO | HPO epoch  40/80 | loss=0.4941 | val={'ROC-AUC': 0.7792156862745099, 'PRC-AUC': 0.6504429145169315}
# INFO | HPO epoch  45/80 | loss=0.4711 | val={'ROC-AUC': 0.8037254901960784, 'PRC-AUC': 0.6764915182233538}
# INFO | HPO epoch  50/80 | loss=0.4608 | val={'ROC-AUC': 0.7921568627450981, 'PRC-AUC': 0.6918368585666153}
# INFO | HPO epoch  55/80 | loss=0.4817 | val={'ROC-AUC': 0.8162745098039215, 'PRC-AUC': 0.7262260150585194}
# INFO | HPO epoch  60/80 | loss=0.4307 | val={'ROC-AUC': 0.8307843137254901, 'PRC-AUC': 0.7345292817116063}
# INFO | HPO epoch  65/80 | loss=0.4334 | val={'ROC-AUC': 0.8362745098039215, 'PRC-AUC': 0.7515473943615306}
# INFO | HPO epoch  70/80 | loss=0.4444 | val={'ROC-AUC': 0.8170588235294117, 'PRC-AUC': 0.7459108050558704}
# INFO | HPO epoch  75/80 | loss=0.3968 | val={'ROC-AUC': 0.8525490196078432, 'PRC-AUC': 0.7703847227731407}
# INFO | HPO epoch  80/80 | loss=0.4060 | val={'ROC-AUC': 0.8401960784313726, 'PRC-AUC': 0.7497781604086935}
# INFO | LSTM HPO — trial 18/20 finished | val=-0.856471 | best=-0.884118
# INFO | LSTM — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=0.6920 | val={'ROC-AUC': 0.6176470588235293, 'PRC-AUC': 0.4556950638727703}
# INFO | HPO epoch   5/80 | loss=0.6279 | val={'ROC-AUC': 0.7047058823529412, 'PRC-AUC': 0.5491072761625331}
# INFO | HPO epoch  10/80 | loss=0.5371 | val={'ROC-AUC': 0.7278431372549019, 'PRC-AUC': 0.569639040928501}
# INFO | HPO epoch  15/80 | loss=0.4379 | val={'ROC-AUC': 0.7954901960784314, 'PRC-AUC': 0.6587095882474645}
# INFO | HPO epoch  20/80 | loss=0.4109 | val={'ROC-AUC': 0.7741176470588235, 'PRC-AUC': 0.6429527906790133}
# INFO | HPO epoch  25/80 | loss=0.3517 | val={'ROC-AUC': 0.8603921568627452, 'PRC-AUC': 0.7545092233775732}
# INFO | HPO epoch  30/80 | loss=0.3159 | val={'ROC-AUC': 0.8343137254901961, 'PRC-AUC': 0.6754232297793719}
# INFO | HPO epoch  35/80 | loss=0.2790 | val={'ROC-AUC': 0.8405882352941176, 'PRC-AUC': 0.7191991401174421}
# INFO | HPO epoch  40/80 | loss=0.2228 | val={'ROC-AUC': 0.8272549019607843, 'PRC-AUC': 0.7127064911801075}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | LSTM HPO — trial 19/20 finished | val=-0.860392 | best=-0.884118
# INFO | LSTM — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=0.6921 | val={'ROC-AUC': 0.5696078431372549, 'PRC-AUC': 0.3982856858860734}
# INFO | HPO epoch   5/80 | loss=0.6589 | val={'ROC-AUC': 0.6258823529411766, 'PRC-AUC': 0.4715843572802688}
# INFO | HPO epoch  10/80 | loss=0.5893 | val={'ROC-AUC': 0.7311764705882352, 'PRC-AUC': 0.591076669683919}
# INFO | HPO epoch  15/80 | loss=0.5187 | val={'ROC-AUC': 0.806078431372549, 'PRC-AUC': 0.7118109848492762}
# INFO | HPO epoch  20/80 | loss=0.4614 | val={'ROC-AUC': 0.8409803921568628, 'PRC-AUC': 0.7770280818014156}
# INFO | HPO epoch  25/80 | loss=0.4413 | val={'ROC-AUC': 0.8549019607843138, 'PRC-AUC': 0.782728749790786}
# INFO | HPO epoch  30/80 | loss=0.4310 | val={'ROC-AUC': 0.8611764705882353, 'PRC-AUC': 0.7884630796528134}
# INFO | HPO epoch  35/80 | loss=0.4064 | val={'ROC-AUC': 0.8543137254901961, 'PRC-AUC': 0.7938679464445291}
# INFO | HPO epoch  40/80 | loss=0.3949 | val={'ROC-AUC': 0.8433333333333333, 'PRC-AUC': 0.7631593720560254}
# INFO | HPO epoch  45/80 | loss=0.3680 | val={'ROC-AUC': 0.8370588235294117, 'PRC-AUC': 0.7729370301512465}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | LSTM HPO — trial 20/20 finished | val=-0.861176 | best=-0.884118
# INFO | Epoch  10 | loss=0.5521 | val={'ROC-AUC': 0.7570588235294118, 'PRC-AUC': 0.6855538932763998}
# INFO | Epoch  20 | loss=0.4928 | val={'ROC-AUC': 0.8080392156862745, 'PRC-AUC': 0.7076308747195308}
# INFO | Epoch  30 | loss=0.4176 | val={'ROC-AUC': 0.805686274509804, 'PRC-AUC': 0.6951532551676833}
# INFO | Epoch  40 | loss=0.3851 | val={'ROC-AUC': 0.8319607843137254, 'PRC-AUC': 0.7386653045887062}
# INFO | Epoch  50 | loss=0.3265 | val={'ROC-AUC': 0.8176470588235295, 'PRC-AUC': 0.6958926246739557}
# INFO | Epoch  60 | loss=0.2861 | val={'ROC-AUC': 0.8174509803921569, 'PRC-AUC': 0.6830999430852023}
# INFO | Epoch  70 | loss=0.2748 | val={'ROC-AUC': 0.8107843137254902, 'PRC-AUC': 0.6781395900651392}
# INFO | Epoch  80 | loss=0.2650 | val={'ROC-AUC': 0.8115686274509805, 'PRC-AUC': 0.6804111937661812}
# INFO | Saved SMILES LSTM → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.7417532349188992, 'PRC-AUC': 0.6470068623654758}

# %% [markdown]
# ### Finalize GPU + merge

# %%
finalize_dataset_results(DATASET_SLUG, PARTIAL_PATH, RESULTS_DIR, TASK_TYPE,
    plot_title=f"BACE – ROC-AUC by Model (higher is better) (GPU, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
cpu_partial = RESULTS_ROOT / "cpu" / f"{DATASET_SLUG}_partial.json"
if cpu_partial.exists():
    merge_combined_results(DATASET_SLUG, cpu_partial, PARTIAL_PATH, RESULTS_ROOT / "combined",
        TASK_TYPE, plot_title=f"BACE – ROC-AUC by Model (higher is better) (all models, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
else:
    print("Run CPU notebook first for combined results.")
# Out:
# === BACE Results (5/12 models) ===
#                             ROC-AUC          PRC-AUC
# Model
# GIN (2D)            0.8447 ± 0.0000  0.7484 ± 0.0000
# D-MPNN (2D)         0.8739 ± 0.0000  0.7971 ± 0.0000
# GIN (3D)            0.8631 ± 0.0000  0.8121 ± 0.0000
# SchNet (3D coords)  0.7547 ± 0.0000  0.6819 ± 0.0000
# SMILES LSTM         0.7418 ± 0.0000  0.6470 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/gpu/bace_partial.json
# === BACE Results (12/12 models) ===
#                                ROC-AUC          PRC-AUC
# Model
# Morgan + RF            0.8682 ± 0.0000  0.7418 ± 0.0000
# Morgan + SVM           0.8340 ± 0.0000  0.7237 ± 0.0000
# Morgan + XGBoost       0.8675 ± 0.0000  0.7784 ± 0.0000
# Descriptors + RF       0.8385 ± 0.0000  0.7000 ± 0.0000
# Descriptors + SVM      0.8050 ± 0.0000  0.7122 ± 0.0000
# Descriptors + XGBoost  0.8199 ± 0.0000  0.7019 ± 0.0000
# Combined + XGBoost     0.8292 ± 0.0000  0.6875 ± 0.0000
# GIN (2D)               0.8447 ± 0.0000  0.7484 ± 0.0000
# D-MPNN (2D)            0.8739 ± 0.0000  0.7971 ± 0.0000
# GIN (3D)               0.8631 ± 0.0000  0.8121 ± 0.0000
# SchNet (3D coords)     0.7547 ± 0.0000  0.6819 ± 0.0000
# SMILES LSTM            0.7418 ± 0.0000  0.6470 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/combined/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/combined/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_1/scaffold/combined/bace_partial.json
