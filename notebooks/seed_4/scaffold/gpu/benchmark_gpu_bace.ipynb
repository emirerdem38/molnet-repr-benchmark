# %% [markdown]
# # Benchmark v5 — GPU — BACE — scaffold split, seed 4
#
# **Task:** Binary — binds BACE-1 (1) or not (0)
# **Size:** ~1,513 molecules
# **Metric:** ROC-AUC ↑
#
# **Scaffold split**, seed **4** — GIN, D-MPNN, SchNet, LSTM with Optuna HPO.
#
# Results go to `results/seed_4/scaffold/`.

# %%
# %load_ext autoreload
# %autoreload 2

import os
# Avoid XGBoost/OpenMP segfaults in Jupyter on macOS (OMP Error #179).
for _omp_var in (
    "OMP_NUM_THREADS",
    "OPENBLAS_NUM_THREADS",
    "MKL_NUM_THREADS",
    "VECLIB_MAXIMUM_THREADS",
    "NUMEXPR_NUM_THREADS",
):
    os.environ[_omp_var] = "1"

import sys
from pathlib import Path

ROOT = Path(".").resolve()
for _ in range(6):
    if (ROOT / "mol_repr_utils.py").exists():
        break
    ROOT = ROOT.parent
else:
    raise FileNotFoundError("Could not find benchmark_v5 root (mol_repr_utils.py)")
sys.path.insert(0, str(ROOT))

from mol_repr_utils import *
from split_utils import (
    get_or_create_splits, subset_array, subset_list, subset_graphs_by_valid_idx,
    check_split_proportions,
)
from conformer_generation import load_conformer_graphs
from hpo_utils import (
    hpo_tabular, hpo_gnn, hpo_schnet, hpo_lstm,
    save_hpo_params, hpo_params_path,
)
from hpo_config import SKLEARN_HPO_N_ITER

DATA_DIR = ROOT / "data"

DEVICE = get_device()
print(f"Benchmark v5 (GPU) code root: {ROOT}")
print(f"Device: {DEVICE}")
print("Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.")
# Out:
# INFO | Using device: cpu (request a GPU node on the cluster for large GNN/LSTM jobs)
# Benchmark v5 (GPU) code root: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5
# Device: cpu
# Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.

# %%
DATASET_SLUG = "bace"
TASK_TYPE = "classification"
OUT_CHANNELS = 1
BATCH_SIZE = 32
GNN_EPOCHS = 100
LSTM_EPOCHS = 100
TOX21_TABULAR = False

HPO_EPOCHS = 80  # Optuna trial length; GNN_EPOCHS for final refit
HPO_N_TRIALS = 20
print(f"GPU HPO tier: standard — {HPO_N_TRIALS} trials, {HPO_EPOCHS} epochs/trial, batch={BATCH_SIZE}")

SPLIT_MODE = "scaffold"   # "scaffold" or "random"
SPLIT_SEED = 4

RESULTS_ROOT = ROOT / "results" / f"seed_{SPLIT_SEED}" / SPLIT_MODE
RESULTS_DIR = RESULTS_ROOT / "gpu"
SPLITS_DIR = RESULTS_ROOT / "splits"
HPO_DIR = RESULTS_DIR / "hpo"
HISTORY_DIR = RESULTS_DIR / "histories"
for d in (RESULTS_DIR, SPLITS_DIR, HPO_DIR, HISTORY_DIR):
    d.mkdir(parents=True, exist_ok=True)
print(f"Results → {RESULTS_ROOT}")

PARTIAL_PATH = RESULTS_DIR / f"{DATASET_SLUG}_partial.json"
FRESH_RUN = False
HPO_N_ITER = SKLEARN_HPO_N_ITER

if FRESH_RUN:
    reset_dataset_run(
        DATASET_SLUG, RESULTS_DIR,
        results_root=RESULTS_ROOT, split_mode=SPLIT_MODE,
    )
    print("Fresh run — cleared partial results and splits.")

results = load_partial_results(PARTIAL_PATH)
if results:
    print(f"Resuming {len(results)} saved model(s): {', '.join(order_results(results).keys())}")
print(f"SPLIT_SEED={SPLIT_SEED}  mode={SPLIT_MODE}")
# Out:
# GPU HPO tier: standard — 20 trials, 80 epochs/trial, batch=32
# Results → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold
# Resuming 2 saved model(s): GIN (2D), D-MPNN (2D)
# SPLIT_SEED=4  mode=scaffold

# %% [markdown]
# ### Load data

# %%
import numpy as np
import pandas as pd

df = load_dataset("bace", cache_dir=DATA_DIR)
smiles, y = preprocess_dataset(df, "bace")
print(f"Molecules : {len(smiles)}")
print(f"Class balance: {np.bincount(y.astype(int))}")
smiles, y = filter_bonded_molecules(smiles, y)
print(f'After bond filter: {len(smiles)} molecules')
# Out:
# INFO | Loading 'bace' from cache: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace.csv
# INFO | [bace] 1513 / 1513 valid molecules
# Molecules : 1513
# Class balance: [822 691]
# After bond filter: 1513 molecules

# %% [markdown]
# ### Representations & scaffold split

# %%
graphs2d_all = smiles_to_graphs(smiles, y)
graphs_dmpnn_all = smiles_to_dmpnn_graphs(smiles, y)
X_tok_all, vocab = tokenize_smiles(smiles)

graphs3d_all, valid_idx_3d, _ = load_conformer_graphs(
    DATASET_SLUG, data_dir=DATA_DIR, n_confs=25
)
graphs3d_all = ensure_atomic_numbers_list(graphs3d_all)
print(f"3D graphs loaded: {len(graphs3d_all)} / {len(smiles)} (valid_idx mapping)")

split_data = get_or_create_splits(
    smiles, RESULTS_ROOT, DATASET_SLUG,
    mode=SPLIT_MODE, seed=SPLIT_SEED, force=FRESH_RUN,
)
train_idx = split_data["train_idx"]
val_idx = split_data["val_idx"]
test_idx = split_data["test_idx"]
check_split_proportions(train_idx, val_idx, test_idx, raise_on_fail=True)
print(split_data["summary"])

tr2d = subset_list(graphs2d_all, train_idx)
va2d = subset_list(graphs2d_all, val_idx)
te2d = subset_list(graphs2d_all, test_idx)

tr_dmpnn = subset_list(graphs_dmpnn_all, train_idx)
va_dmpnn = subset_list(graphs_dmpnn_all, val_idx)
te_dmpnn = subset_list(graphs_dmpnn_all, test_idx)

tr3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, train_idx)
va3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, val_idx)
te3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, test_idx)

tr_ds = SMILESDataset(subset_array(X_tok_all, train_idx), subset_array(y, train_idx))
va_ds = SMILESDataset(subset_array(X_tok_all, val_idx), subset_array(y, val_idx))
te_ds = SMILESDataset(subset_array(X_tok_all, test_idx), subset_array(y, test_idx))
# Out:
# INFO | Loaded 1513 / 1513 graphs from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace_conformers_n25.pkl  (n_confs=25)
# INFO | Loaded splits from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/splits/bace_scaffold_splits.pkl
# 3D graphs loaded: 1513 / 1513 (valid_idx mapping)
# {'n_total': 1513, 'n_train': 1210, 'n_val': 151, 'n_test': 152, 'n_scaffolds_total': 671, 'n_scaffolds_train': 368, 'n_scaffolds_val': 151, 'n_scaffolds_test': 152}

# %% [markdown]
# ### GIN (2D)

# %%
MODEL_KEY = "GIN (2D)"
tr = tr3d if "2D" == "3D" else tr2d
va = va3d if "2D" == "3D" else va2d
te = te3d if "2D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (2D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# Skipping GIN (2D)

# %% [markdown]
# ### D-MPNN (2D)
# Bond-centric directed MPNN (Yang et al. 2019).

# %%
MODEL_KEY = "D-MPNN (2D)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr_dmpnn, va_dmpnn, TASK_TYPE, "DMPNN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("DMPNN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr_dmpnn, va_dmpnn, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te_dmpnn, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_dmpnn.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# Skipping D-MPNN (2D)

# %% [markdown]
# ### GIN (3D)

# %%
MODEL_KEY = "GIN (3D)"
tr = tr3d if "3D" == "3D" else tr2d
va = va3d if "3D" == "3D" else va2d
te = te3d if "3D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "3D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "3D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (3D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | GIN 3D — starting trial 1/20 (layers=3, hidden=256)
# → GIN (3D) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=2.1831 | val={'ROC-AUC': 0.6300000000000001, 'PRC-AUC': 0.45885418785065785}
# INFO | HPO epoch   5/80 | loss=0.5647 | val={'ROC-AUC': 0.7041176470588235, 'PRC-AUC': 0.5190951445066246}
# INFO | HPO epoch  10/80 | loss=0.5149 | val={'ROC-AUC': 0.7515686274509803, 'PRC-AUC': 0.5566531282987058}
# INFO | HPO epoch  15/80 | loss=0.4603 | val={'ROC-AUC': 0.8133333333333334, 'PRC-AUC': 0.6307348654682885}
# INFO | HPO epoch  20/80 | loss=0.4311 | val={'ROC-AUC': 0.8362745098039216, 'PRC-AUC': 0.6861526700428979}
# INFO | HPO epoch  25/80 | loss=0.4106 | val={'ROC-AUC': 0.7980392156862746, 'PRC-AUC': 0.5796669268005468}
# INFO | HPO epoch  30/80 | loss=0.4031 | val={'ROC-AUC': 0.6115686274509804, 'PRC-AUC': 0.39708579958225554}
# INFO | HPO epoch  35/80 | loss=0.3777 | val={'ROC-AUC': 0.6123529411764705, 'PRC-AUC': 0.39670354357007986}
# INFO | HPO epoch  40/80 | loss=0.3925 | val={'ROC-AUC': 0.6829411764705883, 'PRC-AUC': 0.5124072882378825}
# INFO | HPO epoch  45/80 | loss=0.3634 | val={'ROC-AUC': 0.8427450980392157, 'PRC-AUC': 0.6614492564588393}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | GIN 3D HPO — trial 1/20 finished | val=-0.862941 | best=-0.862941
# INFO | GIN 3D — starting trial 2/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=1.6693 | val={'ROC-AUC': 0.7549019607843137, 'PRC-AUC': 0.621705217797671}
# INFO | HPO epoch   5/80 | loss=0.5695 | val={'ROC-AUC': 0.6790196078431373, 'PRC-AUC': 0.4753452494787377}
# INFO | HPO epoch  10/80 | loss=0.5407 | val={'ROC-AUC': 0.7686274509803922, 'PRC-AUC': 0.6068238653919336}
# INFO | HPO epoch  15/80 | loss=0.5090 | val={'ROC-AUC': 0.782156862745098, 'PRC-AUC': 0.6257683722935676}
# INFO | HPO epoch  20/80 | loss=0.4710 | val={'ROC-AUC': 0.8017647058823529, 'PRC-AUC': 0.6103552668232015}
# INFO | HPO epoch  25/80 | loss=0.4456 | val={'ROC-AUC': 0.7415686274509804, 'PRC-AUC': 0.5522199059668738}
# INFO | HPO epoch  30/80 | loss=0.4581 | val={'ROC-AUC': 0.8501960784313726, 'PRC-AUC': 0.6895580444287074}
# INFO | HPO epoch  35/80 | loss=0.4381 | val={'ROC-AUC': 0.7937254901960784, 'PRC-AUC': 0.6477899499446753}
# INFO | HPO epoch  40/80 | loss=0.4307 | val={'ROC-AUC': 0.7417647058823529, 'PRC-AUC': 0.566697651586568}
# INFO | HPO epoch  45/80 | loss=0.3939 | val={'ROC-AUC': 0.803921568627451, 'PRC-AUC': 0.6485835673022291}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | GIN 3D HPO — trial 2/20 finished | val=-0.850196 | best=-0.862941
# INFO | GIN 3D — starting trial 3/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7794 | val={'ROC-AUC': 0.6694117647058824, 'PRC-AUC': 0.4358742303157282}
# INFO | HPO epoch   5/80 | loss=0.5406 | val={'ROC-AUC': 0.7684313725490196, 'PRC-AUC': 0.5823624239942463}
# INFO | HPO epoch  10/80 | loss=0.4951 | val={'ROC-AUC': 0.8062745098039216, 'PRC-AUC': 0.6055613564958183}
# INFO | HPO epoch  15/80 | loss=0.4336 | val={'ROC-AUC': 0.7896078431372549, 'PRC-AUC': 0.597472576857963}
# INFO | HPO epoch  20/80 | loss=0.3988 | val={'ROC-AUC': 0.8249019607843138, 'PRC-AUC': 0.6507327359483042}
# INFO | HPO epoch  25/80 | loss=0.3757 | val={'ROC-AUC': 0.8170588235294117, 'PRC-AUC': 0.6182050974746922}
# INFO | HPO epoch  30/80 | loss=0.3549 | val={'ROC-AUC': 0.7629411764705882, 'PRC-AUC': 0.5772993783928003}
# INFO | Early stop at epoch 34 (patience=15)
# INFO | GIN 3D HPO — trial 3/20 finished | val=-0.843333 | best=-0.862941
# INFO | GIN 3D — starting trial 4/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=2.1286 | val={'ROC-AUC': 0.6623529411764706, 'PRC-AUC': 0.43527220111232623}
# INFO | HPO epoch   5/80 | loss=0.6104 | val={'ROC-AUC': 0.5901960784313725, 'PRC-AUC': 0.4058478393901377}
# INFO | HPO epoch  10/80 | loss=0.5719 | val={'ROC-AUC': 0.7203921568627452, 'PRC-AUC': 0.5791486858157465}
# INFO | HPO epoch  15/80 | loss=0.5667 | val={'ROC-AUC': 0.6194117647058823, 'PRC-AUC': 0.4286694731313075}
# INFO | HPO epoch  20/80 | loss=0.5219 | val={'ROC-AUC': 0.7137254901960784, 'PRC-AUC': 0.4942902247046932}
# INFO | HPO epoch  25/80 | loss=0.4513 | val={'ROC-AUC': 0.8309803921568627, 'PRC-AUC': 0.6893572233317669}
# INFO | HPO epoch  30/80 | loss=0.4660 | val={'ROC-AUC': 0.7778431372549021, 'PRC-AUC': 0.5378317493642124}
# INFO | HPO epoch  35/80 | loss=0.4443 | val={'ROC-AUC': 0.7452941176470589, 'PRC-AUC': 0.5389577708124137}
# INFO | HPO epoch  40/80 | loss=0.3960 | val={'ROC-AUC': 0.8105882352941177, 'PRC-AUC': 0.6187389873590505}
# INFO | Early stop at epoch 42 (patience=15)
# INFO | GIN 3D HPO — trial 4/20 finished | val=-0.836078 | best=-0.862941
# INFO | GIN 3D — starting trial 5/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.7581 | val={'ROC-AUC': 0.7680392156862745, 'PRC-AUC': 0.5894092288412565}
# INFO | HPO epoch   5/80 | loss=0.5374 | val={'ROC-AUC': 0.7884313725490196, 'PRC-AUC': 0.6018923337991313}
# INFO | HPO epoch  10/80 | loss=0.4737 | val={'ROC-AUC': 0.8327450980392157, 'PRC-AUC': 0.6338377519353932}
# INFO | HPO epoch  15/80 | loss=0.4381 | val={'ROC-AUC': 0.8284313725490196, 'PRC-AUC': 0.6562084745204001}
# INFO | HPO epoch  20/80 | loss=0.4449 | val={'ROC-AUC': 0.8119607843137255, 'PRC-AUC': 0.6287315120456312}
# INFO | HPO epoch  25/80 | loss=0.3963 | val={'ROC-AUC': 0.8350980392156863, 'PRC-AUC': 0.6475858396407607}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | GIN 3D HPO — trial 5/20 finished | val=-0.848431 | best=-0.862941
# INFO | GIN 3D — starting trial 6/20 (layers=5, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.7727 | val={'ROC-AUC': 0.7003921568627451, 'PRC-AUC': 0.531019168979188}
# INFO | HPO epoch   5/80 | loss=0.5509 | val={'ROC-AUC': 0.8056862745098039, 'PRC-AUC': 0.6374790384575968}
# INFO | HPO epoch  10/80 | loss=0.4912 | val={'ROC-AUC': 0.8172549019607843, 'PRC-AUC': 0.6427162563069886}
# INFO | HPO epoch  15/80 | loss=0.4254 | val={'ROC-AUC': 0.8021568627450981, 'PRC-AUC': 0.5855335827468245}
# INFO | HPO epoch  20/80 | loss=0.3990 | val={'ROC-AUC': 0.8249019607843137, 'PRC-AUC': 0.6079690255907986}
# INFO | HPO epoch  25/80 | loss=0.3654 | val={'ROC-AUC': 0.8280392156862746, 'PRC-AUC': 0.6061711599358919}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | GIN 3D HPO — trial 6/20 finished | val=-0.842941 | best=-0.862941
# INFO | GIN 3D — starting trial 7/20 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=1.3236 | val={'ROC-AUC': 0.5952941176470588, 'PRC-AUC': 0.4616454998622236}
# INFO | HPO epoch   5/80 | loss=0.5921 | val={'ROC-AUC': 0.8015686274509805, 'PRC-AUC': 0.6448280947231286}
# INFO | HPO epoch  10/80 | loss=0.5108 | val={'ROC-AUC': 0.7637254901960785, 'PRC-AUC': 0.5845759982805511}
# INFO | HPO epoch  15/80 | loss=0.4537 | val={'ROC-AUC': 0.8, 'PRC-AUC': 0.6164654082029105}
# INFO | HPO epoch  20/80 | loss=0.4254 | val={'ROC-AUC': 0.7684313725490196, 'PRC-AUC': 0.5794782542610303}
# INFO | HPO epoch  25/80 | loss=0.4358 | val={'ROC-AUC': 0.8015686274509803, 'PRC-AUC': 0.6568801815065786}
# INFO | HPO epoch  30/80 | loss=0.3839 | val={'ROC-AUC': 0.8156862745098039, 'PRC-AUC': 0.6322214895981701}
# INFO | HPO epoch  35/80 | loss=0.3527 | val={'ROC-AUC': 0.8333333333333334, 'PRC-AUC': 0.6544996119531631}
# INFO | HPO epoch  40/80 | loss=0.3409 | val={'ROC-AUC': 0.8133333333333334, 'PRC-AUC': 0.6367250245461213}
# INFO | HPO epoch  45/80 | loss=0.3189 | val={'ROC-AUC': 0.8425490196078431, 'PRC-AUC': 0.6502867258549191}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | GIN 3D HPO — trial 7/20 finished | val=-0.846078 | best=-0.862941
# INFO | GIN 3D — starting trial 8/20 (layers=5, hidden=256)
# INFO | HPO epoch   1/80 | loss=1.2651 | val={'ROC-AUC': 0.7507843137254901, 'PRC-AUC': 0.5486084147169156}
# INFO | HPO epoch   5/80 | loss=0.5849 | val={'ROC-AUC': 0.7098039215686274, 'PRC-AUC': 0.5217531264905756}
# INFO | HPO epoch  10/80 | loss=0.4873 | val={'ROC-AUC': 0.7637254901960784, 'PRC-AUC': 0.5598912966251238}
# INFO | HPO epoch  15/80 | loss=0.4727 | val={'ROC-AUC': 0.7149019607843137, 'PRC-AUC': 0.507769688211857}
# INFO | HPO epoch  20/80 | loss=0.4529 | val={'ROC-AUC': 0.7750980392156863, 'PRC-AUC': 0.661094007169215}
# INFO | HPO epoch  25/80 | loss=0.4483 | val={'ROC-AUC': 0.8017647058823529, 'PRC-AUC': 0.6128827514891877}
# INFO | HPO epoch  30/80 | loss=0.4098 | val={'ROC-AUC': 0.8184313725490195, 'PRC-AUC': 0.6058144543603522}
# INFO | HPO epoch  35/80 | loss=0.3601 | val={'ROC-AUC': 0.8033333333333332, 'PRC-AUC': 0.59647048488575}
# INFO | HPO epoch  40/80 | loss=0.3643 | val={'ROC-AUC': 0.7896078431372549, 'PRC-AUC': 0.5861662959096094}
# INFO | HPO epoch  45/80 | loss=0.3340 | val={'ROC-AUC': 0.8443137254901961, 'PRC-AUC': 0.6649935853840772}
# INFO | HPO epoch  50/80 | loss=0.3547 | val={'ROC-AUC': 0.8441176470588234, 'PRC-AUC': 0.6612168813968802}
# INFO | HPO epoch  55/80 | loss=0.3141 | val={'ROC-AUC': 0.8150980392156864, 'PRC-AUC': 0.6157590163295821}
# INFO | HPO epoch  60/80 | loss=0.3354 | val={'ROC-AUC': 0.8456862745098039, 'PRC-AUC': 0.6789254804013657}
# INFO | Early stop at epoch 64 (patience=15)
# INFO | GIN 3D HPO — trial 8/20 finished | val=-0.846078 | best=-0.862941
# INFO | GIN 3D — starting trial 9/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.7548 | val={'ROC-AUC': 0.7254901960784315, 'PRC-AUC': 0.610401842211325}
# INFO | HPO epoch   5/80 | loss=0.4952 | val={'ROC-AUC': 0.7992156862745098, 'PRC-AUC': 0.6003752081463883}
# INFO | HPO epoch  10/80 | loss=0.4857 | val={'ROC-AUC': 0.8121568627450981, 'PRC-AUC': 0.6516219941169858}
# INFO | HPO epoch  15/80 | loss=0.4056 | val={'ROC-AUC': 0.8225490196078431, 'PRC-AUC': 0.6477809686564816}
# INFO | HPO epoch  20/80 | loss=0.3870 | val={'ROC-AUC': 0.8386274509803922, 'PRC-AUC': 0.6406554335035323}
# INFO | HPO epoch  25/80 | loss=0.3344 | val={'ROC-AUC': 0.8464705882352941, 'PRC-AUC': 0.649154816283444}
# INFO | HPO epoch  30/80 | loss=0.3294 | val={'ROC-AUC': 0.8505882352941176, 'PRC-AUC': 0.6927611154822382}
# INFO | HPO epoch  35/80 | loss=0.3158 | val={'ROC-AUC': 0.8319607843137256, 'PRC-AUC': 0.6377166376631799}
# INFO | HPO epoch  40/80 | loss=0.3129 | val={'ROC-AUC': 0.8105882352941176, 'PRC-AUC': 0.6478255233796423}
# INFO | HPO epoch  45/80 | loss=0.2589 | val={'ROC-AUC': 0.8523529411764705, 'PRC-AUC': 0.6762475832282975}
# INFO | Early stop at epoch 46 (patience=15)
# INFO | GIN 3D HPO — trial 9/20 finished | val=-0.865098 | best=-0.865098
# INFO | GIN 3D — starting trial 10/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7667 | val={'ROC-AUC': 0.6605882352941177, 'PRC-AUC': 0.43865550248101115}
# INFO | HPO epoch   5/80 | loss=0.6252 | val={'ROC-AUC': 0.7472549019607843, 'PRC-AUC': 0.5545996065843597}
# INFO | HPO epoch  10/80 | loss=0.5847 | val={'ROC-AUC': 0.7717647058823529, 'PRC-AUC': 0.5801720338188626}
# INFO | HPO epoch  15/80 | loss=0.5342 | val={'ROC-AUC': 0.7552941176470588, 'PRC-AUC': 0.5714541869209245}
# INFO | HPO epoch  20/80 | loss=0.4966 | val={'ROC-AUC': 0.7756862745098039, 'PRC-AUC': 0.6271243926043313}
# INFO | HPO epoch  25/80 | loss=0.4741 | val={'ROC-AUC': 0.7849019607843137, 'PRC-AUC': 0.6120575058580303}
# INFO | HPO epoch  30/80 | loss=0.4662 | val={'ROC-AUC': 0.8145098039215686, 'PRC-AUC': 0.6276173862373591}
# INFO | HPO epoch  35/80 | loss=0.4666 | val={'ROC-AUC': 0.8127450980392158, 'PRC-AUC': 0.6336023847251064}
# INFO | HPO epoch  40/80 | loss=0.4329 | val={'ROC-AUC': 0.817843137254902, 'PRC-AUC': 0.6298362431679212}
# INFO | HPO epoch  45/80 | loss=0.4266 | val={'ROC-AUC': 0.806078431372549, 'PRC-AUC': 0.6245777512044137}
# INFO | HPO epoch  50/80 | loss=0.4309 | val={'ROC-AUC': 0.8207843137254902, 'PRC-AUC': 0.6245225922893828}
# INFO | HPO epoch  55/80 | loss=0.3811 | val={'ROC-AUC': 0.8162745098039216, 'PRC-AUC': 0.6124269489368482}
# INFO | HPO epoch  60/80 | loss=0.3819 | val={'ROC-AUC': 0.8170588235294117, 'PRC-AUC': 0.6096541282503697}
# INFO | HPO epoch  65/80 | loss=0.3718 | val={'ROC-AUC': 0.8209803921568628, 'PRC-AUC': 0.6326726891310529}
# INFO | HPO epoch  70/80 | loss=0.3736 | val={'ROC-AUC': 0.8235294117647058, 'PRC-AUC': 0.6195064175741045}
# INFO | Early stop at epoch 72 (patience=15)
# INFO | GIN 3D HPO — trial 10/20 finished | val=-0.847451 | best=-0.865098
# INFO | GIN 3D — starting trial 11/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.8851 | val={'ROC-AUC': 0.7029411764705883, 'PRC-AUC': 0.4934294295439838}
# INFO | HPO epoch   5/80 | loss=0.5129 | val={'ROC-AUC': 0.8243137254901961, 'PRC-AUC': 0.6627644887656223}
# INFO | HPO epoch  10/80 | loss=0.4577 | val={'ROC-AUC': 0.8054901960784313, 'PRC-AUC': 0.6057492656251798}
# INFO | HPO epoch  15/80 | loss=0.4170 | val={'ROC-AUC': 0.8329411764705882, 'PRC-AUC': 0.6483839161197793}
# INFO | HPO epoch  20/80 | loss=0.3872 | val={'ROC-AUC': 0.7960784313725491, 'PRC-AUC': 0.6214675972430483}
# INFO | HPO epoch  25/80 | loss=0.3769 | val={'ROC-AUC': 0.7615686274509804, 'PRC-AUC': 0.5687526241514897}
# INFO | HPO epoch  30/80 | loss=0.3323 | val={'ROC-AUC': 0.8419607843137256, 'PRC-AUC': 0.6558759853584679}
# INFO | HPO epoch  35/80 | loss=0.3433 | val={'ROC-AUC': 0.817843137254902, 'PRC-AUC': 0.6414137049308744}
# INFO | HPO epoch  40/80 | loss=0.2903 | val={'ROC-AUC': 0.8331372549019608, 'PRC-AUC': 0.6619889153854878}
# INFO | Early stop at epoch 42 (patience=15)
# INFO | GIN 3D HPO — trial 11/20 finished | val=-0.867255 | best=-0.867255
# INFO | GIN 3D — starting trial 12/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.9107 | val={'ROC-AUC': 0.6770588235294117, 'PRC-AUC': 0.516525675733729}
# INFO | HPO epoch   5/80 | loss=0.4819 | val={'ROC-AUC': 0.8390196078431372, 'PRC-AUC': 0.6588695541949674}
# INFO | HPO epoch  10/80 | loss=0.4318 | val={'ROC-AUC': 0.8376470588235294, 'PRC-AUC': 0.6292224074852778}
# INFO | HPO epoch  15/80 | loss=0.4120 | val={'ROC-AUC': 0.8233333333333333, 'PRC-AUC': 0.6471224878067638}
# INFO | HPO epoch  20/80 | loss=0.3602 | val={'ROC-AUC': 0.82, 'PRC-AUC': 0.6637705672206099}
# INFO | HPO epoch  25/80 | loss=0.3323 | val={'ROC-AUC': 0.8070588235294118, 'PRC-AUC': 0.6398890714917271}
# INFO | HPO epoch  30/80 | loss=0.3000 | val={'ROC-AUC': 0.8445098039215686, 'PRC-AUC': 0.6767290586053617}
# INFO | HPO epoch  35/80 | loss=0.2944 | val={'ROC-AUC': 0.8347058823529412, 'PRC-AUC': 0.6462789447530004}
# INFO | HPO epoch  40/80 | loss=0.3171 | val={'ROC-AUC': 0.8119607843137254, 'PRC-AUC': 0.6422827796442039}
# INFO | HPO epoch  45/80 | loss=0.2805 | val={'ROC-AUC': 0.8441176470588235, 'PRC-AUC': 0.6652153435391934}
# INFO | HPO epoch  50/80 | loss=0.2687 | val={'ROC-AUC': 0.8488235294117648, 'PRC-AUC': 0.7021471139389933}
# INFO | HPO epoch  55/80 | loss=0.2654 | val={'ROC-AUC': 0.8311764705882353, 'PRC-AUC': 0.681539540475431}
# INFO | HPO epoch  60/80 | loss=0.2393 | val={'ROC-AUC': 0.8350980392156863, 'PRC-AUC': 0.678644426724529}
# INFO | Early stop at epoch 61 (patience=15)
# INFO | GIN 3D HPO — trial 12/20 finished | val=-0.849412 | best=-0.867255
# INFO | GIN 3D — starting trial 13/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.8048 | val={'ROC-AUC': 0.7329411764705882, 'PRC-AUC': 0.49073765631609256}
# INFO | HPO epoch   5/80 | loss=0.4887 | val={'ROC-AUC': 0.8254901960784313, 'PRC-AUC': 0.6510011498299646}
# INFO | HPO epoch  10/80 | loss=0.5027 | val={'ROC-AUC': 0.7705882352941177, 'PRC-AUC': 0.5966525943934243}
# INFO | HPO epoch  15/80 | loss=0.4014 | val={'ROC-AUC': 0.8215686274509804, 'PRC-AUC': 0.6366150596073645}
# INFO | HPO epoch  20/80 | loss=0.3395 | val={'ROC-AUC': 0.8062745098039217, 'PRC-AUC': 0.6384719019261944}
# INFO | Early stop at epoch 21 (patience=15)
# INFO | GIN 3D HPO — trial 13/20 finished | val=-0.859412 | best=-0.867255
# INFO | GIN 3D — starting trial 14/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.7548 | val={'ROC-AUC': 0.7329411764705883, 'PRC-AUC': 0.504529147258037}
# INFO | HPO epoch   5/80 | loss=0.5026 | val={'ROC-AUC': 0.7552941176470588, 'PRC-AUC': 0.561031279787081}
# INFO | HPO epoch  10/80 | loss=0.4179 | val={'ROC-AUC': 0.8431372549019608, 'PRC-AUC': 0.6751996259350378}
# INFO | HPO epoch  15/80 | loss=0.4334 | val={'ROC-AUC': 0.8127450980392158, 'PRC-AUC': 0.6154051952551595}
# INFO | HPO epoch  20/80 | loss=0.3706 | val={'ROC-AUC': 0.8492156862745098, 'PRC-AUC': 0.6584348600618507}
# INFO | HPO epoch  25/80 | loss=0.3504 | val={'ROC-AUC': 0.8013725490196079, 'PRC-AUC': 0.6215224425070076}
# INFO | HPO epoch  30/80 | loss=0.3522 | val={'ROC-AUC': 0.771372549019608, 'PRC-AUC': 0.562426522329893}
# INFO | HPO epoch  35/80 | loss=0.3070 | val={'ROC-AUC': 0.8468627450980393, 'PRC-AUC': 0.6591192980084766}
# INFO | Early stop at epoch 38 (patience=15)
# INFO | GIN 3D HPO — trial 14/20 finished | val=-0.859608 | best=-0.867255
# INFO | GIN 3D — starting trial 15/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.9730 | val={'ROC-AUC': 0.7011764705882352, 'PRC-AUC': 0.4874290488302642}
# INFO | HPO epoch   5/80 | loss=0.5090 | val={'ROC-AUC': 0.7988235294117647, 'PRC-AUC': 0.6012000640584292}
# INFO | HPO epoch  10/80 | loss=0.4639 | val={'ROC-AUC': 0.8011764705882353, 'PRC-AUC': 0.6633219163252285}
# INFO | HPO epoch  15/80 | loss=0.4446 | val={'ROC-AUC': 0.8117647058823529, 'PRC-AUC': 0.6020332223325773}
# INFO | HPO epoch  20/80 | loss=0.3749 | val={'ROC-AUC': 0.8160784313725491, 'PRC-AUC': 0.6198566740893389}
# INFO | HPO epoch  25/80 | loss=0.3415 | val={'ROC-AUC': 0.7992156862745098, 'PRC-AUC': 0.6362183683767387}
# INFO | HPO epoch  30/80 | loss=0.3444 | val={'ROC-AUC': 0.840392156862745, 'PRC-AUC': 0.650598195154335}
# INFO | Early stop at epoch 34 (patience=15)
# INFO | GIN 3D HPO — trial 15/20 finished | val=-0.842745 | best=-0.867255
# INFO | GIN 3D — starting trial 16/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.6746 | val={'ROC-AUC': 0.7378431372549019, 'PRC-AUC': 0.5537797026252661}
# INFO | HPO epoch   5/80 | loss=0.5083 | val={'ROC-AUC': 0.8294117647058823, 'PRC-AUC': 0.6359913031054805}
# INFO | HPO epoch  10/80 | loss=0.4214 | val={'ROC-AUC': 0.8339215686274509, 'PRC-AUC': 0.6521440239707571}
# INFO | HPO epoch  15/80 | loss=0.4023 | val={'ROC-AUC': 0.8337254901960784, 'PRC-AUC': 0.6545126548043718}
# INFO | HPO epoch  20/80 | loss=0.3378 | val={'ROC-AUC': 0.8284313725490196, 'PRC-AUC': 0.6510073668822831}
# INFO | Early stop at epoch 21 (patience=15)
# INFO | GIN 3D HPO — trial 16/20 finished | val=-0.845686 | best=-0.867255
# INFO | GIN 3D — starting trial 17/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.6725 | val={'ROC-AUC': 0.6809803921568628, 'PRC-AUC': 0.543963057153146}
# INFO | HPO epoch   5/80 | loss=0.4747 | val={'ROC-AUC': 0.7468627450980392, 'PRC-AUC': 0.5704228271877708}
# INFO | HPO epoch  10/80 | loss=0.4383 | val={'ROC-AUC': 0.7798039215686274, 'PRC-AUC': 0.5867002334321738}
# INFO | HPO epoch  15/80 | loss=0.4130 | val={'ROC-AUC': 0.8303921568627451, 'PRC-AUC': 0.6635227190225075}
# INFO | HPO epoch  20/80 | loss=0.4130 | val={'ROC-AUC': 0.8168627450980392, 'PRC-AUC': 0.6397700286033894}
# INFO | HPO epoch  25/80 | loss=0.3623 | val={'ROC-AUC': 0.8541176470588235, 'PRC-AUC': 0.6856023436172259}
# INFO | HPO epoch  30/80 | loss=0.3455 | val={'ROC-AUC': 0.8349019607843137, 'PRC-AUC': 0.6564392710108533}
# INFO | HPO epoch  35/80 | loss=0.2931 | val={'ROC-AUC': 0.8233333333333334, 'PRC-AUC': 0.6445353576495233}
# INFO | Early stop at epoch 36 (patience=15)
# INFO | GIN 3D HPO — trial 17/20 finished | val=-0.854510 | best=-0.867255
# INFO | GIN 3D — starting trial 18/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.8054 | val={'ROC-AUC': 0.7425490196078431, 'PRC-AUC': 0.5735673434086355}
# INFO | HPO epoch   5/80 | loss=0.5038 | val={'ROC-AUC': 0.786470588235294, 'PRC-AUC': 0.5839092553264029}
# INFO | HPO epoch  10/80 | loss=0.4526 | val={'ROC-AUC': 0.7866666666666666, 'PRC-AUC': 0.6274035772307066}
# INFO | HPO epoch  15/80 | loss=0.3908 | val={'ROC-AUC': 0.815686274509804, 'PRC-AUC': 0.6336909275890521}
# INFO | HPO epoch  20/80 | loss=0.3903 | val={'ROC-AUC': 0.7213725490196078, 'PRC-AUC': 0.5336702649082761}
# INFO | HPO epoch  25/80 | loss=0.3685 | val={'ROC-AUC': 0.8356862745098039, 'PRC-AUC': 0.6422445067612567}
# INFO | HPO epoch  30/80 | loss=0.3235 | val={'ROC-AUC': 0.851764705882353, 'PRC-AUC': 0.6530693376270076}
# INFO | HPO epoch  35/80 | loss=0.3397 | val={'ROC-AUC': 0.8143137254901961, 'PRC-AUC': 0.6553659427957077}
# INFO | HPO epoch  40/80 | loss=0.3180 | val={'ROC-AUC': 0.8066666666666666, 'PRC-AUC': 0.6513353607107374}
# INFO | HPO epoch  45/80 | loss=0.2709 | val={'ROC-AUC': 0.8172549019607843, 'PRC-AUC': 0.6371458896698997}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | GIN 3D HPO — trial 18/20 finished | val=-0.851765 | best=-0.867255
# INFO | GIN 3D — starting trial 19/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.9221 | val={'ROC-AUC': 0.6458823529411765, 'PRC-AUC': 0.535622507989298}
# INFO | HPO epoch   5/80 | loss=0.5394 | val={'ROC-AUC': 0.6966666666666667, 'PRC-AUC': 0.5449324117111103}
# INFO | HPO epoch  10/80 | loss=0.4507 | val={'ROC-AUC': 0.7386274509803922, 'PRC-AUC': 0.5205756311214733}
# INFO | HPO epoch  15/80 | loss=0.4127 | val={'ROC-AUC': 0.7760784313725491, 'PRC-AUC': 0.6415336073255437}
# INFO | HPO epoch  20/80 | loss=0.3845 | val={'ROC-AUC': 0.8364705882352941, 'PRC-AUC': 0.6229204416549634}
# INFO | Early stop at epoch 23 (patience=15)
# INFO | GIN 3D HPO — trial 19/20 finished | val=-0.839804 | best=-0.867255
# INFO | GIN 3D — starting trial 20/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.6730 | val={'ROC-AUC': 0.7903921568627451, 'PRC-AUC': 0.5994998761876975}
# INFO | HPO epoch   5/80 | loss=0.5057 | val={'ROC-AUC': 0.803921568627451, 'PRC-AUC': 0.6005140986513173}
# INFO | HPO epoch  10/80 | loss=0.4512 | val={'ROC-AUC': 0.8319607843137256, 'PRC-AUC': 0.6280212634423117}
# INFO | HPO epoch  15/80 | loss=0.4016 | val={'ROC-AUC': 0.8005882352941176, 'PRC-AUC': 0.6270728813688602}
# INFO | HPO epoch  20/80 | loss=0.3694 | val={'ROC-AUC': 0.8143137254901961, 'PRC-AUC': 0.6219156998148915}
# INFO | HPO epoch  25/80 | loss=0.3631 | val={'ROC-AUC': 0.8056862745098039, 'PRC-AUC': 0.6374957550690742}
# INFO | HPO epoch  30/80 | loss=0.3204 | val={'ROC-AUC': 0.8374509803921568, 'PRC-AUC': 0.6739923248569821}
# INFO | Early stop at epoch 33 (patience=15)
# INFO | GIN 3D HPO — trial 20/20 finished | val=-0.871373 | best=-0.871373
# INFO | Epoch  10 | loss=0.4340 | val={'ROC-AUC': 0.8229411764705883, 'PRC-AUC': 0.6297052692347838}
# INFO | Epoch  20 | loss=0.3636 | val={'ROC-AUC': 0.7950980392156862, 'PRC-AUC': 0.5711984945162888}
# INFO | Epoch  30 | loss=0.2844 | val={'ROC-AUC': 0.7821568627450981, 'PRC-AUC': 0.5850523973008297}
# INFO | Epoch  40 | loss=0.2446 | val={'ROC-AUC': 0.7829411764705884, 'PRC-AUC': 0.6132910080888503}
# INFO | Epoch  50 | loss=0.2350 | val={'ROC-AUC': 0.8058823529411765, 'PRC-AUC': 0.6779232652026123}
# INFO | Epoch  60 | loss=0.2139 | val={'ROC-AUC': 0.8015686274509803, 'PRC-AUC': 0.6621813207204265}
# INFO | Epoch  70 | loss=0.1919 | val={'ROC-AUC': 0.8005882352941176, 'PRC-AUC': 0.6472382654235515}
# INFO | Epoch  80 | loss=0.1842 | val={'ROC-AUC': 0.8009803921568628, 'PRC-AUC': 0.6540352385494393}
# INFO | Saved GIN (3D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.8330563250230841, 'PRC-AUC': 0.7613940013341022}

# %% [markdown]
# ### SchNet (3D coords)
# Uses atomic numbers + xyz from min-energy n=25 conformer.

# %%
MODEL_KEY = "SchNet (3D coords)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_schnet(
        tr3d, va3d, TASK_TYPE, OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_schnet, PyGLoader, build_schnet, train_schnet
    model = build_schnet(
        OUT_CHANNELS,
        hidden_channels=best["hidden_channels"],
        num_filters=best["num_filters"],
        num_interactions=best["num_interactions"],
        num_gaussians=best["num_gaussians"],
        cutoff=best["cutoff"],
    )
    train_schnet(model, tr3d, va3d, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
                 batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    te3d_schnet = ensure_atomic_numbers_list(te3d)
    test_metrics = eval_schnet(model, PyGLoader(te3d_schnet, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_schnet.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | SchNet — starting trial 1/20
# → SchNet (3D coords) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=1.6770 | val={'ROC-AUC': 0.4984313725490196, 'PRC-AUC': 0.349337050405677}
# INFO | HPO epoch   5/80 | loss=0.6543 | val={'ROC-AUC': 0.6480392156862744, 'PRC-AUC': 0.4678272826671248}
# INFO | HPO epoch  10/80 | loss=0.5951 | val={'ROC-AUC': 0.6798039215686275, 'PRC-AUC': 0.4984088272251926}
# INFO | HPO epoch  15/80 | loss=0.5979 | val={'ROC-AUC': 0.7331372549019609, 'PRC-AUC': 0.5244751655861775}
# INFO | HPO epoch  20/80 | loss=0.5487 | val={'ROC-AUC': 0.7503921568627451, 'PRC-AUC': 0.5470045055160533}
# INFO | HPO epoch  25/80 | loss=0.5032 | val={'ROC-AUC': 0.7350980392156863, 'PRC-AUC': 0.5318946173262532}
# INFO | HPO epoch  30/80 | loss=0.4842 | val={'ROC-AUC': 0.768235294117647, 'PRC-AUC': 0.5647610139775316}
# INFO | HPO epoch  35/80 | loss=0.4685 | val={'ROC-AUC': 0.752549019607843, 'PRC-AUC': 0.5631369354580105}
# INFO | HPO epoch  40/80 | loss=0.5823 | val={'ROC-AUC': 0.7372549019607842, 'PRC-AUC': 0.5351793047990917}
# INFO | HPO epoch  45/80 | loss=0.4492 | val={'ROC-AUC': 0.7394117647058823, 'PRC-AUC': 0.5375138325298018}
# INFO | HPO epoch  50/80 | loss=0.3956 | val={'ROC-AUC': 0.7886274509803921, 'PRC-AUC': 0.6180603061231805}
# INFO | Early stop at epoch 53 (patience=15)
# INFO | SchNet HPO — trial 1/20 finished | val=-0.794706 | best=-0.794706
# INFO | SchNet — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=1.2085 | val={'ROC-AUC': 0.6429411764705882, 'PRC-AUC': 0.45844710058219396}
# INFO | HPO epoch   5/80 | loss=0.6898 | val={'ROC-AUC': 0.6870588235294118, 'PRC-AUC': 0.48375068328042703}
# INFO | HPO epoch  10/80 | loss=0.6055 | val={'ROC-AUC': 0.683921568627451, 'PRC-AUC': 0.5160008272805666}
# INFO | HPO epoch  15/80 | loss=0.5618 | val={'ROC-AUC': 0.6901960784313725, 'PRC-AUC': 0.5339174675058663}
# INFO | Early stop at epoch 17 (patience=15)
# INFO | SchNet HPO — trial 2/20 finished | val=-0.690980 | best=-0.794706
# INFO | SchNet — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=1.5690 | val={'ROC-AUC': 0.606078431372549, 'PRC-AUC': 0.41740585111473844}
# INFO | HPO epoch   5/80 | loss=0.6235 | val={'ROC-AUC': 0.6823529411764706, 'PRC-AUC': 0.5198434963342549}
# INFO | HPO epoch  10/80 | loss=0.6895 | val={'ROC-AUC': 0.6876470588235294, 'PRC-AUC': 0.5271995756755513}
# INFO | HPO epoch  15/80 | loss=0.5501 | val={'ROC-AUC': 0.7592156862745097, 'PRC-AUC': 0.5888166091372848}
# INFO | HPO epoch  20/80 | loss=0.5272 | val={'ROC-AUC': 0.7803921568627451, 'PRC-AUC': 0.6117045813816818}
# INFO | HPO epoch  25/80 | loss=0.4865 | val={'ROC-AUC': 0.778235294117647, 'PRC-AUC': 0.624157302273336}
# INFO | HPO epoch  30/80 | loss=0.5048 | val={'ROC-AUC': 0.7619607843137255, 'PRC-AUC': 0.6069917302601189}
# INFO | HPO epoch  35/80 | loss=0.4246 | val={'ROC-AUC': 0.7784313725490196, 'PRC-AUC': 0.6222644615303993}
# INFO | HPO epoch  40/80 | loss=0.4392 | val={'ROC-AUC': 0.8201960784313725, 'PRC-AUC': 0.6503999214538166}
# INFO | HPO epoch  45/80 | loss=0.4068 | val={'ROC-AUC': 0.8064705882352942, 'PRC-AUC': 0.6728106936744288}
# INFO | HPO epoch  50/80 | loss=0.4492 | val={'ROC-AUC': 0.8066666666666666, 'PRC-AUC': 0.6299535915051422}
# INFO | HPO epoch  55/80 | loss=0.3537 | val={'ROC-AUC': 0.8009803921568628, 'PRC-AUC': 0.6700483633670236}
# INFO | HPO epoch  60/80 | loss=0.3050 | val={'ROC-AUC': 0.8064705882352942, 'PRC-AUC': 0.6301938591743383}
# INFO | Early stop at epoch 64 (patience=15)
# INFO | SchNet HPO — trial 3/20 finished | val=-0.837059 | best=-0.837059
# INFO | SchNet — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=0.9313 | val={'ROC-AUC': 0.5639215686274509, 'PRC-AUC': 0.39803095510221637}
# INFO | HPO epoch   5/80 | loss=0.5909 | val={'ROC-AUC': 0.6890196078431372, 'PRC-AUC': 0.5338091378360634}
# INFO | HPO epoch  10/80 | loss=0.5702 | val={'ROC-AUC': 0.7176470588235294, 'PRC-AUC': 0.5516636287016174}
# INFO | HPO epoch  15/80 | loss=0.5239 | val={'ROC-AUC': 0.7545098039215686, 'PRC-AUC': 0.6165229974780088}
# INFO | HPO epoch  20/80 | loss=0.4699 | val={'ROC-AUC': 0.7815686274509803, 'PRC-AUC': 0.6409246095518062}
# INFO | HPO epoch  25/80 | loss=0.4695 | val={'ROC-AUC': 0.8050980392156863, 'PRC-AUC': 0.683366910849823}
# INFO | HPO epoch  30/80 | loss=0.4613 | val={'ROC-AUC': 0.7849019607843137, 'PRC-AUC': 0.6360392043710767}
# INFO | HPO epoch  35/80 | loss=0.4514 | val={'ROC-AUC': 0.7852941176470588, 'PRC-AUC': 0.6372448730767415}
# INFO | HPO epoch  40/80 | loss=0.3965 | val={'ROC-AUC': 0.816078431372549, 'PRC-AUC': 0.6537013588723146}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | SchNet HPO — trial 4/20 finished | val=-0.825490 | best=-0.837059
# INFO | SchNet — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=3.6079 | val={'ROC-AUC': 0.6123529411764705, 'PRC-AUC': 0.4198474679615356}
# INFO | HPO epoch   5/80 | loss=0.6288 | val={'ROC-AUC': 0.6870588235294117, 'PRC-AUC': 0.4850065819619069}
# INFO | HPO epoch  10/80 | loss=0.5774 | val={'ROC-AUC': 0.7611764705882353, 'PRC-AUC': 0.5394009634671826}
# INFO | HPO epoch  15/80 | loss=0.4788 | val={'ROC-AUC': 0.7849019607843137, 'PRC-AUC': 0.6054356702015641}
# INFO | HPO epoch  20/80 | loss=0.3979 | val={'ROC-AUC': 0.7870588235294118, 'PRC-AUC': 0.6148217668840985}
# INFO | HPO epoch  25/80 | loss=0.3541 | val={'ROC-AUC': 0.7876470588235295, 'PRC-AUC': 0.6218187131640487}
# INFO | HPO epoch  30/80 | loss=0.2129 | val={'ROC-AUC': 0.8164705882352942, 'PRC-AUC': 0.6482463148062302}
# INFO | HPO epoch  35/80 | loss=0.1557 | val={'ROC-AUC': 0.8017647058823529, 'PRC-AUC': 0.6655155031198594}
# INFO | HPO epoch  40/80 | loss=0.1424 | val={'ROC-AUC': 0.7947058823529413, 'PRC-AUC': 0.6478691786476476}
# INFO | HPO epoch  45/80 | loss=0.0767 | val={'ROC-AUC': 0.8105882352941176, 'PRC-AUC': 0.6901133178514204}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | SchNet HPO — trial 5/20 finished | val=-0.816471 | best=-0.837059
# INFO | SchNet — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=1.3464 | val={'ROC-AUC': 0.5852941176470589, 'PRC-AUC': 0.40428586368872765}
# INFO | HPO epoch   5/80 | loss=0.7041 | val={'ROC-AUC': 0.6366666666666666, 'PRC-AUC': 0.4917244909574576}
# INFO | HPO epoch  10/80 | loss=0.6222 | val={'ROC-AUC': 0.6662745098039216, 'PRC-AUC': 0.4955659050981583}
# INFO | HPO epoch  15/80 | loss=0.5709 | val={'ROC-AUC': 0.724313725490196, 'PRC-AUC': 0.5315598187305454}
# INFO | HPO epoch  20/80 | loss=0.5349 | val={'ROC-AUC': 0.7374509803921568, 'PRC-AUC': 0.5478185394255246}
# INFO | HPO epoch  25/80 | loss=0.5523 | val={'ROC-AUC': 0.7598039215686275, 'PRC-AUC': 0.5753277847437626}
# INFO | HPO epoch  30/80 | loss=0.5411 | val={'ROC-AUC': 0.7727450980392156, 'PRC-AUC': 0.5880819684078228}
# INFO | HPO epoch  35/80 | loss=0.4758 | val={'ROC-AUC': 0.7715686274509803, 'PRC-AUC': 0.6015393010176571}
# INFO | HPO epoch  40/80 | loss=0.4744 | val={'ROC-AUC': 0.7833333333333333, 'PRC-AUC': 0.6428581735287269}
# INFO | HPO epoch  45/80 | loss=0.5177 | val={'ROC-AUC': 0.7915686274509803, 'PRC-AUC': 0.6493791915678259}
# INFO | HPO epoch  50/80 | loss=0.4243 | val={'ROC-AUC': 0.7843137254901962, 'PRC-AUC': 0.6363492080026629}
# INFO | HPO epoch  55/80 | loss=0.4128 | val={'ROC-AUC': 0.8192156862745098, 'PRC-AUC': 0.6553245972996294}
# INFO | HPO epoch  60/80 | loss=0.3940 | val={'ROC-AUC': 0.8109803921568628, 'PRC-AUC': 0.6699106210705793}
# INFO | HPO epoch  65/80 | loss=0.3976 | val={'ROC-AUC': 0.8501960784313726, 'PRC-AUC': 0.6908785035206124}
# INFO | HPO epoch  70/80 | loss=0.4608 | val={'ROC-AUC': 0.846078431372549, 'PRC-AUC': 0.6925577159986923}
# INFO | HPO epoch  75/80 | loss=0.3590 | val={'ROC-AUC': 0.8450980392156863, 'PRC-AUC': 0.6994692396687869}
# INFO | HPO epoch  80/80 | loss=0.3307 | val={'ROC-AUC': 0.8454901960784313, 'PRC-AUC': 0.7011441241713458}
# INFO | Early stop at epoch 80 (patience=15)
# INFO | SchNet HPO — trial 6/20 finished | val=-0.850196 | best=-0.850196
# INFO | SchNet — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=0.7264 | val={'ROC-AUC': 0.6121568627450982, 'PRC-AUC': 0.4458433446544563}
# INFO | HPO epoch   5/80 | loss=0.6178 | val={'ROC-AUC': 0.657843137254902, 'PRC-AUC': 0.473735097615847}
# INFO | HPO epoch  10/80 | loss=0.6299 | val={'ROC-AUC': 0.6709803921568628, 'PRC-AUC': 0.4928210782222689}
# INFO | HPO epoch  15/80 | loss=0.5815 | val={'ROC-AUC': 0.6874509803921568, 'PRC-AUC': 0.508274768250659}
# INFO | HPO epoch  20/80 | loss=0.5575 | val={'ROC-AUC': 0.7070588235294119, 'PRC-AUC': 0.5253964900606655}
# INFO | HPO epoch  25/80 | loss=0.5458 | val={'ROC-AUC': 0.7164705882352941, 'PRC-AUC': 0.5376277146409915}
# INFO | HPO epoch  30/80 | loss=0.5438 | val={'ROC-AUC': 0.7249019607843138, 'PRC-AUC': 0.5463865174955046}
# INFO | HPO epoch  35/80 | loss=0.5359 | val={'ROC-AUC': 0.7313725490196078, 'PRC-AUC': 0.5544564353909383}
# INFO | HPO epoch  40/80 | loss=0.5594 | val={'ROC-AUC': 0.7372549019607842, 'PRC-AUC': 0.5494136971092449}
# INFO | HPO epoch  45/80 | loss=0.5268 | val={'ROC-AUC': 0.7452941176470588, 'PRC-AUC': 0.5689864469046704}
# INFO | HPO epoch  50/80 | loss=0.4858 | val={'ROC-AUC': 0.748235294117647, 'PRC-AUC': 0.5713863066908145}
# INFO | HPO epoch  55/80 | loss=0.4749 | val={'ROC-AUC': 0.7519607843137254, 'PRC-AUC': 0.5561690326758161}
# INFO | HPO epoch  60/80 | loss=0.4685 | val={'ROC-AUC': 0.7570588235294117, 'PRC-AUC': 0.5693359169825505}
# INFO | HPO epoch  65/80 | loss=0.4840 | val={'ROC-AUC': 0.7594117647058823, 'PRC-AUC': 0.5766300727784822}
# INFO | HPO epoch  70/80 | loss=0.4478 | val={'ROC-AUC': 0.7594117647058823, 'PRC-AUC': 0.5682674441332264}
# INFO | HPO epoch  75/80 | loss=0.4543 | val={'ROC-AUC': 0.7698039215686274, 'PRC-AUC': 0.5891133456714754}
# INFO | HPO epoch  80/80 | loss=0.4278 | val={'ROC-AUC': 0.768235294117647, 'PRC-AUC': 0.5862145284938592}
# INFO | SchNet HPO — trial 7/20 finished | val=-0.774314 | best=-0.850196
# INFO | SchNet — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=1.2734 | val={'ROC-AUC': 0.5982352941176471, 'PRC-AUC': 0.3970641864889224}
# INFO | HPO epoch   5/80 | loss=0.6031 | val={'ROC-AUC': 0.6752941176470587, 'PRC-AUC': 0.5132190856750156}
# INFO | HPO epoch  10/80 | loss=0.5584 | val={'ROC-AUC': 0.7647058823529411, 'PRC-AUC': 0.6217517442368805}
# INFO | HPO epoch  15/80 | loss=0.4923 | val={'ROC-AUC': 0.7986274509803921, 'PRC-AUC': 0.6571931257288497}
# INFO | HPO epoch  20/80 | loss=0.4244 | val={'ROC-AUC': 0.8272549019607843, 'PRC-AUC': 0.6995777834434718}
# INFO | HPO epoch  25/80 | loss=0.4149 | val={'ROC-AUC': 0.8035294117647059, 'PRC-AUC': 0.683467114137859}
# INFO | HPO epoch  30/80 | loss=0.3348 | val={'ROC-AUC': 0.8350980392156863, 'PRC-AUC': 0.737961539767583}
# INFO | HPO epoch  35/80 | loss=0.2733 | val={'ROC-AUC': 0.8419607843137255, 'PRC-AUC': 0.7470987339836822}
# INFO | HPO epoch  40/80 | loss=0.2458 | val={'ROC-AUC': 0.8229411764705883, 'PRC-AUC': 0.7088669747055779}
# INFO | HPO epoch  45/80 | loss=0.2717 | val={'ROC-AUC': 0.8201960784313725, 'PRC-AUC': 0.7204463797378977}
# INFO | HPO epoch  50/80 | loss=0.1874 | val={'ROC-AUC': 0.8380392156862745, 'PRC-AUC': 0.7364002942416729}
# INFO | HPO epoch  55/80 | loss=0.1067 | val={'ROC-AUC': 0.8309803921568628, 'PRC-AUC': 0.7454621817604493}
# INFO | HPO epoch  60/80 | loss=0.0855 | val={'ROC-AUC': 0.8235294117647058, 'PRC-AUC': 0.7099815550746165}
# INFO | Early stop at epoch 63 (patience=15)
# INFO | SchNet HPO — trial 8/20 finished | val=-0.845490 | best=-0.850196
# INFO | SchNet — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=0.9100 | val={'ROC-AUC': 0.5562745098039215, 'PRC-AUC': 0.3881061127446891}
# INFO | HPO epoch   5/80 | loss=0.6458 | val={'ROC-AUC': 0.5762745098039215, 'PRC-AUC': 0.4324795322027529}
# INFO | HPO epoch  10/80 | loss=0.6147 | val={'ROC-AUC': 0.6415686274509804, 'PRC-AUC': 0.4808724504929185}
# INFO | HPO epoch  15/80 | loss=0.5856 | val={'ROC-AUC': 0.6631372549019608, 'PRC-AUC': 0.505860028241685}
# INFO | HPO epoch  20/80 | loss=0.5794 | val={'ROC-AUC': 0.6692156862745097, 'PRC-AUC': 0.5140671865677707}
# INFO | HPO epoch  25/80 | loss=0.5931 | val={'ROC-AUC': 0.6694117647058824, 'PRC-AUC': 0.5300064055185916}
# INFO | HPO epoch  30/80 | loss=0.5562 | val={'ROC-AUC': 0.6933333333333334, 'PRC-AUC': 0.5287173913420882}
# INFO | HPO epoch  35/80 | loss=0.5366 | val={'ROC-AUC': 0.7088235294117647, 'PRC-AUC': 0.5450097782203637}
# INFO | HPO epoch  40/80 | loss=0.5547 | val={'ROC-AUC': 0.7088235294117647, 'PRC-AUC': 0.5499124809419736}
# INFO | HPO epoch  45/80 | loss=0.5256 | val={'ROC-AUC': 0.7221568627450979, 'PRC-AUC': 0.5533288155237683}
# INFO | HPO epoch  50/80 | loss=0.5071 | val={'ROC-AUC': 0.7284313725490197, 'PRC-AUC': 0.5606010692470289}
# INFO | HPO epoch  55/80 | loss=0.5040 | val={'ROC-AUC': 0.7341176470588234, 'PRC-AUC': 0.5686698292593544}
# INFO | HPO epoch  60/80 | loss=0.5070 | val={'ROC-AUC': 0.7447058823529412, 'PRC-AUC': 0.5803778134194348}
# INFO | HPO epoch  65/80 | loss=0.4833 | val={'ROC-AUC': 0.7435294117647059, 'PRC-AUC': 0.5758547019446981}
# INFO | HPO epoch  70/80 | loss=0.4867 | val={'ROC-AUC': 0.7449019607843137, 'PRC-AUC': 0.5799788531316905}
# INFO | HPO epoch  75/80 | loss=0.4607 | val={'ROC-AUC': 0.7509803921568627, 'PRC-AUC': 0.5868845569983189}
# INFO | HPO epoch  80/80 | loss=0.4799 | val={'ROC-AUC': 0.7594117647058823, 'PRC-AUC': 0.60403782782388}
# INFO | SchNet HPO — trial 9/20 finished | val=-0.759412 | best=-0.850196
# INFO | SchNet — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=1.4742 | val={'ROC-AUC': 0.643921568627451, 'PRC-AUC': 0.43495308548216455}
# INFO | HPO epoch   5/80 | loss=0.7011 | val={'ROC-AUC': 0.6588235294117647, 'PRC-AUC': 0.47318336528101823}
# INFO | HPO epoch  10/80 | loss=0.6204 | val={'ROC-AUC': 0.6694117647058824, 'PRC-AUC': 0.4988139038926355}
# INFO | HPO epoch  15/80 | loss=0.5716 | val={'ROC-AUC': 0.6843137254901961, 'PRC-AUC': 0.5045829697901508}
# INFO | HPO epoch  20/80 | loss=0.5600 | val={'ROC-AUC': 0.7249019607843137, 'PRC-AUC': 0.5347165087444854}
# INFO | HPO epoch  25/80 | loss=0.5388 | val={'ROC-AUC': 0.746078431372549, 'PRC-AUC': 0.5578412332028823}
# INFO | HPO epoch  30/80 | loss=0.5744 | val={'ROC-AUC': 0.7658823529411765, 'PRC-AUC': 0.5859381755346978}
# INFO | HPO epoch  35/80 | loss=0.4779 | val={'ROC-AUC': 0.7603921568627451, 'PRC-AUC': 0.5699969614870526}
# INFO | HPO epoch  40/80 | loss=0.4861 | val={'ROC-AUC': 0.7550980392156863, 'PRC-AUC': 0.5723264870789512}
# INFO | HPO epoch  45/80 | loss=0.4771 | val={'ROC-AUC': 0.7766666666666666, 'PRC-AUC': 0.5985719598755024}
# INFO | HPO epoch  50/80 | loss=0.4742 | val={'ROC-AUC': 0.7813725490196078, 'PRC-AUC': 0.5942529566203456}
# INFO | HPO epoch  55/80 | loss=0.4421 | val={'ROC-AUC': 0.7903921568627451, 'PRC-AUC': 0.607930136884422}
# INFO | HPO epoch  60/80 | loss=0.4300 | val={'ROC-AUC': 0.78, 'PRC-AUC': 0.6039034096790887}
# INFO | HPO epoch  65/80 | loss=0.4156 | val={'ROC-AUC': 0.7980392156862746, 'PRC-AUC': 0.6110265997217759}
# INFO | HPO epoch  70/80 | loss=0.4086 | val={'ROC-AUC': 0.8076470588235294, 'PRC-AUC': 0.6226207755647664}
# INFO | HPO epoch  75/80 | loss=0.3741 | val={'ROC-AUC': 0.7998039215686273, 'PRC-AUC': 0.6479420303099467}
# INFO | HPO epoch  80/80 | loss=0.3980 | val={'ROC-AUC': 0.7964705882352942, 'PRC-AUC': 0.6332529707143317}
# INFO | SchNet HPO — trial 10/20 finished | val=-0.812353 | best=-0.850196
# INFO | SchNet — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=0.9451 | val={'ROC-AUC': 0.483921568627451, 'PRC-AUC': 0.39720082657062633}
# INFO | HPO epoch   5/80 | loss=0.6663 | val={'ROC-AUC': 0.6556862745098039, 'PRC-AUC': 0.45708447915864125}
# INFO | HPO epoch  10/80 | loss=0.6474 | val={'ROC-AUC': 0.6423529411764707, 'PRC-AUC': 0.480057906093082}
# INFO | HPO epoch  15/80 | loss=0.5931 | val={'ROC-AUC': 0.6390196078431373, 'PRC-AUC': 0.48067361498630545}
# INFO | HPO epoch  20/80 | loss=0.5935 | val={'ROC-AUC': 0.6345098039215686, 'PRC-AUC': 0.47513035934975933}
# INFO | HPO epoch  25/80 | loss=0.5926 | val={'ROC-AUC': 0.6705882352941176, 'PRC-AUC': 0.5008288693108022}
# INFO | HPO epoch  30/80 | loss=0.5660 | val={'ROC-AUC': 0.6850980392156862, 'PRC-AUC': 0.5050658511621317}
# INFO | HPO epoch  35/80 | loss=0.5635 | val={'ROC-AUC': 0.7013725490196079, 'PRC-AUC': 0.5133565870887039}
# INFO | HPO epoch  40/80 | loss=0.5536 | val={'ROC-AUC': 0.7088235294117646, 'PRC-AUC': 0.522166908573048}
# INFO | HPO epoch  45/80 | loss=0.5680 | val={'ROC-AUC': 0.7225490196078431, 'PRC-AUC': 0.536787012909848}
# INFO | HPO epoch  50/80 | loss=0.5361 | val={'ROC-AUC': 0.7288235294117646, 'PRC-AUC': 0.5390889495243386}
# INFO | HPO epoch  55/80 | loss=0.5381 | val={'ROC-AUC': 0.7329411764705882, 'PRC-AUC': 0.5293856923322939}
# INFO | HPO epoch  60/80 | loss=0.5288 | val={'ROC-AUC': 0.7437254901960785, 'PRC-AUC': 0.5503834256285934}
# INFO | HPO epoch  65/80 | loss=0.5160 | val={'ROC-AUC': 0.7476470588235294, 'PRC-AUC': 0.552673990918756}
# INFO | HPO epoch  70/80 | loss=0.5132 | val={'ROC-AUC': 0.755686274509804, 'PRC-AUC': 0.5690638741603475}
# INFO | HPO epoch  75/80 | loss=0.5006 | val={'ROC-AUC': 0.7603921568627451, 'PRC-AUC': 0.5625772694246591}
# INFO | HPO epoch  80/80 | loss=0.5058 | val={'ROC-AUC': 0.7694117647058824, 'PRC-AUC': 0.5868254828139059}
# INFO | SchNet HPO — trial 11/20 finished | val=-0.769412 | best=-0.850196
# INFO | SchNet — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=1.3225 | val={'ROC-AUC': 0.4892156862745098, 'PRC-AUC': 0.37369314710157553}
# INFO | HPO epoch   5/80 | loss=0.6028 | val={'ROC-AUC': 0.6723529411764706, 'PRC-AUC': 0.5415485596859582}
# INFO | HPO epoch  10/80 | loss=0.5194 | val={'ROC-AUC': 0.7447058823529412, 'PRC-AUC': 0.6220589216072033}
# INFO | HPO epoch  15/80 | loss=0.4738 | val={'ROC-AUC': 0.7941176470588235, 'PRC-AUC': 0.6896105819607748}
# INFO | HPO epoch  20/80 | loss=0.4149 | val={'ROC-AUC': 0.8231372549019608, 'PRC-AUC': 0.6928481932273337}
# INFO | HPO epoch  25/80 | loss=0.4271 | val={'ROC-AUC': 0.8241176470588235, 'PRC-AUC': 0.7178491807697911}
# INFO | HPO epoch  30/80 | loss=0.3424 | val={'ROC-AUC': 0.8227450980392157, 'PRC-AUC': 0.7353541634270182}
# INFO | HPO epoch  35/80 | loss=0.2390 | val={'ROC-AUC': 0.8303921568627451, 'PRC-AUC': 0.6959741642392999}
# INFO | HPO epoch  40/80 | loss=0.1602 | val={'ROC-AUC': 0.8341176470588234, 'PRC-AUC': 0.7424755320759624}
# INFO | HPO epoch  45/80 | loss=0.1646 | val={'ROC-AUC': 0.8386274509803922, 'PRC-AUC': 0.716127752045672}
# INFO | HPO epoch  50/80 | loss=0.0867 | val={'ROC-AUC': 0.8307843137254901, 'PRC-AUC': 0.7089084469793119}
# INFO | Early stop at epoch 52 (patience=15)
# INFO | SchNet HPO — trial 12/20 finished | val=-0.859608 | best=-0.859608
# INFO | SchNet — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=1.7588 | val={'ROC-AUC': 0.5996078431372549, 'PRC-AUC': 0.4046341825452102}
# INFO | HPO epoch   5/80 | loss=0.6044 | val={'ROC-AUC': 0.701764705882353, 'PRC-AUC': 0.5079062522336975}
# INFO | HPO epoch  10/80 | loss=0.4998 | val={'ROC-AUC': 0.7858823529411764, 'PRC-AUC': 0.6582509328475192}
# INFO | HPO epoch  15/80 | loss=0.5145 | val={'ROC-AUC': 0.8247058823529412, 'PRC-AUC': 0.6922351136125595}
# INFO | HPO epoch  20/80 | loss=0.4196 | val={'ROC-AUC': 0.8301960784313726, 'PRC-AUC': 0.7267160594678993}
# INFO | HPO epoch  25/80 | loss=0.4927 | val={'ROC-AUC': 0.8129411764705883, 'PRC-AUC': 0.6907514958038419}
# INFO | HPO epoch  30/80 | loss=0.3252 | val={'ROC-AUC': 0.8450980392156863, 'PRC-AUC': 0.7550550858095102}
# INFO | HPO epoch  35/80 | loss=0.2728 | val={'ROC-AUC': 0.8194117647058825, 'PRC-AUC': 0.7200205633404786}
# INFO | HPO epoch  40/80 | loss=0.2499 | val={'ROC-AUC': 0.8149019607843138, 'PRC-AUC': 0.6985189937479326}
# INFO | HPO epoch  45/80 | loss=0.1966 | val={'ROC-AUC': 0.8274509803921568, 'PRC-AUC': 0.7231513200890253}
# INFO | HPO epoch  50/80 | loss=0.1625 | val={'ROC-AUC': 0.8241176470588234, 'PRC-AUC': 0.7118601957242694}
# INFO | Early stop at epoch 54 (patience=15)
# INFO | SchNet HPO — trial 13/20 finished | val=-0.845490 | best=-0.859608
# INFO | SchNet — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=2.0120 | val={'ROC-AUC': 0.5958823529411765, 'PRC-AUC': 0.42027947405206556}
# INFO | HPO epoch   5/80 | loss=0.6471 | val={'ROC-AUC': 0.697843137254902, 'PRC-AUC': 0.508558700013275}
# INFO | HPO epoch  10/80 | loss=0.5750 | val={'ROC-AUC': 0.7680392156862744, 'PRC-AUC': 0.5816070889904105}
# INFO | HPO epoch  15/80 | loss=0.6363 | val={'ROC-AUC': 0.7847058823529411, 'PRC-AUC': 0.583655275571527}
# INFO | HPO epoch  20/80 | loss=0.5414 | val={'ROC-AUC': 0.8013725490196079, 'PRC-AUC': 0.6267284980974418}
# INFO | HPO epoch  25/80 | loss=0.5344 | val={'ROC-AUC': 0.7958823529411765, 'PRC-AUC': 0.6145846801646841}
# INFO | HPO epoch  30/80 | loss=0.4042 | val={'ROC-AUC': 0.7915686274509802, 'PRC-AUC': 0.6191570420779573}
# INFO | HPO epoch  35/80 | loss=0.3642 | val={'ROC-AUC': 0.830392156862745, 'PRC-AUC': 0.6513175284022742}
# INFO | HPO epoch  40/80 | loss=0.3605 | val={'ROC-AUC': 0.8370588235294117, 'PRC-AUC': 0.669342157097096}
# INFO | HPO epoch  45/80 | loss=0.2849 | val={'ROC-AUC': 0.8531372549019608, 'PRC-AUC': 0.6865360366726044}
# INFO | HPO epoch  50/80 | loss=0.2641 | val={'ROC-AUC': 0.8419607843137255, 'PRC-AUC': 0.6756867278037556}
# INFO | HPO epoch  55/80 | loss=0.2215 | val={'ROC-AUC': 0.8537254901960785, 'PRC-AUC': 0.6973485456987566}
# INFO | HPO epoch  60/80 | loss=0.1907 | val={'ROC-AUC': 0.845686274509804, 'PRC-AUC': 0.687362744857622}
# INFO | HPO epoch  65/80 | loss=0.1357 | val={'ROC-AUC': 0.8368627450980393, 'PRC-AUC': 0.6643015427348222}
# INFO | HPO epoch  70/80 | loss=0.0855 | val={'ROC-AUC': 0.8425490196078431, 'PRC-AUC': 0.6818906375350041}
# INFO | Early stop at epoch 70 (patience=15)
# INFO | SchNet HPO — trial 14/20 finished | val=-0.853725 | best=-0.859608
# INFO | SchNet — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=2.8909 | val={'ROC-AUC': 0.5831372549019608, 'PRC-AUC': 0.38452722401930517}
# INFO | HPO epoch   5/80 | loss=0.6712 | val={'ROC-AUC': 0.6652941176470588, 'PRC-AUC': 0.4589790507977546}
# INFO | HPO epoch  10/80 | loss=0.7118 | val={'ROC-AUC': 0.7296078431372548, 'PRC-AUC': 0.5229626392922917}
# INFO | HPO epoch  15/80 | loss=0.5132 | val={'ROC-AUC': 0.793921568627451, 'PRC-AUC': 0.5914707052031284}
# INFO | HPO epoch  20/80 | loss=0.4652 | val={'ROC-AUC': 0.7905882352941177, 'PRC-AUC': 0.6337755316024976}
# INFO | HPO epoch  25/80 | loss=0.3730 | val={'ROC-AUC': 0.806078431372549, 'PRC-AUC': 0.6424344814343541}
# INFO | HPO epoch  30/80 | loss=0.3325 | val={'ROC-AUC': 0.7886274509803921, 'PRC-AUC': 0.6335796793520699}
# INFO | HPO epoch  35/80 | loss=0.2543 | val={'ROC-AUC': 0.7513725490196078, 'PRC-AUC': 0.6423723593516337}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | SchNet HPO — trial 15/20 finished | val=-0.812941 | best=-0.859608
# INFO | SchNet — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=1.6392 | val={'ROC-AUC': 0.6117647058823529, 'PRC-AUC': 0.42036892839408224}
# INFO | HPO epoch   5/80 | loss=0.5636 | val={'ROC-AUC': 0.7013725490196078, 'PRC-AUC': 0.5247251391223862}
# INFO | HPO epoch  10/80 | loss=0.5263 | val={'ROC-AUC': 0.7550980392156862, 'PRC-AUC': 0.5920804717642028}
# INFO | HPO epoch  15/80 | loss=0.4849 | val={'ROC-AUC': 0.8154901960784313, 'PRC-AUC': 0.6639667367670324}
# INFO | HPO epoch  20/80 | loss=0.4208 | val={'ROC-AUC': 0.809607843137255, 'PRC-AUC': 0.671243094824192}
# INFO | HPO epoch  25/80 | loss=0.4006 | val={'ROC-AUC': 0.8407843137254902, 'PRC-AUC': 0.7067450010428}
# INFO | HPO epoch  30/80 | loss=0.3366 | val={'ROC-AUC': 0.8068627450980392, 'PRC-AUC': 0.7197731173996874}
# INFO | HPO epoch  35/80 | loss=0.2576 | val={'ROC-AUC': 0.8270588235294118, 'PRC-AUC': 0.6992932418191603}
# INFO | HPO epoch  40/80 | loss=0.1920 | val={'ROC-AUC': 0.8284313725490196, 'PRC-AUC': 0.7171679274693429}
# INFO | Early stop at epoch 40 (patience=15)
# INFO | SchNet HPO — trial 16/20 finished | val=-0.840784 | best=-0.859608
# INFO | SchNet — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=1.3991 | val={'ROC-AUC': 0.5568627450980392, 'PRC-AUC': 0.3860555680875328}
# INFO | HPO epoch   5/80 | loss=0.6351 | val={'ROC-AUC': 0.6807843137254901, 'PRC-AUC': 0.5049763852653679}
# INFO | HPO epoch  10/80 | loss=0.5475 | val={'ROC-AUC': 0.77, 'PRC-AUC': 0.6110338188652904}
# INFO | HPO epoch  15/80 | loss=0.4656 | val={'ROC-AUC': 0.7884313725490196, 'PRC-AUC': 0.6584420926208591}
# INFO | HPO epoch  20/80 | loss=0.4458 | val={'ROC-AUC': 0.8107843137254902, 'PRC-AUC': 0.6651937497720989}
# INFO | HPO epoch  25/80 | loss=0.3458 | val={'ROC-AUC': 0.8062745098039217, 'PRC-AUC': 0.6892089825788136}
# INFO | HPO epoch  30/80 | loss=0.3146 | val={'ROC-AUC': 0.8266666666666667, 'PRC-AUC': 0.7048868976988203}
# INFO | HPO epoch  35/80 | loss=0.1988 | val={'ROC-AUC': 0.8066666666666665, 'PRC-AUC': 0.7047644572952114}
# INFO | Early stop at epoch 37 (patience=15)
# INFO | SchNet HPO — trial 17/20 finished | val=-0.827647 | best=-0.859608
# INFO | SchNet — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=1.1833 | val={'ROC-AUC': 0.5072549019607844, 'PRC-AUC': 0.35909191431820886}
# INFO | HPO epoch   5/80 | loss=0.6189 | val={'ROC-AUC': 0.6949019607843138, 'PRC-AUC': 0.5441505945186964}
# INFO | HPO epoch  10/80 | loss=0.5833 | val={'ROC-AUC': 0.743921568627451, 'PRC-AUC': 0.5904586866415742}
# INFO | HPO epoch  15/80 | loss=0.5809 | val={'ROC-AUC': 0.8015686274509803, 'PRC-AUC': 0.626289726084596}
# INFO | HPO epoch  20/80 | loss=0.4870 | val={'ROC-AUC': 0.7819607843137255, 'PRC-AUC': 0.6126828272465945}
# INFO | HPO epoch  25/80 | loss=0.4676 | val={'ROC-AUC': 0.7866666666666666, 'PRC-AUC': 0.6563127282384575}
# INFO | HPO epoch  30/80 | loss=0.4804 | val={'ROC-AUC': 0.7707843137254902, 'PRC-AUC': 0.6176550861545749}
# INFO | HPO epoch  35/80 | loss=0.4199 | val={'ROC-AUC': 0.773921568627451, 'PRC-AUC': 0.6269438816593838}
# INFO | HPO epoch  40/80 | loss=0.3682 | val={'ROC-AUC': 0.7937254901960784, 'PRC-AUC': 0.6570584634586215}
# INFO | Early stop at epoch 41 (patience=15)
# INFO | SchNet HPO — trial 18/20 finished | val=-0.814510 | best=-0.859608
# INFO | SchNet — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=0.8631 | val={'ROC-AUC': 0.5731372549019608, 'PRC-AUC': 0.3849905379321416}
# INFO | HPO epoch   5/80 | loss=0.6161 | val={'ROC-AUC': 0.6168627450980393, 'PRC-AUC': 0.4383158893264337}
# INFO | HPO epoch  10/80 | loss=0.6677 | val={'ROC-AUC': 0.6639215686274509, 'PRC-AUC': 0.49024802684954755}
# INFO | HPO epoch  15/80 | loss=0.5411 | val={'ROC-AUC': 0.6954901960784313, 'PRC-AUC': 0.5428687453080006}
# INFO | HPO epoch  20/80 | loss=0.5708 | val={'ROC-AUC': 0.7076470588235293, 'PRC-AUC': 0.5444370026682017}
# INFO | HPO epoch  25/80 | loss=0.5364 | val={'ROC-AUC': 0.7415686274509804, 'PRC-AUC': 0.5806808730733136}
# INFO | HPO epoch  30/80 | loss=0.5818 | val={'ROC-AUC': 0.7382352941176471, 'PRC-AUC': 0.5748128108033806}
# INFO | HPO epoch  35/80 | loss=0.4791 | val={'ROC-AUC': 0.7552941176470588, 'PRC-AUC': 0.5913349110325506}
# INFO | HPO epoch  40/80 | loss=0.4964 | val={'ROC-AUC': 0.7698039215686275, 'PRC-AUC': 0.6218052291055282}
# INFO | HPO epoch  45/80 | loss=0.4436 | val={'ROC-AUC': 0.7701960784313726, 'PRC-AUC': 0.6305514393972432}
# INFO | HPO epoch  50/80 | loss=0.4491 | val={'ROC-AUC': 0.7529411764705882, 'PRC-AUC': 0.5983724845215678}
# INFO | HPO epoch  55/80 | loss=0.4819 | val={'ROC-AUC': 0.7686274509803921, 'PRC-AUC': 0.6533897231890425}
# INFO | HPO epoch  60/80 | loss=0.4037 | val={'ROC-AUC': 0.7688235294117647, 'PRC-AUC': 0.6279638556036182}
# INFO | Early stop at epoch 62 (patience=15)
# INFO | SchNet HPO — trial 19/20 finished | val=-0.781373 | best=-0.859608
# INFO | SchNet — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=3.1721 | val={'ROC-AUC': 0.6066666666666667, 'PRC-AUC': 0.43231733019352103}
# INFO | HPO epoch   5/80 | loss=0.6172 | val={'ROC-AUC': 0.6947058823529412, 'PRC-AUC': 0.49951689694308543}
# INFO | HPO epoch  10/80 | loss=0.6768 | val={'ROC-AUC': 0.7396078431372549, 'PRC-AUC': 0.5413141004840962}
# INFO | HPO epoch  15/80 | loss=0.4661 | val={'ROC-AUC': 0.7872549019607844, 'PRC-AUC': 0.6218480072405441}
# INFO | HPO epoch  20/80 | loss=0.4649 | val={'ROC-AUC': 0.7927450980392156, 'PRC-AUC': 0.6102921976186497}
# INFO | HPO epoch  25/80 | loss=0.4245 | val={'ROC-AUC': 0.8021568627450979, 'PRC-AUC': 0.6507884088760336}
# INFO | HPO epoch  30/80 | loss=0.3617 | val={'ROC-AUC': 0.7905882352941176, 'PRC-AUC': 0.6360148416792046}
# INFO | HPO epoch  35/80 | loss=0.3309 | val={'ROC-AUC': 0.8047058823529412, 'PRC-AUC': 0.6452502820857037}
# INFO | HPO epoch  40/80 | loss=0.2390 | val={'ROC-AUC': 0.7498039215686274, 'PRC-AUC': 0.622695883587274}
# INFO | HPO epoch  45/80 | loss=0.1753 | val={'ROC-AUC': 0.8015686274509805, 'PRC-AUC': 0.6638198448943458}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | SchNet HPO — trial 20/20 finished | val=-0.834314 | best=-0.859608
# INFO | Epoch  10 | loss=0.5791 | val={'ROC-AUC': 0.7392156862745097, 'PRC-AUC': 0.5891248974482046}
# INFO | Epoch  20 | loss=0.4077 | val={'ROC-AUC': 0.7913725490196079, 'PRC-AUC': 0.6377348441676631}
# INFO | Epoch  30 | loss=0.3435 | val={'ROC-AUC': 0.7976470588235294, 'PRC-AUC': 0.6755877971669815}
# INFO | Epoch  40 | loss=0.1861 | val={'ROC-AUC': 0.7984313725490195, 'PRC-AUC': 0.6703577096092141}
# INFO | Epoch  50 | loss=0.1148 | val={'ROC-AUC': 0.7831372549019607, 'PRC-AUC': 0.6591727703699879}
# INFO | Epoch  60 | loss=0.0768 | val={'ROC-AUC': 0.7801960784313725, 'PRC-AUC': 0.658806228515393}
# INFO | Epoch  70 | loss=0.0609 | val={'ROC-AUC': 0.7721568627450981, 'PRC-AUC': 0.658858400889935}
# INFO | Epoch  80 | loss=0.0558 | val={'ROC-AUC': 0.7733333333333333, 'PRC-AUC': 0.6613150956503502}
# INFO | Saved SchNet (3D coords) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.7824561403508771, 'PRC-AUC': 0.7170650613578321}

# %% [markdown]
# ### SMILES LSTM
# Canonical isomeric SMILES tokens.

# %%
MODEL_KEY = "SMILES LSTM"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_lstm(
        tr_ds, va_ds, TASK_TYPE, len(vocab), OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import SmilesLSTM, eval_lstm, TorchLoader, train_lstm
    model = SmilesLSTM(len(vocab), embed_dim=best["embed_dim"], hidden_dim=best["hidden_dim"],
                       n_layers=best["n_layers"], out_channels=OUT_CHANNELS, dropout=best["dropout"])
    train_lstm(model, tr_ds, va_ds, TASK_TYPE, epochs=LSTM_EPOCHS, lr=best["lr"],
               batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_lstm(model, TorchLoader(te_ds, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_lstm.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | LSTM — starting trial 1/20
# → SMILES LSTM (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.6899 | val={'ROC-AUC': 0.6656862745098039, 'PRC-AUC': 0.45557726508162116}
# INFO | HPO epoch   5/80 | loss=0.5806 | val={'ROC-AUC': 0.7841176470588236, 'PRC-AUC': 0.6702736720219321}
# INFO | HPO epoch  10/80 | loss=0.5341 | val={'ROC-AUC': 0.7003921568627451, 'PRC-AUC': 0.5161940560781839}
# INFO | HPO epoch  15/80 | loss=0.4843 | val={'ROC-AUC': 0.8376470588235294, 'PRC-AUC': 0.7122501893868612}
# INFO | HPO epoch  20/80 | loss=0.3904 | val={'ROC-AUC': 0.8366666666666667, 'PRC-AUC': 0.6964011267718118}
# INFO | HPO epoch  25/80 | loss=0.4062 | val={'ROC-AUC': 0.8113725490196079, 'PRC-AUC': 0.6715842321912432}
# INFO | HPO epoch  30/80 | loss=0.3229 | val={'ROC-AUC': 0.8213725490196078, 'PRC-AUC': 0.6449206168138788}
# INFO | HPO epoch  35/80 | loss=0.3018 | val={'ROC-AUC': 0.8619607843137255, 'PRC-AUC': 0.704390951461984}
# INFO | Early stop at epoch 39 (patience=15)
# INFO | LSTM HPO — trial 1/20 finished | val=-0.877451 | best=-0.877451
# INFO | LSTM — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=0.6888 | val={'ROC-AUC': 0.6731372549019607, 'PRC-AUC': 0.46239942193803796}
# INFO | HPO epoch   5/80 | loss=0.6421 | val={'ROC-AUC': 0.7637254901960784, 'PRC-AUC': 0.6357339532081802}
# INFO | HPO epoch  10/80 | loss=0.5439 | val={'ROC-AUC': 0.8133333333333334, 'PRC-AUC': 0.6866882887828587}
# INFO | HPO epoch  15/80 | loss=0.5197 | val={'ROC-AUC': 0.8074509803921569, 'PRC-AUC': 0.6816635988473532}
# INFO | HPO epoch  20/80 | loss=0.4787 | val={'ROC-AUC': 0.8166666666666667, 'PRC-AUC': 0.6745882931535842}
# INFO | HPO epoch  25/80 | loss=0.4729 | val={'ROC-AUC': 0.8331372549019608, 'PRC-AUC': 0.690492869672508}
# INFO | HPO epoch  30/80 | loss=0.4460 | val={'ROC-AUC': 0.8266666666666667, 'PRC-AUC': 0.6903296176012536}
# INFO | HPO epoch  35/80 | loss=0.4367 | val={'ROC-AUC': 0.8266666666666667, 'PRC-AUC': 0.6958442073003723}
# INFO | Early stop at epoch 37 (patience=15)
# INFO | LSTM HPO — trial 2/20 finished | val=-0.837255 | best=-0.877451
# INFO | LSTM — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=0.6927 | val={'ROC-AUC': 0.5994117647058823, 'PRC-AUC': 0.39350894818013094}
# INFO | HPO epoch   5/80 | loss=0.6800 | val={'ROC-AUC': 0.6560784313725491, 'PRC-AUC': 0.44104671447038046}
# INFO | HPO epoch  10/80 | loss=0.6268 | val={'ROC-AUC': 0.73, 'PRC-AUC': 0.590930838604505}
# INFO | HPO epoch  15/80 | loss=0.5764 | val={'ROC-AUC': 0.7382352941176471, 'PRC-AUC': 0.6101092413889768}
# INFO | HPO epoch  20/80 | loss=0.5481 | val={'ROC-AUC': 0.7321568627450981, 'PRC-AUC': 0.6009727278326832}
# INFO | HPO epoch  25/80 | loss=0.5312 | val={'ROC-AUC': 0.7650980392156863, 'PRC-AUC': 0.6176408019925955}
# INFO | HPO epoch  30/80 | loss=0.4963 | val={'ROC-AUC': 0.8025490196078432, 'PRC-AUC': 0.6601281256048491}
# INFO | HPO epoch  35/80 | loss=0.4775 | val={'ROC-AUC': 0.7994117647058823, 'PRC-AUC': 0.6320042752493138}
# INFO | HPO epoch  40/80 | loss=0.4668 | val={'ROC-AUC': 0.8296078431372548, 'PRC-AUC': 0.6871394832509393}
# INFO | HPO epoch  45/80 | loss=0.4377 | val={'ROC-AUC': 0.8276470588235294, 'PRC-AUC': 0.6583077703300401}
# INFO | HPO epoch  50/80 | loss=0.4463 | val={'ROC-AUC': 0.8356862745098038, 'PRC-AUC': 0.6880054263016145}
# INFO | HPO epoch  55/80 | loss=0.4147 | val={'ROC-AUC': 0.8368627450980392, 'PRC-AUC': 0.695689446073388}
# INFO | HPO epoch  60/80 | loss=0.4086 | val={'ROC-AUC': 0.8339215686274509, 'PRC-AUC': 0.6454916780154702}
# INFO | HPO epoch  65/80 | loss=0.3993 | val={'ROC-AUC': 0.8419607843137255, 'PRC-AUC': 0.6874142611004126}
# INFO | HPO epoch  70/80 | loss=0.3909 | val={'ROC-AUC': 0.8425490196078431, 'PRC-AUC': 0.6922344241240497}
# INFO | HPO epoch  75/80 | loss=0.3725 | val={'ROC-AUC': 0.852549019607843, 'PRC-AUC': 0.6800184104191789}
# INFO | HPO epoch  80/80 | loss=0.3680 | val={'ROC-AUC': 0.8574509803921568, 'PRC-AUC': 0.7096244757561044}
# INFO | LSTM HPO — trial 3/20 finished | val=-0.858824 | best=-0.877451
# INFO | LSTM — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=0.6933 | val={'ROC-AUC': 0.643921568627451, 'PRC-AUC': 0.4312081606274623}
# INFO | HPO epoch   5/80 | loss=0.6140 | val={'ROC-AUC': 0.7633333333333334, 'PRC-AUC': 0.6254514837984879}
# INFO | HPO epoch  10/80 | loss=0.5313 | val={'ROC-AUC': 0.8001960784313725, 'PRC-AUC': 0.6569135195208963}
# INFO | HPO epoch  15/80 | loss=0.5355 | val={'ROC-AUC': 0.7674509803921568, 'PRC-AUC': 0.6293987046731011}
# INFO | HPO epoch  20/80 | loss=0.4812 | val={'ROC-AUC': 0.8070588235294118, 'PRC-AUC': 0.656885737799265}
# INFO | HPO epoch  25/80 | loss=0.4557 | val={'ROC-AUC': 0.838235294117647, 'PRC-AUC': 0.6853949979297613}
# INFO | HPO epoch  30/80 | loss=0.4628 | val={'ROC-AUC': 0.8386274509803922, 'PRC-AUC': 0.685173256578777}
# INFO | HPO epoch  35/80 | loss=0.4213 | val={'ROC-AUC': 0.8229411764705882, 'PRC-AUC': 0.7116418553884062}
# INFO | HPO epoch  40/80 | loss=0.4378 | val={'ROC-AUC': 0.8198039215686275, 'PRC-AUC': 0.6640249681407335}
# INFO | HPO epoch  45/80 | loss=0.4215 | val={'ROC-AUC': 0.8329411764705883, 'PRC-AUC': 0.692316704859317}
# INFO | HPO epoch  50/80 | loss=0.4060 | val={'ROC-AUC': 0.8266666666666667, 'PRC-AUC': 0.7254665174634797}
# INFO | HPO epoch  55/80 | loss=0.3744 | val={'ROC-AUC': 0.8370588235294117, 'PRC-AUC': 0.6797359362646619}
# INFO | Early stop at epoch 58 (patience=15)
# INFO | LSTM HPO — trial 4/20 finished | val=-0.858039 | best=-0.877451
# INFO | LSTM — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=0.6899 | val={'ROC-AUC': 0.6541176470588235, 'PRC-AUC': 0.4452599294646208}
# INFO | HPO epoch   5/80 | loss=0.6456 | val={'ROC-AUC': 0.7588235294117647, 'PRC-AUC': 0.6393590989013845}
# INFO | HPO epoch  10/80 | loss=0.5538 | val={'ROC-AUC': 0.7390196078431372, 'PRC-AUC': 0.5662544850903096}
# INFO | HPO epoch  15/80 | loss=0.5249 | val={'ROC-AUC': 0.7966666666666667, 'PRC-AUC': 0.6444591523136323}
# INFO | HPO epoch  20/80 | loss=0.4959 | val={'ROC-AUC': 0.8156862745098039, 'PRC-AUC': 0.6347595409596405}
# INFO | HPO epoch  25/80 | loss=0.4948 | val={'ROC-AUC': 0.807843137254902, 'PRC-AUC': 0.6636800615942887}
# INFO | HPO epoch  30/80 | loss=0.4779 | val={'ROC-AUC': 0.8078431372549021, 'PRC-AUC': 0.6524620722939973}
# INFO | HPO epoch  35/80 | loss=0.4607 | val={'ROC-AUC': 0.8184313725490195, 'PRC-AUC': 0.6463027145135644}
# INFO | HPO epoch  40/80 | loss=0.4723 | val={'ROC-AUC': 0.8105882352941176, 'PRC-AUC': 0.6603441720903991}
# INFO | HPO epoch  45/80 | loss=0.4407 | val={'ROC-AUC': 0.8347058823529412, 'PRC-AUC': 0.651348594631666}
# INFO | HPO epoch  50/80 | loss=0.4336 | val={'ROC-AUC': 0.8027450980392157, 'PRC-AUC': 0.632178873648595}
# INFO | HPO epoch  55/80 | loss=0.4181 | val={'ROC-AUC': 0.8137254901960784, 'PRC-AUC': 0.61910892805781}
# INFO | HPO epoch  60/80 | loss=0.4069 | val={'ROC-AUC': 0.8027450980392157, 'PRC-AUC': 0.63082414049236}
# INFO | Early stop at epoch 60 (patience=15)
# INFO | LSTM HPO — trial 5/20 finished | val=-0.834706 | best=-0.877451
# INFO | LSTM — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=0.6945 | val={'ROC-AUC': 0.6574509803921569, 'PRC-AUC': 0.4452387075190673}
# INFO | HPO epoch   5/80 | loss=0.6758 | val={'ROC-AUC': 0.696078431372549, 'PRC-AUC': 0.48740610870328904}
# INFO | HPO epoch  10/80 | loss=0.6070 | val={'ROC-AUC': 0.7866666666666666, 'PRC-AUC': 0.6697853572524204}
# INFO | HPO epoch  15/80 | loss=0.5429 | val={'ROC-AUC': 0.7941176470588235, 'PRC-AUC': 0.6512620637503381}
# INFO | HPO epoch  20/80 | loss=0.4945 | val={'ROC-AUC': 0.8049019607843138, 'PRC-AUC': 0.649621698142887}
# INFO | HPO epoch  25/80 | loss=0.4680 | val={'ROC-AUC': 0.8292156862745097, 'PRC-AUC': 0.6482108487957521}
# INFO | HPO epoch  30/80 | loss=0.4390 | val={'ROC-AUC': 0.8292156862745097, 'PRC-AUC': 0.6436331791910517}
# INFO | HPO epoch  35/80 | loss=0.4179 | val={'ROC-AUC': 0.8505882352941176, 'PRC-AUC': 0.6684064312490039}
# INFO | HPO epoch  40/80 | loss=0.4008 | val={'ROC-AUC': 0.8384313725490196, 'PRC-AUC': 0.6521390585201801}
# INFO | HPO epoch  45/80 | loss=0.3843 | val={'ROC-AUC': 0.8362745098039216, 'PRC-AUC': 0.6557569693533667}
# INFO | HPO epoch  50/80 | loss=0.3769 | val={'ROC-AUC': 0.8401960784313726, 'PRC-AUC': 0.6624168600999487}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | LSTM HPO — trial 6/20 finished | val=-0.850588 | best=-0.877451
# INFO | LSTM — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=0.6905 | val={'ROC-AUC': 0.6529411764705884, 'PRC-AUC': 0.4365483489657936}
# INFO | HPO epoch   5/80 | loss=0.6366 | val={'ROC-AUC': 0.7815686274509803, 'PRC-AUC': 0.6407487813709752}
# INFO | HPO epoch  10/80 | loss=0.5306 | val={'ROC-AUC': 0.78, 'PRC-AUC': 0.6672569414997137}
# INFO | HPO epoch  15/80 | loss=0.4855 | val={'ROC-AUC': 0.7805882352941177, 'PRC-AUC': 0.6674936610341525}
# INFO | HPO epoch  20/80 | loss=0.4904 | val={'ROC-AUC': 0.8252941176470587, 'PRC-AUC': 0.6931489082552399}
# INFO | HPO epoch  25/80 | loss=0.4084 | val={'ROC-AUC': 0.8325490196078431, 'PRC-AUC': 0.6313779803049953}
# INFO | HPO epoch  30/80 | loss=0.3636 | val={'ROC-AUC': 0.8733333333333333, 'PRC-AUC': 0.7734575025902533}
# INFO | HPO epoch  35/80 | loss=0.3337 | val={'ROC-AUC': 0.8341176470588236, 'PRC-AUC': 0.6706126824399659}
# INFO | HPO epoch  40/80 | loss=0.3001 | val={'ROC-AUC': 0.8233333333333334, 'PRC-AUC': 0.620271931325072}
# INFO | HPO epoch  45/80 | loss=0.2441 | val={'ROC-AUC': 0.8194117647058823, 'PRC-AUC': 0.5816505673058181}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | LSTM HPO — trial 7/20 finished | val=-0.873333 | best=-0.877451
# INFO | LSTM — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=0.6922 | val={'ROC-AUC': 0.6519607843137254, 'PRC-AUC': 0.44895006773177903}
# INFO | HPO epoch   5/80 | loss=0.6588 | val={'ROC-AUC': 0.7205882352941176, 'PRC-AUC': 0.6009054379782119}
# INFO | HPO epoch  10/80 | loss=0.6079 | val={'ROC-AUC': 0.7543137254901962, 'PRC-AUC': 0.6186003640196678}
# INFO | HPO epoch  15/80 | loss=0.5702 | val={'ROC-AUC': 0.7558823529411764, 'PRC-AUC': 0.5610863715272415}
# INFO | HPO epoch  20/80 | loss=0.5889 | val={'ROC-AUC': 0.7780392156862744, 'PRC-AUC': 0.607224033386137}
# INFO | HPO epoch  25/80 | loss=0.5472 | val={'ROC-AUC': 0.7711764705882354, 'PRC-AUC': 0.6013063725845482}
# INFO | HPO epoch  30/80 | loss=0.5550 | val={'ROC-AUC': 0.7980392156862745, 'PRC-AUC': 0.6272263780613583}
# INFO | HPO epoch  35/80 | loss=0.5481 | val={'ROC-AUC': 0.7945098039215686, 'PRC-AUC': 0.6215591246889516}
# INFO | HPO epoch  40/80 | loss=0.5188 | val={'ROC-AUC': 0.7935294117647059, 'PRC-AUC': 0.6244133078211532}
# INFO | HPO epoch  45/80 | loss=0.5282 | val={'ROC-AUC': 0.8084313725490196, 'PRC-AUC': 0.6266457165116778}
# INFO | HPO epoch  50/80 | loss=0.4911 | val={'ROC-AUC': 0.8241176470588235, 'PRC-AUC': 0.6851338784722405}
# INFO | HPO epoch  55/80 | loss=0.4964 | val={'ROC-AUC': 0.8158823529411765, 'PRC-AUC': 0.6791828926188419}
# INFO | HPO epoch  60/80 | loss=0.4766 | val={'ROC-AUC': 0.808235294117647, 'PRC-AUC': 0.6788205081612849}
# INFO | HPO epoch  65/80 | loss=0.4650 | val={'ROC-AUC': 0.8194117647058824, 'PRC-AUC': 0.6690515557553246}
# INFO | Early stop at epoch 66 (patience=15)
# INFO | LSTM HPO — trial 8/20 finished | val=-0.826471 | best=-0.877451
# INFO | LSTM — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=0.6929 | val={'ROC-AUC': 0.6141176470588235, 'PRC-AUC': 0.3898466742334758}
# INFO | HPO epoch   5/80 | loss=0.6793 | val={'ROC-AUC': 0.6670588235294117, 'PRC-AUC': 0.44765051145478757}
# INFO | HPO epoch  10/80 | loss=0.6209 | val={'ROC-AUC': 0.7686274509803921, 'PRC-AUC': 0.6577904088662692}
# INFO | HPO epoch  15/80 | loss=0.5545 | val={'ROC-AUC': 0.7919607843137255, 'PRC-AUC': 0.6534936055394782}
# INFO | HPO epoch  20/80 | loss=0.5348 | val={'ROC-AUC': 0.8413725490196078, 'PRC-AUC': 0.7095189590226834}
# INFO | HPO epoch  25/80 | loss=0.5155 | val={'ROC-AUC': 0.8525490196078431, 'PRC-AUC': 0.7349298240115725}
# INFO | HPO epoch  30/80 | loss=0.5097 | val={'ROC-AUC': 0.8472549019607843, 'PRC-AUC': 0.713321217059197}
# INFO | HPO epoch  35/80 | loss=0.4751 | val={'ROC-AUC': 0.8715686274509805, 'PRC-AUC': 0.7587155276472574}
# INFO | HPO epoch  40/80 | loss=0.4711 | val={'ROC-AUC': 0.8496078431372549, 'PRC-AUC': 0.7192800431002245}
# INFO | HPO epoch  45/80 | loss=0.4663 | val={'ROC-AUC': 0.850392156862745, 'PRC-AUC': 0.714225039658245}
# INFO | HPO epoch  50/80 | loss=0.4410 | val={'ROC-AUC': 0.86, 'PRC-AUC': 0.7192460953705387}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | LSTM HPO — trial 9/20 finished | val=-0.871569 | best=-0.877451
# INFO | LSTM — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=0.6901 | val={'ROC-AUC': 0.607843137254902, 'PRC-AUC': 0.39543435787199577}
# INFO | HPO epoch   5/80 | loss=0.6379 | val={'ROC-AUC': 0.7209803921568628, 'PRC-AUC': 0.5738382290575922}
# INFO | HPO epoch  10/80 | loss=0.5669 | val={'ROC-AUC': 0.7498039215686274, 'PRC-AUC': 0.5990842987037603}
# INFO | HPO epoch  15/80 | loss=0.4911 | val={'ROC-AUC': 0.8307843137254901, 'PRC-AUC': 0.6880295307101636}
# INFO | HPO epoch  20/80 | loss=0.4804 | val={'ROC-AUC': 0.8452941176470588, 'PRC-AUC': 0.6825609698675471}
# INFO | HPO epoch  25/80 | loss=0.4483 | val={'ROC-AUC': 0.8323529411764705, 'PRC-AUC': 0.6998191567541843}
# INFO | HPO epoch  30/80 | loss=0.4183 | val={'ROC-AUC': 0.8531372549019608, 'PRC-AUC': 0.6879134146468745}
# INFO | HPO epoch  35/80 | loss=0.3716 | val={'ROC-AUC': 0.8405882352941176, 'PRC-AUC': 0.6689053313393637}
# INFO | Early stop at epoch 37 (patience=15)
# INFO | LSTM HPO — trial 10/20 finished | val=-0.860392 | best=-0.877451
# INFO | LSTM — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=0.6879 | val={'ROC-AUC': 0.6649019607843137, 'PRC-AUC': 0.4432576930919824}
# INFO | HPO epoch   5/80 | loss=0.5754 | val={'ROC-AUC': 0.7915686274509804, 'PRC-AUC': 0.6277389383356522}
# INFO | HPO epoch  10/80 | loss=0.4760 | val={'ROC-AUC': 0.8400000000000001, 'PRC-AUC': 0.6807927172264795}
# INFO | HPO epoch  15/80 | loss=0.4289 | val={'ROC-AUC': 0.846078431372549, 'PRC-AUC': 0.6896536264611242}
# INFO | HPO epoch  20/80 | loss=0.3830 | val={'ROC-AUC': 0.8576470588235293, 'PRC-AUC': 0.7289510096850753}
# INFO | HPO epoch  25/80 | loss=0.3306 | val={'ROC-AUC': 0.8325490196078432, 'PRC-AUC': 0.6684092199988689}
# INFO | Early stop at epoch 29 (patience=15)
# INFO | LSTM HPO — trial 11/20 finished | val=-0.866863 | best=-0.877451
# INFO | LSTM — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=0.6913 | val={'ROC-AUC': 0.6417647058823529, 'PRC-AUC': 0.4225713299513445}
# INFO | HPO epoch   5/80 | loss=0.6344 | val={'ROC-AUC': 0.7507843137254903, 'PRC-AUC': 0.5885753413023347}
# INFO | HPO epoch  10/80 | loss=0.5112 | val={'ROC-AUC': 0.7745098039215687, 'PRC-AUC': 0.5994947385809893}
# INFO | HPO epoch  15/80 | loss=0.4569 | val={'ROC-AUC': 0.7947058823529412, 'PRC-AUC': 0.6258949316176139}
# INFO | HPO epoch  20/80 | loss=0.4113 | val={'ROC-AUC': 0.8223529411764705, 'PRC-AUC': 0.6656711449596964}
# INFO | HPO epoch  25/80 | loss=0.3755 | val={'ROC-AUC': 0.7960784313725491, 'PRC-AUC': 0.646265169502054}
# INFO | HPO epoch  30/80 | loss=0.3462 | val={'ROC-AUC': 0.8505882352941176, 'PRC-AUC': 0.6816831464946453}
# INFO | HPO epoch  35/80 | loss=0.3039 | val={'ROC-AUC': 0.8390196078431372, 'PRC-AUC': 0.6576965765650774}
# INFO | HPO epoch  40/80 | loss=0.2742 | val={'ROC-AUC': 0.857450980392157, 'PRC-AUC': 0.7003617965049947}
# INFO | HPO epoch  45/80 | loss=0.2663 | val={'ROC-AUC': 0.8170588235294117, 'PRC-AUC': 0.6109498914599321}
# INFO | HPO epoch  50/80 | loss=0.2333 | val={'ROC-AUC': 0.8217647058823528, 'PRC-AUC': 0.6477842796002069}
# INFO | HPO epoch  55/80 | loss=0.2326 | val={'ROC-AUC': 0.806078431372549, 'PRC-AUC': 0.6216092274706718}
# INFO | HPO epoch  60/80 | loss=0.1594 | val={'ROC-AUC': 0.816078431372549, 'PRC-AUC': 0.6279079424139659}
# INFO | Early stop at epoch 61 (patience=15)
# INFO | LSTM HPO — trial 12/20 finished | val=-0.863137 | best=-0.877451
# INFO | LSTM — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=0.6889 | val={'ROC-AUC': 0.6584313725490196, 'PRC-AUC': 0.43304675903706646}
# INFO | HPO epoch   5/80 | loss=0.5616 | val={'ROC-AUC': 0.8296078431372549, 'PRC-AUC': 0.7151940109445964}
# INFO | HPO epoch  10/80 | loss=0.4768 | val={'ROC-AUC': 0.8433333333333333, 'PRC-AUC': 0.7204405092722244}
# INFO | HPO epoch  15/80 | loss=0.3966 | val={'ROC-AUC': 0.8745098039215686, 'PRC-AUC': 0.708647801225571}
# INFO | HPO epoch  20/80 | loss=0.3355 | val={'ROC-AUC': 0.8670588235294118, 'PRC-AUC': 0.7426584504909105}
# INFO | HPO epoch  25/80 | loss=0.2853 | val={'ROC-AUC': 0.8803921568627451, 'PRC-AUC': 0.7122758373596131}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | LSTM HPO — trial 13/20 finished | val=-0.891961 | best=-0.891961
# INFO | LSTM — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=0.6909 | val={'ROC-AUC': 0.6649019607843137, 'PRC-AUC': 0.44837244192828923}
# INFO | HPO epoch   5/80 | loss=0.5912 | val={'ROC-AUC': 0.7872549019607843, 'PRC-AUC': 0.6484349717953557}
# INFO | HPO epoch  10/80 | loss=0.4791 | val={'ROC-AUC': 0.8415686274509804, 'PRC-AUC': 0.7381686153901678}
# INFO | HPO epoch  15/80 | loss=0.3753 | val={'ROC-AUC': 0.8747058823529411, 'PRC-AUC': 0.7350914539815927}
# INFO | HPO epoch  20/80 | loss=0.2839 | val={'ROC-AUC': 0.8729411764705883, 'PRC-AUC': 0.7278180389179636}
# INFO | HPO epoch  25/80 | loss=0.2217 | val={'ROC-AUC': 0.8513725490196079, 'PRC-AUC': 0.6905244550897564}
# INFO | Early stop at epoch 27 (patience=15)
# INFO | LSTM HPO — trial 14/20 finished | val=-0.885294 | best=-0.891961
# INFO | LSTM — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=0.6851 | val={'ROC-AUC': 0.6943137254901961, 'PRC-AUC': 0.4911322257229764}
# INFO | HPO epoch   5/80 | loss=0.5614 | val={'ROC-AUC': 0.8039215686274509, 'PRC-AUC': 0.7079591778974879}
# INFO | HPO epoch  10/80 | loss=0.4362 | val={'ROC-AUC': 0.8456862745098039, 'PRC-AUC': 0.6994614889539391}
# INFO | HPO epoch  15/80 | loss=0.3627 | val={'ROC-AUC': 0.8145098039215686, 'PRC-AUC': 0.6209160891154563}
# INFO | HPO epoch  20/80 | loss=0.3250 | val={'ROC-AUC': 0.8286274509803921, 'PRC-AUC': 0.6881233762091461}
# INFO | HPO epoch  25/80 | loss=0.2609 | val={'ROC-AUC': 0.8211764705882353, 'PRC-AUC': 0.6080470027798457}
# INFO | HPO epoch  30/80 | loss=0.2118 | val={'ROC-AUC': 0.846078431372549, 'PRC-AUC': 0.6438076146223738}
# INFO | HPO epoch  35/80 | loss=0.1556 | val={'ROC-AUC': 0.8631372549019607, 'PRC-AUC': 0.6650794315809045}
# INFO | HPO epoch  40/80 | loss=0.1119 | val={'ROC-AUC': 0.844313725490196, 'PRC-AUC': 0.6207333755202654}
# INFO | Early stop at epoch 43 (patience=15)
# INFO | LSTM HPO — trial 15/20 finished | val=-0.869020 | best=-0.891961
# INFO | LSTM — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=0.6905 | val={'ROC-AUC': 0.6705882352941177, 'PRC-AUC': 0.44826318102740836}
# INFO | HPO epoch   5/80 | loss=0.5386 | val={'ROC-AUC': 0.7911764705882353, 'PRC-AUC': 0.6137865398610616}
# INFO | HPO epoch  10/80 | loss=0.4573 | val={'ROC-AUC': 0.8474509803921568, 'PRC-AUC': 0.6794916794823911}
# INFO | HPO epoch  15/80 | loss=0.3770 | val={'ROC-AUC': 0.8674509803921568, 'PRC-AUC': 0.671120981544678}
# INFO | HPO epoch  20/80 | loss=0.3131 | val={'ROC-AUC': 0.8517647058823529, 'PRC-AUC': 0.6725791321874046}
# INFO | HPO epoch  25/80 | loss=0.2588 | val={'ROC-AUC': 0.8125490196078431, 'PRC-AUC': 0.5865978704640493}
# INFO | HPO epoch  30/80 | loss=0.1849 | val={'ROC-AUC': 0.837843137254902, 'PRC-AUC': 0.671079553271445}
# INFO | Early stop at epoch 30 (patience=15)
# INFO | LSTM HPO — trial 16/20 finished | val=-0.867451 | best=-0.891961
# INFO | LSTM — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=0.6937 | val={'ROC-AUC': 0.6558823529411766, 'PRC-AUC': 0.4350107951550699}
# INFO | HPO epoch   5/80 | loss=0.6193 | val={'ROC-AUC': 0.7329411764705883, 'PRC-AUC': 0.5554979484291193}
# INFO | HPO epoch  10/80 | loss=0.5241 | val={'ROC-AUC': 0.781764705882353, 'PRC-AUC': 0.644816395978152}
# INFO | HPO epoch  15/80 | loss=0.4479 | val={'ROC-AUC': 0.837843137254902, 'PRC-AUC': 0.6550579316881033}
# INFO | HPO epoch  20/80 | loss=0.3987 | val={'ROC-AUC': 0.8527450980392157, 'PRC-AUC': 0.6685726443122083}
# INFO | HPO epoch  25/80 | loss=0.3343 | val={'ROC-AUC': 0.8601960784313727, 'PRC-AUC': 0.7193474248647747}
# INFO | HPO epoch  30/80 | loss=0.3043 | val={'ROC-AUC': 0.8501960784313726, 'PRC-AUC': 0.670242477490746}
# INFO | HPO epoch  35/80 | loss=0.2825 | val={'ROC-AUC': 0.8747058823529412, 'PRC-AUC': 0.6908184786478152}
# INFO | HPO epoch  40/80 | loss=0.2377 | val={'ROC-AUC': 0.8352941176470589, 'PRC-AUC': 0.6755258329839502}
# INFO | HPO epoch  45/80 | loss=0.1987 | val={'ROC-AUC': 0.8703921568627451, 'PRC-AUC': 0.7011050905204377}
# INFO | HPO epoch  50/80 | loss=0.1410 | val={'ROC-AUC': 0.8213725490196079, 'PRC-AUC': 0.6405546982324171}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | LSTM HPO — trial 17/20 finished | val=-0.874706 | best=-0.891961
# INFO | LSTM — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=0.6854 | val={'ROC-AUC': 0.7015686274509804, 'PRC-AUC': 0.4924814402466134}
# INFO | HPO epoch   5/80 | loss=0.5424 | val={'ROC-AUC': 0.7909803921568627, 'PRC-AUC': 0.6614287696042003}
# INFO | HPO epoch  10/80 | loss=0.4492 | val={'ROC-AUC': 0.8627450980392157, 'PRC-AUC': 0.7381577779577506}
# INFO | HPO epoch  15/80 | loss=0.4002 | val={'ROC-AUC': 0.8545098039215687, 'PRC-AUC': 0.7474493712318535}
# INFO | HPO epoch  20/80 | loss=0.3403 | val={'ROC-AUC': 0.8823529411764706, 'PRC-AUC': 0.7595356419523248}
# INFO | HPO epoch  25/80 | loss=0.3015 | val={'ROC-AUC': 0.8503921568627452, 'PRC-AUC': 0.7052399939013895}
# INFO | HPO epoch  30/80 | loss=0.2420 | val={'ROC-AUC': 0.8415686274509804, 'PRC-AUC': 0.6629870327403529}
# INFO | HPO epoch  35/80 | loss=0.1634 | val={'ROC-AUC': 0.824313725490196, 'PRC-AUC': 0.6295514568505247}
# INFO | Early stop at epoch 35 (patience=15)
# INFO | LSTM HPO — trial 18/20 finished | val=-0.882353 | best=-0.891961
# INFO | LSTM — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=0.6869 | val={'ROC-AUC': 0.6709803921568627, 'PRC-AUC': 0.4548075744941388}
# INFO | HPO epoch   5/80 | loss=0.5829 | val={'ROC-AUC': 0.8119607843137255, 'PRC-AUC': 0.6576695369355126}
# INFO | HPO epoch  10/80 | loss=0.4616 | val={'ROC-AUC': 0.8307843137254902, 'PRC-AUC': 0.6815690359597225}
# INFO | HPO epoch  15/80 | loss=0.3528 | val={'ROC-AUC': 0.8845098039215686, 'PRC-AUC': 0.7547299526652507}
# INFO | HPO epoch  20/80 | loss=0.3179 | val={'ROC-AUC': 0.8590196078431372, 'PRC-AUC': 0.7524952962268866}
# INFO | HPO epoch  25/80 | loss=0.2258 | val={'ROC-AUC': 0.8519607843137255, 'PRC-AUC': 0.725899186419071}
# INFO | Early stop at epoch 26 (patience=15)
# INFO | LSTM HPO — trial 19/20 finished | val=-0.889020 | best=-0.891961
# INFO | LSTM — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=0.6867 | val={'ROC-AUC': 0.6933333333333332, 'PRC-AUC': 0.5102720096104223}
# INFO | HPO epoch   5/80 | loss=0.5782 | val={'ROC-AUC': 0.795686274509804, 'PRC-AUC': 0.6547437997494244}
# INFO | HPO epoch  10/80 | loss=0.4549 | val={'ROC-AUC': 0.855686274509804, 'PRC-AUC': 0.7396140154482945}
# INFO | HPO epoch  15/80 | loss=0.3541 | val={'ROC-AUC': 0.8654901960784314, 'PRC-AUC': 0.7257242552732317}
# INFO | HPO epoch  20/80 | loss=0.2859 | val={'ROC-AUC': 0.8507843137254902, 'PRC-AUC': 0.6991421972024864}
# INFO | HPO epoch  25/80 | loss=0.2318 | val={'ROC-AUC': 0.8364705882352941, 'PRC-AUC': 0.6588188988547029}
# INFO | HPO epoch  30/80 | loss=0.1350 | val={'ROC-AUC': 0.8274509803921569, 'PRC-AUC': 0.6553177326669332}
# INFO | Early stop at epoch 31 (patience=15)
# INFO | LSTM HPO — trial 20/20 finished | val=-0.869608 | best=-0.891961
# INFO | Epoch  10 | loss=0.4427 | val={'ROC-AUC': 0.8356862745098038, 'PRC-AUC': 0.7055917209693269}
# INFO | Epoch  20 | loss=0.2943 | val={'ROC-AUC': 0.8515686274509804, 'PRC-AUC': 0.721954235195118}
# INFO | Epoch  30 | loss=0.1450 | val={'ROC-AUC': 0.8580392156862745, 'PRC-AUC': 0.6859107590164233}
# INFO | Epoch  40 | loss=0.0829 | val={'ROC-AUC': 0.8501960784313726, 'PRC-AUC': 0.6742619101128646}
# INFO | Epoch  50 | loss=0.0554 | val={'ROC-AUC': 0.8243137254901961, 'PRC-AUC': 0.6581057483999054}
# INFO | Epoch  60 | loss=0.0329 | val={'ROC-AUC': 0.8221568627450981, 'PRC-AUC': 0.6477562099153595}
# INFO | Epoch  70 | loss=0.0261 | val={'ROC-AUC': 0.8174509803921569, 'PRC-AUC': 0.6432804808645585}
# INFO | Epoch  80 | loss=0.0237 | val={'ROC-AUC': 0.8147058823529412, 'PRC-AUC': 0.6500758867989735}
# INFO | Saved SMILES LSTM → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.8254847645429363, 'PRC-AUC': 0.6772287579432564}

# %% [markdown]
# ### Finalize GPU + merge

# %%
finalize_dataset_results(DATASET_SLUG, PARTIAL_PATH, RESULTS_DIR, TASK_TYPE,
    plot_title=f"BACE – ROC-AUC by Model (higher is better) (GPU, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
cpu_partial = RESULTS_ROOT / "cpu" / f"{DATASET_SLUG}_partial.json"
if cpu_partial.exists():
    merge_combined_results(DATASET_SLUG, cpu_partial, PARTIAL_PATH, RESULTS_ROOT / "combined",
        TASK_TYPE, plot_title=f"BACE – ROC-AUC by Model (higher is better) (all models, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
else:
    print("Run CPU notebook first for combined results.")
# Out:
# === BACE Results (5/12 models) ===
#                             ROC-AUC          PRC-AUC
# Model
# GIN (2D)            0.8425 ± 0.0000  0.7856 ± 0.0000
# D-MPNN (2D)         0.8641 ± 0.0000  0.8054 ± 0.0000
# GIN (3D)            0.8331 ± 0.0000  0.7614 ± 0.0000
# SchNet (3D coords)  0.7825 ± 0.0000  0.7171 ± 0.0000
# SMILES LSTM         0.8255 ± 0.0000  0.6772 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/gpu/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/gpu/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/gpu/bace_partial.json
# === BACE Results (12/12 models) ===
#                                ROC-AUC          PRC-AUC
# Model
# Morgan + RF            0.8809 ± 0.0000  0.8215 ± 0.0000
# Morgan + SVM           0.8410 ± 0.0000  0.7466 ± 0.0000
# Morgan + XGBoost       0.8650 ± 0.0000  0.8089 ± 0.0000
# Descriptors + RF       0.8541 ± 0.0000  0.7972 ± 0.0000
# Descriptors + SVM      0.8118 ± 0.0000  0.7546 ± 0.0000
# Descriptors + XGBoost  0.8366 ± 0.0000  0.7904 ± 0.0000
# Combined + XGBoost     0.8460 ± 0.0000  0.8015 ± 0.0000
# GIN (2D)               0.8425 ± 0.0000  0.7856 ± 0.0000
# D-MPNN (2D)            0.8641 ± 0.0000  0.8054 ± 0.0000
# GIN (3D)               0.8331 ± 0.0000  0.7614 ± 0.0000
# SchNet (3D coords)     0.7825 ± 0.0000  0.7171 ± 0.0000
# SMILES LSTM            0.8255 ± 0.0000  0.6772 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/combined/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/combined/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_4/scaffold/combined/bace_partial.json
