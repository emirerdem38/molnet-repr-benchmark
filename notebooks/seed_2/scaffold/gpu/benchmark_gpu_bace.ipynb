# %% [markdown]
# # Benchmark v5 — GPU — BACE — scaffold split, seed 2
#
# **Task:** Binary — binds BACE-1 (1) or not (0)
# **Size:** ~1,513 molecules
# **Metric:** ROC-AUC ↑
#
# **Scaffold split**, seed **2** — GIN, D-MPNN, SchNet, LSTM with Optuna HPO.
#
# Results go to `results/seed_2/scaffold/`.

# %%
# NOTE: autoreload is intentionally NOT enabled. With C-extension packages
# (numpy, torch, torch_geometric) `%autoreload 2` reloads them mid-run and
# corrupts their state (numpy RecursionError / torch_geometric circular
# import). If you edit the benchmark modules, restart the kernel instead.
import os
# Avoid XGBoost/OpenMP segfaults in Jupyter on macOS (OMP Error #179).
for _omp_var in (
    "OMP_NUM_THREADS",
    "OPENBLAS_NUM_THREADS",
    "MKL_NUM_THREADS",
    "VECLIB_MAXIMUM_THREADS",
    "NUMEXPR_NUM_THREADS",
):
    os.environ[_omp_var] = "1"

import sys
from pathlib import Path

ROOT = Path(".").resolve()
for _ in range(6):
    if (ROOT / "mol_repr_utils.py").exists():
        break
    ROOT = ROOT.parent
else:
    raise FileNotFoundError("Could not find benchmark_v5 root (mol_repr_utils.py)")
sys.path.insert(0, str(ROOT))

from mol_repr_utils import *
from split_utils import (
    get_or_create_splits, subset_array, subset_list, subset_graphs_by_valid_idx,
    check_split_proportions,
)
from conformer_generation import load_conformer_graphs
from hpo_utils import (
    hpo_tabular, hpo_gnn, hpo_schnet, hpo_lstm,
    save_hpo_params, hpo_params_path,
)
from hpo_config import SKLEARN_HPO_N_ITER

DATA_DIR = ROOT / "data"

DEVICE = get_device()
print(f"Benchmark v5 (GPU) code root: {ROOT}")
print(f"Device: {DEVICE}")
print("Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.")
# Out:
# INFO | Using device: cpu (request a GPU node on the cluster for large GNN/LSTM jobs)
# Benchmark v5 (GPU) code root: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5
# Device: cpu
# Result paths are set in the next cell from SPLIT_SEED / SPLIT_MODE.

# %%
DATASET_SLUG = "bace"
TASK_TYPE = "classification"
OUT_CHANNELS = 1
BATCH_SIZE = 32
GNN_EPOCHS = 100
LSTM_EPOCHS = 100
TOX21_TABULAR = False

HPO_EPOCHS = 80  # Optuna trial length; GNN_EPOCHS for final refit
HPO_N_TRIALS = 20
print(f"GPU HPO tier: standard — {HPO_N_TRIALS} trials, {HPO_EPOCHS} epochs/trial, batch={BATCH_SIZE}")

SPLIT_MODE = "scaffold"   # "scaffold" or "random"
SPLIT_SEED = 2

RESULTS_ROOT = ROOT / "results" / f"seed_{SPLIT_SEED}" / SPLIT_MODE
RESULTS_DIR = RESULTS_ROOT / "gpu"
SPLITS_DIR = RESULTS_ROOT / "splits"
HPO_DIR = RESULTS_DIR / "hpo"
HISTORY_DIR = RESULTS_DIR / "histories"
for d in (RESULTS_DIR, SPLITS_DIR, HPO_DIR, HISTORY_DIR):
    d.mkdir(parents=True, exist_ok=True)
print(f"Results → {RESULTS_ROOT}")

PARTIAL_PATH = RESULTS_DIR / f"{DATASET_SLUG}_partial.json"
FRESH_RUN = False
HPO_N_ITER = SKLEARN_HPO_N_ITER

if FRESH_RUN:
    reset_dataset_run(
        DATASET_SLUG, RESULTS_DIR,
        results_root=RESULTS_ROOT, split_mode=SPLIT_MODE,
    )
    print("Fresh run — cleared partial results and splits.")

results = load_partial_results(PARTIAL_PATH)
if results:
    print(f"Resuming {len(results)} saved model(s): {', '.join(order_results(results).keys())}")
print(f"SPLIT_SEED={SPLIT_SEED}  mode={SPLIT_MODE}")
# Out:
# GPU HPO tier: standard — 20 trials, 80 epochs/trial, batch=32
# Results → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold
# Resuming 2 saved model(s): GIN (2D), D-MPNN (2D)
# SPLIT_SEED=2  mode=scaffold

# %% [markdown]
# ### Load data

# %%
import numpy as np
import pandas as pd

df = load_dataset("bace", cache_dir=DATA_DIR)
smiles, y = preprocess_dataset(df, "bace")
print(f"Molecules : {len(smiles)}")
print(f"Class balance: {np.bincount(y.astype(int))}")
smiles, y = filter_bonded_molecules(smiles, y)
print(f'After bond filter: {len(smiles)} molecules')
# Out:
# INFO | Loading 'bace' from cache: /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace.csv
# INFO | [bace] 1513 / 1513 valid molecules
# Molecules : 1513
# Class balance: [822 691]
# After bond filter: 1513 molecules

# %% [markdown]
# ### Representations & scaffold split

# %%
graphs2d_all = smiles_to_graphs(smiles, y)
graphs_dmpnn_all = smiles_to_dmpnn_graphs(smiles, y)
X_tok_all, vocab = tokenize_smiles(smiles)

graphs3d_all, valid_idx_3d, _ = load_conformer_graphs(
    DATASET_SLUG, data_dir=DATA_DIR, n_confs=25
)
graphs3d_all = ensure_atomic_numbers_list(graphs3d_all)
print(f"3D graphs loaded: {len(graphs3d_all)} / {len(smiles)} (valid_idx mapping)")

split_data = get_or_create_splits(
    smiles, RESULTS_ROOT, DATASET_SLUG,
    mode=SPLIT_MODE, seed=SPLIT_SEED, force=FRESH_RUN,
)
train_idx = split_data["train_idx"]
val_idx = split_data["val_idx"]
test_idx = split_data["test_idx"]
check_split_proportions(train_idx, val_idx, test_idx, raise_on_fail=True)
print(split_data["summary"])

tr2d = subset_list(graphs2d_all, train_idx)
va2d = subset_list(graphs2d_all, val_idx)
te2d = subset_list(graphs2d_all, test_idx)

tr_dmpnn = subset_list(graphs_dmpnn_all, train_idx)
va_dmpnn = subset_list(graphs_dmpnn_all, val_idx)
te_dmpnn = subset_list(graphs_dmpnn_all, test_idx)

tr3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, train_idx)
va3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, val_idx)
te3d = subset_graphs_by_valid_idx(graphs3d_all, valid_idx_3d, test_idx)

tr_ds = SMILESDataset(subset_array(X_tok_all, train_idx), subset_array(y, train_idx))
va_ds = SMILESDataset(subset_array(X_tok_all, val_idx), subset_array(y, val_idx))
te_ds = SMILESDataset(subset_array(X_tok_all, test_idx), subset_array(y, test_idx))
# Out:
# INFO | Loaded 1513 / 1513 graphs from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/data/bace_conformers_n25.pkl  (n_confs=25)
# INFO | Loaded splits from /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/splits/bace_scaffold_splits.pkl
# 3D graphs loaded: 1513 / 1513 (valid_idx mapping)
# {'n_total': 1513, 'n_train': 1210, 'n_val': 151, 'n_test': 152, 'n_scaffolds_total': 671, 'n_scaffolds_train': 368, 'n_scaffolds_val': 151, 'n_scaffolds_test': 152}

# %% [markdown]
# ### GIN (2D)

# %%
MODEL_KEY = "GIN (2D)"
tr = tr3d if "2D" == "3D" else tr2d
va = va3d if "2D" == "3D" else va2d
te = te3d if "2D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (2D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# Skipping GIN (2D)

# %% [markdown]
# ### D-MPNN (2D)
# Bond-centric directed MPNN (Yang et al. 2019).

# %%
MODEL_KEY = "D-MPNN (2D)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr_dmpnn, va_dmpnn, TASK_TYPE, "DMPNN", "2D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("DMPNN", "2D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr_dmpnn, va_dmpnn, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te_dmpnn, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_dmpnn.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# Skipping D-MPNN (2D)

# %% [markdown]
# ### GIN (3D)

# %%
MODEL_KEY = "GIN (3D)"
tr = tr3d if "3D" == "3D" else tr2d
va = va3d if "3D" == "3D" else va2d
te = te3d if "3D" == "3D" else te2d
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_gnn(
        tr, va, TASK_TYPE, "GIN", "3D", OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_gnn, PyGLoader, build_gnn, train_gnn
    model = build_gnn("GIN", "3D", OUT_CHANNELS,
                      hidden=best["hidden"], num_layers=best["num_layers"], dropout=best["dropout"])
    train_gnn(model, tr, va, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
              batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_gnn(model, PyGLoader(te, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    hist_name = "GIN (3D)".replace(" ", "_").replace("(", "").replace(")", "")
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_{hist_name}.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | GIN 3D — starting trial 1/20 (layers=3, hidden=256)
# → GIN (3D) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.8841 | val={'ROC-AUC': 0.578219696969697, 'PRC-AUC': 0.4437555959834962}
# INFO | HPO epoch   5/80 | loss=0.5024 | val={'ROC-AUC': 0.7393939393939394, 'PRC-AUC': 0.631508882155091}
# INFO | HPO epoch  10/80 | loss=0.4443 | val={'ROC-AUC': 0.7837121212121213, 'PRC-AUC': 0.6328738553455421}
# INFO | HPO epoch  15/80 | loss=0.4497 | val={'ROC-AUC': 0.7954545454545455, 'PRC-AUC': 0.6606229179250451}
# INFO | HPO epoch  20/80 | loss=0.3890 | val={'ROC-AUC': 0.7861742424242424, 'PRC-AUC': 0.6545042356560573}
# INFO | HPO epoch  25/80 | loss=0.3624 | val={'ROC-AUC': 0.781439393939394, 'PRC-AUC': 0.6904418082938596}
# INFO | HPO epoch  30/80 | loss=0.3554 | val={'ROC-AUC': 0.8111742424242424, 'PRC-AUC': 0.7007821446078407}
# INFO | HPO epoch  35/80 | loss=0.3447 | val={'ROC-AUC': 0.8331439393939395, 'PRC-AUC': 0.7218238436580631}
# INFO | HPO epoch  40/80 | loss=0.3282 | val={'ROC-AUC': 0.8045454545454545, 'PRC-AUC': 0.6769457289008127}
# INFO | HPO epoch  45/80 | loss=0.3023 | val={'ROC-AUC': 0.8028409090909091, 'PRC-AUC': 0.7013054975552249}
# INFO | HPO epoch  50/80 | loss=0.2742 | val={'ROC-AUC': 0.8215909090909091, 'PRC-AUC': 0.7056224678502354}
# INFO | HPO epoch  55/80 | loss=0.2890 | val={'ROC-AUC': 0.7704545454545454, 'PRC-AUC': 0.6701716892728867}
# INFO | HPO epoch  60/80 | loss=0.2545 | val={'ROC-AUC': 0.8261363636363637, 'PRC-AUC': 0.7295269723505011}
# INFO | Early stop at epoch 62 (patience=15)
# INFO | GIN 3D HPO — trial 1/20 finished | val=-0.857576 | best=-0.857576
# INFO | GIN 3D — starting trial 2/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.6844 | val={'ROC-AUC': 0.5920454545454545, 'PRC-AUC': 0.4299908874146171}
# INFO | HPO epoch   5/80 | loss=0.5038 | val={'ROC-AUC': 0.7607954545454545, 'PRC-AUC': 0.6258636933222618}
# INFO | HPO epoch  10/80 | loss=0.4423 | val={'ROC-AUC': 0.8066287878787879, 'PRC-AUC': 0.6654091161737454}
# INFO | HPO epoch  15/80 | loss=0.4343 | val={'ROC-AUC': 0.8172348484848484, 'PRC-AUC': 0.6968006708885692}
# INFO | HPO epoch  20/80 | loss=0.3885 | val={'ROC-AUC': 0.8134469696969697, 'PRC-AUC': 0.6751286230860896}
# INFO | HPO epoch  25/80 | loss=0.3870 | val={'ROC-AUC': 0.8136363636363636, 'PRC-AUC': 0.7133399739824053}
# INFO | HPO epoch  30/80 | loss=0.3704 | val={'ROC-AUC': 0.8303030303030303, 'PRC-AUC': 0.6604342812924906}
# INFO | HPO epoch  35/80 | loss=0.3574 | val={'ROC-AUC': 0.8452651515151515, 'PRC-AUC': 0.7480348536951447}
# INFO | HPO epoch  40/80 | loss=0.3363 | val={'ROC-AUC': 0.8558712121212121, 'PRC-AUC': 0.762400581625412}
# INFO | HPO epoch  45/80 | loss=0.3233 | val={'ROC-AUC': 0.8541666666666666, 'PRC-AUC': 0.7274952520258565}
# INFO | HPO epoch  50/80 | loss=0.3113 | val={'ROC-AUC': 0.8520833333333333, 'PRC-AUC': 0.7614141170223739}
# INFO | HPO epoch  55/80 | loss=0.2948 | val={'ROC-AUC': 0.8505681818181818, 'PRC-AUC': 0.7744605383189334}
# INFO | Early stop at epoch 57 (patience=15)
# INFO | GIN 3D HPO — trial 2/20 finished | val=-0.869129 | best=-0.869129
# INFO | GIN 3D — starting trial 3/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7757 | val={'ROC-AUC': 0.6083333333333333, 'PRC-AUC': 0.45133731469445504}
# INFO | HPO epoch   5/80 | loss=0.5711 | val={'ROC-AUC': 0.6958333333333333, 'PRC-AUC': 0.5283498821664776}
# INFO | HPO epoch  10/80 | loss=0.5016 | val={'ROC-AUC': 0.7613636363636364, 'PRC-AUC': 0.6600269991930328}
# INFO | HPO epoch  15/80 | loss=0.4554 | val={'ROC-AUC': 0.7816287878787879, 'PRC-AUC': 0.6510924340565303}
# INFO | HPO epoch  20/80 | loss=0.4404 | val={'ROC-AUC': 0.7954545454545454, 'PRC-AUC': 0.686399955438107}
# INFO | HPO epoch  25/80 | loss=0.4304 | val={'ROC-AUC': 0.7674242424242425, 'PRC-AUC': 0.6416680106007697}
# INFO | HPO epoch  30/80 | loss=0.4164 | val={'ROC-AUC': 0.8090909090909091, 'PRC-AUC': 0.693417094586725}
# INFO | HPO epoch  35/80 | loss=0.3879 | val={'ROC-AUC': 0.7971590909090909, 'PRC-AUC': 0.6647334275082624}
# INFO | HPO epoch  40/80 | loss=0.3802 | val={'ROC-AUC': 0.8244318181818181, 'PRC-AUC': 0.7350432793220005}
# INFO | Early stop at epoch 42 (patience=15)
# INFO | GIN 3D HPO — trial 3/20 finished | val=-0.836174 | best=-0.869129
# INFO | GIN 3D — starting trial 4/20 (layers=5, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.8468 | val={'ROC-AUC': 0.6577651515151516, 'PRC-AUC': 0.48393127843369355}
# INFO | HPO epoch   5/80 | loss=0.5219 | val={'ROC-AUC': 0.7160984848484848, 'PRC-AUC': 0.6107108336390564}
# INFO | HPO epoch  10/80 | loss=0.4424 | val={'ROC-AUC': 0.8399621212121211, 'PRC-AUC': 0.7268261324043819}
# INFO | HPO epoch  15/80 | loss=0.4114 | val={'ROC-AUC': 0.727651515151515, 'PRC-AUC': 0.6688495926909642}
# INFO | HPO epoch  20/80 | loss=0.4004 | val={'ROC-AUC': 0.7503787878787879, 'PRC-AUC': 0.6764478219354522}
# INFO | HPO epoch  25/80 | loss=0.3530 | val={'ROC-AUC': 0.7742424242424242, 'PRC-AUC': 0.6447708065780677}
# INFO | Early stop at epoch 29 (patience=15)
# INFO | GIN 3D HPO — trial 4/20 finished | val=-0.857955 | best=-0.869129
# INFO | GIN 3D — starting trial 5/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.6656 | val={'ROC-AUC': 0.7030303030303031, 'PRC-AUC': 0.535194303930038}
# INFO | HPO epoch   5/80 | loss=0.5235 | val={'ROC-AUC': 0.7151515151515152, 'PRC-AUC': 0.5768167160824706}
# INFO | HPO epoch  10/80 | loss=0.4271 | val={'ROC-AUC': 0.7931818181818182, 'PRC-AUC': 0.6988875179831213}
# INFO | HPO epoch  15/80 | loss=0.4473 | val={'ROC-AUC': 0.8268939393939394, 'PRC-AUC': 0.7029028247210115}
# INFO | HPO epoch  20/80 | loss=0.3547 | val={'ROC-AUC': 0.8549242424242424, 'PRC-AUC': 0.7473062251194886}
# INFO | HPO epoch  25/80 | loss=0.3217 | val={'ROC-AUC': 0.8325757575757575, 'PRC-AUC': 0.747874916261348}
# INFO | HPO epoch  30/80 | loss=0.2976 | val={'ROC-AUC': 0.852840909090909, 'PRC-AUC': 0.7756615576849127}
# INFO | HPO epoch  35/80 | loss=0.2666 | val={'ROC-AUC': 0.8344696969696971, 'PRC-AUC': 0.75182056538417}
# INFO | HPO epoch  40/80 | loss=0.2627 | val={'ROC-AUC': 0.8303030303030303, 'PRC-AUC': 0.7737012168632958}
# INFO | HPO epoch  45/80 | loss=0.2369 | val={'ROC-AUC': 0.8395833333333333, 'PRC-AUC': 0.752871463547088}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | GIN 3D HPO — trial 5/20 finished | val=-0.860985 | best=-0.869129
# INFO | GIN 3D — starting trial 6/20 (layers=4, hidden=256)
# INFO | HPO epoch   1/80 | loss=1.7927 | val={'ROC-AUC': 0.5859848484848486, 'PRC-AUC': 0.4356666411019124}
# INFO | HPO epoch   5/80 | loss=0.6174 | val={'ROC-AUC': 0.5193181818181818, 'PRC-AUC': 0.43852442141609216}
# INFO | HPO epoch  10/80 | loss=0.5467 | val={'ROC-AUC': 0.61875, 'PRC-AUC': 0.5366209794015779}
# INFO | HPO epoch  15/80 | loss=0.4867 | val={'ROC-AUC': 0.6928030303030303, 'PRC-AUC': 0.5501798105538358}
# INFO | HPO epoch  20/80 | loss=0.4825 | val={'ROC-AUC': 0.7518939393939393, 'PRC-AUC': 0.6106497843431609}
# INFO | HPO epoch  25/80 | loss=0.4652 | val={'ROC-AUC': 0.6606060606060605, 'PRC-AUC': 0.5514372313053828}
# INFO | HPO epoch  30/80 | loss=0.4508 | val={'ROC-AUC': 0.7530303030303029, 'PRC-AUC': 0.6305644659038452}
# INFO | HPO epoch  35/80 | loss=0.4186 | val={'ROC-AUC': 0.7861742424242424, 'PRC-AUC': 0.708053625063753}
# INFO | HPO epoch  40/80 | loss=0.4279 | val={'ROC-AUC': 0.8083333333333332, 'PRC-AUC': 0.6886676121844507}
# INFO | HPO epoch  45/80 | loss=0.4181 | val={'ROC-AUC': 0.809280303030303, 'PRC-AUC': 0.7133413519583287}
# INFO | HPO epoch  50/80 | loss=0.4080 | val={'ROC-AUC': 0.7704545454545455, 'PRC-AUC': 0.6745539230732356}
# INFO | HPO epoch  55/80 | loss=0.3577 | val={'ROC-AUC': 0.8140151515151516, 'PRC-AUC': 0.7245270188208158}
# INFO | HPO epoch  60/80 | loss=0.3594 | val={'ROC-AUC': 0.7835227272727272, 'PRC-AUC': 0.6687010956525574}
# INFO | HPO epoch  65/80 | loss=0.3434 | val={'ROC-AUC': 0.8142045454545455, 'PRC-AUC': 0.7039253984419048}
# INFO | HPO epoch  70/80 | loss=0.3040 | val={'ROC-AUC': 0.8214015151515152, 'PRC-AUC': 0.7281876319920842}
# INFO | Early stop at epoch 71 (patience=15)
# INFO | GIN 3D HPO — trial 6/20 finished | val=-0.844129 | best=-0.869129
# INFO | GIN 3D — starting trial 7/20 (layers=3, hidden=192)
# INFO | HPO epoch   1/80 | loss=1.0189 | val={'ROC-AUC': 0.637310606060606, 'PRC-AUC': 0.5255895282756641}
# INFO | HPO epoch   5/80 | loss=0.4895 | val={'ROC-AUC': 0.612310606060606, 'PRC-AUC': 0.5214238958687691}
# INFO | HPO epoch  10/80 | loss=0.4708 | val={'ROC-AUC': 0.6331439393939393, 'PRC-AUC': 0.519000768906988}
# INFO | HPO epoch  15/80 | loss=0.4357 | val={'ROC-AUC': 0.7035984848484849, 'PRC-AUC': 0.6168133722947611}
# INFO | HPO epoch  20/80 | loss=0.4199 | val={'ROC-AUC': 0.7375, 'PRC-AUC': 0.5989599849380953}
# INFO | HPO epoch  25/80 | loss=0.3920 | val={'ROC-AUC': 0.7439393939393939, 'PRC-AUC': 0.6172800407403743}
# INFO | HPO epoch  30/80 | loss=0.3648 | val={'ROC-AUC': 0.7774621212121212, 'PRC-AUC': 0.637738803051541}
# INFO | HPO epoch  35/80 | loss=0.3677 | val={'ROC-AUC': 0.7958333333333333, 'PRC-AUC': 0.7188534301223378}
# INFO | HPO epoch  40/80 | loss=0.2935 | val={'ROC-AUC': 0.806060606060606, 'PRC-AUC': 0.7057424068119332}
# INFO | Early stop at epoch 41 (patience=15)
# INFO | GIN 3D HPO — trial 7/20 finished | val=-0.834470 | best=-0.869129
# INFO | GIN 3D — starting trial 8/20 (layers=3, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.7216 | val={'ROC-AUC': 0.6200757575757575, 'PRC-AUC': 0.4840470641028527}
# INFO | HPO epoch   5/80 | loss=0.4906 | val={'ROC-AUC': 0.7725378787878787, 'PRC-AUC': 0.6132001882863731}
# INFO | HPO epoch  10/80 | loss=0.4260 | val={'ROC-AUC': 0.774810606060606, 'PRC-AUC': 0.6028906631057854}
# INFO | HPO epoch  15/80 | loss=0.4375 | val={'ROC-AUC': 0.818939393939394, 'PRC-AUC': 0.6889024842581808}
# INFO | HPO epoch  20/80 | loss=0.4652 | val={'ROC-AUC': 0.803219696969697, 'PRC-AUC': 0.6751637483226598}
# INFO | HPO epoch  25/80 | loss=0.3768 | val={'ROC-AUC': 0.8009469696969698, 'PRC-AUC': 0.6864048652985539}
# INFO | HPO epoch  30/80 | loss=0.3196 | val={'ROC-AUC': 0.8087121212121211, 'PRC-AUC': 0.7084062439766363}
# INFO | HPO epoch  35/80 | loss=0.3336 | val={'ROC-AUC': 0.8051136363636362, 'PRC-AUC': 0.7240127874565705}
# INFO | HPO epoch  40/80 | loss=0.2966 | val={'ROC-AUC': 0.828030303030303, 'PRC-AUC': 0.7091672724915261}
# INFO | HPO epoch  45/80 | loss=0.2998 | val={'ROC-AUC': 0.8125, 'PRC-AUC': 0.6940835618611263}
# INFO | HPO epoch  50/80 | loss=0.2992 | val={'ROC-AUC': 0.8255681818181818, 'PRC-AUC': 0.7168893770194716}
# INFO | HPO epoch  55/80 | loss=0.2664 | val={'ROC-AUC': 0.812689393939394, 'PRC-AUC': 0.6841343066576234}
# INFO | Early stop at epoch 57 (patience=15)
# INFO | GIN 3D HPO — trial 8/20 finished | val=-0.836932 | best=-0.869129
# INFO | GIN 3D — starting trial 9/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.1770 | val={'ROC-AUC': 0.5649621212121212, 'PRC-AUC': 0.43439481492365767}
# INFO | HPO epoch   5/80 | loss=0.6371 | val={'ROC-AUC': 0.6263257575757576, 'PRC-AUC': 0.5103786345515673}
# INFO | HPO epoch  10/80 | loss=0.5929 | val={'ROC-AUC': 0.6630681818181817, 'PRC-AUC': 0.5407597195940792}
# INFO | HPO epoch  15/80 | loss=0.5526 | val={'ROC-AUC': 0.6776515151515151, 'PRC-AUC': 0.5248252964785066}
# INFO | HPO epoch  20/80 | loss=0.5146 | val={'ROC-AUC': 0.719128787878788, 'PRC-AUC': 0.5539501500772533}
# INFO | HPO epoch  25/80 | loss=0.4763 | val={'ROC-AUC': 0.7117424242424243, 'PRC-AUC': 0.5589123279192969}
# INFO | HPO epoch  30/80 | loss=0.4741 | val={'ROC-AUC': 0.7464015151515152, 'PRC-AUC': 0.6189232809970471}
# INFO | HPO epoch  35/80 | loss=0.4742 | val={'ROC-AUC': 0.7609848484848485, 'PRC-AUC': 0.6122046820658621}
# INFO | HPO epoch  40/80 | loss=0.4543 | val={'ROC-AUC': 0.7859848484848485, 'PRC-AUC': 0.6484329105462462}
# INFO | HPO epoch  45/80 | loss=0.4363 | val={'ROC-AUC': 0.7840909090909092, 'PRC-AUC': 0.6467033468773069}
# INFO | HPO epoch  50/80 | loss=0.4065 | val={'ROC-AUC': 0.7640151515151515, 'PRC-AUC': 0.6477909560272203}
# INFO | HPO epoch  55/80 | loss=0.4045 | val={'ROC-AUC': 0.7888257575757576, 'PRC-AUC': 0.6536660964465687}
# INFO | HPO epoch  60/80 | loss=0.3972 | val={'ROC-AUC': 0.7984848484848485, 'PRC-AUC': 0.6558187230239333}
# INFO | HPO epoch  65/80 | loss=0.4021 | val={'ROC-AUC': 0.790340909090909, 'PRC-AUC': 0.6520236981658588}
# INFO | HPO epoch  70/80 | loss=0.3684 | val={'ROC-AUC': 0.7933712121212121, 'PRC-AUC': 0.6754361331104338}
# INFO | HPO epoch  75/80 | loss=0.3509 | val={'ROC-AUC': 0.7918560606060606, 'PRC-AUC': 0.6680547895798219}
# INFO | Early stop at epoch 75 (patience=15)
# INFO | GIN 3D HPO — trial 9/20 finished | val=-0.798485 | best=-0.869129
# INFO | GIN 3D — starting trial 10/20 (layers=5, hidden=256)
# INFO | HPO epoch   1/80 | loss=0.7735 | val={'ROC-AUC': 0.5943181818181819, 'PRC-AUC': 0.43282851192915767}
# INFO | HPO epoch   5/80 | loss=0.5769 | val={'ROC-AUC': 0.6611742424242425, 'PRC-AUC': 0.5218453861207032}
# INFO | HPO epoch  10/80 | loss=0.5245 | val={'ROC-AUC': 0.6931818181818182, 'PRC-AUC': 0.5649643318032527}
# INFO | HPO epoch  15/80 | loss=0.5050 | val={'ROC-AUC': 0.790719696969697, 'PRC-AUC': 0.6581139559507374}
# INFO | HPO epoch  20/80 | loss=0.4549 | val={'ROC-AUC': 0.7920454545454545, 'PRC-AUC': 0.6885306623722046}
# INFO | HPO epoch  25/80 | loss=0.4251 | val={'ROC-AUC': 0.7962121212121211, 'PRC-AUC': 0.6600787545192236}
# INFO | HPO epoch  30/80 | loss=0.4311 | val={'ROC-AUC': 0.8022727272727272, 'PRC-AUC': 0.6665475117301026}
# INFO | HPO epoch  35/80 | loss=0.4083 | val={'ROC-AUC': 0.8318181818181817, 'PRC-AUC': 0.7198014508316509}
# INFO | HPO epoch  40/80 | loss=0.4103 | val={'ROC-AUC': 0.7943181818181818, 'PRC-AUC': 0.6743486706876591}
# INFO | HPO epoch  45/80 | loss=0.3519 | val={'ROC-AUC': 0.8361742424242424, 'PRC-AUC': 0.7149777158016795}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | GIN 3D HPO — trial 10/20 finished | val=-0.838636 | best=-0.869129
# INFO | GIN 3D — starting trial 11/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.8166 | val={'ROC-AUC': 0.6147727272727272, 'PRC-AUC': 0.489654465535312}
# INFO | HPO epoch   5/80 | loss=0.5267 | val={'ROC-AUC': 0.7363636363636363, 'PRC-AUC': 0.6100957338742123}
# INFO | HPO epoch  10/80 | loss=0.4558 | val={'ROC-AUC': 0.687310606060606, 'PRC-AUC': 0.5923716431187425}
# INFO | HPO epoch  15/80 | loss=0.4356 | val={'ROC-AUC': 0.7359848484848485, 'PRC-AUC': 0.6017126795410471}
# INFO | HPO epoch  20/80 | loss=0.4286 | val={'ROC-AUC': 0.7412878787878787, 'PRC-AUC': 0.6119054364177655}
# INFO | HPO epoch  25/80 | loss=0.4088 | val={'ROC-AUC': 0.7664772727272728, 'PRC-AUC': 0.6681695382075807}
# INFO | HPO epoch  30/80 | loss=0.3432 | val={'ROC-AUC': 0.8178030303030303, 'PRC-AUC': 0.6698190693512868}
# INFO | Early stop at epoch 31 (patience=15)
# INFO | GIN 3D HPO — trial 11/20 finished | val=-0.825379 | best=-0.869129
# INFO | GIN 3D — starting trial 12/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=1.5145 | val={'ROC-AUC': 0.6147727272727272, 'PRC-AUC': 0.5019558865293431}
# INFO | HPO epoch   5/80 | loss=0.5747 | val={'ROC-AUC': 0.6570075757575758, 'PRC-AUC': 0.5588914051186582}
# INFO | HPO epoch  10/80 | loss=0.5239 | val={'ROC-AUC': 0.709469696969697, 'PRC-AUC': 0.588854427336519}
# INFO | HPO epoch  15/80 | loss=0.4944 | val={'ROC-AUC': 0.7698863636363635, 'PRC-AUC': 0.6501114910760497}
# INFO | HPO epoch  20/80 | loss=0.4804 | val={'ROC-AUC': 0.6285984848484849, 'PRC-AUC': 0.5672607558758825}
# INFO | HPO epoch  25/80 | loss=0.4661 | val={'ROC-AUC': 0.7456439393939394, 'PRC-AUC': 0.608536689619217}
# INFO | HPO epoch  30/80 | loss=0.4176 | val={'ROC-AUC': 0.7952651515151515, 'PRC-AUC': 0.6926518132221784}
# INFO | HPO epoch  35/80 | loss=0.4267 | val={'ROC-AUC': 0.7808712121212121, 'PRC-AUC': 0.7005585816671526}
# INFO | HPO epoch  40/80 | loss=0.4064 | val={'ROC-AUC': 0.7869318181818182, 'PRC-AUC': 0.7173572765518381}
# INFO | HPO epoch  45/80 | loss=0.4042 | val={'ROC-AUC': 0.7410984848484848, 'PRC-AUC': 0.6293890339989798}
# INFO | HPO epoch  50/80 | loss=0.3809 | val={'ROC-AUC': 0.8276515151515151, 'PRC-AUC': 0.7194041457968593}
# INFO | HPO epoch  55/80 | loss=0.3784 | val={'ROC-AUC': 0.7865530303030303, 'PRC-AUC': 0.6665862466845113}
# INFO | HPO epoch  60/80 | loss=0.3433 | val={'ROC-AUC': 0.8145833333333333, 'PRC-AUC': 0.7277309477122138}
# INFO | Early stop at epoch 61 (patience=15)
# INFO | GIN 3D HPO — trial 12/20 finished | val=-0.832576 | best=-0.869129
# INFO | GIN 3D — starting trial 13/20 (layers=4, hidden=192)
# INFO | HPO epoch   1/80 | loss=0.8199 | val={'ROC-AUC': 0.6354166666666666, 'PRC-AUC': 0.45735353442212756}
# INFO | HPO epoch   5/80 | loss=0.4802 | val={'ROC-AUC': 0.7852272727272727, 'PRC-AUC': 0.6442126734266773}
# INFO | HPO epoch  10/80 | loss=0.4289 | val={'ROC-AUC': 0.8246212121212121, 'PRC-AUC': 0.6946681139080688}
# INFO | HPO epoch  15/80 | loss=0.4267 | val={'ROC-AUC': 0.7899621212121212, 'PRC-AUC': 0.6998082644413015}
# INFO | HPO epoch  20/80 | loss=0.3749 | val={'ROC-AUC': 0.8337121212121212, 'PRC-AUC': 0.7343121839947768}
# INFO | HPO epoch  25/80 | loss=0.3812 | val={'ROC-AUC': 0.8431818181818181, 'PRC-AUC': 0.7324876778165341}
# INFO | HPO epoch  30/80 | loss=0.3227 | val={'ROC-AUC': 0.8443181818181817, 'PRC-AUC': 0.7521128987582226}
# INFO | Early stop at epoch 31 (patience=15)
# INFO | GIN 3D HPO — trial 13/20 finished | val=-0.850379 | best=-0.869129
# INFO | GIN 3D — starting trial 14/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7261 | val={'ROC-AUC': 0.6037878787878788, 'PRC-AUC': 0.4453896088294727}
# INFO | HPO epoch   5/80 | loss=0.5035 | val={'ROC-AUC': 0.7831439393939393, 'PRC-AUC': 0.6539897414539181}
# INFO | HPO epoch  10/80 | loss=0.4522 | val={'ROC-AUC': 0.8456439393939393, 'PRC-AUC': 0.7281266861096398}
# INFO | HPO epoch  15/80 | loss=0.4133 | val={'ROC-AUC': 0.8299242424242423, 'PRC-AUC': 0.7417184616899073}
# INFO | HPO epoch  20/80 | loss=0.4054 | val={'ROC-AUC': 0.7467803030303031, 'PRC-AUC': 0.6348365429599016}
# INFO | HPO epoch  25/80 | loss=0.3620 | val={'ROC-AUC': 0.8210227272727273, 'PRC-AUC': 0.7643833515990585}
# INFO | HPO epoch  30/80 | loss=0.3426 | val={'ROC-AUC': 0.8079545454545455, 'PRC-AUC': 0.700661303739427}
# INFO | HPO epoch  35/80 | loss=0.2886 | val={'ROC-AUC': 0.8501893939393939, 'PRC-AUC': 0.7610555319615803}
# INFO | HPO epoch  40/80 | loss=0.3005 | val={'ROC-AUC': 0.849810606060606, 'PRC-AUC': 0.7550001437264297}
# INFO | HPO epoch  45/80 | loss=0.2759 | val={'ROC-AUC': 0.8462121212121213, 'PRC-AUC': 0.785662150866637}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | GIN 3D HPO — trial 14/20 finished | val=-0.861174 | best=-0.869129
# INFO | GIN 3D — starting trial 15/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7403 | val={'ROC-AUC': 0.6020833333333333, 'PRC-AUC': 0.46467447680429874}
# INFO | HPO epoch   5/80 | loss=0.4987 | val={'ROC-AUC': 0.7568181818181818, 'PRC-AUC': 0.6359467729643401}
# INFO | HPO epoch  10/80 | loss=0.4869 | val={'ROC-AUC': 0.8015151515151515, 'PRC-AUC': 0.6672365691890049}
# INFO | HPO epoch  15/80 | loss=0.4090 | val={'ROC-AUC': 0.7738636363636363, 'PRC-AUC': 0.6399192186279781}
# INFO | HPO epoch  20/80 | loss=0.4061 | val={'ROC-AUC': 0.7859848484848484, 'PRC-AUC': 0.697385191181753}
# INFO | HPO epoch  25/80 | loss=0.3376 | val={'ROC-AUC': 0.7808712121212121, 'PRC-AUC': 0.6581154746540445}
# INFO | HPO epoch  30/80 | loss=0.3519 | val={'ROC-AUC': 0.7954545454545454, 'PRC-AUC': 0.6796884841371799}
# INFO | HPO epoch  35/80 | loss=0.3192 | val={'ROC-AUC': 0.8149621212121212, 'PRC-AUC': 0.7446011290330561}
# INFO | HPO epoch  40/80 | loss=0.3195 | val={'ROC-AUC': 0.7960227272727274, 'PRC-AUC': 0.7278626440124469}
# INFO | Early stop at epoch 44 (patience=15)
# INFO | GIN 3D HPO — trial 15/20 finished | val=-0.842424 | best=-0.869129
# INFO | GIN 3D — starting trial 16/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7609 | val={'ROC-AUC': 0.5740530303030302, 'PRC-AUC': 0.44348903719819466}
# INFO | HPO epoch   5/80 | loss=0.5153 | val={'ROC-AUC': 0.7700757575757576, 'PRC-AUC': 0.6176024954729811}
# INFO | HPO epoch  10/80 | loss=0.4533 | val={'ROC-AUC': 0.7827651515151516, 'PRC-AUC': 0.6357955630881928}
# INFO | HPO epoch  15/80 | loss=0.4300 | val={'ROC-AUC': 0.8056818181818183, 'PRC-AUC': 0.6546335274020385}
# INFO | HPO epoch  20/80 | loss=0.4078 | val={'ROC-AUC': 0.8149621212121212, 'PRC-AUC': 0.7344416574599687}
# INFO | HPO epoch  25/80 | loss=0.3670 | val={'ROC-AUC': 0.8378787878787878, 'PRC-AUC': 0.7042656920916404}
# INFO | HPO epoch  30/80 | loss=0.3780 | val={'ROC-AUC': 0.8227272727272728, 'PRC-AUC': 0.6923046725676132}
# INFO | HPO epoch  35/80 | loss=0.3613 | val={'ROC-AUC': 0.8314393939393939, 'PRC-AUC': 0.7016795787094038}
# INFO | HPO epoch  40/80 | loss=0.3390 | val={'ROC-AUC': 0.8435606060606061, 'PRC-AUC': 0.7814814218279025}
# INFO | HPO epoch  45/80 | loss=0.3034 | val={'ROC-AUC': 0.8390151515151515, 'PRC-AUC': 0.7258405874020643}
# INFO | Early stop at epoch 47 (patience=15)
# INFO | GIN 3D HPO — trial 16/20 finished | val=-0.848864 | best=-0.869129
# INFO | GIN 3D — starting trial 17/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=1.1429 | val={'ROC-AUC': 0.5725378787878788, 'PRC-AUC': 0.47700024053745893}
# INFO | HPO epoch   5/80 | loss=0.5725 | val={'ROC-AUC': 0.5596590909090908, 'PRC-AUC': 0.4638193599389181}
# INFO | HPO epoch  10/80 | loss=0.5013 | val={'ROC-AUC': 0.6791666666666667, 'PRC-AUC': 0.5434815324229736}
# INFO | HPO epoch  15/80 | loss=0.4856 | val={'ROC-AUC': 0.6505681818181819, 'PRC-AUC': 0.5144220638661613}
# INFO | HPO epoch  20/80 | loss=0.4516 | val={'ROC-AUC': 0.7967803030303031, 'PRC-AUC': 0.6883531506946872}
# INFO | HPO epoch  25/80 | loss=0.4305 | val={'ROC-AUC': 0.7424242424242424, 'PRC-AUC': 0.6270922976364428}
# INFO | HPO epoch  30/80 | loss=0.4242 | val={'ROC-AUC': 0.7725378787878787, 'PRC-AUC': 0.6781518187405788}
# INFO | HPO epoch  35/80 | loss=0.3848 | val={'ROC-AUC': 0.784280303030303, 'PRC-AUC': 0.6621316603531315}
# INFO | HPO epoch  40/80 | loss=0.3501 | val={'ROC-AUC': 0.8018939393939394, 'PRC-AUC': 0.6742453806527714}
# INFO | HPO epoch  45/80 | loss=0.3467 | val={'ROC-AUC': 0.8409090909090909, 'PRC-AUC': 0.7402248608065267}
# INFO | HPO epoch  50/80 | loss=0.3234 | val={'ROC-AUC': 0.8212121212121212, 'PRC-AUC': 0.6983203881888485}
# INFO | HPO epoch  55/80 | loss=0.3342 | val={'ROC-AUC': 0.8348484848484848, 'PRC-AUC': 0.7225627518956526}
# INFO | HPO epoch  60/80 | loss=0.3028 | val={'ROC-AUC': 0.8446969696969697, 'PRC-AUC': 0.7456031706302549}
# INFO | HPO epoch  65/80 | loss=0.2812 | val={'ROC-AUC': 0.8253787878787878, 'PRC-AUC': 0.7134274975772487}
# INFO | Early stop at epoch 67 (patience=15)
# INFO | GIN 3D HPO — trial 17/20 finished | val=-0.850947 | best=-0.869129
# INFO | GIN 3D — starting trial 18/20 (layers=4, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.8780 | val={'ROC-AUC': 0.6017045454545454, 'PRC-AUC': 0.4407587194060266}
# INFO | HPO epoch   5/80 | loss=0.5386 | val={'ROC-AUC': 0.6727272727272726, 'PRC-AUC': 0.5601465775492738}
# INFO | HPO epoch  10/80 | loss=0.4837 | val={'ROC-AUC': 0.7539772727272728, 'PRC-AUC': 0.5958223515010855}
# INFO | HPO epoch  15/80 | loss=0.4598 | val={'ROC-AUC': 0.7785984848484848, 'PRC-AUC': 0.6454771264558752}
# INFO | HPO epoch  20/80 | loss=0.4112 | val={'ROC-AUC': 0.8041666666666667, 'PRC-AUC': 0.7296656952334805}
# INFO | HPO epoch  25/80 | loss=0.3772 | val={'ROC-AUC': 0.7878787878787878, 'PRC-AUC': 0.7059335172221944}
# INFO | HPO epoch  30/80 | loss=0.3290 | val={'ROC-AUC': 0.8293560606060606, 'PRC-AUC': 0.7451086926574411}
# INFO | HPO epoch  35/80 | loss=0.3258 | val={'ROC-AUC': 0.8428030303030303, 'PRC-AUC': 0.7595649429242202}
# INFO | HPO epoch  40/80 | loss=0.2956 | val={'ROC-AUC': 0.8071969696969696, 'PRC-AUC': 0.7210828178028444}
# INFO | HPO epoch  45/80 | loss=0.2882 | val={'ROC-AUC': 0.7954545454545454, 'PRC-AUC': 0.7254063074158333}
# INFO | HPO epoch  50/80 | loss=0.2438 | val={'ROC-AUC': 0.812121212121212, 'PRC-AUC': 0.73027440280231}
# INFO | Early stop at epoch 50 (patience=15)
# INFO | GIN 3D HPO — trial 18/20 finished | val=-0.842803 | best=-0.869129
# INFO | GIN 3D — starting trial 19/20 (layers=3, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7276 | val={'ROC-AUC': 0.6418560606060606, 'PRC-AUC': 0.49563569072073377}
# INFO | HPO epoch   5/80 | loss=0.4745 | val={'ROC-AUC': 0.7221590909090908, 'PRC-AUC': 0.5835086403752928}
# INFO | HPO epoch  10/80 | loss=0.4206 | val={'ROC-AUC': 0.7638257575757575, 'PRC-AUC': 0.6527194866600001}
# INFO | HPO epoch  15/80 | loss=0.4118 | val={'ROC-AUC': 0.7996212121212122, 'PRC-AUC': 0.7020503099873721}
# INFO | HPO epoch  20/80 | loss=0.3594 | val={'ROC-AUC': 0.7969696969696969, 'PRC-AUC': 0.6906713380256337}
# INFO | HPO epoch  25/80 | loss=0.3594 | val={'ROC-AUC': 0.8174242424242425, 'PRC-AUC': 0.7053529430061971}
# INFO | HPO epoch  30/80 | loss=0.3498 | val={'ROC-AUC': 0.8198863636363636, 'PRC-AUC': 0.7218003630717197}
# INFO | HPO epoch  35/80 | loss=0.3272 | val={'ROC-AUC': 0.799431818181818, 'PRC-AUC': 0.7213639091924196}
# INFO | HPO epoch  40/80 | loss=0.3090 | val={'ROC-AUC': 0.8185606060606061, 'PRC-AUC': 0.7133486961762466}
# INFO | HPO epoch  45/80 | loss=0.3049 | val={'ROC-AUC': 0.8134469696969697, 'PRC-AUC': 0.7023479989366886}
# INFO | HPO epoch  50/80 | loss=0.2749 | val={'ROC-AUC': 0.8181818181818181, 'PRC-AUC': 0.7347648868982792}
# INFO | Early stop at epoch 52 (patience=15)
# INFO | GIN 3D HPO — trial 19/20 finished | val=-0.831629 | best=-0.869129
# INFO | GIN 3D — starting trial 20/20 (layers=5, hidden=128)
# INFO | HPO epoch   1/80 | loss=0.7779 | val={'ROC-AUC': 0.5801136363636363, 'PRC-AUC': 0.46204446384244324}
# INFO | HPO epoch   5/80 | loss=0.5903 | val={'ROC-AUC': 0.7140151515151515, 'PRC-AUC': 0.5427162565630237}
# INFO | HPO epoch  10/80 | loss=0.5393 | val={'ROC-AUC': 0.7481060606060607, 'PRC-AUC': 0.6123088485093797}
# INFO | HPO epoch  15/80 | loss=0.5020 | val={'ROC-AUC': 0.8111742424242424, 'PRC-AUC': 0.6862038174746804}
# INFO | HPO epoch  20/80 | loss=0.4678 | val={'ROC-AUC': 0.8157196969696969, 'PRC-AUC': 0.7071297427909697}
# INFO | HPO epoch  25/80 | loss=0.4569 | val={'ROC-AUC': 0.8104166666666666, 'PRC-AUC': 0.7154257332329328}
# INFO | HPO epoch  30/80 | loss=0.4451 | val={'ROC-AUC': 0.8433712121212121, 'PRC-AUC': 0.7046269334755277}
# INFO | HPO epoch  35/80 | loss=0.4347 | val={'ROC-AUC': 0.8232954545454545, 'PRC-AUC': 0.7011518550103533}
# INFO | HPO epoch  40/80 | loss=0.4075 | val={'ROC-AUC': 0.8303030303030303, 'PRC-AUC': 0.7044121847669029}
# INFO | HPO epoch  45/80 | loss=0.3924 | val={'ROC-AUC': 0.8424242424242425, 'PRC-AUC': 0.7242522449446275}
# INFO | HPO epoch  50/80 | loss=0.3859 | val={'ROC-AUC': 0.8367424242424243, 'PRC-AUC': 0.7320741839379294}
# INFO | HPO epoch  55/80 | loss=0.3505 | val={'ROC-AUC': 0.8448863636363636, 'PRC-AUC': 0.7422685732117796}
# INFO | Early stop at epoch 58 (patience=15)
# INFO | GIN 3D HPO — trial 20/20 finished | val=-0.849432 | best=-0.869129
# INFO | Epoch  10 | loss=0.4491 | val={'ROC-AUC': 0.7954545454545454, 'PRC-AUC': 0.6795882264153912}
# INFO | Epoch  20 | loss=0.3985 | val={'ROC-AUC': 0.8473484848484848, 'PRC-AUC': 0.7205103764380509}
# INFO | Epoch  30 | loss=0.3494 | val={'ROC-AUC': 0.85, 'PRC-AUC': 0.7444847780271606}
# INFO | Epoch  40 | loss=0.3342 | val={'ROC-AUC': 0.8388257575757575, 'PRC-AUC': 0.7285524019271982}
# INFO | Epoch  50 | loss=0.3090 | val={'ROC-AUC': 0.8465909090909092, 'PRC-AUC': 0.7520596479664148}
# INFO | Epoch  60 | loss=0.3027 | val={'ROC-AUC': 0.8359848484848484, 'PRC-AUC': 0.7401448334229557}
# INFO | Epoch  70 | loss=0.2753 | val={'ROC-AUC': 0.8452651515151515, 'PRC-AUC': 0.7445558702228272}
# INFO | Epoch  80 | loss=0.2733 | val={'ROC-AUC': 0.8388257575757576, 'PRC-AUC': 0.751135951173172}
# INFO | Saved GIN (3D) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.8789784638841243, 'PRC-AUC': 0.7156423009814988}

# %% [markdown]
# ### SchNet (3D coords)
# Uses atomic numbers + xyz from min-energy n=25 conformer.

# %%
MODEL_KEY = "SchNet (3D coords)"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_schnet(
        tr3d, va3d, TASK_TYPE, OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import eval_schnet, PyGLoader, build_schnet, train_schnet
    model = build_schnet(
        OUT_CHANNELS,
        hidden_channels=best["hidden_channels"],
        num_filters=best["num_filters"],
        num_interactions=best["num_interactions"],
        num_gaussians=best["num_gaussians"],
        cutoff=best["cutoff"],
    )
    train_schnet(model, tr3d, va3d, TASK_TYPE, epochs=GNN_EPOCHS, lr=best["lr"],
                 batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    te3d_schnet = ensure_atomic_numbers_list(te3d)
    test_metrics = eval_schnet(model, PyGLoader(te3d_schnet, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_schnet.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | SchNet — starting trial 1/20
# → SchNet (3D coords) (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=2.3279 | val={'ROC-AUC': 0.5395833333333334, 'PRC-AUC': 0.44890564821310164}
# INFO | HPO epoch   5/80 | loss=0.6855 | val={'ROC-AUC': 0.6488636363636363, 'PRC-AUC': 0.5365105365182123}
# INFO | HPO epoch  10/80 | loss=0.5219 | val={'ROC-AUC': 0.7429924242424242, 'PRC-AUC': 0.5904888376159717}
# INFO | HPO epoch  15/80 | loss=0.5018 | val={'ROC-AUC': 0.7513257575757576, 'PRC-AUC': 0.5473554655589636}
# INFO | HPO epoch  20/80 | loss=0.3857 | val={'ROC-AUC': 0.8018939393939394, 'PRC-AUC': 0.6351145805085165}
# INFO | HPO epoch  25/80 | loss=0.3821 | val={'ROC-AUC': 0.7763257575757576, 'PRC-AUC': 0.5999932975570441}
# INFO | HPO epoch  30/80 | loss=0.3439 | val={'ROC-AUC': 0.7943181818181818, 'PRC-AUC': 0.6485627654119637}
# INFO | HPO epoch  35/80 | loss=0.2379 | val={'ROC-AUC': 0.7780303030303031, 'PRC-AUC': 0.6554592162022665}
# INFO | HPO epoch  40/80 | loss=0.1854 | val={'ROC-AUC': 0.7715909090909091, 'PRC-AUC': 0.6469337814093814}
# INFO | HPO epoch  45/80 | loss=0.1742 | val={'ROC-AUC': 0.7850378787878788, 'PRC-AUC': 0.5957312784033241}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | SchNet HPO — trial 1/20 finished | val=-0.830303 | best=-0.830303
# INFO | SchNet — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=1.6451 | val={'ROC-AUC': 0.506628787878788, 'PRC-AUC': 0.42490669941430337}
# INFO | HPO epoch   5/80 | loss=0.6732 | val={'ROC-AUC': 0.6035984848484849, 'PRC-AUC': 0.49366251868996275}
# INFO | HPO epoch  10/80 | loss=0.6250 | val={'ROC-AUC': 0.6918560606060604, 'PRC-AUC': 0.5860534216043461}
# INFO | HPO epoch  15/80 | loss=0.6265 | val={'ROC-AUC': 0.6998106060606061, 'PRC-AUC': 0.5582844323262093}
# INFO | HPO epoch  20/80 | loss=0.5716 | val={'ROC-AUC': 0.6734848484848484, 'PRC-AUC': 0.5442390833879905}
# INFO | HPO epoch  25/80 | loss=0.5671 | val={'ROC-AUC': 0.709659090909091, 'PRC-AUC': 0.5813305135940822}
# INFO | HPO epoch  30/80 | loss=0.5399 | val={'ROC-AUC': 0.7191287878787879, 'PRC-AUC': 0.5916184009327866}
# INFO | HPO epoch  35/80 | loss=0.5379 | val={'ROC-AUC': 0.693181818181818, 'PRC-AUC': 0.5830540500632299}
# INFO | HPO epoch  40/80 | loss=0.5191 | val={'ROC-AUC': 0.7310606060606061, 'PRC-AUC': 0.6001923580229857}
# INFO | HPO epoch  45/80 | loss=0.4985 | val={'ROC-AUC': 0.712689393939394, 'PRC-AUC': 0.6039153989742975}
# INFO | HPO epoch  50/80 | loss=0.5416 | val={'ROC-AUC': 0.7390151515151515, 'PRC-AUC': 0.6172924854487728}
# INFO | HPO epoch  55/80 | loss=0.4957 | val={'ROC-AUC': 0.7439393939393939, 'PRC-AUC': 0.635948099181948}
# INFO | HPO epoch  60/80 | loss=0.4867 | val={'ROC-AUC': 0.7481060606060607, 'PRC-AUC': 0.6374938565097712}
# INFO | HPO epoch  65/80 | loss=0.4854 | val={'ROC-AUC': 0.7568181818181818, 'PRC-AUC': 0.651531158545844}
# INFO | HPO epoch  70/80 | loss=0.4669 | val={'ROC-AUC': 0.7780303030303031, 'PRC-AUC': 0.6396928007653541}
# INFO | HPO epoch  75/80 | loss=0.4636 | val={'ROC-AUC': 0.7587121212121212, 'PRC-AUC': 0.6450874559547857}
# INFO | HPO epoch  80/80 | loss=0.4704 | val={'ROC-AUC': 0.7935606060606061, 'PRC-AUC': 0.6934018298917954}
# INFO | SchNet HPO — trial 2/20 finished | val=-0.793561 | best=-0.830303
# INFO | SchNet — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=0.8683 | val={'ROC-AUC': 0.5291666666666666, 'PRC-AUC': 0.4362124356295643}
# INFO | HPO epoch   5/80 | loss=0.6178 | val={'ROC-AUC': 0.6191287878787879, 'PRC-AUC': 0.5047571274074208}
# INFO | HPO epoch  10/80 | loss=0.5732 | val={'ROC-AUC': 0.6501893939393939, 'PRC-AUC': 0.5357873329496237}
# INFO | HPO epoch  15/80 | loss=0.5943 | val={'ROC-AUC': 0.7115530303030303, 'PRC-AUC': 0.5921486667036496}
# INFO | HPO epoch  20/80 | loss=0.5247 | val={'ROC-AUC': 0.7174242424242424, 'PRC-AUC': 0.5938257701505901}
# INFO | HPO epoch  25/80 | loss=0.5249 | val={'ROC-AUC': 0.7494318181818181, 'PRC-AUC': 0.6158242142923738}
# INFO | HPO epoch  30/80 | loss=0.4905 | val={'ROC-AUC': 0.7445075757575758, 'PRC-AUC': 0.5999915836086926}
# INFO | HPO epoch  35/80 | loss=0.4725 | val={'ROC-AUC': 0.7638257575757575, 'PRC-AUC': 0.6250631527884978}
# INFO | HPO epoch  40/80 | loss=0.5119 | val={'ROC-AUC': 0.7706439393939394, 'PRC-AUC': 0.625478026169326}
# INFO | HPO epoch  45/80 | loss=0.4509 | val={'ROC-AUC': 0.7676136363636363, 'PRC-AUC': 0.6155033394547906}
# INFO | Early stop at epoch 48 (patience=15)
# INFO | SchNet HPO — trial 3/20 finished | val=-0.775947 | best=-0.830303
# INFO | SchNet — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=1.3947 | val={'ROC-AUC': 0.5420454545454545, 'PRC-AUC': 0.4276115466777417}
# INFO | HPO epoch   5/80 | loss=0.6375 | val={'ROC-AUC': 0.609090909090909, 'PRC-AUC': 0.5183114312779007}
# INFO | HPO epoch  10/80 | loss=0.6039 | val={'ROC-AUC': 0.6392045454545454, 'PRC-AUC': 0.5423269494575171}
# INFO | HPO epoch  15/80 | loss=0.5744 | val={'ROC-AUC': 0.696780303030303, 'PRC-AUC': 0.5912878587189289}
# INFO | HPO epoch  20/80 | loss=0.5494 | val={'ROC-AUC': 0.7310606060606061, 'PRC-AUC': 0.6207710882288737}
# INFO | HPO epoch  25/80 | loss=0.5262 | val={'ROC-AUC': 0.7428030303030303, 'PRC-AUC': 0.6340366445773493}
# INFO | HPO epoch  30/80 | loss=0.5269 | val={'ROC-AUC': 0.7541666666666668, 'PRC-AUC': 0.6316369078240149}
# INFO | HPO epoch  35/80 | loss=0.4885 | val={'ROC-AUC': 0.7679924242424243, 'PRC-AUC': 0.623810467956887}
# INFO | HPO epoch  40/80 | loss=0.4663 | val={'ROC-AUC': 0.780871212121212, 'PRC-AUC': 0.6445162440131705}
# INFO | HPO epoch  45/80 | loss=0.4789 | val={'ROC-AUC': 0.7869318181818181, 'PRC-AUC': 0.6342001877847766}
# INFO | HPO epoch  50/80 | loss=0.4419 | val={'ROC-AUC': 0.7789772727272727, 'PRC-AUC': 0.6040996307646275}
# INFO | HPO epoch  55/80 | loss=0.4297 | val={'ROC-AUC': 0.7918560606060606, 'PRC-AUC': 0.6235391630456277}
# INFO | HPO epoch  60/80 | loss=0.4217 | val={'ROC-AUC': 0.7755681818181818, 'PRC-AUC': 0.6014592189739507}
# INFO | HPO epoch  65/80 | loss=0.4055 | val={'ROC-AUC': 0.7912878787878789, 'PRC-AUC': 0.619116379494964}
# INFO | HPO epoch  70/80 | loss=0.3765 | val={'ROC-AUC': 0.7854166666666667, 'PRC-AUC': 0.6057856506400646}
# INFO | Early stop at epoch 73 (patience=15)
# INFO | SchNet HPO — trial 4/20 finished | val=-0.798485 | best=-0.830303
# INFO | SchNet — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=2.7438 | val={'ROC-AUC': 0.5115530303030302, 'PRC-AUC': 0.44784463196748875}
# INFO | HPO epoch   5/80 | loss=0.6612 | val={'ROC-AUC': 0.6382575757575757, 'PRC-AUC': 0.5180172891327437}
# INFO | HPO epoch  10/80 | loss=0.6107 | val={'ROC-AUC': 0.6426136363636363, 'PRC-AUC': 0.49185339407142503}
# INFO | HPO epoch  15/80 | loss=0.6552 | val={'ROC-AUC': 0.6418560606060606, 'PRC-AUC': 0.5328501421936287}
# INFO | HPO epoch  20/80 | loss=0.5562 | val={'ROC-AUC': 0.700189393939394, 'PRC-AUC': 0.5698515609876861}
# INFO | HPO epoch  25/80 | loss=0.5415 | val={'ROC-AUC': 0.7410984848484848, 'PRC-AUC': 0.611875785535891}
# INFO | HPO epoch  30/80 | loss=0.5098 | val={'ROC-AUC': 0.737310606060606, 'PRC-AUC': 0.6138544760257164}
# INFO | HPO epoch  35/80 | loss=0.5047 | val={'ROC-AUC': 0.771590909090909, 'PRC-AUC': 0.641354929223127}
# INFO | HPO epoch  40/80 | loss=0.5008 | val={'ROC-AUC': 0.7452651515151514, 'PRC-AUC': 0.6321847565195255}
# INFO | HPO epoch  45/80 | loss=0.5009 | val={'ROC-AUC': 0.7634469696969697, 'PRC-AUC': 0.6476135566542018}
# INFO | HPO epoch  50/80 | loss=0.5010 | val={'ROC-AUC': 0.7611742424242424, 'PRC-AUC': 0.6300252506519075}
# INFO | HPO epoch  55/80 | loss=0.4771 | val={'ROC-AUC': 0.7619318181818181, 'PRC-AUC': 0.6649869295865395}
# INFO | HPO epoch  60/80 | loss=0.4716 | val={'ROC-AUC': 0.7837121212121211, 'PRC-AUC': 0.6885227287351036}
# INFO | HPO epoch  65/80 | loss=0.4373 | val={'ROC-AUC': 0.7793560606060607, 'PRC-AUC': 0.6609697184208095}
# INFO | HPO epoch  70/80 | loss=0.4371 | val={'ROC-AUC': 0.7714015151515151, 'PRC-AUC': 0.6435040706533431}
# INFO | HPO epoch  75/80 | loss=0.4709 | val={'ROC-AUC': 0.7946969696969697, 'PRC-AUC': 0.6652217700234456}
# INFO | HPO epoch  80/80 | loss=0.4176 | val={'ROC-AUC': 0.7973484848484848, 'PRC-AUC': 0.6702218848509053}
# INFO | SchNet HPO — trial 5/20 finished | val=-0.809470 | best=-0.830303
# INFO | SchNet — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=2.1132 | val={'ROC-AUC': 0.693560606060606, 'PRC-AUC': 0.6056765464073219}
# INFO | HPO epoch   5/80 | loss=0.6933 | val={'ROC-AUC': 0.6462121212121212, 'PRC-AUC': 0.5224097682456438}
# INFO | HPO epoch  10/80 | loss=0.5922 | val={'ROC-AUC': 0.6982954545454544, 'PRC-AUC': 0.5650226651299386}
# INFO | HPO epoch  15/80 | loss=0.4841 | val={'ROC-AUC': 0.7717803030303031, 'PRC-AUC': 0.6718684009324697}
# INFO | HPO epoch  20/80 | loss=0.4495 | val={'ROC-AUC': 0.7708333333333333, 'PRC-AUC': 0.6755287974762129}
# INFO | HPO epoch  25/80 | loss=0.4862 | val={'ROC-AUC': 0.7869318181818181, 'PRC-AUC': 0.6923333810432825}
# INFO | HPO epoch  30/80 | loss=0.4482 | val={'ROC-AUC': 0.7840909090909091, 'PRC-AUC': 0.6797793083291869}
# INFO | HPO epoch  35/80 | loss=0.3013 | val={'ROC-AUC': 0.8022727272727271, 'PRC-AUC': 0.7188590002783708}
# INFO | HPO epoch  40/80 | loss=0.2804 | val={'ROC-AUC': 0.8003787878787878, 'PRC-AUC': 0.716362998806006}
# INFO | HPO epoch  45/80 | loss=0.2385 | val={'ROC-AUC': 0.7964015151515151, 'PRC-AUC': 0.6843415009073508}
# INFO | HPO epoch  50/80 | loss=0.1982 | val={'ROC-AUC': 0.793939393939394, 'PRC-AUC': 0.6954458311272602}
# INFO | Early stop at epoch 52 (patience=15)
# INFO | SchNet HPO — trial 6/20 finished | val=-0.805492 | best=-0.830303
# INFO | SchNet — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=1.8446 | val={'ROC-AUC': 0.415530303030303, 'PRC-AUC': 0.34918542453593193}
# INFO | HPO epoch   5/80 | loss=0.6579 | val={'ROC-AUC': 0.7085227272727274, 'PRC-AUC': 0.5957855026342544}
# INFO | HPO epoch  10/80 | loss=0.5208 | val={'ROC-AUC': 0.7702651515151515, 'PRC-AUC': 0.6483052372970515}
# INFO | HPO epoch  15/80 | loss=0.3738 | val={'ROC-AUC': 0.7814393939393939, 'PRC-AUC': 0.6792276994590458}
# INFO | HPO epoch  20/80 | loss=0.3126 | val={'ROC-AUC': 0.7731060606060606, 'PRC-AUC': 0.6789078531143746}
# INFO | HPO epoch  25/80 | loss=0.2281 | val={'ROC-AUC': 0.765340909090909, 'PRC-AUC': 0.7172985670083573}
# INFO | HPO epoch  30/80 | loss=0.2000 | val={'ROC-AUC': 0.8066287878787879, 'PRC-AUC': 0.7395781425801996}
# INFO | HPO epoch  35/80 | loss=0.1061 | val={'ROC-AUC': 0.7943181818181817, 'PRC-AUC': 0.7407010388757975}
# INFO | HPO epoch  40/80 | loss=0.0956 | val={'ROC-AUC': 0.8231060606060606, 'PRC-AUC': 0.7481495233341343}
# INFO | Early stop at epoch 43 (patience=15)
# INFO | SchNet HPO — trial 7/20 finished | val=-0.828220 | best=-0.830303
# INFO | SchNet — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=1.6363 | val={'ROC-AUC': 0.5634469696969696, 'PRC-AUC': 0.44047878139977015}
# INFO | HPO epoch   5/80 | loss=0.8583 | val={'ROC-AUC': 0.6160984848484847, 'PRC-AUC': 0.485285107188169}
# INFO | HPO epoch  10/80 | loss=0.5903 | val={'ROC-AUC': 0.6840909090909091, 'PRC-AUC': 0.549073893862808}
# INFO | HPO epoch  15/80 | loss=0.5611 | val={'ROC-AUC': 0.740719696969697, 'PRC-AUC': 0.622687924155391}
# INFO | HPO epoch  20/80 | loss=0.5117 | val={'ROC-AUC': 0.7450757575757575, 'PRC-AUC': 0.6069392997302254}
# INFO | HPO epoch  25/80 | loss=0.4803 | val={'ROC-AUC': 0.7607954545454545, 'PRC-AUC': 0.6178329959824639}
# INFO | HPO epoch  30/80 | loss=0.4468 | val={'ROC-AUC': 0.7371212121212121, 'PRC-AUC': 0.5831585090417919}
# INFO | HPO epoch  35/80 | loss=0.3921 | val={'ROC-AUC': 0.756060606060606, 'PRC-AUC': 0.5959556863849585}
# INFO | Early stop at epoch 37 (patience=15)
# INFO | SchNet HPO — trial 8/20 finished | val=-0.760985 | best=-0.830303
# INFO | SchNet — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=2.1974 | val={'ROC-AUC': 0.5051136363636365, 'PRC-AUC': 0.4162634335943269}
# INFO | HPO epoch   5/80 | loss=0.6011 | val={'ROC-AUC': 0.6736742424242423, 'PRC-AUC': 0.5490247613563717}
# INFO | HPO epoch  10/80 | loss=0.5224 | val={'ROC-AUC': 0.7231060606060606, 'PRC-AUC': 0.6222755993670884}
# INFO | HPO epoch  15/80 | loss=0.4916 | val={'ROC-AUC': 0.7513257575757576, 'PRC-AUC': 0.6415764692338879}
# INFO | HPO epoch  20/80 | loss=0.4796 | val={'ROC-AUC': 0.7755681818181819, 'PRC-AUC': 0.7094181542660015}
# INFO | HPO epoch  25/80 | loss=0.4167 | val={'ROC-AUC': 0.7704545454545455, 'PRC-AUC': 0.6766532741019585}
# INFO | HPO epoch  30/80 | loss=0.4247 | val={'ROC-AUC': 0.7657196969696969, 'PRC-AUC': 0.6589732828898955}
# INFO | HPO epoch  35/80 | loss=0.3471 | val={'ROC-AUC': 0.7780303030303031, 'PRC-AUC': 0.6634182253639266}
# INFO | HPO epoch  40/80 | loss=0.3637 | val={'ROC-AUC': 0.7945075757575757, 'PRC-AUC': 0.7044394601498678}
# INFO | HPO epoch  45/80 | loss=0.3193 | val={'ROC-AUC': 0.7761363636363636, 'PRC-AUC': 0.6569239527713335}
# INFO | HPO epoch  50/80 | loss=0.2833 | val={'ROC-AUC': 0.7886363636363637, 'PRC-AUC': 0.6678501195251949}
# INFO | HPO epoch  55/80 | loss=0.3087 | val={'ROC-AUC': 0.8047348484848484, 'PRC-AUC': 0.7062678715012767}
# INFO | HPO epoch  60/80 | loss=0.2503 | val={'ROC-AUC': 0.7804924242424243, 'PRC-AUC': 0.6490715719885141}
# INFO | HPO epoch  65/80 | loss=0.2466 | val={'ROC-AUC': 0.7878787878787878, 'PRC-AUC': 0.6858347022030991}
# INFO | HPO epoch  70/80 | loss=0.1752 | val={'ROC-AUC': 0.7857954545454545, 'PRC-AUC': 0.661285951011903}
# INFO | Early stop at epoch 71 (patience=15)
# INFO | SchNet HPO — trial 9/20 finished | val=-0.811742 | best=-0.830303
# INFO | SchNet — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=1.9398 | val={'ROC-AUC': 0.5104166666666667, 'PRC-AUC': 0.44861909679957435}
# INFO | HPO epoch   5/80 | loss=0.8145 | val={'ROC-AUC': 0.7047348484848485, 'PRC-AUC': 0.5909391906104592}
# INFO | HPO epoch  10/80 | loss=0.5742 | val={'ROC-AUC': 0.7115530303030303, 'PRC-AUC': 0.5466627458213444}
# INFO | HPO epoch  15/80 | loss=0.5668 | val={'ROC-AUC': 0.7013257575757575, 'PRC-AUC': 0.6108261038971143}
# INFO | HPO epoch  20/80 | loss=0.5346 | val={'ROC-AUC': 0.7316287878787878, 'PRC-AUC': 0.5747874624852177}
# INFO | HPO epoch  25/80 | loss=0.5494 | val={'ROC-AUC': 0.7214015151515152, 'PRC-AUC': 0.6453871337068702}
# INFO | HPO epoch  30/80 | loss=0.4520 | val={'ROC-AUC': 0.7585227272727273, 'PRC-AUC': 0.6164582719620144}
# INFO | HPO epoch  35/80 | loss=0.4376 | val={'ROC-AUC': 0.7797348484848484, 'PRC-AUC': 0.7211519166259093}
# INFO | HPO epoch  40/80 | loss=0.4148 | val={'ROC-AUC': 0.8037878787878787, 'PRC-AUC': 0.730530511107033}
# INFO | HPO epoch  45/80 | loss=0.3890 | val={'ROC-AUC': 0.8359848484848486, 'PRC-AUC': 0.7325951411095947}
# INFO | HPO epoch  50/80 | loss=0.3760 | val={'ROC-AUC': 0.7638257575757577, 'PRC-AUC': 0.6663137543131137}
# INFO | HPO epoch  55/80 | loss=0.3348 | val={'ROC-AUC': 0.8395833333333332, 'PRC-AUC': 0.7376157704922011}
# INFO | HPO epoch  60/80 | loss=0.3590 | val={'ROC-AUC': 0.8077651515151515, 'PRC-AUC': 0.6908273162671241}
# INFO | HPO epoch  65/80 | loss=0.3126 | val={'ROC-AUC': 0.8068181818181818, 'PRC-AUC': 0.6823980127793522}
# INFO | HPO epoch  70/80 | loss=0.2757 | val={'ROC-AUC': 0.8053030303030303, 'PRC-AUC': 0.7235000207201563}
# INFO | HPO epoch  75/80 | loss=0.1993 | val={'ROC-AUC': 0.8102272727272728, 'PRC-AUC': 0.713246618966439}
# INFO | Early stop at epoch 77 (patience=15)
# INFO | SchNet HPO — trial 10/20 finished | val=-0.850758 | best=-0.850758
# INFO | SchNet — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=1.0596 | val={'ROC-AUC': 0.4914772727272727, 'PRC-AUC': 0.4025364489038893}
# INFO | HPO epoch   5/80 | loss=0.6456 | val={'ROC-AUC': 0.5450757575757574, 'PRC-AUC': 0.4764531498587338}
# INFO | HPO epoch  10/80 | loss=0.6180 | val={'ROC-AUC': 0.5750000000000001, 'PRC-AUC': 0.4997347587543217}
# INFO | HPO epoch  15/80 | loss=0.6466 | val={'ROC-AUC': 0.6395833333333334, 'PRC-AUC': 0.5565721359529182}
# INFO | HPO epoch  20/80 | loss=0.5774 | val={'ROC-AUC': 0.6594696969696969, 'PRC-AUC': 0.5685958654601951}
# INFO | HPO epoch  25/80 | loss=0.5657 | val={'ROC-AUC': 0.675189393939394, 'PRC-AUC': 0.5689543680220129}
# INFO | HPO epoch  30/80 | loss=0.5782 | val={'ROC-AUC': 0.6731060606060605, 'PRC-AUC': 0.5655515377195404}
# INFO | HPO epoch  35/80 | loss=0.5412 | val={'ROC-AUC': 0.7138257575757575, 'PRC-AUC': 0.6192188019759776}
# INFO | HPO epoch  40/80 | loss=0.5343 | val={'ROC-AUC': 0.7179924242424243, 'PRC-AUC': 0.5959495043231015}
# INFO | HPO epoch  45/80 | loss=0.5338 | val={'ROC-AUC': 0.7098484848484848, 'PRC-AUC': 0.5951356698322366}
# INFO | HPO epoch  50/80 | loss=0.5098 | val={'ROC-AUC': 0.7253787878787878, 'PRC-AUC': 0.6024625845321543}
# INFO | HPO epoch  55/80 | loss=0.5137 | val={'ROC-AUC': 0.715719696969697, 'PRC-AUC': 0.6000025193883265}
# INFO | HPO epoch  60/80 | loss=0.4971 | val={'ROC-AUC': 0.7270833333333333, 'PRC-AUC': 0.6133720505442782}
# INFO | HPO epoch  65/80 | loss=0.4748 | val={'ROC-AUC': 0.7142045454545454, 'PRC-AUC': 0.5766249719208439}
# INFO | HPO epoch  70/80 | loss=0.4613 | val={'ROC-AUC': 0.7174242424242424, 'PRC-AUC': 0.6181052920781923}
# INFO | Early stop at epoch 74 (patience=15)
# INFO | SchNet HPO — trial 11/20 finished | val=-0.748295 | best=-0.850758
# INFO | SchNet — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=2.1201 | val={'ROC-AUC': 0.45928030303030304, 'PRC-AUC': 0.3793908973014223}
# INFO | HPO epoch   5/80 | loss=0.6153 | val={'ROC-AUC': 0.6992424242424243, 'PRC-AUC': 0.5720498534741807}
# INFO | HPO epoch  10/80 | loss=0.5657 | val={'ROC-AUC': 0.7153409090909091, 'PRC-AUC': 0.6047698337190933}
# INFO | HPO epoch  15/80 | loss=0.6185 | val={'ROC-AUC': 0.746590909090909, 'PRC-AUC': 0.6441192703635268}
# INFO | HPO epoch  20/80 | loss=0.5050 | val={'ROC-AUC': 0.7488636363636364, 'PRC-AUC': 0.6514441906632225}
# INFO | HPO epoch  25/80 | loss=0.5332 | val={'ROC-AUC': 0.7225378787878788, 'PRC-AUC': 0.6446871408914774}
# INFO | HPO epoch  30/80 | loss=0.4564 | val={'ROC-AUC': 0.7871212121212121, 'PRC-AUC': 0.6739808522292452}
# INFO | HPO epoch  35/80 | loss=0.4506 | val={'ROC-AUC': 0.8121212121212121, 'PRC-AUC': 0.702394224036614}
# INFO | HPO epoch  40/80 | loss=0.4138 | val={'ROC-AUC': 0.8109848484848484, 'PRC-AUC': 0.6999949104938379}
# INFO | HPO epoch  45/80 | loss=0.4256 | val={'ROC-AUC': 0.8183712121212121, 'PRC-AUC': 0.7105747176228083}
# INFO | HPO epoch  50/80 | loss=0.3966 | val={'ROC-AUC': 0.8234848484848484, 'PRC-AUC': 0.7060700808667163}
# INFO | HPO epoch  55/80 | loss=0.3562 | val={'ROC-AUC': 0.8098484848484848, 'PRC-AUC': 0.6642469600088505}
# INFO | HPO epoch  60/80 | loss=0.2948 | val={'ROC-AUC': 0.7988636363636364, 'PRC-AUC': 0.6658246816618751}
# INFO | HPO epoch  65/80 | loss=0.2173 | val={'ROC-AUC': 0.8236742424242425, 'PRC-AUC': 0.6950573085201552}
# INFO | HPO epoch  70/80 | loss=0.1868 | val={'ROC-AUC': 0.8026515151515151, 'PRC-AUC': 0.63059386914322}
# INFO | HPO epoch  75/80 | loss=0.2032 | val={'ROC-AUC': 0.8119318181818183, 'PRC-AUC': 0.6507795863520884}
# INFO | Early stop at epoch 79 (patience=15)
# INFO | SchNet HPO — trial 12/20 finished | val=-0.837879 | best=-0.850758
# INFO | SchNet — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=1.9128 | val={'ROC-AUC': 0.5068181818181817, 'PRC-AUC': 0.44026100322216655}
# INFO | HPO epoch   5/80 | loss=0.6806 | val={'ROC-AUC': 0.6831439393939394, 'PRC-AUC': 0.553911183644101}
# INFO | HPO epoch  10/80 | loss=0.6007 | val={'ROC-AUC': 0.6884469696969696, 'PRC-AUC': 0.5541203070239505}
# INFO | HPO epoch  15/80 | loss=0.5914 | val={'ROC-AUC': 0.7140151515151515, 'PRC-AUC': 0.5849687659769812}
# INFO | HPO epoch  20/80 | loss=0.5408 | val={'ROC-AUC': 0.7043560606060605, 'PRC-AUC': 0.5821055128055498}
# INFO | HPO epoch  25/80 | loss=0.4624 | val={'ROC-AUC': 0.724810606060606, 'PRC-AUC': 0.6754328605285721}
# INFO | HPO epoch  30/80 | loss=0.4898 | val={'ROC-AUC': 0.7664772727272726, 'PRC-AUC': 0.6750932748259004}
# INFO | HPO epoch  35/80 | loss=0.4986 | val={'ROC-AUC': 0.8062499999999999, 'PRC-AUC': 0.7144518032573721}
# INFO | HPO epoch  40/80 | loss=0.4024 | val={'ROC-AUC': 0.7869318181818181, 'PRC-AUC': 0.6786962898400188}
# INFO | HPO epoch  45/80 | loss=0.3888 | val={'ROC-AUC': 0.8210227272727273, 'PRC-AUC': 0.7295175550371896}
# INFO | Early stop at epoch 49 (patience=15)
# INFO | SchNet HPO — trial 13/20 finished | val=-0.822917 | best=-0.850758
# INFO | SchNet — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=1.5317 | val={'ROC-AUC': 0.4922348484848486, 'PRC-AUC': 0.42234612585888875}
# INFO | HPO epoch   5/80 | loss=0.8065 | val={'ROC-AUC': 0.6670454545454544, 'PRC-AUC': 0.5579605578953816}
# INFO | HPO epoch  10/80 | loss=0.6120 | val={'ROC-AUC': 0.6034090909090909, 'PRC-AUC': 0.4940698117431435}
# INFO | HPO epoch  15/80 | loss=0.5374 | val={'ROC-AUC': 0.7242424242424242, 'PRC-AUC': 0.5526025271095711}
# INFO | HPO epoch  20/80 | loss=0.5163 | val={'ROC-AUC': 0.7227272727272727, 'PRC-AUC': 0.6255282981336076}
# INFO | HPO epoch  25/80 | loss=0.4908 | val={'ROC-AUC': 0.7785984848484849, 'PRC-AUC': 0.6259032677450774}
# INFO | HPO epoch  30/80 | loss=0.4966 | val={'ROC-AUC': 0.7653409090909091, 'PRC-AUC': 0.7035930757672967}
# INFO | HPO epoch  35/80 | loss=0.4109 | val={'ROC-AUC': 0.7799242424242423, 'PRC-AUC': 0.6705576483787573}
# INFO | HPO epoch  40/80 | loss=0.3602 | val={'ROC-AUC': 0.790719696969697, 'PRC-AUC': 0.6719208307028132}
# INFO | HPO epoch  45/80 | loss=0.3301 | val={'ROC-AUC': 0.796969696969697, 'PRC-AUC': 0.6645492569060026}
# INFO | HPO epoch  50/80 | loss=0.3584 | val={'ROC-AUC': 0.8104166666666666, 'PRC-AUC': 0.7192965800560782}
# INFO | HPO epoch  55/80 | loss=0.2618 | val={'ROC-AUC': 0.7835227272727273, 'PRC-AUC': 0.6969516328062261}
# INFO | Early stop at epoch 57 (patience=15)
# INFO | SchNet HPO — trial 14/20 finished | val=-0.810606 | best=-0.850758
# INFO | SchNet — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=2.1515 | val={'ROC-AUC': 0.5374999999999999, 'PRC-AUC': 0.4423159533377955}
# INFO | HPO epoch   5/80 | loss=0.9293 | val={'ROC-AUC': 0.5850378787878787, 'PRC-AUC': 0.4518042938907781}
# INFO | HPO epoch  10/80 | loss=0.5994 | val={'ROC-AUC': 0.6926136363636363, 'PRC-AUC': 0.6115112660994098}
# INFO | HPO epoch  15/80 | loss=0.5881 | val={'ROC-AUC': 0.6971590909090909, 'PRC-AUC': 0.5905353722188833}
# INFO | HPO epoch  20/80 | loss=0.5324 | val={'ROC-AUC': 0.7361742424242425, 'PRC-AUC': 0.6604023437535057}
# INFO | HPO epoch  25/80 | loss=0.5058 | val={'ROC-AUC': 0.7422348484848484, 'PRC-AUC': 0.6887029099121162}
# INFO | HPO epoch  30/80 | loss=0.5201 | val={'ROC-AUC': 0.746590909090909, 'PRC-AUC': 0.6536168260825728}
# INFO | HPO epoch  35/80 | loss=0.4599 | val={'ROC-AUC': 0.78125, 'PRC-AUC': 0.6877777392947223}
# INFO | HPO epoch  40/80 | loss=0.4368 | val={'ROC-AUC': 0.7695075757575757, 'PRC-AUC': 0.7149473845062472}
# INFO | HPO epoch  45/80 | loss=0.3882 | val={'ROC-AUC': 0.7763257575757575, 'PRC-AUC': 0.6625741412205074}
# INFO | HPO epoch  50/80 | loss=0.4160 | val={'ROC-AUC': 0.7725378787878788, 'PRC-AUC': 0.7234182264263649}
# INFO | HPO epoch  55/80 | loss=0.3488 | val={'ROC-AUC': 0.781439393939394, 'PRC-AUC': 0.673180030714801}
# INFO | HPO epoch  60/80 | loss=0.2510 | val={'ROC-AUC': 0.7761363636363635, 'PRC-AUC': 0.6643942679651158}
# INFO | Early stop at epoch 63 (patience=15)
# INFO | SchNet HPO — trial 15/20 finished | val=-0.810038 | best=-0.850758
# INFO | SchNet — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=1.0645 | val={'ROC-AUC': 0.5056818181818181, 'PRC-AUC': 0.4119910771781047}
# INFO | HPO epoch   5/80 | loss=0.6214 | val={'ROC-AUC': 0.6492424242424243, 'PRC-AUC': 0.5496987721498203}
# INFO | HPO epoch  10/80 | loss=0.5879 | val={'ROC-AUC': 0.7049242424242425, 'PRC-AUC': 0.5961318858805735}
# INFO | HPO epoch  15/80 | loss=0.5654 | val={'ROC-AUC': 0.730871212121212, 'PRC-AUC': 0.5922522211848159}
# INFO | HPO epoch  20/80 | loss=0.5724 | val={'ROC-AUC': 0.6875, 'PRC-AUC': 0.600812189019676}
# INFO | HPO epoch  25/80 | loss=0.5526 | val={'ROC-AUC': 0.7087121212121212, 'PRC-AUC': 0.6350155572889736}
# INFO | HPO epoch  30/80 | loss=0.5301 | val={'ROC-AUC': 0.7285984848484849, 'PRC-AUC': 0.630064435508794}
# INFO | HPO epoch  35/80 | loss=0.5104 | val={'ROC-AUC': 0.7473484848484849, 'PRC-AUC': 0.6398603969644999}
# INFO | HPO epoch  40/80 | loss=0.5231 | val={'ROC-AUC': 0.7691287878787879, 'PRC-AUC': 0.6426192525806954}
# INFO | HPO epoch  45/80 | loss=0.4726 | val={'ROC-AUC': 0.7871212121212121, 'PRC-AUC': 0.7270060535509001}
# INFO | HPO epoch  50/80 | loss=0.4240 | val={'ROC-AUC': 0.8020833333333334, 'PRC-AUC': 0.7373351937409126}
# INFO | HPO epoch  55/80 | loss=0.4299 | val={'ROC-AUC': 0.8196969696969696, 'PRC-AUC': 0.7357934485518868}
# INFO | HPO epoch  60/80 | loss=0.4161 | val={'ROC-AUC': 0.8225378787878788, 'PRC-AUC': 0.7585729476225369}
# INFO | HPO epoch  65/80 | loss=0.4072 | val={'ROC-AUC': 0.8017045454545454, 'PRC-AUC': 0.7561081079463229}
# INFO | HPO epoch  70/80 | loss=0.3736 | val={'ROC-AUC': 0.8202651515151514, 'PRC-AUC': 0.7408332254864708}
# INFO | HPO epoch  75/80 | loss=0.3696 | val={'ROC-AUC': 0.8212121212121212, 'PRC-AUC': 0.7635268835035923}
# INFO | HPO epoch  80/80 | loss=0.3857 | val={'ROC-AUC': 0.8259469696969697, 'PRC-AUC': 0.7571626877572486}
# INFO | SchNet HPO — trial 16/20 finished | val=-0.840530 | best=-0.850758
# INFO | SchNet — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=1.4086 | val={'ROC-AUC': 0.5683712121212121, 'PRC-AUC': 0.5000079663331902}
# INFO | HPO epoch   5/80 | loss=0.7063 | val={'ROC-AUC': 0.5668560606060605, 'PRC-AUC': 0.4835908993982998}
# INFO | HPO epoch  10/80 | loss=0.6107 | val={'ROC-AUC': 0.6973484848484849, 'PRC-AUC': 0.5953989338358523}
# INFO | HPO epoch  15/80 | loss=0.5809 | val={'ROC-AUC': 0.703409090909091, 'PRC-AUC': 0.579265814502606}
# INFO | HPO epoch  20/80 | loss=0.5536 | val={'ROC-AUC': 0.7126893939393939, 'PRC-AUC': 0.6096730530760313}
# INFO | HPO epoch  25/80 | loss=0.5136 | val={'ROC-AUC': 0.709469696969697, 'PRC-AUC': 0.5953909502598136}
# INFO | HPO epoch  30/80 | loss=0.5186 | val={'ROC-AUC': 0.7178030303030302, 'PRC-AUC': 0.6025404988316228}
# INFO | HPO epoch  35/80 | loss=0.4808 | val={'ROC-AUC': 0.7143939393939392, 'PRC-AUC': 0.5839330772105213}
# INFO | HPO epoch  40/80 | loss=0.4877 | val={'ROC-AUC': 0.7607954545454545, 'PRC-AUC': 0.6342597731125292}
# INFO | HPO epoch  45/80 | loss=0.4731 | val={'ROC-AUC': 0.7554924242424242, 'PRC-AUC': 0.6602232432668481}
# INFO | HPO epoch  50/80 | loss=0.4436 | val={'ROC-AUC': 0.7712121212121211, 'PRC-AUC': 0.6522703630719621}
# INFO | HPO epoch  55/80 | loss=0.4204 | val={'ROC-AUC': 0.790151515151515, 'PRC-AUC': 0.6879744588895657}
# INFO | HPO epoch  60/80 | loss=0.4029 | val={'ROC-AUC': 0.8138257575757576, 'PRC-AUC': 0.7203566772609575}
# INFO | HPO epoch  65/80 | loss=0.4013 | val={'ROC-AUC': 0.8051136363636363, 'PRC-AUC': 0.7263940489451922}
# INFO | HPO epoch  70/80 | loss=0.3671 | val={'ROC-AUC': 0.8142045454545455, 'PRC-AUC': 0.7291170551885255}
# INFO | HPO epoch  75/80 | loss=0.3661 | val={'ROC-AUC': 0.8083333333333335, 'PRC-AUC': 0.737572928395669}
# INFO | HPO epoch  80/80 | loss=0.3558 | val={'ROC-AUC': 0.821780303030303, 'PRC-AUC': 0.746830658803776}
# INFO | SchNet HPO — trial 17/20 finished | val=-0.831439 | best=-0.850758
# INFO | SchNet — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=1.3336 | val={'ROC-AUC': 0.5630681818181817, 'PRC-AUC': 0.44451077945168693}
# INFO | HPO epoch   5/80 | loss=0.6852 | val={'ROC-AUC': 0.5939393939393939, 'PRC-AUC': 0.5040813511913096}
# INFO | HPO epoch  10/80 | loss=0.5941 | val={'ROC-AUC': 0.6354166666666666, 'PRC-AUC': 0.5419139598039995}
# INFO | HPO epoch  15/80 | loss=0.6278 | val={'ROC-AUC': 0.6820075757575759, 'PRC-AUC': 0.5625370146827001}
# INFO | HPO epoch  20/80 | loss=0.5980 | val={'ROC-AUC': 0.6977272727272728, 'PRC-AUC': 0.5711585032250606}
# INFO | HPO epoch  25/80 | loss=0.5639 | val={'ROC-AUC': 0.7297348484848484, 'PRC-AUC': 0.5924823075264956}
# INFO | HPO epoch  30/80 | loss=0.5556 | val={'ROC-AUC': 0.709469696969697, 'PRC-AUC': 0.5757117392518128}
# INFO | HPO epoch  35/80 | loss=0.5445 | val={'ROC-AUC': 0.7246212121212121, 'PRC-AUC': 0.621657962505902}
# INFO | HPO epoch  40/80 | loss=0.5064 | val={'ROC-AUC': 0.7378787878787878, 'PRC-AUC': 0.6157521071821542}
# INFO | HPO epoch  45/80 | loss=0.4943 | val={'ROC-AUC': 0.7482954545454544, 'PRC-AUC': 0.630271615718312}
# INFO | HPO epoch  50/80 | loss=0.4792 | val={'ROC-AUC': 0.749810606060606, 'PRC-AUC': 0.6345192942900717}
# INFO | HPO epoch  55/80 | loss=0.4680 | val={'ROC-AUC': 0.7628787878787879, 'PRC-AUC': 0.663257042725727}
# INFO | HPO epoch  60/80 | loss=0.5062 | val={'ROC-AUC': 0.7706439393939394, 'PRC-AUC': 0.6721948273261608}
# INFO | HPO epoch  65/80 | loss=0.4427 | val={'ROC-AUC': 0.7643939393939393, 'PRC-AUC': 0.6705331464709935}
# INFO | HPO epoch  70/80 | loss=0.4301 | val={'ROC-AUC': 0.7784090909090908, 'PRC-AUC': 0.7036987077949526}
# INFO | HPO epoch  75/80 | loss=0.4216 | val={'ROC-AUC': 0.7770833333333332, 'PRC-AUC': 0.6995116126996218}
# INFO | HPO epoch  80/80 | loss=0.4453 | val={'ROC-AUC': 0.8, 'PRC-AUC': 0.6990428668580602}
# INFO | SchNet HPO — trial 18/20 finished | val=-0.800000 | best=-0.850758
# INFO | SchNet — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=1.1377 | val={'ROC-AUC': 0.5075757575757576, 'PRC-AUC': 0.4155669461001409}
# INFO | HPO epoch   5/80 | loss=0.6371 | val={'ROC-AUC': 0.5772727272727272, 'PRC-AUC': 0.4978467097095348}
# INFO | HPO epoch  10/80 | loss=0.5796 | val={'ROC-AUC': 0.6882575757575758, 'PRC-AUC': 0.5734649262939208}
# INFO | HPO epoch  15/80 | loss=0.5252 | val={'ROC-AUC': 0.7179924242424243, 'PRC-AUC': 0.5711305747399398}
# INFO | HPO epoch  20/80 | loss=0.4972 | val={'ROC-AUC': 0.7320075757575758, 'PRC-AUC': 0.609371847119898}
# INFO | HPO epoch  25/80 | loss=0.4924 | val={'ROC-AUC': 0.7303030303030303, 'PRC-AUC': 0.6089938056814759}
# INFO | HPO epoch  30/80 | loss=0.4413 | val={'ROC-AUC': 0.7625, 'PRC-AUC': 0.6203325293957024}
# INFO | HPO epoch  35/80 | loss=0.4353 | val={'ROC-AUC': 0.7751893939393939, 'PRC-AUC': 0.6547546041993674}
# INFO | HPO epoch  40/80 | loss=0.4374 | val={'ROC-AUC': 0.7755681818181818, 'PRC-AUC': 0.6377027287554401}
# INFO | HPO epoch  45/80 | loss=0.4171 | val={'ROC-AUC': 0.7892045454545454, 'PRC-AUC': 0.6944962772037141}
# INFO | HPO epoch  50/80 | loss=0.3755 | val={'ROC-AUC': 0.7748106060606061, 'PRC-AUC': 0.6801601631187066}
# INFO | HPO epoch  55/80 | loss=0.4220 | val={'ROC-AUC': 0.7946969696969697, 'PRC-AUC': 0.6633427885108638}
# INFO | HPO epoch  60/80 | loss=0.3334 | val={'ROC-AUC': 0.8119318181818181, 'PRC-AUC': 0.7163479648973847}
# INFO | HPO epoch  65/80 | loss=0.3542 | val={'ROC-AUC': 0.7969696969696969, 'PRC-AUC': 0.7025717986004664}
# INFO | HPO epoch  70/80 | loss=0.3221 | val={'ROC-AUC': 0.7964015151515151, 'PRC-AUC': 0.6684787384045185}
# INFO | HPO epoch  75/80 | loss=0.2513 | val={'ROC-AUC': 0.7912878787878787, 'PRC-AUC': 0.676587683914054}
# INFO | Early stop at epoch 75 (patience=15)
# INFO | SchNet HPO — trial 19/20 finished | val=-0.811932 | best=-0.850758
# INFO | SchNet — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=0.7573 | val={'ROC-AUC': 0.553030303030303, 'PRC-AUC': 0.498816801833114}
# INFO | HPO epoch   5/80 | loss=0.6216 | val={'ROC-AUC': 0.6246212121212121, 'PRC-AUC': 0.5504187330656002}
# INFO | HPO epoch  10/80 | loss=0.6229 | val={'ROC-AUC': 0.7015151515151515, 'PRC-AUC': 0.5888930801466745}
# INFO | HPO epoch  15/80 | loss=0.5776 | val={'ROC-AUC': 0.6994318181818182, 'PRC-AUC': 0.5920829460656718}
# INFO | HPO epoch  20/80 | loss=0.5613 | val={'ROC-AUC': 0.7221590909090909, 'PRC-AUC': 0.622280298918117}
# INFO | HPO epoch  25/80 | loss=0.5308 | val={'ROC-AUC': 0.7310606060606061, 'PRC-AUC': 0.6055205957308366}
# INFO | HPO epoch  30/80 | loss=0.5398 | val={'ROC-AUC': 0.7454545454545455, 'PRC-AUC': 0.6335900141911143}
# INFO | HPO epoch  35/80 | loss=0.5254 | val={'ROC-AUC': 0.7598484848484849, 'PRC-AUC': 0.6290310686098373}
# INFO | HPO epoch  40/80 | loss=0.4889 | val={'ROC-AUC': 0.7445075757575756, 'PRC-AUC': 0.6575152102674836}
# INFO | HPO epoch  45/80 | loss=0.4872 | val={'ROC-AUC': 0.7753787878787879, 'PRC-AUC': 0.688077346394427}
# INFO | HPO epoch  50/80 | loss=0.4853 | val={'ROC-AUC': 0.7865530303030303, 'PRC-AUC': 0.6547837188563911}
# INFO | HPO epoch  55/80 | loss=0.4490 | val={'ROC-AUC': 0.7598484848484849, 'PRC-AUC': 0.671481030594977}
# INFO | HPO epoch  60/80 | loss=0.4247 | val={'ROC-AUC': 0.8221590909090909, 'PRC-AUC': 0.7091313651181569}
# INFO | HPO epoch  65/80 | loss=0.4507 | val={'ROC-AUC': 0.8151515151515152, 'PRC-AUC': 0.7021517961091812}
# INFO | HPO epoch  70/80 | loss=0.4208 | val={'ROC-AUC': 0.7931818181818182, 'PRC-AUC': 0.7070848773200347}
# INFO | HPO epoch  75/80 | loss=0.3706 | val={'ROC-AUC': 0.8285984848484848, 'PRC-AUC': 0.7494969780923797}
# INFO | HPO epoch  80/80 | loss=0.3773 | val={'ROC-AUC': 0.837689393939394, 'PRC-AUC': 0.7547154599739916}
# INFO | SchNet HPO — trial 20/20 finished | val=-0.837689 | best=-0.850758
# INFO | Epoch  10 | loss=0.6447 | val={'ROC-AUC': 0.7090909090909091, 'PRC-AUC': 0.5774131101430476}
# INFO | Epoch  20 | loss=0.6357 | val={'ROC-AUC': 0.7270833333333333, 'PRC-AUC': 0.6702746396221259}
# INFO | Epoch  30 | loss=0.4989 | val={'ROC-AUC': 0.7859848484848485, 'PRC-AUC': 0.704957140981911}
# INFO | Epoch  40 | loss=0.4187 | val={'ROC-AUC': 0.7821969696969697, 'PRC-AUC': 0.7052091538082886}
# INFO | Epoch  50 | loss=0.3761 | val={'ROC-AUC': 0.7910984848484848, 'PRC-AUC': 0.6573914302041484}
# INFO | Epoch  60 | loss=0.2887 | val={'ROC-AUC': 0.7816287878787879, 'PRC-AUC': 0.7105878298612605}
# INFO | Epoch  70 | loss=0.1868 | val={'ROC-AUC': 0.803030303030303, 'PRC-AUC': 0.6756557184977476}
# INFO | Epoch  80 | loss=0.1056 | val={'ROC-AUC': 0.7844696969696969, 'PRC-AUC': 0.6505317442602739}
# INFO | Saved SchNet (3D coords) → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.7905469792262245, 'PRC-AUC': 0.696071789874292}

# %% [markdown]
# ### SMILES LSTM
# Canonical isomeric SMILES tokens.

# %%
MODEL_KEY = "SMILES LSTM"
results = load_partial_results(PARTIAL_PATH)
if MODEL_KEY in results:
    print(f"Skipping {MODEL_KEY}")
else:
    print(f"→ {MODEL_KEY} (Optuna {HPO_N_TRIALS} trials, {SPLIT_MODE} split) …")
    best, history = hpo_lstm(
        tr_ds, va_ds, TASK_TYPE, len(vocab), OUT_CHANNELS,
        n_trials=HPO_N_TRIALS, epochs=HPO_EPOCHS, batch_size=BATCH_SIZE, device=DEVICE,
        seed=SPLIT_SEED,
    )
    save_hpo_params(
        hpo_params_path(HPO_DIR, MODEL_KEY, DATASET_SLUG),
        best,
        dataset=DATASET_SLUG,
        model=MODEL_KEY,
        seed=SPLIT_SEED,
    )
    from mol_repr_utils import SmilesLSTM, eval_lstm, TorchLoader, train_lstm
    model = SmilesLSTM(len(vocab), embed_dim=best["embed_dim"], hidden_dim=best["hidden_dim"],
                       n_layers=best["n_layers"], out_channels=OUT_CHANNELS, dropout=best["dropout"])
    train_lstm(model, tr_ds, va_ds, TASK_TYPE, epochs=LSTM_EPOCHS, lr=best["lr"],
               batch_size=BATCH_SIZE, device=DEVICE, verbose=False)
    test_metrics = eval_lstm(model, TorchLoader(te_ds, batch_size=BATCH_SIZE), DEVICE, TASK_TYPE)
    metrics = {k: (v, 0.0) for k, v in test_metrics.items()}
    save_model_result(results, MODEL_KEY, metrics, PARTIAL_PATH,
                      history=history, history_path=HISTORY_DIR / f"{DATASET_SLUG}_lstm.json")
    print(f"   {SPLIT_MODE} test: {test_metrics}")
# Out:
# INFO | LSTM — starting trial 1/20
# → SMILES LSTM (Optuna 20 trials, scaffold split) …
# INFO | HPO epoch   1/80 | loss=0.6918 | val={'ROC-AUC': 0.577840909090909, 'PRC-AUC': 0.49971726966839525}
# INFO | HPO epoch   5/80 | loss=0.6851 | val={'ROC-AUC': 0.5787878787878787, 'PRC-AUC': 0.4782201815378147}
# INFO | HPO epoch  10/80 | loss=0.6724 | val={'ROC-AUC': 0.5795454545454545, 'PRC-AUC': 0.4774739751640541}
# INFO | HPO epoch  15/80 | loss=0.6151 | val={'ROC-AUC': 0.6267045454545453, 'PRC-AUC': 0.48923664437732106}
# INFO | HPO epoch  20/80 | loss=0.5690 | val={'ROC-AUC': 0.5996212121212121, 'PRC-AUC': 0.4777695020422249}
# INFO | HPO epoch  25/80 | loss=0.5415 | val={'ROC-AUC': 0.6159090909090909, 'PRC-AUC': 0.5246319813294325}
# INFO | Early stop at epoch 28 (patience=15)
# INFO | LSTM HPO — trial 1/20 finished | val=-0.629924 | best=-0.629924
# INFO | LSTM — starting trial 2/20
# INFO | HPO epoch   1/80 | loss=0.6916 | val={'ROC-AUC': 0.581060606060606, 'PRC-AUC': 0.4516625227499504}
# INFO | HPO epoch   5/80 | loss=0.6756 | val={'ROC-AUC': 0.5859848484848484, 'PRC-AUC': 0.4585736863847689}
# INFO | HPO epoch  10/80 | loss=0.6327 | val={'ROC-AUC': 0.63125, 'PRC-AUC': 0.513335417277313}
# INFO | HPO epoch  15/80 | loss=0.5574 | val={'ROC-AUC': 0.6708333333333334, 'PRC-AUC': 0.5589867493889142}
# INFO | HPO epoch  20/80 | loss=0.4965 | val={'ROC-AUC': 0.7007575757575759, 'PRC-AUC': 0.5781523965125536}
# INFO | HPO epoch  25/80 | loss=0.4818 | val={'ROC-AUC': 0.7178030303030302, 'PRC-AUC': 0.6030074665573852}
# INFO | HPO epoch  30/80 | loss=0.4484 | val={'ROC-AUC': 0.7513257575757576, 'PRC-AUC': 0.624994396637045}
# INFO | HPO epoch  35/80 | loss=0.4202 | val={'ROC-AUC': 0.7276515151515152, 'PRC-AUC': 0.6200914790776553}
# INFO | HPO epoch  40/80 | loss=0.4049 | val={'ROC-AUC': 0.7285984848484849, 'PRC-AUC': 0.5904432569886574}
# INFO | HPO epoch  45/80 | loss=0.3940 | val={'ROC-AUC': 0.7346590909090909, 'PRC-AUC': 0.6181023030603259}
# INFO | HPO epoch  50/80 | loss=0.4001 | val={'ROC-AUC': 0.7662878787878789, 'PRC-AUC': 0.6701425019074335}
# INFO | HPO epoch  55/80 | loss=0.3839 | val={'ROC-AUC': 0.7558712121212122, 'PRC-AUC': 0.643505416579881}
# INFO | HPO epoch  60/80 | loss=0.3820 | val={'ROC-AUC': 0.7679924242424242, 'PRC-AUC': 0.6915443641177982}
# INFO | HPO epoch  65/80 | loss=0.3513 | val={'ROC-AUC': 0.7738636363636363, 'PRC-AUC': 0.7212289800735143}
# INFO | HPO epoch  70/80 | loss=0.3623 | val={'ROC-AUC': 0.7678030303030303, 'PRC-AUC': 0.6870745843574331}
# INFO | HPO epoch  75/80 | loss=0.3957 | val={'ROC-AUC': 0.7833333333333332, 'PRC-AUC': 0.6830962662755984}
# INFO | HPO epoch  80/80 | loss=0.3377 | val={'ROC-AUC': 0.7778409090909091, 'PRC-AUC': 0.7130596861190637}
# INFO | LSTM HPO — trial 2/20 finished | val=-0.800379 | best=-0.800379
# INFO | LSTM — starting trial 3/20
# INFO | HPO epoch   1/80 | loss=0.6920 | val={'ROC-AUC': 0.5712121212121213, 'PRC-AUC': 0.45194184658271275}
# INFO | HPO epoch   5/80 | loss=0.6794 | val={'ROC-AUC': 0.5931818181818181, 'PRC-AUC': 0.4714911789544429}
# INFO | HPO epoch  10/80 | loss=0.6223 | val={'ROC-AUC': 0.6149621212121212, 'PRC-AUC': 0.5316422997202994}
# INFO | HPO epoch  15/80 | loss=0.6143 | val={'ROC-AUC': 0.6092803030303031, 'PRC-AUC': 0.5257631857327065}
# INFO | HPO epoch  20/80 | loss=0.5974 | val={'ROC-AUC': 0.6206439393939395, 'PRC-AUC': 0.5336786098961872}
# INFO | Early stop at epoch 23 (patience=15)
# INFO | LSTM HPO — trial 3/20 finished | val=-0.625379 | best=-0.800379
# INFO | LSTM — starting trial 4/20
# INFO | HPO epoch   1/80 | loss=0.6930 | val={'ROC-AUC': 0.5604166666666668, 'PRC-AUC': 0.46313554863480577}
# INFO | HPO epoch   5/80 | loss=0.6751 | val={'ROC-AUC': 0.5933712121212121, 'PRC-AUC': 0.4827582873990559}
# INFO | HPO epoch  10/80 | loss=0.6140 | val={'ROC-AUC': 0.6422348484848485, 'PRC-AUC': 0.5437810166663238}
# INFO | HPO epoch  15/80 | loss=0.5371 | val={'ROC-AUC': 0.649621212121212, 'PRC-AUC': 0.5553061166466511}
# INFO | HPO epoch  20/80 | loss=0.5024 | val={'ROC-AUC': 0.6975378787878789, 'PRC-AUC': 0.564837409271387}
# INFO | HPO epoch  25/80 | loss=0.4757 | val={'ROC-AUC': 0.6738636363636363, 'PRC-AUC': 0.5614800293428143}
# INFO | HPO epoch  30/80 | loss=0.4445 | val={'ROC-AUC': 0.7075757575757575, 'PRC-AUC': 0.5929367071385919}
# INFO | HPO epoch  35/80 | loss=0.4351 | val={'ROC-AUC': 0.740719696969697, 'PRC-AUC': 0.627624301350608}
# INFO | HPO epoch  40/80 | loss=0.4219 | val={'ROC-AUC': 0.7346590909090909, 'PRC-AUC': 0.6282086716052342}
# INFO | HPO epoch  45/80 | loss=0.4060 | val={'ROC-AUC': 0.7770833333333333, 'PRC-AUC': 0.6354821705642749}
# INFO | HPO epoch  50/80 | loss=0.3936 | val={'ROC-AUC': 0.7587121212121213, 'PRC-AUC': 0.6203246957964187}
# INFO | HPO epoch  55/80 | loss=0.3726 | val={'ROC-AUC': 0.774621212121212, 'PRC-AUC': 0.6356425226868982}
# INFO | HPO epoch  60/80 | loss=0.3728 | val={'ROC-AUC': 0.7888257575757577, 'PRC-AUC': 0.6641338057685882}
# INFO | HPO epoch  65/80 | loss=0.3579 | val={'ROC-AUC': 0.7899621212121213, 'PRC-AUC': 0.6527474828650839}
# INFO | HPO epoch  70/80 | loss=0.3440 | val={'ROC-AUC': 0.7986742424242425, 'PRC-AUC': 0.6768991128076199}
# INFO | HPO epoch  75/80 | loss=0.3457 | val={'ROC-AUC': 0.796780303030303, 'PRC-AUC': 0.6584224498685921}
# INFO | HPO epoch  80/80 | loss=0.3409 | val={'ROC-AUC': 0.8111742424242424, 'PRC-AUC': 0.6698002882341796}
# INFO | LSTM HPO — trial 4/20 finished | val=-0.812121 | best=-0.812121
# INFO | LSTM — starting trial 5/20
# INFO | HPO epoch   1/80 | loss=0.6922 | val={'ROC-AUC': 0.5662878787878788, 'PRC-AUC': 0.44895769993091716}
# INFO | HPO epoch   5/80 | loss=0.6343 | val={'ROC-AUC': 0.6280303030303032, 'PRC-AUC': 0.517629909581838}
# INFO | HPO epoch  10/80 | loss=0.5440 | val={'ROC-AUC': 0.6354166666666666, 'PRC-AUC': 0.5282067819834302}
# INFO | HPO epoch  15/80 | loss=0.6978 | val={'ROC-AUC': 0.7210227272727273, 'PRC-AUC': 0.5908442187317167}
# INFO | HPO epoch  20/80 | loss=0.4995 | val={'ROC-AUC': 0.7454545454545455, 'PRC-AUC': 0.6555506538271959}
# INFO | HPO epoch  25/80 | loss=0.4678 | val={'ROC-AUC': 0.7369318181818181, 'PRC-AUC': 0.5974099981784433}
# INFO | HPO epoch  30/80 | loss=0.4370 | val={'ROC-AUC': 0.8064393939393939, 'PRC-AUC': 0.6875868992738321}
# INFO | HPO epoch  35/80 | loss=0.4110 | val={'ROC-AUC': 0.7638257575757575, 'PRC-AUC': 0.588844341855847}
# INFO | HPO epoch  40/80 | loss=0.3822 | val={'ROC-AUC': 0.8215909090909091, 'PRC-AUC': 0.7185693333125961}
# INFO | HPO epoch  45/80 | loss=0.3829 | val={'ROC-AUC': 0.8196969696969697, 'PRC-AUC': 0.708982146700431}
# INFO | HPO epoch  50/80 | loss=0.3568 | val={'ROC-AUC': 0.8356060606060606, 'PRC-AUC': 0.7482341958931564}
# INFO | HPO epoch  55/80 | loss=0.3402 | val={'ROC-AUC': 0.8340909090909091, 'PRC-AUC': 0.7191008765412505}
# INFO | HPO epoch  60/80 | loss=0.3276 | val={'ROC-AUC': 0.8321969696969697, 'PRC-AUC': 0.7191047945009652}
# INFO | HPO epoch  65/80 | loss=0.3153 | val={'ROC-AUC': 0.8215909090909091, 'PRC-AUC': 0.7270303695212724}
# INFO | HPO epoch  70/80 | loss=0.2786 | val={'ROC-AUC': 0.8473484848484849, 'PRC-AUC': 0.7400898542657536}
# INFO | HPO epoch  75/80 | loss=0.2705 | val={'ROC-AUC': 0.8534090909090909, 'PRC-AUC': 0.7642989909504142}
# INFO | HPO epoch  80/80 | loss=0.2612 | val={'ROC-AUC': 0.8528409090909091, 'PRC-AUC': 0.780682406168193}
# INFO | LSTM HPO — trial 5/20 finished | val=-0.860417 | best=-0.860417
# INFO | LSTM — starting trial 6/20
# INFO | HPO epoch   1/80 | loss=0.6893 | val={'ROC-AUC': 0.5742424242424242, 'PRC-AUC': 0.4577841673092931}
# INFO | HPO epoch   5/80 | loss=0.5694 | val={'ROC-AUC': 0.6333333333333334, 'PRC-AUC': 0.543188601984493}
# INFO | HPO epoch  10/80 | loss=0.5332 | val={'ROC-AUC': 0.6829545454545455, 'PRC-AUC': 0.5370782284666746}
# INFO | HPO epoch  15/80 | loss=0.4645 | val={'ROC-AUC': 0.7104166666666667, 'PRC-AUC': 0.5635335190653997}
# INFO | HPO epoch  20/80 | loss=0.4313 | val={'ROC-AUC': 0.7022727272727273, 'PRC-AUC': 0.5290115668922455}
# INFO | HPO epoch  25/80 | loss=0.3677 | val={'ROC-AUC': 0.7583333333333333, 'PRC-AUC': 0.5976860778487839}
# INFO | HPO epoch  30/80 | loss=0.3317 | val={'ROC-AUC': 0.7598484848484848, 'PRC-AUC': 0.5829221188724655}
# INFO | HPO epoch  35/80 | loss=0.2913 | val={'ROC-AUC': 0.7706439393939394, 'PRC-AUC': 0.6093599559857883}
# INFO | HPO epoch  40/80 | loss=0.2559 | val={'ROC-AUC': 0.7670454545454545, 'PRC-AUC': 0.6175183843550359}
# INFO | HPO epoch  45/80 | loss=0.2133 | val={'ROC-AUC': 0.7763257575757576, 'PRC-AUC': 0.6118746672879771}
# INFO | HPO epoch  50/80 | loss=0.1550 | val={'ROC-AUC': 0.7831439393939393, 'PRC-AUC': 0.65807001455682}
# INFO | Early stop at epoch 51 (patience=15)
# INFO | LSTM HPO — trial 6/20 finished | val=-0.788636 | best=-0.860417
# INFO | LSTM — starting trial 7/20
# INFO | HPO epoch   1/80 | loss=0.6903 | val={'ROC-AUC': 0.58125, 'PRC-AUC': 0.45604047538016396}
# INFO | HPO epoch   5/80 | loss=0.6392 | val={'ROC-AUC': 0.6221590909090909, 'PRC-AUC': 0.5212753158675683}
# INFO | HPO epoch  10/80 | loss=0.5814 | val={'ROC-AUC': 0.6484848484848486, 'PRC-AUC': 0.5038600639655656}
# INFO | HPO epoch  15/80 | loss=0.5595 | val={'ROC-AUC': 0.6825757575757575, 'PRC-AUC': 0.5446573675249974}
# INFO | HPO epoch  20/80 | loss=0.4907 | val={'ROC-AUC': 0.7071969696969697, 'PRC-AUC': 0.5503107957542797}
# INFO | HPO epoch  25/80 | loss=0.4430 | val={'ROC-AUC': 0.7284090909090908, 'PRC-AUC': 0.583501237589662}
# INFO | HPO epoch  30/80 | loss=0.4382 | val={'ROC-AUC': 0.7386363636363636, 'PRC-AUC': 0.5913069477630778}
# INFO | HPO epoch  35/80 | loss=0.4314 | val={'ROC-AUC': 0.7615530303030303, 'PRC-AUC': 0.6355357581589773}
# INFO | HPO epoch  40/80 | loss=0.4222 | val={'ROC-AUC': 0.7863636363636364, 'PRC-AUC': 0.6763452198583094}
# INFO | HPO epoch  45/80 | loss=0.3891 | val={'ROC-AUC': 0.771969696969697, 'PRC-AUC': 0.6604155023562195}
# INFO | HPO epoch  50/80 | loss=0.4073 | val={'ROC-AUC': 0.7969696969696969, 'PRC-AUC': 0.6624452362563029}
# INFO | HPO epoch  55/80 | loss=0.3897 | val={'ROC-AUC': 0.7609848484848485, 'PRC-AUC': 0.6413944071534812}
# INFO | HPO epoch  60/80 | loss=0.3757 | val={'ROC-AUC': 0.7945075757575758, 'PRC-AUC': 0.6430716164355165}
# INFO | HPO epoch  65/80 | loss=0.3469 | val={'ROC-AUC': 0.7742424242424242, 'PRC-AUC': 0.6443357833662514}
# INFO | Early stop at epoch 65 (patience=15)
# INFO | LSTM HPO — trial 7/20 finished | val=-0.796970 | best=-0.860417
# INFO | LSTM — starting trial 8/20
# INFO | HPO epoch   1/80 | loss=0.6927 | val={'ROC-AUC': 0.5626893939393939, 'PRC-AUC': 0.45034320664929467}
# INFO | HPO epoch   5/80 | loss=0.6786 | val={'ROC-AUC': 0.5746212121212122, 'PRC-AUC': 0.4659070203608515}
# INFO | HPO epoch  10/80 | loss=0.6342 | val={'ROC-AUC': 0.6361742424242423, 'PRC-AUC': 0.5329672196421484}
# INFO | HPO epoch  15/80 | loss=0.5554 | val={'ROC-AUC': 0.6429924242424242, 'PRC-AUC': 0.5417700971639797}
# INFO | HPO epoch  20/80 | loss=0.5299 | val={'ROC-AUC': 0.6859848484848485, 'PRC-AUC': 0.5681879541870661}
# INFO | HPO epoch  25/80 | loss=0.5124 | val={'ROC-AUC': 0.7147727272727272, 'PRC-AUC': 0.5998832866926705}
# INFO | HPO epoch  30/80 | loss=0.5059 | val={'ROC-AUC': 0.7159090909090909, 'PRC-AUC': 0.6353074746109054}
# INFO | HPO epoch  35/80 | loss=0.5017 | val={'ROC-AUC': 0.7399621212121212, 'PRC-AUC': 0.6298413883407288}
# INFO | HPO epoch  40/80 | loss=0.4896 | val={'ROC-AUC': 0.7520833333333333, 'PRC-AUC': 0.6463041876982867}
# INFO | HPO epoch  45/80 | loss=0.4898 | val={'ROC-AUC': 0.7537878787878789, 'PRC-AUC': 0.656175100204011}
# INFO | HPO epoch  50/80 | loss=0.4691 | val={'ROC-AUC': 0.7740530303030303, 'PRC-AUC': 0.6631984308765164}
# INFO | HPO epoch  55/80 | loss=0.4462 | val={'ROC-AUC': 0.7511363636363637, 'PRC-AUC': 0.6631763356641569}
# INFO | Early stop at epoch 59 (patience=15)
# INFO | LSTM HPO — trial 8/20 finished | val=-0.774053 | best=-0.860417
# INFO | LSTM — starting trial 9/20
# INFO | HPO epoch   1/80 | loss=0.6907 | val={'ROC-AUC': 0.5801136363636364, 'PRC-AUC': 0.4449342669540314}
# INFO | HPO epoch   5/80 | loss=0.5937 | val={'ROC-AUC': 0.6575757575757576, 'PRC-AUC': 0.5645641572458334}
# INFO | HPO epoch  10/80 | loss=0.4874 | val={'ROC-AUC': 0.7738636363636364, 'PRC-AUC': 0.6850935419813253}
# INFO | HPO epoch  15/80 | loss=0.3981 | val={'ROC-AUC': 0.7835227272727273, 'PRC-AUC': 0.5923988896945881}
# INFO | HPO epoch  20/80 | loss=0.3894 | val={'ROC-AUC': 0.731439393939394, 'PRC-AUC': 0.5490083518608758}
# INFO | HPO epoch  25/80 | loss=0.3038 | val={'ROC-AUC': 0.7884469696969697, 'PRC-AUC': 0.6041337638390815}
# INFO | Early stop at epoch 29 (patience=15)
# INFO | LSTM HPO — trial 9/20 finished | val=-0.824053 | best=-0.860417
# INFO | LSTM — starting trial 10/20
# INFO | HPO epoch   1/80 | loss=0.6893 | val={'ROC-AUC': 0.5821969696969697, 'PRC-AUC': 0.4697160219786558}
# INFO | HPO epoch   5/80 | loss=0.6254 | val={'ROC-AUC': 0.6789772727272727, 'PRC-AUC': 0.5416569386238751}
# INFO | HPO epoch  10/80 | loss=0.5267 | val={'ROC-AUC': 0.6719696969696969, 'PRC-AUC': 0.5432483112874126}
# INFO | HPO epoch  15/80 | loss=0.4895 | val={'ROC-AUC': 0.6922348484848485, 'PRC-AUC': 0.5790649984133696}
# INFO | HPO epoch  20/80 | loss=0.4382 | val={'ROC-AUC': 0.7039772727272726, 'PRC-AUC': 0.5803908224542755}
# INFO | Early stop at epoch 22 (patience=15)
# INFO | LSTM HPO — trial 10/20 finished | val=-0.717992 | best=-0.860417
# INFO | LSTM — starting trial 11/20
# INFO | HPO epoch   1/80 | loss=0.6849 | val={'ROC-AUC': 0.5785984848484848, 'PRC-AUC': 0.4572131018247034}
# INFO | HPO epoch   5/80 | loss=0.5670 | val={'ROC-AUC': 0.6587121212121211, 'PRC-AUC': 0.5718354043291348}
# INFO | HPO epoch  10/80 | loss=0.4532 | val={'ROC-AUC': 0.7759469696969696, 'PRC-AUC': 0.6332620720710818}
# INFO | HPO epoch  15/80 | loss=0.3740 | val={'ROC-AUC': 0.831060606060606, 'PRC-AUC': 0.7074762971551238}
# INFO | HPO epoch  20/80 | loss=0.3339 | val={'ROC-AUC': 0.8297348484848485, 'PRC-AUC': 0.707674031648859}
# INFO | HPO epoch  25/80 | loss=0.2776 | val={'ROC-AUC': 0.8356060606060607, 'PRC-AUC': 0.7246212546164078}
# INFO | HPO epoch  30/80 | loss=0.2083 | val={'ROC-AUC': 0.827840909090909, 'PRC-AUC': 0.712005410194062}
# INFO | Early stop at epoch 32 (patience=15)
# INFO | LSTM HPO — trial 11/20 finished | val=-0.849811 | best=-0.860417
# INFO | LSTM — starting trial 12/20
# INFO | HPO epoch   1/80 | loss=0.6871 | val={'ROC-AUC': 0.5706439393939394, 'PRC-AUC': 0.4351896319833247}
# INFO | HPO epoch   5/80 | loss=0.5894 | val={'ROC-AUC': 0.6375, 'PRC-AUC': 0.527704923294487}
# INFO | HPO epoch  10/80 | loss=0.4352 | val={'ROC-AUC': 0.7270833333333333, 'PRC-AUC': 0.582394143209705}
# INFO | HPO epoch  15/80 | loss=0.3898 | val={'ROC-AUC': 0.7893939393939394, 'PRC-AUC': 0.6214454735688946}
# INFO | HPO epoch  20/80 | loss=0.3198 | val={'ROC-AUC': 0.7592803030303029, 'PRC-AUC': 0.612967842632529}
# INFO | HPO epoch  25/80 | loss=0.2901 | val={'ROC-AUC': 0.7721590909090909, 'PRC-AUC': 0.637943209034494}
# INFO | Early stop at epoch 29 (patience=15)
# INFO | LSTM HPO — trial 12/20 finished | val=-0.794318 | best=-0.860417
# INFO | LSTM — starting trial 13/20
# INFO | HPO epoch   1/80 | loss=0.6851 | val={'ROC-AUC': 0.590719696969697, 'PRC-AUC': 0.47324143563773813}
# INFO | HPO epoch   5/80 | loss=0.5719 | val={'ROC-AUC': 0.675, 'PRC-AUC': 0.5626624041936661}
# INFO | HPO epoch  10/80 | loss=0.4391 | val={'ROC-AUC': 0.7653409090909091, 'PRC-AUC': 0.6465790193623071}
# INFO | HPO epoch  15/80 | loss=0.3939 | val={'ROC-AUC': 0.7935606060606061, 'PRC-AUC': 0.6271766200656727}
# INFO | HPO epoch  20/80 | loss=0.3337 | val={'ROC-AUC': 0.7986742424242423, 'PRC-AUC': 0.6591819194404039}
# INFO | HPO epoch  25/80 | loss=0.2958 | val={'ROC-AUC': 0.7193181818181817, 'PRC-AUC': 0.5742848850849624}
# INFO | HPO epoch  30/80 | loss=0.2511 | val={'ROC-AUC': 0.8106060606060606, 'PRC-AUC': 0.706283235337726}
# INFO | HPO epoch  35/80 | loss=0.2037 | val={'ROC-AUC': 0.8204545454545454, 'PRC-AUC': 0.6945054507957877}
# INFO | HPO epoch  40/80 | loss=0.1701 | val={'ROC-AUC': 0.7893939393939393, 'PRC-AUC': 0.6666494482938613}
# INFO | HPO epoch  45/80 | loss=0.1615 | val={'ROC-AUC': 0.8003787878787878, 'PRC-AUC': 0.6844235876282756}
# INFO | HPO epoch  50/80 | loss=0.1000 | val={'ROC-AUC': 0.7928030303030303, 'PRC-AUC': 0.6879315897107602}
# INFO | Early stop at epoch 52 (patience=15)
# INFO | LSTM HPO — trial 13/20 finished | val=-0.820455 | best=-0.860417
# INFO | LSTM — starting trial 14/20
# INFO | HPO epoch   1/80 | loss=0.6890 | val={'ROC-AUC': 0.5897727272727272, 'PRC-AUC': 0.4740417245844759}
# INFO | HPO epoch   5/80 | loss=0.5784 | val={'ROC-AUC': 0.649621212121212, 'PRC-AUC': 0.5289442645613924}
# INFO | HPO epoch  10/80 | loss=0.4578 | val={'ROC-AUC': 0.7899621212121211, 'PRC-AUC': 0.6581165811156104}
# INFO | HPO epoch  15/80 | loss=0.3727 | val={'ROC-AUC': 0.818371212121212, 'PRC-AUC': 0.7021269963850669}
# INFO | HPO epoch  20/80 | loss=0.3232 | val={'ROC-AUC': 0.7984848484848486, 'PRC-AUC': 0.6930824011461836}
# INFO | HPO epoch  25/80 | loss=0.2742 | val={'ROC-AUC': 0.8212121212121213, 'PRC-AUC': 0.7358758234987325}
# INFO | HPO epoch  30/80 | loss=0.2340 | val={'ROC-AUC': 0.812310606060606, 'PRC-AUC': 0.6903480333861848}
# INFO | Early stop at epoch 33 (patience=15)
# INFO | LSTM HPO — trial 14/20 finished | val=-0.832955 | best=-0.860417
# INFO | LSTM — starting trial 15/20
# INFO | HPO epoch   1/80 | loss=0.6880 | val={'ROC-AUC': 0.5856060606060606, 'PRC-AUC': 0.4631418496233655}
# INFO | HPO epoch   5/80 | loss=0.5470 | val={'ROC-AUC': 0.6700757575757575, 'PRC-AUC': 0.5409815813173164}
# INFO | HPO epoch  10/80 | loss=0.4468 | val={'ROC-AUC': 0.8056818181818183, 'PRC-AUC': 0.6413615417935151}
# INFO | HPO epoch  15/80 | loss=0.3925 | val={'ROC-AUC': 0.8001893939393938, 'PRC-AUC': 0.6454473063283602}
# INFO | HPO epoch  20/80 | loss=0.3883 | val={'ROC-AUC': 0.8259469696969697, 'PRC-AUC': 0.6897964087681765}
# INFO | HPO epoch  25/80 | loss=0.2812 | val={'ROC-AUC': 0.8113636363636363, 'PRC-AUC': 0.6526693200340167}
# INFO | HPO epoch  30/80 | loss=0.2398 | val={'ROC-AUC': 0.8160984848484848, 'PRC-AUC': 0.6848656481517842}
# INFO | HPO epoch  35/80 | loss=0.2167 | val={'ROC-AUC': 0.8071969696969696, 'PRC-AUC': 0.6501240042000127}
# INFO | HPO epoch  40/80 | loss=0.1320 | val={'ROC-AUC': 0.8153409090909091, 'PRC-AUC': 0.6992047154116692}
# INFO | Early stop at epoch 42 (patience=15)
# INFO | LSTM HPO — trial 15/20 finished | val=-0.859091 | best=-0.860417
# INFO | LSTM — starting trial 16/20
# INFO | HPO epoch   1/80 | loss=0.6814 | val={'ROC-AUC': 0.5662878787878788, 'PRC-AUC': 0.47623470436711957}
# INFO | HPO epoch   5/80 | loss=0.6103 | val={'ROC-AUC': 0.6960227272727273, 'PRC-AUC': 0.5785629496670269}
# INFO | HPO epoch  10/80 | loss=0.4607 | val={'ROC-AUC': 0.7386363636363636, 'PRC-AUC': 0.6363131422354062}
# INFO | HPO epoch  15/80 | loss=0.3856 | val={'ROC-AUC': 0.7895833333333334, 'PRC-AUC': 0.7093339073168503}
# INFO | HPO epoch  20/80 | loss=0.3461 | val={'ROC-AUC': 0.8070075757575758, 'PRC-AUC': 0.7360711791270015}
# INFO | HPO epoch  25/80 | loss=0.2929 | val={'ROC-AUC': 0.8270833333333332, 'PRC-AUC': 0.7528834278102131}
# INFO | HPO epoch  30/80 | loss=0.2522 | val={'ROC-AUC': 0.8414772727272727, 'PRC-AUC': 0.7868224438357587}
# INFO | HPO epoch  35/80 | loss=0.2129 | val={'ROC-AUC': 0.8115530303030303, 'PRC-AUC': 0.7446261880628101}
# INFO | HPO epoch  40/80 | loss=0.1536 | val={'ROC-AUC': 0.7956439393939394, 'PRC-AUC': 0.7046026970094341}
# INFO | HPO epoch  45/80 | loss=0.0965 | val={'ROC-AUC': 0.8357954545454546, 'PRC-AUC': 0.7868485272307459}
# INFO | Early stop at epoch 45 (patience=15)
# INFO | LSTM HPO — trial 16/20 finished | val=-0.841477 | best=-0.860417
# INFO | LSTM — starting trial 17/20
# INFO | HPO epoch   1/80 | loss=0.6840 | val={'ROC-AUC': 0.6056818181818181, 'PRC-AUC': 0.500155647706483}
# INFO | HPO epoch   5/80 | loss=0.5610 | val={'ROC-AUC': 0.6410984848484849, 'PRC-AUC': 0.5234665928734095}
# INFO | HPO epoch  10/80 | loss=0.4470 | val={'ROC-AUC': 0.7759469696969696, 'PRC-AUC': 0.6255352617437013}
# INFO | HPO epoch  15/80 | loss=0.4073 | val={'ROC-AUC': 0.7945075757575758, 'PRC-AUC': 0.6652267846424773}
# INFO | HPO epoch  20/80 | loss=0.3341 | val={'ROC-AUC': 0.7829545454545455, 'PRC-AUC': 0.6681780247098275}
# INFO | HPO epoch  25/80 | loss=0.2837 | val={'ROC-AUC': 0.8285984848484849, 'PRC-AUC': 0.7023813527801602}
# INFO | HPO epoch  30/80 | loss=0.2509 | val={'ROC-AUC': 0.8276515151515151, 'PRC-AUC': 0.7107445087607462}
# INFO | HPO epoch  35/80 | loss=0.2063 | val={'ROC-AUC': 0.8287878787878787, 'PRC-AUC': 0.7307044037952533}
# INFO | HPO epoch  40/80 | loss=0.1642 | val={'ROC-AUC': 0.8128787878787879, 'PRC-AUC': 0.7082577287178946}
# INFO | Early stop at epoch 43 (patience=15)
# INFO | LSTM HPO — trial 17/20 finished | val=-0.838068 | best=-0.860417
# INFO | LSTM — starting trial 18/20
# INFO | HPO epoch   1/80 | loss=0.6859 | val={'ROC-AUC': 0.603030303030303, 'PRC-AUC': 0.49768916373784466}
# INFO | HPO epoch   5/80 | loss=0.5615 | val={'ROC-AUC': 0.665340909090909, 'PRC-AUC': 0.5276256458557991}
# INFO | HPO epoch  10/80 | loss=0.4451 | val={'ROC-AUC': 0.8102272727272727, 'PRC-AUC': 0.6641270811130198}
# INFO | HPO epoch  15/80 | loss=0.3912 | val={'ROC-AUC': 0.7791666666666666, 'PRC-AUC': 0.6616716371485182}
# INFO | HPO epoch  20/80 | loss=0.3055 | val={'ROC-AUC': 0.8458333333333333, 'PRC-AUC': 0.7479590147091585}
# INFO | HPO epoch  25/80 | loss=0.2428 | val={'ROC-AUC': 0.8096590909090909, 'PRC-AUC': 0.6669370435988144}
# INFO | HPO epoch  30/80 | loss=0.2105 | val={'ROC-AUC': 0.7935606060606061, 'PRC-AUC': 0.6581038202352234}
# INFO | HPO epoch  35/80 | loss=0.1639 | val={'ROC-AUC': 0.7958333333333334, 'PRC-AUC': 0.7086521037885966}
# INFO | Early stop at epoch 35 (patience=15)
# INFO | LSTM HPO — trial 18/20 finished | val=-0.845833 | best=-0.860417
# INFO | LSTM — starting trial 19/20
# INFO | HPO epoch   1/80 | loss=0.6917 | val={'ROC-AUC': 0.5721590909090909, 'PRC-AUC': 0.4486758960736028}
# INFO | HPO epoch   5/80 | loss=0.6381 | val={'ROC-AUC': 0.6429924242424243, 'PRC-AUC': 0.5443841525745949}
# INFO | HPO epoch  10/80 | loss=0.5485 | val={'ROC-AUC': 0.7149621212121211, 'PRC-AUC': 0.5999581182940116}
# INFO | HPO epoch  15/80 | loss=0.4906 | val={'ROC-AUC': 0.7509469696969697, 'PRC-AUC': 0.6527518549442624}
# INFO | HPO epoch  20/80 | loss=0.4507 | val={'ROC-AUC': 0.7443181818181818, 'PRC-AUC': 0.6341327683796061}
# INFO | HPO epoch  25/80 | loss=0.4301 | val={'ROC-AUC': 0.7846590909090909, 'PRC-AUC': 0.7119974986868877}
# INFO | HPO epoch  30/80 | loss=0.4005 | val={'ROC-AUC': 0.7668560606060606, 'PRC-AUC': 0.6505945426396832}
# INFO | HPO epoch  35/80 | loss=0.3932 | val={'ROC-AUC': 0.8102272727272727, 'PRC-AUC': 0.7279270583486632}
# INFO | HPO epoch  40/80 | loss=0.3627 | val={'ROC-AUC': 0.8304924242424243, 'PRC-AUC': 0.7538499732193522}
# INFO | HPO epoch  45/80 | loss=0.3702 | val={'ROC-AUC': 0.8524621212121212, 'PRC-AUC': 0.7598143799855929}
# INFO | HPO epoch  50/80 | loss=0.3335 | val={'ROC-AUC': 0.8382575757575758, 'PRC-AUC': 0.7321135542577589}
# INFO | HPO epoch  55/80 | loss=0.3405 | val={'ROC-AUC': 0.8649621212121212, 'PRC-AUC': 0.766687001955147}
# INFO | HPO epoch  60/80 | loss=0.3090 | val={'ROC-AUC': 0.8638257575757576, 'PRC-AUC': 0.745749023686586}
# INFO | HPO epoch  65/80 | loss=0.2935 | val={'ROC-AUC': 0.8691287878787879, 'PRC-AUC': 0.769258148405416}
# INFO | HPO epoch  70/80 | loss=0.2731 | val={'ROC-AUC': 0.8515151515151516, 'PRC-AUC': 0.7592519448292657}
# INFO | HPO epoch  75/80 | loss=0.2816 | val={'ROC-AUC': 0.8384469696969696, 'PRC-AUC': 0.73046464838825}
# INFO | HPO epoch  80/80 | loss=0.2307 | val={'ROC-AUC': 0.8541666666666666, 'PRC-AUC': 0.7665540014016405}
# INFO | LSTM HPO — trial 19/20 finished | val=-0.870076 | best=-0.870076
# INFO | LSTM — starting trial 20/20
# INFO | HPO epoch   1/80 | loss=0.6924 | val={'ROC-AUC': 0.5657196969696969, 'PRC-AUC': 0.45477418821700244}
# INFO | HPO epoch   5/80 | loss=0.6505 | val={'ROC-AUC': 0.6142045454545454, 'PRC-AUC': 0.5288920976192729}
# INFO | HPO epoch  10/80 | loss=0.5639 | val={'ROC-AUC': 0.6272727272727273, 'PRC-AUC': 0.5585770111002447}
# INFO | HPO epoch  15/80 | loss=0.5204 | val={'ROC-AUC': 0.7354166666666666, 'PRC-AUC': 0.64824395124231}
# INFO | HPO epoch  20/80 | loss=0.4723 | val={'ROC-AUC': 0.7755681818181818, 'PRC-AUC': 0.6925198095062886}
# INFO | HPO epoch  25/80 | loss=0.4465 | val={'ROC-AUC': 0.7931818181818181, 'PRC-AUC': 0.7051084541937732}
# INFO | HPO epoch  30/80 | loss=0.4231 | val={'ROC-AUC': 0.802651515151515, 'PRC-AUC': 0.708242447068603}
# INFO | HPO epoch  35/80 | loss=0.4134 | val={'ROC-AUC': 0.818939393939394, 'PRC-AUC': 0.7451167591853862}
# INFO | HPO epoch  40/80 | loss=0.3899 | val={'ROC-AUC': 0.8113636363636364, 'PRC-AUC': 0.7205509149921414}
# INFO | HPO epoch  45/80 | loss=0.3619 | val={'ROC-AUC': 0.8261363636363637, 'PRC-AUC': 0.7683792021398029}
# INFO | HPO epoch  50/80 | loss=0.3274 | val={'ROC-AUC': 0.8145833333333333, 'PRC-AUC': 0.7230128710779989}
# INFO | HPO epoch  55/80 | loss=0.3213 | val={'ROC-AUC': 0.8214015151515152, 'PRC-AUC': 0.7242890518043704}
# INFO | HPO epoch  60/80 | loss=0.3075 | val={'ROC-AUC': 0.8136363636363637, 'PRC-AUC': 0.7221969365701473}
# INFO | HPO epoch  65/80 | loss=0.3072 | val={'ROC-AUC': 0.8149621212121211, 'PRC-AUC': 0.6912278262346432}
# INFO | Early stop at epoch 69 (patience=15)
# INFO | LSTM HPO — trial 20/20 finished | val=-0.837311 | best=-0.870076
# INFO | Epoch  10 | loss=0.5626 | val={'ROC-AUC': 0.6556818181818181, 'PRC-AUC': 0.5690062047668591}
# INFO | Epoch  20 | loss=0.4694 | val={'ROC-AUC': 0.7195075757575757, 'PRC-AUC': 0.6274561648110925}
# INFO | Epoch  30 | loss=0.4043 | val={'ROC-AUC': 0.7901515151515152, 'PRC-AUC': 0.6822207296240482}
# INFO | Epoch  40 | loss=0.3534 | val={'ROC-AUC': 0.7982954545454546, 'PRC-AUC': 0.7110615291080341}
# INFO | Epoch  50 | loss=0.3363 | val={'ROC-AUC': 0.7916666666666666, 'PRC-AUC': 0.6986448207452253}
# INFO | Epoch  60 | loss=0.3195 | val={'ROC-AUC': 0.8208333333333334, 'PRC-AUC': 0.7466697644602405}
# INFO | Epoch  70 | loss=0.2713 | val={'ROC-AUC': 0.8125, 'PRC-AUC': 0.7521769696319627}
# INFO | Epoch  80 | loss=0.2313 | val={'ROC-AUC': 0.8138257575757576, 'PRC-AUC': 0.7588960840814203}
# INFO | Saved SMILES LSTM → /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/gpu/bace_partial.json
#    scaffold test: {'ROC-AUC': 0.8094149037545264, 'PRC-AUC': 0.6937837817278842}

# %% [markdown]
# ### Finalize GPU + merge

# %%
finalize_dataset_results(DATASET_SLUG, PARTIAL_PATH, RESULTS_DIR, TASK_TYPE,
    plot_title=f"BACE – ROC-AUC by Model (higher is better) (GPU, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
cpu_partial = RESULTS_ROOT / "cpu" / f"{DATASET_SLUG}_partial.json"
if cpu_partial.exists():
    merge_combined_results(DATASET_SLUG, cpu_partial, PARTIAL_PATH, RESULTS_ROOT / "combined",
        TASK_TYPE, plot_title=f"BACE – ROC-AUC by Model (higher is better) (all models, {SPLIT_MODE}, seed={SPLIT_SEED})", ylabel="ROC-AUC", minimize=False)
else:
    print("Run CPU notebook first for combined results.")
# Out:
# === BACE Results (5/12 models) ===
#                             ROC-AUC          PRC-AUC
# Model
# GIN (2D)            0.8107 ± 0.0000  0.6653 ± 0.0000
# D-MPNN (2D)         0.8256 ± 0.0000  0.6674 ± 0.0000
# GIN (3D)            0.8790 ± 0.0000  0.7156 ± 0.0000
# SchNet (3D coords)  0.7905 ± 0.0000  0.6961 ± 0.0000
# SMILES LSTM         0.8094 ± 0.0000  0.6938 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/gpu/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/gpu/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/gpu/bace_partial.json
# === BACE Results (12/12 models) ===
#                                ROC-AUC          PRC-AUC
# Model
# Morgan + RF            0.8694 ± 0.0000  0.7671 ± 0.0000
# Morgan + SVM           0.8098 ± 0.0000  0.6513 ± 0.0000
# Morgan + XGBoost       0.8763 ± 0.0000  0.7882 ± 0.0000
# Descriptors + RF       0.8399 ± 0.0000  0.7480 ± 0.0000
# Descriptors + SVM      0.8191 ± 0.0000  0.7379 ± 0.0000
# Descriptors + XGBoost  0.8269 ± 0.0000  0.7187 ± 0.0000
# Combined + XGBoost     0.8271 ± 0.0000  0.7143 ± 0.0000
# GIN (2D)               0.8107 ± 0.0000  0.6653 ± 0.0000
# D-MPNN (2D)            0.8256 ± 0.0000  0.6674 ± 0.0000
# GIN (3D)               0.8790 ± 0.0000  0.7156 ± 0.0000
# SchNet (3D coords)     0.7905 ± 0.0000  0.6961 ± 0.0000
# SMILES LSTM            0.8094 ± 0.0000  0.6938 ± 0.0000
#
# Final CSV : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/combined/bace_results.csv
# Plot      : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/combined/bace_auc_comparison.png
# Partial   : /Users/emirerdem/Library/Mobile Documents/com~apple~CloudDocs/Projects/Thesis/molnet_esol_project/benchmark_v5/results/seed_2/scaffold/combined/bace_partial.json
